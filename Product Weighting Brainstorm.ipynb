# %% [markdown]
# # Product Weighting Project

# %% [markdown]
#                                          Data Reduction - Food Purchased In Store

# %% [markdown]
# ###### Import Necessary Libraries

# %%
import pandas as pd

# %% [markdown]
# Read in Data

# %%
Labelled = pd.read_csv(r'C:\Users\medekar\Desktop\Product Weighting Project\Data\Processed\Labelling2021_watercress.csv')

# %% [markdown]
# ###### Looking at this data Alphabetically starting from A.

# %%
Prod_A = Labelled.loc[Labelled['Food Name'].str.startswith('A')]
Prod_A.head()
# Out:
#   Food Code                        Food Name  \
# 0    13-145           Ackee, canned, drained
# 1    13-146                      Agar, dried
# 2    13-147  Agar, dried, soaked and drained
# 3    13-148             Alfalfa sprouts, raw
# 4    13-801                 Allspice, ground
#
#                          Description Group Previous  \
# 0                             8 cans    DG      554
# 1                 Literature sources    DG      NaN
# 2                 Literature sources    DG      NaN
# 3  Analytical and literature sources    DG      NaN
# 4                 Literature sources     H      NaN
#
#                                 Main data references Footnote Energy (kJ)  \
# 0  MW4, 1978; and Vegetables, Herbs and Spices Su...      NaN         639
# 1  Wu Leung et al. (1972) Food composition table ...      NaN         721
# 2  Wu Leung et al. (1972) Food composition table ...      NaN         127
# 3      Vegetables, Herbs and Spices Supplement, 1991      NaN         113
# 4  Marsh et al. (1977) Composition of foods: spic...      NaN        1536
#
#   Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g)  \
# 0           155     15.2          4.44              0.8        0.8          0
# 1           180      1.2           0.3                0          0          0
# 2            32      0.1             0                0          0          0
# 3            27      0.7          0.07              0.3        0.3          0
# 4           366      8.7           2.5             55.1       55.1          0
#
#   Fibre (g)  Protein (g) Salt (g)
# 0       1.8          2.9      0.6
# 1      81.1          1.6     0.28
# 2        15          0.2     0.03
# 3       1.7          4.0     0.02
# 4      21.6          6.1     0.19

# %% [markdown]
# Products within a Group (provide identification of the food group and food type to which the food belongs)

# %%
Prod_A.groupby('Group')['Food Name'].count()
# Out:
# Group
# AA     1
# DG    22
# DR     3
# F      2
# FA    24
# FC     1
# GA     4
# H      3
# JA     1
# JC     1
# PE     1
# WC     1
# Name: Food Name, dtype: int64

# %% [markdown]
# ## *Reducing products based on its most basic form. Improve as you go on*

# %% [markdown]
#                                               Cereals and cereal products

# %% [markdown]
# Flours, grains and starches

# %%
AA = Prod_A.loc[Prod_A['Group']== 'AA']
AA
# Out:
#    Food Code  Food Name                     Description Group Previous  \
# 40    11-001  Arrowroot  2 samples from different shops    AA      NaN
#
#         Main data references Footnote Energy (kJ) Energy (kcal)  Fat (g)  \
# 40  MW3, 1960. Reviewed 2014      NaN        1471           346      0.1
#
#    Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 40          0.02             85.5          0       85.5       0.9
#
#     Protein (g) Salt (g)
# 40          0.4     0.01

# %%
AA['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_17356\2826330813.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AA['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
#                                                        Vegetables

# %% [markdown]
# Vegetables, general

# %%
DG = Prod_A.loc[Prod_A['Group']== 'DG']
DG.head()
# Out:
#   Food Code                                  Food Name  \
# 0    13-145                     Ackee, canned, drained
# 1    13-146                                Agar, dried
# 2    13-147            Agar, dried, soaked and drained
# 3    13-148                       Alfalfa sprouts, raw
# 9    13-150  Amaranth leaves, boiled in unsalted water
#
#                          Description Group Previous  \
# 0                             8 cans    DG      554
# 1                 Literature sources    DG      NaN
# 2                 Literature sources    DG      NaN
# 3  Analytical and literature sources    DG      NaN
# 9               Calculation from raw    DG      NaN
#
#                                 Main data references Footnote Energy (kJ)  \
# 0  MW4, 1978; and Vegetables, Herbs and Spices Su...      NaN         639
# 1  Wu Leung et al. (1972) Food composition table ...      NaN         721
# 2  Wu Leung et al. (1972) Food composition table ...      NaN         127
# 3      Vegetables, Herbs and Spices Supplement, 1991      NaN         113
# 9  Wu Leung et al. (1972) Food composition table ...      NaN         102
#
#   Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g)  \
# 0           155     15.2          4.44              0.8        0.8          0
# 1           180      1.2           0.3                0          0          0
# 2            32      0.1             0                0          0          0
# 3            27      0.7          0.07              0.3        0.3          0
# 9            25      0.3           0.1              0.3        0.2        0.1
#
#   Fibre (g)  Protein (g) Salt (g)
# 0       1.8          2.9      0.6
# 1      81.1          1.6     0.28
# 2        15          0.2     0.03
# 3       1.7          4.0     0.02
# 9       4.4          3.0     0.03

# %% [markdown]
# **Reduced**

# %%
Priority_DG = ['Ackee, canned, drained','Agar, dried','Alfalfa sprouts, raw','Amaranth leaves, raw','Arrowhead, raw','Artichoke, globe, raw','Asparagus, raw','Aubergine, raw']

# %%
Filt_DG = DG[DG['Food Name'].isin(Priority_DG)]
Filt_DG
# Out:
#    Food Code               Food Name                        Description Group  \
# 0     13-145  Ackee, canned, drained                             8 cans    DG
# 1     13-146             Agar, dried                 Literature sources    DG
# 3     13-148    Alfalfa sprouts, raw  Analytical and literature sources    DG
# 10    13-149    Amaranth leaves, raw                 Literature sources    DG
# 39    13-151          Arrowhead, raw                 Literature sources    DG
# 43    13-153   Artichoke, globe, raw                 Literature sources    DG
# 47    13-157          Asparagus, raw        Tough base of stems removed    DG
# 55    13-161          Aubergine, raw                       Ends trimmed    DG
#
#    Previous                               Main data references Footnote  \
# 0       554  MW4, 1978; and Vegetables, Herbs and Spices Su...      NaN
# 1       NaN  Wu Leung et al. (1972) Food composition table ...      NaN
# 3       NaN      Vegetables, Herbs and Spices Supplement, 1991      NaN
# 10      NaN  Wu Leung et al. (1972) Food composition table ...      NaN
# 39      NaN  Haytowitz and Matthews (1984) Composition of f...      NaN
# 43      NaN      Vegetables, Herbs and Spices Supplement, 1991      NaN
# 47  50-737   Reviewed 2013. IFR, The nutritional compositio...      NaN
# 55  50-739   Reviewed 2013. IFR, The nutritional compositio...      NaN
#
#    Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 0          639           155     15.2          4.44              0.8
# 1          721           180      1.2           0.3                0
# 3          113            27      0.7          0.07              0.3
# 10         111            27      0.3           0.1              0.3
# 39         447           106      0.3          0.03             19.5
# 43         120            29      0.2           0.1              1.3
# 47         120            29      0.6           0.1                2
# 55          84            20      0.4           0.1              2.2
#
#    Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 0         0.8          0       1.8          2.9      0.6
# 1           0          0      81.1          1.6     0.28
# 3         0.3          0       1.7          4.0     0.02
# 10        0.2        0.1       4.4          3.5     0.03
# 39        0.9       18.6       2.4          5.0     0.06
# 43        1.3          0       5.4          2.8     0.07
# 47        1.9        0.1       1.7          2.9        0
# 55          2        0.2         2          0.9     0.01

# %%
Filt_DG['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_17356\1311392366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DG['Super Group'] = 'Vegetables'

# %% [markdown]
# Vegetable Dishes

# %%
DR = Prod_A.loc[Prod_A['Group']== 'DR']
DR
# Out:
#    Food Code                                          Food Name  \
# 56    15-001     Aubergine, stuffed with lentils and vegetables
# 57    15-662                       Aubergine, stuffed with rice
# 58    15-663  Aubergine, stuffed with vegetables, cheese top...
#
#                                           Description Group Previous  \
# 56  Recipe from dietary survey records. Whole dish...    DR      NaN
# 57  Rice, tomato, onion and raisin stuffing. Recip...    DR  15-385
# 58  Tomato, mushroom and onion stuffing. Recipe fr...    DR  15-386
#
#                    Main data references Footnote Energy (kJ) Energy (kcal)  \
# 56  As Vegetable Dishes Supplement 1992      NaN         283            68
# 57                         Updated 2014      NaN         378            90
# 58                         Updated 2014      NaN         523           126
#
#     Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 56      4.6           0.5              3.6        1.6        1.9       1.9
# 57      2.1          0.22             14.8        5.9        8.9       2.1
# 58      9.7          3.48              3.4        3.2        0.2       2.2
#
#     Protein (g) Salt (g)
# 56          2.1      0.2
# 57          1.9     0.02
# 58          5.3     0.27

# %%
DR['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_17356\1901232877.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DR['Super Group'] = 'Vegetables'

# %%
DR['Food Name'].unique()
# Out:
# array(['Aubergine, stuffed with lentils and vegetables',
#        'Aubergine, stuffed with rice',
#        'Aubergine, stuffed with vegetables, cheese topping'], dtype=object)

# %% [markdown]
#                                                         Fruit

# %%
F = Prod_A.loc[Prod_A['Group']== 'F']
F
# Out:
#    Food Code                                          Food Name  \
# 21    14-362           Apples, cooking, raw, flesh only, peeled
# 22    14-363  Apples, cooking, raw, flesh only, weighed with...
#
#                                           Description Group Previous  \
# 21  Bramley apples and unspecified. Analytical dat...     F  14-002
# 22            Bramley variety; calculated from 14-362     F  14-003
#
#                                  Main data references Footnote Energy (kJ)  \
# 21  LGC, Nutritional composition of fresh fruit, 1...      NaN         187
# 22  LGC, Nutritional composition of fresh fruit, 1...      NaN         136
#
#    Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 21            44      0.3          0.06              8.9        8.9
# 22            32      0.2          0.04              6.5        6.5
#
#    Starch (g) Fibre (g)  Protein (g) Salt (g)
# 21          0       1.7          0.3     0.01
# 22          0       1.2          0.3        0

# %%
F['Food Name'].unique()
# Out:
# array(['Apples, cooking, raw, flesh only, peeled',
#        'Apples, cooking, raw, flesh only, weighed with skin and core'],
#       dtype=object)

# %% [markdown]
# **Reduced**

# %%
Filt_F = F.loc[F['Food Name'] == 'Apples, cooking, raw, flesh only, weighed with skin and core']
Filt_F
# Out:
#    Food Code                                          Food Name  \
# 22    14-363  Apples, cooking, raw, flesh only, weighed with...
#
#                                 Description Group Previous  \
# 22  Bramley variety; calculated from 14-362     F  14-003
#
#                                  Main data references Footnote Energy (kJ)  \
# 22  LGC, Nutritional composition of fresh fruit, 1...      NaN         136
#
#    Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 22            32      0.2          0.04              6.5        6.5
#
#    Starch (g) Fibre (g)  Protein (g) Salt (g)
# 22          0       1.2          0.3        0

# %%
Filt_F['Super Group'] = 'Fruit'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_17356\4228301647.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_F['Super Group'] = 'Fruit'

# %% [markdown]
# Fruit General

# %%
FA = Prod_A.loc[Prod_A['Group']== 'FA']
FA
# Out:
#    Food Code                                          Food Name  \
# 11    14-001                                               Amla
# 17    14-344      Apples, cooking, baked with sugar, flesh only
# 18    14-345  Apples, cooking, baked with sugar, flesh only,...
# 19    14-342   Apples, cooking, baked without sugar, flesh only
# 20    14-343  Apples, cooking, baked without sugar, flesh on...
# 23    14-332     Apples, cooking, stewed with sugar, flesh only
# 24    14-320  Apples, cooking, stewed without sugar, flesh only
# 25    14-016                              Apples, eating, dried
# 26    14-319                Apples, eating, raw, flesh and skin
# 27    14-346  Apples, eating, raw, flesh and skin, weighed w...
# 28    14-031                                    Apricots, dried
# 29    14-032                 Apricots, dried, stewed with sugar
# 30    14-033              Apricots, dried, stewed without sugar
# 31    14-025                      Apricots, raw, flesh and skin
# 32    14-026  Apricots, raw, flesh and skin, weighed with st...
# 33    14-392                 Apricots, ready-to-eat, semi-dried
# 34    14-027                        Apricots, stewed with sugar
# 35    14-028   Apricots, stewed with sugar, weighed with stones
# 36    14-029                     Apricots, stewed without sugar
# 37    14-030  Apricots, stewed without sugar, weighed with s...
# 59    14-039                        Avocado, Fuerte, flesh only
# 60    14-040  Avocado, Fuerte, flesh only, weighed with skin...
# 61    14-386                          Avocado, Hass, flesh only
# 62    14-387  Avocado, Hass, flesh only, weighed with skin a...
#
#                                           Description Group       Previous  \
# 11                                 Literature sources    FA            NaN
# 17  Calculated from 672g apple (14-342) and 40g su...    FA        14-007
# 18  Calculated from 14-344 using edible portion of...    FA        14-008
# 19                             Calculated from 14-320    FA        14-010
# 20  Calculated from 14-342 using edible portion of...    FA        14-011
# 23               Calculated from stewed without sugar    FA        14-004
# 24  22 samples, autumn and winter, UK grown pre-pa...    FA            NaN
# 25    6 samples, 3 brands and calculation from 14-014    FA            NaN
# 26  22 samples, autumn and winter, UK grown and im...    FA        14-012
# 27  Calculated from 14-319 using edible portion of...    FA        14-013
# 28                                          No stones    FA            NaN
# 29  Calculated from 450g fruit, 770g water, 54g sugar    FA            NaN
# 30             Calculated from 450g fruit, 770g water    FA            NaN
# 31                                         18 samples    FA        50-860
# 32                             Calculated from 14-025    FA        50-861
# 33  10 samples, 8 products, including soft, ready-...    FA         14-036
# 34  1000g fruit, 100g water, 120g sugar; stones re...    FA            NaN
# 35                             Calculated from 14-027    FA            NaN
# 36              500g fruit, 75g water; stones removed    FA            NaN
# 37                             Calculated from 14-029    FA            NaN
# 59                          10 samples and literature    FA            NaN
# 60                             Calculated from 14-039    FA            NaN
# 61  11 samples, imported, Hass variety, ripe and r...    FA  14-041 14-037
# 62                             Calculated from 14-386    FA  14-042 14-038
#
#                                  Main data references Footnote Energy (kJ)  \
# 11  Gopalan et al. (1980) Nutritive value of India...      NaN         143
# 17                                       Updated 2014      NaN         323
# 18                                       Updated 2014      NaN         269
# 19  DH, Nutrient analysis of fruit and vegetables,...      NaN         232
# 20  DH, Nutrient analysis of fruit and vegetables,...      NaN         194
# 23  DH, Nutrient analysis of fruit and vegetables,...      NaN         377
# 24  DH, Nutrient analysis of fruit and vegetables,...      NaN         196
# 25               LGC, Fruit and vegetables, 1989-1990      NaN        1172
# 26  DH, Nutrient analysis of fruit and vegetables,...      NaN         248
# 27  DH, Nutrient analysis of fruit and vegetables,...      NaN         213
# 28  LGC, Nutritional composition of fruit products...      NaN        1027
# 29                    Fruit and Nuts Supplement, 1992      NaN         481
# 30                    Fruit and Nuts Supplement, 1992      NaN         441
# 31  Reviewed 2013. LGC, Fruit and vegetables, 1989...      NaN         169
# 32               LGC, Fruit and vegetables, 1989-1990      NaN         156
# 33  PHE, Nutrient analysis of fresh and processed ...      NaN         851
# 34                    Fruit and Nuts Supplement, 1992      NaN         345
# 35                    Fruit and Nuts Supplement, 1992      NaN         324
# 36                    Fruit and Nuts Supplement, 1992      NaN         148
# 37                    Fruit and Nuts Supplement, 1992      NaN         138
# 59               LGC, Fruit and vegetables, 1989-1990      NaN         792
# 60               LGC, Fruit and vegetables, 1989-1990      NaN         565
# 61  PHE, Nutrient analysis of fresh and processed ...      NaN         735
# 62  PHE, Nutrient analysis of fresh and processed ...      NaN         508
#
#    Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 11            35      0.1             0                4        3.4
# 17            76      0.4          0.07             16.7       16.7
# 18            64      0.3          0.06               14         14
# 19            55      0.4          0.07             11.3       11.3
# 20            46      0.3          0.06              9.5        9.5
# 23            89      0.3          0.06             20.3       20.3
# 24            46      0.3          0.06              9.6        9.6
# 25           277      0.5           0.1             59.3       59.3
# 26            59      0.5          0.12             11.5       11.5
# 27            50      0.4           0.1              9.9        9.9
# 28           242      0.7          0.18             42.8       42.8
# 29           113      0.3             0             21.6       21.6
# 30           104      0.3             0             17.7       17.7
# 31            40      0.1             0              6.9        6.9
# 32            37      0.1             0              6.3        6.3
# 33           201      0.5          0.13             39.2       39.2
# 34            81      0.1             0             17.6       17.6
# 35            76      0.1             0             16.6       16.6
# 36            35      0.1             0              5.9        5.9
# 37            33      0.1             0              5.5        5.5
# 59           193     19.3           3.5              0.5        0.5
# 60           137     13.7           2.5              0.4        0.4
# 61           178     17.4          4.15              1.7        0.4
# 62           123     12.0          2.86              1.1        0.2
#
#    Starch (g) Fibre (g)  Protein (g) Salt (g)
# 11        0.6       7.8          0.5     0.01
# 17          0       1.9          0.1        0
# 18          0       1.6          0.1        0
# 19          0         2          0.1        0
# 20          0       1.7          0.1        0
# 23          0       1.4          0.2        0
# 24          0       1.7          0.1        0
# 25          0       9.7          2.0     0.04
# 26          0       1.2          0.6        0
# 27          0         1          0.5        0
# 28          0       7.7          4.8     0.14
# 29          0         3          1.9     0.05
# 30          0       3.2          2.0     0.06
# 31          0       1.7          0.9     0.01
# 32          0       1.6          0.8     0.01
# 33          0       5.3          2.2     0.02
# 34          0       1.6          0.7        0
# 35          0       1.5          0.6        0
# 36          0       1.5          0.8        0
# 37          0       1.4          0.7        0
# 59          0       3.4          2.1     0.02
# 60          0       2.4          1.5     0.02
# 61          0       3.1          1.8     0.02
# 62          0       2.1          1.3     0.01

# %%
FA['Food Name'].unique()
# Out:
# array(['Amla', 'Apples, cooking, baked with sugar, flesh only',
#        'Apples, cooking, baked with sugar, flesh only, weighed with skin',
#        'Apples, cooking, baked without sugar, flesh only',
#        'Apples, cooking, baked without sugar, flesh only, weighed with skin',
#        'Apples, cooking, stewed with sugar, flesh only',
#        'Apples, cooking, stewed without sugar, flesh only',
#        'Apples, eating, dried', 'Apples, eating, raw, flesh and skin',
#        'Apples, eating, raw, flesh and skin, weighed with core',
#        'Apricots, dried', 'Apricots, dried, stewed with sugar',
#        'Apricots, dried, stewed without sugar',
#        'Apricots, raw, flesh and skin',
#        'Apricots, raw, flesh and skin, weighed with stones',
#        'Apricots, ready-to-eat, semi-dried',
#        'Apricots, stewed with sugar',
#        'Apricots, stewed with sugar, weighed with stones',
#        'Apricots, stewed without sugar',
#        'Apricots, stewed without sugar, weighed with stones',
#        'Avocado, Fuerte, flesh only',
#        'Avocado, Fuerte, flesh only, weighed with skin and stone',
#        'Avocado, Hass, flesh only',
#        'Avocado, Hass, flesh only, weighed with skin and stone'],
#       dtype=object)

# %% [markdown]
# ##### Reduced

# %%
Priority_FA = ['Amla','Apricots, raw, flesh and skin','Apricots, ready-to-eat, semi-dried','Avocado, Fuerte, flesh only, weighed with skin and stone','Avocado, Hass, flesh only, weighed with skin and stone']

# %%
Filt_FAR = FA[FA['Food Name'].isin(Priority_FA)]
Filt_FAR
# Out:
#    Food Code                                          Food Name  \
# 11    14-001                                               Amla
# 31    14-025                      Apricots, raw, flesh and skin
# 33    14-392                 Apricots, ready-to-eat, semi-dried
# 60    14-040  Avocado, Fuerte, flesh only, weighed with skin...
# 62    14-387  Avocado, Hass, flesh only, weighed with skin a...
#
#                                           Description Group       Previous  \
# 11                                 Literature sources    FA            NaN
# 31                                         18 samples    FA        50-860
# 33  10 samples, 8 products, including soft, ready-...    FA         14-036
# 60                             Calculated from 14-039    FA            NaN
# 62                             Calculated from 14-386    FA  14-042 14-038
#
#                                  Main data references Footnote Energy (kJ)  \
# 11  Gopalan et al. (1980) Nutritive value of India...      NaN         143
# 31  Reviewed 2013. LGC, Fruit and vegetables, 1989...      NaN         169
# 33  PHE, Nutrient analysis of fresh and processed ...      NaN         851
# 60               LGC, Fruit and vegetables, 1989-1990      NaN         565
# 62  PHE, Nutrient analysis of fresh and processed ...      NaN         508
#
#    Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 11            35      0.1             0                4        3.4
# 31            40      0.1             0              6.9        6.9
# 33           201      0.5          0.13             39.2       39.2
# 60           137     13.7           2.5              0.4        0.4
# 62           123     12.0          2.86              1.1        0.2
#
#    Starch (g) Fibre (g)  Protein (g) Salt (g)
# 11        0.6       7.8          0.5     0.01
# 31          0       1.7          0.9     0.01
# 33          0       5.3          2.2     0.02
# 60          0       2.4          1.5     0.02
# 62          0       2.1          1.3     0.01

# %%
Filt_FAR['Super Group'] = 'Fruit'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_17356\15316282.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_FAR['Super Group'] = 'Fruit'

# %% [markdown]
# Fruit Juices

# %%
FC = Prod_A.loc[Prod_A['Group']== 'FC']
FC
# Out:
#    Food Code                                Food Name  \
# 15    14-331  Apple juice, clear, ambient and chilled
#
#                                Description Group Previous  \
# 15  10 samples, 9 brands, from concentrate    FC  14-271
#
#                                  Main data references Footnote Energy (kJ)  \
# 15  DH, Nutrient analysis of fruit and vegetables,...      NaN         172
#
#    Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 15            40      0.0             0              9.6        9.6
#
#    Starch (g) Fibre (g)  Protein (g) Salt (g)
# 15          0         0          0.1     0.01

# %%
FC['Super Group'] = 'Fruit'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_17356\4233848853.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FC['Super Group'] = 'Fruit'

# %% [markdown]
#                                                     Nuts and Seeds

# %%
GA = Prod_A.loc[Prod_A['Group']== 'GA']
GA
# Out:
#   Food Code                     Food Name                        Description  \
# 5    14-870    Almonds, flaked and ground                         10 samples
# 6    14-897              Almonds, toasted                 Literature sources
# 7    14-898  Almonds, weighed with shells             Calculated from 14-896
# 8    14-896        Almonds, whole kernels  Literature sources, Prunus dulcis
#
#   Group               Previous  \
# 5    GA  14-801 14-855 50-972
# 6    GA                 14-803
# 7    GA                 14-883
# 8    GA                    NaN
#
#                                 Main data references Footnote Energy (kJ)  \
# 5  Reviewed 2013. LGC, Snacks and nuts, 1989-1991...      NaN        2686
# 6                                    USDA SR28, 2015      NaN        2555
# 7                                    USDA SR28, 2015      NaN         912
# 8                                    USDA SR28, 2015      NaN        2466
#
#   Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g)  \
# 5           650     55.8          4.43              6.5          4        2.5
# 6           618     52.5          4.09              5.6        4.9        0.7
# 7           221     18.5          1.41              1.8        1.5        0.3
# 8           596     49.9           3.8                5        4.3        0.7
#
#   Fibre (g)  Protein (g) Salt (g)
# 5       9.9         25.4     0.04
# 6      10.9         25.3     0.01
# 7       4.6          9.4        0
# 8      12.5         25.6        0

# %%
Priority_GA = ['Almonds, flaked and ground','Almonds, toasted','Almonds, whole kernels']

# %% [markdown]
# **Reduced**

# %%
Filt_GA = GA[GA['Food Name'].isin(Priority_GA)]
Filt_GA
# Out:
#   Food Code                   Food Name                        Description  \
# 5    14-870  Almonds, flaked and ground                         10 samples
# 6    14-897            Almonds, toasted                 Literature sources
# 8    14-896      Almonds, whole kernels  Literature sources, Prunus dulcis
#
#   Group               Previous  \
# 5    GA  14-801 14-855 50-972
# 6    GA                 14-803
# 8    GA                    NaN
#
#                                 Main data references Footnote Energy (kJ)  \
# 5  Reviewed 2013. LGC, Snacks and nuts, 1989-1991...      NaN        2686
# 6                                    USDA SR28, 2015      NaN        2555
# 8                                    USDA SR28, 2015      NaN        2466
#
#   Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g)  \
# 5           650     55.8          4.43              6.5          4        2.5
# 6           618     52.5          4.09              5.6        4.9        0.7
# 8           596     49.9           3.8                5        4.3        0.7
#
#   Fibre (g)  Protein (g) Salt (g)
# 5       9.9         25.4     0.04
# 6      10.9         25.3     0.01
# 8      12.5         25.6        0

# %%
Filt_GA['Super Group'] = 'Nuts and Seeds'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_17356\3953553267.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_GA['Super Group'] = 'Nuts and Seeds'

# %% [markdown]
#                                                    Herbs and Spices

# %%
H = Prod_A.loc[Prod_A['Group']== 'H']
H
# Out:
#    Food Code         Food Name  \
# 4     13-801  Allspice, ground
# 13    13-802       Anise seeds
# 45    13-803        Asafoetida
#
#                                           Description Group Previous  \
# 4                                  Literature sources     H      NaN
# 13                                 Literature sources     H      NaN
# 45  Resin from root of Ferula plant. Literature so...     H      NaN
#
#                                  Main data references Footnote Energy (kJ)  \
# 4   Marsh et al. (1977) Composition of foods: spic...      NaN        1536
# 13  Marsh et al. (1977) Composition of foods: spic...      NaN        1607
# 45  Gopalan et al. (1980) Nutritive value of India...      NaN         790
#
#    Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 4            366      8.7           2.5             55.1       55.1
# 13           384     15.9           2.3             35.4       31.5
# 45           187      1.1          0.24             37.7        0.9
#
#    Starch (g) Fibre (g)  Protein (g) Salt (g)
# 4           0      21.6          6.1     0.19
# 13        3.9      14.6         17.6     0.04
# 45       36.8       5.1          4.0     0.04

# %%
H['Super Group'] = 'Herbs and Spices'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_17356\1426934226.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   H['Super Group'] = 'Herbs and Spices'

# %% [markdown]
#                                                    Fish and Fish Products

# %% [markdown]
# White Fish

# %%
JA = Prod_A.loc[Prod_A['Group']== 'JA']
JA
# Out:
#    Food Code Food Name                                        Description  \
# 63    16-001  Ayr, raw  Literature sources. Imported frozen from Bangl...
#
#    Group Previous                               Main data references Footnote  \
# 63    JA      NaN  Gopalan et al (1980) Nutritive value of Indian...      NaN
#
#    Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 63         318            75      1.3           0.2                0
#
#    Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 63          0          0         0         15.9     0.24

# %%
JA['Super Group'] = 'Fish and Fish Products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_17356\2768349389.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   JA['Super Group'] = 'Fish and Fish Products'

# %% [markdown]
# Fatty Fish

# %%
JC = Prod_A.loc[Prod_A['Group']== 'JC']
JC
# Out:
#    Food Code                          Food Name           Description Group  \
# 12    16-448  Anchovies, canned in oil, drained  10 samples, 4 brands    JC
#
#    Previous                               Main data references Footnote  \
# 12  16-323   Data from Fish and Fish Products Supplement, 1...      NaN
#
#    Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 12         798           191     10.0           1.6                0
#
#    Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 12          0          0         0         25.2    14.68

# %%
JC['Super Group'] = 'Fish and Fish Products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_17356\3192902706.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   JC['Super Group'] = 'Fish and Fish Products'

# %% [markdown]
#                                                         Beverages

# %% [markdown]
# Juices

# %%
PE = Prod_A.loc[Prod_A['Group']== 'PE']
PE
# Out:
#    Food Code                                         Food Name  \
# 14    14-272  Apple juice concentrate, unsweetened, commerical
#
#                                           Description Group Previous  \
# 14  10 samples, 68.6 Brix; imported commercial con...    PE      NaN
#
#                Main data references Footnote Energy (kJ) Energy (kcal)  \
# 14  Fruit and Nuts Supplement, 1992      NaN        1037           244
#
#     Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 14      0.6           0.1               57         57          0         0
#
#     Protein (g) Salt (g)
# 14          0.5     0.03

# %%
PE['Super Group'] = 'Beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_17356\2899612824.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PE['Super Group'] = 'Beverages'

# %% [markdown]
#                                         Soups, sauces and miscellaneous foods

# %% [markdown]
# Sauces

# %%
WC = Prod_A.loc[Prod_A['Group']== 'WC']
WC
# Out:
#    Food Code              Food Name Description Group Previous  \
# 16    17-851  Apple sauce, homemade      Recipe    WC  17-608
#
#    Main data references Footnote Energy (kJ) Energy (kcal)  Fat (g)  \
# 16         Updated 2014      NaN         359            85      0.2
#
#    Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 16          0.05             19.4       19.4          0       1.4
#
#     Protein (g) Salt (g)
# 16          0.3     0.01

# %%
WC['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_17356\3985520795.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WC['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
#                                               **Join Reduced Tables**

# %%
Red11 = pd.concat([Red10,WC], axis=0, join='inner')
Red11
# Out:
#    Food Code                                          Food Name  \
# 40    11-001                                          Arrowroot
# 0     13-145                             Ackee, canned, drained
# 1     13-146                                        Agar, dried
# 3     13-148                               Alfalfa sprouts, raw
# 10    13-149                               Amaranth leaves, raw
# 39    13-151                                     Arrowhead, raw
# 43    13-153                              Artichoke, globe, raw
# 47    13-157                                     Asparagus, raw
# 55    13-161                                     Aubergine, raw
# 56    15-001     Aubergine, stuffed with lentils and vegetables
# 57    15-662                       Aubergine, stuffed with rice
# 58    15-663  Aubergine, stuffed with vegetables, cheese top...
# 22    14-363  Apples, cooking, raw, flesh only, weighed with...
# 11    14-001                                               Amla
# 31    14-025                      Apricots, raw, flesh and skin
# 33    14-392                 Apricots, ready-to-eat, semi-dried
# 60    14-040  Avocado, Fuerte, flesh only, weighed with skin...
# 62    14-387  Avocado, Hass, flesh only, weighed with skin a...
# 15    14-331            Apple juice, clear, ambient and chilled
# 5     14-870                         Almonds, flaked and ground
# 6     14-897                                   Almonds, toasted
# 8     14-896                             Almonds, whole kernels
# 4     13-801                                   Allspice, ground
# 13    13-802                                        Anise seeds
# 45    13-803                                         Asafoetida
# 63    16-001                                           Ayr, raw
# 12    16-448                  Anchovies, canned in oil, drained
# 14    14-272   Apple juice concentrate, unsweetened, commerical
# 16    17-851                              Apple sauce, homemade
#
#                                           Description Group  \
# 40                     2 samples from different shops    AA
# 0                                              8 cans    DG
# 1                                  Literature sources    DG
# 3                   Analytical and literature sources    DG
# 10                                 Literature sources    DG
# 39                                 Literature sources    DG
# 43                                 Literature sources    DG
# 47                        Tough base of stems removed    DG
# 55                                       Ends trimmed    DG
# 56  Recipe from dietary survey records. Whole dish...    DR
# 57  Rice, tomato, onion and raisin stuffing. Recip...    DR
# 58  Tomato, mushroom and onion stuffing. Recipe fr...    DR
# 22            Bramley variety; calculated from 14-362     F
# 11                                 Literature sources    FA
# 31                                         18 samples    FA
# 33  10 samples, 8 products, including soft, ready-...    FA
# 60                             Calculated from 14-039    FA
# 62                             Calculated from 14-386    FA
# 15             10 samples, 9 brands, from concentrate    FC
# 5                                          10 samples    GA
# 6                                  Literature sources    GA
# 8                   Literature sources, Prunus dulcis    GA
# 4                                  Literature sources     H
# 13                                 Literature sources     H
# 45  Resin from root of Ferula plant. Literature so...     H
# 63  Literature sources. Imported frozen from Bangl...    JA
# 12                               10 samples, 4 brands    JC
# 14  10 samples, 68.6 Brix; imported commercial con...    PE
# 16                                             Recipe    WC
#
#                  Previous                               Main data references  \
# 40                    NaN                           MW3, 1960. Reviewed 2014
# 0                     554  MW4, 1978; and Vegetables, Herbs and Spices Su...
# 1                     NaN  Wu Leung et al. (1972) Food composition table ...
# 3                     NaN      Vegetables, Herbs and Spices Supplement, 1991
# 10                    NaN  Wu Leung et al. (1972) Food composition table ...
# 39                    NaN  Haytowitz and Matthews (1984) Composition of f...
# 43                    NaN      Vegetables, Herbs and Spices Supplement, 1991
# 47                50-737   Reviewed 2013. IFR, The nutritional compositio...
# 55                50-739   Reviewed 2013. IFR, The nutritional compositio...
# 56                    NaN                As Vegetable Dishes Supplement 1992
# 57                15-385                                        Updated 2014
# 58                15-386                                        Updated 2014
# 22                14-003   LGC, Nutritional composition of fresh fruit, 1...
# 11                    NaN  Gopalan et al. (1980) Nutritive value of India...
# 31                50-860   Reviewed 2013. LGC, Fruit and vegetables, 1989...
# 33                 14-036  PHE, Nutrient analysis of fresh and processed ...
# 60                    NaN               LGC, Fruit and vegetables, 1989-1990
# 62          14-042 14-038  PHE, Nutrient analysis of fresh and processed ...
# 15                14-271   DH, Nutrient analysis of fruit and vegetables,...
# 5   14-801 14-855 50-972   Reviewed 2013. LGC, Snacks and nuts, 1989-1991...
# 6                  14-803                                    USDA SR28, 2015
# 8                     NaN                                    USDA SR28, 2015
# 4                     NaN  Marsh et al. (1977) Composition of foods: spic...
# 13                    NaN  Marsh et al. (1977) Composition of foods: spic...
# 45                    NaN  Gopalan et al. (1980) Nutritive value of India...
# 63                    NaN  Gopalan et al (1980) Nutritive value of Indian...
# 12                16-323   Data from Fish and Fish Products Supplement, 1...
# 14                    NaN                    Fruit and Nuts Supplement, 1992
# 16                17-608                                        Updated 2014
#
#    Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 40      NaN        1471           346      0.1          0.02             85.5
# 0       NaN         639           155     15.2          4.44              0.8
# 1       NaN         721           180      1.2           0.3                0
# 3       NaN         113            27      0.7          0.07              0.3
# 10      NaN         111            27      0.3           0.1              0.3
# 39      NaN         447           106      0.3          0.03             19.5
# 43      NaN         120            29      0.2           0.1              1.3
# 47      NaN         120            29      0.6           0.1                2
# 55      NaN          84            20      0.4           0.1              2.2
# 56      NaN         283            68      4.6           0.5              3.6
# 57      NaN         378            90      2.1          0.22             14.8
# 58      NaN         523           126      9.7          3.48              3.4
# 22      NaN         136            32      0.2          0.04              6.5
# 11      NaN         143            35      0.1             0                4
# 31      NaN         169            40      0.1             0              6.9
# 33      NaN         851           201      0.5          0.13             39.2
# 60      NaN         565           137     13.7           2.5              0.4
# 62      NaN         508           123     12.0          2.86              1.1
# 15      NaN         172            40      0.0             0              9.6
# 5       NaN        2686           650     55.8          4.43              6.5
# 6       NaN        2555           618     52.5          4.09              5.6
# 8       NaN        2466           596     49.9           3.8                5
# 4       NaN        1536           366      8.7           2.5             55.1
# 13      NaN        1607           384     15.9           2.3             35.4
# 45      NaN         790           187      1.1          0.24             37.7
# 63      NaN         318            75      1.3           0.2                0
# 12      NaN         798           191     10.0           1.6                0
# 14      NaN        1037           244      0.6           0.1               57
# 16      NaN         359            85      0.2          0.05             19.4
#
#    Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)  \
# 40          0       85.5       0.9          0.4     0.01
# 0         0.8          0       1.8          2.9      0.6
# 1           0          0      81.1          1.6     0.28
# 3         0.3          0       1.7          4.0     0.02
# 10        0.2        0.1       4.4          3.5     0.03
# 39        0.9       18.6       2.4          5.0     0.06
# 43        1.3          0       5.4          2.8     0.07
# 47        1.9        0.1       1.7          2.9        0
# 55          2        0.2         2          0.9     0.01
# 56        1.6        1.9       1.9          2.1      0.2
# 57        5.9        8.9       2.1          1.9     0.02
# 58        3.2        0.2       2.2          5.3     0.27
# 22        6.5          0       1.2          0.3        0
# 11        3.4        0.6       7.8          0.5     0.01
# 31        6.9          0       1.7          0.9     0.01
# 33       39.2          0       5.3          2.2     0.02
# 60        0.4          0       2.4          1.5     0.02
# 62        0.2          0       2.1          1.3     0.01
# 15        9.6          0         0          0.1     0.01
# 5           4        2.5       9.9         25.4     0.04
# 6         4.9        0.7      10.9         25.3     0.01
# 8         4.3        0.7      12.5         25.6        0
# 4        55.1          0      21.6          6.1     0.19
# 13       31.5        3.9      14.6         17.6     0.04
# 45        0.9       36.8       5.1          4.0     0.04
# 63          0          0         0         15.9     0.24
# 12          0          0         0         25.2    14.68
# 14         57          0         0          0.5     0.03
# 16       19.4          0       1.4          0.3     0.01
#
#                               Super Group
# 40            Cereals and cereal products
# 0                              Vegetables
# 1                              Vegetables
# 3                              Vegetables
# 10                             Vegetables
# 39                             Vegetables
# 43                             Vegetables
# 47                             Vegetables
# 55                             Vegetables
# 56                             Vegetables
# 57                             Vegetables
# 58                             Vegetables
# 22                                  Fruit
# 11                                  Fruit
# 31                                  Fruit
# 33                                  Fruit
# 60                                  Fruit
# 62                                  Fruit
# 15                                  Fruit
# 5                          Nuts and Seeds
# 6                          Nuts and Seeds
# 8                          Nuts and Seeds
# 4                        Herbs and Spices
# 13                       Herbs and Spices
# 45                       Herbs and Spices
# 63                 Fish and Fish Products
# 12                 Fish and Fish Products
# 14                              Beverages
# 16  Soups, sauces and miscellaneous foods

# %% [markdown]
#                                                        Export

# %%
Red11.to_csv(r'C:\Users\medekar\Desktop\Product Weighting Project\Data\Processed\Reduced_A.csv')
