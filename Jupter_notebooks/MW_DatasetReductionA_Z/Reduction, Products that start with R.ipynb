# %% [markdown]
# # Product Weighting Project

# %% [markdown]
#                                          Data Reduction - Food Purchased In Store

# %% [markdown]
# ###### Import Necessary Libraries

# %%
import pandas as pd

# %% [markdown]
# Read in Data

# %%
Labelled = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Labelling2021_watercress.csv')

# %% [markdown]
# ### Products beginning with a 'R'

# %%
Prod_R = Labelled.loc[Labelled['Food Name'].str.startswith('R')]
Prod_R
# Out:
#      Food Code                                     Food Name  \
# 2291    18-387                        Rabbit, raw, meat only
# 2292    18-388                     Rabbit, stewed, meat only
# 2293    18-389  Rabbit, stewed, meat only, weighed with bone
# 2294    13-329                                Raddiccio, raw
# 2295    13-332                            Radish leaves, raw
# ...        ...                                           ...
# 2387    13-882                               Rosemary, dried
# 2388    13-892                               Rosemary, fresh
# 2389    15-869                              Roulade, spinach
# 2390   11-1111                            Rum baba, homemade
# 2391    11-940                                         Rusks
#
#                                             Description Group  \
# 2291                       10 samples from leg and loin   MEC
# 2292  30 samples of a mixture of fresh, wild, farmed...   MEC
# ...

# %% [markdown]
# Products within a Group (provide identification of the food group and food type to which the food belongs)

# %%
Prod_R.groupby('Group')['Food Name'].count()
# Out:
# Group
# AC     29
# AK      1
# AN      1
# AP      1
# AT      1
# BV      1
# DG      6
# DR     22
# FA     11
# H       2
# JA     16
# JR      3
# MEC     3
# MR      1
# WC      1
# WCN     2
# Name: Food Name, dtype: int64

# %% [markdown]
# ## *Reducing products based on its most basic form. Improve as you go on*

# %% [markdown]
#                                                 Cereals and cereal products

# %%
AC = Prod_R.loc[Prod_R['Group']== 'AC']
AC
# Out:
#      Food Code                                          Food Name  \
# 2308    11-877                 Red rice, boiled in unsalted water
# 2332    11-867     Rice, brown, basmati, boiled in unsalted water
# 2333    11-866                          Rice, brown, basmati, raw
# 2334    11-871   Rice, brown, easy cook, boiled in unsalted water
# 2335    11-870                        Rice, brown, easy cook, raw
# 2336    11-869  Rice, brown, wholegrain, boiled in unsalted water
# 2337    11-868                       Rice, brown, wholegrain, raw
# 2338    11-885  Rice, egg fried, ready cooked, re-heated, reta...
# 2339    11-444                          Rice, egg fried, takeaway
# 2340    11-968                       Rice, pilau, plain, homemade
# 2341    11-884             Rice, ready-cooked, "plain", re-heated
# 2342    11-876                                     Rice, red, raw
# 2343    11-881  Rice, savoury, including chicken, beef, mushro...
# ...

# %%
AC['Food Name'].unique()
# Out:
# array(['Red rice, boiled in unsalted water',
#        'Rice, brown, basmati, boiled in unsalted water',
#        'Rice, brown, basmati, raw',
#        'Rice, brown, easy cook, boiled in unsalted water',
#        'Rice, brown, easy cook, raw',
#        'Rice, brown, wholegrain, boiled in unsalted water',
#        'Rice, brown, wholegrain, raw',
#        'Rice, egg fried, ready cooked, re-heated, retail, not takeaway',
#        'Rice, egg fried, takeaway', 'Rice, pilau, plain, homemade',
#        'Rice, ready-cooked, "plain", re-heated', 'Rice, red, raw',
#        'Rice, savoury, including chicken, beef, mushroom and vegetable varieties, dried, cooked',
#        'Rice, savoury, including chicken, beef, mushroom and vegetable varieties, dried, uncooked',
#        'Rice, Thai fragrant, boiled in unsalted water',
#        'Rice, Thai fragrant, raw',
#        'Rice, white, basmati, boiled in unsalted water',
#        'Rice, white, basmati, easy cook, boiled in unsalted water',
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_AC = ['Rice, brown, basmati, raw','Rice, brown, easy cook, raw', 'Rice, Thai fragrant, raw','Rice, white, long grain, easy cook, raw']

# %%
Filt_AC = AC[AC['Food Name'].isin(Priority_AC)]
Filt_AC
# Out:
#      Food Code                                Food Name  \
# 2333    11-866                Rice, brown, basmati, raw
# 2335    11-870              Rice, brown, easy cook, raw
# 2346    11-874                 Rice, Thai fragrant, raw
# 2355    11-863  Rice, white, long grain, easy cook, raw
#
#                                             Description Group Previous  \
# 2333                              6 samples, 5 products    AC      NaN
# 2335  6 samples, 5 products, including Italian and A...    AC      NaN
# 2346                              8 samples, 7 products    AC      NaN
# 2355                             10 samples, 9 products    AC  11-445
#
#                                  Main data references Footnote Energy (kJ)  \
# 2333  LGC, Nutrient survey of flours and grains, 2005      NaN        1499
# 2335  LGC, Nutrient survey of flours and grains, 2005      NaN        1547
# 2346  LGC, Nutrient survey of flours and grains, 2005      NaN        1466
# ...

# %%
Filt_AC['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_22380\2047431866.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AC['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Infant cereal foods

# %%
AK = Prod_R.loc[Prod_R['Group']== 'AK']
AK
# Out:
#      Food Code Food Name            Description Group  \
# 2391    11-940     Rusks  8 samples, 8 products    AK
#
#                           Previous  \
# 2391  11-161 11-162 11-163 11-164
#
#                                    Main data references Footnote Energy (kJ)  \
# 2391  Nutrient analysis of a range of processed food...      NaN        1685
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2391           400     10.7          4.59             67.6       22.5
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2391       45.1       2.4          7.1     0.22

# %%
AK['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_22380\528049520.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AK['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Removed AN - Cakes

# %% [markdown]
# Remvoed AP - Buns and pastries

# %% [markdown]
# Savouries

# %%
AT= Prod_R.loc[Prod_R['Group']== 'AT']
AT
# Out:
#      Food Code                 Food Name Description Group Previous  \
# 2361    11-999  Risotto, plain, homemade      Recipe    AT  11-605
#
#      Main data references Footnote Energy (kJ) Energy (kcal)  Fat (g)  \
# 2361    Recalculated 2013      NaN         791           188      4.7
#
#      Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 2361          0.67             32.4          1       31.2       0.9
#
#       Protein (g) Salt (g)
# 2361          3.4     1.12

# %%
AT['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_22380\2815507821.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AT['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
#                                                   Milk and milk products

# %% [markdown]
# Savoury dishes and sauces

# %%
BV = Prod_R.loc[Prod_R['Group']== 'BV']
BV
# Out:
#      Food Code                               Food Name Description Group  \
# 2300    12-595  Raita, yogurt and gram flour, homemade      Recipe    BV
#
#      Previous Main data references Footnote Energy (kJ) Energy (kcal)  \
# 2300  12-457          Updated 2014      NaN         410            99
#
#       Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 2300      6.6          3.83              5.8        4.2        1.6       1.4
#
#       Protein (g) Salt (g)
# 2300          3.3     0.07

# %%
BV['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_22380\3947839067.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BV['Super Group'] = 'Milk and milk products'

# %% [markdown]
#                                                         Vegetables

# %% [markdown]
# Vegetables, general

# %%
DG = Prod_R.loc[Prod_R['Group']== 'DG']
DG
# Out:
#      Food Code                         Food Name  \
# 2294    13-329                    Raddiccio, raw
# 2295    13-332                Radish leaves, raw
# 2296    13-656  Radish, red, flesh and skin, raw
# 2297    13-331          Radish, white/mooli, raw
# 2302    13-333                  Rape leaves, raw
# 2382    13-522                       Rocket, raw
#
#                                             Description Group Previous  \
# 2294                    3 samples. Outer leaves removed    DG      NaN
# 2295                                 Literature sources    DG      NaN
# 2296   10 samples, UK and imported, end and top trimmed    DG   13-330
# 2297                                 Literature sources    DG      NaN
# 2302                                Literature sources;    DG      NaN
# 2382  19 samples, autumn and winter, UK grown and im...    DG      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# ...

# %%
DG['Food Name'].unique()
# Out:
# array(['Raddiccio, raw', 'Radish leaves, raw',
#        'Radish, red, flesh and skin, raw', 'Radish, white/mooli, raw',
#        'Rape leaves, raw', 'Rocket, raw'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_DG = ['Radish leaves, raw','Rocket, raw']

# %%
Filt_DG = DG[DG['Food Name'].isin(Priority_DG)]
Filt_DG
# Out:
#      Food Code           Food Name  \
# 2295    13-332  Radish leaves, raw
# 2382    13-522         Rocket, raw
#
#                                             Description Group Previous  \
# 2295                                 Literature sources    DG      NaN
# 2382  19 samples, autumn and winter, UK grown and im...    DG      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2295      Vegetables, Herbs and Spices Supplement, 1991      NaN         171
# 2382  DH, Nutrient analysis of fruit and vegetables,...      NaN          89
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2295            41      0.5          0.05              3.5        3.5
# 2382            21      0.4          0.07                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2295          0         4          3.6     0.28
# 2382          0       1.7          3.6     0.08

# %%
Filt_DG['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_22380\1311392366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DG['Super Group'] = 'Vegetables'

# %% [markdown]
# Vegetable dishes

# %%
DR = Prod_R.loc[Prod_R['Group']== 'DR']
DR
# Out:
#      Food Code                                     Food Name  \
# 2306    15-659                         Ratatouille, homemade
# 2307    15-853                                  Red pea loaf
# 2318    15-854                                Re-fried beans
# 2324    15-855                      Rice and black-eye beans
# 2325    15-856          Rice and black-eye beans, brown rice
# 2326    15-857                          Rice and pigeon peas
# 2327    15-858              Rice and pigeon peas, brown rice
# 2328    15-859                     Rice and red kidney beans
# 2329    15-860         Rice and red kidney beans, brown rice
# 2330    15-861                           Rice and split peas
# 2331    15-862               Rice and split peas, brown rice
# 2362    15-864                Risotto, vegetable, brown rice
# 2363    15-863      Risotto, white rice, vegetable, homemade
# 2364    15-281  Rissoles, brown rice, fried in sunflower oil
# ...

# %%
DR['Food Name'].unique()
# Out:
# array(['Ratatouille, homemade', 'Red pea loaf', 'Re-fried beans',
#        'Rice and black-eye beans', 'Rice and black-eye beans, brown rice',
#        'Rice and pigeon peas', 'Rice and pigeon peas, brown rice',
#        'Rice and red kidney beans',
#        'Rice and red kidney beans, brown rice', 'Rice and split peas',
#        'Rice and split peas, brown rice',
#        'Risotto, vegetable, brown rice',
#        'Risotto, white rice, vegetable, homemade',
#        'Rissoles, brown rice, fried in sunflower oil',
#        'Rissoles, brown rice, fried in vegetable oil',
#        'Rissoles, chick pea, fried in sunflower oil',
#        'Rissoles, chick pea, fried in vegetable oil',
#        'Rissoles, lentil, fried in sunflower oil',
#        'Rissoles, lentil, fried in vegetable oil',
#        'Rissoles, vegetable, fried in sunflower oil',
#        'Rissoles, vegetable, fried in vegetable oil', 'Roulade, spinach'],
#       dtype=object)

# %%
Filt_DR = DR[DR['Food Name'] == 'Roulade, spinach']

# %%
Filt_DR['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_22380\2508077319.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DR['Super Group'] = 'Vegetables'

# %% [markdown]
#                                                            Fruit

# %%
FA = Prod_R.loc[Prod_R['Group']== 'FA']
FA
# Out:
#      Food Code                                  Food Name  \
# 2298    14-393                             Raisins, dried
# 2301    14-243                       Rambutan, flesh only
# 2303    14-375                           Raspberries, raw
# 2304    14-245             Raspberries, stewed with sugar
# 2305    14-246          Raspberries, stewed without sugar
# 2314    14-249                           Redcurrants, raw
# 2315    14-250             Redcurrants, stewed with sugar
# 2316    14-251          Redcurrants, stewed without sugar
# 2321    14-252                   Rhubarb, stems only, raw
# 2322    14-253     Rhubarb, stems only, stewed with sugar
# 2323    14-389  Rhubarb, stems only, stewed without sugar
#
#                                             Description Group Previous  \
# 2298  10 samples, 10 products, not including soft, r...    FA   14-242
# 2301                                 Literature sources    FA      NaN
# ...

# %%
FA['Food Name'].unique()
# Out:
# array(['Raisins, dried', 'Rambutan, flesh only', 'Raspberries, raw',
#        'Raspberries, stewed with sugar',
#        'Raspberries, stewed without sugar', 'Redcurrants, raw',
#        'Redcurrants, stewed with sugar',
#        'Redcurrants, stewed without sugar', 'Rhubarb, stems only, raw',
#        'Rhubarb, stems only, stewed with sugar',
#        'Rhubarb, stems only, stewed without sugar'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_FA = ['Raisins, dried','Raspberries, raw','Redcurrants, raw','Rhubarb, stems only, raw']

# %%
Filt_FA = FA[FA['Food Name'].isin(Priority_FA)]
Filt_FA
# Out:
#      Food Code                 Food Name  \
# 2298    14-393            Raisins, dried
# 2303    14-375          Raspberries, raw
# 2314    14-249          Redcurrants, raw
# 2321    14-252  Rhubarb, stems only, raw
#
#                                             Description Group Previous  \
# 2298  10 samples, 10 products, not including soft, r...    FA   14-242
# 2303             11 samples, mixture of UK and imported    FA   14-244
# 2314                        Whole fruit, stalks removed    FA      NaN
# 2321                                         Stems only    FA  50-961
#
#                                    Main data references Footnote Energy (kJ)  \
# 2298  PHE, Nutrient analysis of fresh and processed ...      NaN        1176
# 2303  PHE, Nutrient analysis of fresh and processed ...      NaN         167
# 2314  MW4, 1978. Values revised for Fruit and Nuts S...      NaN         166
# 2321  LGC, Nutritional composition of fresh fruit, 1...      NaN          76
#
# ...

# %%
Filt_FA['Super Group'] = 'Fruit'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_22380\3797725470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_FA['Super Group'] = 'Fruit'

# %% [markdown]
#                                                     Herbs and spices

# %%
H = Prod_R.loc[Prod_R['Group']== 'H']
H
# Out:
#      Food Code        Food Name                           Description Group  \
# 2387    13-882  Rosemary, dried                    Literature sources     H
# 2388    13-892  Rosemary, fresh  7 samples and calculation from dried     H
#
#      Previous                               Main data references Footnote  \
# 2387  13-851   Reviewed 2013. Marsh et al. (1977) Composition...      NaN
# 2388  13-850   LGC, Fruit and vegetables, 1989-1990; and data...      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 2387        1462           354     15.2          7.37               28
# 2388         515           124      4.4          2.15             13.5
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2387       27.8        0.2      42.6          4.9     0.13
# 2388       13.4        0.1      12.4          1.4     0.04

# %% [markdown]
# **Reduced**

# %%
Filt_H = H[H['Food Name'] == 'Rosemary, fresh']
Filt_H
# Out:
#      Food Code        Food Name                           Description Group  \
# 2388    13-892  Rosemary, fresh  7 samples and calculation from dried     H
#
#      Previous                               Main data references Footnote  \
# 2388  13-850   LGC, Fruit and vegetables, 1989-1990; and data...      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 2388         515           124      4.4          2.15             13.5
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2388       13.4        0.1      12.4          1.4     0.04

# %%
Filt_H['Super Group'] = 'Herbs and spices'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_22380\2675675023.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_H['Super Group'] = 'Herbs and spices'

# %% [markdown]
#                                                 Fish and fish products

# %% [markdown]
# Removed JA - White fish

# %% [markdown]
# Removed JR - Fish products and dishes

# %% [markdown]
#                                                Meat and meat products

# %% [markdown]
# Rabbit

# %%
MEC = Prod_R.loc[Prod_R['Group']== 'MEC']
MEC
# Out:
#      Food Code                                     Food Name  \
# 2291    18-387                        Rabbit, raw, meat only
# 2292    18-388                     Rabbit, stewed, meat only
# 2293    18-389  Rabbit, stewed, meat only, weighed with bone
#
#                                             Description Group  Previous  \
# 2291                       10 samples from leg and loin   MEC   50-468
# 2292  30 samples of a mixture of fresh, wild, farmed...   MEC  50-469
# 2293                             Calculated from 18-388   MEC   50-470
#
#                                    Main data references Footnote Energy (kJ)  \
# 2291  Reviewed 2013. LGC, Poultry and game surveys, ...      NaN         575
# 2292  Reviewed 2013. LGC, Poultry and game surveys, ...      NaN         479
# 2293            Meat, Poultry and Game Supplement, 1995      NaN         286
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# ...

# %%
MEC['Food Name'].unique()
# Out:
# array(['Rabbit, raw, meat only', 'Rabbit, stewed, meat only',
#        'Rabbit, stewed, meat only, weighed with bone'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Filt_MEC = MEC[MEC['Food Name'] == 'Rabbit, raw, meat only']

# %%
Filt_MEC['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_22380\2319667859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_MEC['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Removed MR - Meat dishes

# %% [markdown]
#                                         Soups, sauces and miscellaneous foods

# %% [markdown]
# Removed WC- Sauces

# %% [markdown]
# Non-salad sauces

# %%
WCN = Prod_R.loc[Prod_R['Group']== 'WCN']
WCN
# Out:
#      Food Code                    Food Name  \
# 2319    17-708  Relish, corn/cucumber/onion
# 2320    17-354         Relish, tomato based
#
#                                             Description Group Previous  \
# 2319                                9 samples, 5 brands   WCN  17-353
# 2320  9 samples, 4 brands, including chilli and burg...   WCN      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2319  LFRA, Nutrient analysis of miscellaneous foods...      NaN         642
# 2320  Reviewed 2013. LFRA, Nutrient analysis of misc...      NaN         496
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2319           151      0.3             0             35.4       28.4
# 2320           117      0.1             0             26.8       24.5
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2319          7       1.5          1.0     1.05
# 2320        2.3         2          1.2      1.2

# %% [markdown]
# **Reduced**

# %%
Filt_WCN = WCN[WCN['Food Name'] == 'Relish, tomato based']
Filt_WCN
# Out:
#      Food Code             Food Name  \
# 2320    17-354  Relish, tomato based
#
#                                             Description Group Previous  \
# 2320  9 samples, 4 brands, including chilli and burg...   WCN      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2320  Reviewed 2013. LFRA, Nutrient analysis of misc...      NaN         496
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2320           117      0.1             0             26.8       24.5
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2320        2.3         2          1.2      1.2

# %%
Filt_WCN['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_22380\3671653614.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_WCN['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
#                                               **Join Reduced Tables**

# %%
Red = pd.concat([Filt_AC, AK], axis=0, join='inner')
Red
# Out:
#      Food Code                                Food Name  \
# 2333    11-866                Rice, brown, basmati, raw
# 2335    11-870              Rice, brown, easy cook, raw
# 2346    11-874                 Rice, Thai fragrant, raw
# 2355    11-863  Rice, white, long grain, easy cook, raw
# 2391    11-940                                    Rusks
#
#                                             Description Group  \
# 2333                              6 samples, 5 products    AC
# 2335  6 samples, 5 products, including Italian and A...    AC
# 2346                              8 samples, 7 products    AC
# 2355                             10 samples, 9 products    AC
# 2391                              8 samples, 8 products    AK
#
#                           Previous  \
# 2333                           NaN
# 2335                           NaN
# 2346                           NaN
# 2355                       11-445
# 2391  11-161 11-162 11-163 11-164
#
# ...

# %%
Red2 = pd.concat([Red,AT], axis=0, join='inner')
Red2
# Out:
#      Food Code                                Food Name  \
# 2333    11-866                Rice, brown, basmati, raw
# 2335    11-870              Rice, brown, easy cook, raw
# 2346    11-874                 Rice, Thai fragrant, raw
# 2355    11-863  Rice, white, long grain, easy cook, raw
# 2391    11-940                                    Rusks
# 2361    11-999                 Risotto, plain, homemade
#
#                                             Description Group  \
# 2333                              6 samples, 5 products    AC
# 2335  6 samples, 5 products, including Italian and A...    AC
# 2346                              8 samples, 7 products    AC
# 2355                             10 samples, 9 products    AC
# 2391                              8 samples, 8 products    AK
# 2361                                             Recipe    AT
#
#                           Previous  \
# 2333                           NaN
# 2335                           NaN
# ...

# %%
Red3 = pd.concat([Red2,BV], axis=0, join='inner')
Red3
# Out:
#      Food Code                                Food Name  \
# 2333    11-866                Rice, brown, basmati, raw
# 2335    11-870              Rice, brown, easy cook, raw
# 2346    11-874                 Rice, Thai fragrant, raw
# 2355    11-863  Rice, white, long grain, easy cook, raw
# 2391    11-940                                    Rusks
# 2361    11-999                 Risotto, plain, homemade
# 2300    12-595   Raita, yogurt and gram flour, homemade
#
#                                             Description Group  \
# 2333                              6 samples, 5 products    AC
# 2335  6 samples, 5 products, including Italian and A...    AC
# 2346                              8 samples, 7 products    AC
# 2355                             10 samples, 9 products    AC
# 2391                              8 samples, 8 products    AK
# 2361                                             Recipe    AT
# 2300                                             Recipe    BV
#
# ...

# %%
Red4 = pd.concat([Red3,Filt_DG], axis=0, join='inner')
Red4
# Out:
#      Food Code                                Food Name  \
# 2333    11-866                Rice, brown, basmati, raw
# 2335    11-870              Rice, brown, easy cook, raw
# 2346    11-874                 Rice, Thai fragrant, raw
# 2355    11-863  Rice, white, long grain, easy cook, raw
# 2391    11-940                                    Rusks
# 2361    11-999                 Risotto, plain, homemade
# 2300    12-595   Raita, yogurt and gram flour, homemade
# 2295    13-332                       Radish leaves, raw
# 2382    13-522                              Rocket, raw
#
#                                             Description Group  \
# 2333                              6 samples, 5 products    AC
# 2335  6 samples, 5 products, including Italian and A...    AC
# 2346                              8 samples, 7 products    AC
# 2355                             10 samples, 9 products    AC
# 2391                              8 samples, 8 products    AK
# ...

# %%
Red5 = pd.concat([Red4,Filt_DR], axis=0, join='inner')
Red5
# Out:
#      Food Code                                Food Name  \
# 2333    11-866                Rice, brown, basmati, raw
# 2335    11-870              Rice, brown, easy cook, raw
# 2346    11-874                 Rice, Thai fragrant, raw
# 2355    11-863  Rice, white, long grain, easy cook, raw
# 2391    11-940                                    Rusks
# 2361    11-999                 Risotto, plain, homemade
# 2300    12-595   Raita, yogurt and gram flour, homemade
# 2295    13-332                       Radish leaves, raw
# 2382    13-522                              Rocket, raw
# 2389    15-869                         Roulade, spinach
#
#                                             Description Group  \
# 2333                              6 samples, 5 products    AC
# 2335  6 samples, 5 products, including Italian and A...    AC
# 2346                              8 samples, 7 products    AC
# 2355                             10 samples, 9 products    AC
# ...

# %%
Red6 = pd.concat([Red5,Filt_FA], axis=0, join='inner')
Red6
# Out:
#      Food Code                                Food Name  \
# 2333    11-866                Rice, brown, basmati, raw
# 2335    11-870              Rice, brown, easy cook, raw
# 2346    11-874                 Rice, Thai fragrant, raw
# 2355    11-863  Rice, white, long grain, easy cook, raw
# 2391    11-940                                    Rusks
# 2361    11-999                 Risotto, plain, homemade
# 2300    12-595   Raita, yogurt and gram flour, homemade
# 2295    13-332                       Radish leaves, raw
# 2382    13-522                              Rocket, raw
# 2389    15-869                         Roulade, spinach
# 2298    14-393                           Raisins, dried
# 2303    14-375                         Raspberries, raw
# 2314    14-249                         Redcurrants, raw
# 2321    14-252                 Rhubarb, stems only, raw
#
#                                             Description Group  \
# ...

# %%
Red7 = pd.concat([Red6,Filt_H], axis=0, join='inner')
Red7
# Out:
#      Food Code                                Food Name  \
# 2333    11-866                Rice, brown, basmati, raw
# 2335    11-870              Rice, brown, easy cook, raw
# 2346    11-874                 Rice, Thai fragrant, raw
# 2355    11-863  Rice, white, long grain, easy cook, raw
# 2391    11-940                                    Rusks
# 2361    11-999                 Risotto, plain, homemade
# 2300    12-595   Raita, yogurt and gram flour, homemade
# 2295    13-332                       Radish leaves, raw
# 2382    13-522                              Rocket, raw
# 2389    15-869                         Roulade, spinach
# 2298    14-393                           Raisins, dried
# 2303    14-375                         Raspberries, raw
# 2314    14-249                         Redcurrants, raw
# 2321    14-252                 Rhubarb, stems only, raw
# 2388    13-892                          Rosemary, fresh
#
#                                             Description Group  \
# ...

# %%
Red8 = pd.concat([Red7,Filt_MEC], axis=0, join='inner')
Red8
# Out:
#      Food Code                                Food Name  \
# 2333    11-866                Rice, brown, basmati, raw
# 2335    11-870              Rice, brown, easy cook, raw
# 2346    11-874                 Rice, Thai fragrant, raw
# 2355    11-863  Rice, white, long grain, easy cook, raw
# 2391    11-940                                    Rusks
# 2361    11-999                 Risotto, plain, homemade
# 2300    12-595   Raita, yogurt and gram flour, homemade
# 2295    13-332                       Radish leaves, raw
# 2382    13-522                              Rocket, raw
# 2389    15-869                         Roulade, spinach
# 2298    14-393                           Raisins, dried
# 2303    14-375                         Raspberries, raw
# 2314    14-249                         Redcurrants, raw
# 2321    14-252                 Rhubarb, stems only, raw
# 2388    13-892                          Rosemary, fresh
# 2291    18-387                   Rabbit, raw, meat only
#
# ...

# %%
Red9 = pd.concat([Red8,Filt_WCN], axis=0, join='inner')
Red9
# Out:
#      Food Code                                Food Name  \
# 2333    11-866                Rice, brown, basmati, raw
# 2335    11-870              Rice, brown, easy cook, raw
# 2346    11-874                 Rice, Thai fragrant, raw
# 2355    11-863  Rice, white, long grain, easy cook, raw
# 2391    11-940                                    Rusks
# 2361    11-999                 Risotto, plain, homemade
# 2300    12-595   Raita, yogurt and gram flour, homemade
# 2295    13-332                       Radish leaves, raw
# 2382    13-522                              Rocket, raw
# 2389    15-869                         Roulade, spinach
# 2298    14-393                           Raisins, dried
# 2303    14-375                         Raspberries, raw
# 2314    14-249                         Redcurrants, raw
# 2321    14-252                 Rhubarb, stems only, raw
# 2388    13-892                          Rosemary, fresh
# 2291    18-387                   Rabbit, raw, meat only
# ...

# %% [markdown]
#                                                        Export

# %%
Red9.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced_R.csv')
