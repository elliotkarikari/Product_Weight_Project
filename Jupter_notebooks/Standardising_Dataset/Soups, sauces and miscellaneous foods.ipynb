# %% [markdown]
#                                      SelfScale DataBase Soups, sauces and miscellaneous foods

# %% [markdown]
# Libraries Imported

# %%
import pandas as pd
import re

# %% [markdown]
# Reading in Updated List

# %%
#Red_List = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Total\Updated2_RedLab2021.csv', index_col=0)

# %% [markdown]
# ###### Selecting all Fruits in Reduced List

# %%
#SoupM = Red_List.loc[Red_List['Super Group'] == 'Soups, sauces and miscellaneous foods']

# %%
#SoupM.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Soups, sauces and miscellaneous foods.csv')

# %% [markdown]
#                                                        Fruit

# %%
SSm = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Soups, sauces and miscellaneous foods.csv', index_col=0)

# %%
SSm.shape
# Out:
# (44, 6)

# %% [markdown]
# ##### Reviewing Veg List

# %% [markdown]
# Most of Review done in Excel

# %%
#Loop through dataframe and print comments
for comment in SSm:
    pd.set_option('display.max_colwidth', None)
    #pd.set_option('display.max_rows', None)
SSm
# Out:
#    Food Code                                             Food Name Group  \
# 1        NaN                                   Apple sauce, retail    WC
# 2     17-705                                        Barbecue sauce    WC
# 3     17-678                       Brown sauce, reduced salt/sugar   WCN
# 4     17-697  Chicken soup, cream of, canned, condensed, as served   WAC
# 5     17-719                                          Chilli sauce    WC
# 6        NaN                                          Cheese sauce   WCD
# 7     17-345                                       Chutney, tomato   WCG
# 8     17-358                                       Cream of tartar    WY
# 9     17-715                                 Dressing, blue cheese   WCG
# 10    17-701                                      Dressing, French   WCG
# 11    17-717                             Dressing, thousand island   WCG
# 12       NaN                                     Guacamole, retail    WC
# ...

# %%
SSm.drop('VJ comments', axis=1, inplace=True)

# %%
SSm.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Cleaned\Soups, sauces and miscellaneous foods_Cleaned.csv')
