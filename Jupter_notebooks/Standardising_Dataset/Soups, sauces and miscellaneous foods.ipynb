# %% [markdown]
#                                      SelfScale DataBase Soups, sauces and miscellaneous foods

# %% [markdown]
# Libraries Imported

# %%
import pandas as pd
import re

# %% [markdown]
# Reading in Updated List

# %%
#Red_List = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Total\Updated2_RedLab2021.csv', index_col=0)

# %% [markdown]
# ###### Selecting all Fruits in Reduced List

# %%
#SoupM = Red_List.loc[Red_List['Super Group'] == 'Soups, sauces and miscellaneous foods']

# %%
#SoupM.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Soups, sauces and miscellaneous foods.csv')

# %% [markdown]
#                                                        Fruit

# %%
SSm = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Soups, sauces and miscellaneous foods.csv', index_col=0)

# %%
SSm.shape
# Out:
# (42, 6)

# %% [markdown]
# ##### Reviewing Veg List

# %% [markdown]
# Most of Review done in Excel

# %%
#Loop through dataframe and print comments
for comment in SSm:
    pd.set_option('display.max_colwidth', None)
    #pd.set_option('display.max_rows', None)
SSm
# Out:
#     Food Code                                               Food Name Group  \
# 28     17-851                                   Apple sauce, homemade    WC
# 133    17-769                                Barbecue sauce, homemade    WC
# 135    17-678                         Brown sauce, reduced salt/sugar   WCN
# 239    17-697    Chicken soup, cream of, canned, condensed, as served   WAC
# 240    17-719                                            Chilli sauce    WC
# 241    17-773          Cheese sauce, made with skimmed milk, homemade   WCD
# 242    17-345                                         Chutney, tomato   WCG
# 243    17-358                                         Cream of tartar    WY
# 256    17-715                                   Dressing, blue cheese   WCG
# 257    17-701                                        Dressing, French   WCG
# 258    17-717                               Dressing, thousand island   WCG
# 302    17-797                                     Guacamole, homemade    WC
# 303    17-360                                                Gelatine    WY
# 304    17-724                                  Gravy instant granules    WY
# 316    17-800                             Hollandaise sauce, homemade    WC
# 400    17-654                            Mayonnaise, standard, retail   WCG
# 401    17-364                                         Mustard, smooth    WY
# 470    17-623                                              Pesto, red    WC
# 471    17-718                                           Pickle, sweet   WCG
# 472    17-702                                              Piccalilli   WCN
# 492    17-354                                    Relish, tomato based   WCN
# 519    17-711                                Soup, minestrone, canned    WA
# 520    17-695                         Soup, chicken, cream of, canned   WAC
# 521    17-652                           Soup, cream of tomato, canned   WAC
# 522    17-698                                    Soup, lentil, canned   WAC
# 523    17-700                                    Soup, oxtail, canned   WAC
# 524    17-712                                 Soup, vegetable, canned   WAC
# 525    17-653                      Soup, instant, dried, as purchased   WAE
# 526    17-628                    Sauce, Chinese cook in, sweet & sour    WC
# 527    17-629                                 Sauce, Chinese stir fry    WC
# 528    17-703                                             Salad cream   WCG
# 529    17-336                        Sauce, sweet and sour, take-away   WCN
# 530    17-721                     Soy sauce, light and dark varieties   WCN
# 531    17-367                                                    Salt    WY
# 532    17-515                                       Stock cubes, beef    WY
# 533    17-680                                               Stock gel    WY
# 534    17-681                      Stock, chicken, ready made, retail    WY
# 563    17-339                                                 Vinegar    WY
# 571    17-778  White sauce, savoury, made with skimmed milk, homemade   WCD
# 572    17-723                                    Worcestershire sauce   WCN
# 573    17-377                                        Water, distilled    WY
# 578    17-517                                           Yeast extract    WY
#
#                                Super Group Sale format(s)  \
# 28   Soups, sauces and miscellaneous foods            jar
# 133  Soups, sauces and miscellaneous foods            NaN
# 135  Soups, sauces and miscellaneous foods            NaN
# 239  Soups, sauces and miscellaneous foods            can
# 240  Soups, sauces and miscellaneous foods            NaN
# 241  Soups, sauces and miscellaneous foods            NaN
# 242  Soups, sauces and miscellaneous foods            jar
# 243  Soups, sauces and miscellaneous foods            NaN
# 256  Soups, sauces and miscellaneous foods            NaN
# 257  Soups, sauces and miscellaneous foods            NaN
# 258  Soups, sauces and miscellaneous foods            NaN
# 302  Soups, sauces and miscellaneous foods            NaN
# 303  Soups, sauces and miscellaneous foods            NaN
# 304  Soups, sauces and miscellaneous foods            NaN
# 316  Soups, sauces and miscellaneous foods            jar
# 400  Soups, sauces and miscellaneous foods            NaN
# 401  Soups, sauces and miscellaneous foods            jar
# 470  Soups, sauces and miscellaneous foods            jar
# 471  Soups, sauces and miscellaneous foods            jar
# 472  Soups, sauces and miscellaneous foods            jar
# 492  Soups, sauces and miscellaneous foods            jar
# 519  Soups, sauces and miscellaneous foods            can
# 520  Soups, sauces and miscellaneous foods            can
# 521  Soups, sauces and miscellaneous foods            can
# 522  Soups, sauces and miscellaneous foods            can
# 523  Soups, sauces and miscellaneous foods            can
# 524  Soups, sauces and miscellaneous foods            can
# 525  Soups, sauces and miscellaneous foods            can
# 526  Soups, sauces and miscellaneous foods            NaN
# 527  Soups, sauces and miscellaneous foods            NaN
# 528  Soups, sauces and miscellaneous foods            NaN
# 529  Soups, sauces and miscellaneous foods            NaN
# 530  Soups, sauces and miscellaneous foods            NaN
# 531  Soups, sauces and miscellaneous foods            NaN
# 532  Soups, sauces and miscellaneous foods            NaN
# 533  Soups, sauces and miscellaneous foods            NaN
# 534  Soups, sauces and miscellaneous foods            NaN
# 563  Soups, sauces and miscellaneous foods            NaN
# 571  Soups, sauces and miscellaneous foods            NaN
# 572  Soups, sauces and miscellaneous foods            NaN
# 573  Soups, sauces and miscellaneous foods            NaN
# 578  Soups, sauces and miscellaneous foods            jar
#
#                                                                                      VJ comments
# 28                                           Suggest this should be a retail option if available
# 133  I'd suggest removing this one as we only really need the retail version, whch we have below
# 135                                                                                          NaN
# 239                                                                                          NaN
# 240                                                                                          NaN
# 241                                                                                          NaN
# 242                                                                                          NaN
# 243                                                                                          NaN
# 256                                                                                          NaN
# 257                                                                                          NaN
# 258                                                                                          NaN
# 302                                                                                          NaN
# 303                                                                                          NaN
# 304                                                                                          NaN
# 316                                                                                          NaN
# 400                                                                                          NaN
# 401                                                                                          NaN
# 470                                                                                          NaN
# 471                                                                                          NaN
# 472                                                                                          NaN
# 492                                                                                          NaN
# 519                                                                                          NaN
# 520                                                                                          NaN
# 521                                                                                          NaN
# 522                                                                                          NaN
# 523                                                                                          NaN
# 524                                                                                          NaN
# 525                                                                                          NaN
# 526                                                                                          NaN
# 527                                                                                          NaN
# 528                                                                                          NaN
# 529                                                                                          NaN
# 530                                                                                          NaN
# 531                                                                                          NaN
# 532                                                                                          NaN
# 533                                                                                          NaN
# 534                                                                                          NaN
# 563                                                                                          NaN
# 571                                                                                          NaN
# 572                                                                                          NaN
# 573                                                                                          NaN
# 578                                                                                          NaN

# %%
#Mmp.drop('VJ comments', axis=1, inplace=True)

# %%
#Mmp.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Cleaned\Meat and meat products_Cleaned.csv')
