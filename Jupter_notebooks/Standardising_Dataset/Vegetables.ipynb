# %% [markdown]
#                                    SelfScale DataBase Vegetables

# %% [markdown]
# Libraries Imported

# %%
import pandas as pd
import re

# %% [markdown]
# Reading in Updated List

# %% [markdown]
#                                            Vegetables

# %%
Vegg = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Vegetables.csv', index_col=0)

# %%
Vegg.shape
# Out:
# (114, 6)

# %% [markdown]
# ###### Checking Corrections Made

# %%
Veggna = Vegg[Vegg['Food Code'].isna()]
Veggna.drop_duplicates()
# Out:
#     Food Code                          Food Name Group Super Group  \
# 1         NaN                      Ackee, canned    DG  Vegetables
# 7         NaN                  Artichoke, canned    DG  Vegetables
# 8         NaN                     Artichoke, jar    DG  Vegetables
# 13        NaN               Beans, aduki, canned    DB  Vegetables
# 15        NaN            Beans, blackeye, canned    DB  Vegetables
# 17        NaN              Beans, butter, canned    DB  Vegetables
# 19        NaN          Beans, chick peas, canned    DB  Vegetables
# 21        NaN             Beans, edamame, frozen    DB  Vegetables
# 22        NaN             Beans, edamame, canned    DB  Vegetables
# 25        NaN             Beans, haricot, canned    DB  Vegetables
# 29        NaN             Beans, pinto, canned,     DB  Vegetables
# 31        NaN          Beans, red kidney, canned    DB  Vegetables
# 42        NaN                 Beanburger, retail    DR  Vegetables
# ...

# %% [markdown]
#                                             Comments

# %%
pd.set_option('display.max_colwidth', None)
Vegg[~Vegg['VJ comments'].isna()]
# Out:
#     Food Code                                    Food Name Group Super Group  \
# 12     13-041              Beans, aduki, whole, dried, raw    DB  Vegetables
# 21        NaN                       Beans, edamame, frozen    DB  Vegetables
# 73     13-089  Lentils, green and brown, whole, dried, raw    DB  Vegetables
# 87        NaN                        Peas, canned in water    DF  Vegetables
# 100    13-359                       Swede, flesh only, raw    DG  Vegetables
# 102    13-463                Sweet potato, raw, flesh only    DG  Vegetables
# 104       NaN                    Sweetcorn kernels, canned    DG  Vegetables
# 105    13-622                      Sweetcorn, kernels, raw    DG  Vegetables
# 110       NaN                    Vegetables, mixed, frozen    DG  Vegetables
#
#     Sale format(s)  \
# 12          packet
# 21          packet
# 73          packet
# 87             tin
# 100            NaN
# 102         packet
# 104            tin
# 105         packet
# ...

# %% [markdown]
# ##### Reviewing Veg List

# %%
pd.set_option('display.max_rows', None)
Vegg.head(127)
# Out:
#     Food Code                                     Food Name Group Super Group  \
# 1         NaN                                 Ackee, canned    DG  Vegetables
# 2      13-146                                   Agar, dried    DG  Vegetables
# 3      13-148                          Alfalfa sprouts, raw    DG  Vegetables
# 4      13-149                          Amaranth leaves, raw    DG  Vegetables
# 5      13-151                                Arrowhead, raw    DG  Vegetables
# 6      13-153                         Artichoke, globe, raw    DG  Vegetables
# 7         NaN                             Artichoke, canned    DG  Vegetables
# 8         NaN                                Artichoke, jar    DG  Vegetables
# 9      13-157                                Asparagus, raw    DG  Vegetables
# 10     13-161                                Aubergine, raw    DG  Vegetables
# 11     13-532           Baked beans, canned in tomato sauce    DB  Vegetables
# ...

# %%
Vegg.drop('VJ comments', axis=1, inplace=True)

# %%
Vegg.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Vegetables_Upd.csv')
