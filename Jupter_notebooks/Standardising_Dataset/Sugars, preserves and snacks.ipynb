# %% [markdown]
#                                           SelfScale DataBase Sugars, preserves and snacks

# %% [markdown]
# Libraries Imported

# %%
import pandas as pd
import re

# %% [markdown]
# Reading in Updated List

# %%
Red_List = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Total\Updated2_RedLab2021.csv', index_col=0)

# %% [markdown]
# ###### Selecting all Fruits in Reduced List

# %%
Sug = Red_List.loc[Red_List['Super Group'] == 'Sugars, preserves and snacks']

# %%
Sug.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Sugars, preserves and snacks.csv')

# %% [markdown]
#                                                    Herbs and spices

# %%
SuGps = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Sugars, preserves and snacks.csv', index_col=0)

# %%
SuGps.shape
# Out:
# (25, 6)

# %% [markdown]
# ##### Reviewing Veg List

# %% [markdown]
# Most of Review done in Excel

# %%
#Loop through dataframe and print comments
for comment in SuGps:
    pd.set_option('display.max_colwidth', None)
    #pd.set_option('display.max_rows', None)
SuGps
# Out:
#    Food Code                                                    Food Name  \
# 1     17-659                                             Chocolate spread
# 2     17-658                Chocolate covered bar with caramel and cereal
# 3     17-763                                                    Creme egg
# 4     17-645                                                  Corn snacks
# 5        NaN                                 Chevda/chevra/chewra, retial
# 6     17-049                                           Glucose liquid, BP
# 7     17-050                                                        Honey
# 8     17-689  Ice cream sauce, topping, strawberry and chocolate flavours
# 9     17-075                                           Jam, reduced sugar
# 10    17-777                                           Liquorice allsorts
# 11    17-078                                                    Marmalade
# 12    17-651                               Maltesers and similar products
# ...

# %%
SuGps.drop('VJ comments', axis=1, inplace=True)

# %%
SuGps.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Cleaned\Sugars, preserves and snacks_Cleaned.csv')
