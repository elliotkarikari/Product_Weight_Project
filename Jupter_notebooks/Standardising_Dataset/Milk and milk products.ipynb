# %% [markdown]
#                                            SelfScale DataBase Milk and milk products

# %% [markdown]
# Libraries Imported

# %%
import pandas as pd
import re

# %% [markdown]
# Reading in Updated List

# %%
#Red_List = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Total\Updated2_RedLab2021.csv', index_col=0)

# %% [markdown]
# ###### Selecting all Fruits in Reduced List

# %%
#Milk = Red_List.loc[Red_List['Super Group'] == 'Milk and milk products']

# %%
#Milk.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Milk and milk products.csv')

# %% [markdown]
#                                                        Fruit

# %%
Milkmp = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Milk and milk products.csv', index_col=0)

# %%
Milkmp.shape
# Out:
# (33, 6)

# %% [markdown]
# ##### Reviewing Veg List

# %% [markdown]
# Most of Review done in Excel

# %%
#Loop through dataframe and print comments
for comment in Milkmp:
    pd.set_option('display.max_colwidth', None)
    #pd.set_option('display.max_rows', None)
Milkmp
# Out:
#       Food Code  \
# 69.0     12-500
# 149.0    12-333
# 151.0    12-537
# 152.0    12-346
# 154.0    12-354
# 155.0    12-357
# 156.0    12-360
# 157.0    12-549
# 158.0    12-486
# 159.0    12-507
# 160.0    12-542
# 161.0    12-461
# NaN      12-543
# 247.0    12-398
# 317.0    12-508
# 318.0    12-509
# 323.0       NaN
# 335.0    12-373
# 336.0    12-390
# 337.0    12-389
# 365.0    12-512
# 366.0    12-322
# 367.0    12-307
# 368.0    12-313
# 369.0    12-596
# 370.0    12-520
# 371.0    12-522
# 372.0    12-524
# 374.0    12-401
# 435.0    12-553
# 482.0       NaN
# 575.0    12-555
# 576.0    12-375
#
#                                                                Food Name  \
# 69.0                   Baking fat and margarine (75-90% fat), hard block
# 149.0                                             Cream, fresh, whipping
# 151.0                                  Cheese spread, plain, reduced fat
# 152.0                                           Cheese, Cheddar, English
# ...

# %%
Milkmp.drop('VJ comments', axis=1, inplace=True)

# %%
Milkmp.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Cleaned\Soups, sauces and miscellaneous foods_Cleaned.csv')
