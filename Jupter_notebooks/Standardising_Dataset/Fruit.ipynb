# %% [markdown]
#                                                SelfScale DataBase Fruit

# %% [markdown]
# Libraries Imported

# %%
import pandas as pd
import re

# %% [markdown]
# Reading in Updated List

# %%
Red_List = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Total\Updated2_RedLab2021.csv', index_col=0)

# %% [markdown]
# ###### Selecting all Fruits in Reduced List

# %%
#Ff = Red_List.loc[Red_List['Super Group'] == 'Fruit']

# %%
#Ff.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Fruit.csv')

# %% [markdown]
#                                                        Fruit

# %%
Fruit = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Fruit.csv', index_col=0)

# %%
Fruit.shape
# Out:
# (68, 6)

# %% [markdown]
# ##### Reviewing Veg List

# %%
pd.set_option('display.max_rows', None)
Fruit.head(127)
# Out:
#    Food Code                                          Food Name Group  \
# 1     14-363  Apples, cooking, raw, flesh only, weighed with...     F
# 2     14-319                Apples, eating, raw, flesh and skin     F
# 3     14-001                                               Amla    FA
# 4     14-025                      Apricots, raw, flesh and skin    FA
# 5     14-392                 Apricots, ready-to-eat, semi-dried    FA
# 6     14-040  Avocado, Fuerte, flesh only, weighed with skin...    FA
# 7     14-387  Avocado, Hass, flesh only, weighed with skin a...    FA
# 8     14-331            Apple juice, clear, ambient and chilled    FC
# 9     14-043                                 Babaco, flesh only    FA
# 10    14-318                            Bananas, flesh and skin    FA
# 11    14-388                                  Blackberries, raw    FA
# 12    14-053                                 Blackcurrants, raw    FA
# ...

# %%
Fruit.drop('VJ comments', axis=1, inplace=True)

# %%
Fruit.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Fruit_Cleaned.csv')
