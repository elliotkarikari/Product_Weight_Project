# %% [markdown]
#                                              Reduced Dataset - 2nd Round

# %%
import pandas as pd
import glob

# %% [markdown]
# Read in all cleaned CSV file and save as Pandas Dataframe

# %%
# Get a list of all the CSV files in the current directory.
csv_files = glob.glob(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Cleaned\*.csv')
print('This Worked First')

# Loop through the list of CSV files and read each file into a Pandas DataFrame.
df = pd.DataFrame()
for csv_file in csv_files:
    df = df.append(pd.read_csv(csv_file))

# Did it work ?.
print('This Worked Second')
# Out:
# This Worked First
# This Worked Second
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11352\3350489534.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_csv(csv_file))
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11352\3350489534.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_csv(csv_file))
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11352\3350489534.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.read_csv(csv_file))
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11352\3350489534.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# Figure out how to prevent an index being created when data if read into dataframe

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# Convert pd dataframe to CSV

# %%
df.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Cleaned\Reduced_SecondClean.csv')

# %% [markdown]
# Read in Cleaned 2nd Round

# %%
second = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Cleaned\Reduced_SecondClean.csv', index_col=0)

# %%
pd.set_option('display.max_column',None)
pd.set_option('display.max_row', None)
second
# Out:
#     Food Code                                          Food Name Group  \
# 1      17-208                        Beer, bitter, best, premium    QA
# 2      17-224                                       Cider, sweet    QC
# 3      17-234                                               Port    QF
# 4      17-236                                     Sherry, medium    QF
# 5      17-247                                Spirits, 40% volume    QK
# 6      17-239                                      Vermouth, dry    QG
# 7      17-752                                          Wine, red    QE
# 8      17-756                                Wine, white, medium    QE
# 9      14-272   Apple juice concentrate, unsweetened, commerical    PE
# 10     17-632                          Coffee, cappuccino, latte     P
# 11     17-175                                               Cola   PCA
# 12     17-744                        Cranberry fruit juice drink    PE
# ...

# %%
second.shape
# Out:
# (535, 5)

# %%
Labelled = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Raw Data\Labelling2021_watercress.csv')
Labelled.shape
# Out:
# (2887, 17)

# %%
f'The second store data reduction process left us with {round((535/2887) * 100, 2)}% of produce'
# Out:
# 'The second store data reduction process left us with 18.53% of produce'
