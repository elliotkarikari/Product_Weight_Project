# %% [markdown]
#                                    SelfScale DataBase Vegetables

# %% [markdown]
# Libraries Imported

# %%
import pandas as pd
import re

# %% [markdown]
# Reading in Updated List

# %%
UpRed = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Total\Updated2_RedLab2021.csv', index_col=False)

# %%
UpRed.shape
# Out:
# (582, 7)

# %% [markdown]
#                                            Vegetables

# %%
Vegg = UpRed[UpRed['Super Group'] == 'Vegetables']
Vegg.drop(['Unnamed: 0',], axis=1, inplace=True)
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_53992\1515720634.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Vegg.drop(['Unnamed: 0',], axis=1, inplace=True)

# %%
#Vegg.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Vegetables.csv')

# %% [markdown]
# ###### Checking Corrections Made

# %%
Veggna = Vegg[Vegg['Food Code'].isna()]
Veggna.drop_duplicates()
# Out:
#     Food Code                                  Food Name Group Super Group  \
# 76        NaN                   Beans, edamame, frozen,     DB  Vegetables
# 120       NaN                      Beans, aduki, canned,    DB  Vegetables
# 123       NaN            Beans, blackeye, whole, dried,     DB  Vegetables
# 126       NaN                      Beans, broad, whole,     DB  Vegetables
# 128       NaN                      Beans, butter, canned    DB  Vegetables
# 129       NaN                  Beans, cannellini, canned    DB  Vegetables
# 130       NaN                  Beans, chick peas, canned    DB  Vegetables
# 132       NaN  Beans, chick peas, Kabuli, whole, dried,     DB  Vegetables
# 134       NaN                             Beans, green,     DB  Vegetables
# 136       NaN                     Beans, haricot, canned    DB  Vegetables
# 137       NaN             Beans, haricot, whole, dried,     DB  Vegetables
# ...

# %% [markdown]
#                                             Comments

# %%
pd.set_option('display.max_colwidth', None)
Vegg[~Vegg['VJ comments'].isna()]
# Out:
#     Food Code                                            Food Name Group  \
# 71     13-041                      Beans, aduki, whole, dried, raw    DB
# 76        NaN                             Beans, edamame, frozen,     DB
# 338    13-089          Lentils, green and brown, whole, dried, raw    DB
# 439    13-564            Peas, canned in water, re-heated, drained    DF
# 500    13-359                               Swede, flesh only, raw    DG
# 501    13-672                                  Sweet potato, baked    DG
# 502    13-529          Sweetcorn kernels, canned in water, drained    DG
# 503    13-622                              Sweetcorn, kernels, raw    DG
# 558    13-543  Vegetables, mixed, frozen, boiled in unsalted water    DG
# 581    13-463                        Sweet potato, raw, flesh only    DG
#
#     Super Group Sale format(s)  \
# 71   Vegetables         packet
# 76   Vegetables            NaN
# 338  Vegetables            NaN
# 439  Vegetables            tin
# ...
