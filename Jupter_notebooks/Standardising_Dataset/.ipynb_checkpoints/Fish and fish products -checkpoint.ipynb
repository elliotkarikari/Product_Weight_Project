# %% [markdown]
#                                           SelfScale DataBase Fish and fish products

# %% [markdown]
# Libraries Imported

# %%
import pandas as pd
import re

# %% [markdown]
# Reading in Updated List

# %%
Red_List = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Total\Updated2_RedLab2021.csv', index_col=0)

# %% [markdown]
# ###### Selecting all Fruits in Reduced List

# %%
Fish = Red_List.loc[Red_List['Super Group'] == 'Fish and fish products']

# %%
Fish.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Fish and fish products.csv')

# %% [markdown]
#                                                    Herbs and spices

# %%
FFp = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Fish and fish products.csv', index_col=0)

# %%
FFp.shape
# Out:
# (33, 6)

# %% [markdown]
# ##### Reviewing Veg List

# %% [markdown]
# Most of Review done in Excel

# %%
#Loop through dataframe and print comments
for comment in FFp:
    pd.set_option('display.max_colwidth', None)
    #pd.set_option('display.max_rows', None)
FFp
# Out:
#    Food Code                          Food Name Group             Super Group  \
# 1     16-001                           Ayr, raw    JA  Fish and fish products
# 2        NaN          Anchovies, canned in oil,    JC  Fish and fish products
# 3     16-385         Bass, sea, flesh only, raw    JA  Fish and fish products
# 4     16-003                          Bele, raw    JA  Fish and fish products
# 5     16-004                          Boal, raw    JA  Fish and fish products
# 6     16-005                        Bombay duck    JA  Fish and fish products
# 7     16-006                    Bream, Sea, raw    JA  Fish and fish products
# 8     16-169                         Bacha, raw    JC  Fish and fish products
# 9     16-372               Cod, flesh only, raw    JA  Fish and fish products
# 10    16-172                          Carp, raw    JA  Fish and fish products
# 11    16-007                       Catfish, raw    JA  Fish and fish products
# ...

# %%
FFp.drop('VJ comments', axis=1, inplace=True)

# %%
FFp.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Cleaned\Fish and fish products.csv')
