# %% [markdown]
#                                           SelfScale DataBase Herbs and spices

# %% [markdown]
# Libraries Imported

# %%
import pandas as pd
import re

# %% [markdown]
# Reading in Updated List

# %%
Red_List = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Total\Updated2_RedLab2021.csv', index_col=0)

# %% [markdown]
# ###### Selecting all Fruits in Reduced List

# %%
Herbs = Red_List.loc[Red_List['Super Group'] == 'Herbs and spices']

# %%
Herbs.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Herbs and spices.csv')

# %% [markdown]
#                                                    Herbs and spices

# %%
HnS = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Herbs and spices.csv', index_col=0)

# %%
HnS.shape
# Out:
# (35, 6)

# %% [markdown]
# ##### Reviewing Veg List

# %% [markdown]
# Most of Review done in Excel

# %%
#Loop through dataframe and print comments
for comment in HnS:
    pd.set_option('display.max_colwidth', None)
    #pd.set_option('display.max_rows', None)
HnS
# Out:
#     Food Code                Food Name Group       Super Group  \
# 22     13-801         Allspice, ground     H  Herbs and spices
# 23     13-802              Anise seeds     H  Herbs and spices
# 24     13-803               Asafoetida     H  Herbs and spices
# 107    13-805     Basil, dried, ground     H  Herbs and spices
# 108    13-804             Basil, fresh     H  Herbs and spices
# 189    13-808            Caraway seeds     H  Herbs and spices
# 190    13-809         Cardamom, ground     H  Herbs and spices
# 191    13-810             Celery seeds     H  Herbs and spices
# 192    13-811           Chervil, dried     H  Herbs and spices
# 193    13-873            Chilli powder     H  Herbs and spices
# 194    13-813          Chinese 5 spice     H  Herbs and spices
# 195    13-887            Chives, fresh     H  Herbs and spices
# 196    13-874         Cinnamon, ground     H  Herbs and spices
# 197    13-816            Cloves, dried     H  Herbs and spices
# ...

# %%
HnS.drop('VJ comments', axis=1, inplace=True)

# %%
HnS.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Cleaned\Herbs and spices_Cleaned.csv')
