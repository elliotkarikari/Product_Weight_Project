# %% [markdown]
# # Weight Data - Open Food Facts

# %% [markdown]
# Import necessary librarys

# %%
import pandas as pd
import openfoodfacts

# %% [markdown]
#                                    Accessing Data with Open Food Facts Python Package

# %% [markdown]
# All products recorded from England

# %%
products = openfoodfacts.products.get_all_by_country('england')

# %%
product_table = pd.DataFrame(products)

# %% [markdown]
# Looking at all columns available in data

# %%
for c in product_table.columns:
    print(c)
# Out:
# _id
# _keywords
# added_countries_tags
# additives_n
# additives_old_n
# additives_old_tags
# additives_original_tags
# additives_tags
# allergens
# allergens_from_ingredients
# allergens_from_user
# allergens_hierarchy
# allergens_tags
# amino_acids_tags
# brands
# brands_tags
# categories
# categories_hierarchy
# categories_lc
# categories_old
# categories_properties
# categories_properties_tags
# categories_tags
# checkers_tags
# code
# codes_tags
# complete
# completeness
# correctors_tags
# countries
# countries_hierarchy
# countries_lc
# countries_tags
# created_t
# creator
# data_quality_bugs_tags
# data_quality_errors_tags
# data_quality_info_tags
# data_quality_tags
# data_quality_warnings_tags
# data_sources
# data_sources_tags
# ecoscore_data
# ecoscore_grade
# ecoscore_tags
# editors_tags
# entry_dates_tags
# food_groups_tags
# id
# image_front_small_url
# image_front_thumb_url
# image_front_url
# image_ingredients_small_url
# image_ingredients_thumb_url
# image_ingredients_url
# image_small_url
# image_thumb_url
# image_url
# images
# informers_tags
# ingredients
# ingredients_analysis
# ingredients_analysis_tags
# ingredients_from_or_that_may_be_from_palm_oil_n
# ingredients_from_palm_oil_n
# ingredients_from_palm_oil_tags
# ingredients_hierarchy
# ingredients_n
# ingredients_n_tags
# ingredients_original_tags
# ingredients_percent_analysis
# ingredients_tags
# ingredients_text
# ingredients_text_en
# ingredients_text_with_allergens
# ingredients_text_with_allergens_en
# ingredients_that_may_be_from_palm_oil_n
# ingredients_that_may_be_from_palm_oil_tags
# ingredients_with_specified_percent_n
# ingredients_with_specified_percent_sum
# ingredients_with_unspecified_percent_n
# ingredients_with_unspecified_percent_sum
# interface_version_created
# interface_version_modified
# known_ingredients_n
# labels
# labels_hierarchy
# labels_lc
# labels_old
# labels_tags
# lang
# languages
# languages_codes
# languages_hierarchy
# languages_tags
# last_edit_dates_tags
# last_editor
# last_image_dates_tags
# last_image_t
# last_modified_by
# last_modified_t
# lc
# main_countries_tags
# max_imgid
# minerals_tags
# misc_tags
# nova_group
# nova_group_debug
# nova_groups
# nova_groups_markers
# nova_groups_tags
# nucleotides_tags
# nutrient_levels
# nutrient_levels_tags
# nutriments
# nutriscore_data
# nutriscore_grade
# nutriscore_score
# nutriscore_score_opposite
# nutrition_data_per
# nutrition_data_prepared_per
# nutrition_grade_fr
# nutrition_grades
# nutrition_grades_tags
# nutrition_score_beverage
# nutrition_score_debug
# nutrition_score_warning_fruits_vegetables_nuts_estimate_from_ingredients
# nutrition_score_warning_fruits_vegetables_nuts_estimate_from_ingredients_value
# origins
# origins_hierarchy
# origins_lc
# origins_old
# origins_tags
# other_nutritional_substances_tags
# packaging
# packaging_hierarchy
# packaging_lc
# packaging_old
# packaging_old_before_taxonomization
# packaging_tags
# packagings
# photographers_tags
# pnns_groups_1
# pnns_groups_1_tags
# pnns_groups_2
# pnns_groups_2_tags
# popularity_key
# popularity_tags
# product_name
# product_name_en
# product_quantity
# purchase_places
# purchase_places_tags
# quantity
# removed_countries_tags
# rev
# scans_n
# selected_images
# sortkey
# states
# states_hierarchy
# states_tags
# stores
# stores_tags
# teams
# teams_tags
# traces
# traces_from_ingredients
# traces_from_user
# traces_hierarchy
# traces_tags
# unique_scans_n
# unknown_ingredients_n
# unknown_nutrients_tags
# update_key
# url
# vitamins_tags
# weighers_tags
# allergens_lc
# cities_tags
# compared_to_category
# debug_param_sorted_langs
# emb_codes
# emb_codes_tags
# expiration_date
# food_groups
# generic_name_en
# image_nutrition_small_url
# image_nutrition_thumb_url
# image_nutrition_url
# link
# manufacturing_places
# manufacturing_places_tags
# no_nutrition_data
# nutrition_data
# nutrition_data_prepared
# packaging_text_en
# serving_quantity
# serving_size
# traces_lc
# with_sweeteners
# category_properties
# ciqual_food_name_tags
# ecoscore_score
# ingredients_text_fr
# ingredients_text_with_allergens_fr
# nutrition_score_warning_no_fiber
# product_name_fr
# forest_footprint_data
# generic_name
# image_packaging_small_url
# image_packaging_thumb_url
# image_packaging_url
# origin_en
# additives_debug_tags
# additives_prev_original_tags
# amino_acids_prev_tags
# ecoscore_extended_data
# ecoscore_extended_data_version
# ingredients_debug
# ingredients_ids_debug
# minerals_prev_tags
# nucleotides_prev_tags
# packaging_materials_tags
# packaging_recycling_tags
# packaging_shapes_tags
# vitamins_prev_tags
# generic_name_de
# ingredients_text_de
# ingredients_text_debug
# ingredients_text_with_allergens_de
# packaging_text_de
# product_name_de
# nova_group_error
# nova_group_tags
# downgraded
# nutrition_score_warning_no_fruits_vegetables_nuts
# carbon_footprint_from_known_ingredients_debug
# carbon_footprint_percent_of_known_ingredients
# product_name_debug_tags

# %% [markdown]
# Filtering Product Table

# %%
Filtpt = product_table[['_id', 'product_name','product_quantity','brands','labels','packaging','url','stores']]
Filtpt
# Out:
#               _id                                   product_name  \
# 0   5032722306325                                           Tofu
# 1   4056489013716                          Colossus energy drink
# 2        21114731                                Malted Wheaties
# 3   5060201181125                                Coffee whitener
# 4   4088600323961                           chicken tikka slices
# 5        20018986                                       Rich Tea
# 6   5011766999939           Organic Wholemeal Digestive Biscuits
# 7        40875477                                       Espresso
# 8   8060195465833                         Mr Organic Baked Beans
# 9        01066036                         Danish cinnamon whirls
# 10  5060102622147                   Blackcurrant Flavour Cordial
# 11       12258383                                    soft pittas
# 12  5013531940757                               UNDHIU (Curried)
# 13  0782733910046                       Thai Penang Ginger Curry
# 14  5013531940955                         Curried Mustard Leaves
# 15       20718527                         Light Brown Soft Sugar
# 16  5031416082545  Green peas & cottage cheese in a tomato gravy
# 17  5010301340304                     white  ready to roll icing
#
#    product_quantity                         brands  \
# 0               500                  Biona organic
# 1               NaN                       Colossus
# 2               750                           Asda
# 3               400                   Cafe Classic
# 4               300                      Crestwood
# 5               300                     Tower Gate
# 6               400                     Doves Farm
# 7               200                       Bellarom
# 8               400                     Mr Organic
# 9               NaN                    Sainsbury's
# 10             1000  Hartridges British Drinks Co.
# 11              NaN                     warburtons
# 12              450                          Natco
# 13              285                     Tasty Bite
# 14              450                          Natco
# 15             1000                        Belbake
# 16              450                          Heera
# 17             1000                       renshaws
#
#                                            labels  \
# 0   Organic, Vegetarian, Vegan, Organic NL-bio-01
# 1
# 2                                             NaN
# 3                                      Vegetarian
# 4
# 5                               Vegetarian, Vegan
# 6                                             NaN
# 7        Nachhaltige Agrikultur, UTZ Zertifiziert
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                     Vegetarian
# 13        Vegetarian, No gluten, No preservatives
# 14                                     Vegetarian
# 15                                            NaN
# 16                             Vegetarian, Indian
# 17                                            NaN
#
#                                  packaging  \
# 0                                    Glass
# 1
# 2                                Cardboard
# 3                                      NaN
# 4   1 Film to throw away,1 Tray to Recycle
# 5                          Pp film-wrapper
# 6                                 Opp film
# 7                   Dose, en:aluminium-tin
# 8                                      Tin
# 9                                  plastic
# 10                                 Plastic
# 11                                 Plastic
# 12                           Can, Food can
# 13                                 Plastic
# 14                           Can, Food can
# 15                                 Plastic
# 16                           Can, Food can
# 17                                     NaN
#
#                                                   url  \
# 0   https://world.openfoodfacts.org/product/503272...
# 1   https://world.openfoodfacts.org/product/405648...
# 2   https://world.openfoodfacts.org/product/211147...
# 3   https://world.openfoodfacts.org/product/506020...
# 4   https://world.openfoodfacts.org/product/408860...
# 5   https://world.openfoodfacts.org/product/200189...
# 6   https://world.openfoodfacts.org/product/501176...
# 7   https://world.openfoodfacts.org/product/408754...
# 8   https://world.openfoodfacts.org/product/806019...
# 9   https://world.openfoodfacts.org/product/010660...
# 10  https://world.openfoodfacts.org/product/506010...
# 11  https://world.openfoodfacts.org/product/122583...
# 12  https://world.openfoodfacts.org/product/501353...
# 13  https://world.openfoodfacts.org/product/078273...
# 14  https://world.openfoodfacts.org/product/501353...
# 15  https://world.openfoodfacts.org/product/207185...
# 16  https://world.openfoodfacts.org/product/503141...
# 17  https://world.openfoodfacts.org/product/501030...
#
#                        stores
# 0             wholefood store
# 1
# 2                        Asda
# 3                    Best-one
# 4                        Aldi
# 5                        Lidl
# 6   Waitrose,wholefood stores
# 7                        Lidl
# 8                    Waitrose
# 9                 Sainsbury's
# 10               supermarkets
# 11                      tesco
# 12                 specialist
# 13            wholefood store
# 14                 Specialist
# 15                       lidl
# 16                 specialist
# 17                     amazon

# %% [markdown]
#                                                     All Ingredients

# %% [markdown]
# Searching through all categories and filtering out columns interested In.

# %%
# Search all products
ingredient = openfoodfacts.products.search_all('ingredients')
print('Stage 1 done')

# Create an empty dataframe
product_table = pd.DataFrame(ingredient)

print('Stage 2 done')

# Filter the product table
Filtpt = product_table[['_id', 'product_name_en', 'product_quantity', 'brands', 'labels', 'packaging', 'url', 'stores']]
# Out:
# stage 1 done
# stage 2 done

# %%
filtb = Filtpt[['product_name_en', 'product_quantity','packaging', 'url', 'stores']]
filtb
# Out:
#                                        product_name_en product_quantity  \
# 0                                Ketchup 5 Ingrédients              468
# 1                                                  NaN              400
# 2                                                  NaN              300
# 3                                                                  1000
# 4                                                  NaN              400
# ..                                                 ...              ...
# 654                                                NaN              NaN
# 655                                                NaN              NaN
# 656  Perfectly Simple, Limited Ingredient Nutrition...              NaN
# 657  D'Allesandro Gourmet Ingredients, Split Mung B...              NaN
# 658  Pepperjack Cheese, A Lively, Flavorful Ingredi...              NaN
#
#                                              packaging  \
# 0    OPERCULE A JETER, BOUTEILLE PLASTIQUE ET SON B...
# 1     Bouteille, Flacon souple, Bouteille en plastique
# 2                                               Carton
# 3                                        Brique,Carton
# 4    Bouteille, Bouchon en plastique, Bouteille en ...
# ..                                                 ...
# 654
# 655                                                NaN
# 656                                                NaN
# 657                                                NaN
# 658                                                NaN
#
#                                                    url  \
# 0    https://world.openfoodfacts.org/product/871052...
# 1    https://world.openfoodfacts.org/product/871052...
# 2    https://world.openfoodfacts.org/product/322982...
# 3    https://world.openfoodfacts.org/product/303681...
# 4    https://world.openfoodfacts.org/product/871052...
# ..                                                 ...
# 654  https://world.openfoodfacts.org/product/541068...
# 655  https://world.openfoodfacts.org/product/500016...
# 656  https://world.openfoodfacts.org/product/063810...
# 657  https://world.openfoodfacts.org/product/068708...
# 658  https://world.openfoodfacts.org/product/021516...
#
#                                                 stores
# 0                               E.Leclerc,carrefour.fr
# 1                                         carrefour.fr
# 2                                       carrefour,lidl
# 3    Banque alimentaire,Leclerc,Magasins U,carrefou...
# 4                                         carrefour.fr
# ..                                                 ...
# 654                                           Delhaize
# 655                                           Waitrose
# 656                                                NaN
# 657                                                NaN
# 658                                                NaN
#
# [659 rows x 5 columns]

# %% [markdown]
# In product_name there were empty spaces and nan values. Remove all of these as I wont be able to identify what products they are.

# %% [markdown]
# ###### Removing ingredients with no name

# %%
noname = filtb.loc[filtb['product_name_en'] == '']
noname
# Out:
#     product_name_en product_quantity  \
# 3                               1000
# 7                                200
# 9                               1000
# 23                              1000
# 32                              1200
# 33                               550
# 42                               600
# 47                               150
# 48                               240
# 52                               375
# 84                               600
# 233                               38
# 370                              150
# 446                              700
#
#                                              packaging  \
# 3                                        Brique,Carton
# 7          Carton, Barquette plastique, Film plastique
# 9                                           Sac papier
# 23
# 32   Tetra Pak,Brique,Récipient,Briquette,Film plas...
# 33                                   Plastique, Sachet
# 42                                Plastique, Bouteille
# 47                        Point vert, Sachet plastique
# 48    Sous atmosphère protectrice, Opercule, Barquette
# 52                                                 Bag
# 84                             fr:Bouteille métallique
# 233
# 370
# 446                                          Container
#
#                                                    url  \
# 3    https://world.openfoodfacts.org/product/303681...
# 7    https://world.openfoodfacts.org/product/325039...
# 9    https://world.openfoodfacts.org/product/327019...
# 23   https://world.openfoodfacts.org/product/930065...
# 32   https://world.openfoodfacts.org/product/317657...
# 33   https://world.openfoodfacts.org/product/325622...
# 42   https://world.openfoodfacts.org/product/309271...
# 47   https://world.openfoodfacts.org/product/505605...
# 48   https://world.openfoodfacts.org/product/318094...
# 52   https://world.openfoodfacts.org/product/325622...
# 84   https://world.openfoodfacts.org/product/309271...
# 233  https://world.openfoodfacts.org/product/006290...
# 370  https://world.openfoodfacts.org/product/871050...
# 446  https://world.openfoodfacts.org/product/402627...
#
#                                                 stores
# 3    Banque alimentaire,Leclerc,Magasins U,carrefou...
# 7                                          Intermarché
# 9                           Carrefour,Dia,carrefour.fr
# 23                                Woolworths,Coles,OTR
# 32                    Magasins U,carrefour.fr,FRANPRIX
# 33                                          Magasins U
# 42                                          Magasins U
# 47                     Magasins U,Proxis, carrefour.fr
# 48                                Auchan, carrefour.fr
# 52                                  Magasins U,Super U
# 84                                               Match
# 233
# 370
# 446                                          Marktkauf

# %%
inglist = filtb[~filtb.isin(noname)]
inglist
# Out:
#                                        product_name_en product_quantity  \
# 0                                Ketchup 5 Ingrédients              468
# 1                                                  NaN              400
# 2                                                  NaN              300
# 3                                                  NaN              NaN
# 4                                                  NaN              400
# ..                                                 ...              ...
# 654                                                NaN              NaN
# 655                                                NaN              NaN
# 656  Perfectly Simple, Limited Ingredient Nutrition...              NaN
# 657  D'Allesandro Gourmet Ingredients, Split Mung B...              NaN
# 658  Pepperjack Cheese, A Lively, Flavorful Ingredi...              NaN
#
#                                              packaging  \
# 0    OPERCULE A JETER, BOUTEILLE PLASTIQUE ET SON B...
# 1     Bouteille, Flacon souple, Bouteille en plastique
# 2                                               Carton
# 3                                                  NaN
# 4    Bouteille, Bouchon en plastique, Bouteille en ...
# ..                                                 ...
# 654
# 655                                                NaN
# 656                                                NaN
# 657                                                NaN
# 658                                                NaN
#
#                                                    url                  stores
# 0    https://world.openfoodfacts.org/product/871052...  E.Leclerc,carrefour.fr
# 1    https://world.openfoodfacts.org/product/871052...            carrefour.fr
# 2    https://world.openfoodfacts.org/product/322982...          carrefour,lidl
# 3                                                  NaN                     NaN
# 4    https://world.openfoodfacts.org/product/871052...            carrefour.fr
# ..                                                 ...                     ...
# 654  https://world.openfoodfacts.org/product/541068...                Delhaize
# 655  https://world.openfoodfacts.org/product/500016...                Waitrose
# 656  https://world.openfoodfacts.org/product/063810...                     NaN
# 657  https://world.openfoodfacts.org/product/068708...                     NaN
# 658  https://world.openfoodfacts.org/product/021516...                     NaN
#
# [659 rows x 5 columns]

# %%
ENFood = inglist.dropna()
ENFood#.product_name_en.isnull()
# Out:
#                           product_name_en product_quantity  \
# 0                   Ketchup 5 Ingrédients              468
# 6                    Chocolat noir fruité              100
# 18     Golden sunflower oil cooking spray              190
# 22                Tuna in olive oil blend               95
# 24                               Pringles   18.99418049375
# ..                                    ...              ...
# 631                                olives              163
# 632    Tomato basil flavored lentil chips              120
# 633           sea salt 70% Dark Chocolate     28.349523125
# 634              Cacao superfood smoothie             1000
# 638  apricot and macadamia toasted muesli              500
#
#                                              packaging  \
# 0    OPERCULE A JETER, BOUTEILLE PLASTIQUE ET SON B...
# 6                                             Tablette
# 18                        Plastic, Bottle, Hdpe-bottle
# 22                                           Tin steel
# 24                                        Plastic, Tub
# ..                                                 ...
# 631                                  Metal, Glass, Jar
# 632                                                Bag
# 633                                            Wrapper
# 634                                             Bottle
# 638
#
#                                                    url  \
# 0    https://world.openfoodfacts.org/product/871052...
# 6    https://world.openfoodfacts.org/product/761303...
# 18   https://world.openfoodfacts.org/product/500044...
# 22   https://world.openfoodfacts.org/product/930046...
# 24   https://world.openfoodfacts.org/product/038083...
# ..                                                 ...
# 631  https://world.openfoodfacts.org/product/007789...
# 632  https://world.openfoodfacts.org/product/085864...
# 633  https://world.openfoodfacts.org/product/087449...
# 634  https://world.openfoodfacts.org/product/942190...
# 638  https://world.openfoodfacts.org/product/073585...
#
#                                     stores
# 0                   E.Leclerc,carrefour.fr
# 6             Carrefour,Leclerc,Magasins U
# 18   Asda,Tesco,Iceland,Waitrose,Morrisons
# 22                       Woolworths, Coles
# 24                                  Kroger
# ..                                     ...
# 631                                Wegmans
# 632                               ShopRite
# 633                            Mama Jean's
# 634                      Géant Dumbea Mall
# 638                                    IGA
#
# [160 rows x 5 columns]

# %%
for o in ENFood.product_name_en:
    print(o)
# Out:
# Ketchup 5 Ingrédients
# Chocolat noir fruité
# Golden sunflower oil cooking spray
# Tuna in olive oil blend
# Pringles
# Nairn's Cheese Oatcakes
# Trecce dell'orto
# Green Giant
# Tahini
# Poulet au curry et riz Basmati
# Light fat spread
# Mouliné de légumes verts
# no added sugar or salt Smooth peanut butter
# Tomates farcies
# Rye Bread
# Muesli Bars Fruit Free
# Diced Tomatoes - No Salt Added
# Gluten Free Rotini Pasta
# Sugar free V
# Vaalia Ygt LF Lusc Bry 900GM
# Carlin peas
# Doisy and Dam Truffles
# Cooks' Ingredients 8 Meringue Nests
# Yoplait Light Harvest Peach Fat Free Yogurt
# Tomato Sauce - No Salt Added
# Doisy and Dam Truffles
# Ingredient Lemon Juice
# Smooth Peanut Butter
# Choc Bar
# Potato & Cheddar Flavoured Perogies
# Tomato Sauce - No Salt Added
# Tomatoes
# Potato, Spinach, & Feta Perogies
# 72% Cocoa Swiss Dark Chocolate
# 90% Cocoa Swiss Dark Chocolate
# Sea Salt Swiss Dark Chocolate
# Sugar free starlight mints
# Potato, Bacon, & Onion Perogies
# Tomato Paste - No Salt Added
# Spinach
# Naturally Flavoured Coconut Mango Creme Cookies
# Naturally Flavoured Coconut Lime Creme Cookies
# Roasted almond chia and honey crunch
# Supervalu Cooks Ingredient Green Pesto (190 Grams)
# Spinach
# Rosemary
# Wholemeal Loaf
# Naturally Flavoured Coconut Mango Creme Cookies
# Potato, Bacon, & Onion Perogies
# Wholemeal Loaf
# Naturally Flavoured Coconut Mango Creme Cookies
# Potato, Bacon, & Onion Perogies
# Organic Wholemeal Kamut
# Rotini
# Sugar free starlight mints
# Delights brownie mix
# Delights brownie mix
# Caramel Toffee Milk Chocolate
# All natural ground beef
# We’re-Bix Multi-Grain
# Lean Cuisine Spaghetti Bolognese
# limes w/ elderflower
# Orange Milk Chocolate
# VIDRATE
# 100% Grape Juice From Concentrate With Added Ingredient
# Plant-based burgers
# Kornig 14 Seeds & Grains
# Very Berry Toasted Muesli
# Keto Protein Cookie
# Cookie chocolate chip
# Pediasure Vanilla
# Cerealology Chef-Inspired Blends Fruit & Maple Crunch Cereal
# Natural Selection Crystallised ginger
# Rye Bread
# Breakfast Muesli - Blueberries, Goji Berries, Coconut & Chia
# Breakfast Muesli - Blueberries, Goji Berries, Coconut & Chia
# Special K Milk Chocolate
# Tasty curry sauce mix medium hot
# Twinings Strawberry & Raspberry Tea
# Australia draught
# MeadowLea Original
# elite 100% whey
# Vine Ripened Tomato Marinara Sauce
# Tomato paste
# Sourdough grain
# Gnocchi fresh potato
# dark fruits
# 100% juice blend
# Fish 'n' chips
# Aussie Classic Lamington Bar Cake
# Coles Orange Juice
# 100% juice blend
# Hot & Spicy Tom-Toms Turkey Snack Stick
# Cream Cheese Spread
# Cream Cheese Spread
# 100% juice blend
# Hot & Spicy Tom-Toms Turkey Snack Stick
# Crunchy Peanut Butter
# Wholemeal Family Loaf
# Pineapple & Grapefruit Green Tea
# Coco-Chia Tropical Fruit Smoothie
# Traditional Napoli Sauce
# Chicken and Coriander Dumplings
# Organic Basil
# Flat Leaf Parsley
# Country Orchard 100% Orange Juice
# 100% juice apple juice from concentrate with added ingredient
# Cheese Lasagna Rolls
# Cheese Lasagna Rolls
# Aylmer Accents Original Green Pepper, Celery & Onions Chunky Stewed Tomatoes
# ALL NATURAL SMOKED TURKEY BREAST SLICED
# Chicken Leg Quarters
# Marinara pasta sauce
# olives
# Aylmer Accents Original Green Pepper, Celery & Onions Chunky Stewed Tomatoes
# ALL NATURAL SMOKED TURKEY BREAST SLICED
# Chicken Leg Quarters
# Marinara pasta sauce
# olives
# Tomato basil flavored lentil chips
# sea salt 70% Dark Chocolate
# Aylmer Accents Original Green Pepper, Celery & Onions Chunky Stewed Tomatoes
# ALL NATURAL SMOKED TURKEY BREAST SLICED
# Chicken Leg Quarters
# Marinara pasta sauce
# olives
# Tomato basil flavored lentil chips
# sea salt 70% Dark Chocolate
# Pineapple & Grapefruit Green Tea
# ALL NATURAL SMOKED TURKEY BREAST SLICED
# Chicken Leg Quarters
# Marinara pasta sauce
# olives
# Tomato basil flavored lentil chips
# sea salt 70% Dark Chocolate
# Cacao superfood smoothie
# ALL NATURAL SMOKED TURKEY BREAST SLICED
# Chicken Leg Quarters
# Marinara pasta sauce
# olives
# Tomato basil flavored lentil chips
# sea salt 70% Dark Chocolate
# Cacao superfood smoothie
# Traditional Napoli Sauce
# ALL NATURAL SMOKED TURKEY BREAST SLICED
# Chicken Leg Quarters
# Marinara pasta sauce
# olives
# Tomato basil flavored lentil chips
# sea salt 70% Dark Chocolate
# Cacao superfood smoothie
# Flat Leaf Parsley
# ALL NATURAL SMOKED TURKEY BREAST SLICED
# Chicken Leg Quarters
# Marinara pasta sauce
# olives
# Tomato basil flavored lentil chips
# sea salt 70% Dark Chocolate
# Cacao superfood smoothie
# apricot and macadamia toasted muesli

# %% [markdown]
#                                           All products that start with an A

# %%
A = ENFood.loc[ENFood['product_name_en'].str.startswith('A')]
A
# Out:
#                                        product_name_en product_quantity  \
# 291                            All natural ground beef             1000
# 350                                  Australia draught              375
# 405                  Aussie Classic Lamington Bar Cake              450
# 505  Aylmer Accents Original Green Pepper, Celery &...              540
# 513            ALL NATURAL SMOKED TURKEY BREAST SLICED            18000
# 520  Aylmer Accents Original Green Pepper, Celery &...              540
# 531            ALL NATURAL SMOKED TURKEY BREAST SLICED            18000
# 542  Aylmer Accents Original Green Pepper, Celery &...              540
# 551            ALL NATURAL SMOKED TURKEY BREAST SLICED            18000
# 569            ALL NATURAL SMOKED TURKEY BREAST SLICED            18000
# 588            ALL NATURAL SMOKED TURKEY BREAST SLICED            18000
# 606            ALL NATURAL SMOKED TURKEY BREAST SLICED            18000
# 625            ALL NATURAL SMOKED TURKEY BREAST SLICED            18000
#
#        packaging                                                url  \
# 291      Plastic  https://world.openfoodfacts.org/product/003977...
# 350       Bottle  https://world.openfoodfacts.org/product/085205...
# 405      Plastic  https://world.openfoodfacts.org/product/933968...
# 505          Can  https://world.openfoodfacts.org/product/006000...
# 513  Plastic bag  https://world.openfoodfacts.org/product/100422...
# 520          Can  https://world.openfoodfacts.org/product/006000...
# 531  Plastic bag  https://world.openfoodfacts.org/product/100422...
# 542          Can  https://world.openfoodfacts.org/product/006000...
# 551  Plastic bag  https://world.openfoodfacts.org/product/100422...
# 569  Plastic bag  https://world.openfoodfacts.org/product/100422...
# 588  Plastic bag  https://world.openfoodfacts.org/product/100422...
# 606  Plastic bag  https://world.openfoodfacts.org/product/100422...
# 625  Plastic bag  https://world.openfoodfacts.org/product/100422...
#
#          stores
# 291
# 350        Aldi
# 405  Woolworths
# 505   Richelieu
# 513
# 520   Richelieu
# 531
# 542   Richelieu
# 551
# 569
# 588
# 606
# 625

# %%
a = ENFood.loc[ENFood['product_name_en'].str.startswith('a')]
a
# Out:
#                           product_name_en product_quantity packaging  \
# 638  apricot and macadamia toasted muesli              500
#
#                                                    url stores
# 638  https://world.openfoodfacts.org/product/073585...    IGA

# %% [markdown]
#                                           All products that start with a B

# %%
B = ENFood.loc[ENFood['product_name_en'].str.startswith('B')]
B
# Out:
#                                        product_name_en product_quantity  \
# 336  Breakfast Muesli - Blueberries, Goji Berries, ...              500
# 342  Breakfast Muesli - Blueberries, Goji Berries, ...              500
#
#                        packaging  \
# 336  Resealable bag,Soft Plastic
# 342  Resealable bag,Soft Plastic
#
#                                                    url            stores
# 336  https://world.openfoodfacts.org/product/931189...  Woolworths,Coles
# 342  https://world.openfoodfacts.org/product/931189...  Woolworths,Coles

# %% [markdown]
#                                           All products that start with a C

# %%
C = ENFood.loc[ENFood['product_name_en'].str.startswith('C')]
C
# Out:
#                                        product_name_en product_quantity  \
# 6                                 Chocolat noir fruité              100
# 197                                        Carlin peas              230
# 200                Cooks' Ingredients 8 Meringue Nests               30
# 209                                           Choc Bar               85
# 287                      Caramel Toffee Milk Chocolate              100
# 311                              Cookie chocolate chip  120.48547328125
# 319  Cerealology Chef-Inspired Blends Fruit & Maple...        453.59237
# 428                                 Coles Orange Juice             2000
# 438                                Cream Cheese Spread              227
# 440                                Cream Cheese Spread              227
# 447                              Crunchy Peanut Butter              375
# 457                  Coco-Chia Tropical Fruit Smoothie             1000
# 459                    Chicken and Coriander Dumplings              200
# 464                  Country Orchard 100% Orange Juice             2000
# 498                               Cheese Lasagna Rolls        907.18474
# 503                               Cheese Lasagna Rolls        907.18474
# 514                               Chicken Leg Quarters            10000
# 532                               Chicken Leg Quarters            10000
# 552                               Chicken Leg Quarters            10000
# 570                               Chicken Leg Quarters            10000
# 578                           Cacao superfood smoothie             1000
# 589                               Chicken Leg Quarters            10000
# 597                           Cacao superfood smoothie             1000
# 607                               Chicken Leg Quarters            10000
# 616                           Cacao superfood smoothie             1000
# 626                               Chicken Leg Quarters            10000
# 634                           Cacao superfood smoothie             1000
#
#                              packaging  \
# 6                             Tablette
# 197           Metal, Paper, Can, Label
# 200         Plastic film, Plastic tray
# 209
# 287
# 311                       Plastic, Bag
# 319                     Card Board Box
# 428                            Plastic
# 438                            Plastic
# 440                            Plastic
# 447  Glass jar with metal screw on lid
# 457                             Bottle
# 459                    Plastic, Frozen
# 464                     Plastic Bottle
# 498                Frozen,Microwavable
# 503                Frozen,Microwavable
# 514                        Plastic Bag
# 532                        Plastic Bag
# 552                        Plastic Bag
# 570                        Plastic Bag
# 578                             Bottle
# 589                        Plastic Bag
# 597                             Bottle
# 607                        Plastic Bag
# 616                             Bottle
# 626                        Plastic Bag
# 634                             Bottle
#
#                                                    url  \
# 6    https://world.openfoodfacts.org/product/761303...
# 197  https://world.openfoodfacts.org/product/506032...
# 200  https://world.openfoodfacts.org/product/500016...
# 209  https://world.openfoodfacts.org/product/292568...
# 287  https://world.openfoodfacts.org/product/062773...
# 311  https://world.openfoodfacts.org/product/070374...
# 319  https://world.openfoodfacts.org/product/004122...
# 428  https://world.openfoodfacts.org/product/930060...
# 438  https://world.openfoodfacts.org/product/032440...
# 440  https://world.openfoodfacts.org/product/032440...
# 447  https://world.openfoodfacts.org/product/930063...
# 457  https://world.openfoodfacts.org/product/942190...
# 459  https://world.openfoodfacts.org/product/933652...
# 464  https://world.openfoodfacts.org/product/261616...
# 498  https://world.openfoodfacts.org/product/409910...
# 503  https://world.openfoodfacts.org/product/409910...
# 514  https://world.openfoodfacts.org/product/003737...
# 532  https://world.openfoodfacts.org/product/003737...
# 552  https://world.openfoodfacts.org/product/003737...
# 570  https://world.openfoodfacts.org/product/003737...
# 578  https://world.openfoodfacts.org/product/942190...
# 589  https://world.openfoodfacts.org/product/003737...
# 597  https://world.openfoodfacts.org/product/942190...
# 607  https://world.openfoodfacts.org/product/003737...
# 616  https://world.openfoodfacts.org/product/942190...
# 626  https://world.openfoodfacts.org/product/003737...
# 634  https://world.openfoodfacts.org/product/942190...
#
#                            stores
# 6    Carrefour,Leclerc,Magasins U
# 197                          Suma
# 200                      Waitrose
# 209             Marks and Spencer
# 287                       Walmart
# 311
# 319
# 428                         Coles
# 438             Wal-Mart, Walmart
# 440             Wal-Mart, Walmart
# 447                    Woolworths
# 457             Géant Dumbea Mall
# 459                    Coles,Bilo
# 464                          Aldi
# 498
# 503
# 514
# 532
# 552
# 570
# 578             Géant Dumbea Mall
# 589
# 597             Géant Dumbea Mall
# 607
# 616             Géant Dumbea Mall
# 626
# 634             Géant Dumbea Mall

# %% [markdown]
#                                           All products that start with a D

# %%
D = ENFood.loc[ENFood['product_name_en'].str.startswith('D')]
D
# Out:
#                     product_name_en product_quantity     packaging  \
# 188  Diced Tomatoes - No Salt Added   411.0680853125  metal, paper
# 198          Doisy and Dam Truffles              144          Card
# 205          Doisy and Dam Truffles              144          Card
# 278            Delights brownie mix      521.6312255  Carboard Box
# 281            Delights brownie mix      521.6312255  Carboard Box
#
#                                                    url stores
# 188  https://world.openfoodfacts.org/product/002700...
# 198  https://world.openfoodfacts.org/product/506050...
# 205  https://world.openfoodfacts.org/product/506050...
# 278  https://world.openfoodfacts.org/product/001600...
# 281  https://world.openfoodfacts.org/product/001600...

# %%
d = ENFood.loc[ENFood['product_name_en'].str.startswith('d')]
d
# Out:
#     product_name_en product_quantity packaging  \
# 382     dark fruits              125   Plastic
#
#                                                    url      stores
# 382  https://world.openfoodfacts.org/product/942102...  Pak n save
