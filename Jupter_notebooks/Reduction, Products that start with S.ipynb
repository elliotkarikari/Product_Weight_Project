# %% [markdown]
# # Product Weighting Project

# %% [markdown]
#                                          Data Reduction - Food Purchased In Store

# %% [markdown]
# ###### Import Necessary Libraries

# %%
import pandas as pd

# %% [markdown]
# Read in Data

# %%
Labelled = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Labelling2021_watercress.csv')

# %% [markdown]
# ### Products beginning with a 'S'

# %%
prod_s = Labelled.loc[Labelled['Food Name'].str.startswith('S')]
prod_s
# Out:
#      Food Code                                          Food Name  \
# 2392    15-629                                     Saag, homemade
# 2393    13-852                                            Saffron
# 2394    13-854                                Sage, dried, ground
# 2395    13-853                                        Sage, fresh
# 2396    11-023                                          Sago, raw
# ...        ...                                                ...
# 2663    16-223  Swordfish, flesh only, grilled, weighed with b...
# 2664    16-221                         Swordfish, flesh only, raw
# 2665    17-064                                  Syrup, corn, dark
# 2666    17-065                                      Syrup, golden
# 2667    16-335          Szechuan prawns with vegetables, takeaway
#
#                                             Description Group  Previous  \
# 2392                           5 samples, spinach curry    DR       NaN
# ...

# %% [markdown]
# Products within a Group (provide identification of the food group and food type to which the food belongs)

# %%
prod_s.groupby('Group')['Food Name'].count()
# Out:
# Group
# AA      2
# AB      6
# AM      1
# AN      2
# AP      8
# AS      2
# AT      3
# BP      1
# BV      1
# CD      2
# DG     38
# DI      2
# DR     26
# FA      6
# GA      3
# H       3
# J       5
# JA      6
# JC     23
# JK      7
# JM      3
# JR      8
# MG      2
# MI     22
# MR     20
# OF      2
# PE      1
# QA      3
# QF      1
# QK      1
# SC      6
# SEA     1
# SEC     3
# SNC     1
# WA      5
# WAA    11
# WAC     8
# WAE     4
# WC     16
# WCG     2
# WCN     2
# WY      7
# Name: Food Name, dtype: int64

# %% [markdown]
# ## *Reducing products based on its most basic form. Improve as you go on*

# %% [markdown]
#                                                 Cereals and cereal products

# %% [markdown]
# Flours, grains and starches

# %%
aa = prod_s.loc[prod_s['Group']== 'AA']
aa
# Out:
#      Food Code      Food Name                     Description Group Previous  \
# 2396    11-023      Sago, raw  2 samples from different shops    AA  50-008
# 2517    11-903  Semolina, raw           6 samples, 5 products    AA  11-024
#
#                            Main data references Footnote Energy (kJ)  \
# 2396                   MW3, 1960. Reviewed 2014      NaN        1468
# 2517  Nutrient survey of flours and grains 2005      NaN        1482
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2396           346      0.2           0.1             85.5          0
# 2517           349      1.6          0.23             70.7        0.5
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2396       85.5       0.5          0.3     0.01
# 2517       70.3       2.9         11.6        0

# %% [markdown]
# **Reduced**

# %%
filt_aa = aa[aa['Food Name'] == 'Semolina, raw']
filt_aa
# Out:
#      Food Code      Food Name            Description Group Previous  \
# 2517    11-903  Semolina, raw  6 samples, 5 products    AA  11-024
#
#                            Main data references Footnote Energy (kJ)  \
# 2517  Nutrient survey of flours and grains 2005      NaN        1482
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2517           349      1.6          0.23             70.7        0.5
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2517       70.3       2.9         11.6        0

# %%
filt_aa['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\3107044486.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_aa['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Sandwiches

# %%
ab = prod_s.loc[prod_s['Group']== 'AB']
ab
# Out:
#      Food Code                                         Food Name  \
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2439    11-963  Sandwich, white bread, cheddar cheese and pickle
# 2440    11-964              Sandwich, white bread, chicken salad
# 2441    11-966             Sandwich, white bread, egg mayonnaise
# 2442    11-965                  Sandwich, white bread, ham salad
# 2443    11-967            Sandwich, white bread, tuna mayonnaise
#
#                                             Description Group Previous  \
# 2438  Recipe from University of North London survey ...    AB  11-563
# 2439  Recipe from University of North London survey ...    AB  11-564
# 2440  Recipe from University of North London survey ...    AB  11-565
# 2441  Recipe from University of North London survey ...    AB  11-567
# 2442  Recipe from University of North London survey ...    AB  11-566
# 2443  Recipe from University of North London survey ...    AB  11-568
#
# ...

# %%
ab['Food Name'].unique()
# Out:
# array(['Sandwich, white bread, bacon, lettuce and tomato',
#        'Sandwich, white bread, cheddar cheese and pickle',
#        'Sandwich, white bread, chicken salad',
#        'Sandwich, white bread, egg mayonnaise',
#        'Sandwich, white bread, ham salad',
#        'Sandwich, white bread, tuna mayonnaise'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
filt_ab = ab[ab['Food Name'] == 'Sandwich, white bread, bacon, lettuce and tomato']
filt_ab
# Out:
#      Food Code                                         Food Name  \
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
#
#                                             Description Group Previous  \
# 2438  Recipe from University of North London survey ...    AB  11-563
#
#                                    Main data references Footnote Energy (kJ)  \
# 2438  University of North London 1997. Recalculated ...      NaN         973
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2438           233     11.9          2.46             21.9        2.2
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2438       19.7       1.5          8.7     1.19

# %%
filt_ab['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\1016340840.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_ab['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Biscuits

# %%
am = prod_s.loc[prod_s['Group']== 'AM']
am
# Out:
#      Food Code   Food Name             Description Group Previous  \
# 2534    11-802  Shortbread  10 samples, 7 products    AM  11-523
#
#                                    Main data references Footnote Energy (kJ)  \
# 2534  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        2162
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2534           517     29.0         17.45             57.1       14.9
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2534       42.3       2.2          5.9      0.8

# %%
am['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\2518148781.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   am['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Removed AN - Cakes

# %% [markdown]
# Buns and pastries

# %%
ap = prod_s.loc[prod_s['Group']== 'AP']
ap
# Out:
#      Food Code                           Food Name  \
# 2499   11-1112            Scones, cheese, homemade
# 2500    11-993               Scones, fruit, retail
# 2501   11-1115  Scones, fruit, wholemeal, homemade
# 2502    11-958             Scones, plain, homemade
# 2504   11-1113            Scones, potato, homemade
# 2505   11-1114         Scones, wholemeal, homemade
# 2508   11-1116           Scotch pancakes, homemade
# 2509    11-544             Scotch pancakes, retail
#
#                            Description Group        Previous  \
# 2499                            Recipe    AP         11-669
# 2500  10 samples, 5 brands, 3 bakeries    AP         11-543
# 2501                            Recipe    AP         11-674
# 2502                            Recipe    AP         11-592
# 2504                            Recipe    AP         11-673
# 2505  Recipe. Ref. Wiles et al. (1980)    AP         11-593
# 2508                            Recipe    AP         11-675
# ...

# %% [markdown]
# **Reduced**

# %%
filt_ap = ap[ap['Food Name'] == 'Scotch pancakes, retail']
filt_ap
# Out:
#      Food Code                Food Name          Description Group  \
# 2509    11-544  Scotch pancakes, retail  6 samples, 4 brands    AP
#
#             Previous                               Main data references  \
# 2509  11-270 50-148   LGC, Nutrient analysis of bread and morning go...
#
#      Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 2509      NaN        1160           276      9.6          0.74
#
#      Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2509             40.2       20.6       19.5       1.9          6.3     1.05

# %%
filt_ap['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\366743703.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_ap['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Puddings

# %%
AS = prod_s.loc[prod_s['Group']== 'AS']
AS
# Out:
#      Food Code                              Food Name  \
# 2521    11-915                      Sevyian, homemade
# 2621    11-919  Strudel, fruit filled, retail, frozen
#
#                                            Description Group Previous  \
# 2521  6 samples, dessert made from vermicelli and milk    AS  11-676
# 2621                            12 samples, 7 products    AS      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2521  University of Leeds, Nutritional analysis of c...      NaN         511
# 2621  ADAS Laboratories, Nutrient analysis of ice cr...      NaN        1060
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2521           121      3.1          1.86               19         13
# 2621           254     13.5          5.02             27.3       10.5
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2521          6         1          3.8      0.1
# ...

# %% [markdown]
# **Reduced**

# %%
filt_AS = AS[AS['Food Name'] == 'Strudel, fruit filled, retail, frozen']
filt_AS
# Out:
#      Food Code                              Food Name             Description  \
# 2621    11-919  Strudel, fruit filled, retail, frozen  12 samples, 7 products
#
#      Group Previous                               Main data references  \
# 2621    AS      NaN  ADAS Laboratories, Nutrient analysis of ice cr...
#
#      Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 2621      NaN        1060           254     13.5          5.02
#
#      Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2621             27.3       10.5       16.7       5.4          3.0        N

# %%
filt_AS['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\3274103439.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_AS['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Savouries

# %%
at= prod_s.loc[prod_s['Group']== 'AT']
at
# Out:
#      Food Code                                        Food Name  \
# 2622    17-371                              Stuffing mix, dried
# 2623    17-372  Stuffing mix, dried, assorted flavours, made up
# 2624   11-1000               Stuffing, sage and onion, homemade
#
#                                   Description Group Previous  \
# 2622  10 samples, 4 brands; assorted flavours    AT  50-178
# 2623   Made up according to packet directions    AT  50-179
# 2624                                   Recipe    AT  11-606
#
#                       Main data references Footnote Energy (kJ) Energy (kcal)  \
# 2622  Miscellaneous Foods Supplement, 1994      NaN        1458           345
# 2623                             MW5, 1991      NaN         417            99
# 2624          As MW6. Recalculated in 2013      NaN        1070           256
#
#       Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# ...

# %%
at['Food Name'].unique()
# Out:
# array(['Stuffing mix, dried',
#        'Stuffing mix, dried, assorted flavours, made up',
#        'Stuffing, sage and onion, homemade'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
filt_at = at[at['Food Name'] == 'Stuffing mix, dried']
filt_at
# Out:
#      Food Code            Food Name                              Description  \
# 2622    17-371  Stuffing mix, dried  10 samples, 4 brands; assorted flavours
#
#      Group Previous                  Main data references Footnote  \
# 2622    AT  50-178   Miscellaneous Foods Supplement, 1994      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 2622        1458           345      5.2           2.4             61.4
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2622        4.3       57.1       6.8          9.9     3.65

# %%
filt_at['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\2533386253.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_at['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Removed BP, BV, CD

# %% [markdown]
#                                                         Vegetables

# %% [markdown]
# Vegetables, general

# %%
dg = prod_s.loc[prod_s['Group']== 'DG']
dg
# Out:
#      Food Code                                          Food Name  \
# 2430    13-601      Salsify, flesh only, boiled in unsalted water
# 2431    13-334                           Salsify, flesh only, raw
# 2512    13-337       Seakale, stem only, boiled in unsalted water
# 2513    13-338                           Seaweed, Irish moss, raw
# 2514    13-339                         Seaweed, kombu, dried, raw
# 2515    13-340                          Seaweed, nori, dried, raw
# 2516    13-341                        Seaweed, wakame, dried, raw
# 2522    13-342                                      Shallots, raw
# 2581    13-550            Spinach, baby, boiled in unsalted water
# 2582    13-521                                 Spinach, baby, raw
# 2584    13-458          Spinach, frozen, boiled in unsalted water
# 2585    13-573          Spinach, mature, boiled in unsalted water
# 2586    13-572                               Spinach, mature, raw
# ...

# %%
dg['Food Name'].unique()
# Out:
# array(['Salsify, flesh only, boiled in unsalted water',
#        'Salsify, flesh only, raw',
#        'Seakale, stem only, boiled in unsalted water',
#        'Seaweed, Irish moss, raw', 'Seaweed, kombu, dried, raw',
#        'Seaweed, nori, dried, raw', 'Seaweed, wakame, dried, raw',
#        'Shallots, raw', 'Spinach, baby, boiled in unsalted water',
#        'Spinach, baby, raw', 'Spinach, frozen, boiled in unsalted water',
#        'Spinach, mature, boiled in unsalted water',
#        'Spinach, mature, raw', 'Spring greens, boiled in unsalted water',
#        'Spring greens, raw', 'Spring onions, bulbs and tops, raw',
#        'Spring onions, bulbs only, raw', 'Squash, acorn, baked',
#        'Squash, acorn, raw', 'Squash, butternut, baked',
#        'Squash, butternut, boiled in unsalted water',
#        'Squash, butternut, raw', 'Squash, spaghetti, baked',
#        'Squash, spaghetti, raw',
#        'Swede, flesh only, boiled in unsalted water',
# ...

# %% [markdown]
# **Reduced**

# %%
priority_dg = ['Spinach, baby, raw', 'Swede, flesh only, raw','Sweet potato, baked','Sweetcorn kernels, canned in water, drained','Sweetcorn, kernels, raw']

# %%
filt_dg = dg[dg['Food Name'].isin(priority_dg)]
filt_dg
# Out:
#      Food Code                                    Food Name  \
# 2582    13-521                           Spinach, baby, raw
# 2639    13-359                       Swede, flesh only, raw
# 2644    13-672                          Sweet potato, baked
# 2651    13-529  Sweetcorn kernels, canned in water, drained
# 2658    13-622                      Sweetcorn, kernels, raw
#
#                                             Description Group Previous  \
# 2582  16 samples, autumn and winter, UK grown and im...    DG      NaN
# 2639                                      Peeled thinly    DG  50-819
# 2644        Literature sources and calculation from raw    DG   13-363
# 2651       12 samples, 8 brands, no added salt or sugar    DG  13-459
# 2658                              IFR; removed from cob    DG  13-368
#
#                                    Main data references Footnote Energy (kJ)  \
# 2582  DH, Nutrient analysis of fruit and vegetables,...      NaN          78
# ...

# %%
filt_dg['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\412654847.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_dg['Super Group'] = 'Vegetables'

# %% [markdown]
# Removed DI - Vegetables, dried

# %% [markdown]
# Vegetable dishes

# %%
dr = prod_s.loc[prod_s['Group']== 'DR']
dr
# Out:
#      Food Code                                          Food Name  \
# 2392    15-629                                     Saag, homemade
# 2399    15-870       Salad, beetroot and onion in French dressing
# 2400    15-871                                       Salad, Greek
# 2401    15-648                                       Salad, green
# 2402    15-872            Salad, pasta, vegetables and mayonnaise
# 2403    15-873                Salad, potato, with French dressing
# 2404    15-874                     Salad, potato, with mayonnaise
# 2405    15-654             Salad, potato, with mayonnaise, retail
# 2406    15-875                                 Salad, rice, brown
# 2407    15-649                              Salad, rice, homemade
# 2408    15-876                            Salad, tomato and onion
# 2409    15-878                                     Salad, Waldorf
# 2410    15-294  Salad, wholemeal pasta, with vegetables and ma...
# ...

# %%
dr['Food Name'].unique()
# Out:
# array(['Saag, homemade', 'Salad, beetroot and onion in French dressing',
#        'Salad, Greek', 'Salad, green',
#        'Salad, pasta, vegetables and mayonnaise',
#        'Salad, potato, with French dressing',
#        'Salad, potato, with mayonnaise',
#        'Salad, potato, with mayonnaise, retail', 'Salad, rice, brown',
#        'Salad, rice, homemade', 'Salad, tomato and onion',
#        'Salad, Waldorf',
#        'Salad, wholemeal pasta, with vegetables and mayonnaise',
#        'Sambar, homemade', 'Samosas, vegetable, retail',
#        'Sauce, curry, onion, with butter, homemade',
#        'Sauce, curry, onion, with vegetable oil, homemade',
#        'Sauce, curry, sweet, UK type, homemade',
#        'Sauce, curry, tomato and onion, homemade',
#        'Sauce, tomato and mushroom, homemade', 'Sauerkraut',
#        'Sausages, vegetarian, baked/grilled', "Shepherd's pie, vegetable",
#        "Shepherd's pie, vegetable, retail", 'Sushi, vegetable',
# ...

# %%
priority_dr = ['Salad, pasta, vegetables and mayonnaise',"Shepherd's pie, vegetable",'Sushi, vegetable']

# %%
filt_dr = dr[dr['Food Name'].isin(priority_dr)]
filt_dr
# Out:
#      Food Code                                Food Name  \
# 2402    15-872  Salad, pasta, vegetables and mayonnaise
# 2528    15-883                Shepherd's pie, vegetable
# 2637    15-617                         Sushi, vegetable
#
#                                             Description Group Previous  \
# 2402                 Recipe from dietary survey records    DR  15-590
# 2528  Recipe. Vegetable and lentil base with potato ...    DR  15-602
# 2637                             10 samples, 9 products    DR      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2402                                       Updated 2014      NaN         639
# 2528                                       Updated 2014      NaN         482
# 2637  Direct Laboratories, Nutrient analysis catch u...      NaN         631
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2402           153      7.9          0.76             15.9        1.9
# ...

# %%
filt_dr['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\2816155892.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_dr['Super Group'] = 'Vegetables'

# %% [markdown]
#                                                            Fruit

# %%
fa = prod_s.loc[prod_s['Group']== 'FA']
fa
# Out:
#      Food Code                 Food Name  \
# 2444    14-256     Sapodilla, flesh only
# 2526    14-259  Sharon fruit, flesh only
# 2605    14-059                Star fruit
# 2620    14-324         Strawberries, raw
# 2627    14-076   Sugar apple, flesh only
# 2632    14-263                  Sultanas
#
#                                             Description Group Previous  \
# 2444                                Literature sources;    FA      NaN
# 2526                               7 samples, Persimmon    FA      NaN
# 2605  Carambola. Analysis and literature sources; en...    FA      NaN
# 2620  19 samples, summer and autumn, UK grown and im...    FA  14-260
# 2627  Literature sources, Annona squamosa, sometimes...    FA      NaN
# 2632                  10 samples, 9 brands; whole fruit    FA  50-969
#
#                                    Main data references Footnote Energy (kJ)  \
# 2444                    Fruit and Nuts Supplement, 1992      NaN         363
# ...

# %%
fa['Food Name'].unique()
# Out:
# array(['Sapodilla, flesh only', 'Sharon fruit, flesh only', 'Star fruit',
#        'Strawberries, raw', 'Sugar apple, flesh only', 'Sultanas'],
#       dtype=object)

# %% [markdown]
# **Reduced**

# %%
priority_fa = ['Strawberries, raw','Star fruit']

# %%
filt_fa = fa[fa['Food Name'].isin(priority_fa)]
filt_fa
# Out:
#      Food Code          Food Name  \
# 2605    14-059         Star fruit
# 2620    14-324  Strawberries, raw
#
#                                             Description Group Previous  \
# 2605  Carambola. Analysis and literature sources; en...    FA      NaN
# 2620  19 samples, summer and autumn, UK grown and im...    FA  14-260
#
#                                    Main data references Footnote Energy (kJ)  \
# 2605                    Fruit and Nuts Supplement, 1992      NaN         182
# 2620  DH, Nutrient analysis of fruit and vegetables,...      NaN         178
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2605            43      0.3           0.1              7.2        7.1
# 2620            42      0.5          0.04              6.1        6.1
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2605        0.2       2.8          0.5     0.01
# 2620          0       3.8          0.6        0

# %%
filt_fa['Super Group'] = 'Fruit'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\1984065028.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_fa['Super Group'] = 'Fruit'

# %% [markdown]
#                                                     Nuts and seeds

# %%
ga = prod_s.loc[prod_s['Group']== 'GA']
ga
# Out:
#      Food Code                 Food Name                         Description  \
# 2519    14-844              Sesame seeds  10 samples, with and without hulls
# 2633    14-845           Sunflower seeds     Analysis and literature sources
# 2634    14-846  Sunflower seeds, toasted              Calculated from 14-845
#
#      Group        Previous                               Main data references  \
# 2519    GA  50-944 14-858   Reviewed 2013. LGC, Fatty acid composition of ...
# 2633    GA  50-995 14-859   Reviewed 2013. LGC, Fatty acid composition of ...
# 2634    GA             NaN  LGC, Fatty acid composition of foods, 1987; an...
#
#      Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 2519      NaN        2645           641     58.0         10.48
# 2633      NaN        2513           606     47.5          6.58
# 2634      NaN        2607           629     49.2           6.8
#
#      Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# ...

# %% [markdown]
# **Reduced**

# %%
filt_ga = ga[ga['Food Name'] == 'Sunflower seeds']

# %%
filt_ga['Super Group'] = 'Nuts and seeds'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\1548421473.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_ga['Super Group'] = 'Nuts and seeds'

# %% [markdown]
#                                                     Herbs and spices

# %%
h = prod_s.loc[prod_s['Group']== 'H']
h
# Out:
#      Food Code            Food Name                           Description  \
# 2393    13-852              Saffron                    Literature sources
# 2394    13-854  Sage, dried, ground                     Literature souces
# 2395    13-853          Sage, fresh  5 samples and calculation from dried
#
#      Group Previous                               Main data references  \
# 2393     H      NaN  Marsh et al. (1977) Composition of foods: spic...
# 2394     H  50-850   Marsh et al. (1977) Composition of foods: spic...
# 2395     H      NaN               LGC, Fruit and vegetables, 1989-1990
#
#      Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 2393      NaN        1489           353      5.9          1.59
# 2394      NaN        1549           372     12.7             7
# 2395      NaN         533           128      4.6           2.6
#
#      Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# ...

# %% [markdown]
# **Reduced**

# %%
priority_h = ['Saffron','Sage, dried, ground']

# %%
filt_h = h[h['Food Name'].isin(priority_h)]
filt_h
# Out:
#      Food Code            Food Name         Description Group Previous  \
# 2393    13-852              Saffron  Literature sources     H      NaN
# 2394    13-854  Sage, dried, ground   Literature souces     H  50-850
#
#                                    Main data references Footnote Energy (kJ)  \
# 2393  Marsh et al. (1977) Composition of foods: spic...      NaN        1489
# 2394  Marsh et al. (1977) Composition of foods: spic...      NaN        1549
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2393           353      5.9          1.59             61.5       44.1
# 2394           372     12.7             7             38.8        1.7
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2393       17.4       3.9         11.4     0.38
# 2394       37.1      29.9         10.6     0.03

# %%
filt_h['Super Group'] = 'Herbs and spices'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\16012654.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_h['Super Group'] = 'Herbs and spices'

# %% [markdown]
#                                                 Fish and fish products

# %% [markdown]
# Molluscs

# %%
j = prod_s.loc[prod_s['Group']== 'J']
j
# Out:
#      Food Code                            Food Name  \
# 2415    16-359    Salmon, farmed, flesh only, baked
# 2416    16-357  Salmon, farmed, flesh only, grilled
# 2418    16-356      Salmon, farmed, flesh only, raw
# 2419    16-358  Salmon, farmed, flesh only, steamed
# 2427    16-360        Salmon, wild, flesh only, raw
#
#                     Description Group Previous  \
# 2415  10 samples, fresh fillets     J      NaN
# 2416  10 samples, fresh fillets     J  16-327
# 2418  10 samples, fresh fillets     J  16-326
# 2419  10 samples, fresh fillets     J  16-205
# 2427   10 samples, fresh steaks     J  16-326
#
#                                    Main data references Footnote Energy (kJ)  \
# 2415  Direct Laboratories, Nutrient analysis catch u...      NaN         968
# 2416  Direct Laboratories, Nutrient analysis catch u...      NaN         996
# 2418  Direct Laboratories, Nutrient analysis catch u...      NaN         903
# ...

# %% [markdown]
# **Reduced**

# %%
filt_j = j[j['Food Name'] == 'Salmon, farmed, flesh only, raw' ]

# %%
filt_j['Super Group'] = 'Fish and fish products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\3852209710.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_j['Super Group'] = 'Fish and fish products'

# %% [markdown]
# Remvoed JA - White fish

# %% [markdown]
# Fatty fish

# %%
jc = prod_s.loc[prod_s['Group']== 'JC']
jc
# Out:
#      Food Code                                          Food Name  \
# 2417    16-484  Salmon, farmed, flesh only, grilled, weighed w...
# 2420    16-483  Salmon, farmed, flesh only, steamed, fillets w...
# 2421    16-420             Salmon, pink, canned in brine, drained
# 2422    16-418              Salmon, red, canned in brine, drained
# 2423    16-419  Salmon, red, canned in brine, skinless and bon...
# 2424    16-412                       Salmon, smoked (cold-smoked)
# 2425    16-413                        Salmon, smoked (hot-smoked)
# 2426    16-485                                Salmon, wild, baked
# 2428    16-486                              Salmon, wild, grilled
# 2429    16-487                              Salmon, wild, steamed
# 2445    16-424                 Sardines, canned in brine, drained
# 2446    16-440             Sardines, canned in olive oil, drained
# 2447    16-439         Sardines, canned in sunflower oil, drained
# ...

# %%
jc['Food Name'].unique()
# Out:
# array(['Salmon, farmed, flesh only, grilled, weighed with bones and skin',
#        'Salmon, farmed, flesh only, steamed, fillets weighed with bones and skin',
#        'Salmon, pink, canned in brine, drained',
#        'Salmon, red, canned in brine, drained',
#        'Salmon, red, canned in brine, skinless and boneless, drained',
#        'Salmon, smoked (cold-smoked)', 'Salmon, smoked (hot-smoked)',
#        'Salmon, wild, baked', 'Salmon, wild, grilled',
#        'Salmon, wild, steamed', 'Sardines, canned in brine, drained',
#        'Sardines, canned in olive oil, drained',
#        'Sardines, canned in sunflower oil, drained',
#        'Sardines, canned in tomato sauce, whole contents',
#        'Sardines, flesh only, grilled',
#        'Sardines, flesh only, grilled, weighed with skin and bones',
#        'Sardines, flesh only, raw', 'Sprats, fried',
#        'Sprats, fried, weighed with bones', 'Sprats, raw',
#        'Swordfish, flesh only, grilled',
# ...

# %% [markdown]
# **Removed**

# %%
priority_jc = ['Sardines, canned in brine, drained','Swordfish, flesh only, grilled']

# %%
filt_jc = jc[jc['Food Name'].isin(priority_jc)]
filt_jc
# Out:
#      Food Code                           Food Name  \
# 2445    16-424  Sardines, canned in brine, drained
# 2662    16-222      Swordfish, flesh only, grilled
#
#                       Description Group Previous  \
# 2445        6 samples, 5 products    JC  16-328
# 2662  Calculated from raw, steaks    JC      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2445  DH, Nutrient analysis of fish and fish product...      NaN         713
# 2662            Fish and Fish Products Supplement, 1993      NaN         582
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2445           170      9.1          2.61                0          0
# 2662           139      5.2           1.2                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2445          0         0         22.1     0.92
# 2662          0         0         22.9     0.43

# %%
filt_jc['Super Group'] = 'Fish and fish products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\601193131.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_jc['Super Group'] = 'Fish and fish products'

# %% [markdown]
# Crustacea

# %%
jk = prod_s.loc[prod_s['Group']== 'JK']
jk
# Out:
#      Food Code                                          Food Name  \
# 2497    16-443  Scampi, coated in breadcrumbs, fried in sunflo...
# 2498    16-442  Scampi, in breadcrumbs, frozen, fried in rapes...
# 2536    16-245                                    Shrimps, boiled
# 2537    16-246               Shrimps, boiled, weighed with shells
# 2538    16-247                  Shrimps, canned in brine, drained
# 2539    16-249                                     Shrimps, dried
# 2540    16-248                                    Shrimps, frozen
#
#                                             Description Group Previous  \
# 2497  Calculated from baked 16-409 using analysed wa...    JK  16-244
# 2498  Calculated from baked 16-409 using analysed wa...    JK  16-243
# 2536    Purchased cooked, probably in sea or salt water    JK      NaN
# 2537                      Calculated from boiled 16-245    JK      NaN
# 2538                                  10 cans, 3 brands    JK  50-643
# ...

# %% [markdown]
# **Reduced**

# %%
filt_jk = jk[jk['Food Name'] == 'Shrimps, frozen']
filt_jk
# Out:
#      Food Code        Food Name  \
# 2540    16-248  Shrimps, frozen
#
#                                             Description Group Previous  \
# 2540  10 packets from Chinese supermarkets. Shrimps ...    JK  50-642
#
#                          Main data references Footnote Energy (kJ)  \
# 2540  Fish and Fish Products Supplement, 1993      NaN         310
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2540            73      0.8           0.1                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2540          0         0         16.5     0.95

# %%
filt_jk['Super Group'] = 'Fish and fish products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\2930333924.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_jk['Super Group'] = 'Fish and fish products'

# %% [markdown]
# Molluscs

# %%
jm = prod_s.loc[prod_s['Group']== 'JM']
jm
# Out:
#      Food Code          Food Name  \
# 2495    16-262  Scallops, steamed
# 2603    16-267       Squid, dried
# 2604    16-263         Squid, raw
#
#                                       Description Group Previous  \
# 2495            Analytical and literature sources    JM      NaN
# 2603  Literature sources and calculation from raw    JM      NaN
# 2604            Analytical and literature sources    JM      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2495            Fish and Fish Products Supplement, 1993      NaN         446
# 2603  Wu Leung et al (1972) Food composition table f...      NaN        1247
# 2604            Fish and Fish Products Supplement, 1993      NaN         324
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2495           105      1.4           0.4                0          0
# 2603           295      4.6             1                0          0
# ...

# %% [markdown]
# **Reduced**

# %%
filt_jm = jm[jm['Food Name'] == 'Squid, raw']
filt_jm
# Out:
#      Food Code   Food Name                        Description Group Previous  \
# 2604    16-263  Squid, raw  Analytical and literature sources    JM      NaN
#
#                          Main data references Footnote Energy (kJ)  \
# 2604  Fish and Fish Products Supplement, 1993      NaN         324
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2604            77      1.7           0.4                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2604          0         0         15.4     0.28

# %%
filt_jm['Super Group'] = 'Fish and fish products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\867841930.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_jm['Super Group'] = 'Fish and fish products'

# %% [markdown]
# Removed JR - Fish products and dishes

# %% [markdown]
#                                                Meat and meat products

# %% [markdown]
# Removed MG - Offal

# %%
mi = prod_s.loc[prod_s['Group']== 'MI']
mi
# Out:
#      Food Code                                          Food Name  \
# 2411    19-517                                             Salami
# 2412    19-508                                       Salami snack
# 2436    19-597  Samosas, lamb, deep fried in rapeseed oil, hom...
# 2477    19-468   Sausage roll, flaky pastry, ready-to-eat, retail
# 2478    19-643              Sausage rolls, short pastry, homemade
# 2479    19-653             Sausages, beef, fried in vegetable oil
# 2480    19-489                            Sausages, beef, grilled
# 2481    19-656                                Sausages, beef, raw
# 2482    19-512    Sausages, pork, chilled, fried in vegetable oil
# 2483    19-509                   Sausages, pork, chilled, grilled
# 2484    19-654     Sausages, pork, frozen, fried in vegetable oil
# 2485    19-655                    Sausages, pork, frozen, grilled
# 2486    19-510                                Sausages, pork, raw
# ...

# %%
mi['Food Name'].unique()
# Out:
# array(['Salami', 'Salami snack',
#        'Samosas, lamb, deep fried in rapeseed oil, homemade',
#        'Sausage roll, flaky pastry, ready-to-eat, retail',
#        'Sausage rolls, short pastry, homemade',
#        'Sausages, beef, fried in vegetable oil',
#        'Sausages, beef, grilled', 'Sausages, beef, raw',
#        'Sausages, pork, chilled, fried in vegetable oil',
#        'Sausages, pork, chilled, grilled',
#        'Sausages, pork, frozen, fried in vegetable oil',
#        'Sausages, pork, frozen, grilled', 'Sausages, pork, raw',
#        'Sausages, pork, reduced fat, fried in vegetable oil',
#        'Sausages, pork, reduced fat, grilled',
#        'Sausages, pork, reduced fat, raw',
#        'Sausages, premium, fried in vegetable oil',
#        'Sausages, premium, grilled', 'Sausages, premium, raw',
#        'Saveloy, unbattered, takeaway', 'Scotch eggs, retail',
#        'Steak and kidney pudding, homemade'], dtype=object)

# %%
priority_mi = ['Salami','Samosas, lamb, deep fried in rapeseed oil, homemade','Sausage roll, flaky pastry, ready-to-eat, retail','Sausages, pork, reduced fat, raw',]

# %% [markdown]
# **Reduced**

# %%
filt_mi = mi[mi['Food Name'].isin(priority_mi)]
filt_mi
# Out:
#      Food Code                                          Food Name  \
# 2411    19-517                                             Salami
# 2436    19-597  Samosas, lamb, deep fried in rapeseed oil, hom...
# 2477    19-468   Sausage roll, flaky pastry, ready-to-eat, retail
# 2489    19-658                   Sausages, pork, reduced fat, raw
#
#                                             Description Group Previous  \
# 2411  22 samples including Danish, French, German an...    MI  19-110
# 2436                                             Recipe    MI  19-362
# 2477            10 samples, 10 products, mini and large    MI      NaN
# 2489  7 samples, 5 brands of thin and thick sausages...    MI  19-084
#
#                                    Main data references Footnote Energy (kJ)  \
# 2411  LGC, Analytical survey of meat products, 1990-...      NaN        1817
# 2436                                       Updated 2014      NaN        1569
# ...

# %%
filt_mi['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\886000444.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_mi['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Removed MR - Meat dishes

# %%
mr = prod_s.loc[prod_s['Group']== 'MR']
mr
# Out:
#      Food Code                                          Food Name  \
# 2413    19-625                       Salmis of pheasant, homemade
# 2435    19-596                     Samosas, lamb, baked, homemade
# 2461    19-577                             Sauce, duck a l'orange
# 2527    19-626                           Shepherd's pie, homemade
# 2531    19-525              Shish kebab in pitta bread with salad
# 2532    19-150                             Shish kebab, meat only
# 2533    19-627    Shish kebabs, with onions and peppers, homemade
# 2578    19-628                      Spaghetti bolognese, homemade
# 2579    19-542  Spaghetti bolognese, retail, meat and sauce on...
# 2580    19-524  Spaghetti bolognese, retail, reheated, with sp...
# 2595    19-327                       Spring rolls, meat, takeaway
# 2607    19-473                               Stew, beef, homemade
# 2608    19-550          Stew, beef, made with lean beef, homemade
# ...

# %% [markdown]
# Removed OF - Fats and Oils

# %% [markdown]
#                                                         Beverages

# %%
pe = prod_s.loc[prod_s['Group']== 'PE']
pe
# Out:
#      Food Code  Food Name                                        Description  \
# 2545    17-747  Smoothies  Retail, chilled, yellow and red fruit smoothie...
#
#      Group Previous Main data references Footnote Energy (kJ) Energy (kcal)  \
# 2545    PE      NaN  Industry data, 2013      NaN         222            52
#
#       Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 2545      0.1             0             11.8       11.3        0.5         1
#
#       Protein (g) Salt (g)
# 2545          0.5        0

# %%
pe['Super Group'] = 'Beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\2340237900.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pe['Super Group'] = 'Beverages'

# %% [markdown]
#                                                 Alcoholic beverages

# %%
qa = prod_s.loc[prod_s['Group']== 'QA']
qa
# Out:
#      Food Code                    Food Name  \
# 2523    17-760  Shandy, 50% lager, homemade
# 2524    17-821    Shandy, bottled or canned
# 2619    17-767              Stout, Guinness
#
#                                             Description Group Previous  \
# 2523  Calculated from standard lager and standard le...    QA  17-218
# 2524  <1% ABV, typically 10-12% beer or lager. 10 ca...    QA  17-217
# 2619  Approx. 4% ABV. 10 samples including canned, b...    QA  17-219
#
#                                    Main data references Footnote Energy (kJ)  \
# 2523                                       Updated 2014      NaN          99
# 2524  Reviewed 2013. LGC, Alcoholic beverages, soft ...      NaN         104
# 2619  Miscellaneous Foods Supplement, 1994; and indu...      NaN         154
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2523            24      0.0             0              2.9        2.9
# ...

# %% [markdown]
# **Reduced**

# %%
removed_qa = ['Shandy, 50% lager, homemade']

# %%
filt_qa = qa[~qa['Food Name'].isin(removed_qa)]
filt_qa
# Out:
#      Food Code                  Food Name  \
# 2524    17-821  Shandy, bottled or canned
# 2619    17-767            Stout, Guinness
#
#                                             Description Group Previous  \
# 2524  <1% ABV, typically 10-12% beer or lager. 10 ca...    QA  17-217
# 2619  Approx. 4% ABV. 10 samples including canned, b...    QA  17-219
#
#                                    Main data references Footnote Energy (kJ)  \
# 2524  Reviewed 2013. LGC, Alcoholic beverages, soft ...      NaN         104
# 2619  Miscellaneous Foods Supplement, 1994; and indu...      NaN         154
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2524            25      0.0             0              4.9        4.9
# 2619            37      0.0             0                3          3
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2524          0         0          0.0     0.02
# 2619          0         0          0.4     0.02

# %%
filt_qa['Super Group'] = 'Alcoholic beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\1484818436.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_qa['Super Group'] = 'Alcoholic beverages'

# %% [markdown]
# Fortified wines

# %%
qf = prod_s.loc[prod_s['Group']== 'QF']
qf
# Out:
#      Food Code       Food Name  \
# 2530    17-236  Sherry, medium
#
#                                             Description Group  Previous  \
# 2530  15-19.5% ABV. 8 samples; including Spanish, Br...    QF  50-1115
#
#                                    Main data references Footnote Energy (kJ)  \
# 2530  Reviewed 2013. LGC, Alcoholic beverages, soft ...      NaN         488
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2530           117      0.0             0              5.9        5.9
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2530          0         0          0.1     0.07

# %%
qf['Super Group'] = 'Alcoholic beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\2876871772.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qf['Super Group'] = 'Alcoholic beverages'

# %% [markdown]
# Spirits

# %%
qk = prod_s.loc[prod_s['Group']== 'QK']
qk
# Out:
#      Food Code            Food Name  \
# 2587    17-247  Spirits, 40% volume
#
#                                      Description Group  Previous  \
# 2587  Mean of brandy, gin, rum, whisky and vodka    QK  50-1122
#
#                                    Main data references Footnote Energy (kJ)  \
# 2587  Reviewed 2013. MW5, 1991. Vitamin K1 from Bolt...      NaN         919
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2587           222      0.0             0                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2587          0         0          0.0        0

# %%
qk['Super Group'] = 'Alcoholic beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\1101545459.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qk['Super Group'] = 'Alcoholic beverages'

# %% [markdown]
#                                             Sugars, preserves and snacks

# %% [markdown]
# Sugars, syrups and preserves

# %%
sc = prod_s.loc[prod_s['Group']== 'SC']
sc
# Out:
#      Food Code          Food Name                       Description Group  \
# 2628    17-060       Sugar, brown                         3 samples    SC
# 2629    17-061    Sugar, Demerara                         5 samples    SC
# 2630    17-062       Sugar, icing  Analysis and maunfacturers' data    SC
# 2631    17-063       Sugar, white         Granulated and loaf sugar    SC
# 2665    17-064  Syrup, corn, dark                Literature sources    SC
# 2666    17-065      Syrup, golden       3 samples of the same brand    SC
#
#       Previous                               Main data references Footnote  \
# 2628       NaN  Reviewed 2013. LGC, Analysis of assorted foods...      NaN
# 2629  50-1010   Reviewed 2013. LGC, Analysis of assorted foods...      NaN
# 2630       NaN               Miscellaneous Foods Supplement, 1994      NaN
# 2631  50-1011   Reviewed 2013. LGC, Analysis of assorted foods...      NaN
# ...

# %%
sc['Food Name'].unique()
# Out:
# array(['Sugar, brown', 'Sugar, Demerara', 'Sugar, icing', 'Sugar, white',
#        'Syrup, corn, dark', 'Syrup, golden'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
priority_sc = ['Sugar, brown','Sugar, icing', 'Sugar, white','Syrup, golden']

# %%
filt_sc = sc[sc['Food Name'].isin(priority_sc)]
filt_sc
# Out:
#      Food Code      Food Name                       Description Group  \
# 2628    17-060   Sugar, brown                         3 samples    SC
# 2630    17-062   Sugar, icing  Analysis and maunfacturers' data    SC
# 2631    17-063   Sugar, white         Granulated and loaf sugar    SC
# 2666    17-065  Syrup, golden       3 samples of the same brand    SC
#
#       Previous                               Main data references Footnote  \
# 2628       NaN  Reviewed 2013. LGC, Analysis of assorted foods...      NaN
# 2630       NaN               Miscellaneous Foods Supplement, 1994      NaN
# 2631  50-1011   Reviewed 2013. LGC, Analysis of assorted foods...      NaN
# 2666  50-1012   Reviewed 2013. LGC, Analysis of assorted foods...      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 2628        1642           386      0.0             0             96.5
# 2630        1698           399      0.0             0             99.9
# ...

# %%
filt_sc['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\743039957.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_sc['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
# Chocolate confectionery

# %%
sea = prod_s.loc[prod_s['Group']== 'SEA']
sea
# Out:
#      Food Code            Food Name  \
# 2544    17-096  Smartie-type sweets
#
#                                     Description Group  Previous  \
# 2544  10 samples including Smarties and M & M's   SEA  50-1023
#
#                                    Main data references Footnote Energy (kJ)  \
# 2544  Reviewed 2013. LGC, Analytical survey of confe...      NaN           N
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2544             N     17.5          10.4             70.3       67.4
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2544        2.8         N          5.4     0.15

# %%
sea['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\2560556164.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sea['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
# remvoed SEC

# %% [markdown]
# removed SNC

# %% [markdown]
#                                         Soups, sauces and miscellaneous foods

# %% [markdown]
# Soups

# %%
wa = prod_s.loc[prod_s['Group']== 'WA']
wa
# Out:
#      Food Code                                    Food Name  \
# 2550    17-637  Soup, broccoli and stilton, carton, chilled
# 2551    17-634  Soup, carrot and coriander, carton, chilled
# 2566    17-711                     Soup, minestrone, canned
# 2569    17-635              Soup, mushroom, carton, chilled
# 2574    17-636                Soup, tomato, carton, chilled
#
#                                             Description Group Previous  \
# 2550  10 samples, 7 products, including New Convent ...    WA      NaN
# 2551  8 samples, 5 products, including New Convent G...    WA      NaN
# 2566                                         Label data    WA  17-542
# 2569  10 samples, 4 products, including New Convent ...    WA      NaN
# 2574  10 samples, 7 products, including New Convent ...    WA      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2550  Direct Laboratories, Nutrient analysis catch u...      NaN           N
# ...

# %% [markdown]
# **Reduced**

# %%
filt_wa = wa[wa['Food Name'] == 'Soup, minestrone, canned']
filt_wa
# Out:
#      Food Code                 Food Name Description Group Previous  \
# 2566    17-711  Soup, minestrone, canned  Label data    WA  17-542
#
#      Main data references Footnote Energy (kJ) Energy (kcal)  Fat (g)  \
# 2566  Industry data, 2013      NaN         139            33      0.2
#
#      Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 2566           0.1              6.2        1.8        4.4       0.9
#
#       Protein (g) Salt (g)
# 2566          1.1      0.5

# %%
filt_wa['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\911613723.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_wa['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
# Removed WAA - Homemade soups

# %% [markdown]
# Canned soups

# %%
wac = prod_s.loc[prod_s['Group']== 'WAC']
wac
# Out:
#      Food Code                                   Food Name  \
# 2555    17-695             Soup, chicken, cream of, canned
# 2556    17-696  Soup, chicken, cream of, canned, condensed
# 2557    17-652               Soup, cream of tomato, canned
# 2563    17-698                        Soup, lentil, canned
# 2565    17-699                   Soup, low calorie, canned
# 2570    17-713            Soup, mushroom, cream of, canned
# 2571    17-700                        Soup, oxtail, canned
# 2575    17-712                     Soup, vegetable, canned
#
#                                             Description Group Previous  \
# 2555                                  10 cans, 3 brands   WAC  17-250
# 2556                           7 cans of the same brand   WAC  17-251
# 2557                               10 samples, 5 brands   WAC  17-278
# 2563                                  10 cans, 4 brands   WAC  17-263
# 2565  7 cans, 3 brands; tomato, vegetable and minest...   WAC  17-265
# ...

# %%
wac['Food Name'].unique()
# Out:
# array(['Soup, chicken, cream of, canned',
#        'Soup, chicken, cream of, canned, condensed',
#        'Soup, cream of tomato, canned', 'Soup, lentil, canned',
#        'Soup, low calorie, canned', 'Soup, mushroom, cream of, canned',
#        'Soup, oxtail, canned', 'Soup, vegetable, canned'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
priority_wac = ['Soup, chicken, cream of, canned','Soup, cream of tomato, canned', 'Soup, lentil, canned','Soup, oxtail, canned', 'Soup, vegetable, canned']

# %%
filt_wac = wac[wac['Food Name'].isin(priority_wac)]
filt_wac
# Out:
#      Food Code                        Food Name           Description Group  \
# 2555    17-695  Soup, chicken, cream of, canned     10 cans, 3 brands   WAC
# 2557    17-652    Soup, cream of tomato, canned  10 samples, 5 brands   WAC
# 2563    17-698             Soup, lentil, canned     10 cans, 4 brands   WAC
# 2571    17-700             Soup, oxtail, canned     10 cans, 3 brands   WAC
# 2575    17-712          Soup, vegetable, canned     10 cans, 3 brands   WAC
#
#      Previous                               Main data references Footnote  \
# 2555  17-250                  MW5, 1991; and industry data, 2013      NaN
# 2557  17-278   DH, Nutrient analysis of a range of processed ...      NaN
# 2563  17-263   LFRA, Nutrient analysis of miscellaneous foods...      NaN
# 2571  17-272                  MW4, 1978; and industry data, 2013      NaN
# 2575  17-284   LFRA, Nutrient analysis of miscellaneous foods...      NaN
#
# ...

# %%
filt_wac['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\4189102066.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_wac['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
# Packet soups

# %%
wae = prod_s.loc[prod_s['Group']== 'WAE']
wae
# Out:
#      Food Code                               Food Name  \
# 2553    17-850             Soup, chicken noodle, dried
# 2554    17-714  Soup, chicken noodle, dried, as served
# 2561    17-653      Soup, instant, dried, as purchased
# 2562    17-660         Soup, instant, dried, as served
#
#                                             Description Group Previous  \
# 2553                               10 packets, 4 brands   WAE  17-253
# 2554     Calculated from 35g soup powder to 570ml water   WAE  17-254
# 2561  11 samples, 3 brands, powder only, not includi...   WAE  17-507
# 2562  Calculated from instant soup powder, 24g powde...   WAE  17-508
#
#                                    Main data references Footnote Energy (kJ)  \
# 2553  LFRA, Nutrient analysis of miscellaneous foods...      NaN        1283
# 2554  LFRA, Nutrient analysis of miscellanous foods,...      NaN          75
# 2561  DH, Nutrient analysis of a range of processed ...      NaN        1652
# ...

# %% [markdown]
# **Reduced**

# %%
filt_wae = wae[wae['Food Name'] == 'Soup, instant, dried, as purchased']

# %%
filt_wae['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\3558699281.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_wae['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
# Sauces

# %%
wc = prod_s.loc[prod_s['Group']== 'WC']
wc
# Out:
#      Food Code                                          Food Name  \
# 2453    17-628               Sauce, Chinese cook in, sweet & sour
# 2454    17-629                            Sauce, Chinese stir fry
# 2459    17-329                          Sauce, dry, casserole mix
# 2460    17-330                 Sauce, dry, casserole mix, made up
# 2462    17-626          Sauce, Indian cook in, korma/tikka masala
# 2463    17-625                       Sauce, pasta, carbonara type
# 2464    17-624                          Sauce, pasta, four cheese
# 2465    17-618          Sauce, pasta, tomato based, for bolognese
# 2466    17-619             Sauce, pasta, tomato based, napoletana
# 2467    17-620            Sauce, pasta, tomato based, reduced fat
# 2468    17-621  Sauce, pasta, tomato based, with added vegetables
# 2469    17-827  Sauce, pasta, white, with ham and mushrooms, h...
# 2472    17-834                      Sauce, tomato based, homemade
# ...

# %%
wc['Food Name'].unique()
# Out:
# array(['Sauce, Chinese cook in, sweet & sour', 'Sauce, Chinese stir fry',
#        'Sauce, dry, casserole mix', 'Sauce, dry, casserole mix, made up',
#        'Sauce, Indian cook in, korma/tikka masala',
#        'Sauce, pasta, carbonara type', 'Sauce, pasta, four cheese',
#        'Sauce, pasta, tomato based, for bolognese',
#        'Sauce, pasta, tomato based, napoletana',
#        'Sauce, pasta, tomato based, reduced fat',
#        'Sauce, pasta, tomato based, with added vegetables',
#        'Sauce, pasta, white, with ham and mushrooms, homemade',
#        'Sauce, tomato based, homemade',
#        'Sauce, traditional cook in, tomato based',
#        'Sauce, traditional cook in, white sauce based',
#        'Sauces, Indian cook in, other'], dtype=object)

# %%
priority_wc = ['Sauce, Chinese cook in, sweet & sour', 'Sauce, Chinese stir fry']

# %% [markdown]
# **Reduced**

# %%
filt_wc = wc[wc['Food Name'].isin(priority_wc)]
filt_wc
# Out:
#      Food Code                             Food Name  \
# 2453    17-628  Sauce, Chinese cook in, sweet & sour
# 2454    17-629               Sauce, Chinese stir fry
#
#                                             Description Group Previous  \
# 2453        10 samples, 7 products, chilled and ambient    WC      NaN
# 2454  10 samples, 10 products, including black bean ...    WC      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2453  Direct Laboratories, Nutrient analysis catch u...      NaN         414
# 2454  Direct Laboratories, Nutrient analysis catch u...      NaN         405
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2453            98      1.0             0             21.3       18.8
# 2454            96      1.3          0.12             19.2       16.2
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2453        2.5       0.8          0.5     0.63
# ...

# %%
filt_wc['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\1921019764.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_wc['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
# Salad sauces, dressings and pickles

# %%
wcg = prod_s.loc[prod_s['Group']== 'WCG']
wcg
# Out:
#      Food Code                 Food Name                  Description Group  \
# 2397    17-703               Salad cream  3 samples, different brands   WCG
# 2398    17-704  Salad cream, reduced fat    Label and data calculated   WCG
#
#      Previous                               Main data references Footnote  \
# 2397  17-512   LGC, Dairy products and eggs, 1989; and indust...      NaN
# 2398  17-327   Industry data, 2013;  fatty acids calculated f...      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 2397        1359           328     26.7             2             20.2
# 2398         663           159     10.6          1.57             14.7
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2397       16.1        4.1       0.5          1.4     1.75
# 2398          9        5.7       0.5          1.0     1.33

# %% [markdown]
# **Reduced**

# %%
filt_wcg = wcg[wcg['Food Name'] == 'Salad cream']
filt_wcg
# Out:
#      Food Code    Food Name                  Description Group Previous  \
# 2397    17-703  Salad cream  3 samples, different brands   WCG  17-512
#
#                                    Main data references Footnote Energy (kJ)  \
# 2397  LGC, Dairy products and eggs, 1989; and indust...      NaN        1359
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2397           328     26.7             2             20.2       16.1
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2397        4.1       0.5          1.4     1.75

# %%
filt_wcg['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\3979936519.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_wcg['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
# Removed WC- Sauces

# %% [markdown]
# Non-salad sauces

# %%
wcn = prod_s.loc[prod_s['Group']== 'WCN']
wcn
# Out:
#      Food Code                            Food Name  \
# 2470    17-336     Sauce, sweet and sour, take-away
# 2577    17-721  Soy sauce, light and dark varieties
#
#                                             Description Group Previous  \
# 2470  7 samples purchased from Chinese restaurants, ...   WCN      NaN
# 2577                                8 samples, 4 brands   WCN  17-334
#
#                                    Main data references Footnote Energy (kJ)  \
# 2470  LFRA, Nutrient analysis of miscellaneous foods...      NaN           N
# 2577  LFRA, Nutrient analysis of miscellaneous foods...      NaN         345
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2470             N      3.4             N             31.9       27.1
# 2577            81      0.0             0             17.3       15.9
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2470        4.8         N          0.2     0.38
# ...

# %%
wcn['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\2652417809.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wcn['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
# Miscellaneous foods

# %%
wy = prod_s.loc[prod_s['Group']== 'WY']
wy
# Out:
#      Food Code                                 Food Name  \
# 2432    17-367                                      Salt
# 2613    17-515                         Stock cubes, beef
# 2614    17-726                      Stock cubes, chicken
# 2615    17-774  Stock cubes, chicken, made up with water
# 2616    17-727                    Stock cubes, vegetable
# 2617    17-680                                 Stock gel
# 2618    17-681        Stock, chicken, ready made, retail
#
#                                             Description Group  \
# 2432                              2 samples, table salt    WY
# 2613  10 samples, 6 brands including Bovril, Oxo and...    WY
# 2614                  7 samples, 4 brands including Oxo    WY
# 2615       Calcualted from 7g stock cube to 190ml water    WY
# 2616                  8 samples, 4 brands including Oxo    WY
# 2617  Including stock pots, stock melts and squeezy ...    WY
# 2618                                         Label data    WY
#
# ...

# %%
wy['Food Name'].unique()
# Out:
# array(['Salt', 'Stock cubes, beef', 'Stock cubes, chicken',
#        'Stock cubes, chicken, made up with water',
#        'Stock cubes, vegetable', 'Stock gel',
#        'Stock, chicken, ready made, retail'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
priority_wy = ['Salt', 'Stock cubes, beef','Stock gel','Stock, chicken, ready made, retail']

# %%
filt_wy = wy[wy['Food Name'].isin(priority_wy )]
filt_wy
# Out:
#      Food Code                           Food Name  \
# 2432    17-367                                Salt
# 2613    17-515                   Stock cubes, beef
# 2617    17-680                           Stock gel
# 2618    17-681  Stock, chicken, ready made, retail
#
#                                             Description Group  \
# 2432                              2 samples, table salt    WY
# 2613  10 samples, 6 brands including Bovril, Oxo and...    WY
# 2617  Including stock pots, stock melts and squeezy ...    WY
# 2618                                         Label data    WY
#
#                     Previous  \
# 2432                50-1184
# 2613  17-368 17-476 50-1182
# 2617                     NaN
# 2618                     NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2432  Reviewed 2013. LGC, Analysis of assorted foods...      NaN           0
# 2613  Reviewed 2013. RHM Technology, Nutrient analys...      NaN        1162
# ...

# %%
filt_wy['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_51144\2693890349.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_wy['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
#                                               **Join Reduced Tables**

# %%
Red = pd.concat([filt_aa, filt_ab], axis=0, join='inner')
Red
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
#
#                                             Description Group Previous  \
# 2517                              6 samples, 5 products    AA  11-024
# 2438  Recipe from University of North London survey ...    AB  11-563
#
#                                    Main data references Footnote Energy (kJ)  \
# 2517          Nutrient survey of flours and grains 2005      NaN        1482
# 2438  University of North London 1997. Recalculated ...      NaN         973
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2517           349      1.6          0.23             70.7        0.5
# 2438           233     11.9          2.46             21.9        2.2
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# ...

# %%
Red2 = pd.concat([Red,am], axis=0, join='inner')
Red2
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
#
#                                             Description Group Previous  \
# 2517                              6 samples, 5 products    AA  11-024
# 2438  Recipe from University of North London survey ...    AB  11-563
# 2534                             10 samples, 7 products    AM  11-523
#
#                                    Main data references Footnote Energy (kJ)  \
# 2517          Nutrient survey of flours and grains 2005      NaN        1482
# 2438  University of North London 1997. Recalculated ...      NaN         973
# 2534  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        2162
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# ...

# %%
Red3 = pd.concat([Red2,filt_ap], axis=0, join='inner')
Red3
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
#
#                                             Description Group        Previous  \
# 2517                              6 samples, 5 products    AA         11-024
# 2438  Recipe from University of North London survey ...    AB         11-563
# 2534                             10 samples, 7 products    AM         11-523
# 2509                                6 samples, 4 brands    AP  11-270 50-148
#
#                                    Main data references Footnote Energy (kJ)  \
# 2517          Nutrient survey of flours and grains 2005      NaN        1482
# 2438  University of North London 1997. Recalculated ...      NaN         973
# ...

# %%
Red4 = pd.concat([Red3,filt_AS], axis=0, join='inner')
Red4
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
#
#                                             Description Group        Previous  \
# 2517                              6 samples, 5 products    AA         11-024
# 2438  Recipe from University of North London survey ...    AB         11-563
# 2534                             10 samples, 7 products    AM         11-523
# 2509                                6 samples, 4 brands    AP  11-270 50-148
# 2621                             12 samples, 7 products    AS             NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# ...

# %%
Red5 = pd.concat([Red4,filt_at], axis=0, join='inner')
Red5
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
# 2622    17-371                               Stuffing mix, dried
#
#                                             Description Group        Previous  \
# 2517                              6 samples, 5 products    AA         11-024
# 2438  Recipe from University of North London survey ...    AB         11-563
# 2534                             10 samples, 7 products    AM         11-523
# 2509                                6 samples, 4 brands    AP  11-270 50-148
# 2621                             12 samples, 7 products    AS             NaN
# ...

# %%
Red6 = pd.concat([Red5,filt_dg], axis=0, join='inner')
Red6
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
# 2622    17-371                               Stuffing mix, dried
# 2582    13-521                                Spinach, baby, raw
# 2639    13-359                            Swede, flesh only, raw
# 2644    13-672                               Sweet potato, baked
# 2651    13-529       Sweetcorn kernels, canned in water, drained
# 2658    13-622                           Sweetcorn, kernels, raw
#
#                                             Description Group        Previous  \
# 2517                              6 samples, 5 products    AA         11-024
# ...

# %%
Red7 = pd.concat([Red6,filt_dr], axis=0, join='inner')
Red7
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
# 2622    17-371                               Stuffing mix, dried
# 2582    13-521                                Spinach, baby, raw
# 2639    13-359                            Swede, flesh only, raw
# 2644    13-672                               Sweet potato, baked
# 2651    13-529       Sweetcorn kernels, canned in water, drained
# 2658    13-622                           Sweetcorn, kernels, raw
# 2402    15-872           Salad, pasta, vegetables and mayonnaise
# 2528    15-883                         Shepherd's pie, vegetable
# ...

# %%
Red8 = pd.concat([Red7,filt_fa], axis=0, join='inner')
Red8
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
# 2622    17-371                               Stuffing mix, dried
# 2582    13-521                                Spinach, baby, raw
# 2639    13-359                            Swede, flesh only, raw
# 2644    13-672                               Sweet potato, baked
# 2651    13-529       Sweetcorn kernels, canned in water, drained
# 2658    13-622                           Sweetcorn, kernels, raw
# 2402    15-872           Salad, pasta, vegetables and mayonnaise
# 2528    15-883                         Shepherd's pie, vegetable
# ...

# %%
Red9 = pd.concat([Red8,filt_ga], axis=0, join='inner')
Red9
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
# 2622    17-371                               Stuffing mix, dried
# 2582    13-521                                Spinach, baby, raw
# 2639    13-359                            Swede, flesh only, raw
# 2644    13-672                               Sweet potato, baked
# 2651    13-529       Sweetcorn kernels, canned in water, drained
# 2658    13-622                           Sweetcorn, kernels, raw
# 2402    15-872           Salad, pasta, vegetables and mayonnaise
# 2528    15-883                         Shepherd's pie, vegetable
# ...

# %%
Red10 = pd.concat([Red9,filt_h], axis=0, join='inner')
Red10
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
# 2622    17-371                               Stuffing mix, dried
# 2582    13-521                                Spinach, baby, raw
# 2639    13-359                            Swede, flesh only, raw
# 2644    13-672                               Sweet potato, baked
# 2651    13-529       Sweetcorn kernels, canned in water, drained
# 2658    13-622                           Sweetcorn, kernels, raw
# 2402    15-872           Salad, pasta, vegetables and mayonnaise
# 2528    15-883                         Shepherd's pie, vegetable
# ...

# %%
Red11 = pd.concat([Red10,filt_j], axis=0, join='inner')
Red11
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
# 2622    17-371                               Stuffing mix, dried
# 2582    13-521                                Spinach, baby, raw
# 2639    13-359                            Swede, flesh only, raw
# 2644    13-672                               Sweet potato, baked
# 2651    13-529       Sweetcorn kernels, canned in water, drained
# 2658    13-622                           Sweetcorn, kernels, raw
# 2402    15-872           Salad, pasta, vegetables and mayonnaise
# 2528    15-883                         Shepherd's pie, vegetable
# ...

# %%
Red12 = pd.concat([Red11,filt_jc], axis=0, join='inner')
Red12
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
# 2622    17-371                               Stuffing mix, dried
# 2582    13-521                                Spinach, baby, raw
# 2639    13-359                            Swede, flesh only, raw
# 2644    13-672                               Sweet potato, baked
# 2651    13-529       Sweetcorn kernels, canned in water, drained
# 2658    13-622                           Sweetcorn, kernels, raw
# 2402    15-872           Salad, pasta, vegetables and mayonnaise
# 2528    15-883                         Shepherd's pie, vegetable
# ...

# %%
Red13 = pd.concat([Red12,filt_jk], axis=0, join='inner')
Red13
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
# 2622    17-371                               Stuffing mix, dried
# 2582    13-521                                Spinach, baby, raw
# 2639    13-359                            Swede, flesh only, raw
# 2644    13-672                               Sweet potato, baked
# 2651    13-529       Sweetcorn kernels, canned in water, drained
# 2658    13-622                           Sweetcorn, kernels, raw
# 2402    15-872           Salad, pasta, vegetables and mayonnaise
# 2528    15-883                         Shepherd's pie, vegetable
# ...

# %%
Red14 = pd.concat([Red13,filt_jm], axis=0, join='inner')
Red14
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
# 2622    17-371                               Stuffing mix, dried
# 2582    13-521                                Spinach, baby, raw
# 2639    13-359                            Swede, flesh only, raw
# 2644    13-672                               Sweet potato, baked
# 2651    13-529       Sweetcorn kernels, canned in water, drained
# 2658    13-622                           Sweetcorn, kernels, raw
# 2402    15-872           Salad, pasta, vegetables and mayonnaise
# 2528    15-883                         Shepherd's pie, vegetable
# ...

# %%
Red15 = pd.concat([Red14,filt_mi], axis=0, join='inner')
Red15
# Out:
#      Food Code                                          Food Name  \
# 2517    11-903                                      Semolina, raw
# 2438    11-955   Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                         Shortbread
# 2509    11-544                            Scotch pancakes, retail
# 2621    11-919              Strudel, fruit filled, retail, frozen
# 2622    17-371                                Stuffing mix, dried
# 2582    13-521                                 Spinach, baby, raw
# 2639    13-359                             Swede, flesh only, raw
# 2644    13-672                                Sweet potato, baked
# 2651    13-529        Sweetcorn kernels, canned in water, drained
# 2658    13-622                            Sweetcorn, kernels, raw
# 2402    15-872            Salad, pasta, vegetables and mayonnaise
# 2528    15-883                          Shepherd's pie, vegetable
# ...

# %%
Red16 = pd.concat([Red15,pe], axis=0, join='inner')
Red16
# Out:
#      Food Code                                          Food Name  \
# 2517    11-903                                      Semolina, raw
# 2438    11-955   Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                         Shortbread
# 2509    11-544                            Scotch pancakes, retail
# 2621    11-919              Strudel, fruit filled, retail, frozen
# 2622    17-371                                Stuffing mix, dried
# 2582    13-521                                 Spinach, baby, raw
# 2639    13-359                             Swede, flesh only, raw
# 2644    13-672                                Sweet potato, baked
# 2651    13-529        Sweetcorn kernels, canned in water, drained
# 2658    13-622                            Sweetcorn, kernels, raw
# 2402    15-872            Salad, pasta, vegetables and mayonnaise
# 2528    15-883                          Shepherd's pie, vegetable
# ...

# %%
Red17 = pd.concat([Red16,filt_qa], axis=0, join='inner')
Red17
# Out:
#      Food Code                                          Food Name  \
# 2517    11-903                                      Semolina, raw
# 2438    11-955   Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                         Shortbread
# 2509    11-544                            Scotch pancakes, retail
# 2621    11-919              Strudel, fruit filled, retail, frozen
# 2622    17-371                                Stuffing mix, dried
# 2582    13-521                                 Spinach, baby, raw
# 2639    13-359                             Swede, flesh only, raw
# 2644    13-672                                Sweet potato, baked
# 2651    13-529        Sweetcorn kernels, canned in water, drained
# 2658    13-622                            Sweetcorn, kernels, raw
# 2402    15-872            Salad, pasta, vegetables and mayonnaise
# 2528    15-883                          Shepherd's pie, vegetable
# ...

# %%
Red18 = pd.concat([Red10,qf], axis=0, join='inner')
Red18
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
# 2622    17-371                               Stuffing mix, dried
# 2582    13-521                                Spinach, baby, raw
# 2639    13-359                            Swede, flesh only, raw
# 2644    13-672                               Sweet potato, baked
# 2651    13-529       Sweetcorn kernels, canned in water, drained
# 2658    13-622                           Sweetcorn, kernels, raw
# 2402    15-872           Salad, pasta, vegetables and mayonnaise
# 2528    15-883                         Shepherd's pie, vegetable
# ...

# %%
Red19 = pd.concat([Red18,qk], axis=0, join='inner')
Red19
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
# 2622    17-371                               Stuffing mix, dried
# 2582    13-521                                Spinach, baby, raw
# 2639    13-359                            Swede, flesh only, raw
# 2644    13-672                               Sweet potato, baked
# 2651    13-529       Sweetcorn kernels, canned in water, drained
# 2658    13-622                           Sweetcorn, kernels, raw
# 2402    15-872           Salad, pasta, vegetables and mayonnaise
# 2528    15-883                         Shepherd's pie, vegetable
# ...

# %%
Red20 = pd.concat([Red19,filt_sc], axis=0, join='inner')
Red20
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
# 2622    17-371                               Stuffing mix, dried
# 2582    13-521                                Spinach, baby, raw
# 2639    13-359                            Swede, flesh only, raw
# 2644    13-672                               Sweet potato, baked
# 2651    13-529       Sweetcorn kernels, canned in water, drained
# 2658    13-622                           Sweetcorn, kernels, raw
# 2402    15-872           Salad, pasta, vegetables and mayonnaise
# 2528    15-883                         Shepherd's pie, vegetable
# ...

# %%
Red21 = pd.concat([Red20,sea], axis=0, join='inner')
Red21
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
# 2622    17-371                               Stuffing mix, dried
# 2582    13-521                                Spinach, baby, raw
# 2639    13-359                            Swede, flesh only, raw
# 2644    13-672                               Sweet potato, baked
# 2651    13-529       Sweetcorn kernels, canned in water, drained
# 2658    13-622                           Sweetcorn, kernels, raw
# 2402    15-872           Salad, pasta, vegetables and mayonnaise
# 2528    15-883                         Shepherd's pie, vegetable
# ...

# %%
Red22 = pd.concat([Red21,filt_wa], axis=0, join='inner')
Red22
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
# 2622    17-371                               Stuffing mix, dried
# 2582    13-521                                Spinach, baby, raw
# 2639    13-359                            Swede, flesh only, raw
# 2644    13-672                               Sweet potato, baked
# 2651    13-529       Sweetcorn kernels, canned in water, drained
# 2658    13-622                           Sweetcorn, kernels, raw
# 2402    15-872           Salad, pasta, vegetables and mayonnaise
# 2528    15-883                         Shepherd's pie, vegetable
# ...

# %%
Red23 = pd.concat([Red22,filt_wac], axis=0, join='inner')
Red23
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
# 2622    17-371                               Stuffing mix, dried
# 2582    13-521                                Spinach, baby, raw
# 2639    13-359                            Swede, flesh only, raw
# 2644    13-672                               Sweet potato, baked
# 2651    13-529       Sweetcorn kernels, canned in water, drained
# 2658    13-622                           Sweetcorn, kernels, raw
# 2402    15-872           Salad, pasta, vegetables and mayonnaise
# 2528    15-883                         Shepherd's pie, vegetable
# ...

# %%
Red24 = pd.concat([Red23,filt_wae], axis=0, join='inner')
Red24
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
# 2622    17-371                               Stuffing mix, dried
# 2582    13-521                                Spinach, baby, raw
# 2639    13-359                            Swede, flesh only, raw
# 2644    13-672                               Sweet potato, baked
# 2651    13-529       Sweetcorn kernels, canned in water, drained
# 2658    13-622                           Sweetcorn, kernels, raw
# 2402    15-872           Salad, pasta, vegetables and mayonnaise
# 2528    15-883                         Shepherd's pie, vegetable
# ...

# %%
Red25 = pd.concat([Red24,filt_wc], axis=0, join='inner')
Red25
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
# 2622    17-371                               Stuffing mix, dried
# 2582    13-521                                Spinach, baby, raw
# 2639    13-359                            Swede, flesh only, raw
# 2644    13-672                               Sweet potato, baked
# 2651    13-529       Sweetcorn kernels, canned in water, drained
# 2658    13-622                           Sweetcorn, kernels, raw
# 2402    15-872           Salad, pasta, vegetables and mayonnaise
# 2528    15-883                         Shepherd's pie, vegetable
# ...

# %%
Red26 = pd.concat([Red25,filt_wcg], axis=0, join='inner')
Red26
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
# 2622    17-371                               Stuffing mix, dried
# 2582    13-521                                Spinach, baby, raw
# 2639    13-359                            Swede, flesh only, raw
# 2644    13-672                               Sweet potato, baked
# 2651    13-529       Sweetcorn kernels, canned in water, drained
# 2658    13-622                           Sweetcorn, kernels, raw
# 2402    15-872           Salad, pasta, vegetables and mayonnaise
# 2528    15-883                         Shepherd's pie, vegetable
# ...

# %%
Red27 = pd.concat([Red26,wcn], axis=0, join='inner')
Red27
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
# 2622    17-371                               Stuffing mix, dried
# 2582    13-521                                Spinach, baby, raw
# 2639    13-359                            Swede, flesh only, raw
# 2644    13-672                               Sweet potato, baked
# 2651    13-529       Sweetcorn kernels, canned in water, drained
# 2658    13-622                           Sweetcorn, kernels, raw
# 2402    15-872           Salad, pasta, vegetables and mayonnaise
# 2528    15-883                         Shepherd's pie, vegetable
# ...

# %%
Red28 = pd.concat([Red27,filt_wy], axis=0, join='inner')
Red28
# Out:
#      Food Code                                         Food Name  \
# 2517    11-903                                     Semolina, raw
# 2438    11-955  Sandwich, white bread, bacon, lettuce and tomato
# 2534    11-802                                        Shortbread
# 2509    11-544                           Scotch pancakes, retail
# 2621    11-919             Strudel, fruit filled, retail, frozen
# 2622    17-371                               Stuffing mix, dried
# 2582    13-521                                Spinach, baby, raw
# 2639    13-359                            Swede, flesh only, raw
# 2644    13-672                               Sweet potato, baked
# 2651    13-529       Sweetcorn kernels, canned in water, drained
# 2658    13-622                           Sweetcorn, kernels, raw
# 2402    15-872           Salad, pasta, vegetables and mayonnaise
# 2528    15-883                         Shepherd's pie, vegetable
# ...

# %% [markdown]
#                                                        Export

# %%
Red28.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced_S.csv')
