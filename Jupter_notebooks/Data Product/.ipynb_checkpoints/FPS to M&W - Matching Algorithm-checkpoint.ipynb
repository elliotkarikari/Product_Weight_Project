# %% [markdown]
# # Matching Algorithm - Matching Through One Column

# %% [markdown]
# ##### Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re #regular expressions

# %% [markdown]
# ##### Read In Data

# %% [markdown]
#                                                       M&W Reduced

# %%
#pd.set_option('display.max_rows', None)
redFood = pd.read_csv(r"C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Cleaned\Reduced_SecondClean.csv", index_col=0)
redFood.rename(columns={'Super Group':'SuperGroup'})
redFood['Food Name'] = redFood['Food Name'].str.lower()
redFood.head()
# Out:
#   Food Code                    Food Name Group          Super Group  \
# 0    17-208  beer, bitter, best, premium    QA  Alcoholic beverages
# 1    17-224                 cider, sweet    QC  Alcoholic beverages
# 2    17-234                         port    QF  Alcoholic beverages
# 3    17-236               sherry, medium    QF  Alcoholic beverages
# 4    17-247          spirits, 40% volume    QK  Alcoholic beverages
#
#                                  Sale format(s)
# 0  can, can multipack, bottle, bottle multipack
# 1  can, can multipack, bottle, bottle multipack
# 2                                        bottle
# 3                                        bottle
# 4                             bottle, miniature

# %% [markdown]
#                                                          FPS Data

# %%
CleanRetai = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\FoodPortionSized\FPS_VJ.csv')
CleanRetai['Food Name'] = CleanRetai['Food Name'].str.lower()
CleanRetai.tail()
# Out:
#                            Group   Brand               Food Name  \
# 2670  YOGHURTS AND FROMAGE FRAIS     NaN                   onken
# 2671  YOGHURTS AND FROMAGE FRAIS     NaN           petit danoneâ
# 2672  YOGHURTS AND FROMAGE FRAIS     NaN  st ivel fiendish faces
# 2673  YOGHURTS AND FROMAGE FRAIS     NaN      baby fromage frais
# 2674  YOGHURTS AND FROMAGE FRAIS  Heinz       baby fromage frais
#
#      Portion Consumed Weight PurEqualCon  Purchased Format Source
# 2670              NaN   200g         NaN        NaN    NaN    NaN
# 2671            small    50g         NaN        NaN    NaN    NaN
# 2672              NaN    50g         NaN        NaN    NaN    NaN
# 2673      Baby Danone    60g           Y        NaN    NaN    NaN
# 2674              Jar   163g           Y        NaN    NaN    NaN

# %%
CleanRetail = CleanRetai[CleanRetai['PurEqualCon'].isin(['Y', 'Y, P'])]
CleanRetail.head()
# Out:
#         Group  Brand                       Food Name Portion Consumed Weight  \
# 0  BABY FOODS  Boots   first harvest,dessert starter              NaN   125g
# 1  BABY FOODS  Boots  first harvest, infant desserts              NaN   125g
# 2  BABY FOODS  Boots  first harvest,infant savouries              NaN   125g
# 3  BABY FOODS  Boots   first harvest,junior desserts              NaN   190g
# 4  BABY FOODS  Boots  first harvest,junior savouries              NaN   190g
#
#   PurEqualCon  Purchased Format Source
# 0           Y        NaN    NaN    NaN
# 1           Y        NaN    NaN    NaN
# 2           Y        NaN    NaN    NaN
# 3           Y        NaN    NaN    NaN
# 4           Y        NaN    NaN    NaN

# %% [markdown]
# ###                                                        Match Data.
#
# ###### Once matched, Import Weight and Unit Columns into Reduced M&W table

# %% [markdown]
# # 1

# %% [markdown]
#                                                    Using Fuzzy Matching

# %%
# %%time
from fuzzywuzzy import fuzz

def match_food_group(CleanRetail, redFood):
    """
    Matches food groups between two DataFrames using fuzzy matching and updates 
    redFood database with Weight and Unit from CleanRetail dataframe.

    Args:
        CleanRetail (DataFrame): The DataFrame containing the clean retail data.
        redFood (DataFrame): The DataFrame containing the red food data.

    Returns:
        DataFrame: The red food DataFrame with updated weight, unit, and super group values.
    """
    # Set a threshold for fuzzy matching.
    threshold = 65

    # Create a set to store the SKU descriptions that have already been matched.
    matched_skus = set()

    # Add Weight and Unit columns to the redFood DataFrame.
    redFood['Weight'] = ''
    redFood['PurEqualCon'] = ''
    redFood['Portion Consumed'] = ''

    # Loop through the rows in the redFood DataFrame.
    for i, row in redFood.iterrows():
        # Get the food name from the current row.
        product = row['Food Name']

        # Check if the food name has already been matched.
        if product in matched_skus:
            continue

        # Check similarity between the food name and SKU descriptions using fuzzy matching.
        matches = CleanRetail['Food Name'].apply(lambda x: fuzz.token_sort_ratio(x, product) >= threshold)

        # Replace NaN values in the boolean Series with False.
        matches = matches.fillna(False)

        # If any match is found, update the 'Weight', 'Unit', and 'Super Group' values in the redFood DataFrame.
        if matches.any():
            match_indices = matches[matches].index
            match_index = match_indices[0]
            food = CleanRetail.loc[match_index, 'Weight']
            unit = CleanRetail.loc[match_index, 'PurEqualCon']
            cons = CleanRetail.loc[match_index, 'Portion Consumed']
            matched_skus.add(product)

            
            redFood.loc[i, 'Weight'] = food
            redFood.loc[i, 'PurEqualCon'] = unit
            redFood.loc[i, 'Portion Consumed'] = cons
            

    return redFood

redFood1 = match_food_group(CleanRetail.copy(), redFood.copy())
# Out:
# CPU times: total: 2.7 s
# Wall time: 2.7 s

# %%
redFood1['Source'] = ' '

# %% [markdown]
# ###### Identifying all columns with weights and assigning data source

# %%
pd.set_option('display.max_rows', None)
WeiRdf1 = redFood1.loc[redFood1['Weight'] != '']
WeiRdf1['Source'] = 'FPS'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_26720\2909531313.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WeiRdf1['Source'] = 'FPS'

# %% [markdown]
# ###### Updating Red M&W List with Source indications

# %%
redFood1.update(WeiRdf1)

# %%
a = redFood1.loc[redFood1['Weight'] != '']
a['Weight'].value_counts().sum()
# Out:
# 94

# %% [markdown]
# ### 94 / 535 items Matched Using Algo 1

# %%
f'First Algorithm Matched {round((94/535) * 100, 2)}% of products between McCane and Widdowson df and Food Portion Sizes df'
# Out:
# 'First Algorithm Matched 17.57% of products between McCane and Widdowson df and Food Portion Sizes df'

# %% [markdown]
# # 2

# %% [markdown]
#                                     Using Term Frequency-Inverse Document Frequency
#
# Its a feature extraction technique used in natural language processing and information retrieval. The main purpose of TfidfVectorizer is to transform a collection of text documents into a numerical feature matrix that can be used as input for machine learning algorithms.
#
# Starts with:
#
# Tokenization: The input text is first split into individual words or tokens.
#
# Term Frequency (TF): For each token, the term frequency is calculated, which represents the number of times a token appears in a specific document.
#
# Inverse Document Frequency (IDF): The inverse document frequency measures how important a word is in the entire collection of documents. If a word appears frequently in many documents, its IDF score will be low. But if a word is rare and only appears in a few documents, its IDF score will be high.
#
# TF-IDF Weighting: The TF-IDF score is calculated for each token in each document by multiplying the term frequency (TF) with the inverse document frequency (IDF)(how unique it is among all the documents).
#
# The result is that words that appear often in a document but are rare overall get a high TF-IDF score.

# %%
# %%time
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity


def match_food_group(CleanRetail, redFood):
    """
    Matches food groups between two DataFrames using TF-IDF and cosine similarity and updates 
    redFood database with Weight and Unit from CleanRetail dataframe.

    Args:
        CleanRetail (DataFrame): The DataFrame containing the clean retail data.
        redFood (DataFrame): The DataFrame containing the red food data.

    Returns:
        DataFrame: The red food DataFrame with updated weight and unit values.
    """
    # Set a threshold for cosine similarity.
    threshold = 0.65

    # Add Weight and Unit columns to the redFood DataFrame.
    redFood['Weight'] = ''
    redFood['PurEqualCon'] = ''
    redFood['Portion Consumed'] = ''

    # Preprocess text data in both DataFrames for the "Food Name" field.
    CleanRetail['Food Name'] = CleanRetail['Food Name'].str.lower()
    redFood['Food Name'] = redFood['Food Name'].str.lower()

    # Create a TF-IDF vectorizer for the "Food Name" field only in the redFood DataFrame.
    vectorizer = TfidfVectorizer()
    vectorizer.fit(CleanRetail['Food Name'])

    # Transform the "Food Name" field into TF-IDF vectors for both DataFrames.
    tfidf_clean_retail = vectorizer.transform(CleanRetail['Food Name'])
    tfidf_red_food = vectorizer.transform(redFood['Food Name'])

    # Loop through the rows in the redFood DataFrame.
    for i, row in redFood.iterrows():
        # Get the food name from the current row.
        product = row['Food Name']

        # Calculate cosine similarity between the food name and all CleanRetail food names.
        similarities = cosine_similarity(tfidf_red_food[i], tfidf_clean_retail)

        # Find the index of the most similar food name based on cosine similarity.
        match_index = similarities.argmax()

        # If the similarity exceeds the threshold, update the 'Weight' and 'PurEqualCon' values in the redFood DataFrame.
        if similarities[0, match_index] >= threshold:
            food = CleanRetail.loc[CleanRetail.index[match_index], 'Weight']
            unit = CleanRetail.loc[CleanRetail.index[match_index], 'PurEqualCon']
            consumed = CleanRetail.loc[CleanRetail.index[match_index], 'Portion Consumed']

            redFood.at[i, 'Weight'] = food
            redFood.at[i, 'PurEqualCon'] = unit
            redFood.at[i, 'Portion Consumed'] = consumed

    return redFood

redFood2 = match_food_group(CleanRetail.copy(), redFood.copy())
# Out:
# CPU times: total: 203 ms
# Wall time: 209 ms

# %%
redFood2['Source'] = ' '

# %% [markdown]
# ###### Identifying all columns with weights and assigning data source

# %%
pd.set_option('display.max_rows', None)
WeiRdf2 = redFood2.loc[redFood2['Weight'] != '']
WeiRdf2['Source'] = 'FPS'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_17200\1784067148.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WeiRdf2['Source'] = 'FPS'

# %% [markdown]
# ###### Updating Red M&W List with Source indications

# %%
redFood2.update(WeiRdf2)

# %%
#redFood2
b = redFood2.loc[redFood2['Weight'] != '']
b
#b.tail()
# Out:
#     Food Code                                          Food Name Group  \
# 0      17-208                        beer, bitter, best, premium    QA
# 4      17-247                                spirits, 40% volume    QK
# 6      17-752                                          wine, red    QE
# 7      17-756                                wine, white, medium    QE
# 9      17-632                          coffee, cappuccino, latte     P
# 11     17-744                        cranberry fruit juice drink    PE
# 13     17-672                           energy drink, carbonated   PCA
# 18     17-751                                     lager, premium    QA
# 19     17-244                            liqueurs, high strength    QI
# 20     17-733                                 milk shake, powder   PAA
# 23     11-002                                 barley, pearl, raw    AA
# 29     11-969                                    bread, ciabatta    AF
# 30     11-937                     bread, garlic and herb, retail    AF
# 31     11-910    bread, naan, peshwari naan, takeaway and retail    AF
# 32     11-973                                bread, naan, retail    AF
# 34     11-947                                      bread, seeded    AF
# 41     11-984                          bread rolls, malted wheat    AG
# 43     11-986                             bread rolls, wholemeal    AG
# 52     11-821                         biscuits, cheese flavoured    AM
# 54     11-799                         biscuits, digestive, plain    AM
# 57     11-826                                 breadsticks, plain    AM
# 61     11-970                                      bagels, plain    AP
# 65     11-820                                     cream crackers    AM
# 68     11-850                              doughnuts, ring, iced    AP
# 75        NaN                            macaroni cheese, retail    AD
# 76     11-780                   muesli, swiss style, unfortified    AI
# 93        NaN                            pudding, sponge, retail    AS
# 94    11-1021                            pudding, sponge, canned    AS
# 95        NaN                                     prawn crackers    AT
# 96     11-866                          rice, brown, basmati, raw    AC
# 97     11-870                        rice, brown, easy cook, raw    AC
# 98     11-874                           rice, thai fragrant, raw    AC
# 99     11-863            rice, white, long grain, easy cook, raw    AC
# 101       NaN                                     risotto, plain    AT
# 108    17-371                                stuffing mix, dried    AT
# 116    17-039                                          oil, palm    OC
# 118    17-045                                     oil, sunflower    OC
# 121       NaN                          anchovies, canned in oil,    JC
# 128    16-372                               cod, flesh only, raw    JA
# 133       NaN                              crab, canned in brine    JK
# 134       NaN                                               crab    JK
# 150    16-260                                       oysters, raw    JM
# 152    16-387                                  prawns, king, raw    JK
# 157    14-392                 apricots, ready-to-eat, semi-dried    FA
# 206    14-285                                passion fruit juice    FC
# 210    14-289                                        prune juice    FC
# 213    14-391                   prunes, ready-to-eat, semi-dried    FA
# 214    14-393                                     raisins, dried    FA
# 240    13-830                                      garlic powder     H
# 247    13-839                                      mustard seeds     H
# 256    19-646              bacon rashers, back, fat trimmed, raw   MAA
# 257    18-006                    beef, braising steak, raw, lean   MAC
# 259    18-016                      beef, fillet steak, raw, lean   MAC
# 264    18-064                     beef, sirloin steak, raw, lean   MAC
# 266    18-504                chicken breast/steak, coated, baked   MCA
# 273    19-538                                     chicken slices    MI
# 275    19-128                                corned beef, canned    MI
# 278       NaN                         chow mein, chicken, retail    MR
# 280       NaN                         coronation chicken, retail    MR
# 284    17-640                                       ghee, butter    OF
# 311    12-507                       cornetto type ice cream cone    BP
# 312    12-542                      cheesecake, fruit, individual    BR
# 320    12-390                      lollies, containing ice-cream    BP
# 321    12-389                     lollies, with real fruit juice    BP
# 328    12-522                            milk, evaporated, whole   BAR
# 337    14-896                             almonds, whole kernels    GA
# 339    14-806                                         betel nuts    GA
# 346    14-892                              peanut butter, smooth    GA
# 365    17-724                             gravy instant granules    WY
# 368    17-654                       mayonnaise, standard, retail   WCG
# 369    17-364                                    mustard, smooth    WY
# 371    17-718                                      pickle, sweet   WCG
# 374    17-711                           soup, minestrone, canned    WA
# 377    17-698                               soup, lentil, canned   WAC
# 378    17-700                               soup, oxtail, canned   WAC
# 381    17-628               sauce, chinese cook in, sweet & sour    WC
# 383    17-703                                        salad cream   WCG
# 384       NaN                      sauce, sweet and sour, retail   WCN
# 394    17-377                                   water, distilled    WY
# 398    17-763                                          creme egg   SEA
# 403    17-689  ice cream sauce, topping, strawberry and choco...    SC
# 405    17-777                                 liquorice allsorts   SEC
# 409    17-669                milky way and own brand equivalents   SEA
# 410    17-114                                       marshmallows   SEC
# 411       NaN                                             nougat   SEC
# 414    17-132                                   pork scratchings    SN
# 416    17-060                                       sugar, brown    SC
# 417    17-062                                       sugar, icing    SC
# 418    17-063                                       sugar, white    SC
# 440    13-080                                beans, cluster, raw    DB
# 443    13-514                                  beans, green, raw    DB
# 446    13-098                      beans, mung, dahl, dried, raw    DB
# 448    13-106                           beans, pinto, dried, raw    DB
# 452    13-112                                 beans, runner, raw    DB
# 454    13-117                                  beans, sword, raw    DB
# 464    13-067                           beans, broad, dried, raw    DB
# 480    13-234                                    curly kale, raw    DG
# 482    15-637                         cauliflower cheese, retail    DR
# 485    13-244                                        garlic, raw    DG
# 487    13-608                                 green beans, dried    DI
# 490    13-258                                   horseradish, raw    DG
# 500    13-298                                mustard leaves, raw    DG
# 504       NaN                                          potatoes,    DA
# 508    13-527                                  peas, frozen, raw    DF
# 519    13-521                                 spinach, baby, raw    DG
# 529    15-617                                   sushi, vegetable    DR
#
#                                Super Group  \
# 0                      Alcoholic beverages
# 4                      Alcoholic beverages
# 6                      Alcoholic beverages
# 7                      Alcoholic beverages
# 9                                Beverages
# 11                               Beverages
# 13                               Beverages
# 18                               Beverages
# 19                               Beverages
# 20                               Beverages
# 23             Cereals and cereal products
# 29             Cereals and cereal products
# 30             Cereals and cereal products
# 31             Cereals and cereal products
# 32             Cereals and cereal products
# 34             Cereals and cereal products
# 41             Cereals and cereal products
# 43             Cereals and cereal products
# 52             Cereals and cereal products
# 54             Cereals and cereal products
# 57             Cereals and cereal products
# 61             Cereals and cereal products
# 65             Cereals and cereal products
# 68             Cereals and cereal products
# 75             Cereals and cereal products
# 76             Cereals and cereal products
# 93             Cereals and cereal products
# 94             Cereals and cereal products
# 95             Cereals and cereal products
# 96             Cereals and cereal products
# 97             Cereals and cereal products
# 98             Cereals and cereal products
# 99             Cereals and cereal products
# 101            Cereals and cereal products
# 108            Cereals and cereal products
# 116                          Fats and oils
# 118                          Fats and oils
# 121                 Fish and fish products
# 128                 Fish and fish products
# 133                 Fish and fish products
# 134                 Fish and fish products
# 150                 Fish and fish products
# 152                 Fish and fish products
# 157                                  Fruit
# 206                                  Fruit
# 210                                  Fruit
# 213                                  Fruit
# 214                                  Fruit
# 240                       Herbs and spices
# 247                       Herbs and spices
# 256                 Meat and meat products
# 257                 Meat and meat products
# 259                 Meat and meat products
# 264                 Meat and meat products
# 266                 Meat and meat products
# 273                 Meat and meat products
# 275                 Meat and meat products
# 278                 Meat and meat products
# 280                 Meat and meat products
# 284                 Meat and meat products
# 311                 Milk and milk products
# 312                 Milk and milk products
# 320                 Milk and milk products
# 321                 Milk and milk products
# 328                 Milk and milk products
# 337                         Nuts and seeds
# 339                         Nuts and seeds
# 346                         Nuts and seeds
# 365  Soups, sauces and miscellaneous foods
# 368  Soups, sauces and miscellaneous foods
# 369  Soups, sauces and miscellaneous foods
# 371  Soups, sauces and miscellaneous foods
# 374  Soups, sauces and miscellaneous foods
# 377  Soups, sauces and miscellaneous foods
# 378  Soups, sauces and miscellaneous foods
# 381  Soups, sauces and miscellaneous foods
# 383  Soups, sauces and miscellaneous foods
# 384  Soups, sauces and miscellaneous foods
# 394  Soups, sauces and miscellaneous foods
# 398           Sugars, preserves and snacks
# 403           Sugars, preserves and snacks
# 405           Sugars, preserves and snacks
# 409           Sugars, preserves and snacks
# 410           Sugars, preserves and snacks
# 411           Sugars, preserves and snacks
# 414           Sugars, preserves and snacks
# 416           Sugars, preserves and snacks
# 417           Sugars, preserves and snacks
# 418           Sugars, preserves and snacks
# 440                             Vegetables
# 443                             Vegetables
# 446                             Vegetables
# 448                             Vegetables
# 452                             Vegetables
# 454                             Vegetables
# 464                             Vegetables
# 480                             Vegetables
# 482                             Vegetables
# 485                             Vegetables
# 487                             Vegetables
# 490                             Vegetables
# 500                             Vegetables
# 504                             Vegetables
# 508                             Vegetables
# 519                             Vegetables
# 529                             Vegetables
#
#                                    Sale format(s)     Weight PurEqualCon  \
# 0    can, can multipack, bottle, bottle multipack       574g           Y
# 4                               bottle, miniature        29g           Y
# 6                       bottle, small bottle, box       200g           Y
# 7                       bottle, small bottle, box       200g           Y
# 9                                             NaN       170g           Y
# 11                       carton, tetrapak, bottle       200g           Y
# 13     can, ready to drink bottle, sharing bottle      250ml           Y
# 18   can, multipack can, bottle, multipack bottle       574g           Y
# 19                              bottle, miniature       150g           Y
# 20                                            NaN       585g           Y
# 23                                         packet       180g           Y
# 29               loose, individual\nmultiple pack        20g           Y
# 30               loose, individual\nmultiple pack        20g           Y
# 31               loose, individual\nmultiple pack       160g           Y
# 32               loose, individual\nmultiple pack       160g           Y
# 34                                           loaf        20g           Y
# 41               loose, individual\nmultiple pack        20g           Y
# 43               loose, individual\nmultiple pack        20g           Y
# 52                                 wrapper or box       214g           Y
# 54                                 wrapper or box       266g           Y
# 57                                            box        45g           Y
# 61               loose, individual\nmultiple pack        45g           Y
# 65                                 wrapper or box       150g           Y
# 68                                            NaN        30g        Y, P
# 75                                            NaN       430g           Y
# 76                                     cereal box       150g           Y
# 93                                            NaN       300g           Y
# 94                                            NaN       300g           Y
# 95                                         packet    30g/40g           Y
# 96                                         packet       300g           Y
# 97                                         packet       300g           Y
# 98                                         packet       300g           Y
# 99                                         packet       300g           Y
# 101                                           NaN        45g           Y
# 108                                           NaN       100g           Y
# 116                                        bottle       200g           Y
# 118                                        bottle       200g           Y
# 121                                           tin       200g           Y
# 128                                        fillet       170g           Y
# 133                                           tin        85g           Y
# 134                                           NaN        85g           Y
# 150                                           NaN       105g           Y
# 152                                           NaN       100g           Y
# 157                                        packet       125g           Y
# 206                      carton, tetrapak, bottle       200g           Y
# 210                      carton, tetrapak, bottle       200g           Y
# 213                                           NaN       125g           Y
# 214                                        packet        44g           Y
# 240                                     spice jar        20g           Y
# 247                                     spice jar         5g           Y
# 256                                           NaN    25g/50g           Y
# 257                                           NaN       213g           Y
# 259                                           NaN       213g           Y
# 264                                           NaN       213g           Y
# 266                                           NaN       100g           Y
# 273                                           NaN        70g           Y
# 275                                           tin       198g           Y
# 278                                           NaN       350g           Y
# 280                                           NaN       190g           Y
# 284                                           NaN        25g           Y
# 311                                           box        60g           Y
# 312                                           NaN        90g           Y
# 320                                           NaN        60g           Y
# 321                                           NaN       200g           Y
# 328                                           tin       170g           Y
# 337                                        packet        51g           Y
# 339                                        packet        47g           Y
# 346                                           jar        25g           Y
# 365                                           NaN        11g           Y
# 368                                           NaN       165g           Y
# 369                                           jar         5g           Y
# 371                                           jar        20g           Y
# 374                                           can       405g           Y
# 377                                           can       405g           Y
# 378                                           can       405g           Y
# 381                                           NaN        25g           Y
# 383                                           NaN        12g           Y
# 384                                           jar        25g           Y
# 394                                           NaN       500g           Y
# 398                                    individual        39g           Y
# 403                                           NaN        60g           Y
# 405                                           bag       115g           Y
# 409                     indiviudal bar, multipack        26g           Y
# 410                                           NaN        40g           Y
# 411                                           NaN       114g           Y
# 414                                           bag        22g           Y
# 416                                           bag         6g           Y
# 417                                           bag         6g           Y
# 418                                           bag         6g           Y
# 440                                        packet       170g           Y
# 443                                        packet       170g           Y
# 446                                        packet       170g           Y
# 448                                        packet       170g           Y
# 452                                        packet       170g           Y
# 454                                        packet       170g           Y
# 464                             loose, individual       170g           Y
# 480                                           bag        29g           Y
# 482                                        packet       185g           Y
# 485                              individual, pack        20g           Y
# 487                                        packet       170g           Y
# 490                                           NaN        12g           Y
# 500                                           NaN         5g           Y
# 504                                           NaN        75g           Y
# 508                                           NaN       100g           Y
# 519                                        packet       150g           Y
# 529                                           NaN  210g/440g           Y
#
#                   Portion Consumed Source
# 0                           1 pint    FPS
# 4                      1 miniature    FPS
# 6                   I small bottle    FPS
# 7                   I small bottle    FPS
# 9    1 average vending machine cup    FPS
# 11               individual carton    FPS
# 13                        slim can    FPS
# 18                          1 pint    FPS
# 19                            pots    FPS
# 20                          1 pint    FPS
# 23                        I bottle    FPS
# 29                         1 slice    FPS
# 30                         1 slice    FPS
# 31                             NaN    FPS
# 32                             NaN    FPS
# 34                         1 slice    FPS
# 41                         1 slice    FPS
# 43                         1 slice    FPS
# 52   Crazy Milk, individual carton    FPS
# 54                             NaN    FPS
# 57                             NaN    FPS
# 61                             NaN    FPS
# 65       1 small carton (5 fi. oz)    FPS
# 68                         per bag    FPS
# 75                       large can    FPS
# 76                             NaN    FPS
# 93                           whole    FPS
# 94                           whole    FPS
# 95                         per bag    FPS
# 96                1 packet made up    FPS
# 97                1 packet made up    FPS
# 98                1 packet made up    FPS
# 99                1 packet made up    FPS
# 101                            NaN    FPS
# 108                        per bag    FPS
# 116                    1 small can    FPS
# 118                    1 small can    FPS
# 121                    1 small can    FPS
# 128    in sauce, purchased, frozen    FPS
# 133                    1 small can    FPS
# 134                    1 small can    FPS
# 150           1 can smoked oysters    FPS
# 152             1 small jar prawns    FPS
# 157                        per pot    FPS
# 206              individual carton    FPS
# 210              individual carton    FPS
# 213                        per pot    FPS
# 214                         packet    FPS
# 240                        1 slice    FPS
# 247                       I sachet    FPS
# 256                        per bag    FPS
# 257                          small    FPS
# 259                          small    FPS
# 264                          small    FPS
# 266                            NaN    FPS
# 273                            NaN    FPS
# 275                    1 small can    FPS
# 278                            NaN    FPS
# 280                            NaN    FPS
# 284                 1 portion pack    FPS
# 311                            tub    FPS
# 312                     individual    FPS
# 320                            tub    FPS
# 321              individual carton    FPS
# 328                    1 small can    FPS
# 337                       standard    FPS
# 339                         packet    FPS
# 346                 1 portion pack    FPS
# 365              1 sachet, average    FPS
# 368                            NaN    FPS
# 369                       I sachet    FPS
# 371                 1 portion pack    FPS
# 374                      large can    FPS
# 377                      large can    FPS
# 378                      large can    FPS
# 381                            NaN    FPS
# 383                       1 sachet    FPS
# 384                            NaN    FPS
# 394                          large    FPS
# 398                            NaN    FPS
# 403                            tub    FPS
# 405                            box    FPS
# 409                       standard    FPS
# 410                            bag    FPS
# 411                      large bar    FPS
# 414                        per bag    FPS
# 416               1 'packet' sugar    FPS
# 417               1 'packet' sugar    FPS
# 418               1 'packet' sugar    FPS
# 440                      small tin    FPS
# 443                      small tin    FPS
# 446                      small tin    FPS
# 448                      small tin    FPS
# 452                      small tin    FPS
# 454                      small tin    FPS
# 464                      small tin    FPS
# 480                            NaN    FPS
# 482                            NaN    FPS
# 485                        1 slice    FPS
# 487                      small tin    FPS
# 490                       1 sachet    FPS
# 500                       I sachet    FPS
# 504                          small    FPS
# 508                           tubs    FPS
# 519                            Jar    FPS
# 529                            can    FPS

# %%
b['Weight'].value_counts().sum()
# Out:
# 106

# %% [markdown]
# ### 106 / 535 items Matched Using Algo 2

# %%
f'Second Algorithm Matched {round((106/535) * 100, 2)}% of products between McCane and Widdowson df and Food Portion Sizes df. Contains some errors'
# Out:
# 'Second Algorithm Matched 19.81% of products between McCane and Widdowson df and Food Portion Sizes df. Contains some errors'

# %% [markdown]
# # 3

# %% [markdown]
#                                                Using Fuzzy Matching

# %% [markdown]
# Here, I use fuzz.token_set_ratio from the fuzzywuzzy library to calculate a similarity score between each food name in redFood and all food names in CleanRetail. The token_set_ratio function considers the set of unique tokens (words) in the strings and calculates the similarity based on common token matches. The similarity score ranges from 0 to 100, where higher values indicate more similarity.
#
#
# By adjusting the threshold value, you can control the matching sensitivity. Lower threshold values will allow for more leniency in matching, potentially catching more variations, while higher threshold values will require closer matches.

# %%
# %%time
from fuzzywuzzy import fuzz

def match_food_group(CleanRetai, redFood):
    """
    Matches food groups between two DataFrames using approximate string matching and updates 
    redFood database with Weight and Unit from CleanRetail dataframe.

    Args:
        CleanRetail (DataFrame): The DataFrame containing the clean retail data.
        redFood (DataFrame): The DataFrame containing the red food data.

    Returns:
        DataFrame: The red food DataFrame with updated weight and unit values.
    """
    # Set a threshold for string matching similarity.
    threshold = 65  # You can experiment with different threshold values (0 to 100).

    # Add Weight and Unit columns to the redFood DataFrame.
    redFood['Weight'] = ''
    redFood['PurEqualCon'] = ''
    redFood['Portion Consumed'] = ''

    # Preprocess text data in both DataFrames for the "Food Name" field.
    CleanRetai['Food Name'] = CleanRetai['Food Name'].str.lower()
    redFood['Food Name'] = redFood['Food Name'].str.lower()

    # Loop through the rows in the redFood DataFrame.
    for i, row in redFood.iterrows():
        # Get the food name from the current row.
        product = row['Food Name']

        # Find the most similar food name in CleanRetail using fuzzy string matching.
        best_match = None
        best_score = 0

        for _, retail_row in CleanRetai.iterrows():
            retail_product = retail_row['Food Name']
            similarity_score = fuzz.token_set_ratio(product, retail_product)

            if similarity_score > best_score:
                best_score = similarity_score
                best_match = retail_row

        # If the similarity exceeds the threshold, update the 'Weight' and 'PurEqualCon' values in the redFood DataFrame.
        if best_score >= threshold:
            food = best_match['Weight']
            unit = best_match['PurEqualCon']
            consumed = best_match['Portion Consumed']

            redFood.at[i, 'Weight'] = food
            redFood.at[i, 'PurEqualCon'] = unit
            redFood.at[i, 'Portion Consumed'] = consumed

    return redFood

redFood3 = match_food_group(CleanRetai.copy(), redFood.copy())
# Out:
# CPU times: total: 47.8 s
# Wall time: 48.3 s

# %% [markdown]
#                               Creating Source column so I can Identify where weights are from

# %%
redFood3['Source'] = ' '

# %% [markdown]
# ###### Identifying all columns with weights and assigning data source

# %%
pd.set_option('display.max_rows', None)
WeiRdf3 = redFood3.loc[redFood3['Weight'] != '']
WeiRdf3['Source'] = 'FPS'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_17200\2784020946.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WeiRdf3['Source'] = 'FPS'

# %% [markdown]
# ###### Updating Red M&W List with Source indications

# %%
redFood3.update(WeiRdf3)

# %%
redFood3
# Out:
#     Food Code                                          Food Name Group  \
# 0      17-208                        beer, bitter, best, premium    QA
# 1      17-224                                       cider, sweet    QC
# 2      17-234                                               port    QF
# 3      17-236                                     sherry, medium    QF
# 4      17-247                                spirits, 40% volume    QK
# 5      17-239                                      vermouth, dry    QG
# 6      17-752                                          wine, red    QE
# 7      17-756                                wine, white, medium    QE
# 8      14-272   apple juice concentrate, unsweetened, commerical    PE
# 9      17-632                          coffee, cappuccino, latte     P
# 10     17-175                                               cola   PCA
# 11     17-744                        cranberry fruit juice drink    PE
# 12     17-498                         drinking chocolate, powder   PAA
# 13     17-672                           energy drink, carbonated   PCA
# 14     17-745                           grape juice, unsweetened    PE
# 15     17-731                                   horlicks, powder   PAA
# 16     17-179                                           lemonade   PCA
# 17     17-761                                           lucozade   PCA
# 18     17-751                                     lager, premium    QA
# 19     17-244                            liqueurs, high strength    QI
# 20     17-733                                 milk shake, powder   PAA
# 21     17-734                                   ovaltine, powder   PAA
# 22     11-001                                          arrowroot    AA
# 23     11-002                                 barley, pearl, raw    AA
# 24     11-906                                        bran, wheat    AA
# 25     11-006                                  buckwheat, groats    AA
# 26    11-1144                         bread rolls, brown, crusty    AF
# 27    11-1006                           bread rolls, white, soft    AF
# 28     11-971                              bread, brown, average    AF
# 29     11-969                                    bread, ciabatta    AF
# 30     11-937                     bread, garlic and herb, retail    AF
# 31     11-910    bread, naan, peshwari naan, takeaway and retail    AF
# 32     11-973                                bread, naan, retail    AF
# 33     11-974                                bread, pitta, white    AF
# 34     11-947                                      bread, seeded    AF
# 35    11-1145                              bread, white, average    AF
# 36     11-977               bread, white, farmhouse or split tin    AF
# 37     11-978                         bread, white, french stick    AF
# 38     11-980                               bread, white, sliced    AF
# 39     11-981                          bread, wholemeal, average    AF
# 40     11-983                           bread rolls, brown, soft    AG
# 41     11-984                          bread rolls, malted wheat    AG
# 42     11-985                         bread rolls, white, crusty    AG
# 43     11-986                             bread rolls, wholemeal    AG
# 44     11-763           breakfast cereal, bran flakes, fortified    AI
# 45     11-742            breakfast cereal, cornflakes, fortified    AI
# 46     11-779  breakfast cereal, fruit and fibre type, fortified    AI
# 47     11-755  breakfast cereal, honey loops and hoops, inclu...    AI
# 48     11-792  breakfast cereal, instant hot oat, plain, raw,...    AI
# 49     11-753  breakfast cereal, rice, chocolate flavoured, f...    AI
# 50     11-778  breakfast cereal, shredded wheat, honey nut, n...    AI
# 51     11-773  breakfast cereal, wheat biscuits, weetabix typ...    AI
# 52     11-821                         biscuits, cheese flavoured    AM
# 53     11-815        biscuits, cookies, chocolate chip, standard    AM
# 54     11-799                         biscuits, digestive, plain    AM
# 55     11-809              biscuits, fully coated with chocolate    AM
# 56     11-801                       biscuits, plain, reduced fat    AM
# 57     11-826                                 breadsticks, plain    AM
# 58        NaN                               banana bread, retail    AN
# 59        NaN                        brownies, chocolate, retail    AN
# 60        NaN                    brownies, chocolate, baking mix    AN
# 61     11-970                                      bagels, plain    AP
# 62        NaN                           bread and butter pudding    AS
# 63     11-011                                   cornmeal, sifted    AA
# 64     11-988                                         croissants    AG
# 65     11-820                                     cream crackers    AM
# 66     11-839              cakes, fancy iced, individual, retail    AN
# 67    11-1020                             crumble, fruit, retail    AS
# 68     11-850                              doughnuts, ring, iced    AP
# 69     11-849                                doughnuts, with jam    AP
# 70        NaN                                         dumplings,    AT
# 71        NaN                               biscuit, gingerbread    AN
# 72        NaN                                   hot cross buns,     AP
# 73     11-739                                        jaffa cakes    AM
# 74     11-846                                  jam tarts, retail    AS
# 75        NaN                            macaroni cheese, retail    AD
# 76     11-780                   muesli, swiss style, unfortified    AI
# 77     11-737               muffins, american, chocolate, retail    AN
# 78     11-848                                 mince pies, retail    AS
# 79     11-719                           noodles, egg, dried, raw    AD
# 80     11-823                            oatcakes, plain, retail    AM
# 81     11-936                   pizza, cheese and tomato, retail     A
# 82     11-788                         porridge oats, unfortified     A
# 83     11-726                             pasta, egg, fresh, raw    AD
# 84     11-718           pasta, wholewheat, spaghetti, dried, raw    AD
# 85     11-735          pasta, spaghetti, canned, in tomato sauce    AD
# 86        NaN                                   papadums, retail    AF
# 87     11-853                 pastry, shortcrust, retail, cooked    AO
# 88     11-844  pastries, chocolate eclairs, cream filled, retail    AP
# 89        NaN                                           pancakes    AS
# 90     11-544                            scotch pancakes, retail    AS
# 91     11-921           pie, apple, pastry, double crust, retail    AS
# 92     11-847                     pie, fruit, individual, retail    AS
# 93        NaN                            pudding, sponge, retail    AS
# 94    11-1021                            pudding, sponge, canned    AS
# 95        NaN                                     prawn crackers    AT
# 96     11-866                          rice, brown, basmati, raw    AC
# 97     11-870                        rice, brown, easy cook, raw    AC
# 98     11-874                           rice, thai fragrant, raw    AC
# 99     11-863            rice, white, long grain, easy cook, raw    AC
# 100    11-940                                              rusks    AK
# 101       NaN                                     risotto, plain    AT
# 102    11-903                                      semolina, raw    AA
# 103       NaN                             sandwich, white bread,    AB
# 104       NaN                              sandwich, brown bread    AB
# 105    11-802                                         shortbread    AM
# 106    11-544                            scotch pancakes, retail    AP
# 107    11-919              strudel, fruit filled, retail, frozen    AS
# 108    17-371                                stuffing mix, dried    AT
# 109    11-800         wafers, plain ice cream wafers, not filled    AM
# 110       NaN                                  yorkshire pudding    AT
# 111    12-937                          eggs, chicken, whole, raw    CA
# 112    12-949                          quiche, vegetable, retail    CD
# 113    17-487                                     dripping, beef    OF
# 114    17-010                                               lard    OF
# 115    17-031                                       oil, coconut    OC
# 116    17-039                                          oil, palm    OC
# 117    17-044                                          oil, soya    OC
# 118    17-045                                     oil, sunflower    OC
# 119    17-686                            oil, vegetable, average    OC
# 120    16-001                                           ayr, raw    JA
# 121       NaN                          anchovies, canned in oil,    JC
# 122    16-385                         bass, sea, flesh only, raw    JA
# 123    16-003                                          bele, raw    JA
# 124    16-004                                          boal, raw    JA
# 125    16-005                                        bombay duck    JA
# 126    16-006                                    bream, sea, raw    JA
# 127    16-169                                         bacha, raw    JC
# 128    16-372                               cod, flesh only, raw    JA
# 129    16-172                                          carp, raw    JA
# 130    16-007                                       catfish, raw    JA
# 131    16-011                                        chital, raw    JA
# 132    16-383                             coley, flesh only, raw    JA
# 133       NaN                              crab, canned in brine    JK
# 134       NaN                                               crab    JK
# 135       NaN                                   crab, white meat    JK
# 136    16-235                                      crayfish, raw    JK
# 137       NaN                                           calamari    JM
# 138       NaN                                            cockles    JM
# 139    16-254                                    cuttlefish, raw    JM
# 140       NaN                                            caviare    JR
# 141    16-173                                   eel, yellow, raw    JC
# 142    16-375                           haddock, flesh only, raw    JA
# 143    16-070                              hake, flesh only, raw    JA
# 144    16-081                                      kalabasu, raw    JA
# 145    16-186                                         katla, raw    JA
# 146       NaN                                kippers, flesh only    JC
# 147    16-393                          mackerel, flesh only, raw    JC
# 148    16-497                                       mussels, raw    JM
# 149    16-259                                       octopus, raw    JM
# 150    16-260                                       oysters, raw    JM
# 151    16-378                  pollock, alaskan, flesh only, raw    JA
# 152    16-387                                  prawns, king, raw    JK
# 153    14-363  apples, cooking, raw, flesh only, weighed with...     F
# 154    14-319                apples, eating, raw, flesh and skin     F
# 155    14-001                                               amla    FA
# 156    14-025                      apricots, raw, flesh and skin    FA
# 157    14-392                 apricots, ready-to-eat, semi-dried    FA
# 158    14-040  avocado, fuerte, flesh only, weighed with skin...    FA
# 159    14-387  avocado, hass, flesh only, weighed with skin a...    FA
# 160    14-331            apple juice, clear, ambient and chilled    FC
# 161    14-043                                 babaco, flesh only    FA
# 162    14-318                            bananas, flesh and skin    FA
# 163    14-388                                  blackberries, raw    FA
# 164    14-053                                 blackcurrants, raw    FA
# 165    14-325                                        blueberries    FA
# 166    14-382                      cherries, flesh and skin, raw    FA
# 167    14-326   citrus fruit, soft/easy peelers, flesh with skin    FA
# 168    14-073                                        cranberries    FA
# 169    14-074                                           currants    FA
# 170    14-077                       damsons, flesh and skin, raw    FA
# 171    14-083                         dates, raw, flesh and skin    FA
# 172    14-087                                  dried mixed fruit    FA
# 173    14-089                          elderberries, whole fruit    FA
# 174    14-100                         gooseberries, cooking, raw    FA
# 175    14-384                        grapefruit, flesh only, raw    FA
# 176    14-322                                      grapes, green    FA
# 177    14-118                             guava, flesh only, raw    FA
# 178    14-371                        kiwi fruit, flesh only, raw    FA
# 179    14-373     kiwi fruit, flesh only, raw, weighed with skin    FA
# 180    14-125                         kumquats, whole fruit, raw    FA
# 181    14-128                        lemons, whole, without pips    FA
# 182    14-131                                  limes, flesh only    FA
# 183    14-132                              limes, flesh and skin    FA
# 184    14-133                                  loganberries, raw    FA
# 185    14-277                                 lemon juice, fresh    FC
# 186    14-378                     mangoes, ripe, flesh only, raw    FA
# 187    14-379          mangoes, raw, weighed with skin and stone    FA
# 188    14-339                 melon, canteloupe-type, flesh only    FA
# 189    14-353             melon, canteloupe-type, flesh and skin    FA
# 190    14-356                              melon, flesh and skin    FA
# 191    14-168                       mulberries, whole fruit, raw    FA
# 192    14-380                    nectarines, flesh and skin, raw    FA
# 193       NaN                                           olives,     FA
# 194    14-327                                oranges, flesh only    FA
# 195    14-360                  oranges, flesh with peel and pips    FA
# 196    14-369                     orange juice, freshly squeezed    FC
# 197    14-361  pears, average, flesh and skin, raw, weighed w...     F
# 198    14-188           peaches, canned in juice, whole contents    FA
# 199    14-321                         pears, raw, flesh and skin    FA
# 200    14-376                         pineapple, flesh only, raw    FA
# 201    14-377                 pineapple, flesh with skin and top    FA
# 202    14-211         pineapple, canned in juice, whole contents    FA
# 203    14-396                                   pineapple, dried    FA
# 204    14-220               plums, victoria, flesh and skin, raw    FA
# 205    14-227     pomegranate, flesh and pips, weighed with skin    FA
# 206    14-285                                passion fruit juice    FC
# 207    14-179   passion fruit, flesh and pips, weighed with skin    FA
# 208    14-341                            pomegranate juice drink    FC
# 209    14-227     pomegranate, flesh and pips, weighed with skin    FA
# 210    14-289                                        prune juice    FC
# 211    14-237            prunes, canned in juice, whole contents    FA
# 212    14-231                             prunes, flesh and skin    FA
# 213    14-391                   prunes, ready-to-eat, semi-dried    FA
# 214    14-393                                     raisins, dried    FA
# 215    14-375                                   raspberries, raw    FA
# 216    14-249                                   redcurrants, raw    FA
# 217    14-252                           rhubarb, stems only, raw    FA
# 218    14-059                                         star fruit    FA
# 219    14-324                                  strawberries, raw    FA
# 220    14-268                                 whitecurrants, raw    FA
# 221    13-801                                   allspice, ground     H
# 222    13-802                                        anise seeds     H
# 223    13-803                                         asafoetida     H
# 224    13-805                               basil, dried, ground     H
# 225    13-804                                       basil, fresh     H
# 226    13-808                                      caraway seeds     H
# 227    13-809                                   cardamom, ground     H
# 228    13-810                                       celery seeds     H
# 229    13-811                                     chervil, dried     H
# 230    13-873                                      chilli powder     H
# 231    13-813                                    chinese 5 spice     H
# 232    13-887                                      chives, fresh     H
# 233    13-874                                   cinnamon, ground     H
# 234    13-816                                      cloves, dried     H
# 235    13-818                            coriander leaves, dried     H
# 236    13-889                                        cumin seeds     H
# 237    13-876                                       curry powder     H
# 238    13-824                                        dill, fresh     H
# 239    13-829                                       garam masala     H
# 240    13-830                                      garlic powder     H
# 241    13-890                                      ginger, fresh     H
# 242    13-832                                     ginger, ground     H
# 243    13-835                                    marjoram, dried     H
# 244    13-836                                        mint, fresh     H
# 245    13-886                                 mixed curry spices     H
# 246    13-884                                 mixed herbs, dried     H
# 247    13-839                                      mustard seeds     H
# 248    13-877                                     nutmeg, ground     H
# 249    13-878                             oregano, dried, ground     H
# 250    13-879                                            paprika     H
# 251    13-844                                     parsley, fresh     H
# 252    13-880                                      pepper, black     H
# 253    13-892                                    rosemary, fresh     H
# 254    13-852                                            saffron     H
# 255    13-854                                sage, dried, ground     H
# 256    19-646              bacon rashers, back, fat trimmed, raw   MAA
# 257    18-006                    beef, braising steak, raw, lean   MAC
# 258    18-003                            beef, fat, average, raw   MAC
# 259    18-016                      beef, fillet steak, raw, lean   MAC
# 260    18-024                             beef, flank, raw, lean   MAC
# 261    18-468                           beef, lean, average, raw   MAC
# 262    18-469                                   beef, mince, raw   MAC
# 263    18-054                        beef, silverside, raw, lean   MAC
# 264    18-064                     beef, sirloin steak, raw, lean   MAC
# 265    18-084                           beef, topside, raw, lean   MAC
# 266    18-504                chicken breast/steak, coated, baked   MCA
# 267    18-501                   chicken pieces, coated, takeaway   MCA
# 268    18-293           chicken, leg quarter, raw, meat and skin   MCA
# 269    18-488                        chicken, meat, average, raw   MCA
# 270    18-297                 chicken, whole, raw, meat and skin   MCA
# 271    18-295          chicken, wing quarter, raw, meat and skin   MCA
# 272    18-503               chicken/turkey pieces, coated, baked   MCA
# 273    19-538                                     chicken slices    MI
# 274    19-516                                            chorizo    MI
# 275    19-128                                corned beef, canned    MI
# 276    19-449                       curry, chicken balti, retail    MR
# 277       NaN                          casserole, sausage,retail    MR
# 278       NaN                         chow mein, chicken, retail    MR
# 279    19-466                              cornish pasty, retail    MR
# 280       NaN                         coronation chicken, retail    MR
# 281    18-489                               duck, meat only, raw   MCC
# 282    19-539                            doner kebabs, meat only    MR
# 283       NaN                       enchiladas, meal kit, retail    MR
# 284    17-640                                       ghee, butter    OF
# 285    19-496                                                ham   MAA
# 286       NaN                                            haggis,    MI
# 287       NaN          hot pot, lamb/beef with potatoes, retail,    MR
# 288    18-402                                  kidney, lamb, raw    MG
# 289    18-478                   lamb, average, raw, lean and fat   MAE
# 290    18-111                            lamb, breast, raw, lean   MAE
# 291    18-115               lamb, chump chops, raw, lean and fat   MAE
# 292    18-481                                   lamb, mince, raw   MAE
# 293    18-413                                   liver, lamb, raw    MG
# 294       NaN                                     luncheon meat,    MI
# 295    19-326                             meat samosas, takeaway    MR
# 296       NaN                            meatballs, beef, retail    MR
# 297       NaN                meatballs, in tomatoe sauce, retail    MR
# 298    18-419                                        oxtail, raw    MG
# 299    18-609                pork, spare ribs, raw, lean and fat   MAG
# 300    18-387                             rabbit, raw, meat only   MEC
# 301    18-390                            venison, meat only, raw   MEE
# 302    12-500  baking fat and margarine (75-90% fat), hard block   BTM
# 303    12-333                             cream, fresh, whipping   BJC
# 304    12-537                  cheese spread, plain, reduced fat    BL
# 305    12-346                           cheese, cheddar, english    BL
# 306    12-354                                cheese, danish blue    BL
# 307    12-357     cheese, goats milk, full fat, soft, white rind    BL
# 308    12-360                          cheese, mozzarella, fresh    BL
# 309    12-549             cheese, processed, slices, reduced fat    BL
# 310    12-486                             cheese, white cheshire    BL
# 311    12-507                       cornetto type ice cream cone    BP
# 312    12-542                      cheesecake, fruit, individual    BR
# 313    12-461                         tarts, custard, individual    BR
# 314    12-543        custard, ready to eat, canned and tetra-pak    BR
# 315    12-398                         desserts, dairy, chocolate    BR
# 316    12-508              ice cream, dairy, vanilla, soft scoop    BP
# 317    12-509          ice cream, non dairy, vanilla, soft scoop    BP
# 318       NaN                                      jelly, retail    BR
# 319    12-373                                   lassi, sweetened    BN
# 320    12-390                      lollies, containing ice-cream    BP
# 321    12-389                     lollies, with real fruit juice    BP
# 322    12-512                          milk, 1% fat, pasteurised    BA
# 323    12-322               milk, channel islands, whole, summer   BAB
# 324    12-307                milk, skimmed, pasteurised, average   BAE
# 325    12-313           milk, semi-skimmed, pasteurised, average   BAH
# 326    12-596                  milk, whole, pasteurised, average   BAK
# 327    12-520                  milk, condensed, whole, sweetened   BAR
# 328    12-522                            milk, evaporated, whole   BAR
# 329    12-524  milk, soya, non-dairy alternative to milk, uns...    BC
# 330    12-401                         mousse, chocolate, low fat    BR
# 331    12-553                     pudding, rice, canned, low fat    BR
# 332       NaN                                      raita, retail    BV
# 333    12-555                         yogurt, greek style, plain    BN
# 334    12-375                          yogurt, whole milk, fruit    BN
# 335    14-870                         almonds, flaked and ground    GA
# 336    14-897                                   almonds, toasted    GA
# 337    14-896                             almonds, whole kernels    GA
# 338    14-895                              breadnut seeds, dried     G
# 339    14-806                                         betel nuts    GA
# 340    14-813                        chestnuts, kernel only, raw    GA
# 341    14-889                               coconut milk, retail    GA
# 342    14-874                             hazelnuts, kernel only    GA
# 343    14-891                             macadamia nuts, salted     G
# 344    14-875                 marzipan, white and yellow, retail    GA
# 345    14-880                                        nuts, mixed    GA
# 346    14-892                              peanut butter, smooth    GA
# 347    14-882                                peanuts and raisins    GA
# 348    14-840    pistachio nuts, kernel only, roasted and salted    GA
# 349    14-843                                        quinoa, raw    GA
# 350    14-845                                    sunflower seeds    GA
# 351    14-879                               walnuts, kernel only    GA
# 352       NaN                                apple sauce, retail    WC
# 353    17-705                                     barbecue sauce    WC
# 354    17-678                    brown sauce, reduced salt/sugar   WCN
# 355    17-697  chicken soup, cream of, canned, condensed, as ...   WAC
# 356    17-719                                       chilli sauce    WC
# 357       NaN                                       cheese sauce   WCD
# 358    17-345                                    chutney, tomato   WCG
# 359    17-358                                    cream of tartar    WY
# 360    17-715                              dressing, blue cheese   WCG
# 361    17-701                                   dressing, french   WCG
# 362    17-717                          dressing, thousand island   WCG
# 363       NaN                                  guacamole, retail    WC
# 364    17-360                                           gelatine    WY
# 365    17-724                             gravy instant granules    WY
# 366       NaN                          hollandaise sauce, retail    WC
# 367       NaN                   hollandaise sauce, vegan, retail    WC
# 368    17-654                       mayonnaise, standard, retail   WCG
# 369    17-364                                    mustard, smooth    WY
# 370    17-623                                         pesto, red    WC
# 371    17-718                                      pickle, sweet   WCG
# 372    17-702                                         piccalilli   WCN
# 373    17-354                               relish, tomato based   WCN
# 374    17-711                           soup, minestrone, canned    WA
# 375    17-695                    soup, chicken, cream of, canned   WAC
# 376    17-652                      soup, cream of tomato, canned   WAC
# 377    17-698                               soup, lentil, canned   WAC
# 378    17-700                               soup, oxtail, canned   WAC
# 379    17-712                            soup, vegetable, canned   WAC
# 380    17-653                 soup, instant, dried, as purchased   WAE
# 381    17-628               sauce, chinese cook in, sweet & sour    WC
# 382    17-629                            sauce, chinese stir fry    WC
# 383    17-703                                        salad cream   WCG
# 384       NaN                      sauce, sweet and sour, retail   WCN
# 385    17-721                soy sauce, light and dark varieties   WCN
# 386    17-367                                               salt    WY
# 387    17-515                                  stock cubes, beef    WY
# 388    17-680                                          stock gel    WY
# 389    17-681                 stock, chicken, ready made, retail    WY
# 390    17-339                                            vinegar    WY
# 391       NaN                                white sauce, retial   WCD
# 392       NaN                         white sauce, vegan, retial   WCD
# 393    17-723                               worcestershire sauce   WCN
# 394    17-377                                   water, distilled    WY
# 395    17-517                                      yeast extract    WY
# 396    17-659                                   chocolate spread    SC
# 397    17-658      chocolate covered bar with caramel and cereal   SEA
# 398    17-763                                          creme egg   SEA
# 399    17-645                                        corn snacks    SN
# 400       NaN                       chevda/chevra/chewra, retial   SNC
# 401    17-049                                 glucose liquid, bp    SC
# 402    17-050                                              honey    SC
# 403    17-689  ice cream sauce, topping, strawberry and choco...    SC
# 404    17-075                                 jam, reduced sugar    SC
# 405    17-777                                 liquorice allsorts   SEC
# 406    17-078                                          marmalade    SC
# 407    17-651                     maltesers and similar products   SEA
# 408    17-668                 mars bar and own brand equivalents   SEA
# 409    17-669                milky way and own brand equivalents   SEA
# 410    17-114                                       marshmallows   SEC
# 411       NaN                                             nougat   SEC
# 412    17-117                                        peppermints   SEC
# 413    17-692                            popcorn, salted, retail    SN
# 414    17-132                                   pork scratchings    SN
# 415    17-693                             potato crisps, low fat    SN
# 416    17-060                                       sugar, brown    SC
# 417    17-062                                       sugar, icing    SC
# 418    17-063                                       sugar, white    SC
# 419    17-065                                      syrup, golden    SC
# 420    17-096                                smartie-type sweets   SEA
# 421       NaN                                      ackee, canned    DG
# 422    13-146                                        agar, dried    DG
# 423    13-148                               alfalfa sprouts, raw    DG
# 424    13-149                               amaranth leaves, raw    DG
# 425    13-151                                     arrowhead, raw    DG
# 426    13-153                              artichoke, globe, raw    DG
# 427       NaN                                  artichoke, canned    DG
# 428       NaN                                     artichoke, jar    DG
# 429    13-157                                     asparagus, raw    DG
# 430    13-161                                     aubergine, raw    DG
# 431    13-532                baked beans, canned in tomato sauce    DB
# 432    13-041                    beans, aduki, whole, dried, raw    DB
# 433       NaN                               beans, aduki, canned    DB
# 434    13-062                 beans, blackeye, whole, dried, raw    DB
# 435       NaN                            beans, blackeye, canned    DB
# 436    13-070                          beans, butter, dried, raw    DB
# 437       NaN                              beans, butter, canned    DB
# 438    13-074       beans, chick peas, kabuli, whole, dried, raw    DB
# 439       NaN                          beans, chick peas, canned    DB
# 440    13-080                                beans, cluster, raw    DB
# 441       NaN                             beans, edamame, frozen    DB
# 442       NaN                             beans, edamame, canned    DB
# 443    13-514                                  beans, green, raw    DB
# 444    13-086                  beans, haricot, whole, dried, raw    DB
# 445       NaN                             beans, haricot, canned    DB
# 446    13-098                      beans, mung, dahl, dried, raw    DB
# 447    13-102              beans, pigeon peas, whole, dried, raw    DB
# 448    13-106                           beans, pinto, dried, raw    DB
# 449       NaN                             beans, pinto, canned,     DB
# 450    13-109                      beans, red kidney, dried, raw    DB
# 451       NaN                          beans, red kidney, canned    DB
# 452    13-112                                 beans, runner, raw    DB
# 453    13-115                            beans, soya, dried, raw    DB
# 454    13-117                                  beans, sword, raw    DB
# 455    13-426                             beansprouts, mung, raw    DB
# 456    13-056           black gram, urad gram, whole, dried, raw    DB
# 457    13-164                                      beetroot, raw    DG
# 458    13-167                                    breadfruit, raw    DG
# 459    13-502                               broccoli, green, raw    DG
# 460    13-174                    broccoli, purple sprouting, raw    DG
# 461    13-177                              brussels sprouts, raw    DG
# 462       NaN                                 beanburger, retail    DR
# 463       NaN                             beanburger, vegetarian    DR
# 464    13-067                           beans, broad, dried, raw    DB
# 465       NaN                               beans, broad, canned    DB
# 466    13-064              beans, broad, whole, raw, without pod    DB
# 467       NaN                          beans, cannellini, canned    DB
# 468    13-582                              cabbage, average, raw    DG
# 469    13-187                              cabbage, chinese, raw    DG
# 470    13-510                                cabbage, green, raw    DG
# 471    13-190                                  cabbage, red, raw    DG
# 472    13-509                                cabbage, white, raw    DG
# 473    13-448                                carrots, young, raw    DG
# 474    13-512                                   cauliflower, raw    DG
# 475    13-219                                      celeriac, raw    DG
# 476    13-636                                        celery, raw    DG
# 477    13-223                                  chard, swiss, raw    DG
# 478    13-225                         chicory, pale variety, raw    DG
# 479    13-627                                     courgette, raw    DG
# 480    13-234                                    curly kale, raw    DG
# 481       NaN                       casserole, vegetable, retail    DR
# 482    15-637                         cauliflower cheese, retail    DR
# 483    15-635                  coleslaw, not low calorie, retail    DR
# 484       NaN                    curry, vegetable, mixed, canned    DR
# 485    13-244                                        garlic, raw    DG
# 486    13-245                                      gherkins, raw    DG
# 487    13-608                                 green beans, dried    DI
# 488       NaN                     green beans, in water, canned     DI
# 489    13-556                                            houmous    DB
# 490    13-258                                   horseradish, raw    DG
# 491    13-261                                     kohl rabi, raw    DG
# 492    15-809                                             khadhi    DR
# 493    13-089        lentils, green and brown, whole, dried, raw    DB
# 494       NaN                                    lentils, canned    DB
# 495    13-624                                         leeks, raw    DG
# 496    13-520                              lettuce, average, raw    DG
# 497    13-271                                  lotus tubers, raw    DG
# 498    15-651                         lasagne, vegetable, retail    DR
# 499    13-505                              mushrooms, white, raw    DG
# 500    13-298                                mustard leaves, raw    DG
# 501    15-652                        moussaka, vegetable, retail    DR
# 502    13-300                                          okra, raw    DG
# 503    13-499                                        onions, raw    DG
# 504       NaN                                          potatoes,    DA
# 505       NaN                                      potato chips,   DAP
# 506       NaN                            potato wedges, retail,    DAR
# 507       NaN                              peas, canned in water    DF
# 508    13-527                                  peas, frozen, raw    DF
# 509       NaN                                      pak choi, raw    DG
# 510    13-311                   papaya, unripe, green flesh, raw    DG
# 511    13-312                                       parsnip, raw    DG
# 512    13-524                         pepper, capsicum, red, raw    DG
# 513    13-323                         plantain, green flesh, raw    DG
# 514    13-326                           pumpkin, flesh only, raw    DG
# 515    15-262                                        quorn korma    DR
# 516    13-332                                 radish leaves, raw    DG
# 517    13-522                                        rocket, raw    DG
# 518    15-869                                   roulade, spinach    DR
# 519    13-521                                 spinach, baby, raw    DG
# 520    13-359                             swede, flesh only, raw    DG
# 521       NaN                          swede, raw,flesh and skin    DG
# 522    13-463                      sweet potato, raw, flesh only    DG
# 523       NaN                  sweet potato, raw, flesh and skin    DG
# 524       NaN                          sweetcorn kernels, canned    DG
# 525    13-622                            sweetcorn, kernels, raw    DG
# 526       NaN                                 sweetcorn on a cob    DG
# 527    15-872            salad, pasta, vegetables and mayonnaise    DR
# 528    15-883                          shepherd's pie, vegetable    DR
# 529    15-617                                   sushi, vegetable    DR
# 530       NaN                          vegetables, mixed, frozen    DG
# 531    15-656                        vegeburger, retail, grilled    DR
# 532       NaN                            vegetable stir fry mix,    DR
# 533    13-673                                    watercress, raw    DG
# 534    13-397                               yam, flesh only, raw    DG
#
#                                Super Group  \
# 0                      Alcoholic beverages
# 1                      Alcoholic beverages
# 2                      Alcoholic beverages
# 3                      Alcoholic beverages
# 4                      Alcoholic beverages
# 5                      Alcoholic beverages
# 6                      Alcoholic beverages
# 7                      Alcoholic beverages
# 8                                Beverages
# 9                                Beverages
# 10                               Beverages
# 11                               Beverages
# 12                               Beverages
# 13                               Beverages
# 14                               Beverages
# 15                               Beverages
# 16                               Beverages
# 17                               Beverages
# 18                               Beverages
# 19                               Beverages
# 20                               Beverages
# 21                               Beverages
# 22             Cereals and cereal products
# 23             Cereals and cereal products
# 24             Cereals and cereal products
# 25             Cereals and cereal products
# 26             Cereals and cereal products
# 27             Cereals and cereal products
# 28             Cereals and cereal products
# 29             Cereals and cereal products
# 30             Cereals and cereal products
# 31             Cereals and cereal products
# 32             Cereals and cereal products
# 33             Cereals and cereal products
# 34             Cereals and cereal products
# 35             Cereals and cereal products
# 36             Cereals and cereal products
# 37             Cereals and cereal products
# 38             Cereals and cereal products
# 39             Cereals and cereal products
# 40             Cereals and cereal products
# 41             Cereals and cereal products
# 42             Cereals and cereal products
# 43             Cereals and cereal products
# 44             Cereals and cereal products
# 45             Cereals and cereal products
# 46             Cereals and cereal products
# 47             Cereals and cereal products
# 48             Cereals and cereal products
# 49             Cereals and cereal products
# 50             Cereals and cereal products
# 51             Cereals and cereal products
# 52             Cereals and cereal products
# 53             Cereals and cereal products
# 54             Cereals and cereal products
# 55             Cereals and cereal products
# 56             Cereals and cereal products
# 57             Cereals and cereal products
# 58             Cereals and cereal products
# 59             Cereals and cereal products
# 60             Cereals and cereal products
# 61             Cereals and cereal products
# 62             Cereals and cereal products
# 63             Cereals and cereal products
# 64             Cereals and cereal products
# 65             Cereals and cereal products
# 66             Cereals and cereal products
# 67             Cereals and cereal products
# 68             Cereals and cereal products
# 69             Cereals and cereal products
# 70             Cereals and cereal products
# 71             Cereals and cereal products
# 72             Cereals and cereal products
# 73             Cereals and cereal products
# 74             Cereals and cereal products
# 75             Cereals and cereal products
# 76             Cereals and cereal products
# 77             Cereals and cereal products
# 78             Cereals and cereal products
# 79             Cereals and cereal products
# 80             Cereals and cereal products
# 81             Cereals and cereal products
# 82             Cereals and cereal products
# 83             Cereals and cereal products
# 84             Cereals and cereal products
# 85             Cereals and cereal products
# 86             Cereals and cereal products
# 87             Cereals and cereal products
# 88             Cereals and cereal products
# 89             Cereals and cereal products
# 90             Cereals and cereal products
# 91             Cereals and cereal products
# 92             Cereals and cereal products
# 93             Cereals and cereal products
# 94             Cereals and cereal products
# 95             Cereals and cereal products
# 96             Cereals and cereal products
# 97             Cereals and cereal products
# 98             Cereals and cereal products
# 99             Cereals and cereal products
# 100            Cereals and cereal products
# 101            Cereals and cereal products
# 102            Cereals and cereal products
# 103            Cereals and cereal products
# 104            Cereals and cereal products
# 105            Cereals and cereal products
# 106            Cereals and cereal products
# 107            Cereals and cereal products
# 108            Cereals and cereal products
# 109            Cereals and cereal products
# 110            Cereals and cereal products
# 111                                   Eggs
# 112                                   Eggs
# 113                          Fats and oils
# 114                          Fats and oils
# 115                          Fats and oils
# 116                          Fats and oils
# 117                          Fats and oils
# 118                          Fats and oils
# 119                          Fats and oils
# 120                 Fish and fish products
# 121                 Fish and fish products
# 122                 Fish and fish products
# 123                 Fish and fish products
# 124                 Fish and fish products
# 125                 Fish and fish products
# 126                 Fish and fish products
# 127                 Fish and fish products
# 128                 Fish and fish products
# 129                 Fish and fish products
# 130                 Fish and fish products
# 131                 Fish and fish products
# 132                 Fish and fish products
# 133                 Fish and fish products
# 134                 Fish and fish products
# 135                 Fish and fish products
# 136                 Fish and fish products
# 137                 Fish and fish products
# 138                 Fish and fish products
# 139                 Fish and fish products
# 140                 Fish and fish products
# 141                 Fish and fish products
# 142                 Fish and fish products
# 143                 Fish and fish products
# 144                 Fish and fish products
# 145                 Fish and fish products
# 146                 Fish and fish products
# 147                 Fish and fish products
# 148                 Fish and fish products
# 149                 Fish and fish products
# 150                 Fish and fish products
# 151                 Fish and fish products
# 152                 Fish and fish products
# 153                                  Fruit
# 154                                  Fruit
# 155                                  Fruit
# 156                                  Fruit
# 157                                  Fruit
# 158                                  Fruit
# 159                                  Fruit
# 160                                  Fruit
# 161                                  Fruit
# 162                                  Fruit
# 163                                  Fruit
# 164                                  Fruit
# 165                                  Fruit
# 166                                  Fruit
# 167                                  Fruit
# 168                                  Fruit
# 169                                  Fruit
# 170                                  Fruit
# 171                                  Fruit
# 172                                  Fruit
# 173                                  Fruit
# 174                                  Fruit
# 175                                  Fruit
# 176                                  Fruit
# 177                                  Fruit
# 178                                  Fruit
# 179                                  Fruit
# ...
# 310         NaN                                  chunk, small    FPS
# 311         NaN                               average serving    FPS
# 312         NaN                                 average slice    FPS
# 313         NaN                               average portion    FPS
# 314         NaN                               average portion    FPS
# 315           Y                                           Can    FPS
# 316         NaN                               average serving    FPS
# 317         NaN                               average serving    FPS
# 318         NaN                               average portion    FPS
# 319        Y, P                                      1 sachet    FPS
# 320         NaN                               average serving    FPS
# 321           N                                 average glass    FPS
# 322           Y                                        1 pint    FPS
# 323           Y                                        1 pint    FPS
# 324           Y                                        1 pint    FPS
# 325           Y                                        1 pint    FPS
# 326           Y                                        1 pint    FPS
# 327           Y                                        1 pint    FPS
# 328           Y                                        1 pint    FPS
# 329           Y                                        1 pint    FPS
# 330         NaN                                           NaN    FPS
# 331         NaN                           1 heaped tablespoon    FPS
# 332           Y                                           NaN    FPS
# 333           Y                                           NaN    FPS
# 334           Y                                        1 pint    FPS
# 335         NaN                                       6 whole    FPS
# 336         NaN                                       6 whole    FPS
# 337         NaN                                       6 whole    FPS
# 338         NaN                                       1 dried    FPS
# 339         NaN                                       3 whole    FPS
# 340         NaN                                       5 whole    FPS
# 341           Y                                        1 pint    FPS
# 342         NaN                                      10 whole    FPS
# 343         NaN                                   6, no shell    FPS
# 344         NaN                                          each    FPS
# 345           Y                                       per bag    FPS
# 346         NaN                   thickly spread on one slice    FPS
# 347         NaN                                          each    FPS
# 348         NaN                              10, kernels only    FPS
# 349
# 350         NaN                                  1 tablespoon    FPS
# 351         NaN                                      6 halves    FPS
# 352         NaN                               average portion    FPS
# 353         NaN                               average portion    FPS
# 354         NaN                              1 level teaspoon    FPS
# 355           Y                     1 small carton (5 fi. oz)    FPS
# 356         NaN                                           NaN    FPS
# 357         NaN                                       1 small    FPS
# 358         NaN                                       1 small    FPS
# 359           Y                     1 small carton (5 fi. oz)    FPS
# 360         NaN                                  1 tablespoon    FPS
# 361         NaN                      1 salad, average portion    FPS
# 362         NaN                                  1 tablespoon    FPS
# 363
# 364
# 365         NaN                        small, average portion    FPS
# 366         NaN                                    1 teaspoon    FPS
# 367         NaN                                    1 teaspoon    FPS
# 368         NaN                               average portion    FPS
# 369         NaN                              1 level teaspoon    FPS
# 370         NaN                                  1 tablespoon    FPS
# 371         NaN                             I heaped teaspoon    FPS
# 372
# 373         NaN                                     in burger    FPS
# 374         NaN                         small average portion    FPS
# 375           Y                     1 small carton (5 fi. oz)    FPS
# 376           Y                     1 small carton (5 fi. oz)    FPS
# 377         NaN                         small average portion    FPS
# 378         NaN                         small average portion    FPS
# 379         NaN                         small average portion    FPS
# 380         NaN                         small average portion    FPS
# 381         NaN                               average portion    FPS
# 382           Y                                           NaN    FPS
# 383           Y                     1 small carton (5 fi. oz)    FPS
# 384         NaN                               average portion    FPS
# 385         NaN                                    1 teaspoon    FPS
# 386         NaN                              1 level teaspoon    FPS
# 387         NaN                                      Knort, 1    FPS
# 388         NaN                                      Knort, 1    FPS
# 389         NaN                                    individual    FPS
# 390         NaN                                    1 teaspoon    FPS
# 391         NaN                                           NaN    FPS
# 392         NaN                                    1 teaspoon    FPS
# 393         NaN                                    1 teaspoon    FPS
# 394
# 395         NaN                                           NaN    FPS
# 396         NaN       1 average spreading on 1 slice of bread    FPS
# 397         NaN                                    individual    FPS
# 398           Y                                           NaN    FPS
# 399           Y                                       per bag    FPS
# 400
# 401
# 402           N                                           NaN    FPS
# 403         NaN                                         1 raw    FPS
# 404         NaN                                        1 cube    FPS
# 405           Y                                           box    FPS
# 406         NaN       1 average spreading on 1 slice of bread    FPS
# 407           Y                                    family bag    FPS
# 408           Y                                      kingsize    FPS
# 409           Y                                          pots    FPS
# 410         NaN                                          each    FPS
# 411           Y                                           bar    FPS
# 412         NaN                              1 level teaspoon    FPS
# 413         NaN                                caramel coated    FPS
# 414           Y                                       per bag    FPS
# 415           Y                                         small    FPS
# 416         NaN                                        1 cube    FPS
# 417         NaN                                        1 cube    FPS
# 418         NaN                                        1 cube    FPS
# 419           Y                                         large    FPS
# 420         NaN                                          each    FPS
# 421         NaN                           average slice, thin    FPS
# 422         NaN                                       1 dried    FPS
# 423
# 424
# 425
# 426         NaN               one globe heart, edible portion    FPS
# 427         NaN               one globe heart, edible portion    FPS
# 428         NaN               one globe heart, edible portion    FPS
# 429         NaN                                      5 spears    FPS
# 430         NaN                           half including skin    FPS
# 431         NaN                 average, with meatifishlpasta    FPS
# 432         NaN                                 2 tablespoons    FPS
# 433         NaN                           average slice, thin    FPS
# 434         NaN                                 2 tablespoons    FPS
# 435         NaN                           average slice, thin    FPS
# 436         NaN                                 2 tablespoons    FPS
# 437         NaN                           average slice, thin    FPS
# 438         NaN                               average portion    FPS
# 439         NaN                               average portion    FPS
# 440           N                               (all varieties)    FPS
# 441         NaN                                      fun size    FPS
# 442         NaN                           average slice, thin    FPS
# 443           Y                                       per bag    FPS
# 444         NaN                                 2 tablespoons    FPS
# 445         NaN                           average slice, thin    FPS
# 446         NaN                                 2 tablespoons    FPS
# 447         NaN                        average portion, small    FPS
# 448         NaN                                 2 tablespoons    FPS
# 449         NaN                           average slice, thin    FPS
# 450         NaN                           1 heaped tablespoon    FPS
# 451         NaN                           1 heaped tablespoon    FPS
# 452         NaN                                 small portion    FPS
# 453         NaN                                 2 tablespoons    FPS
# 454         NaN                                 2 tablespoons    FPS
# 455         NaN                                  1 tablespoon    FPS
# 456         NaN                                       1 dried    FPS
# 457         NaN                                 1 small whole    FPS
# 458
# 459         NaN                                medium portion    FPS
# 460
# 461         NaN                    average serving, 9 sprouts    FPS
# 462           Y                                           NaN    FPS
# 463           Y                                           NaN    FPS
# 464         NaN                                 2 tablespoons    FPS
# 465         NaN                                 2 tablespoons    FPS
# 466         NaN                                 2 tablespoons    FPS
# 467         NaN                           average slice, thin    FPS
# 468         NaN                             1/6 small cabbage    FPS
# 469         NaN                             1/6 small cabbage    FPS
# 470         NaN                             1/6 small cabbage    FPS
# 471         NaN                             1/6 small cabbage    FPS
# 472         NaN                             1/6 small cabbage    FPS
# 473         NaN                                  a few slices    FPS
# 474         NaN                                      I floret    FPS
# 475
# 476         NaN                                       1 stick    FPS
# 477         NaN                                           NaN    FPS
# 478
# 479         NaN                                 small portion    FPS
# 480         NaN                                           NaN    FPS
# 481         NaN                         small average portion    FPS
# 482         NaN                    average portion, main dish    FPS
# 483         NaN                                  1 tablespoon    FPS
# 484         NaN                    1 serving, 3-4 tablespoons    FPS
# 485           Y                                       1 slice    FPS
# 486
# 487         NaN                                 2 tablespoons    FPS
# 488         NaN                           average slice, thin    FPS
# 489         NaN                                          each    FPS
# 490           Y                                      1 sachet    FPS
# 491
# 492
# 493         NaN                                     (20z raw)    FPS
# 494         NaN                                     (20z raw)    FPS
# 495         NaN                               average serving    FPS
# 496         NaN                                4 small leaves    FPS
# 497
# 498         NaN                               average portion    FPS
# 499         NaN                                       1 small    FPS
# 500         NaN                              1 level teaspoon    FPS
# 501         NaN                    1 serving, 3-4 tablespoons    FPS
# 502         NaN                                         1 raw    FPS
# 503         NaN                                       1 small    FPS
# 504         NaN                                         small    FPS
# 505         NaN                                           NaN    FPS
# 506
# 507         NaN                        average portion, small    FPS
# 508         NaN                        average portion, small    FPS
# 509
# 510
# 511         NaN                        average portion, small    FPS
# 512         NaN                              1 level teaspoon    FPS
# 513         NaN                                       1 whole    FPS
# 514         NaN                                      1/2, raw    FPS
# 515
# 516         NaN                                     1 average    FPS
# 517
# 518         NaN                               average serving    FPS
# 519         NaN                               average serving    FPS
# 520         NaN                                      1/2, raw    FPS
# 521         NaN                                     1 average    FPS
# 522         NaN                                      1/2, raw    FPS
# 523         NaN                                     1 average    FPS
# 524         NaN                               average portion    FPS
# 525         NaN                               average portion    FPS
# 526         NaN                               average portion    FPS
# 527         NaN                                  1 tablespoon    FPS
# 528         NaN                    1 serving, 3-4 tablespoons    FPS
# 529         NaN                                           NaN    FPS
# 530         NaN                               average serving    FPS
# 531         NaN                                average, fried    FPS
# 532         NaN                    1 serving, 3-4 tablespoons    FPS
# 533         NaN                            quarter of a bunch    FPS
# 534         NaN                                      1/2, raw    FPS

# %%
c = redFood3.loc[redFood3['Weight'] != '']
c['Food Name'].value_counts().sum()
# Out:
# 464

# %% [markdown]
# ### 94 / 535 items Matched Using Algo 3

# %%
f'Third Algorithm Matched {round((464/535) * 100, 2)}% of products between McCane and Widdowson df and Food Portion Sizes df. Contains some errors'
# Out:
# 'Third Algorithm Matched 86.73% of products between McCane and Widdowson df and Food Portion Sizes df. Contains some errors'

# %% [markdown]
# Exporting Updated dataframe

# %%
#redFood.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\ReducedwithWeights\RedM&Weight.csv')

# %% [markdown]
#                                             Visualising Matching Efficiency

# %%
counts = ReducedM.groupby('Super Group')['Super Group'].count().sort_values(ascending=True)

min_count = counts.min()

# Create a list of colors for the bars
bar_colors = ['teal' if count != min_count else 'red' for i, count in enumerate(counts)]

counts.plot.barh(color=bar_colors)
plt.title('Evaluation of Initial Mathcing Output', fontsize=13)

plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(1, 2, sharex=False, sharey=True) 
fig.set_size_inches(18,7)

ax1.plot(range(2,8), scores , 'bo-')
ax1.set_title('Silhouette Score - Filtered dataset (1225270)', loc='center')
ax1.set_xlim(1,8)

ax2.plot(range(2,10), scores1 , 'bo-')
ax2.set_title('Silhouette Score - Full Dataset')
ax2.set_xlim(1,10)

fig.supxlabel("K") 
fig.supylabel("Silhouette Score")
plt.show()

# %% [markdown]
#                                                   NEXT NOTEBOOK

# %% [markdown]
#                                         Importing Retail Data With Weights
#
#
# To testing algorithm again I'm using an Update list of retail matched data to match M&W dataframe and append all unmatched products to M&W dataframe.

# %%
RetailD = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Confidential\RetailSuperG.csv', index_col=0)
RetailD

# %%
RetailD.shape

# %% [markdown]
# ## Algo to Import products from Sainsbury's df to M&W df

# %%
# %%time
from fuzzywuzzy import fuzz

def match_food_retail(redFood, RetailD):
    """
    Matches food groups between two DataFrames using fuzzy matching and updates 
    redFood database with Weight and Unit from CleanRetail DataFrame.

    Args:
        CleanRetail (DataFrame): The DataFrame containing the clean retail data.
        redFood (DataFrame): The DataFrame containing the red food data.

    Returns:
        DataFrame: The red food DataFrame with updated items in RetailID that didn't match.
    """
    # Set a higher threshold for fuzzy matching.
    min_token_sort_ratio = 86

    # Create a list to store the SKU descriptions that have already been matched.
    matched_skus = []

    # Check similarity between the food names and SKU descriptions using fuzzy matching.
    for i, row in redFood.iterrows():
        product = redFood.loc[i, 'Food Name']
        matches = RetailD["SKUDesc"].apply(lambda x: fuzz.token_sort_ratio(x, product) >= min_token_sort_ratio)
        matched_skus.extend(matches[matches].index)

    # Filter the unmatched products based on the matched SKUs.
    unmatched_products_df = redFood[~redFood.index.isin(matched_skus)].copy()

    # Add unmatched retail data rows to unmatched_products_df with attached information.
    unmatched_retail_rows = RetailD[~RetailD.index.isin(matched_skus)].copy()
    unmatched_retail_rows["Unmatched Food Name"] = unmatched_retail_rows["SKUDesc"]
    unmatched_products_df = unmatched_products_df.append(unmatched_retail_rows)

    return unmatched_products_df


    unmatched_products_df = match_food_retail(redFood.copy(), RetailD.copy())

# %% [markdown]
# ##### Checking to see products added to M&W. Did some cleaning in Excel at this point.

# %%
unmatched_products_df

# %% [markdown]
# ##### Read in refined M&W-Sainsbury Retail df

# %%
RetailUM = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Confidential\RetdJoin.csv')

# %%
RetailUM.shape

# %% [markdown]
# ##### Correcting Sentence Case

# %%
RetailUM['Food Name'] = RetailUM['Food Name'].str.capitalize()
RetailUM

# %% [markdown]
# ##### Updating Data Source for all M&W Data

# %%
MnW = RetailUM[RetailUM['Source Data'].isna()]
MM = MnW[~MnW['Food Code'].isna()]
MM['Source Data'] = 'M&W Data'

# %%
RetailUM.update(MM)

# %%
RetailUM

# %% [markdown]
#                                                    Exprot Data

# %%
RetailUM.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Confidential\RetdJoin.csv')
