# %% [markdown]
# # Product Weighting Project

# %% [markdown]
#                                          Data Reduction - Food Purchased In Store

# %% [markdown]
# ###### Import Necessary Libraries

# %%
import pandas as pd

# %% [markdown]
# Read in Data

# %%
Labelled = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Labelling2021_watercress.csv')

# %% [markdown]
# ### Products beginning with a 'C'

# %%
Prod_C = Labelled.loc[Labelled['Food Name'].str.startswith('C')]
Prod_C.head()
# Out:
#     Food Code                                          Food Name  \
# 485    19-631  Cabbage leaves, stuffed with lamb and rice, ho...
# 486    13-581         Cabbage, average, boiled in unsalted water
# 487    13-582                              Cabbage, average, raw
# 488    13-187                              Cabbage, Chinese, raw
# 489    13-511           Cabbage, green, boiled in unsalted water
#
#                                            Description Group Previous  \
# 485                                             Recipe    MR  19-437
# 486                 Average of green and white cabbage    DG      NaN
# 487  Average of white (13-509) and green (13-510) c...    DG  13-468
# 488                 Base trimmed, outer leaves removed    DG      NaN
# 489                     As raw, boiled for 4-8 minutes    DG  13-444
#
#                                   Main data references Footnote Energy (kJ)  \
# 485                                       Updated 2014      NaN         415
# ...

# %% [markdown]
# Products within a Group (provide identification of the food group and food type to which the food belongs)

# %%
Prod_C.groupby('Group')['Food Name'].count()
# Out:
# Group
# AA      2
# AF      3
# AG      1
# AM      8
# AN     27
# AP      4
# AS      5
# AT      3
# BAR     1
# BH      9
# BJC     8
# BJP     2
# BJS     2
# BL     46
# BP      2
# BR     11
# BTM     1
# BV      1
# DG     43
# DI      1
# DR     99
# FA     14
# GA     10
# H      16
# J       3
# JA     27
# JK      6
# JM      3
# JR      8
# MCA    61
# MI      4
# MIG     1
# MR     52
# OE      1
# P       1
# PA      1
# PAA     3
# PAC    10
# PCA     2
# PE      1
# QC      4
# SC      2
# SEA     9
# SEC     1
# SN      1
# SNC     1
# WAC     1
# WC      2
# WCD     6
# WCG     2
# WE      2
# WY      1
# Name: Food Name, dtype: int64

# %% [markdown]
# ## *Reducing products based on its most basic form. Improve as you go on*

# %% [markdown]
#                                               Cereals and cereal products

# %% [markdown]
# Flours, grains and starches

# %%
AA = Prod_C.loc[Prod_C['Group']== 'AA']
AA
# Out:
#      Food Code         Food Name  \
# 852     11-011  Cornmeal, sifted
# 1012   11-1138    Custard powder
#
#                                             Description Group Previous  \
# 852                   Analytical and literature sources    AA      NaN
# 1012  Taken as cornflour (11-1045) except Na, Cl and Cu    AA      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 852   Wu Leung et al. (1968) Food composition table ...      NaN        1586
# 1012  LGC, Nutrient survey of flours and grains, 200...      NaN        1457
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 852            375      3.3          0.41             74.9        1.6
# 1012           343      0.7           0.1             83.6          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 852        73.3       3.9          9.4        0
# 1012       83.6         0          0.6     0.95

# %%
AA['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\2826330813.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AA['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Breads

# %%
AF = Prod_C.loc[Prod_C['Group']== 'AF']
AF
# Out:
#     Food Code                        Food Name  \
# 579    11-987  Chapatis, made with fat, retail
# 580    11-459       Chapatis, made without fat
# 907   11-1009             Currant buns, retail
#
#                                Description Group        Previous  \
# 579                              6 samples    AF         11-458
# 580         Analysed and calculated values    AF  11-075 50-036
# 907  9 samples, 5 supermarkets, 3 bakeries    AF         11-536
#
#                                   Main data references Footnote Energy (kJ)  \
# 579  MW4, 1978; and industry data, 2013. Selenium f...      NaN        1390
# 580  Data from MW5 with selenium data from SAC Anal...      NaN         908
# 907  LGC, Nutrient analysis of bread and morning go...      NaN        1218
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 579           331     12.8          1.56               44        1.7
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_AF = AF.loc[AF['Food Name'] == 'Chapatis, made with fat, retail']
Filt_AF
# Out:
#     Food Code                        Food Name Description Group Previous  \
# 579    11-987  Chapatis, made with fat, retail   6 samples    AF  11-458
#
#                                   Main data references Footnote Energy (kJ)  \
# 579  MW4, 1978; and industry data, 2013. Selenium f...      NaN        1390
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 579           331     12.8          1.56               44        1.7
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 579       42.3       2.2          8.9     0.75

# %%
Filt_AF['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\2620942196.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AF['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Rolls

# %%
AG = Prod_C.loc[Prod_C['Group']== 'AG']
AG
# Out:
#     Food Code   Food Name           Description Group Previous  \
# 892    11-988  Croissants  10 samples, 7 brands    AG  11-480
#
#                                   Main data references Footnote Energy (kJ)  \
# 892  LGC, Nutrient analysis of bread and morning go...      NaN        1589
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 892           380     19.7          9.76             39.7        5.2
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 892       34.5       3.1          9.4     0.83

# %%
AG['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\2401441672.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AG['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Biscuits

# %%
AM = Prod_C.loc[Prod_C['Group']== 'AM']
AM
# Out:
#     Food Code                                          Food Name  \
# 497    11-916                                         Cake rusks
# 577    11-819  Cereal bars, with fruit and/or nuts, no chocol...
# 578    11-818  Cereal bars, with fruit and/or nuts, with choc...
# 593    11-824                       Cheese straws/twists, retail
# 749    11-812                    Chocolate covered wafer biscuit
# 870   11-1134                      Crackers, wholemeal, homemade
# 874    11-820                                     Cream crackers
# 891    11-822                                    Crispbread, rye
#
#                                            Description Group        Previous  \
# 497  South Asian sweet bread, 6 samples, ethnic foo...    AM             NaN
# 577  5 samples, 5 products, including Jordan's frus...    AM  17-103 17-494
# 578  5 samples, 4 products, including Cadbury Brunc...    AM  17-103 17-494
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_AM = ['Cake rusks','Cereal bars, with fruit and/or nuts, no chocolate, unfortified','Cheese straws/twists, retail','Cream crackers','Crispbread, rye']

# %%
Filt_AM = AM[AM['Food Name'].isin(Priority_AM)]
Filt_AM
# Out:
#     Food Code                                          Food Name  \
# 497    11-916                                         Cake rusks
# 577    11-819  Cereal bars, with fruit and/or nuts, no chocol...
# 593    11-824                       Cheese straws/twists, retail
# 874    11-820                                     Cream crackers
# 891    11-822                                    Crispbread, rye
#
#                                            Description Group        Previous  \
# 497  South Asian sweet bread, 6 samples, ethnic foo...    AM             NaN
# 577  5 samples, 5 products, including Jordan's frus...    AM  17-103 17-494
# 593  10 samples, 7 products, including cheese straw...    AM             NaN
# 874                             10 samples, 6 products    AM         11-510
# 891  5 samples, 2 products, Ryvita original and Ryv...    AM         11-511
#
#                                   Main data references Footnote Energy (kJ)  \
# ...

# %%
Filt_AM['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\1616565383.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AM['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Cakes

# %%
AN = Prod_C.loc[Prod_C['Group']== 'AN']
AN
# Out:
#     Food Code                                          Food Name  \
# 496    11-740                               Cake bars, chocolate
# 498    11-835                           Cake, battenberg, retail
# 499    11-836                         Cake, carrot, iced, retail
# 500   11-1041               Cake, carrot, with topping, homemade
# 501   11-1044                             Cake, cherry, homemade
# 502    11-527                              Cake, chocolate fudge
# 503   11-1046              Cake, chocolate, not filled, homemade
# 504   11-1047       Cake, chocolate, with butter icing, homemade
# 505    11-830    Cake, chocolate, with filling and icing, retail
# 506   11-1053                            Cake, coconut, homemade
# 507    11-829                                Cake, fruit, retail
# 508   11-1005                        Cake, fruit, rich, homemade
# 509    11-991                  Cake, fruit, rich, iced, homemade
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_AN = ['Cake, sponge, soft iced, retail','Cakes, fancy iced, individual, retail',"Cakes from 'healthy eating' ranges"]

# %%
Filt_AN = AN[AN['Food Name'].isin(Priority_AN)]
Filt_AN
# Out:
#     Food Code                              Food Name  \
# 515    11-832        Cake, sponge, soft iced, retail
# 521    11-840     Cakes from 'healthy eating' ranges
# 523    11-839  Cakes, fancy iced, individual, retail
#
#                                            Description Group Previous  \
# 515  10 samples, 8 products, including angel cake, ...    AN      NaN
# 521  10 samples, 7 products, including carrot, lemo...    AN      NaN
# 523  10 samples, 8 products, including French and f...    AN      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 515  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1563
# 521  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1121
# 523  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1616
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 515           373     15.8          6.21             51.7       37.1
# ...

# %%
Filt_AN['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\569209402.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AN['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Buns and pastries

# %%
AP = Prod_C.loc[Prod_C['Group']== 'AP']
AP
# Out:
#     Food Code               Food Name                            Description  \
# 641   11-1043  Chelsea buns, homemade       Recipe. Ref. Wiles et al. (1980)
# 759   11-1050    Choux buns, homemade                                 Recipe
# 902    11-989       Crumpets, toasted                              9 samples
# 908    11-948   Currant buns, toasted  Calculated using a weight loss of 10%
#
#     Group Previous                               Main data references  \
# 641    AP  11-588   Based on Flour Milling and Baking Research Ass...
# 759    AP  11-653   Based on recipe as proportions in shop bought ...
# 902    AP  11-535   LGC, Nutrient analysis of bread and morning go...
# 908    AP      NaN  LGC, Nutrient analysis of bread and morning go...
#
#     Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 641      NaN        1532           364     12.5          4.08
# 759      NaN        1641           396     34.1         18.23
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_AP = AP.loc[AP['Food Name'] == 'Crumpets, toasted']
Filt_AP
# Out:
#     Food Code          Food Name Description Group Previous  \
# 902    11-989  Crumpets, toasted   9 samples    AP  11-535
#
#                                   Main data references Footnote Energy (kJ)  \
# 902  LGC, Nutrient analysis of bread and morning go...      NaN         894
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 902           211      1.0           0.1             41.5          3
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 902       38.5       3.1          7.5     2.57

# %%
Filt_AP['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\739656524.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AP['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Puddings

# %%
AS = Prod_C.loc[Prod_C['Group']== 'AS']
AS
# Out:
#     Food Code                            Food Name  \
# 893   11-1055             Crumble, apple, homemade
# 894   11-1056             Crumble, fruit, homemade
# 895   11-1020               Crumble, fruit, retail
# 896    11-994  Crumble, fruit, wholemeal, homemade
# 901   11-1057  Crumble, with pie filling, homemade
#
#                                            Description Group Previous  \
# 893                                             Recipe    AS  11-694
# 894  Recipe, apple, plum, gooseberry, rhubarb, home...    AS  11-695
# 895  10 samples, including apple, apple and blackbe...    AS  11-546
# 896           Apple, gooseberry, plum, rhubarb recipe.    AS  11-595
# 901                                             Recipe    AS  11-693
#
#                                   Main data references Footnote Energy (kJ)  \
# 893                                       Updated 2014      NaN         851
# 894                                       Updated 2014      NaN         848
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_AS = AS.loc[AS['Food Name'] == 'Crumble, fruit, retail']
Filt_AS
# Out:
#     Food Code               Food Name  \
# 895   11-1020  Crumble, fruit, retail
#
#                                            Description Group Previous  \
# 895  10 samples, including apple, apple and blackbe...    AS  11-546
#
#                                   Main data references Footnote Energy (kJ)  \
# 895  ADAS Laboratories, Nutrient analysis of ice cr...      NaN         958
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 895           228      8.3          3.97             34.1       21.2
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 895       12.7       2.3          2.4     0.21

# %%
Filt_AS['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\346938166.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AS['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Savouries

# %%
AT = Prod_C.loc[Prod_C['Group']== 'AT']
AT
# Out:
#     Food Code                               Food Name  \
# 583    11-997  Cheese and onion rolls, pastry, retail
# 863    11-902                 Couscous, plain, cooked
# 864    11-901                    Couscous, plain, raw
#
#                       Description Group Previous  \
# 583   Oven-baked pastry, 3 brands    AT  11-550
# 863  8 samples, 8 products, wheat    AT      NaN
# 864  8 samples, 8 products, wheat    AT      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 583  RHM, Nutrient analysis of manufactured foods f...      NaN        1379
# 863                       Calculated from raw (11-901)      NaN         769
# 864      LGC Nutrient survey of flours and grains 2005      NaN        1554
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 583           331     20.0          8.97               28          3
# 863           181      1.0          0.18             34.1          1
# ...

# %% [markdown]
# **Reduced**

# %%
Remove_AT = ['Couscous, plain, cooked']

# %%
Filt_AT = AT[~AT['Food Name'].isin(Remove_AT)]
Filt_AT
# Out:
#     Food Code                               Food Name  \
# 583    11-997  Cheese and onion rolls, pastry, retail
# 864    11-901                    Couscous, plain, raw
#
#                       Description Group Previous  \
# 583   Oven-baked pastry, 3 brands    AT  11-550
# 864  8 samples, 8 products, wheat    AT      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 583  RHM, Nutrient analysis of manufactured foods f...      NaN        1379
# 864      LGC Nutrient survey of flours and grains 2005      NaN        1554
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 583           331     20.0          8.97               28          3
# 864           367      2.1           0.3               72        2.1
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 583         22       2.9          8.2     0.78
# 864       69.9       3.7         13.1     0.01

# %%
Filt_AT['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\2561790092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AT['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
#                                                   Milk and milk products

# %% [markdown]
# Processed milks

# %%
BAR = Prod_C.loc[Prod_C['Group']== 'BAR']
BAR
# Out:
#     Food Code                    Food Name  \
# 818    12-546  Coffeemate, whitener powder
#
#                                       Description Group Previous  \
# 818  Analysis and manufacturer's data (Carnation)   BAR  12-027
#
#                                   Main data references Footnote Energy (kJ)  \
# 818  Milk Products and Eggs Supplement, 1989; Vitam...      NaN        2222
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 818           533     34.5            26             53.5        9.2
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 818          0         0          2.1        1

# %%
BAR['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\1916122628.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BAR['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Milk-based drinks

# %%
BH = Prod_C.loc[Prod_C['Group']== 'BH']
BH
# Out:
#     Food Code                                          Food Name  \
# 778    12-545                                       Cocoa powder
# 779    12-563       Cocoa powder, made up with semi-skimmed milk
# 780    12-564            Cocoa powder, made up with skimmed milk
# 781    12-565              Cocoa powder, made up with whole milk
# 832    12-566        Complan powder, savoury, made up with water
# 833    12-568  Complan powder, sweet, made up with semi-skimm...
# 834    12-569   Complan powder, sweet, made up with skimmed milk
# 835    12-567          Complan powder, sweet, made up with water
# 836    12-570     Complan powder, sweet, made up with whole milk
#
#                                            Description Group Previous  \
# 778                               10 samples, 2 brands    BH  12-082
# 779  Recipe. Calculated from 4g powder, 4g sugar an...    BH  12-437
# 780  Recipe. Calculated from 4g powder, 4g sugar an...    BH  12-438
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_BH = BH.loc[BH['Food Name'] == 'Cocoa powder']
Filt_BH
# Out:
#     Food Code     Food Name           Description Group Previous  \
# 778    12-545  Cocoa powder  10 samples, 2 brands    BH  12-082
#
#                                   Main data references Footnote Energy (kJ)  \
# 778  MW4 (1978).  Additional data from 50-1050. Vit...      NaN        1617
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 778           390     21.7          12.8             10.5          0
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 778       10.5      30.4         23.1     0.09

# %%
Filt_BH['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\4223810532.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_BH['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Fresh creams (pasteurised)

# %%
BJC = Prod_C.loc[Prod_C['Group']== 'BJC']
BJC
# Out:
#     Food Code                                     Food Name  \
# 878    12-337           Cream, dairy, extra thick (24% fat)
# 881    12-592                         Cream, fresh, clotted
# 882    12-334  Cream, fresh, double, including Jersey cream
# 883    12-332                          Cream, fresh, single
# 884    12-333                        Cream, fresh, whipping
# 885    12-112                            Cream, half, fresh
# 889    12-335                       Creme fraiche, full fat
# 890    12-336                       Creme fraiche, half fat
#
#                                            Description Group  \
# 878  16 samples, 4 brands, average of summer and wi...   BJC
# 881                               17 samples, 3 brands   BJC
# 882   Average of 22 samples of summer and winter cream   BJC
# 883   Average of 22 samples of summer and winter cream   BJC
# 884   Average of 22 samples of summer and winter cream   BJC
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_BJC = ['Cream, fresh, clotted','Cream, fresh, single', 'Cream, fresh, whipping','Creme fraiche, half fat']

# %%
Filt_BJC = BJC[BJC['Food Name'].isin(Priority_BJC)]
Filt_BJC
# Out:
#     Food Code                Food Name  \
# 881    12-592    Cream, fresh, clotted
# 883    12-332     Cream, fresh, single
# 884    12-333   Cream, fresh, whipping
# 890    12-336  Creme fraiche, half fat
#
#                                           Description Group  \
# 881                              17 samples, 3 brands   BJC
# 883  Average of 22 samples of summer and winter cream   BJC
# 884  Average of 22 samples of summer and winter cream   BJC
# 890                        8 samples, 6 brands, plain   BJC
#
#                    Previous  \
# 881                 12-117
# 883  12-113 12-842 50-212
# 884          12-115 50-214
# 890                     NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 881  Milk Products and Eggs Supplement, 1989. Iodin...      NaN        2413
# 883  Reviewed 2013. LGC, Nutrient analysis of ‘othe...      NaN         798
# 884  Reviewed 2013. LGC, Nutrient analysis of ‘othe...      NaN        1568
# ...

# %%
Filt_BJC['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\3990307707.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_BJC['Super Group'] = 'Milk and milk products'

# %% [markdown]
# UHT creams

# %%
BJP = Prod_C.loc[Prod_C['Group']== 'BJP']
BJP
# Out:
#     Food Code                                   Food Name  \
# 879    12-338  Cream, dairy, UHT, canned spray, 85% cream
# 880    12-339   Cream, dairy, UHT, half fat, canned spray
#
#                            Description Group                Previous  \
# 879               10 samples, 6 brands   BJP  12-124 12-844 50-218
# 880  4 samples, 1 brand (Anchor Light)   BJP                     NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 879  Reviewed 2013. LGC, Nutrient analysis of ‘othe...      NaN        1044
# 880  Reviewed 2013. LGC, Nutrient analysis of ‘othe...      NaN         810
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 879           253     24.2          15.2              6.9        6.9
# 880           196     17.3         10.87              7.2          7
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 879          0         0          1.9     0.08
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_BJP = BJP.loc[BJP['Food Name'] == 'Cream, dairy, UHT, half fat, canned spray']
Filt_BJP
# Out:
#     Food Code                                  Food Name  \
# 880    12-339  Cream, dairy, UHT, half fat, canned spray
#
#                            Description Group Previous  \
# 880  4 samples, 1 brand (Anchor Light)   BJP      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 880  Reviewed 2013. LGC, Nutrient analysis of ‘othe...      NaN         810
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 880           196     17.3         10.87              7.2          7
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 880          0         0          2.8     0.09

# %%
Filt_BJP['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\1807433135.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_BJP['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Imitation creams

# %%
BJS = Prod_C.loc[Prod_C['Group']== 'BJS']
BJS
# Out:
#     Food Code                 Food Name                  Description Group  \
# 876    12-342  Cream substitute, double  4 samples, including Elmlea   BJS
# 877    12-544  Cream substitute, single  5 samples, including Elmlea   BJS
#
#                   Previous                               Main data references  \
# 876  12-128 12-847 50-224   Reviewed 2013. LGC, Nutrient analysis of ‘othe...
# 877                12-340   LGC, Nutrient analysis of ‘other’ milk and cre...
#
#     Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 876      NaN        1424           346     35.7         24.34
# 877      NaN         655           158     14.5          9.19
#
#     Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 876              3.4        3.4          0       0.2          2.6     0.12
# 877              3.8        3.8          0       0.2          3.1     0.15

# %%
BJS['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\2995452898.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BJS['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Cheeses

# %%
BL = Prod_C.loc[Prod_C['Group']== 'BL']
BL
# Out:
#     Food Code                                       Food Name  \
# 591    12-540                            Cheese spread, plain
# 592    12-537               Cheese spread, plain, reduced fat
# 594    12-491                         Cheese, Brie, rind only
# 595    12-344           Cheese, Brie, with outer rind removed
# 596    12-132                              Cheese, Caerphilly
# 597    12-345                               Cheese, Camembert
# 598    12-548            Cheese, Cheddar type, '30% less fat'
# 599    12-348                  Cheese, Cheddar type, half fat
# 600    12-346                        Cheese, Cheddar, English
# 601    12-539                          Cheese, cottage, plain
# 602    12-550             Cheese, cottage, plain, reduced fat
# 603    12-354                             Cheese, Danish blue
# 604    12-152                                   Cheese, Derby
# 605    12-494                Cheese, Dolcelatte, rind removed
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_BL = ['Cheese spread, plain, reduced fat','Cheese, Cheddar, English','Cheese, cottage, plain, reduced fat','Cheese, Danish blue',
              'Cheese, goats milk, full fat, soft, white rind','Cheese, Mozzarella, fresh','Cheese, processed, slices, reduced fat','Cheese, White Cheshire']

# %%
Filt_BL = BL[BL['Food Name'].isin(Priority_BL)]
Filt_BL
# Out:
#     Food Code                                       Food Name  \
# 592    12-537               Cheese spread, plain, reduced fat
# 600    12-346                        Cheese, Cheddar, English
# 602    12-550             Cheese, cottage, plain, reduced fat
# 603    12-354                             Cheese, Danish blue
# 610    12-357  Cheese, goats milk, full fat, soft, white rind
# 617    12-360                       Cheese, Mozzarella, fresh
# 622    12-549          Cheese, processed, slices, reduced fat
# 636    12-486                          Cheese, White Cheshire
#
#                                            Description Group         Previous  \
# 592            13 samples, 9 brands, portions and tubs    BL          12-350
# 600  20 samples of English cheddar, including mild ...    BL  12-134 50-228
# 602                                         20 samples    BL          12-352
# 603                                         18 samples    BL   12-151 50-236
# ...

# %%
Filt_BL['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\41496511.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_BL['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Ice creams

# %%
BP = Prod_C.loc[Prod_C['Group']== 'BP']
BP
# Out:
#     Food Code                     Food Name            Description Group  \
# 751    12-518          Chocolate nut sundae                 Recipe    BP
# 849    12-507  Cornetto type ice cream cone  7 samples, 5 products    BP
#
#     Previous                               Main data references Footnote  \
# 751  12-411                                   Recalculated 2013      NaN
# 849  12-386   DH, Nutrient analysis of a range of processed ...      NaN
#
#     Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 751           N             N     15.0          8.94                N
# 849        1237           295     14.4         11.04             37.4
#
#     Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 751       29.4          N         N          2.7     0.09
# 849       26.7       10.6       1.2          3.5     0.23

# %% [markdown]
# **Reduced**

# %%
Filt_BP = BP.loc[BP['Food Name'] == 'Cornetto type ice cream cone']
Filt_BP
# Out:
#     Food Code                     Food Name            Description Group  \
# 849    12-507  Cornetto type ice cream cone  7 samples, 5 products    BP
#
#     Previous                               Main data references Footnote  \
# 849  12-386   DH, Nutrient analysis of a range of processed ...      NaN
#
#     Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 849        1237           295     14.4         11.04             37.4
#
#     Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 849       26.7       10.6       1.2          3.5     0.23

# %%
Filt_BP['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\4191555766.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_BP['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Puddings and chilled desserts

# %%
BR = Prod_C.loc[Prod_C['Group']== 'BR']
BR
# Out:
#      Food Code                                    Food Name  \
# 638     12-395                    Cheesecake, fruit, frozen
# 639     12-542                Cheesecake, fruit, individual
# 640     12-562                         Cheesecake, homemade
# 886     12-571                      Crème caramel, homemade
# 887     12-397                        Creme caramel, retail
# 1013    12-572                      Custard, confectioners'
# 1014    12-573                                 Custard, egg
# 1015    12-519      Custard, made up with semi-skimmed milk
# 1016    12-574           Custard, made up with skimmed milk
# 1017    12-575             Custard, made up with whole milk
# 1018    12-543  Custard, ready to eat, canned and tetra-pak
#
#                                             Description Group  \
# 638        10 samples, assorted flavours, fruit topping    BR
# 639   8 samples, 3 brands including strawberry, apri...    BR
# ...

# %%
BR['Food Name'].unique()
# Out:
# array(['Cheesecake, fruit, frozen', 'Cheesecake, fruit, individual',
#        'Cheesecake, homemade', 'Crème caramel, homemade',
#        'Creme caramel, retail', "Custard, confectioners'", 'Custard, egg',
#        'Custard, made up with semi-skimmed milk',
#        'Custard, made up with skimmed milk',
#        'Custard, made up with whole milk',
#        'Custard, ready to eat, canned and tetra-pak'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_BR = ['Cheesecake, fruit, individual','Creme caramel, retail','Custard, made up with semi-skimmed milk']

# %%
Filt_BR = BR[BR['Food Name'].isin(Priority_BR)]
Filt_BR
# Out:
#      Food Code                                Food Name  \
# 639     12-542            Cheesecake, fruit, individual
# 887     12-397                    Creme caramel, retail
# 1015    12-519  Custard, made up with semi-skimmed milk
#
#                                             Description Group  \
# 639   8 samples, 3 brands including strawberry, apri...    BR
# 887                                 9 samples, 4 brands    BR
# 1015                                             Recipe    BR
#
#                     Previous  \
# 639                  12-396
# 887   12-220 12-875 50-275
# 1015                 12-413
#
#                                    Main data references Footnote Energy (kJ)  \
# 639   Campden and Chorleywood FRA, Nutrient analysis...      NaN        1126
# 887   Reviewed 2013. Milk Products and Eggs Suppleme...      NaN           N
# 1015                                       Updated 2013      NaN         403
#
# ...

# %%
Filt_BR['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\3725017385.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_BR['Super Group'] = 'Milk and milk products'

# %% [markdown]
# BTM removed as I didn't think Cooking fat is a product

# %% [markdown]
# BV removed I think I have enough cheese products. Aim is to make it open enough to be updated by other entities

# %% [markdown]
#                                                        Vegetables

# %% [markdown]
# Vegetables, general

# %%
DG = Prod_C.loc[Prod_C['Group']== 'DG']
DG
# Out:
#     Food Code                                          Food Name  \
# 486    13-581         Cabbage, average, boiled in unsalted water
# 487    13-582                              Cabbage, average, raw
# 488    13-187                              Cabbage, Chinese, raw
# 489    13-511           Cabbage, green, boiled in unsalted water
# 490    13-510                                Cabbage, green, raw
# 491    13-540             Cabbage, red, boiled in unsalted water
# 493    13-190                                  Cabbage, red, raw
# 494    13-584           Cabbage, white, boiled in unsalted water
# 495    13-509                                Cabbage, white, raw
# 534    13-607                                       Carrot juice
# 535    13-497             Carrots, old, boiled in unsalted water
# 536    13-498                           Carrots, old, microwaved
# 537    13-496                                  Carrots, old, raw
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_DG = ['Cabbage, average, raw', 'Cabbage, Chinese, raw','Cabbage, green, raw','Cabbage, red, raw','Cabbage, white, raw',
              'Carrots, old, raw','Carrots, young, raw','Cauliflower, raw','Celeriac, raw','Celery, raw','Chard, Swiss, raw',
              'Chicory, pale variety, raw','Courgette, raw','Curly kale, raw']

# %%
Filt_DG = DG[DG['Food Name'].isin(Priority_DG)]
Filt_DG
# Out:
#     Food Code                   Food Name  \
# 487    13-582       Cabbage, average, raw
# 488    13-187       Cabbage, Chinese, raw
# 490    13-510         Cabbage, green, raw
# 493    13-190           Cabbage, red, raw
# 495    13-509         Cabbage, white, raw
# 537    13-496           Carrots, old, raw
# 540    13-448         Carrots, young, raw
# 570    13-512            Cauliflower, raw
# 573    13-219               Celeriac, raw
# 576    13-636                 Celery, raw
# 582    13-223           Chard, Swiss, raw
# 732    13-225  Chicory, pale variety, raw
# 860    13-627              Courgette, raw
# 906    13-234             Curly kale, raw
#
#                                            Description Group        Previous  \
# 487  Average of white (13-509) and green (13-510) c...    DG         13-468
# 488                 Base trimmed, outer leaves removed    DG             NaN
# 490  22 samples, autumn and winter, UK grown and im...    DG         13-468
# ...

# %%
Filt_DG['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\1311392366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DG['Super Group'] = 'Vegetables'

# %% [markdown]
# Vegetables, dried

# %%
DI = Prod_C.loc[Prod_C['Group']== 'DI']
DI
# Out:
#     Food Code         Food Name             Description Group Previous  \
# 856    13-668  Courgette, dried  Calculated from 13-627    DI   17-413
#
#                                   Main data references Footnote Energy (kJ)  \
# 856  PHE, Nutrient analysis of fresh and processed ...      NaN        1298
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 856           308      3.6           0.9               41       39.4
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 856        1.6         9         23.3        0

# %%
DI['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\2839694359.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DI['Super Group'] = 'Vegetables'

# %% [markdown]
# Vegetable Dishes

# %%
DR = Prod_C.loc[Prod_C['Group']== 'DR']
DR.head(20)
# Out:
#     Food Code                                          Food Name  \
# 492    15-705                    Cabbage, red, cooked with apple
# 525    15-706                     Callaloo and cho cho, homemade
# 526    15-707                        Callaloo and okra, homemade
# 527    15-708                      Cannelloni, spinach, homemade
# 528    15-709                    Cannelloni, vegetable, homemade
# 549    15-712      Casserole, bean and mixed vegetable, homemade
# 550    15-713       Casserole, bean and root vegetable, homemade
# 556    15-714  Casserole, sweet potato and green banana, home...
# 557    15-638                     Casserole, vegetable, homemade
# 561    15-639  Cauliflower cheese, made with semi-skimmed mil...
# 562    15-710  Cauliflower cheese, made with skimmed milk, ho...
# 563    15-711  Cauliflower cheese, made with whole milk, home...
# 564    15-637                         Cauliflower cheese, retail
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_DR = ['Casserole, vegetable, homemade','Cauliflower cheese, retail','Chilli, bean and lentil, homemade','Coleslaw, not low calorie, retail',
               'Curry, chick pea, UK type, homemade','Curry, egg, in sweet sauce, UK type, homemade', 'Curry, red kidney bean, Punjabi, homemade']

# %%
Filt_DR = DR[DR['Food Name'].isin(Priority_DR)]
Filt_DR
# Out:
#     Food Code                                      Food Name  \
# 557    15-638                 Casserole, vegetable, homemade
# 564    15-637                     Cauliflower cheese, retail
# 738    15-719              Chilli, bean and lentil, homemade
# 822    15-635              Coleslaw, not low calorie, retail
# 932    15-748            Curry, chick pea, UK type, homemade
# 953    15-752  Curry, egg, in sweet sauce, UK type, homemade
# 999    15-146      Curry, red kidney bean, Punjabi, homemade
#
#                                            Description Group Previous  \
# 557                 Recipe from dietary survey records    DR  15-368
# 564                           Recipe and industry data    DR      NaN
# 738                                             Recipe    DR  15-439
# 822                              8 samples, 7 products    DR      NaN
# 932                                             Recipe    DR  15-464
# ...

# %%
Filt_DR['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\2508077319.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DR['Super Group'] = 'Vegetables'

# %% [markdown]
#                                                         Fruit

# %% [markdown]
# Fruit General

# %%
FA = Prod_C.loc[Prod_C['Group']== 'FA']
FA
# Out:
#      Food Code                                          Food Name  \
# 541     14-060                           Cashew fruit, flesh only
# 642     14-382                      Cherries, flesh and skin, raw
# 643     14-383  Cherries, flesh and skin, raw, weighed with st...
# 644     14-335                                    Cherries, glace
# 645     14-063                        Cherries, stewed with sugar
# 646     14-064   Cherries, stewed with sugar, weighed with stones
# 647     14-065                     Cherries, stewed without sugar
# 648     14-066  Cherries, stewed without sugar, weighed with s...
# 649     14-069                  Cherries, West Indian, flesh only
# 772     14-326        Citrus fruit, soft/easy peelers, flesh only
# 773     14-348  Citrus fruit, soft/easy peelers, flesh only, w...
# 871     14-073                                        Cranberries
# 909     14-074                                           Currants
# ...

# %% [markdown]
# ##### Reduced

# %%
Priority_FA = ['Cherries, flesh and skin, raw','Citrus fruit, soft/easy peelers, flesh only','Cranberries', 'Currants',]

# %%
Filt_FA = FA[FA['Food Name'].isin(Priority_FA)]
Filt_FA
# Out:
#     Food Code                                    Food Name  \
# 642    14-382                Cherries, flesh and skin, raw
# 772    14-326  Citrus fruit, soft/easy peelers, flesh only
# 871    14-073                                  Cranberries
# 909    14-074                                     Currants
#
#                                            Description Group Previous  \
# 642                        11 samples, UK and imported    FA   14-061
# 772  22 samples, early and late winter, including c...    FA      NaN
# 871       Analysis and literature sources; whole fruit    FA      NaN
# 909                               10 samples, 9 brands    FA  50-883
#
#                                   Main data references Footnote Energy (kJ)  \
# 642  PHE, Nutrient analysis of fresh and processed ...      NaN         310
# 772  DH, Nutrient analysis of fruit and vegetables,...      NaN         206
# 871                    Fruit and Nuts Supplement, 1992      NaN         122
# ...

# %%
Filt_FA['Super Group'] = 'Fruit'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\3797725470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_FA['Super Group'] = 'Fruit'

# %% [markdown]
#                                                     Nuts and Seeds

# %% [markdown]
# Nuts and seeds, general

# %%
GA = Prod_C.loc[Prod_C['Group']== 'GA']
GA
# Out:
#     Food Code                                         Food Name  \
# 542    14-811                   Cashew nuts, kernel only, plain
# 543    14-812      Cashew nuts, kernel only, roasted and salted
# 651    14-815                                  Chestnuts, dried
# 652    14-813                       Chestnuts, kernel only, raw
# 653    14-814  Chestnuts, kernel only, raw, weighed with shells
# 783    14-820                                      Coconut milk
# 784    14-890                 Coconut milk, reduced fat, retail
# 785    14-889                              Coconut milk, retail
# 786    14-873                               Coconut, desiccated
# 787    14-816                        Coconut, flesh only, fresh
#
#                                            Description Group        Previous  \
# 542               20 samples, whole and broken kernels    GA             NaN
# 543                           10 samples, kernels only    GA         50-976
# ...

# %%
GA['Food Name'].unique()
# Out:
# array(['Cashew nuts, kernel only, plain',
#        'Cashew nuts, kernel only, roasted and salted', 'Chestnuts, dried',
#        'Chestnuts, kernel only, raw',
#        'Chestnuts, kernel only, raw, weighed with shells', 'Coconut milk',
#        'Coconut milk, reduced fat, retail', 'Coconut milk, retail',
#        'Coconut, desiccated', 'Coconut, flesh only, fresh'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_GA = ['Chestnuts, kernel only, raw','Coconut milk, retail',]

# %%
Filt_GA = GA[GA['Food Name'].isin(Priority_GA)]
Filt_GA
# Out:
#     Food Code                    Food Name                      Description  \
# 652    14-813  Chestnuts, kernel only, raw  Analysis and literature sources
# 785    14-889         Coconut milk, retail   Estimated from 2013 label data
#
#     Group Previous                            Main data references Footnote  \
# 652    GA  50-977   Reviewed 2013. Fruit and Nuts Supplement, 1992      NaN
# 785    GA                                      Industry data, 2013      NaN
#
#     Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 652         764           181      2.7           0.5             33.6
# 785         696           169     16.9         14.64              2.7
#
#     Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 652        6.7       26.9       6.8          2.3     0.03
# 785        1.5        1.2       0.4          1.3        0

# %%
Filt_GA['Super Group'] = 'Nuts and Seeds'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\3953553267.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_GA['Super Group'] = 'Nuts and Seeds'

# %% [markdown]
#                                                    Herbs and Spices

# %%
H = Prod_C.loc[Prod_C['Group']== 'H']
H
# Out:
#     Food Code                     Food Name                   Description  \
# 530    13-808                 Caraway seeds            Literature sources
# 532    13-809              Cardamom, ground            Literature sources
# 574    13-810                  Celery seeds            Literature sources
# 650    13-811                Chervil, dried            Literature sources
# 736    13-873                 Chilli powder            Literature sources
# 741    13-813               Chinese 5 spice        Calculated from recipe
# 743    13-887                 Chives, fresh            Literature sources
# 771    13-874              Cinnamon, ground            Literature sources
# 774    13-816                 Cloves, dried            Literature sources
# 841    13-818       Coriander leaves, dried            Literature sources
# 842    13-888       Coriander leaves, fresh            Literature sources
# 843    13-875               Coriander seeds            Literature sources
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_H = ['Caraway seeds', 'Cardamom, ground', 'Celery seeds',
       'Chervil, dried', 'Chilli powder', 'Chinese 5 spice',
       'Chives, fresh', 'Cinnamon, ground', 'Cloves, dried',
       'Coriander leaves, dried','Cumin seeds','Curry powder']

# %%
Filt_H = H[H['Food Name'].isin(Priority_H)]
Filt_H
# Out:
#     Food Code                Food Name             Description Group Previous  \
# 530    13-808            Caraway seeds      Literature sources     H      NaN
# 532    13-809         Cardamom, ground      Literature sources     H      NaN
# 574    13-810             Celery seeds      Literature sources     H      NaN
# 650    13-811           Chervil, dried      Literature sources     H      NaN
# 736    13-873            Chilli powder      Literature sources     H  13-812
# 741    13-813          Chinese 5 spice  Calculated from recipe     H      NaN
# 743    13-887            Chives, fresh      Literature sources     H  13-814
# 771    13-874         Cinnamon, ground      Literature sources     H  13-815
# 774    13-816            Cloves, dried      Literature sources     H      NaN
# 841    13-818  Coriander leaves, dried      Literature sources     H      NaN
# 904    13-889              Cumin seeds      Literature sources     H  13-820
# ...

# %%
Filt_H['Super Group'] = 'Herbs and Spices'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\854041242.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_H['Super Group'] = 'Herbs and Spices'

# %% [markdown]
#                                                    Fish and Fish Products

# %%
J = Prod_C.loc[Prod_C['Group']== 'J']
J
# Out:
#     Food Code                                         Food Name  \
# 802    16-428  Cod, in batter, fried in sunflower oil, takeaway
# 956    16-462  Curry, fish and vegetable, Bangladeshi, homemade
# 993    16-457               Curry, prawn and mushroom, homemade
#
#                                            Description Group Previous  \
# 802                  Calculated from 16-368 and 16-024     J  16-024
# 956  Recipe, containing boal, hilsa, mackerel, rohu...     J  16-348
# 993                                             Recipe     J  16-351
#
#                                   Main data references Footnote Energy (kJ)  \
# 802  DH, Nutrient analysis of fish and fish product...      NaN         998
# 956                                       Updated 2014      NaN         501
# 993                                       Updated 2014      NaN         688
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# ...

# %%
J['Food Name'].unique()
# Out:
# array(['Cod, in batter, fried in sunflower oil, takeaway',
#        'Curry, fish and vegetable, Bangladeshi, homemade',
#        'Curry, prawn and mushroom, homemade'], dtype=object)

# %%
Filt_J = J.loc[J['Food Name'] == 'Cod, in batter, fried in sunflower oil, takeaway']
Filt_J
# Out:
#     Food Code                                         Food Name  \
# 802    16-428  Cod, in batter, fried in sunflower oil, takeaway
#
#                            Description Group Previous  \
# 802  Calculated from 16-368 and 16-024     J  16-024
#
#                                   Main data references Footnote Energy (kJ)  \
# 802  DH, Nutrient analysis of fish and fish product...      NaN         998
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 802           239     14.7          1.72              9.7        0.9
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 802        8.8       0.5         16.8     0.44

# %%
Filt_J['Super Group'] = 'Fish and Fish Products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\3707995785.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_J['Super Group'] = 'Fish and Fish Products'

# %% [markdown]
# White Fish

# %%
JA = Prod_C.loc[Prod_C['Group']== 'JA']
JA
# Out:
#     Food Code                                          Food Name  \
# 533    16-172                                          Carp, raw
# 558    16-008                       Catfish, flesh only, steamed
# 559    16-009   Catfish, flesh only, steamed, weighed with bones
# 560    16-007                                       Catfish, raw
# 742    16-011                                        Chital, raw
# 788    16-490                         Cod, dried, salted, boiled
# 789    16-373                             Cod, flesh only, baked
# 790    16-465  Cod, flesh only, baked, weighed with bones and...
# 791    16-466                           Cod, flesh only, grilled
# 792    16-374                        Cod, flesh only, microwaved
# 793    16-015  Cod, flesh only, poached in milk, butter and s...
# 794    16-016  Cod, flesh only, poached in milk, butter and s...
# 795    16-372                               Cod, flesh only, raw
# ...

# %%
JA['Food Name'].unique()
# Out:
# array(['Carp, raw', 'Catfish, flesh only, steamed',
#        'Catfish, flesh only, steamed, weighed with bones', 'Catfish, raw',
#        'Chital, raw', 'Cod, dried, salted, boiled',
#        'Cod, flesh only, baked',
#        'Cod, flesh only, baked, weighed with bones and skin',
#        'Cod, flesh only, grilled', 'Cod, flesh only, microwaved',
#        'Cod, flesh only, poached in milk, butter and salt added',
#        'Cod, flesh only, poached in milk, butter and salt added, weighed with bones and skin',
#        'Cod, flesh only, raw', 'Cod, flesh only, salted and smoked, raw',
#        'Cod, flesh only, steamed',
#        'Cod, flesh only, steamed, weighed with bones and skin',
#        'Cod, in batter, baked',
#        'Cod, in batter, fried in dripping, takeaway',
#        'Cod, in batter, fried in rapeseed oil',
#        'Cod, in batter, fried, takeaway', 'Cod, in breadcrumbs, baked',
#        'Coley, flesh only, baked', 'Coley, flesh only, grilled',
# ...

# %% [markdown]
# **Reduced**

# %%
Priortiy_JA = ['Carp, raw','Catfish, raw','Chital, raw', 'Cod, flesh only, baked', 'Coley, flesh only, baked']

# %%
Filt_JA = JA[JA['Food Name'].isin(Priortiy_JA)]
Filt_JA
# Out:
#     Food Code                 Food Name  \
# 533    16-172                 Carp, raw
# 560    16-007              Catfish, raw
# 742    16-011               Chital, raw
# 789    16-373    Cod, flesh only, baked
# 824    16-429  Coley, flesh only, baked
#
#                                            Description Group Previous  \
# 533                                 Literature sources    JA      NaN
# 560                                 Literature sources    JA      NaN
# 742  Literature sources. Imported frozen from Bangl...    JA      NaN
# 789        11 samples, 11 products, frozen and chilled    JA  16-013
# 824     Calculated from 16-383 using 26.1% weight loss    JA      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 533            Fish and Fish Products Supplement, 1993      NaN         471
# 560            Fish and Fish Products Supplement, 1993      NaN         403
# ...

# %%
Filt_JA['Super Group'] = 'Fish and Fish Products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\2823660487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_JA['Super Group'] = 'Fish and Fish Products'

# %% [markdown]
# Fatty Fish

# %%
JK = Prod_C.loc[Prod_C['Group']== 'JK']
JK
# Out:
#     Food Code                                          Food Name  \
# 865    16-391                 Crab, brown meat, purchased cooked
# 866    16-452                     Crab, canned in brine, drained
# 867    16-441                             Crab, purchased cooked
# 868    16-470  Crab, white and brown meat, purchased cooked, ...
# 869    16-392                 Crab, white meat, purchased cooked
# 873    16-235                                      Crayfish, raw
#
#                                            Description Group Previous  \
# 865                              7 samples, 6 products    JK      NaN
# 866                                   6 cans, 2 brands    JK  16-234
# 867  Frozen and chilled. Average of brown and white...    JK  16-331
# 868  Calculated from brown and white crab meat usin...    JK  16-342
# 869                              7 samples, 6 products    JK      NaN
# 873                                 Literature sources    JK      NaN
#
# ...

# %%
JK['Food Name'].unique()
# Out:
# array(['Crab, brown meat, purchased cooked',
#        'Crab, canned in brine, drained', 'Crab, purchased cooked',
#        'Crab, white and brown meat, purchased cooked, weighed with shell',
#        'Crab, white meat, purchased cooked', 'Crayfish, raw'],
#       dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_JK = ['Crayfish, raw', 'Crab, canned in brine, drained', 'Crab, purchased cooked']

# %%
Filt_JK = JK[JK['Food Name'].isin(Priority_JK)]
Filt_JK
# Out:
#     Food Code                       Food Name  \
# 866    16-452  Crab, canned in brine, drained
# 867    16-441          Crab, purchased cooked
# 873    16-235                   Crayfish, raw
#
#                                            Description Group Previous  \
# 866                                   6 cans, 2 brands    JK  16-234
# 867  Frozen and chilled. Average of brown and white...    JK  16-331
# 873                                 Literature sources    JK      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 866  Fish and Fish Products Supplement, 1993; and i...      NaN         327
# 867  DH, Nutrient analysis of fish and fish product...      NaN         485
# 873            Fish and Fish Products Supplement, 1993      NaN         282
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 866            77      0.5           0.1                0          0
# ...

# %%
Filt_JK['Super Group'] = 'Fish and Fish Products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\2432483002.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_JK['Super Group'] = 'Fish and Fish Products'

# %% [markdown]
# Molluscs

# %%
JM = Prod_C.loc[Prod_C['Group']== 'JM']
JM
# Out:
#      Food Code                          Food Name  \
# 524     16-404  Calamari, coated in batter, baked
# 775     16-252                    Cockles, boiled
# 1019    16-254                    Cuttlefish, raw
#
#                                             Description Group        Previous  \
# 524                       5 samples, 2 products, frozen    JM  16-266 16-265
# 775   11 samples from assorted outlets; fresh and fr...    JM         50-644
# 1019                                 Literature sources    JM             NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 524   DH, Nutrient analysis of fish and fish product...      NaN        1207
# 775   Reviewed 2013. LGC, Nutritional survey fish an...      NaN         226
# 1019  Wu Leung et al (1972) Food composition table f...      NaN         300
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# ...

# %%
JM['Super Group'] = 'Fish and Fish Products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\26455013.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   JM['Super Group'] = 'Fish and Fish Products'

# %% [markdown]
# Fish products and dishes

# %%
JR = Prod_C.loc[Prod_C['Group']== 'JR']
JR
# Out:
#     Food Code                           Food Name  \
# 571    16-272  Caviare, bottled in brine, drained
# 957    16-446  Curry, fish, Bangladeshi, homemade
# 958    16-364               Curry, fish, homemade
# 960    16-455   Curry, haddock, Bengali, homemade
# 961    16-456   Curry, herring, Bengali, homemade
# 994    16-365        Curry, Prawn bhuna, takeaway
# 995    16-366       Curry, Prawn madras, takeaway
# 996    16-333              Curry, prawn, takeaway
#
#                                            Description Group  \
# 571                   Literature sources. Lumpfish roe    JR
# 957  Recipe, containing boal, rohu, spices, water a...    JR
# 958  5 samples, containing white fish, onions, toma...    JR
# 960                                             Recipe    JR
# 961                                             Recipe    JR
# 994  10 samples, 2 from different establishments in...    JR
# 995  10 samples, 2 from different establishments in...    JR
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_JR = JR.loc[JR['Food Name'] == 'Caviare, bottled in brine, drained']
Filt_JR
# Out:
#     Food Code                           Food Name  \
# 571    16-272  Caviare, bottled in brine, drained
#
#                           Description Group Previous  \
# 571  Literature sources. Lumpfish roe    JR      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 571  Lewis and English (1990) Composition of Foods ...      NaN         410
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 571            98      5.4           0.8                0          0
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 571          0         0         12.4      5.3

# %%
Filt_JR['Super Group'] = 'Fish and Fish Products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\3454645712.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_JR['Super Group'] = 'Fish and Fish Products'

# %% [markdown]
#                                                   Meat and meat products

# %% [markdown]
# Poulty/Chicken

# %%
MCA = Prod_C.loc[Prod_C['Group']== 'MCA']
MCA
# Out:
#     Food Code                                          Food Name  \
# 655    18-504                Chicken breast/steak, coated, baked
# 662    18-501                   Chicken pieces, coated, takeaway
# 663    18-500   Chicken portions, battered, deep fried, takeaway
# 669    18-308         Chicken, breast, casseroled, meat and skin
# 670    18-309  Chicken, breast, casseroled, meat and skin, we...
# ..        ...                                                ...
# 725    18-295          Chicken, wing quarter, raw, meat and skin
# 726    18-296  Chicken, wing quarter, raw, meat and skin, wei...
# 727    18-339      Chicken, wing quarter, roasted, meat and skin
# 728    18-340  Chicken, wing quarter, roasted, meat and skin,...
# 730    18-503               Chicken/turkey pieces, coated, baked
#
#                                            Description Group Previous  \
# 655        8 samples, 7 products, breaded and battered   MCA  19-119
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_MCA = ['Chicken, meat, average, raw','Chicken, whole, raw, meat and skin','Chicken, wing quarter, raw, meat and skin','Chicken breast/steak, coated, baked','Chicken pieces, coated, takeaway','Chicken, corn-fed, raw, meat only''Chicken, drumsticks, roasted, meat and skin', 'Chicken, leg quarter, raw, meat and skin', 'Chicken/turkey pieces, coated, baked']

# %%
Filt_MCA = MCA[MCA['Food Name'].isin(Priority_MCA)]
Filt_MCA
# Out:
#     Food Code                                  Food Name  \
# 655    18-504        Chicken breast/steak, coated, baked
# 662    18-501           Chicken pieces, coated, takeaway
# 694    18-293   Chicken, leg quarter, raw, meat and skin
# 700    18-488                Chicken, meat, average, raw
# 718    18-297         Chicken, whole, raw, meat and skin
# 725    18-295  Chicken, wing quarter, raw, meat and skin
# 730    18-503       Chicken/turkey pieces, coated, baked
#
#                                            Description Group        Previous  \
# 655        8 samples, 7 products, breaded and battered   MCA         19-119
# 662  8 samples, 7 products, including chicken nugge...   MCA         19-124
# 694         Calculated from 77% dark meat and 23% skin   MCA             NaN
# 700   Calculated from 44% light meat and 56% dark meat   MCA  18-291 50-431
# 718  Calculated from 33% light meat, 42% dark meat ...   MCA             NaN
# ...

# %%
Filt_MCA['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\3262525810.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_MCA['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Meat Products

# %%
MI = Prod_C.loc[Prod_C['Group']== 'MI']
MI
# Out:
#     Food Code                                   Food Name  \
# 665    19-538                              Chicken slices
# 729    19-469  Chicken/turkey pasties/slices, puff pastry
# 758    19-516                                     Chorizo
# 848    19-128                         Corned beef, canned
#
#                                            Description Group  Previous  \
# 665  7 samples including smoked and wafer thin chic...    MI       NaN
# 729  10 samples, 10 products, including chicken and...    MI       NaN
# 758                                Manufacturers' data    MI   19-099
# 848                               10 samples, 4 brands    MI  50-507
#
#                                   Main data references Footnote Energy (kJ)  \
# 665  LGC, Nutritional analysis of meat and poultry ...      NaN         479
# 729  DH, Nutrient analysis of a range of processed ...      NaN        1217
# 758                                Industry data, 2013      NaN        1645
# ...

# %% [markdown]
# **Reduced**

# %%
Remove_MI = ['Chicken/turkey pasties/slices, puff pastry']
Remove_MI
# Out:
# ['Chicken/turkey pasties/slices, puff pastry']

# %%
Filt_MI = MI[~MI['Food Name'].isin(Remove_MI)]
Filt_MI
# Out:
#     Food Code            Food Name  \
# 665    19-538       Chicken slices
# 758    19-516              Chorizo
# 848    19-128  Corned beef, canned
#
#                                            Description Group  Previous  \
# 665  7 samples including smoked and wafer thin chic...    MI       NaN
# 758                                Manufacturers' data    MI   19-099
# 848                               10 samples, 4 brands    MI  50-507
#
#                                   Main data references Footnote Energy (kJ)  \
# 665  LGC, Nutritional analysis of meat and poultry ...      NaN         479
# 758                                Industry data, 2013      NaN        1645
# 848  Reviewed 2013. Meat Products and Dishes Supple...      NaN         859
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 665           113      1.5           0.4              1.6        0.2
# 758           397     32.2            12              2.2          1
# ...

# %%
Filt_MI['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\1350248321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_MI['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Other meat products

# %%
MIG = Prod_C.loc[Prod_C['Group']== 'MIG']
MIG
# Out:
#     Food Code                                      Food Name  \
# 942    19-296  Curry, chicken tikka masala, retail, reheated
#
#                                      Description Group Previous  \
# 942  11 samples, 11 products, chilled and frozen   MIG      341
#
#                                   Main data references Footnote Energy (kJ)  \
# 942  LGC, Nutrient analysis of foods important in e...      NaN         666
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 942           160      9.8           3.3              4.7        3.5
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 942        1.2       1.4         12.5     0.55

# %%
MIG['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\1977784187.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MIG['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Meat dishes

# %%
MR = Prod_C.loc[Prod_C['Group']== 'MR']
MR
# Out:
#     Food Code                                          Food Name  \
# 485    19-631  Cabbage leaves, stuffed with lamb and rice, ho...
# 531    19-558                       Carbonnade of Beef, homemade
# 551    19-470           Casserole, beef, made with cook-in sauce
# 552    19-612                Casserole, pork and apple, homemade
# 553    19-536           Casserole, pork, made with cook-in sauce
# 554    19-623                        Casserole, rabbit, homemade
# 555    19-484                       Casserole, sausage, homemade
# 656    19-560                         Chicken chasseur, homemade
# 657    19-663      Chicken chasseur, homemade, weighed with bone
# 658    19-561                        Chicken fricassee, homemade
# 659    19-562           Chicken fricassee, reduced fat, homemade
# 660    19-563  Chicken in white sauce, made with semi-skimmed...
# 661    19-564       Chicken in white sauce, made with whole milk
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_MR = ['Casserole, sausage, homemade','Chow mein, chicken, takeaway','Cornish pasty, retail','Coronation chicken, homemade']

# %%
Filt_MR = MR[MR['Food Name'].isin(Priority_MR)]
Filt_MR
# Out:
#     Food Code                     Food Name              Description Group  \
# 555    19-484  Casserole, sausage, homemade                   Recipe    MR
# 761    19-321  Chow mein, chicken, takeaway               10 samples    MR
# 851    19-466         Cornish pasty, retail  11 samples, 10 products    MR
# 853    19-477  Coronation chicken, homemade                   Recipe    MR
#
#     Previous                               Main data references Footnote  \
# 555  19-351                                        Updated 2013      NaN
# 761      NaN  Reviewed 2013. Aspland and James Ltd, Nutrient...      NaN
# 851  19-316   DH, Nutrient analysis of a range of processed ...      NaN
# 853  19-339                                        Updated 2013      NaN
#
#     Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 555         702           169     10.9          3.65              4.9
# 761         621           148      7.2          1.17             11.7
# ...

# %%
Filt_MR['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\3346374556.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_MR['Super Group'] = 'Meat and meat products'

# %% [markdown]
#                                                    Fats and Oils

# %% [markdown]
# Spreading Fats

# %%
OE = Prod_C.loc[Prod_C['Group']== 'OE']
OE
# Out:
#     Food Code     Food Name                      Description Group Previous  \
# 777    17-002  Cocoa butter  Analysis and literature sources    OE      NaN
#
#                      Main data references Footnote Energy (kJ) Energy (kcal)  \
# 777  Miscellaneous Foods Supplement, 1994      NaN        3682           896
#
#      Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 777     99.5            59                0          0          0         0
#
#      Protein (g) Salt (g)
# 777          0.0        0

# %%
OE['Super Group'] = 'Fats and Oils'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\660970776.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   OE['Super Group'] = 'Fats and Oils'

# %% [markdown]
#                                                         Beverages

# %% [markdown]
# Powdered drinks and essences

# %%
P = Prod_C.loc[Prod_C['Group']== 'P']
P
# Out:
#     Food Code                  Food Name            Description Group  \
# 806    17-632  Coffee, cappuccino, latte  9 samples as consumed     P
#
#     Previous                               Main data references Footnote  \
# 806      NaN  Direct Laboratories, Nutrient analysis catch u...      NaN
#
#     Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 806         115            27      0.8          0.52                3
#
#     Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 806        2.3        0.7         0          2.0     0.06

# %%
P['Super Group'] = 'Beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\3697906943.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   P['Super Group'] = 'Beverages'

# %% [markdown]
# ##### Removed PA. Its also coffee

# %% [markdown]
# ##### Removed PAA. Couldn't Identify Products

# %% [markdown]
# ##### Removed PAC. Varieties of Coffee

# %% [markdown]
# Soft drinks/Carbonated drinks

# %%
PCA = Prod_C.loc[Prod_C['Group'] == 'PCA']
PCA
# Out:
#     Food Code   Food Name           Description Group  Previous  \
# 819    17-175        Cola  10 samples, 6 brands   PCA  50-1080
# 820    17-505  Cola, diet  Calculated from Cola   PCA
#
#                                   Main data references Footnote Energy (kJ)  \
# 819  Reviewed 2013. LFRA, Nutritional analysis of s...      NaN         182
# 820  Reviewed 2013. Miscellaneous Foods and USDA 19...      NaN           0
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 819            43      0.0             0             10.7       10.7
# 820             0      0.0             0                0          0
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 819          0         0          0.0     0.01
# 820          0         0          0.0     0.01

# %% [markdown]
# **Reduced**

# %%
Priortiy_PCA = ['Cola']

# %%
Filt_PCA = PCA.loc[PCA['Food Name'].isin(Priortiy_PCA)]
Filt_PCA
# Out:
#     Food Code Food Name           Description Group  Previous  \
# 819    17-175      Cola  10 samples, 6 brands   PCA  50-1080
#
#                                   Main data references Footnote Energy (kJ)  \
# 819  Reviewed 2013. LFRA, Nutritional analysis of s...      NaN         182
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 819            43      0.0             0             10.7       10.7
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 819          0         0          0.0     0.01

# %%
Filt_PCA['Super Group'] = 'Beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\1940018051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_PCA['Super Group'] = 'Beverages'

# %% [markdown]
# Juices

# %%
PE = Prod_C.loc[Prod_C['Group']== 'PE']
PE
# Out:
#     Food Code                    Food Name  \
# 872    17-744  Cranberry fruit juice drink
#
#                             Description Group Previous  \
# 872  Manufacturers' data and literature    PE  17-537
#
#                   Main data references Footnote Energy (kJ) Energy (kcal)  \
# 872  USDA 1998 and industry data, 2013      NaN         199            47
#
#      Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 872      0.0             0             11.5       11.5          0         0
#
#      Protein (g) Salt (g)
# 872          0.0        0

# %%
PE['Super Group'] = 'Beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\251056394.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PE['Super Group'] = 'Beverages'

# %% [markdown]
#                                                 Alcoholic beverages

# %% [markdown]
# Ciders

# %%
QC = Prod_C.loc[Prod_C['Group'] == 'QC']
QC
# Out:
#     Food Code           Food Name  \
# 767    17-222          Cider, dry
# 768    17-223  Cider, low alcohol
# 769    17-822       Cider, strong
# 770    17-224        Cider, sweet
#
#                                            Description Group  Previous  \
# 767  4.7-5.5% ABV. Including Strongbow, Blackthorn ...    QC  50-1104
# 768  <1% ABV. 10 samples, 3 brands including Koppar...    QC       NaN
# 769  6-8.5% ABV. 3 samples of the same brand, inclu...    QC   17-225
# 770  3.5-5.0% ABV. 3 samples of different brands, i...    QC  50-1105
#
#                                   Main data references Footnote Energy (kJ)  \
# 767  Reviewed 2013. MW3, 1960. Additional values fr...      NaN         153
# 768  Reviewed 2013. LFRA, Nutritional analysis of s...      NaN          77
# 769                           Reviewed 2013. MW3, 1960      NaN         291
# 770  Reviewed 2013. MW3, 1960. Additional values fr...      NaN         177
#
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_QC =['Cider, sweet']

# %%
Filt_QC = QC.loc[QC['Food Name'].isin(Priority_QC)]
Filt_QC
# Out:
#     Food Code     Food Name  \
# 770    17-224  Cider, sweet
#
#                                            Description Group  Previous  \
# 770  3.5-5.0% ABV. 3 samples of different brands, i...    QC  50-1105
#
#                                   Main data references Footnote Energy (kJ)  \
# 770  Reviewed 2013. MW3, 1960. Additional values fr...      NaN         177
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 770            42      0.0             0              4.1        4.1
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 770          0         0          0.0     0.02

# %%
Filt_QC['Super Group'] = 'Alcoholic beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\2484317793.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_QC['Super Group'] = 'Alcoholic beverages'

# %% [markdown]
#                                                 Sugars, preserves and snacks

# %% [markdown]
# Sugars, syrups and preserves

# %%
SC = Prod_C.loc[Prod_C['Group'] == 'SC']
SC
# Out:
#     Food Code             Food Name          Description Group Previous  \
# 750    17-687  Chocolate nut spread  8 samples, 5 brands    SC  17-070
# 752    17-659      Chocolate spread  7 samples, 5 brands    SC  17-069
#
#                                   Main data references Footnote Energy (kJ)  \
# 750  LFRA, Nutrient analysis of miscellaneous foods...      NaN        2329
# 752  DH, Nutrient analysis of a range of processed ...      NaN        2429
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 750           558     33.0          9.34             57.6       56.9
# 752           583     37.7          8.13             56.7       56.7
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 750        0.7         3          6.2     0.13
# 752          0         2          3.3     0.15

# %% [markdown]
# ##### Reduced

# %%
Filt_SC = SC.loc[SC['Food Name'] == 'Chocolate spread']
Filt_SC
# Out:
#     Food Code         Food Name          Description Group Previous  \
# 752    17-659  Chocolate spread  7 samples, 5 brands    SC  17-069
#
#                                   Main data references Footnote Energy (kJ)  \
# 752  DH, Nutrient analysis of a range of processed ...      NaN        2429
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 752           583     37.7          8.13             56.7       56.7
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 752          0         2          3.3     0.15

# %%
Filt_SC['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\266286910.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_SC['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
# Chocolate confectionery

# %%
SEA = Prod_C.loc[Prod_C['Group'] == 'SEA']
SEA
# Out:
#     Food Code                                          Food Name  \
# 529    17-649         Caramel bars and sweets, chocolate covered
# 747    17-658      Chocolate covered bar with caramel and cereal
# 748    17-657      Chocolate covered caramel and biscuit fingers
# 753    17-650  Chocolate, dark, with crème or mint fondant ce...
# 754    17-690                        Chocolate, fancy and filled
# 755    17-648                                    Chocolate, milk
# 756    17-491                                   Chocolate, plain
# 757    17-091                                   Chocolate, white
# 888    17-763                                          Creme egg
#
#                                            Description Group  \
# 529  10 samples, 6 brands, including Cadbury's Cara...   SEA
# 747  6 samples, 6 products, including Balisto, Lion...   SEA
# 748  9 samples, 7 products, including Twix and equi...   SEA
# 753  10 samples, 8 products, including After Eights...   SEA
# ...

# %% [markdown]
# ##### Reduced

# %%
Priority_SEA = ['Chocolate covered bar with caramel and cereal','Creme egg']

# %%
Filt_SEA = SEA[SEA['Food Name'].isin(Priority_SEA)]
Filt_SEA
# Out:
#     Food Code                                      Food Name  \
# 747    17-658  Chocolate covered bar with caramel and cereal
# 888    17-763                                      Creme egg
#
#                                            Description Group Previous  \
# 747  6 samples, 6 products, including Balisto, Lion...   SEA  17-550
# 888                                         10 samples   SEA  17-544
#
#                                   Main data references Footnote Energy (kJ)  \
# 747  DH, Nutrient analysis of a range of processed ...      NaN        2117
# 888  LGC, Dairy products and eggs, 1989; and indust...      NaN        1604
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 747           506     25.8         16.26             62.4       44.3
# 888           382     15.9           9.7             55.5       55.5
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 747       10.5       1.9          5.1      0.4
# ...

# %%
Filt_SEA['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\2887802754.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_SEA['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
# ###### Removed SEC. Not clear on what product this is

# %% [markdown]
# Savoury snacks

# %%
SN = Prod_C.loc[Prod_C['Group']== 'SN']
SN
# Out:
#     Food Code    Food Name                                        Description  \
# 846    17-645  Corn snacks  6 samples, 4 products, including Wotsits, Mons...
#
#     Group Previous                               Main data references  \
# 846    SN  17-125   DH, Nutrient analysis of a range of processed ...
#
#     Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 846      NaN        2180           522     30.4          2.76
#
#     Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 846             55.5        5.2       50.3       1.3          5.9     2.27

# %%
SN['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\1807899663.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SN['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
# Savoury snacks/Non-potato snacks

# %%
SNC = Prod_C.loc[Prod_C['Group']== 'SNC']
SNC
# Out:
#     Food Code                       Food Name Description Group Previous  \
# 654    17-782  Chevda/chevra/chewra, homemade      Recipe   SNC  17-557
#
#     Main data references Footnote Energy (kJ) Energy (kcal)  Fat (g)  \
# 654         Updated 2014      NaN           N             N     31.8
#
#     Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 654          4.71                N          N       28.7       4.2
#
#      Protein (g) Salt (g)
# 654         20.4     0.29

# %%
SNC['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\2123181595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SNC['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
#                                         Soups, sauces and miscellaneous foods

# %% [markdown]
# Canned soups

# %%
WAC = Prod_C.loc[Prod_C['Group']== 'WAC']
WAC
# Out:
#     Food Code                                          Food Name  \
# 666    17-697  Chicken soup, cream of, canned, condensed, as ...
#
#                                            Description Group Previous  \
# 666  7 cans of the same brand. Diluted with an equa...   WAC  17-252
#
#                                   Main data references Footnote Energy (kJ)  \
# 666  As Miscellaneous Foods and Fatty Acids supplem...      NaN         176
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 666            42      2.9           0.4              2.8        0.7
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 666        2.1         0          1.3     0.63

# %%
WAC['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\1824018109.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WAC['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
# Sauces

# %%
WC = Prod_C.loc[Prod_C['Group']== 'WC']
WC
# Out:
#     Food Code     Food Name  \
# 737    17-719  Chilli sauce
# 911    17-720   Curry paste
#
#                                            Description Group Previous  \
# 737  8 samples; assorted types, including garlic ch...    WC  17-294
# 911                               20 samples, 3 brands    WC  17-297
#
#                                   Main data references Footnote Energy (kJ)  \
# 737  LFRA, Nutrient analysis of miscellaneous foods...      NaN         193
# 911  LFRA, Nutrient analysis of miscellaneous foods...      NaN        1103
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 737            46      0.8             0              7.3        6.9
# 911           266     21.3           1.7             10.6        6.7
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 737        0.4       2.2          1.3     3.13
# 911        3.9       6.8          4.7      3.8

# %%
Filt_WC = WC[WC['Food Name'] == 'Chilli sauce']
Filt_WC
# Out:
#     Food Code     Food Name  \
# 737    17-719  Chilli sauce
#
#                                            Description Group Previous  \
# 737  8 samples; assorted types, including garlic ch...    WC  17-294
#
#                                   Main data references Footnote Energy (kJ)  \
# 737  LFRA, Nutrient analysis of miscellaneous foods...      NaN         193
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 737            46      0.8             0              7.3        6.9
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 737        0.4       2.2          1.3     3.13

# %%
Filt_WC['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\3218677465.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_WC['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
# Dairy sauces

# %%
WCD = Prod_C.loc[Prod_C['Group']== 'WCD']
WCD
# Out:
#     Food Code                                          Food Name Description  \
# 585    17-665  Cheese sauce, made with semi-skimmed milk, hom...      Recipe
# 586    17-773     Cheese sauce, made with skimmed milk, homemade      Recipe
# 587    17-775       Cheese sauce, made with whole milk, homemade      Recipe
# 588    17-666  Cheese sauce, packet mix, made up with semi-sk...      Recipe
# 589    17-780  Cheese sauce, packet mix, made up with skimmed...      Recipe
# 590    17-781  Cheese sauce, packet mix, made up with whole m...      Recipe
#
#     Group Previous Main data references Footnote Energy (kJ) Energy (kcal)  \
# 585   WCD  17-522          Updated 2013      NaN         757           182
# 586   WCD  17-568          Updated 2014      NaN         714           171
# 587   WCD  17-521          Updated 2014      NaN         819           197
# 588   WCD  17-524          Updated 2013      NaN         445           106
# ...

# %% [markdown]
# **Reduce**

# %%
Filt_WCD = WCD.loc[WCD['Food Name'] == 'Cheese sauce, made with skimmed milk, homemade']
Filt_WCD
# Out:
#     Food Code                                       Food Name Description  \
# 586    17-773  Cheese sauce, made with skimmed milk, homemade      Recipe
#
#     Group Previous Main data references Footnote Energy (kJ) Energy (kcal)  \
# 586   WCD  17-568          Updated 2014      NaN         714           171
#
#      Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 586     11.6          7.23              8.5          4        4.5       0.2
#
#      Protein (g) Salt (g)
# 586          8.2     0.54

# %%
Filt_WCD['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\634448677.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_WCD['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
# Salad sauces, dressings and pickles

# %%
WCG = Prod_C.loc[Prod_C['Group']== 'WCG']
WCG
# Out:
#     Food Code                 Food Name          Description Group Previous  \
# 763    17-784  Chutney, apple, homemade               Recipe   WCG  17-531
# 765    17-345           Chutney, tomato  9 samples, 5 brands   WCG      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 763                                       Updated 2014      NaN         820
# 765  Reviewed 2013. LFRA, Nutrient analysis of misc...      NaN         561
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 763           193      0.2             0             46.7       46.6
# 765           132      0.2             0             30.7       28.1
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 763        0.1       0.7          0.8     0.03
# 765        2.6       1.4          1.2     1.03

# %% [markdown]
# **Reduced**

# %%
Remove_WCG = ['Chutney, apple, homemade']

# %%
Filt_WCG = WCG[~WCG['Food Name'].isin(Remove_WCG)]
Filt_WCG
# Out:
#     Food Code        Food Name          Description Group Previous  \
# 765    17-345  Chutney, tomato  9 samples, 5 brands   WCG      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 765  Reviewed 2013. LFRA, Nutrient analysis of misc...      NaN         561
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 765           132      0.2             0             30.7       28.1
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 765        2.6       1.4          1.2     1.03

# %%
Filt_WCG['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\2275349619.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_WCG['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
# ###### Removed WE as i've already recorded a chutney

# %% [markdown]
# Miscellaneous foods

# %%
WY = Prod_C.loc[Prod_C['Group']== 'WY']
WY
# Out:
#     Food Code        Food Name            Description Group Previous  \
# 875    17-358  Cream of tartar  As potassium tartrate    WY      NaN
#
#                      Main data references Footnote Energy (kJ) Energy (kcal)  \
# 875  Miscellaneous Foods Supplement, 1994      NaN           2             0
#
#      Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 875      0.0             0                0          0          0       0.2
#
#      Protein (g) Salt (g)
# 875          0.0        0

# %%
WY['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_23504\647319242.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WY['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
#                                               **Join Reduced Tables**

# %%
Red = pd.concat([AA,Filt_AF], axis=0, join='inner')
Red
# Out:
#      Food Code                        Food Name  \
# 852     11-011                 Cornmeal, sifted
# 1012   11-1138                   Custard powder
# 579     11-987  Chapatis, made with fat, retail
#
#                                             Description Group Previous  \
# 852                   Analytical and literature sources    AA      NaN
# 1012  Taken as cornflour (11-1045) except Na, Cl and Cu    AA      NaN
# 579                                           6 samples    AF  11-458
#
#                                    Main data references Footnote Energy (kJ)  \
# 852   Wu Leung et al. (1968) Food composition table ...      NaN        1586
# 1012  LGC, Nutrient survey of flours and grains, 200...      NaN        1457
# 579   MW4, 1978; and industry data, 2013. Selenium f...      NaN        1390
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 852            375      3.3          0.41             74.9        1.6
# ...

# %%
Red2 = pd.concat([Red,AG], axis=0, join='inner')
Red2
# Out:
#      Food Code                        Food Name  \
# 852     11-011                 Cornmeal, sifted
# 1012   11-1138                   Custard powder
# 579     11-987  Chapatis, made with fat, retail
# 892     11-988                       Croissants
#
#                                             Description Group Previous  \
# 852                   Analytical and literature sources    AA      NaN
# 1012  Taken as cornflour (11-1045) except Na, Cl and Cu    AA      NaN
# 579                                           6 samples    AF  11-458
# 892                                10 samples, 7 brands    AG  11-480
#
#                                    Main data references Footnote Energy (kJ)  \
# 852   Wu Leung et al. (1968) Food composition table ...      NaN        1586
# 1012  LGC, Nutrient survey of flours and grains, 200...      NaN        1457
# 579   MW4, 1978; and industry data, 2013. Selenium f...      NaN        1390
# ...

# %%
Red3 = pd.concat([Red2,Filt_AM], axis=0, join='inner')
Red3
# Out:
#      Food Code                                          Food Name  \
# 852     11-011                                   Cornmeal, sifted
# 1012   11-1138                                     Custard powder
# 579     11-987                    Chapatis, made with fat, retail
# 892     11-988                                         Croissants
# 497     11-916                                         Cake rusks
# 577     11-819  Cereal bars, with fruit and/or nuts, no chocol...
# 593     11-824                       Cheese straws/twists, retail
# 874     11-820                                     Cream crackers
# 891     11-822                                    Crispbread, rye
#
#                                             Description Group        Previous  \
# 852                   Analytical and literature sources    AA             NaN
# 1012  Taken as cornflour (11-1045) except Na, Cl and Cu    AA             NaN
# ...

# %%
Red4 = pd.concat([Red3,Filt_AN], axis=0, join='inner')
Red4
# Out:
#      Food Code                                          Food Name  \
# 852     11-011                                   Cornmeal, sifted
# 1012   11-1138                                     Custard powder
# 579     11-987                    Chapatis, made with fat, retail
# 892     11-988                                         Croissants
# 497     11-916                                         Cake rusks
# 577     11-819  Cereal bars, with fruit and/or nuts, no chocol...
# 593     11-824                       Cheese straws/twists, retail
# 874     11-820                                     Cream crackers
# 891     11-822                                    Crispbread, rye
# 515     11-832                    Cake, sponge, soft iced, retail
# 521     11-840                 Cakes from 'healthy eating' ranges
# 523     11-839              Cakes, fancy iced, individual, retail
#
#                                             Description Group        Previous  \
# ...

# %%
Red5 = pd.concat([Red4,Filt_AP], axis=0, join='inner')
Red5
# Out:
#      Food Code                                          Food Name  \
# 852     11-011                                   Cornmeal, sifted
# 1012   11-1138                                     Custard powder
# 579     11-987                    Chapatis, made with fat, retail
# 892     11-988                                         Croissants
# 497     11-916                                         Cake rusks
# 577     11-819  Cereal bars, with fruit and/or nuts, no chocol...
# 593     11-824                       Cheese straws/twists, retail
# 874     11-820                                     Cream crackers
# 891     11-822                                    Crispbread, rye
# 515     11-832                    Cake, sponge, soft iced, retail
# 521     11-840                 Cakes from 'healthy eating' ranges
# 523     11-839              Cakes, fancy iced, individual, retail
# 902     11-989                                  Crumpets, toasted
#
# ...

# %%
Red5 = pd.concat([Red4,Filt_AP], axis=0, join='inner')
Red5

# %%
Red34 = pd.concat([Red33,WY], axis=0, join='inner')
Red34.tail(15)

# %% [markdown]
#                                                        Export

# %%
Red34.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced_B.csv')
