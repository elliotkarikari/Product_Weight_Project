# %% [markdown]
# # Product Weighting Project

# %% [markdown]
#                                          Data Reduction - Food Purchased In Store

# %% [markdown]
# ###### Import Necessary Libraries

# %%
import pandas as pd

# %% [markdown]
# Read in Data

# %%
Labelled = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Labelling2021_watercress.csv')

# %% [markdown]
# ### Products beginning with a 'C'

# %%
Prod_C = Labelled.loc[Labelled['Food Name'].str.startswith('C')]
Prod_C.head()
# Out:
#     Food Code                                          Food Name  \
# 485    19-631  Cabbage leaves, stuffed with lamb and rice, ho...
# 486    13-581         Cabbage, average, boiled in unsalted water
# 487    13-582                              Cabbage, average, raw
# 488    13-187                              Cabbage, Chinese, raw
# 489    13-511           Cabbage, green, boiled in unsalted water
#
#                                            Description Group Previous  \
# 485                                             Recipe    MR  19-437
# 486                 Average of green and white cabbage    DG      NaN
# 487  Average of white (13-509) and green (13-510) c...    DG  13-468
# 488                 Base trimmed, outer leaves removed    DG      NaN
# 489                     As raw, boiled for 4-8 minutes    DG  13-444
#
#                                   Main data references Footnote Energy (kJ)  \
# 485                                       Updated 2014      NaN         415
# ...

# %% [markdown]
# Products within a Group (provide identification of the food group and food type to which the food belongs)

# %%
Prod_C.groupby('Group')['Food Name'].count()
# Out:
# Group
# AA      2
# AF      3
# AG      1
# AM      8
# AN     27
# AP      4
# AS      5
# AT      3
# BAR     1
# BH      9
# BJC     8
# BJP     2
# BJS     2
# BL     46
# BP      2
# BR     11
# BTM     1
# BV      1
# DG     43
# DI      1
# DR     99
# FA     14
# GA     10
# H      16
# J       3
# JA     27
# JK      6
# JM      3
# JR      8
# MCA    61
# MI      4
# MIG     1
# MR     52
# OE      1
# P       1
# PA      1
# PAA     3
# PAC    10
# PCA     2
# PE      1
# QC      4
# SC      2
# SEA     9
# SEC     1
# SN      1
# SNC     1
# WAC     1
# WC      2
# WCD     6
# WCG     2
# WE      2
# WY      1
# Name: Food Name, dtype: int64

# %% [markdown]
# ## *Reducing products based on its most basic form. Improve as you go on*

# %% [markdown]
#                                               Cereals and cereal products

# %% [markdown]
# Flours, grains and starches

# %%
AA = Prod_C.loc[Prod_C['Group']== 'AA']
AA
# Out:
#      Food Code         Food Name  \
# 852     11-011  Cornmeal, sifted
# 1012   11-1138    Custard powder
#
#                                             Description Group Previous  \
# 852                   Analytical and literature sources    AA      NaN
# 1012  Taken as cornflour (11-1045) except Na, Cl and Cu    AA      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 852   Wu Leung et al. (1968) Food composition table ...      NaN        1586
# 1012  LGC, Nutrient survey of flours and grains, 200...      NaN        1457
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 852            375      3.3          0.41             74.9        1.6
# 1012           343      0.7           0.1             83.6          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 852        73.3       3.9          9.4        0
# 1012       83.6         0          0.6     0.95

# %%
AA['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11424\2826330813.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AA['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Breads

# %%
AF = Prod_C.loc[Prod_C['Group']== 'AF']
AF
# Out:
#     Food Code                        Food Name  \
# 579    11-987  Chapatis, made with fat, retail
# 580    11-459       Chapatis, made without fat
# 907   11-1009             Currant buns, retail
#
#                                Description Group        Previous  \
# 579                              6 samples    AF         11-458
# 580         Analysed and calculated values    AF  11-075 50-036
# 907  9 samples, 5 supermarkets, 3 bakeries    AF         11-536
#
#                                   Main data references Footnote Energy (kJ)  \
# 579  MW4, 1978; and industry data, 2013. Selenium f...      NaN        1390
# 580  Data from MW5 with selenium data from SAC Anal...      NaN         908
# 907  LGC, Nutrient analysis of bread and morning go...      NaN        1218
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 579           331     12.8          1.56               44        1.7
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_AF = AF.loc[AF['Food Name'] == 'Chapatis, made with fat, retail']
Filt_AF
# Out:
#     Food Code                        Food Name Description Group Previous  \
# 579    11-987  Chapatis, made with fat, retail   6 samples    AF  11-458
#
#                                   Main data references Footnote Energy (kJ)  \
# 579  MW4, 1978; and industry data, 2013. Selenium f...      NaN        1390
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 579           331     12.8          1.56               44        1.7
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 579       42.3       2.2          8.9     0.75

# %%
Filt_AF['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11424\2620942196.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AF['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Rolls

# %%
AG = Prod_C.loc[Prod_C['Group']== 'AG']
AG
# Out:
#     Food Code   Food Name           Description Group Previous  \
# 892    11-988  Croissants  10 samples, 7 brands    AG  11-480
#
#                                   Main data references Footnote Energy (kJ)  \
# 892  LGC, Nutrient analysis of bread and morning go...      NaN        1589
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 892           380     19.7          9.76             39.7        5.2
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 892       34.5       3.1          9.4     0.83

# %%
AG['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11424\2401441672.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AG['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Biscuits

# %%
AM = Prod_C.loc[Prod_C['Group']== 'AM']
AM
# Out:
#     Food Code                                          Food Name  \
# 497    11-916                                         Cake rusks
# 577    11-819  Cereal bars, with fruit and/or nuts, no chocol...
# 578    11-818  Cereal bars, with fruit and/or nuts, with choc...
# 593    11-824                       Cheese straws/twists, retail
# 749    11-812                    Chocolate covered wafer biscuit
# 870   11-1134                      Crackers, wholemeal, homemade
# 874    11-820                                     Cream crackers
# 891    11-822                                    Crispbread, rye
#
#                                            Description Group        Previous  \
# 497  South Asian sweet bread, 6 samples, ethnic foo...    AM             NaN
# 577  5 samples, 5 products, including Jordan's frus...    AM  17-103 17-494
# 578  5 samples, 4 products, including Cadbury Brunc...    AM  17-103 17-494
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_AM = ['Cake rusks','Cereal bars, with fruit and/or nuts, no chocolate, unfortified','Cheese straws/twists, retail','Cream crackers','Crispbread, rye']

# %%
Filt_AM = AM[AM['Food Name'].isin(Priority_AM)]
Filt_AM
# Out:
#     Food Code                                          Food Name  \
# 497    11-916                                         Cake rusks
# 577    11-819  Cereal bars, with fruit and/or nuts, no chocol...
# 593    11-824                       Cheese straws/twists, retail
# 874    11-820                                     Cream crackers
# 891    11-822                                    Crispbread, rye
#
#                                            Description Group        Previous  \
# 497  South Asian sweet bread, 6 samples, ethnic foo...    AM             NaN
# 577  5 samples, 5 products, including Jordan's frus...    AM  17-103 17-494
# 593  10 samples, 7 products, including cheese straw...    AM             NaN
# 874                             10 samples, 6 products    AM         11-510
# 891  5 samples, 2 products, Ryvita original and Ryv...    AM         11-511
#
#                                   Main data references Footnote Energy (kJ)  \
# ...

# %%
Filt_AM['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11424\1616565383.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AM['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Cakes

# %%
AN = Prod_C.loc[Prod_C['Group']== 'AN']
AN
# Out:
#     Food Code                                          Food Name  \
# 496    11-740                               Cake bars, chocolate
# 498    11-835                           Cake, battenberg, retail
# 499    11-836                         Cake, carrot, iced, retail
# 500   11-1041               Cake, carrot, with topping, homemade
# 501   11-1044                             Cake, cherry, homemade
# 502    11-527                              Cake, chocolate fudge
# 503   11-1046              Cake, chocolate, not filled, homemade
# 504   11-1047       Cake, chocolate, with butter icing, homemade
# 505    11-830    Cake, chocolate, with filling and icing, retail
# 506   11-1053                            Cake, coconut, homemade
# 507    11-829                                Cake, fruit, retail
# 508   11-1005                        Cake, fruit, rich, homemade
# 509    11-991                  Cake, fruit, rich, iced, homemade
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_AN = ['Cake, sponge, soft iced, retail','Cakes, fancy iced, individual, retail',"Cakes from 'healthy eating' ranges"]

# %%
Filt_AN = AN[AN['Food Name'].isin(Priority_AN)]
Filt_AN
# Out:
#     Food Code                              Food Name  \
# 515    11-832        Cake, sponge, soft iced, retail
# 521    11-840     Cakes from 'healthy eating' ranges
# 523    11-839  Cakes, fancy iced, individual, retail
#
#                                            Description Group Previous  \
# 515  10 samples, 8 products, including angel cake, ...    AN      NaN
# 521  10 samples, 7 products, including carrot, lemo...    AN      NaN
# 523  10 samples, 8 products, including French and f...    AN      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 515  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1563
# 521  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1121
# 523  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1616
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 515           373     15.8          6.21             51.7       37.1
# ...

# %%
Filt_AN['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11424\569209402.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AN['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Buns and pastries

# %%
AP = Prod_C.loc[Prod_C['Group']== 'AP']
AP
# Out:
#     Food Code               Food Name                            Description  \
# 641   11-1043  Chelsea buns, homemade       Recipe. Ref. Wiles et al. (1980)
# 759   11-1050    Choux buns, homemade                                 Recipe
# 902    11-989       Crumpets, toasted                              9 samples
# 908    11-948   Currant buns, toasted  Calculated using a weight loss of 10%
#
#     Group Previous                               Main data references  \
# 641    AP  11-588   Based on Flour Milling and Baking Research Ass...
# 759    AP  11-653   Based on recipe as proportions in shop bought ...
# 902    AP  11-535   LGC, Nutrient analysis of bread and morning go...
# 908    AP      NaN  LGC, Nutrient analysis of bread and morning go...
#
#     Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 641      NaN        1532           364     12.5          4.08
# 759      NaN        1641           396     34.1         18.23
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_AP = AP.loc[AP['Food Name'] == 'Crumpets, toasted']
Filt_AP
# Out:
#     Food Code          Food Name Description Group Previous  \
# 902    11-989  Crumpets, toasted   9 samples    AP  11-535
#
#                                   Main data references Footnote Energy (kJ)  \
# 902  LGC, Nutrient analysis of bread and morning go...      NaN         894
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 902           211      1.0           0.1             41.5          3
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 902       38.5       3.1          7.5     2.57

# %%
Filt_AP['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11424\739656524.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AP['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Puddings

# %%
AS = Prod_C.loc[Prod_C['Group']== 'AS']
AS
# Out:
#     Food Code                            Food Name  \
# 893   11-1055             Crumble, apple, homemade
# 894   11-1056             Crumble, fruit, homemade
# 895   11-1020               Crumble, fruit, retail
# 896    11-994  Crumble, fruit, wholemeal, homemade
# 901   11-1057  Crumble, with pie filling, homemade
#
#                                            Description Group Previous  \
# 893                                             Recipe    AS  11-694
# 894  Recipe, apple, plum, gooseberry, rhubarb, home...    AS  11-695
# 895  10 samples, including apple, apple and blackbe...    AS  11-546
# 896           Apple, gooseberry, plum, rhubarb recipe.    AS  11-595
# 901                                             Recipe    AS  11-693
#
#                                   Main data references Footnote Energy (kJ)  \
# 893                                       Updated 2014      NaN         851
# 894                                       Updated 2014      NaN         848
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_AS = AS.loc[AS['Food Name'] == 'Crumble, fruit, retail']
Filt_AS
# Out:
#     Food Code               Food Name  \
# 895   11-1020  Crumble, fruit, retail
#
#                                            Description Group Previous  \
# 895  10 samples, including apple, apple and blackbe...    AS  11-546
#
#                                   Main data references Footnote Energy (kJ)  \
# 895  ADAS Laboratories, Nutrient analysis of ice cr...      NaN         958
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 895           228      8.3          3.97             34.1       21.2
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 895       12.7       2.3          2.4     0.21

# %%
Filt_AS['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11424\346938166.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AS['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Savouries

# %%
AT = Prod_C.loc[Prod_C['Group']== 'AT']
AT
# Out:
#     Food Code                               Food Name  \
# 583    11-997  Cheese and onion rolls, pastry, retail
# 863    11-902                 Couscous, plain, cooked
# 864    11-901                    Couscous, plain, raw
#
#                       Description Group Previous  \
# 583   Oven-baked pastry, 3 brands    AT  11-550
# 863  8 samples, 8 products, wheat    AT      NaN
# 864  8 samples, 8 products, wheat    AT      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 583  RHM, Nutrient analysis of manufactured foods f...      NaN        1379
# 863                       Calculated from raw (11-901)      NaN         769
# 864      LGC Nutrient survey of flours and grains 2005      NaN        1554
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 583           331     20.0          8.97               28          3
# 863           181      1.0          0.18             34.1          1
# ...

# %% [markdown]
# **Reduced**

# %%
Remove_AT = ['Couscous, plain, cooked']

# %%
Filt_AT = AT[~AT['Food Name'].isin(Remove_AT)]
Filt_AT
# Out:
#     Food Code                               Food Name  \
# 583    11-997  Cheese and onion rolls, pastry, retail
# 864    11-901                    Couscous, plain, raw
#
#                       Description Group Previous  \
# 583   Oven-baked pastry, 3 brands    AT  11-550
# 864  8 samples, 8 products, wheat    AT      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 583  RHM, Nutrient analysis of manufactured foods f...      NaN        1379
# 864      LGC Nutrient survey of flours and grains 2005      NaN        1554
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 583           331     20.0          8.97               28          3
# 864           367      2.1           0.3               72        2.1
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 583         22       2.9          8.2     0.78
# 864       69.9       3.7         13.1     0.01

# %%
Filt_AT['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11424\2561790092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AT['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
#                                                   Milk and milk products

# %% [markdown]
# Processed milks

# %%
BAR = Prod_C.loc[Prod_C['Group']== 'BAR']
BAR
# Out:
#     Food Code                    Food Name  \
# 818    12-546  Coffeemate, whitener powder
#
#                                       Description Group Previous  \
# 818  Analysis and manufacturer's data (Carnation)   BAR  12-027
#
#                                   Main data references Footnote Energy (kJ)  \
# 818  Milk Products and Eggs Supplement, 1989; Vitam...      NaN        2222
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 818           533     34.5            26             53.5        9.2
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 818          0         0          2.1        1

# %%
BAR['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11424\1916122628.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BAR['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Milk-based drinks

# %%
BH = Prod_C.loc[Prod_C['Group']== 'BH']
BH
# Out:
#     Food Code                                          Food Name  \
# 778    12-545                                       Cocoa powder
# 779    12-563       Cocoa powder, made up with semi-skimmed milk
# 780    12-564            Cocoa powder, made up with skimmed milk
# 781    12-565              Cocoa powder, made up with whole milk
# 832    12-566        Complan powder, savoury, made up with water
# 833    12-568  Complan powder, sweet, made up with semi-skimm...
# 834    12-569   Complan powder, sweet, made up with skimmed milk
# 835    12-567          Complan powder, sweet, made up with water
# 836    12-570     Complan powder, sweet, made up with whole milk
#
#                                            Description Group Previous  \
# 778                               10 samples, 2 brands    BH  12-082
# 779  Recipe. Calculated from 4g powder, 4g sugar an...    BH  12-437
# 780  Recipe. Calculated from 4g powder, 4g sugar an...    BH  12-438
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_BH = BH.loc[BH['Food Name'] == 'Cocoa powder']
Filt_BH
# Out:
#     Food Code     Food Name           Description Group Previous  \
# 778    12-545  Cocoa powder  10 samples, 2 brands    BH  12-082
#
#                                   Main data references Footnote Energy (kJ)  \
# 778  MW4 (1978).  Additional data from 50-1050. Vit...      NaN        1617
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 778           390     21.7          12.8             10.5          0
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 778       10.5      30.4         23.1     0.09

# %%
Filt_BH['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11424\4223810532.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_BH['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Fresh creams (pasteurised)

# %%
BJC = Prod_C.loc[Prod_C['Group']== 'BJC']
BJC
# Out:
#     Food Code                                     Food Name  \
# 878    12-337           Cream, dairy, extra thick (24% fat)
# 881    12-592                         Cream, fresh, clotted
# 882    12-334  Cream, fresh, double, including Jersey cream
# 883    12-332                          Cream, fresh, single
# 884    12-333                        Cream, fresh, whipping
# 885    12-112                            Cream, half, fresh
# 889    12-335                       Creme fraiche, full fat
# 890    12-336                       Creme fraiche, half fat
#
#                                            Description Group  \
# 878  16 samples, 4 brands, average of summer and wi...   BJC
# 881                               17 samples, 3 brands   BJC
# 882   Average of 22 samples of summer and winter cream   BJC
# 883   Average of 22 samples of summer and winter cream   BJC
# 884   Average of 22 samples of summer and winter cream   BJC
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_BJC = ['Cream, fresh, clotted','Cream, fresh, single', 'Cream, fresh, whipping','Creme fraiche, half fat']

# %%
Filt_BJC = BJC[BJC['Food Name'].isin(Priority_BJC)]
Filt_BJC
# Out:
#     Food Code                Food Name  \
# 881    12-592    Cream, fresh, clotted
# 883    12-332     Cream, fresh, single
# 884    12-333   Cream, fresh, whipping
# 890    12-336  Creme fraiche, half fat
#
#                                           Description Group  \
# 881                              17 samples, 3 brands   BJC
# 883  Average of 22 samples of summer and winter cream   BJC
# 884  Average of 22 samples of summer and winter cream   BJC
# 890                        8 samples, 6 brands, plain   BJC
#
#                    Previous  \
# 881                 12-117
# 883  12-113 12-842 50-212
# 884          12-115 50-214
# 890                     NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 881  Milk Products and Eggs Supplement, 1989. Iodin...      NaN        2413
# 883  Reviewed 2013. LGC, Nutrient analysis of ‘othe...      NaN         798
# 884  Reviewed 2013. LGC, Nutrient analysis of ‘othe...      NaN        1568
# ...

# %% [markdown]
# Banana split (BP) removed. Didn't find it in tesco products.

# %%
BTM = Prod_B.loc[Prod_B['Group']== 'BTM']
BTM
# Out:
#    Food Code                                          Food Name  \
# 92    12-500  Baking fat and margarine (75-90% fat), hard block
#
#                                           Description Group        Previous  \
# 92  10 samples, 4 products, including Stork and ow...   BTM  17-539 17-018
#
#                                  Main data references Footnote Energy (kJ)  \
# 92  DH, Nutrient analysis of a range of processed ...      NaN        2827
#
#    Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 92           688     76.4         26.41                0          0
#
#    Starch (g) Fibre (g)  Protein (g) Salt (g)
# 92          0         0          0.0      1.5

# %%
BTM['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\338318624.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BTM['Super Group'] = 'Milk and milk products'

# %% [markdown]
#                                                        Vegetables

# %% [markdown]
# Beans and lentils

# %%
DB = Prod_B.loc[Prod_B['Group']== 'DB']
DB
# Out:
#     Food Code                                          Food Name  \
# 88     13-578              Baked beans, canned in barbecue sauce
# 89     13-532                Baked beans, canned in tomato sauce
# 90     13-535  Baked beans, canned in tomato sauce, reduced s...
# 91     13-579  Baked beans, canned in tomato sauce, with pork...
# 120    13-042  Beans, aduki, whole, dried, boiled in unsalted...
# 121    13-041                    Beans, aduki, whole, dried, raw
# 122    13-049                    Beans, balor, ends trimmed, raw
# 123    13-063  Beans, blackeye, whole, dried, boiled in unsal...
# 124    13-062                 Beans, blackeye, whole, dried, raw
# 125    13-067                           Beans, broad, dried, raw
# 126    13-648      Beans, broad, whole, boiled in unsalted water
# 127    13-064                           Beans, broad, whole, raw
# 128    13-559          Beans, butter, canned, re-heated, drained
# ...

# %% [markdown]
# **Reduced**

# %%
Priortiy_DB = ['Baked beans, canned in tomato sauce','Beans, aduki, whole, dried, raw','Beans, blackeye, whole, dried, raw','Beans, butter, dried, raw','Beans, chick peas, Kabuli, whole, dried, raw',
       'Beans, cluster, raw','Beans, edamame, frozen, boiled in unsalted water','Beans, green, raw','Beans, haricot, whole, dried, raw','Beans, mung, dahl, dried, raw',
               'Beans, pigeon peas, whole, dried, raw','Beans, pinto, dried, raw','Beans, red kidney, dried, raw','Beans, runner, raw', 'Beans, soya, dried, raw', 'Beans, sword, raw',
              'Beansprouts, mung, raw','Black gram, urad gram, whole, dried, raw']

# %%
Filt_DB = DB[DB['Food Name'].isin(Priortiy_DB)]
Filt_DB
# Out:
#     Food Code                                         Food Name  \
# 89     13-532               Baked beans, canned in tomato sauce
# 121    13-041                   Beans, aduki, whole, dried, raw
# 124    13-062                Beans, blackeye, whole, dried, raw
# 130    13-070                         Beans, butter, dried, raw
# 136    13-074      Beans, chick peas, Kabuli, whole, dried, raw
# 137    13-080                               Beans, cluster, raw
# 138    13-667  Beans, edamame, frozen, boiled in unsalted water
# 140    13-514                                 Beans, green, raw
# 143    13-086                 Beans, haricot, whole, dried, raw
# 145    13-098                     Beans, mung, dahl, dried, raw
# 152    13-102             Beans, pigeon peas, whole, dried, raw
# 154    13-106                          Beans, pinto, dried, raw
# 158    13-109                     Beans, red kidney, dried, raw
# 160    13-112                                Beans, runner, raw
# ...

# %%
Filt_DB['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\2223481409.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DB['Super Group'] = 'Vegetables'

# %% [markdown]
# Vegetables, general

# %%
DG = Prod_B.loc[Prod_B['Group']== 'DG']
DG
# Out:
#     Food Code                                          Food Name  \
# 272    13-633                 Beetroot, cooked in unsalted water
# 273    13-166                         Beetroot, pickled, drained
# 274    13-164                                      Beetroot, raw
# 413    13-168               Breadfruit, boiled in unsalted water
# 414    13-167                                    Breadfruit, raw
# 448    13-583            Broccoli, green, boiled in salted water
# 449    13-503          Broccoli, green, boiled in unsalted water
# 450    13-502                               Broccoli, green, raw
# 451    13-504                           Broccoli, green, steamed
# 452    13-176  Broccoli, purple sprouting, boiled in unsalted...
# 453    13-174                    Broccoli, purple sprouting, raw
# 457    13-630         Brussels sprouts, boiled in unsalted water
# 458    13-177                              Brussels sprouts, raw
#
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_DG = ['Beetroot, raw','Breadfruit, raw','Broccoli, green, raw','Broccoli, purple sprouting, raw','Brussels sprouts, raw']

# %%
Filt_DG = DG[DG['Food Name'].isin(Priority_DG)]
Filt_DG
# Out:
#     Food Code                        Food Name  \
# 274    13-164                    Beetroot, raw
# 414    13-167                  Breadfruit, raw
# 450    13-502             Broccoli, green, raw
# 453    13-174  Broccoli, purple sprouting, raw
# 458    13-177            Brussels sprouts, raw
#
#                                            Description Group Previous  \
# 274                       Top and root trimmed, peeled    DG  50-741
# 414                                 Literature sources    DG      NaN
# 450  22 samples, autumn and winter, UK grown and im...    DG  13-170
# 453              Tough stems and coarse leaves removed    DG      NaN
# 458                 Base trimmed, outer leaves removed    DG  50-746
#
#                                   Main data references Footnote Energy (kJ)  \
# 274  IFR, The nutritional composition of retail veg...      NaN         176
# 414      Vegetables, Herbs and Spices Supplement, 1991      NaN         444
# ...

# %%
Filt_DG['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\1311392366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DG['Super Group'] = 'Vegetables'

# %% [markdown]
# Vegetable Dishes

# %%
DR = Prod_B.loc[Prod_B['Group']== 'DR']
DR
# Out:
#     Food Code                                          Food Name  \
# 115    15-664                   Bean loaf, mixed beans, homemade
# 116    15-665  Beanburger, aduki, fried in rapeseed oil, home...
# 117    15-666  Beanburger, butter bean, fried in rapeseed oil...
# 118    15-667  Beanburger, red kidney bean, fried in rapeseed...
# 119    15-668            Beanburger, soya, fried in rapeseed oil
# 278    15-669              Bhaji, aubergine and potato, homemade
# 279    15-670  Bhaji, aubergine, pea, potato and cauliflower,...
# 280    15-672  Bhaji, cabbage and pea, with butter ghee, home...
# 281    15-673  Bhaji, cabbage and pea, with rapeseed oil, hom...
# 282    15-674   Bhaji, cabbage and potato, with butter, homemade
# 283    15-397  Bhaji, cabbage and potato, with rapeseed oil, ...
# 284    15-675      Bhaji, cabbage and potato, with vegetable oil
# 285    15-016                         Bhaji, cabbage and spinach
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_DR = ['Bean loaf, mixed beans, homemade','Beanburger, red kidney bean, fried in rapeseed oil','Bhaji, aubergine and potato, homemade','Bhaji, cabbage and pea, with butter ghee, homemade','Bhaji, carrot, potato and pea, with butter, homemade','Bubble and squeak, fried in sunflower oil, homemade']

# %%
Filt_DR = DR[DR['Food Name'].isin(Priority_DR)]
Filt_DR
# Out:
#     Food Code                                          Food Name  \
# 115    15-664                   Bean loaf, mixed beans, homemade
# 118    15-667  Beanburger, red kidney bean, fried in rapeseed...
# 278    15-669              Bhaji, aubergine and potato, homemade
# 280    15-672  Bhaji, cabbage and pea, with butter ghee, home...
# 287    15-676  Bhaji, carrot, potato and pea, with butter, ho...
# 460    15-703  Bubble and squeak, fried in sunflower oil, hom...
#
#                                            Description Group Previous  \
# 115                 Recipe from dietary survey records    DR  15-387
# 118                      Recipe from Leeds Polytechnic    DR  15-390
# 278            Recipe from review of recipe collection    DR  15-391
# 280  Bangladeshi dish. Recipe adapted from literatu...    DR  15-394
# 287   Punjabi dish. Recipe from dietary survey records    DR  15-398
# 460  Fried cabbage and potato. Recipe from Wiles et...    DR  15-426
#
# ...

# %%
Filt_DR['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\2508077319.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DR['Super Group'] = 'Vegetables'

# %% [markdown]
#                                                         Fruit

# %%
F = Prod_B.loc[Prod_B['Group']== 'F']
F
# Out:
#     Food Code                                   Food Name  \
# 355    14-364  Blackberry and apple, stewed without sugar
#
#                                            Description Group Previous  \
# 355  Calculated from 400g blackberries, 550g apples...     F  14-055
#
#     Main data references Footnote Energy (kJ) Energy (kcal)  Fat (g)  \
# 355         Updated 2014      NaN         148            35      0.2
#
#     Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 355          0.03              6.3        6.3          0       1.9
#
#      Protein (g) Salt (g)
# 355          0.5     0.01

# %%
F['Super Group'] = 'Fruit'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\305761203.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   F['Super Group'] = 'Fruit'

# %% [markdown]
# Fruit General

# %%
FA = Prod_B.loc[Prod_B['Group']== 'FA']
FA
# Out:
#     Food Code                                    Food Name  \
# 64     14-043                           Babaco, flesh only
# 96     14-318                          Bananas, flesh only
# 97     14-347  Bananas, raw, flesh only, weighed with skin
# 351    14-388                            Blackberries, raw
# 352    14-049              Blackberries, stewed with sugar
# 353    14-050           Blackberries, stewed without sugar
# 354    14-349      Blackberry and apple, stewed with sugar
# 358    14-053                           Blackcurrants, raw
# 359    14-054             Blackcurrants, stewed with sugar
# 360    14-055          Blackcurrants, stewed without sugar
# 364    14-325                                  Blueberries
#
#                                            Description Group Previous  \
# 64                                  Literature sources    FA      NaN
# 96   11 samples, including Fairtrade and organic, p...    FA  14-045
# ...

# %% [markdown]
# ##### Reduced

# %%
Priority_FA = ['Babaco, flesh only', 'Bananas, flesh only','Blackberries, raw','Blackcurrants, raw','Blueberries']

# %%
Filt_FAR = FA[FA['Food Name'].isin(Priority_FA)]
Filt_FAR
# Out:
#     Food Code            Food Name  \
# 64     14-043   Babaco, flesh only
# 96     14-318  Bananas, flesh only
# 351    14-388    Blackberries, raw
# 358    14-053   Blackcurrants, raw
# 364    14-325          Blueberries
#
#                                            Description Group Previous  \
# 64                                  Literature sources    FA      NaN
# 96   11 samples, including Fairtrade and organic, p...    FA  14-045
# 351                        11 samples, UK and imported    FA   14-048
# 358                        Whole fruit, stalks removed    FA  50-872
# 364  21 samples, summer and winter, UK grown and im...    FA      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 64   Cashel et al (1989) Composition of foods, Aust...      NaN          91
# 96   DH, Nutrient analysis of fruit and vegetables,...      NaN         380
# 351  PHE, Nutrient analysis of fresh and processed ...      NaN         216
# ...

# %%
Filt_FAR['Super Group'] = 'Fruit'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\15316282.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_FAR['Super Group'] = 'Fruit'

# %% [markdown]
#                                                     Nuts and Seeds

# %%
G = Prod_B.loc[Prod_B['Group']== 'G']
G
# Out:
#     Food Code              Food Name         Description Group  Previous  \
# 415    14-895  Breadnut seeds, dried  Literature sources     G  14-810
#
#                                   Main data references Footnote Energy (kJ)  \
# 415  McCarthy and Matthews (1984) Composition of fo...      NaN           N
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 415             N      1.7           0.5                N          N
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 415          N      14.9         10.2     0.13

# %%
G['Super Group'] = 'Nuts and Seeds'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\2234915281.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   G['Super Group'] = 'Nuts and Seeds'

# %% [markdown]
# Nuts and seeds, general

# %%
GA = Prod_B.loc[Prod_B['Group']== 'GA']
GA
# Out:
#     Food Code                                         Food Name  \
# 102    14-804                       Barcelona nuts, Kernel only
# 103    14-805  Barcelona nuts, kernel only, weighed with shells
# 277    14-806                                        Betel nuts
# 376    14-871                          Brazil nuts, kernel only
# 377    14-884     Brazil nuts, kernel only, weighed with shells
#
#                 Description Group               Previous  \
# 102             Kernel only    GA                    NaN
# 103  Calculated from 14-804    GA                    NaN
# 277      Literature sources    GA                    NaN
# 376              10 samples    GA  14-808 14-856 50-974
# 377  Calculated from 14-871    GA         14-809 50-975
#
#                                   Main data references Footnote Energy (kJ)  \
# 102  MW4, 1978. Values reviewed for Fruit and Nuts ...      NaN        2726
# 103  MW4, 1978. Values reviewed for Fruit and Nuts ...      NaN        1690
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_GA = ['Betel nuts']

# %%
Filt_GA = GA[GA['Food Name'].isin(Priority_GA)]
Filt_GA
# Out:
#     Food Code   Food Name         Description Group Previous  \
# 277    14-806  Betel nuts  Literature sources    GA      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 277  Wu Leung et al. (1972) Food composition table ...      NaN        1448
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 277           345     10.2          7.65             51.5        1.8
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 277       49.7      11.4          6.1     0.19

# %%
Filt_GA['Super Group'] = 'Nuts and Seeds'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\3953553267.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_GA['Super Group'] = 'Nuts and Seeds'

# %% [markdown]
#                                                    Herbs and Spices

# %%
H = Prod_B.loc[Prod_B['Group']== 'H']
H
# Out:
#     Food Code             Food Name  \
# 108    13-805  Basil, dried, ground
# 109    13-804          Basil, fresh
# 114    13-806       Bay leaf, dried
# 276    13-807   Betel leaves, fresh
#
#                                            Description Group Previous  \
# 108                                 Literature sources     H      NaN
# 109                   6 samples and literature sources     H      NaN
# 114  Reviewed 2013. LGC, Fruit and Vegetables, 1989...     H      NaN
# 276                                 Literature sources     H      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 108  Marsh et al. (1977) Composition of foods: spic...      NaN         866
# 109  Reviewed 2013. LGC, Fruit and Vegetables, 1989...      NaN         114
# 114  Marsh et al. (1977) Composition of foods: spic...      NaN        1477
# 276  Chughtai and Khan (1960) Nutritive value of fo...      NaN         274
#
# ...

# %% [markdown]
# **Reduced**

# %%
Remove_H = ['Bay leaf, dried','Betel leaves, fresh']

# %%
Filt_H = H[~H['Food Name'].isin(Remove_H)]
Filt_H
# Out:
#     Food Code             Food Name                       Description Group  \
# 108    13-805  Basil, dried, ground                Literature sources     H
# 109    13-804          Basil, fresh  6 samples and literature sources     H
#
#     Previous                               Main data references Footnote  \
# 108      NaN  Marsh et al. (1977) Composition of foods: spic...      NaN
# 109      NaN  Reviewed 2013. LGC, Fruit and Vegetables, 1989...      NaN
#
#     Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 108         866           209      4.0           0.2             10.1
# 109         114            27      0.8          0.04              1.1
#
#     Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 108        1.7        8.4      37.7         14.4     0.09
# 109        0.3        0.8       1.6          3.1     0.02

# %%
Filt_H['Super Group'] = 'Herbs and Spices'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\854041242.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_H['Super Group'] = 'Herbs and Spices'

# %% [markdown]
#                                                    Fish and Fish Products

# %% [markdown]
# White Fish

# %%
JA = Prod_B.loc[Prod_B['Group']== 'JA']
JA
# Out:
#     Food Code                                          Food Name  \
# 110    16-386                       Bass, sea, flesh only, baked
# 111    16-463  Bass, sea, flesh only, baked, weighed with bon...
# 112    16-385                         Bass, sea, flesh only, raw
# 113    16-464  Bass, sea, flesh only, raw, weighed with bones...
# 275    16-003                                          Bele, raw
# 365    16-004                                          Boal, raw
# 368    16-005                                        Bombay duck
# 444    16-006                                    Bream, Sea, raw
#
#                                            Description Group Previous  \
# 110        10 samples, 10 products, frozen and chilled    JA      NaN
# 111  Calculated from baked 16-386 using edible conv...    JA      NaN
# 112        10 samples, 10 products, frozen and chilled    JA      NaN
# 113  Calculated from 16-385 using edible conversion...    JA      NaN
# ...

# %% [markdown]
# **Reduced**

# %%
Priortiy_JA = ['Bass, sea, flesh only, raw','Bele, raw', 'Boal, raw', 'Bombay duck', 'Bream, Sea, raw']

# %%
Filt_JA = JA[JA['Food Name'].isin(Priortiy_JA)]
Filt_JA
# Out:
#     Food Code                   Food Name  \
# 112    16-385  Bass, sea, flesh only, raw
# 275    16-003                   Bele, raw
# 365    16-004                   Boal, raw
# 368    16-005                 Bombay duck
# 444    16-006             Bream, Sea, raw
#
#                                            Description Group Previous  \
# 112        10 samples, 10 products, frozen and chilled    JA      NaN
# 275  Literature sources. Imported frozen from Bangl...    JA      NaN
# 365  Literature sources. Imported frozen from Bangl...    JA      NaN
# 368  Literature sources. Salted dried fish, also kn...    JA      NaN
# 444                                 Literature sources    JA      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 112  DH, Nutrient analysis of fish and fish product...      NaN         703
# 275            Fish and Fish Products Supplement, 1993      NaN         286
# ...

# %%
Filt_JA['Super Group'] = 'Fish and Fish Products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\2823660487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_JA['Super Group'] = 'Fish and Fish Products'

# %% [markdown]
# Fatty Fish

# %%
JC = Prod_B.loc[Prod_B['Group']== 'JC']
JC
# Out:
#     Food Code                                          Food Name  \
# 65     16-169                                         Bacha, raw
# 362    16-170                       Bloater, flesh only, grilled
# 363    16-171  Bloater, flesh only, grilled, weighed with bon...
#
#                                            Description Group Previous  \
# 65   Literature sources. Imported frozen from Bangl...    JC      NaN
# 362                          Salted and smoked herring    JC      NaN
# 363                     Calculated from grilled 16-170    JC      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 65   Gopalan et al (1980) Nutritive value of Indian...      NaN         515
# 362                                          MW1, 1940      NaN        1043
# 363                                          MW1, 1940      NaN         677
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# ...

# %% [markdown]
# **Reduced**

# %%
Remove_JC = ['Bloater, flesh only, grilled, weighed with bones and skin','Bloater, flesh only, grilled']

# %%
Filt_JC = JC[~JC['Food Name'].isin(Remove_JC)]
Filt_JC
# Out:
#    Food Code   Food Name                                        Description  \
# 65    16-169  Bacha, raw  Literature sources. Imported frozen from Bangl...
#
#    Group Previous                               Main data references Footnote  \
# 65    JC      NaN  Gopalan et al (1980) Nutritive value of Indian...      NaN
#
#    Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 65         515           123      5.6           0.8                0
#
#    Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 65          0          0         0         18.1     0.24

# %%
Filt_JC['Super Group'] = 'Fish and Fish Products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\3410602523.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_JC['Super Group'] = 'Fish and Fish Products'

# %% [markdown]
#                                                   Meat and meat products

# %% [markdown]
# Bacon

# %%
MAA = Prod_B.loc[Prod_B['Group']== 'MAA']
MAA
# Out:
#    Food Code                                    Food Name  \
# 66    19-644             Bacon loin steaks, lean, grilled
# 67    19-645      Bacon rashers, back, dry-cured, grilled
# 68    19-498               Bacon rashers, back, dry-fried
# 69    19-499    Bacon rashers, back, fat trimmed, grilled
# 70    19-646        Bacon rashers, back, fat trimmed, raw
# 71    19-500                 Bacon rashers, back, grilled
# 72    19-501          Bacon rashers, back, grilled crispy
# 73    19-502              Bacon rashers, back, microwaved
# 74    19-497                     Bacon rashers, back, raw
# 75    19-009   Bacon rashers, back, reduced salt, grilled
# 76    19-659         Bacon rashers, back, smoked, grilled
# 77    19-647      Bacon rashers, back, sweetcure, grilled
# 78    19-660  Bacon rashers, back, 'tendersweet', grilled
# 79    19-648     Bacon rashers, middle, fried in corn oil
# 80    19-503               Bacon rashers, middle, grilled
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_MAA = MAA.loc[MAA['Food Name'] == 'Bacon rashers, back, fat trimmed, raw']
Filt_MAA
# Out:
#    Food Code                              Food Name  \
# 70    19-646  Bacon rashers, back, fat trimmed, raw
#
#                                           Description Group Previous  \
# 70  24 samples, back fat removed. MLC data and cal...   MAA  19-007
#
#                                  Main data references Footnote Energy (kJ)  \
# 70  LGC, Nutrient analysis of retail cuts of bacon...      NaN         568
#
#    Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 70           136      6.7           2.5                0          0
#
#    Starch (g) Fibre (g)  Protein (g) Salt (g)
# 70          0         0         18.8      2.5

# %%
Filt_MAA['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\11230460.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_MAA['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Beef

# %%
MAC = Prod_B.loc[Prod_B['Group']== 'MAC']
MAC
# Out:
#     Food Code                                         Food Name  \
# 174    18-009       Beef, braising steak, braised, lean and fat
# 175    18-008          Beef, braising steak, braised, lean only
# 176    18-006                   Beef, braising steak, raw, lean
# 177    18-007           Beef, braising steak, raw, lean and fat
# 178    18-010           Beef, braising steak, slow cooked, lean
# ..        ...                                               ...
# 264    18-085                  Beef, topside, raw, lean and fat
# 265    18-088          Beef, topside, roasted medium-rare, lean
# 266    18-089  Beef, topside, roasted medium-rare, lean and fat
# 267    18-090            Beef, topside, roasted well-done, lean
# 268    18-091    Beef, topside, roasted well-done, lean and fat
#
#                               Description Group  Previous  \
# 174   Calculated from 90% lean and 9% fat   MAC
# 175                            10 samples   MAC       NaN
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_MAC = ['Beef, braising steak, raw, lean','Beef, fat, average, raw','Beef, fillet steak, raw, lean','Beef, flank, raw, lean',
                'Beef, fore-rib/rib-roast, raw, lean','Beef, lean, average, raw','Beef, mince, raw','Beef, rump steak, raw, lean','Beef, silverside, raw, lean',
               'Beef, sirloin steak, raw, lean','Beef, stewing steak, raw, lean','Beef, topside, raw, lean']

# %%
Filt_MAC = MAC[MAC['Food Name'].isin(Priority_MAC)]
Filt_MAC
# Out:
#     Food Code                            Food Name  \
# 176    18-006      Beef, braising steak, raw, lean
# 185    18-003              Beef, fat, average, raw
# 193    18-016        Beef, fillet steak, raw, lean
# 197    18-024               Beef, flank, raw, lean
# 202    18-028  Beef, fore-rib/rib-roast, raw, lean
# 207    18-468             Beef, lean, average, raw
# 213    18-469                     Beef, mince, raw
# 226    18-043          Beef, rump steak, raw, lean
# 232    18-054          Beef, silverside, raw, lean
# 250    18-064       Beef, sirloin steak, raw, lean
# 256    18-076       Beef, stewing steak, raw, lean
# 263    18-084             Beef, topside, raw, lean
#
#                                        Description Group  \
# 176                                     10 samples   MAC
# 185  Average of 10 different cuts, trimmed of lean   MAC
# 193                                     17 samples   MAC
# 197                                      6 samples   MAC
# ...

# %%
Filt_MAC['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\2390852533.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_MAC['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Burgers and grillsteaks

# %%
MBG = Prod_B.loc[Prod_B['Group']== 'MBG']
MBG
# Out:
#     Food Code                                          Food Name  \
# 464    19-651                     Burger, beef, 62-85% beef, raw
# 465    19-546                Burger, beef, 62-85%, beef, grilled
# 466    19-490  Burger, beef, 98-99% beef, fried in vegetable oil
# 467    19-491                 Burger, beef, 98-99% beef, grilled
# 468    19-492                     Burger, beef, 98-99% beef, raw
# 473    19-493                          Burger, Big Mac, takeaway
# 474    19-545                     Burger, cheeseburger, takeaway
# 475    19-315                          Burger, chicken, takeaway
# 477    19-544                        Burger, hamburger, takeaway
# 478    19-487      Burger, Quarter Pounder with cheese, takeaway
# 479    19-514                          Burger, Whopper, takeaway
#
#                                            Description Group        Previous  \
# 464  10 samples, 6 brands containing onion, frozen ...   MBG         19-042
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_MBG = MBG.loc[MBG['Food Name'] == 'Burger, beef, 98-99% beef, raw']
Priority_MBG
# Out:
#     Food Code                       Food Name  \
# 468    19-492  Burger, beef, 98-99% beef, raw
#
#                                  Description Group        Previous  \
# 468  8 samples, 3 brands, chilled and frozen   MBG  19-309 50-503
#
#                                   Main data references Footnote Energy (kJ)  \
# 468  LGC, Analytical survey of meat products, 1990-...      NaN        1211
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 468           292     24.7         10.71              0.1        0.1
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 468          0       0.5         17.1     0.73

# %%
Priority_MBG['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\3962426368.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Priority_MBG['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Poulty/Chicken

# %%
MCA = Prod_B.loc[Prod_B['Group']== 'MCA']
MCA
# Out:
#     Food Code                                        Food Name  \
# 476    18-502  Burger, chicken/turkey, coated, retail, grilled
#
#                                       Description Group Previous  \
# 476  10 samples, 7 products, breaded and battered   MCA      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 476  DH, Nutrient analysis of a range of processed ...      NaN        1109
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 476           266     15.5          2.63               17        0.9
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 476       16.1       0.8         14.2     0.96

# %%
MCA['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\4110797459.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MCA['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Removed **MBG** as I already have beef products in my list. These are either composite food or already captured.

# %% [markdown]
# Offal

# %%
MG = Prod_B.loc[Prod_B['Group']== 'MG']
MG
# Out:
#     Food Code            Food Name Description Group Previous  \
# 372    18-392  Brain, lamb, boiled  11 samples    MG      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 372  MW4, 1978. Values reviewed for Meat Products a...      NaN         523
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 372           126      8.8             2                0          0
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 372          0         0         11.6     0.53

# %%
MG['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\156133725.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MG['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Meat Products

# %%
MI = Prod_B.loc[Prod_B['Group']== 'MI']
MI
# Out:
#     Food Code                 Food Name          Description Group Previous  \
# 349    19-114  Black pudding, dry-fried  8 samples, 6 brands    MI  50-505
# 350    19-113        Black pudding, raw  8 samples, 6 brands    MI      336
# 375    19-115                     Brawn           10 samples    MI  50-506
#
#                                   Main data references Footnote Energy (kJ)  \
# 349  Reviewed 2013. LGC, Analytical survey of meat ...      NaN        1244
# 350  LGC, Analytical survey of meat products, 1990-...      NaN        1159
# 375  MW4, 1978. Values reviewed for Meat Products a...      NaN         637
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 349           299     21.5           8.5             15.1        0.2
# 350           279     20.6           7.7             13.3          0
# 375           153     11.5          3.86                0          0
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_MI = MI.loc[MI['Food Name'] == 'Black pudding, raw']
Filt_MI
# Out:
#     Food Code           Food Name          Description Group Previous  \
# 350    19-113  Black pudding, raw  8 samples, 6 brands    MI      336
#
#                                   Main data references Footnote Energy (kJ)  \
# 350  LGC, Analytical survey of meat products, 1990-...      NaN        1159
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 350           279     20.6           7.7             13.3          0
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 350       13.3         2          9.1     2.08

# %%
Filt_MI['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\1350248321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_MI['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Didn't include these Meat Dishes **(MR)**. Composite food. Making a note that these types of dishes were categorised under Meat and Meat products

# %% [markdown]
# Fats and Oils

# %%
OA = Prod_B.loc[Prod_B['Group']== 'OA']
OA
# Out:
#     Food Code                            Food Name  \
# 480    17-685                       Butter, salted
# 481    17-655      Butter, spreadable (75-80% fat)
# 482    17-656  Butter, spreadable, light (60% fat)
# 483    17-661                     Butter, unsalted
#
#                                            Description Group Previous  \
# 480   Average of UK/Irish, Danish, French, New Zealand    OA  17-485
# 481  9 samples, 7 products, containing butter and v...    OA  17-486
# 482  11 samples, 7 products, containing vegetable o...    OA      NaN
# 483   Average of UK/Irish, Danish, French, New Zealand    OA      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 480  LGC, Nutrient analysis of ‘other’ milk and cre...      NaN        3062
# 481  DH, Nutrient analysis of a range of processed ...      NaN        2941
# 482  DH, Nutrient analysis of a range of processed ...      NaN        2249
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_OA  = ['Butter, salted','Butter, unsalted']

# %%
Filt_OA = OA[OA['Food Name'].isin(Priority_OA)]
Filt_OA
# Out:
#     Food Code         Food Name  \
# 480    17-685    Butter, salted
# 483    17-661  Butter, unsalted
#
#                                           Description Group Previous  \
# 480  Average of UK/Irish, Danish, French, New Zealand    OA  17-485
# 483  Average of UK/Irish, Danish, French, New Zealand    OA      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 480  LGC, Nutrient analysis of ‘other’ milk and cre...      NaN        3062
# 483  LGC, Nutrient analysis of ‘other’ milk and cre...      NaN        3062
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 480           745     82.2         52.09              0.6        0.6
# 483           745     82.2         52.09              0.6        0.6
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 480          0         0          0.6     1.83
# 483          0         0          0.6     0.02

# %%
Filt_OA['Super Group'] = 'Fats and Oils'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\2982959108.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_OA['Super Group'] = 'Fats and Oils'

# %% [markdown]
# Animal Fats

# %%
OB = Prod_B.loc[Prod_B['Group']== 'OB']
OB
# Out:
#     Food Code            Food Name             Description Group Previous  \
# 484    17-001  Butteroil, unsalted  Calculated from butter    OB      NaN
#
#                      Main data references Footnote Energy (kJ) Energy (kcal)  \
# 484  Miscellaneous Foods Supplement, 1994      NaN        3685           896
#
#      Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 484     99.3          65.6                0          0          0         0
#
#      Protein (g) Salt (g)
# 484          0.6     0.04

# %%
OB['Super Group'] = 'Fats and Oils'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\3884697610.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   OB['Super Group'] = 'Fats and Oils'

# %% [markdown]
#                                                         Beverages

# %% [markdown]
# Powdered drinks and essences

# %%
PAA = Prod_B.loc[Prod_B['Group']== 'PAA']
PAA
# Out:
#     Food Code                                   Food Name  \
# 462    17-823  Build up, powder, shake, assorted flavours
# 463    17-728    Build-up powder, soup, assorted flavours
#
#                                            Description Group Previous  \
# 462  Manufacturer's data (Nestlé). Average of choco...   PAA  17-534
# 463  Manufacturer's data (Nestlé). Average of chick...   PAA  17-535
#
#                                   Main data references Footnote Energy (kJ)  \
# 462  Industry data 2013; some minerals estimated fr...      NaN        1460
# 463                                Industry data, 2013      NaN        1748
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 462           345      0.7           0.4               60         59
# 463           416     14.9           4.6               53       13.6
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 462          0       8.2         20.5     0.63
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_PAA = PAA.loc[PAA['Food Name'] == 'Build up, powder, shake, assorted flavours']
Filt_PAA
# Out:
#     Food Code                                   Food Name  \
# 462    17-823  Build up, powder, shake, assorted flavours
#
#                                            Description Group Previous  \
# 462  Manufacturer's data (Nestlé). Average of choco...   PAA  17-534
#
#                                   Main data references Footnote Energy (kJ)  \
# 462  Industry data 2013; some minerals estimated fr...      NaN        1460
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 462           345      0.7           0.4               60         59
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 462          0       8.2         20.5     0.63

# %%
Filt_PAA['Super Group'] = 'Beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\5251205.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_PAA['Super Group'] = 'Beverages'

# %% [markdown]
# Squash and cordials

# %%
PCC = Prod_B.loc[Prod_B['Group']== 'PCC']
PCC
# Out:
#     Food Code                                   Food Name  \
# 104    17-844                       Barley water, diluted
# 105    17-743                     Barley water, undiluted
# 356    17-845    Blackcurrant juice drink/squash, diluted
# 357    17-737  Blackcurrant juice drink/squash, undiluted
#
#                                         Description Group Previous  \
# 104  Calculated from 50g concentrate to 200ml water   PCC  17-186
# 105                       Orange and lemon flavours   PCC  17-185
# 356  Calculated from 38g concentrate to 250ml water   PCC  17-188
# 357                 Including Ribena and own brands   PCC  17-187
#
#                                   Main data references Footnote Energy (kJ)  \
# 104  Miscellaneous Foods Supplement, 1994; and indu...      NaN          77
# 105  Miscellaneous Foods Supplement, 1994; and indu...      NaN         388
# 356  LFRA, Nutritional analysis of soft drinks, 199...      NaN         118
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_PCC = ['Barley water, undiluted','Blackcurrant juice drink/squash, undiluted']

# %%
Filt_PCC = PCC[PCC['Food Name'].isin(Priority_PCC)]
Filt_PCC
# Out:
#     Food Code                                   Food Name  \
# 105    17-743                     Barley water, undiluted
# 357    17-737  Blackcurrant juice drink/squash, undiluted
#
#                          Description Group Previous  \
# 105        Orange and lemon flavours   PCC  17-185
# 357  Including Ribena and own brands   PCC  17-187
#
#                                   Main data references Footnote Energy (kJ)  \
# 105  Miscellaneous Foods Supplement, 1994; and indu...      NaN         388
# 357  LFRA, Nutritional analysis of soft drinks, 199...      NaN         893
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 105            91      0.0             0             22.5       20.5
# 357           210      0.0             0             52.4       52.4
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 105          2         0          0.3     0.04
# 357          0         0          0.1     0.04

# %%
Filt_PCC['Super Group'] = 'Beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\801278599.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_PCC['Super Group'] = 'Beverages'

# %% [markdown]
#                                                 Alcoholic beverages

# %%
QA = Prod_B.loc[Prod_B['Group'] == 'QA']
QA
# Out:
#     Food Code                        Food Name  \
# 269    17-506  Beer, bitter, average (<4% ABV)
# 270    17-208      Beer, bitter, best, premium
# 271    17-748   Beer, bitter, strong (>5% ABV)
#
#                                            Description Group Previous  \
# 269  <4% ABV. 5 samples from different brewers; can...    QA  17-207
# 270  Mixed sample from different brewers, ABV 4-5%,...    QA      NaN
# 271  >5% ABV, including Old Speckled Hen, Hobgoblin...    QA      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 269  Reviewed 2013. LGC, Alcoholic beverages, soft ...      NaN         125
# 270  Reviewed 2013. LGC, Alcoholic beverages, soft ...      NaN         140
# 271   Estimated from beer, bitter, best, premium, 2013      NaN         177
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 269            30      0.0             0              2.1        2.1
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_QA = QA.loc[QA['Food Name'] == 'Beer, bitter, best, premium']
Filt_QA
# Out:
#     Food Code                    Food Name  \
# 270    17-208  Beer, bitter, best, premium
#
#                                            Description Group Previous  \
# 270  Mixed sample from different brewers, ABV 4-5%,...    QA      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 270  Reviewed 2013. LGC, Alcoholic beverages, soft ...      NaN         140
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 270            33      0.0             0              2.1        2.1
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 270          0         0          0.3     0.02

# %%
Filt_QA['Super Group'] = 'Alcoholic beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\1162960103.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_QA['Super Group'] = 'Alcoholic beverages'

# %% [markdown]
#                                                 Sugars, preserves and snacks

# %% [markdown]
# Chocolate confectionery

# %%
SEA = Prod_B.loc[Prod_B['Group'] == 'SEA']
SEA
# Out:
#     Food Code                             Food Name  \
# 371    17-766  Bounty bar and own brand equivalents
#
#                                     Description Group Previous  \
# 371  Manufacturer's data (Mars). milk chocolate   SEA  17-546
#
#                                   Main data references Footnote Energy (kJ)  \
# 371  Data from manufacturer (Mars). Total carbohydr...      NaN        2044
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 371           489     26.3          20.5             57.8       48.2
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 371        9.6       3.2          3.7     0.45

# %%
SEA['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\3172647907.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SEA['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
# Savoury snacks

# %%
SN = Prod_B.loc[Prod_B['Group']== 'SN']
SN
# Out:
#     Food Code   Food Name                                        Description  \
# 369    17-764  Bombay mix  20 samples; savoury mix of gram flour, assorte...
#
#     Group Previous                               Main data references  \
# 369    SN  14-807   LGC, Survey on the Nutritional Composition of ...
#
#     Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 369      NaN        2153           517     32.9          3.95
#
#     Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 369             32.1        2.3       29.8       8.8         18.8      1.6

# %%
SN['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\1807899663.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SN['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
#                                         Soups, sauces and miscellaneous foods

# %% [markdown]
# Soups

# %% [markdown]
# Didn't find on Tesco groceries search

# %%
WAA = Prod_B.loc[Prod_B['Group']== 'WAA']
WAA
# Out:
#     Food Code                Food Name Description Group Previous  \
# 370    17-770  Bouillabaisse, homemade      Recipe   WAA  17-597
#
#     Main data references Footnote Energy (kJ) Energy (kcal)  Fat (g)  \
# 370         Updated 2014      NaN         610           147     10.5
#
#     Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 370          1.34              1.6        1.5        0.1       0.4
#
#      Protein (g) Salt (g)
# 370         11.3     0.14

# %%
WAA['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\2995164211.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WAA['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
# Sauces

# %% [markdown]
# Didn't include home made barbecue sause, data for barbecue source exist.

# %%
WC = Prod_B.loc[Prod_B['Group']== 'WC']
WC
# Out:
#     Food Code                 Food Name Description Group  Previous  \
# 101    17-769  Barbecue sauce, homemade      Recipe    WC  17-609
#
#     Main data references Footnote Energy (kJ) Energy (kcal)  Fat (g)  \
# 101         Updated 2014      NaN        1181           284     21.0
#
#     Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 101         12.45             20.3       20.2        0.1       1.7
#
#      Protein (g) Salt (g)
# 101          2.7     0.98

# %%
WC['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\392309441.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WC['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
# Dairy sauces

# %%
WCD = Prod_B.loc[Prod_B['Group']== 'WCD']
WCD
# Out:
#     Food Code                                          Food Name Description  \
# 385    17-664  Bread sauce, made with semi-skimmed milk, HOME...      Recipe
# 386    17-771      Bread sauce, made with skimmed milk, homemade      Recipe
# 387    17-772        Bread sauce, made with whole milk, homemade      Recipe
#
#     Group Previous Main data references Footnote Energy (kJ) Energy (kcal)  \
# 385   WCD  17-520          Updated 2013      NaN           N             N
# 386   WCD  17-567          Updated 2014      NaN         362            86
# 387   WCD  17-519          Updated 2014      NaN         440           105
#
#      Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 385      2.5          1.43             14.4        5.1        8.9         N
# 386      1.4          0.41             13.7        4.6        9.1       0.5
# 387      3.7           1.9             13.4        4.3        9.1       0.5
#
#      Protein (g) Salt (g)
# ...

# %% [markdown]
# **Reduce**

# %%
Filt_WCD = WCD.loc[WCD['Food Name'] == 'Bread sauce, made with skimmed milk, homemade']
Filt_WCD
# Out:
#     Food Code                                      Food Name Description  \
# 386    17-771  Bread sauce, made with skimmed milk, homemade      Recipe
#
#     Group Previous Main data references Footnote Energy (kJ) Energy (kcal)  \
# 386   WCD  17-567          Updated 2014      NaN         362            86
#
#      Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 386      1.4          0.41             13.7        4.6        9.1       0.5
#
#      Protein (g) Salt (g)
# 386          4.3     0.36

# %%
Filt_WCD['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\634448677.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_WCD['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
# Non-salad sauces

# %%
WCN = Prod_B.loc[Prod_B['Group']== 'WCN']
WCN
# Out:
#     Food Code                        Food Name  \
# 100    17-705                   Barbecue sauce
# 454    17-706               Brown fruity sauce
# 455    17-678  Brown sauce, reduced salt/sugar
#
#                                    Description Group Previous  \
# 100                  Literature sources (1980)   WCN  17-289
# 454                       10 bottles, 4 brands   WCN  17-293
# 455  Estimated from brown sauce and label data   WCN      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 100  Miscellaneous Foods Supplement, 1994; and indu...      NaN         611
# 454  LFRA, Nutrient analysis of miscellaneous foods...      NaN         400
# 455  LFRA, Nutrient analysis of miscellaneous foods...      NaN         348
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 100           144      0.1             0             34.1       28.5
# 454            94      0.1             0             21.8       19.4
# ...

# %% [markdown]
# **Reduced**

# %%
Remove_WCN = ['Brown fruity sauce']

# %%
Filt_WCN = WCN[~WCN['Food Name'].isin(Remove_WCN)]
Filt_WCN
# Out:
#     Food Code                        Food Name  \
# 100    17-705                   Barbecue sauce
# 455    17-678  Brown sauce, reduced salt/sugar
#
#                                    Description Group Previous  \
# 100                  Literature sources (1980)   WCN  17-289
# 455  Estimated from brown sauce and label data   WCN      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 100  Miscellaneous Foods Supplement, 1994; and indu...      NaN         611
# 455  LFRA, Nutrient analysis of miscellaneous foods...      NaN         348
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 100           144      0.1             0             34.1       28.5
# 455            82      0.1             0             19.2         14
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 100        5.6       1.2          1.0     1.58
# 455        5.3       0.7          0.7     0.98

# %%
Filt_WCN['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\714788789.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_WCN['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
# Miscellaneous foods

# %%
WY = Prod_B.loc[Prod_B['Group']== 'WY']
WY
# Out:
#     Food Code            Food Name  \
# 93     17-355        Baking powder
# 169    17-514         Beef extract
# 319    17-356  Bicarbonate of soda
#
#                                       Description Group         Previous  \
# 93                    6 samples of the same brand    WY         50-1174
# 169  Mixed sample including Bovril and own brands    WY  17-361 50-1175
# 319                         As sodium bicarbonate    WY              NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 93                            Reviewed 2013. MW4, 1978      NaN         681
# 169  Reviewed 2013. LFRA, Nutritional analysis of s...      NaN         778
# 319               Miscellaneous Foods Supplement, 1994      NaN           0
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 93            160      0.0             0             34.4          0
# 169           183      0.6          0.23              2.9        0.4
# ...

# %%
WY['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27356\647319242.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WY['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
#                                               **Join Reduced Tables**

# %%
Red34 = pd.concat([Red33,WY], axis=0, join='inner')
Red34.tail(15)
# Out:
#     Food Code                                      Food Name  \
# 484    17-001                            Butteroil, unsalted
# 462    17-823     Build up, powder, shake, assorted flavours
# 105    17-743                        Barley water, undiluted
# 357    17-737     Blackcurrant juice drink/squash, undiluted
# 270    17-208                    Beer, bitter, best, premium
# 371    17-766           Bounty bar and own brand equivalents
# 369    17-764                                     Bombay mix
# 370    17-770                        Bouillabaisse, homemade
# 101    17-769                       Barbecue sauce, homemade
# 386    17-771  Bread sauce, made with skimmed milk, homemade
# 100    17-705                                 Barbecue sauce
# 455    17-678                Brown sauce, reduced salt/sugar
# 93     17-355                                  Baking powder
# 169    17-514                                   Beef extract
# ...

# %% [markdown]
#                                                        Export

# %%
Red34.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced_B.csv')
