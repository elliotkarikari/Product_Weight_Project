# %% [markdown]
# # Product Weighting Project

# %% [markdown]
#                                          Data Reduction - Food Purchased In Store

# %% [markdown]
# ###### Import Necessary Libraries

# %%
import pandas as pd

# %% [markdown]
# Read in Data

# %%
Labelled = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Raw Data\Labelling2021_watercress.csv')

# %% [markdown]
# ### Products beginning with a 'T'

# %%
prod_t = Labelled.loc[Labelled['Food Name'].str.startswith('T')]
prod_t
# Out:
#      Food Code                              Food Name  \
# 2668    15-885                               Tabouleh
# 2669    14-847                           Tahini paste
# 2670    14-264            Tamarillos, flesh and seeds
# 2671    14-265                               Tamarind
# 2672    13-855                 Tamarind leaves, fresh
# ...        ...                                    ...
# 2791    13-392  Turnip tops, boiled in unsalted water
# 2792    13-391       Turnip, boiled in unsalted water
# 2793    13-389                Turnip, flesh only, raw
# 2794    17-694                               Twiglets
# 2795    12-547                               Tzatziki
#
#                                             Description Group Previous  \
# 2668  Recipe. Bulgur wheat based salad. Recipe from ...    DR  15-604
# 2669     Literature sources and calculation from 14-844    GA  50-996
# 2670                                 Literature sources    FA      NaN
# 2671                                 Literature sources    FA      NaN
# 2672                                 Literature sources     H      NaN
# ...                                                 ...   ...      ...
# 2791                          Leaves; boiled 20 minutes    DG      NaN
# 2792  Peeled thinly, diced and boiled 19 minutes, ba...    DG  50-834
# 2793                                      Peeled thinly    DG  50-833
# 2794              20 samples, savoury wholewheat sticks    SN  17-150
# 2795                 Yogurt-based Greek starter. Recipe    BN  12-410
#
#                                    Main data references Footnote Energy (kJ)  \
# 2668                                       Updated 2014      NaN           N
# 2669  Reviewed 2013. McCarthy and Matthews (1984) Co...      NaN        2639
# 2670                    Fruit and Nuts Supplement, 1992      NaN         149
# 2671                    Fruit and Nuts Supplement, 1992      NaN        1052
# 2672  Gopalan et al. (1980) Nutritive value of India...      NaN         498
# ...                                                 ...      ...         ...
# 2791  MW4, 1978. Values revised for Fruit and Nuts S...      NaN          77
# 2792  Reviewed 2013. IFR, The nutritional compositio...      NaN          70
# 2793  As Vegetables, Herbs and Spices Supplement, 19...      NaN         128
# 2794  LGC, Survey of the composition of savoury snac...      NaN        1744
# 2795                                       Updated 2013      NaN         321
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2668             N      4.6          0.29             15.6        0.6
# 2669           639     58.9           8.4              0.8        0.4
# 2670            36      0.3           0.1              4.6        4.6
# 2671           248      0.3           0.1             56.5       38.8
# 2672           118      2.1          0.78             16.5        0.5
# ...            ...      ...           ...              ...        ...
# 2791            19      0.0             0              0.2        0.1
# 2792            17      0.2             0                2        1.9
# 2793            31      0.3             0              4.8        4.6
# 2794           415     11.8           1.6             57.6        0.6
# 2795            77      5.5          3.58              3.4          3
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2668         15         N          2.8     0.01
# 2669        0.5       9.3         21.8     0.05
# 2670          0       3.3          2.0        0
# 2671       17.7       5.1          2.3     0.04
# 2672         16       5.1          5.8     0.03
# ...         ...       ...          ...      ...
# 2791        0.1       3.5          2.7     0.02
# 2792        0.1         2          0.6     0.07
# 2793        0.2       2.4          0.9     0.04
# 2794         57      12.4         13.5        2
# 2795        0.4       0.3          3.4     0.92
#
# [128 rows x 17 columns]

# %% [markdown]
# Products within a Group (provide identification of the food group and food type to which the food belongs)

# %%
prod_t.groupby('Group')['Food Name'].count()
# Out:
# Group
# AA      1
# AF      1
# AP      5
# AS      3
# BN      1
# BR      6
# DB      3
# DG     17
# DR      8
# FA      2
# GA      3
# H       7
# JA      4
# JC     10
# JR      1
# MCO    21
# MG      7
# MI      1
# MR      5
# PAA     1
# PAC     7
# PCA     1
# PE      1
# SC      1
# SEA     3
# SEC     3
# SN      2
# WCN     3
# Name: Food Name, dtype: int64

# %% [markdown]
# ## *Reducing products based on its most basic form. Improve as you go on*

# %% [markdown]
#                                                 Cereals and cereal products

# %% [markdown]
# Remoced AA - Flours, grains and starches

# %%
af = prod_t.loc[prod_t['Group']== 'AF']
af
# Out:
#      Food Code              Food Name            Description Group Previous  \
# 2739    11-925  Tortilla, wheat, soft  8 samples, 6 products    AF  11-632
#
#                                    Main data references Footnote Energy (kJ)  \
# 2739  LGC, Nutrient analysis of bread and morning go...      NaN        1220
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2739           289      5.7           2.5             49.1        1.9
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2739       47.2       3.6          8.6     1.56

# %%
af['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_75088\2854512313.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   af['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Puddings

# %%
AS = prod_t.loc[prod_t['Group']== 'AS']
AS
# Out:
#      Food Code                      Food Name  \
# 2685   11-1028       Tart, bakewell, homemade
# 2690    11-845  Tarts, bakewell, iced, retail
# 2741   11-1126         Treacle tart, homemade
#
#                                             Description Group Previous  \
# 2685                                             Recipe    AS  11-685
# 2690  10 samples, 7 products, including large, slice...    AS  11-426
# 2741                                             Recipe    AS  11-602
#
#                                    Main data references Footnote Energy (kJ)  \
# 2685                                       Updated 2014      NaN        1919
# 2690  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1746
# 2741                                       Updated 2014      NaN        1627
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2685           461     30.4           8.8             38.3       21.9
# 2690           416     16.8          6.94             62.2       43.4
# 2741           388     15.9          5.84             56.1         33
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2685       16.5       1.5          7.7     0.53
# 2690       18.8       1.1          3.4     0.33
# 2741       23.1       1.7          4.2     0.65

# %%
AS['Food Name'].unique()
# Out:
# array(['Tart, bakewell, homemade', 'Tarts, bakewell, iced, retail',
#        'Treacle tart, homemade'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
filt_AS = AS[AS['Food Name'] == 'Tarts, bakewell, iced, retail']
filt_AS
# Out:
#      Food Code                      Food Name  \
# 2690    11-845  Tarts, bakewell, iced, retail
#
#                                             Description Group Previous  \
# 2690  10 samples, 7 products, including large, slice...    AS  11-426
#
#                                    Main data references Footnote Energy (kJ)  \
# 2690  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1746
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2690           416     16.8          6.94             62.2       43.4
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2690       18.8       1.1          3.4     0.33

# %%
filt_AS['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_75088\3274103439.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_AS['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
#                                                     Milk and milk products

# %% [markdown]
# Yogurts

# %%
bn = prod_t.loc[prod_t['Group']== 'BN']
bn
# Out:
#      Food Code Food Name                         Description Group Previous  \
# 2795    12-547  Tzatziki  Yogurt-based Greek starter. Recipe    BN  12-410
#
#      Main data references Footnote Energy (kJ) Energy (kcal)  Fat (g)  \
# 2795         Updated 2013      NaN         321            77      5.5
#
#      Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 2795          3.58              3.4          3        0.4       0.3
#
#       Protein (g) Salt (g)
# 2795          3.4     0.92

# %%
bn['Super Group'] = ' Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_75088\2291127035.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bn['Super Group'] = ' Milk and milk products'

# %% [markdown]
# Puddings and chilled desserts

# %%
br = prod_t.loc[prod_t['Group']== 'BR']
br
# Out:
#      Food Code                   Food Name  \
# 2691    12-461  Tarts, custard, individual
# 2709    12-476                    Tiramisu
# 2737    12-408                Torte, fruit
# 2743    12-409       Trifle, fruit, retail
# 2744    12-600            Trifle, homemade
# 2745    12-601  Trifle, with Dream Topping
#
#                                             Description Group  \
# 2691                             10 samples, 6 products    BR
# 2709         10 samples, 6 products, frozen and chilled    BR
# 2737  8 samples, 5 brands including lemon, raspberry...    BR
# 2743                               12 samples, 7 brands    BR
# 2744                                             Recipe    BR
# 2745  Recipe, substituting 25g of made up dream topp...    BR
#
#                           Previous  \
# 2691                       11-537
# 2709                           NaN
# 2737                       11-423
# 2743  12-915 12-252 50-289 11-335
# 2744                       12-417
# 2745                       12-432
#
#                                    Main data references Footnote Energy (kJ)  \
# 2691  DH, Nutrient analysis survey of biscuits, buns...      NaN        1105
# 2709  ADAS Laboratories, Nutrient analysis of ice cr...      NaN        1034
# 2737  Reviewed 2013. RHM, Nutrient content of select...      NaN        1089
# 2743  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN         716
# 2744                                       Updated 2014      NaN         703
# 2745                                       Updated 2014      NaN         641
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2691           264     14.3          5.87             26.7       13.5
# 2709           248     14.0          8.61             25.8       20.3
# 2737           261     15.5          9.35               26       16.7
# 2743           171      9.0          5.56             18.7       14.9
# 2744           168      7.9          4.42               20         16
# 2745           153      5.9          3.37             20.6       16.5
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2691       13.2       1.1          6.7     0.29
# 2709        4.1         1          4.1     0.17
# 2737          9       1.2          3.8     0.22
# 2743        3.8       2.4          2.6     0.16
# 2744          4       0.4          2.8     0.19
# 2745        4.1       0.4          2.9      0.2

# %% [markdown]
# **Reduced**

# %%
br['Food Name'].unique()
# Out:
# array(['Tarts, custard, individual', 'Tiramisu', 'Torte, fruit',
#        'Trifle, fruit, retail', 'Trifle, homemade',
#        'Trifle, with Dream Topping'], dtype=object)

# %%
priority_br = ['Tiramisu', 'Trifle, fruit, retail']

# %%
filt_br = br[br['Food Name'].isin(priority_br)]
filt_br
# Out:
#      Food Code              Food Name  \
# 2709    12-476               Tiramisu
# 2743    12-409  Trifle, fruit, retail
#
#                                      Description Group  \
# 2709  10 samples, 6 products, frozen and chilled    BR
# 2743                        12 samples, 7 brands    BR
#
#                           Previous  \
# 2709                           NaN
# 2743  12-915 12-252 50-289 11-335
#
#                                    Main data references Footnote Energy (kJ)  \
# 2709  ADAS Laboratories, Nutrient analysis of ice cr...      NaN        1034
# 2743  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN         716
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2709           248     14.0          8.61             25.8       20.3
# 2743           171      9.0          5.56             18.7       14.9
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2709        4.1         1          4.1     0.17
# 2743        3.8       2.4          2.6     0.16

# %%
filt_br['Super Group'] = ' Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_75088\3074923105.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_br['Super Group'] = ' Milk and milk products'

# %% [markdown]
#                                                         Vegetables

# %%
db = prod_t.loc[prod_t['Group']== 'DB']
db
# Out:
#      Food Code                        Food Name  \
# 2702    13-118                           Tempeh
# 2715    13-570         Tofu, soya bean, steamed
# 2716    13-571  Tofu, soya bean, steamed, fried
#
#                                          Description Group Previous  \
# 2702    Fermented soya bean cake. Literature sources    DB      NaN
# 2715              Soya bean curd; 7 assorted samples    DB  13-119
# 2716  Calculated from steamed and Literature sources    DB  13-120
#
#                                    Main data references Footnote Energy (kJ)  \
# 2702      Vegetables, Herbs and Spices Supplement, 1991      NaN         709
# 2715      Vegetables, Herbs and Spices Supplement, 1991      NaN         305
# 2716  Vegetables, Herbs and Spices Supplement, 1991;...      NaN        1116
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2702           169      6.4          1.32                5        0.9
# 2715            73      4.2           0.5              0.6        0.2
# 2716           268     17.7          2.92              1.8        0.8
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2702        4.2       4.3         20.7     0.02
# 2715        0.3       0.4          8.1     0.01
# 2716        0.8       3.9         23.5     0.03

# %% [markdown]
# **Reduced**

# %%
filt_db = db[db['Food Name'] == 'Tofu, soya bean, steamed']
filt_db
# Out:
#      Food Code                 Food Name                         Description  \
# 2715    13-570  Tofu, soya bean, steamed  Soya bean curd; 7 assorted samples
#
#      Group Previous                           Main data references Footnote  \
# 2715    DB  13-119   Vegetables, Herbs and Spices Supplement, 1991      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 2715         305            73      4.2           0.5              0.6
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2715        0.2        0.3       0.4          8.1     0.01

# %%
filt_db['Super Group'] = ' Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_75088\1269290310.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_db['Super Group'] = ' Vegetables'

# %% [markdown]
# Vegetables, general

# %%
dg = prod_t.loc[prod_t['Group']== 'DG']
dg
# Out:
#      Food Code                                          Food Name  \
# 2674    13-375                                        Tannia, raw
# 2677    13-380                                   Taro leaves, raw
# 2678    13-381                               Taro leaves, steamed
# 2679    13-377                                        Taro, baked
# 2680    13-378                     Taro, boiled in unsalted water
# 2681    13-376                                          Taro, raw
# 2682    13-379                                      Taro, steamed
# 2719    13-531                                       Tomato puree
# 2721    13-530                   Tomatoes, canned, whole contents
# 2722    13-519                              Tomatoes, cherry, raw
# 2723    13-603              Tomatoes, standard, fried in corn oil
# 2724    13-602          Tomatoes, standard, fried in rapeseed oil
# 2725    13-518  Tomatoes, standard, grilled, flesh and seeds only
# 2726    13-517                            Tomatoes, standard, raw
# 2791    13-392              Turnip tops, boiled in unsalted water
# 2792    13-391                   Turnip, boiled in unsalted water
# 2793    13-389                            Turnip, flesh only, raw
#
#                                             Description Group Previous  \
# 2674                                 Literature sources    DG      NaN
# 2677                                 Literature sources    DG      NaN
# 2678                    Ref. 4 and calculation from raw    DG      NaN
# 2679  Literature sources and calculation from raw, b...    DG      NaN
# 2680              Literature sources, boiled 20 minutes    DG      NaN
# 2681                    Analysis and literature sources    DG      NaN
# 2682           Literature sources. Calculation from raw    DG      NaN
# 2719  9 samples, 8 brands, double concentrate, no ad...    DG  17-516
# 2721  12 samples, 9 brands, whole and chopped, no ad...    DG  13-461
# 2722  21 samples, autumn and winter, UK grown and im...    DG  13-388
# 2723                             Calculated from 13-517    DG  13-385
# 2724                             Calculated from 13-517    DG  50-828
# 2725                    As raw, grilled for 6-9 minutes    DG  13-461
# 2726  22 samples, autumn and winter, UK grown and im...    DG  13-460
# 2791                          Leaves; boiled 20 minutes    DG      NaN
# 2792  Peeled thinly, diced and boiled 19 minutes, ba...    DG  50-834
# 2793                                      Peeled thinly    DG  50-833
#
#                                    Main data references Footnote Energy (kJ)  \
# 2674      Vegetables, Herbs and Spices Supplement, 1991      NaN         433
# 2677      Vegetables, Herbs and Spices Supplement, 1991      NaN         181
# 2678  Haytowitz and Matthews (1986) Composition of f...      NaN          98
# 2679      Vegetables, Herbs and Spices Supplement, 1991      NaN         600
# 2680      Vegetables, Herbs and Spices Supplement, 1991      NaN         417
# 2681      Vegetables, Herbs and Spices Supplement, 1991      NaN         478
# 2682      Vegetables, Herbs and Spices Supplement, 1991      NaN         452
# 2719  DH, Nutrient analysis of fruit and vegetables,...      NaN         340
# 2721  DH, Nutrient analysis of fruit and vegetables,...      NaN          94
# 2722  DH, Nutrient analysis of fruit and vegetables,...      NaN         108
# 2723  DH, Nutrient analysis of fruit and vegetables,...      NaN         386
# 2724  DH, Nutrient analysis of fruit and vegetables,...      NaN         386
# 2725  DH, Nutrient analysis of fruit and vegetables,...      NaN          75
# 2726  DH, Nutrient analysis of fruit and vegetables,...      NaN          71
# 2791  MW4, 1978. Values revised for Fruit and Nuts S...      NaN          77
# 2792  Reviewed 2013. IFR, The nutritional compositio...      NaN          70
# 2793  As Vegetables, Herbs and Spices Supplement, 19...      NaN         128
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2674           102      0.4          0.08             22.3        0.2
# 2677            43      0.9           0.2              2.6        2.2
# 2678            24      0.5           0.1              1.4        1.2
# 2679           142      0.2          0.02             29.4        1.3
# 2680            99      0.2          0.02             20.5          1
# 2681           113      0.2          0.02             23.9        1.1
# 2682           107      0.2          0.02             22.4        1.1
# 2719            81      0.2          0.04             12.9       12.9
# 2721            22      0.1          0.01              3.8        3.8
# 2722            26      0.5           0.1              3.6        3.6
# 2723            93      7.7          1.12              4.5        4.5
# 2724            93      7.7          0.53              4.5        4.5
# 2725            18      0.2          0.04              3.4        3.4
# 2726            17      0.1          0.03                3          3
# 2791            19      0.0             0              0.2        0.1
# 2792            17      0.2             0                2        1.9
# 2793            31      0.3             0              4.8        4.6
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2674       22.1       2.3          1.3     0.01
# 2677        0.4       3.7          4.4     0.01
# 2678        0.2         2          2.4     0.01
# 2679       28.2       7.9          1.7     0.01
# 2680       19.5       5.1          1.2     0.01
# 2681       22.8       5.1          1.4     0.01
# 2682       21.4       5.1          1.3     0.01
# 2719          0       4.7          4.4     0.12
# 2721          0       0.8          1.1     0.01
# 2722          0       1.3          1.1     0.01
# 2723          0       1.5          0.8     0.01
# 2724          0       1.5          0.8     0.01
# 2725          0         0          0.6     0.01
# 2726          0         1          0.5     0.01
# 2791        0.1       3.5          2.7     0.02
# 2792        0.1         2          0.6     0.07
# 2793        0.2       2.4          0.9     0.04

# %%
dg['Food Name'].unique()
# Out:
# array(['Tannia, raw', 'Taro leaves, raw', 'Taro leaves, steamed',
#        'Taro, baked', 'Taro, boiled in unsalted water', 'Taro, raw',
#        'Taro, steamed', 'Tomato puree',
#        'Tomatoes, canned, whole contents', 'Tomatoes, cherry, raw',
#        'Tomatoes, standard, fried in corn oil',
#        'Tomatoes, standard, fried in rapeseed oil',
#        'Tomatoes, standard, grilled, flesh and seeds only',
#        'Tomatoes, standard, raw', 'Turnip tops, boiled in unsalted water',
#        'Turnip, boiled in unsalted water', 'Turnip, flesh only, raw'],
#       dtype=object)

# %% [markdown]
# **Reduced**

# %%
priority_dg = ['Tomatoes, canned, whole contents', 'Tomatoes, standard, raw','Turnip, flesh only, raw']

# %%
filt_dg = dg[dg['Food Name'].isin(priority_dg)]
filt_dg
# Out:
#      Food Code                         Food Name  \
# 2721    13-530  Tomatoes, canned, whole contents
# 2726    13-517           Tomatoes, standard, raw
# 2793    13-389           Turnip, flesh only, raw
#
#                                             Description Group Previous  \
# 2721  12 samples, 9 brands, whole and chopped, no ad...    DG  13-461
# 2726  22 samples, autumn and winter, UK grown and im...    DG  13-460
# 2793                                      Peeled thinly    DG  50-833
#
#                                    Main data references Footnote Energy (kJ)  \
# 2721  DH, Nutrient analysis of fruit and vegetables,...      NaN          94
# 2726  DH, Nutrient analysis of fruit and vegetables,...      NaN          71
# 2793  As Vegetables, Herbs and Spices Supplement, 19...      NaN         128
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2721            22      0.1          0.01              3.8        3.8
# 2726            17      0.1          0.03                3          3
# 2793            31      0.3             0              4.8        4.6
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2721          0       0.8          1.1     0.01
# 2726          0         1          0.5     0.01
# 2793        0.2       2.4          0.9     0.04

# %%
filt_dg['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_75088\412654847.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_dg['Super Group'] = 'Vegetables'

# %% [markdown]
# Removed DR - Vegetable dishes

# %% [markdown]
#                                                     Nuts and seeds

# %%
ga = prod_t.loc[prod_t['Group']== 'GA']
ga
# Out:
#      Food Code     Food Name                                     Description  \
# 2669    14-847  Tahini paste  Literature sources and calculation from 14-844
# 2706    14-848     Tigernuts                              Literature sources
# 2740    14-849     Trail mix         10 samples; mix of nuts and dried fruit
#
#      Group  Previous                               Main data references  \
# 2669    GA   50-996   Reviewed 2013. McCarthy and Matthews (1984) Co...
# 2706    GA       NaN                    Fruit and Nuts Supplement, 1992
# 2740    GA  50-1041   Reviewed 2013. LGC, Nutritional composition of...
#
#      Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 2669      NaN        2639           639     58.9           8.4
# 2706      NaN        1811           435     23.8             4
# 2740      NaN        1880           451     28.5          5.37
#
#      Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2669              0.8        0.4        0.5       9.3         21.8     0.05
# 2706             42.2       15.3       26.9      17.4          4.3        0
# 2740             37.1         37        0.1       5.1          9.1     0.07

# %%
ga['Super Group'] = 'Nuts and seeds'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_75088\1779072657.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ga['Super Group'] = 'Nuts and seeds'

# %% [markdown]
#                                                     Herbs and spices

# %%
h = prod_t.loc[prod_t['Group']== 'H']
h
# Out:
#      Food Code                  Food Name  \
# 2672    13-855     Tamarind leaves, fresh
# 2673    13-856  Tamarind pulp, flesh only
# 2683    13-858    Tarragon, dried, ground
# 2684    13-857            Tarragon, fresh
# 2704    13-883       Thyme, dried, ground
# 2705    13-893               Thyme, fresh
# 2790    13-861           Turmeric, ground
#
#                                     Description Group Previous  \
# 2672                         Literature sources     H      NaN
# 2673      No seeds or shell; literature sources     H      NaN
# 2683                         Literature sources     H      NaN
# 2684  LGC, 5 samples and calculation from dried     H      NaN
# 2704                         Literature sources     H  13-860
# 2705       4 samples and calculation from dried     H  13-859
# 2790                         Literature sources     H      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2672  Gopalan et al. (1980) Nutritive value of India...      NaN         498
# 2673      Vegetables, Herbs and Spices Supplement, 1991      NaN        1177
# 2683  Marsh et al. (1977) Composition of foods: spic...      NaN        1374
# 2684               LGC, Fruit and vegetables, 1989-1990      NaN         223
# 2704  Marsh et al. (1977) Composition of foods: spic...      NaN        1383
# 2705  LGC, Fruit and vegetables, 1989-1990; and data...      NaN         461
# 2790      Vegetables, Herbs and Spices Supplement, 1991      NaN        1467
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2672           118      2.1          0.78             16.5        0.5
# 2673           278      0.3          0.06             62.9       62.9
# 2683           326      7.2          1.88             38.9        8.2
# 2684            53      1.1          0.29              5.7        1.2
# 2704           332      7.4           2.7             38.7        1.7
# 2705           111      2.5           1.2             12.9        0.6
# 2790           350      7.0           2.9             53.7        3.2
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2672         16       5.1          5.8     0.03
# 2673          0       5.3          3.2     0.06
# 2683       30.7       7.4         22.8     0.16
# 2684        4.5       3.5          3.4     0.02
# 2704         37        37          9.1     0.14
# 2705       12.3      12.3          3.0     0.05
# 2790       50.5      22.7          6.7     0.08

# %% [markdown]
# **Reduced**

# %%
priority_h = ['Tarragon, dried, ground','Thyme, dried, ground','Turmeric, ground']

# %%
filt_h = h[h['Food Name'].isin(priority_h)]
filt_h
# Out:
#      Food Code                Food Name         Description Group Previous  \
# 2683    13-858  Tarragon, dried, ground  Literature sources     H      NaN
# 2704    13-883     Thyme, dried, ground  Literature sources     H  13-860
# 2790    13-861         Turmeric, ground  Literature sources     H      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2683  Marsh et al. (1977) Composition of foods: spic...      NaN        1374
# 2704  Marsh et al. (1977) Composition of foods: spic...      NaN        1383
# 2790      Vegetables, Herbs and Spices Supplement, 1991      NaN        1467
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2683           326      7.2          1.88             38.9        8.2
# 2704           332      7.4           2.7             38.7        1.7
# 2790           350      7.0           2.9             53.7        3.2
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2683       30.7       7.4         22.8     0.16
# 2704         37        37          9.1     0.14
# 2790       50.5      22.7          6.7     0.08

# %%
filt_h['Super Group'] = 'Herbs and spices'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_75088\16012654.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_h['Super Group'] = 'Herbs and spices'

# %% [markdown]
#                                                 Fish and fish products

# %% [markdown]
# Molluscs

# %%
ja = prod_t.loc[prod_t['Group']== 'JA']
ja
# Out:
#      Food Code                                          Food Name  \
# 2707    16-154                                       Tilapia, raw
# 2761    16-156                        Turbot, flesh only, grilled
# 2762    16-157  Turbot, flesh only, grilled, weighed with bone...
# 2763    16-155                            Turbot, flesh only, raw
#
#                                       Description Group Previous  \
# 2707            Literature sources. Type of bream    JA      NaN
# 2761  Calculated from raw, whole fish and fillets    JA      NaN
# 2762               Calculated from grilled 16-156    JA      NaN
# 2763                           Literature sources    JA      NaN
#
#                          Main data references Footnote Energy (kJ)  \
# 2707  Fish and Fish Products Supplement, 1993      NaN         358
# 2761  Fish and Fish Products Supplement, 1993      NaN         515
# 2762  Fish and Fish Products Supplement, 1993      NaN         317
# 2763  Fish and Fish Products Supplement, 1993      NaN         401
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2707            85      1.5           0.3                0          0
# 2761           122      3.5           0.9                0          0
# 2762            75      2.1           0.5                0          0
# 2763            95      2.7           0.7                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2707          0         0         17.8     0.13
# 2761          0         0         22.7     0.02
# 2762          0         0         14.1     0.02
# 2763          0         0         17.7     0.17

# %% [markdown]
# **Reduced**

# %%
filt_ja = ja[ja['Food Name'] == 'Tilapia, raw' ]
filt_ja
# Out:
#      Food Code     Food Name                        Description Group  \
# 2707    16-154  Tilapia, raw  Literature sources. Type of bream    JA
#
#      Previous                     Main data references Footnote Energy (kJ)  \
# 2707      NaN  Fish and Fish Products Supplement, 1993      NaN         358
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2707            85      1.5           0.3                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2707          0         0         17.8     0.13

# %%
filt_ja['Super Group'] = 'Fish and fish products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_75088\138002760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_ja['Super Group'] = 'Fish and fish products'

# %%
filt_ja
# Out:
#      Food Code     Food Name                        Description Group  \
# 2707    16-154  Tilapia, raw  Literature sources. Type of bream    JA
#
#      Previous                     Main data references Footnote Energy (kJ)  \
# 2707      NaN  Fish and Fish Products Supplement, 1993      NaN         358
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2707            85      1.5           0.3                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)             Super Group
# 2707          0         0         17.8     0.13  Fish and fish products

# %% [markdown]
# Fatty fish

# %%
jc = prod_t.loc[prod_t['Group']== 'JC']
jc
# Out:
#      Food Code                                          Food Name  \
# 2749    16-224                                  Trout, brown, raw
# 2750    50-629                              Trout, brown, steamed
# 2751    50-630          Trout, brown, steamed, weighed with bones
# 2752    16-489  Trout, rainbow, baked, flesh only, fillets wei...
# 2753    16-396                  Trout, rainbow, flesh only, baked
# 2754    16-395                    Trout, rainbow, flesh only, raw
# 2757    16-416                     Tuna, canned in brine, drained
# 2758    16-417             Tuna, canned in sunflower oil, drained
# 2759    16-400                            Tuna, flesh only, baked
# 2760    16-399                              Tuna, flesh only, raw
#
#                                             Description Group Previous  \
# 2749                  Analytical and literature sources    JC      NaN
# 2750                                         Flesh only    JC      NaN
# 2751                     Calculated from steamed 50-629    JC      NaN
# 2752  Calculated from 16-396 using edible conversion...    JC      NaN
# 2753          9 samples, 9 products, frozen and chilled    JC      NaN
# 2754          9 samples, 9 products, frozen and chilled    JC  16-225
# 2757                            11 samples, 10 products    JC  16-339
# 2758                            11 samples, 10 products    JC  16-230
# 2759          9 samples, 9 products, frozen and chilled    JC      NaN
# 2760          9 samples, 9 products, frozen and chilled    JC  16-228
#
#                                    Main data references Footnote Energy (kJ)  \
# 2749            Fish and Fish Products Supplement, 1993      NaN         470
# 2750  MW4, 1978. Estimated values, cholesterol, Se a...      NaN         566
# 2751  MW4, 1978. Estimated values, cholesterol, Se a...      NaN         375
# 2752  DH, Nutrient analysis of fish and fish product...      NaN         548
# 2753  DH, Nutrient analysis of fish and fish product...      NaN         631
# 2754  DH, Nutrient analysis of fish and fish product...      NaN         534
# 2757  DH, Nutrient analysis of fish and fish product...      NaN         460
# 2758  DH, Nutrient analysis of fish and fish product...      NaN         668
# 2759  DH, Nutrient analysis of fish and fish product...      NaN         579
# 2760  DH, Nutrient analysis of fish and fish product...      NaN         454
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2749           112      3.8          0.84                0          0
# 2750           135      4.5             1                0          0
# 2751            89      3.0           0.7                0          0
# 2752           130      5.3          1.25                0          0
# 2753           150      6.1          1.44                0          0
# 2754           127      5.3          1.21                0          0
# 2757           109      1.0           0.3                0          0
# 2758           159      6.4          0.78                0          0
# 2759           136      0.8          0.29                0          0
# 2760           107      0.7          0.21                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2749          0         0         19.4     0.14
# 2750          0         0         23.5     0.22
# 2751          0         0         15.5     0.15
# 2752          0         0         20.7      0.2
# 2753          0         0         23.8     0.23
# 2754          0         0         19.9     0.28
# 2757          0         0         24.9     0.73
# 2758          0         0         25.4     0.92
# 2759          0         0         32.3     0.16
# 2760          0         0         25.2     0.17

# %%
jc['Food Name'].unique()
# Out:
# array(['Trout, brown, raw', 'Trout, brown, steamed',
#        'Trout, brown, steamed, weighed with bones',
#        'Trout, rainbow, baked, flesh only, fillets weighed with bones and skin',
#        'Trout, rainbow, flesh only, baked',
#        'Trout, rainbow, flesh only, raw',
#        'Tuna, canned in brine, drained',
#        'Tuna, canned in sunflower oil, drained',
#        'Tuna, flesh only, baked', 'Tuna, flesh only, raw'], dtype=object)

# %% [markdown]
# **Removed**

# %%
priority_jc = ['Trout, brown, raw','Tuna, canned in brine, drained']

# %%
filt_jc = jc[jc['Food Name'].isin(priority_jc)]
filt_jc
# Out:
#      Food Code                       Food Name  \
# 2749    16-224               Trout, brown, raw
# 2757    16-416  Tuna, canned in brine, drained
#
#                             Description Group Previous  \
# 2749  Analytical and literature sources    JC      NaN
# 2757            11 samples, 10 products    JC  16-339
#
#                                    Main data references Footnote Energy (kJ)  \
# 2749            Fish and Fish Products Supplement, 1993      NaN         470
# 2757  DH, Nutrient analysis of fish and fish product...      NaN         460
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2749           112      3.8          0.84                0          0
# 2757           109      1.0           0.3                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2749          0         0         19.4     0.14
# 2757          0         0         24.9     0.73

# %%
filt_jc['Super Group'] = 'Fish and fish products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_75088\601193131.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_jc['Super Group'] = 'Fish and fish products'

# %% [markdown]
# Removed JR - Fish products and dishes

# %% [markdown]
#                                                Meat and meat products

# %% [markdown]
# Turkey

# %%
mco = prod_t.loc[prod_t['Group']== 'MCO']
mco
# Out:
#      Food Code                                          Food Name  \
# 2766    18-356         Turkey, breast, fillet, grilled, meat only
# 2767    18-348                             Turkey, dark meat, raw
# 2768    18-358                         Turkey, dark meat, roasted
# 2769    18-365         Turkey, drumsticks, roasted, meat and skin
# 2770    18-366  Turkey, drumsticks, roasted, meat and skin, we...
# 2771    18-364             Turkey, drumsticks, roasted, meat only
# 2772    18-349                            Turkey, light meat, raw
# 2773    18-359                        Turkey, light meat, roasted
# 2774    18-350                         Turkey, meat, average, raw
# 2775    18-361                     Turkey, meat, average, roasted
# 2776    18-354                              Turkey, mince, stewed
# 2777    18-360          Turkey, self-basting, light meat, roasted
# 2778    18-362                         Turkey, skin, dry, roasted
# 2779    18-363                       Turkey, skin, moist, roasted
# 2780    18-351                                  Turkey, skin, raw
# 2782    18-357             Turkey, strips, stir-fried in corn oil
# 2783    18-355       Turkey, thighs, diced, casseroled, meat only
# 2784    18-352                                 Turkey, whole, raw
# 2785    18-353              Turkey, whole, raw, weighed with bone
# 2786    18-367              Turkey, whole, roasted, meat and skin
# 2787    18-368  Turkey, whole, roasted, meat and skin, weighed...
#
#                                             Description Group        Previous  \
# 2766                                9 samples; skinless   MCO
# 2767                                         20 samples   MCO         50-461
# 2768           27 samples including self-basting turkey   MCO  50-465 18-459
# 2769          Calculated from 92% dark meat and 8% skin   MCO             NaN
# 2770                             Calculated from 18-365   MCO             NaN
# 2771                                          9 samples   MCO             NaN
# 2772                                         20 samples   MCO         50-460
# 2773                                         18 samples   MCO  50-464 18-460
# 2774   Calculated from 56% light meat and 44% dark meat   MCO         50-458
# 2775  Calculated from 51% light meat and 49% dark me...   MCO         50-462
# 2776                                          5 samples   MCO             273
# 2777                                          9 samples   MCO             NaN
# 2778                                         10 samples   MCO             NaN
# 2779                                         18 samples   MCO             NaN
# 2780                                         21 samples   MCO             269
# 2782                                8 samples; skinless   MCO             NaN
# 2783                                8 samples; skinless   MCO             274
# 2784  Calculated from 49% light meat, 39% dark meat ...   MCO             NaN
# 2785                             Calculated from 18-352   MCO             NaN
# 2786  Calculated from 47% light meat, 45% dark meat ...   MCO             NaN
# 2787                             Calculated from 18-367   MCO             NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2766  Reviewed 2013. LGC, Nutrient analysis of chick...      NaN         658
# 2767  Reviewed 2013. LGC, Nutrient analysis of chick...      NaN         439
# 2768  Reviewed 2013. LGC, Nutrient analysis of chick...      NaN         745
# 2769  LGC, Nutrient analysis of chicken and turkey, ...      NaN         780
# 2770  LGC, Nutrient analysis of chicken and turkey, ...      NaN         560
# 2771  LGC, Nutrient analysis of chicken and turkey, ...      NaN         682
# 2772  Reviewed 2013. LGC, Nutrient analysis of chick...      NaN         444
# 2773  Reviewed 2013. LGC, Nutrient analysis of chick...      NaN         647
# 2774  Reviewed 2013. LGC, Nutrient analysis of chick...      NaN         444
# 2775  Reviewed 2013. LGC, Nutrient analysis of chick...      NaN         700
# 2776  LGC, Nutrient analysis of chicken and turkey, ...      NaN         738
# 2777  LGC, Nutrient analysis of chicken and turkey, ...      NaN         687
# 2778  Reviewed 2013. LGC, Nutrient analysis of chick...      NaN        1813
# 2779  LGC, Nutrient analysis of chicken and turkey, ...      NaN        1541
# 2780  LGC, Nutrient analysis of chicken and turkey, ...      NaN        1374
# 2782  Reviewed 2013. LGC, Nutrient analysis of chick...      NaN         694
# 2783  Reviewed 2013. LGC, Nutrient analysis of chick...      NaN         760
# 2784  LGC, Nutrient analysis of chicken and turkey, ...      NaN         560
# 2785  LGC, Nutrient analysis of chicken and turkey, ...      NaN         390
# 2786  LGC, Nutrient analysis of chicken and turkey, ...      NaN         799
# 2787  LGC, Nutrient analysis of chicken and turkey, ...      NaN         520
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2766           155      1.7           0.6                0          0
# 2767           104      2.5           0.8                0          0
# 2768           177      6.6             2                0          0
# 2769           186      8.5           2.6                0          0
# 2770           134      6.1           1.8                0          0
# 2771           162      5.8           1.7                0          0
# 2772           105      0.8           0.3                0          0
# 2773           153      2.0           0.7                0          0
# 2774           105      1.6           0.5                0          0
# 2775           166      4.6           1.4                0          0
# 2776           176      6.8             2                0          0
# 2777           163      4.0           1.2                0          0
# 2778           438     40.2          13.2                0          0
# 2779           372     31.7          10.5                0          0
# 2780           332     30.7          10.1                0          0
# 2782           165      4.5          1.06                0          0
# 2783           181      7.5           2.5                0          0
# 2784           133      5.2           1.7                0          0
# 2785            93      3.6           1.1                0          0
# 2786           190      7.4           2.3                0          0
# 2787           124      4.8           1.5                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2766          0         0         35.0     0.23
# 2767          0         0         20.4     0.23
# 2768          0         0         29.4     0.28
# 2769          0         0         27.4     0.26
# 2770          0         0         19.7     0.19
# 2771          0         0         27.5     0.26
# 2772          0         0         24.4     0.13
# 2773          0         0         33.7     0.13
# 2774          0         0         22.6     0.17
# 2775          0         0         31.2     0.23
# 2776          0         0         28.6     0.11
# 2777          0         0         31.7     0.23
# 2778          0         0         19.1     0.28
# 2779          0         0         21.6      0.3
# 2780          0         0         14.0     0.17
# 2782          0         0         31.0     0.15
# 2783          0         0         28.4     0.16
# 2784          0         0         21.6     0.18
# 2785          0         0         15.1     0.13
# 2786          0         0         30.9     0.23
# 2787          0         0         20.1     0.15

# %%
mco['Food Name'].unique()
# Out:
# array(['Turkey, breast, fillet, grilled, meat only',
#        'Turkey, dark meat, raw', 'Turkey, dark meat, roasted',
#        'Turkey, drumsticks, roasted, meat and skin',
#        'Turkey, drumsticks, roasted, meat and skin, weighed with bone',
#        'Turkey, drumsticks, roasted, meat only',
#        'Turkey, light meat, raw', 'Turkey, light meat, roasted',
#        'Turkey, meat, average, raw', 'Turkey, meat, average, roasted',
#        'Turkey, mince, stewed',
#        'Turkey, self-basting, light meat, roasted',
#        'Turkey, skin, dry, roasted', 'Turkey, skin, moist, roasted',
#        'Turkey, skin, raw', 'Turkey, strips, stir-fried in corn oil',
#        'Turkey, thighs, diced, casseroled, meat only',
#        'Turkey, whole, raw', 'Turkey, whole, raw, weighed with bone',
#        'Turkey, whole, roasted, meat and skin',
#        'Turkey, whole, roasted, meat and skin, weighed with bone'],
#       dtype=object)

# %% [markdown]
# **Reduced**

# %%
priority_mco = ['Turkey, whole, raw']

# %%
filt_mco = mco[mco['Food Name'].isin(priority_mco)]
filt_mco
# Out:
#      Food Code           Food Name  \
# 2784    18-352  Turkey, whole, raw
#
#                                             Description Group Previous  \
# 2784  Calculated from 49% light meat, 39% dark meat ...   MCO      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2784  LGC, Nutrient analysis of chicken and turkey, ...      NaN         560
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2784           133      5.2           1.7                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2784          0         0         21.6     0.18

# %%
filt_mco['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_75088\2858972884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_mco['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Offal

# %%
mg = prod_t.loc[prod_t['Group']== 'MG']
mg
# Out:
#      Food Code                               Food Name  \
# 2729    18-423                       Tongue, lamb, raw
# 2730    18-424     Tongue, ox, meat only, pickled, raw
# 2731    18-425  Tongue, ox, meat only, pickled, stewed
# 2732    18-426           Tongue, ox, meat only, stewed
# 2733    18-427        Tongue, sheep, meat only, stewed
# 2747    18-428                     Tripe, dressed, raw
# 2748    50-502          Tripe, dressed, stewed in milk
#
#                                    Description Group Previous  \
# 2729                                20 samples    MG  50-497
# 2730           6 samples, fat and skin removed    MG  50-498
# 2731                      Fat and skin removed    MG  50-499
# 2732          10 samples, fat and skin removed    MG      NaN
# 2733                      Fat and skin removed    MG  50-500
# 2747                                 6 samples    MG  50-501
# 2748  18 samples; lime treated before purchase    MG  18-457
#
#                                    Main data references Footnote Energy (kJ)  \
# 2729  MW4 (1978). Values reviewed for Meat, Poultry ...      NaN         801
# 2730  MW4 (1978). Values reviewed for Meat, Poultry ...      NaN         914
# 2731  MW4 (1978). Values reviewed for Meat, Poultry ...      NaN        1216
# 2732      LGC, Carcase meat and offal survey, 1982-1983      NaN        1006
# 2733  MW4 (1978). Values reviewed for Meat, Poultry ...      NaN        1197
# 2747  LGC, Nutritional analysis of meat and poultry ...      NaN         140
# 2748  MW4, 1978. As MW 5-502  (note that full fatty ...      NaN         418
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2729           193     14.6          6.63                0          0
# 2730           220     17.5          7.95                0          0
# 2731           293     23.9         10.85                0          0
# 2732           242     18.3          8.31                0          0
# 2733           289     24.0          10.9                0          0
# 2747            33      0.5           0.2                0          0
# 2748           100      4.5           2.4                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2729          0         0         15.3     1.05
# 2730          0         0         15.7     3.03
# 2731          0         0         19.5      2.5
# 2732          0         0         19.4     2.15
# 2733          0         0         18.2      0.2
# 2747          0         0          7.1     0.13
# 2748          0         0         14.8     0.18

# %%
mg['Food Name'].unique()
# Out:
# array(['Tongue, lamb, raw', 'Tongue, ox, meat only, pickled, raw',
#        'Tongue, ox, meat only, pickled, stewed',
#        'Tongue, ox, meat only, stewed',
#        'Tongue, sheep, meat only, stewed', 'Tripe, dressed, raw',
#        'Tripe, dressed, stewed in milk'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
priority_mg = ['Tongue, lamb, raw','Tripe, dressed, raw']

# %%
filt_mg = mg[mg['Food Name'].isin(priority_mg)]
filt_mg
# Out:
#      Food Code            Food Name Description Group Previous  \
# 2729    18-423    Tongue, lamb, raw  20 samples    MG  50-497
# 2747    18-428  Tripe, dressed, raw   6 samples    MG  50-501
#
#                                    Main data references Footnote Energy (kJ)  \
# 2729  MW4 (1978). Values reviewed for Meat, Poultry ...      NaN         801
# 2747  LGC, Nutritional analysis of meat and poultry ...      NaN         140
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2729           193     14.6          6.63                0          0
# 2747            33      0.5           0.2                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2729          0         0         15.3     1.05
# 2747          0         0          7.1     0.13

# %%
filt_mg['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_75088\2423777326.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_mg['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Meat products

# %%
mi = prod_t.loc[prod_t['Group']== 'MI']
mi
# Out:
#      Food Code      Food Name  \
# 2765    19-543  Turkey slices
#
#                                             Description Group Previous  \
# 2765  13 samples including honey roast and wafer thi...    MI  19-157
#
#                                    Main data references Footnote Energy (kJ)  \
# 2765  LGC, Nutritional analysis of meat and poultry ...      NaN         481
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2765           114      1.9           0.6              1.1        0.4
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2765        0.4         0         23.0     1.48

# %%
mi['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_75088\4073990927.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mi['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Removed MR - Meat dishes

# %% [markdown]
#                                                         Beverages

# %% [markdown]
# Powdered drinks and essences

# %%
paa = prod_t.loc[prod_t['Group']== 'PAA']
paa
# Out:
#      Food Code                      Food Name  \
# 2694    17-165  Tea, black, infusion, average
#
#                                             Description Group Previous  \
# 2694  15g leaves per litre water, strained after 5 m...   PAA      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2694  Reviewed 2013. LGC, Alcoholic beverages, soft ...      NaN           0
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2694             0      0.0             0                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2694          0         0          0.0        0

# %%
paa['Super Group'] = 'Beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_75088\313636622.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   paa['Super Group'] = 'Beverages'

# %% [markdown]
# Removed PAC

# %% [markdown]
# Carbonated drinks

# %%
pca = prod_t.loc[prod_t['Group']== 'PCA']
pca
# Out:
#      Food Code    Food Name         Description Group Previous  \
# 2734    17-736  Tonic water  Literature sources   PCA  17-184
#
#                                    Main data references Footnote Energy (kJ)  \
# 2734  Cutrufelli and Matthews (1986) Composition of ...      NaN          95
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2734            22      0.0             0              5.6        5.6
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2734          0         0          0.0     0.01

# %%
pca['Super Group'] = 'Beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_75088\158874358.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pca['Super Group'] = 'Beverages'

# %% [markdown]
# Juices

# %%
pe = prod_t.loc[prod_t['Group']== 'PE']
pe
# Out:
#      Food Code     Food Name           Description Group  Previous  \
# 2717    13-382  Tomato juice  10 samples, 9 brands    PE  50-1093
#
#                                    Main data references Footnote Energy (kJ)  \
# 2717  Reviewed 2013. LGC, Canned and other processed...      NaN          70
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2717            16      0.0             0                3          3
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2717          0       0.6          0.8     0.58

# %%
pe['Super Group'] = 'Beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_75088\2340237900.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pe['Super Group'] = 'Beverages'

# %% [markdown]
#                                             Sugars, preserves and snacks

# %% [markdown]
# Sugars, syrups and preserves

# %%
sc = prod_t.loc[prod_t['Group']== 'SC']
sc
# Out:
#      Food Code       Food Name Description Group Previous  \
# 2742    17-826  Treacle, black   3 samples    SC  17-068
#
#                                    Main data references Footnote Energy (kJ)  \
# 2742  LGC Analysis of Assorted Foods, 1994. Iodine u...      NaN        1129
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2742           266      0.0             0             65.2       65.2
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2742          0         0          1.2     0.45

# %%
sc['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_75088\254444824.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sc['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
# Chocolate confectionery

# %%
sea = prod_t.loc[prod_t['Group']== 'SEA']
sea
# Out:
#      Food Code                                 Food Name  \
# 2735    17-670  Topic/Snickers and own brand equivalents
# 2755    17-098                 Truffles, mocha, homemade
# 2756    17-837                   Truffles, rum, homemade
#
#                                             Description Group Previous  \
# 2735  16 samples, 3 brands, including standard, snac...   SEA  17-549
# 2755                                             Recipe   SEA      NaN
# 2756                                             Recipe   SEA  17-588
#
#                                    Main data references Footnote Energy (kJ)  \
# 2735  DH, Nutrient analysis of a range of processed ...      NaN        2058
# 2755            As Miscellaneous Foods Supplement, 1994      NaN        2073
# 2756                                       Updated 2014      NaN        2236
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2735           493     28.2          9.15             49.7       44.1
# 2755           495     24.9            15             60.6       59.9
# 2756           536     32.9         19.02             51.6       50.9
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2735        5.5       2.8          8.7     0.47
# 2755        0.7         2          6.2     0.09
# 2756        0.7       2.1          6.0     0.13

# %%
sea['Food Name'].unique()
# Out:
# array(['Topic/Snickers and own brand equivalents',
#        'Truffles, mocha, homemade', 'Truffles, rum, homemade'],
#       dtype=object)

# %% [markdown]
# **Redueced**

# %%
priority_sea = ['Topic/Snickers and own brand equivalents','Truffles, mocha, homemade']

# %%
filt_sea = sea[sea['Food Name'].isin(priority_sea)]
filt_sea
# Out:
#      Food Code                                 Food Name  \
# 2735    17-670  Topic/Snickers and own brand equivalents
# 2755    17-098                 Truffles, mocha, homemade
#
#                                             Description Group Previous  \
# 2735  16 samples, 3 brands, including standard, snac...   SEA  17-549
# 2755                                             Recipe   SEA      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2735  DH, Nutrient analysis of a range of processed ...      NaN        2058
# 2755            As Miscellaneous Foods Supplement, 1994      NaN        2073
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2735           493     28.2          9.15             49.7       44.1
# 2755           495     24.9            15             60.6       59.9
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2735        5.5       2.8          8.7     0.47
# 2755        0.7         2          6.2     0.09

# %%
filt_sea['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_75088\124761542.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_sea['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
# Non-chocolate confectionery

# %%
sec = prod_t.loc[prod_t['Group']== 'SEC']
sec
# Out:
#      Food Code                             Food Name  \
# 2712    17-646                        Toffees, mixed
# 2788    17-593  Turkish delight, with nuts, homemade
# 2789    17-122         Turkish delight, without nuts
#
#                                             Description Group  Previous  \
# 2712  8 samples, 8 products, including liquorice and...   SEC   17-120
# 2788                                             Recipe   SEC   17-121
# 2789                                 7 assorted samples   SEC  50-1033
#
#                                    Main data references Footnote Energy (kJ)  \
# 2712  DH, Nutrient analysis of a range of processed ...      NaN        1637
# 2788  Recipe as Miscellaneous Foods Supplement (1994...      NaN        1506
# 2789                           Reviewed 2013. MW5, 1991      NaN        1321
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2712           390     15.9           8.6             59.6       37.5
# 2788           355      2.6          0.35             78.1       77.9
# 2789           311      0.0             0             77.1       68.6
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2712          0         0          2.1     0.78
# 2788        0.2       0.3          4.7     0.21
# 2789        8.5         0          0.6     0.08

# %%
priority_sec = ['Toffees, mixed','Turkish delight, with nuts, homemade']

# %% [markdown]
# **Reduced**

# %%
filt_sec = sec[sec['Food Name'].isin(priority_sec)]
filt_sec
# Out:
#      Food Code                             Food Name  \
# 2712    17-646                        Toffees, mixed
# 2788    17-593  Turkish delight, with nuts, homemade
#
#                                             Description Group Previous  \
# 2712  8 samples, 8 products, including liquorice and...   SEC  17-120
# 2788                                             Recipe   SEC  17-121
#
#                                    Main data references Footnote Energy (kJ)  \
# 2712  DH, Nutrient analysis of a range of processed ...      NaN        1637
# 2788  Recipe as Miscellaneous Foods Supplement (1994...      NaN        1506
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2712           390     15.9           8.6             59.6       37.5
# 2788           355      2.6          0.35             78.1       77.9
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2712          0         0          2.1     0.78
# 2788        0.2       0.3          4.7     0.21

# %%
filt_sec['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_75088\3222985597.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_sec['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
# Savoury snacks

# %%
sn = prod_t.loc[prod_t['Group']== 'SN']
sn
# Out:
#      Food Code                              Food Name  \
# 2738    17-644  Tortilla chips fried in sunflower oil
# 2794    17-694                               Twiglets
#
#                                             Description Group Previous  \
# 2738  7 samples, 6 products, assorted flavours, frie...    SN  17-497
# 2794              20 samples, savoury wholewheat sticks    SN  17-150
#
#                                    Main data references Footnote Energy (kJ)  \
# 2738  DH, Nutrient analysis of a range of processed ...      NaN        2126
# 2794  LGC, Survey of the composition of savoury snac...      NaN        1744
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2738           509     27.4          2.89             55.4        2.4
# 2794           415     11.8           1.6             57.6        0.6
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2738         53       5.9          7.3     1.59
# 2794         57      12.4         13.5        2

# %%
sn['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_75088\3385870545.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sn['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
#                                         Soups, sauces and miscellaneous foods

# %% [markdown]
# Non-salad sauces

# %%
wcn = prod_t.loc[prod_t['Group']== 'WCN']
wcn
# Out:
#      Food Code               Food Name           Description Group Previous  \
# 2688    17-722           Tartare sauce  10 samples, 4 brands   WCN  17-337
# 2718    17-709          Tomato ketchup  10 samples, 5 brands   WCN  17-513
# 2720   50-1173  Tomato sauce, homemade                Recipe   WCN      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2688  LFRA, Nutrient analysis of miscellaneous foods...      NaN        1236
# 2718  LFRA, Nutrient analysis of miscellaneous foods...      NaN         511
# 2720                                       AS MW5, 1991      NaN         319
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2688           298     24.6           1.6             17.6         16
# 2718           120      0.1             0             27.8       26.8
# 2720            77      5.5           1.8              3.9          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2688        1.5       0.6          1.3      2.7
# 2718          1       0.9          1.6        2
# 2720        3.9       1.4          2.3     0.85

# %%
wcn['Food Name'].unique()
# Out:
# array(['Tartare sauce', 'Tomato ketchup', 'Tomato sauce, homemade'],
#       dtype=object)

# %%
priority_wcn = ['Tartare sauce', 'Tomato ketchup',]

# %% [markdown]
# **Reduced**

# %%
filt_wcn = wcn[wcn['Food Name'].isin(priority_wcn)]
filt_wcn
# Out:
#      Food Code       Food Name           Description Group Previous  \
# 2688    17-722   Tartare sauce  10 samples, 4 brands   WCN  17-337
# 2718    17-709  Tomato ketchup  10 samples, 5 brands   WCN  17-513
#
#                                    Main data references Footnote Energy (kJ)  \
# 2688  LFRA, Nutrient analysis of miscellaneous foods...      NaN        1236
# 2718  LFRA, Nutrient analysis of miscellaneous foods...      NaN         511
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2688           298     24.6           1.6             17.6         16
# 2718           120      0.1             0             27.8       26.8
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2688        1.5       0.6          1.3      2.7
# 2718          1       0.9          1.6        2

# %%
filt_wcn['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_75088\2991050135.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_wcn['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
#                                               **Join Reduced Tables**

# %%
Red = pd.concat([af, filt_AS], axis=0, join='inner')
Red
# Out:
#      Food Code                      Food Name  \
# 2739    11-925          Tortilla, wheat, soft
# 2690    11-845  Tarts, bakewell, iced, retail
#
#                                             Description Group Previous  \
# 2739                              8 samples, 6 products    AF  11-632
# 2690  10 samples, 7 products, including large, slice...    AS  11-426
#
#                                    Main data references Footnote Energy (kJ)  \
# 2739  LGC, Nutrient analysis of bread and morning go...      NaN        1220
# 2690  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1746
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2739           289      5.7           2.5             49.1        1.9
# 2690           416     16.8          6.94             62.2       43.4
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# 2739       47.2       3.6          8.6     1.56  Cereals and cereal products
# 2690       18.8       1.1          3.4     0.33  Cereals and cereal products

# %%
Red2 = pd.concat([Red,bn], axis=0, join='inner')
Red2
# Out:
#      Food Code                      Food Name  \
# 2739    11-925          Tortilla, wheat, soft
# 2690    11-845  Tarts, bakewell, iced, retail
# 2795    12-547                       Tzatziki
#
#                                             Description Group Previous  \
# 2739                              8 samples, 6 products    AF  11-632
# 2690  10 samples, 7 products, including large, slice...    AS  11-426
# 2795                 Yogurt-based Greek starter. Recipe    BN  12-410
#
#                                    Main data references Footnote Energy (kJ)  \
# 2739  LGC, Nutrient analysis of bread and morning go...      NaN        1220
# 2690  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1746
# 2795                                       Updated 2013      NaN         321
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2739           289      5.7           2.5             49.1        1.9
# 2690           416     16.8          6.94             62.2       43.4
# 2795            77      5.5          3.58              3.4          3
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# 2739       47.2       3.6          8.6     1.56  Cereals and cereal products
# 2690       18.8       1.1          3.4     0.33  Cereals and cereal products
# 2795        0.4       0.3          3.4     0.92       Milk and milk products

# %%
Red3 = pd.concat([Red2,filt_db], axis=0, join='inner')
Red3
# Out:
#      Food Code                      Food Name  \
# 2739    11-925          Tortilla, wheat, soft
# 2690    11-845  Tarts, bakewell, iced, retail
# 2795    12-547                       Tzatziki
# 2715    13-570       Tofu, soya bean, steamed
#
#                                             Description Group Previous  \
# 2739                              8 samples, 6 products    AF  11-632
# 2690  10 samples, 7 products, including large, slice...    AS  11-426
# 2795                 Yogurt-based Greek starter. Recipe    BN  12-410
# 2715                 Soya bean curd; 7 assorted samples    DB  13-119
#
#                                    Main data references Footnote Energy (kJ)  \
# 2739  LGC, Nutrient analysis of bread and morning go...      NaN        1220
# 2690  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1746
# 2795                                       Updated 2013      NaN         321
# 2715      Vegetables, Herbs and Spices Supplement, 1991      NaN         305
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2739           289      5.7           2.5             49.1        1.9
# 2690           416     16.8          6.94             62.2       43.4
# 2795            77      5.5          3.58              3.4          3
# 2715            73      4.2           0.5              0.6        0.2
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# 2739       47.2       3.6          8.6     1.56  Cereals and cereal products
# 2690       18.8       1.1          3.4     0.33  Cereals and cereal products
# 2795        0.4       0.3          3.4     0.92       Milk and milk products
# 2715        0.3       0.4          8.1     0.01                   Vegetables

# %%
Red4 = pd.concat([Red3,filt_dg], axis=0, join='inner')
Red4
# Out:
#      Food Code                         Food Name  \
# 2739    11-925             Tortilla, wheat, soft
# 2690    11-845     Tarts, bakewell, iced, retail
# 2795    12-547                          Tzatziki
# 2715    13-570          Tofu, soya bean, steamed
# 2721    13-530  Tomatoes, canned, whole contents
# 2726    13-517           Tomatoes, standard, raw
# 2793    13-389           Turnip, flesh only, raw
#
#                                             Description Group Previous  \
# 2739                              8 samples, 6 products    AF  11-632
# 2690  10 samples, 7 products, including large, slice...    AS  11-426
# 2795                 Yogurt-based Greek starter. Recipe    BN  12-410
# 2715                 Soya bean curd; 7 assorted samples    DB  13-119
# 2721  12 samples, 9 brands, whole and chopped, no ad...    DG  13-461
# 2726  22 samples, autumn and winter, UK grown and im...    DG  13-460
# 2793                                      Peeled thinly    DG  50-833
#
#                                    Main data references Footnote Energy (kJ)  \
# 2739  LGC, Nutrient analysis of bread and morning go...      NaN        1220
# 2690  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1746
# 2795                                       Updated 2013      NaN         321
# 2715      Vegetables, Herbs and Spices Supplement, 1991      NaN         305
# 2721  DH, Nutrient analysis of fruit and vegetables,...      NaN          94
# 2726  DH, Nutrient analysis of fruit and vegetables,...      NaN          71
# 2793  As Vegetables, Herbs and Spices Supplement, 19...      NaN         128
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2739           289      5.7           2.5             49.1        1.9
# 2690           416     16.8          6.94             62.2       43.4
# 2795            77      5.5          3.58              3.4          3
# 2715            73      4.2           0.5              0.6        0.2
# 2721            22      0.1          0.01              3.8        3.8
# 2726            17      0.1          0.03                3          3
# 2793            31      0.3             0              4.8        4.6
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# 2739       47.2       3.6          8.6     1.56  Cereals and cereal products
# 2690       18.8       1.1          3.4     0.33  Cereals and cereal products
# 2795        0.4       0.3          3.4     0.92       Milk and milk products
# 2715        0.3       0.4          8.1     0.01                   Vegetables
# 2721          0       0.8          1.1     0.01                   Vegetables
# 2726          0         1          0.5     0.01                   Vegetables
# 2793        0.2       2.4          0.9     0.04                   Vegetables

# %%
Red5 = pd.concat([Red4,ga], axis=0, join='inner')
Red5
# Out:
#      Food Code                         Food Name  \
# 2739    11-925             Tortilla, wheat, soft
# 2690    11-845     Tarts, bakewell, iced, retail
# 2795    12-547                          Tzatziki
# 2715    13-570          Tofu, soya bean, steamed
# 2721    13-530  Tomatoes, canned, whole contents
# 2726    13-517           Tomatoes, standard, raw
# 2793    13-389           Turnip, flesh only, raw
# 2669    14-847                      Tahini paste
# 2706    14-848                         Tigernuts
# 2740    14-849                         Trail mix
#
#                                             Description Group  Previous  \
# 2739                              8 samples, 6 products    AF   11-632
# 2690  10 samples, 7 products, including large, slice...    AS   11-426
# 2795                 Yogurt-based Greek starter. Recipe    BN   12-410
# 2715                 Soya bean curd; 7 assorted samples    DB   13-119
# 2721  12 samples, 9 brands, whole and chopped, no ad...    DG   13-461
# 2726  22 samples, autumn and winter, UK grown and im...    DG   13-460
# 2793                                      Peeled thinly    DG   50-833
# 2669     Literature sources and calculation from 14-844    GA   50-996
# 2706                                 Literature sources    GA       NaN
# 2740            10 samples; mix of nuts and dried fruit    GA  50-1041
#
#                                    Main data references Footnote Energy (kJ)  \
# 2739  LGC, Nutrient analysis of bread and morning go...      NaN        1220
# 2690  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1746
# 2795                                       Updated 2013      NaN         321
# 2715      Vegetables, Herbs and Spices Supplement, 1991      NaN         305
# 2721  DH, Nutrient analysis of fruit and vegetables,...      NaN          94
# 2726  DH, Nutrient analysis of fruit and vegetables,...      NaN          71
# 2793  As Vegetables, Herbs and Spices Supplement, 19...      NaN         128
# 2669  Reviewed 2013. McCarthy and Matthews (1984) Co...      NaN        2639
# 2706                    Fruit and Nuts Supplement, 1992      NaN        1811
# 2740  Reviewed 2013. LGC, Nutritional composition of...      NaN        1880
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2739           289      5.7           2.5             49.1        1.9
# 2690           416     16.8          6.94             62.2       43.4
# 2795            77      5.5          3.58              3.4          3
# 2715            73      4.2           0.5              0.6        0.2
# 2721            22      0.1          0.01              3.8        3.8
# 2726            17      0.1          0.03                3          3
# 2793            31      0.3             0              4.8        4.6
# 2669           639     58.9           8.4              0.8        0.4
# 2706           435     23.8             4             42.2       15.3
# 2740           451     28.5          5.37             37.1         37
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# 2739       47.2       3.6          8.6     1.56  Cereals and cereal products
# 2690       18.8       1.1          3.4     0.33  Cereals and cereal products
# 2795        0.4       0.3          3.4     0.92       Milk and milk products
# 2715        0.3       0.4          8.1     0.01                   Vegetables
# 2721          0       0.8          1.1     0.01                   Vegetables
# 2726          0         1          0.5     0.01                   Vegetables
# 2793        0.2       2.4          0.9     0.04                   Vegetables
# 2669        0.5       9.3         21.8     0.05               Nuts and seeds
# 2706       26.9      17.4          4.3        0               Nuts and seeds
# 2740        0.1       5.1          9.1     0.07               Nuts and seeds

# %%
Red6 = pd.concat([Red5,filt_h], axis=0, join='inner')
Red6
# Out:
#      Food Code                         Food Name  \
# 2739    11-925             Tortilla, wheat, soft
# 2690    11-845     Tarts, bakewell, iced, retail
# 2795    12-547                          Tzatziki
# 2715    13-570          Tofu, soya bean, steamed
# 2721    13-530  Tomatoes, canned, whole contents
# 2726    13-517           Tomatoes, standard, raw
# 2793    13-389           Turnip, flesh only, raw
# 2669    14-847                      Tahini paste
# 2706    14-848                         Tigernuts
# 2740    14-849                         Trail mix
# 2683    13-858           Tarragon, dried, ground
# 2704    13-883              Thyme, dried, ground
# 2790    13-861                  Turmeric, ground
#
#                                             Description Group  Previous  \
# 2739                              8 samples, 6 products    AF   11-632
# 2690  10 samples, 7 products, including large, slice...    AS   11-426
# 2795                 Yogurt-based Greek starter. Recipe    BN   12-410
# 2715                 Soya bean curd; 7 assorted samples    DB   13-119
# 2721  12 samples, 9 brands, whole and chopped, no ad...    DG   13-461
# 2726  22 samples, autumn and winter, UK grown and im...    DG   13-460
# 2793                                      Peeled thinly    DG   50-833
# 2669     Literature sources and calculation from 14-844    GA   50-996
# 2706                                 Literature sources    GA       NaN
# 2740            10 samples; mix of nuts and dried fruit    GA  50-1041
# 2683                                 Literature sources     H       NaN
# 2704                                 Literature sources     H   13-860
# 2790                                 Literature sources     H       NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2739  LGC, Nutrient analysis of bread and morning go...      NaN        1220
# 2690  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1746
# 2795                                       Updated 2013      NaN         321
# 2715      Vegetables, Herbs and Spices Supplement, 1991      NaN         305
# 2721  DH, Nutrient analysis of fruit and vegetables,...      NaN          94
# 2726  DH, Nutrient analysis of fruit and vegetables,...      NaN          71
# 2793  As Vegetables, Herbs and Spices Supplement, 19...      NaN         128
# 2669  Reviewed 2013. McCarthy and Matthews (1984) Co...      NaN        2639
# 2706                    Fruit and Nuts Supplement, 1992      NaN        1811
# 2740  Reviewed 2013. LGC, Nutritional composition of...      NaN        1880
# 2683  Marsh et al. (1977) Composition of foods: spic...      NaN        1374
# 2704  Marsh et al. (1977) Composition of foods: spic...      NaN        1383
# 2790      Vegetables, Herbs and Spices Supplement, 1991      NaN        1467
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2739           289      5.7           2.5             49.1        1.9
# 2690           416     16.8          6.94             62.2       43.4
# 2795            77      5.5          3.58              3.4          3
# 2715            73      4.2           0.5              0.6        0.2
# 2721            22      0.1          0.01              3.8        3.8
# 2726            17      0.1          0.03                3          3
# 2793            31      0.3             0              4.8        4.6
# 2669           639     58.9           8.4              0.8        0.4
# 2706           435     23.8             4             42.2       15.3
# 2740           451     28.5          5.37             37.1         37
# 2683           326      7.2          1.88             38.9        8.2
# 2704           332      7.4           2.7             38.7        1.7
# 2790           350      7.0           2.9             53.7        3.2
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# 2739       47.2       3.6          8.6     1.56  Cereals and cereal products
# 2690       18.8       1.1          3.4     0.33  Cereals and cereal products
# 2795        0.4       0.3          3.4     0.92       Milk and milk products
# 2715        0.3       0.4          8.1     0.01                   Vegetables
# 2721          0       0.8          1.1     0.01                   Vegetables
# 2726          0         1          0.5     0.01                   Vegetables
# 2793        0.2       2.4          0.9     0.04                   Vegetables
# 2669        0.5       9.3         21.8     0.05               Nuts and seeds
# 2706       26.9      17.4          4.3        0               Nuts and seeds
# 2740        0.1       5.1          9.1     0.07               Nuts and seeds
# 2683       30.7       7.4         22.8     0.16             Herbs and spices
# 2704         37        37          9.1     0.14             Herbs and spices
# 2790       50.5      22.7          6.7     0.08             Herbs and spices

# %%
Red7 = pd.concat([Red6,filt_ja], axis=0, join='inner')
Red7
# Out:
#      Food Code                         Food Name  \
# 2739    11-925             Tortilla, wheat, soft
# 2690    11-845     Tarts, bakewell, iced, retail
# 2795    12-547                          Tzatziki
# 2715    13-570          Tofu, soya bean, steamed
# 2721    13-530  Tomatoes, canned, whole contents
# 2726    13-517           Tomatoes, standard, raw
# 2793    13-389           Turnip, flesh only, raw
# 2669    14-847                      Tahini paste
# 2706    14-848                         Tigernuts
# 2740    14-849                         Trail mix
# 2683    13-858           Tarragon, dried, ground
# 2704    13-883              Thyme, dried, ground
# 2790    13-861                  Turmeric, ground
# 2707    16-154                      Tilapia, raw
#
#                                             Description Group  Previous  \
# 2739                              8 samples, 6 products    AF   11-632
# 2690  10 samples, 7 products, including large, slice...    AS   11-426
# 2795                 Yogurt-based Greek starter. Recipe    BN   12-410
# 2715                 Soya bean curd; 7 assorted samples    DB   13-119
# 2721  12 samples, 9 brands, whole and chopped, no ad...    DG   13-461
# 2726  22 samples, autumn and winter, UK grown and im...    DG   13-460
# 2793                                      Peeled thinly    DG   50-833
# 2669     Literature sources and calculation from 14-844    GA   50-996
# 2706                                 Literature sources    GA       NaN
# 2740            10 samples; mix of nuts and dried fruit    GA  50-1041
# 2683                                 Literature sources     H       NaN
# 2704                                 Literature sources     H   13-860
# 2790                                 Literature sources     H       NaN
# 2707                  Literature sources. Type of bream    JA       NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2739  LGC, Nutrient analysis of bread and morning go...      NaN        1220
# 2690  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1746
# 2795                                       Updated 2013      NaN         321
# 2715      Vegetables, Herbs and Spices Supplement, 1991      NaN         305
# 2721  DH, Nutrient analysis of fruit and vegetables,...      NaN          94
# 2726  DH, Nutrient analysis of fruit and vegetables,...      NaN          71
# 2793  As Vegetables, Herbs and Spices Supplement, 19...      NaN         128
# 2669  Reviewed 2013. McCarthy and Matthews (1984) Co...      NaN        2639
# 2706                    Fruit and Nuts Supplement, 1992      NaN        1811
# 2740  Reviewed 2013. LGC, Nutritional composition of...      NaN        1880
# 2683  Marsh et al. (1977) Composition of foods: spic...      NaN        1374
# 2704  Marsh et al. (1977) Composition of foods: spic...      NaN        1383
# 2790      Vegetables, Herbs and Spices Supplement, 1991      NaN        1467
# 2707            Fish and Fish Products Supplement, 1993      NaN         358
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2739           289      5.7           2.5             49.1        1.9
# 2690           416     16.8          6.94             62.2       43.4
# 2795            77      5.5          3.58              3.4          3
# 2715            73      4.2           0.5              0.6        0.2
# 2721            22      0.1          0.01              3.8        3.8
# 2726            17      0.1          0.03                3          3
# 2793            31      0.3             0              4.8        4.6
# 2669           639     58.9           8.4              0.8        0.4
# 2706           435     23.8             4             42.2       15.3
# 2740           451     28.5          5.37             37.1         37
# 2683           326      7.2          1.88             38.9        8.2
# 2704           332      7.4           2.7             38.7        1.7
# 2790           350      7.0           2.9             53.7        3.2
# 2707            85      1.5           0.3                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# 2739       47.2       3.6          8.6     1.56  Cereals and cereal products
# 2690       18.8       1.1          3.4     0.33  Cereals and cereal products
# 2795        0.4       0.3          3.4     0.92       Milk and milk products
# 2715        0.3       0.4          8.1     0.01                   Vegetables
# 2721          0       0.8          1.1     0.01                   Vegetables
# 2726          0         1          0.5     0.01                   Vegetables
# 2793        0.2       2.4          0.9     0.04                   Vegetables
# 2669        0.5       9.3         21.8     0.05               Nuts and seeds
# 2706       26.9      17.4          4.3        0               Nuts and seeds
# 2740        0.1       5.1          9.1     0.07               Nuts and seeds
# 2683       30.7       7.4         22.8     0.16             Herbs and spices
# 2704         37        37          9.1     0.14             Herbs and spices
# 2790       50.5      22.7          6.7     0.08             Herbs and spices
# 2707          0         0         17.8     0.13       Fish and fish products

# %%
Red8 = pd.concat([Red7,filt_jc], axis=0, join='inner')
Red8
# Out:
#      Food Code                         Food Name  \
# 2739    11-925             Tortilla, wheat, soft
# 2690    11-845     Tarts, bakewell, iced, retail
# 2795    12-547                          Tzatziki
# 2715    13-570          Tofu, soya bean, steamed
# 2721    13-530  Tomatoes, canned, whole contents
# 2726    13-517           Tomatoes, standard, raw
# 2793    13-389           Turnip, flesh only, raw
# 2669    14-847                      Tahini paste
# 2706    14-848                         Tigernuts
# 2740    14-849                         Trail mix
# 2683    13-858           Tarragon, dried, ground
# 2704    13-883              Thyme, dried, ground
# 2790    13-861                  Turmeric, ground
# 2707    16-154                      Tilapia, raw
# 2749    16-224                 Trout, brown, raw
# 2757    16-416    Tuna, canned in brine, drained
#
#                                             Description Group  Previous  \
# 2739                              8 samples, 6 products    AF   11-632
# 2690  10 samples, 7 products, including large, slice...    AS   11-426
# 2795                 Yogurt-based Greek starter. Recipe    BN   12-410
# 2715                 Soya bean curd; 7 assorted samples    DB   13-119
# 2721  12 samples, 9 brands, whole and chopped, no ad...    DG   13-461
# 2726  22 samples, autumn and winter, UK grown and im...    DG   13-460
# 2793                                      Peeled thinly    DG   50-833
# 2669     Literature sources and calculation from 14-844    GA   50-996
# 2706                                 Literature sources    GA       NaN
# 2740            10 samples; mix of nuts and dried fruit    GA  50-1041
# 2683                                 Literature sources     H       NaN
# 2704                                 Literature sources     H   13-860
# 2790                                 Literature sources     H       NaN
# 2707                  Literature sources. Type of bream    JA       NaN
# 2749                  Analytical and literature sources    JC       NaN
# 2757                            11 samples, 10 products    JC   16-339
#
#                                    Main data references Footnote Energy (kJ)  \
# 2739  LGC, Nutrient analysis of bread and morning go...      NaN        1220
# 2690  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1746
# 2795                                       Updated 2013      NaN         321
# 2715      Vegetables, Herbs and Spices Supplement, 1991      NaN         305
# 2721  DH, Nutrient analysis of fruit and vegetables,...      NaN          94
# 2726  DH, Nutrient analysis of fruit and vegetables,...      NaN          71
# 2793  As Vegetables, Herbs and Spices Supplement, 19...      NaN         128
# 2669  Reviewed 2013. McCarthy and Matthews (1984) Co...      NaN        2639
# 2706                    Fruit and Nuts Supplement, 1992      NaN        1811
# 2740  Reviewed 2013. LGC, Nutritional composition of...      NaN        1880
# 2683  Marsh et al. (1977) Composition of foods: spic...      NaN        1374
# 2704  Marsh et al. (1977) Composition of foods: spic...      NaN        1383
# 2790      Vegetables, Herbs and Spices Supplement, 1991      NaN        1467
# 2707            Fish and Fish Products Supplement, 1993      NaN         358
# 2749            Fish and Fish Products Supplement, 1993      NaN         470
# 2757  DH, Nutrient analysis of fish and fish product...      NaN         460
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2739           289      5.7           2.5             49.1        1.9
# 2690           416     16.8          6.94             62.2       43.4
# 2795            77      5.5          3.58              3.4          3
# 2715            73      4.2           0.5              0.6        0.2
# 2721            22      0.1          0.01              3.8        3.8
# 2726            17      0.1          0.03                3          3
# 2793            31      0.3             0              4.8        4.6
# 2669           639     58.9           8.4              0.8        0.4
# 2706           435     23.8             4             42.2       15.3
# 2740           451     28.5          5.37             37.1         37
# 2683           326      7.2          1.88             38.9        8.2
# 2704           332      7.4           2.7             38.7        1.7
# 2790           350      7.0           2.9             53.7        3.2
# 2707            85      1.5           0.3                0          0
# 2749           112      3.8          0.84                0          0
# 2757           109      1.0           0.3                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# 2739       47.2       3.6          8.6     1.56  Cereals and cereal products
# 2690       18.8       1.1          3.4     0.33  Cereals and cereal products
# 2795        0.4       0.3          3.4     0.92       Milk and milk products
# 2715        0.3       0.4          8.1     0.01                   Vegetables
# 2721          0       0.8          1.1     0.01                   Vegetables
# 2726          0         1          0.5     0.01                   Vegetables
# 2793        0.2       2.4          0.9     0.04                   Vegetables
# 2669        0.5       9.3         21.8     0.05               Nuts and seeds
# 2706       26.9      17.4          4.3        0               Nuts and seeds
# 2740        0.1       5.1          9.1     0.07               Nuts and seeds
# 2683       30.7       7.4         22.8     0.16             Herbs and spices
# 2704         37        37          9.1     0.14             Herbs and spices
# 2790       50.5      22.7          6.7     0.08             Herbs and spices
# 2707          0         0         17.8     0.13       Fish and fish products
# 2749          0         0         19.4     0.14       Fish and fish products
# 2757          0         0         24.9     0.73       Fish and fish products

# %%
Red9 = pd.concat([Red8,filt_mco], axis=0, join='inner')
Red9
# Out:
#      Food Code                         Food Name  \
# 2739    11-925             Tortilla, wheat, soft
# 2690    11-845     Tarts, bakewell, iced, retail
# 2795    12-547                          Tzatziki
# 2715    13-570          Tofu, soya bean, steamed
# 2721    13-530  Tomatoes, canned, whole contents
# 2726    13-517           Tomatoes, standard, raw
# 2793    13-389           Turnip, flesh only, raw
# 2669    14-847                      Tahini paste
# 2706    14-848                         Tigernuts
# 2740    14-849                         Trail mix
# 2683    13-858           Tarragon, dried, ground
# 2704    13-883              Thyme, dried, ground
# 2790    13-861                  Turmeric, ground
# 2707    16-154                      Tilapia, raw
# 2749    16-224                 Trout, brown, raw
# 2757    16-416    Tuna, canned in brine, drained
# 2784    18-352                Turkey, whole, raw
#
#                                             Description Group  Previous  \
# 2739                              8 samples, 6 products    AF   11-632
# 2690  10 samples, 7 products, including large, slice...    AS   11-426
# 2795                 Yogurt-based Greek starter. Recipe    BN   12-410
# 2715                 Soya bean curd; 7 assorted samples    DB   13-119
# 2721  12 samples, 9 brands, whole and chopped, no ad...    DG   13-461
# 2726  22 samples, autumn and winter, UK grown and im...    DG   13-460
# 2793                                      Peeled thinly    DG   50-833
# 2669     Literature sources and calculation from 14-844    GA   50-996
# 2706                                 Literature sources    GA       NaN
# 2740            10 samples; mix of nuts and dried fruit    GA  50-1041
# 2683                                 Literature sources     H       NaN
# 2704                                 Literature sources     H   13-860
# 2790                                 Literature sources     H       NaN
# 2707                  Literature sources. Type of bream    JA       NaN
# 2749                  Analytical and literature sources    JC       NaN
# 2757                            11 samples, 10 products    JC   16-339
# 2784  Calculated from 49% light meat, 39% dark meat ...   MCO       NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2739  LGC, Nutrient analysis of bread and morning go...      NaN        1220
# 2690  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1746
# 2795                                       Updated 2013      NaN         321
# 2715      Vegetables, Herbs and Spices Supplement, 1991      NaN         305
# 2721  DH, Nutrient analysis of fruit and vegetables,...      NaN          94
# 2726  DH, Nutrient analysis of fruit and vegetables,...      NaN          71
# 2793  As Vegetables, Herbs and Spices Supplement, 19...      NaN         128
# 2669  Reviewed 2013. McCarthy and Matthews (1984) Co...      NaN        2639
# 2706                    Fruit and Nuts Supplement, 1992      NaN        1811
# 2740  Reviewed 2013. LGC, Nutritional composition of...      NaN        1880
# 2683  Marsh et al. (1977) Composition of foods: spic...      NaN        1374
# 2704  Marsh et al. (1977) Composition of foods: spic...      NaN        1383
# 2790      Vegetables, Herbs and Spices Supplement, 1991      NaN        1467
# 2707            Fish and Fish Products Supplement, 1993      NaN         358
# 2749            Fish and Fish Products Supplement, 1993      NaN         470
# 2757  DH, Nutrient analysis of fish and fish product...      NaN         460
# 2784  LGC, Nutrient analysis of chicken and turkey, ...      NaN         560
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2739           289      5.7           2.5             49.1        1.9
# 2690           416     16.8          6.94             62.2       43.4
# 2795            77      5.5          3.58              3.4          3
# 2715            73      4.2           0.5              0.6        0.2
# 2721            22      0.1          0.01              3.8        3.8
# 2726            17      0.1          0.03                3          3
# 2793            31      0.3             0              4.8        4.6
# 2669           639     58.9           8.4              0.8        0.4
# 2706           435     23.8             4             42.2       15.3
# 2740           451     28.5          5.37             37.1         37
# 2683           326      7.2          1.88             38.9        8.2
# 2704           332      7.4           2.7             38.7        1.7
# 2790           350      7.0           2.9             53.7        3.2
# 2707            85      1.5           0.3                0          0
# 2749           112      3.8          0.84                0          0
# 2757           109      1.0           0.3                0          0
# 2784           133      5.2           1.7                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# 2739       47.2       3.6          8.6     1.56  Cereals and cereal products
# 2690       18.8       1.1          3.4     0.33  Cereals and cereal products
# 2795        0.4       0.3          3.4     0.92       Milk and milk products
# 2715        0.3       0.4          8.1     0.01                   Vegetables
# 2721          0       0.8          1.1     0.01                   Vegetables
# 2726          0         1          0.5     0.01                   Vegetables
# 2793        0.2       2.4          0.9     0.04                   Vegetables
# 2669        0.5       9.3         21.8     0.05               Nuts and seeds
# 2706       26.9      17.4          4.3        0               Nuts and seeds
# 2740        0.1       5.1          9.1     0.07               Nuts and seeds
# 2683       30.7       7.4         22.8     0.16             Herbs and spices
# 2704         37        37          9.1     0.14             Herbs and spices
# 2790       50.5      22.7          6.7     0.08             Herbs and spices
# 2707          0         0         17.8     0.13       Fish and fish products
# 2749          0         0         19.4     0.14       Fish and fish products
# 2757          0         0         24.9     0.73       Fish and fish products
# 2784          0         0         21.6     0.18       Meat and meat products

# %%
Red10 = pd.concat([Red9,filt_mg], axis=0, join='inner')
Red10
# Out:
#      Food Code                         Food Name  \
# 2739    11-925             Tortilla, wheat, soft
# 2690    11-845     Tarts, bakewell, iced, retail
# 2795    12-547                          Tzatziki
# 2715    13-570          Tofu, soya bean, steamed
# 2721    13-530  Tomatoes, canned, whole contents
# 2726    13-517           Tomatoes, standard, raw
# 2793    13-389           Turnip, flesh only, raw
# 2669    14-847                      Tahini paste
# 2706    14-848                         Tigernuts
# 2740    14-849                         Trail mix
# 2683    13-858           Tarragon, dried, ground
# 2704    13-883              Thyme, dried, ground
# 2790    13-861                  Turmeric, ground
# 2707    16-154                      Tilapia, raw
# 2749    16-224                 Trout, brown, raw
# 2757    16-416    Tuna, canned in brine, drained
# 2784    18-352                Turkey, whole, raw
# 2729    18-423                 Tongue, lamb, raw
# 2747    18-428               Tripe, dressed, raw
#
#                                             Description Group  Previous  \
# 2739                              8 samples, 6 products    AF   11-632
# 2690  10 samples, 7 products, including large, slice...    AS   11-426
# 2795                 Yogurt-based Greek starter. Recipe    BN   12-410
# 2715                 Soya bean curd; 7 assorted samples    DB   13-119
# 2721  12 samples, 9 brands, whole and chopped, no ad...    DG   13-461
# 2726  22 samples, autumn and winter, UK grown and im...    DG   13-460
# 2793                                      Peeled thinly    DG   50-833
# 2669     Literature sources and calculation from 14-844    GA   50-996
# 2706                                 Literature sources    GA       NaN
# 2740            10 samples; mix of nuts and dried fruit    GA  50-1041
# 2683                                 Literature sources     H       NaN
# 2704                                 Literature sources     H   13-860
# 2790                                 Literature sources     H       NaN
# 2707                  Literature sources. Type of bream    JA       NaN
# 2749                  Analytical and literature sources    JC       NaN
# 2757                            11 samples, 10 products    JC   16-339
# 2784  Calculated from 49% light meat, 39% dark meat ...   MCO       NaN
# 2729                                         20 samples    MG   50-497
# 2747                                          6 samples    MG   50-501
#
#                                    Main data references Footnote Energy (kJ)  \
# 2739  LGC, Nutrient analysis of bread and morning go...      NaN        1220
# 2690  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1746
# 2795                                       Updated 2013      NaN         321
# 2715      Vegetables, Herbs and Spices Supplement, 1991      NaN         305
# 2721  DH, Nutrient analysis of fruit and vegetables,...      NaN          94
# 2726  DH, Nutrient analysis of fruit and vegetables,...      NaN          71
# 2793  As Vegetables, Herbs and Spices Supplement, 19...      NaN         128
# 2669  Reviewed 2013. McCarthy and Matthews (1984) Co...      NaN        2639
# 2706                    Fruit and Nuts Supplement, 1992      NaN        1811
# 2740  Reviewed 2013. LGC, Nutritional composition of...      NaN        1880
# 2683  Marsh et al. (1977) Composition of foods: spic...      NaN        1374
# 2704  Marsh et al. (1977) Composition of foods: spic...      NaN        1383
# 2790      Vegetables, Herbs and Spices Supplement, 1991      NaN        1467
# 2707            Fish and Fish Products Supplement, 1993      NaN         358
# 2749            Fish and Fish Products Supplement, 1993      NaN         470
# 2757  DH, Nutrient analysis of fish and fish product...      NaN         460
# 2784  LGC, Nutrient analysis of chicken and turkey, ...      NaN         560
# 2729  MW4 (1978). Values reviewed for Meat, Poultry ...      NaN         801
# 2747  LGC, Nutritional analysis of meat and poultry ...      NaN         140
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2739           289      5.7           2.5             49.1        1.9
# 2690           416     16.8          6.94             62.2       43.4
# 2795            77      5.5          3.58              3.4          3
# 2715            73      4.2           0.5              0.6        0.2
# 2721            22      0.1          0.01              3.8        3.8
# 2726            17      0.1          0.03                3          3
# 2793            31      0.3             0              4.8        4.6
# 2669           639     58.9           8.4              0.8        0.4
# 2706           435     23.8             4             42.2       15.3
# 2740           451     28.5          5.37             37.1         37
# 2683           326      7.2          1.88             38.9        8.2
# 2704           332      7.4           2.7             38.7        1.7
# 2790           350      7.0           2.9             53.7        3.2
# 2707            85      1.5           0.3                0          0
# 2749           112      3.8          0.84                0          0
# 2757           109      1.0           0.3                0          0
# 2784           133      5.2           1.7                0          0
# 2729           193     14.6          6.63                0          0
# 2747            33      0.5           0.2                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# 2739       47.2       3.6          8.6     1.56  Cereals and cereal products
# 2690       18.8       1.1          3.4     0.33  Cereals and cereal products
# 2795        0.4       0.3          3.4     0.92       Milk and milk products
# 2715        0.3       0.4          8.1     0.01                   Vegetables
# 2721          0       0.8          1.1     0.01                   Vegetables
# 2726          0         1          0.5     0.01                   Vegetables
# 2793        0.2       2.4          0.9     0.04                   Vegetables
# 2669        0.5       9.3         21.8     0.05               Nuts and seeds
# 2706       26.9      17.4          4.3        0               Nuts and seeds
# 2740        0.1       5.1          9.1     0.07               Nuts and seeds
# 2683       30.7       7.4         22.8     0.16             Herbs and spices
# 2704         37        37          9.1     0.14             Herbs and spices
# 2790       50.5      22.7          6.7     0.08             Herbs and spices
# 2707          0         0         17.8     0.13       Fish and fish products
# 2749          0         0         19.4     0.14       Fish and fish products
# 2757          0         0         24.9     0.73       Fish and fish products
# 2784          0         0         21.6     0.18       Meat and meat products
# 2729          0         0         15.3     1.05       Meat and meat products
# 2747          0         0          7.1     0.13       Meat and meat products

# %%
Red11 = pd.concat([Red10,mi], axis=0, join='inner')
Red11
# Out:
#      Food Code                         Food Name  \
# 2739    11-925             Tortilla, wheat, soft
# 2690    11-845     Tarts, bakewell, iced, retail
# 2795    12-547                          Tzatziki
# 2715    13-570          Tofu, soya bean, steamed
# 2721    13-530  Tomatoes, canned, whole contents
# 2726    13-517           Tomatoes, standard, raw
# 2793    13-389           Turnip, flesh only, raw
# 2669    14-847                      Tahini paste
# 2706    14-848                         Tigernuts
# 2740    14-849                         Trail mix
# 2683    13-858           Tarragon, dried, ground
# 2704    13-883              Thyme, dried, ground
# 2790    13-861                  Turmeric, ground
# 2707    16-154                      Tilapia, raw
# 2749    16-224                 Trout, brown, raw
# 2757    16-416    Tuna, canned in brine, drained
# 2784    18-352                Turkey, whole, raw
# 2729    18-423                 Tongue, lamb, raw
# 2747    18-428               Tripe, dressed, raw
# 2765    19-543                     Turkey slices
#
#                                             Description Group  Previous  \
# 2739                              8 samples, 6 products    AF   11-632
# 2690  10 samples, 7 products, including large, slice...    AS   11-426
# 2795                 Yogurt-based Greek starter. Recipe    BN   12-410
# 2715                 Soya bean curd; 7 assorted samples    DB   13-119
# 2721  12 samples, 9 brands, whole and chopped, no ad...    DG   13-461
# 2726  22 samples, autumn and winter, UK grown and im...    DG   13-460
# 2793                                      Peeled thinly    DG   50-833
# 2669     Literature sources and calculation from 14-844    GA   50-996
# 2706                                 Literature sources    GA       NaN
# 2740            10 samples; mix of nuts and dried fruit    GA  50-1041
# 2683                                 Literature sources     H       NaN
# 2704                                 Literature sources     H   13-860
# 2790                                 Literature sources     H       NaN
# 2707                  Literature sources. Type of bream    JA       NaN
# 2749                  Analytical and literature sources    JC       NaN
# 2757                            11 samples, 10 products    JC   16-339
# 2784  Calculated from 49% light meat, 39% dark meat ...   MCO       NaN
# 2729                                         20 samples    MG   50-497
# 2747                                          6 samples    MG   50-501
# 2765  13 samples including honey roast and wafer thi...    MI   19-157
#
#                                    Main data references Footnote Energy (kJ)  \
# 2739  LGC, Nutrient analysis of bread and morning go...      NaN        1220
# 2690  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1746
# 2795                                       Updated 2013      NaN         321
# 2715      Vegetables, Herbs and Spices Supplement, 1991      NaN         305
# 2721  DH, Nutrient analysis of fruit and vegetables,...      NaN          94
# 2726  DH, Nutrient analysis of fruit and vegetables,...      NaN          71
# 2793  As Vegetables, Herbs and Spices Supplement, 19...      NaN         128
# 2669  Reviewed 2013. McCarthy and Matthews (1984) Co...      NaN        2639
# 2706                    Fruit and Nuts Supplement, 1992      NaN        1811
# 2740  Reviewed 2013. LGC, Nutritional composition of...      NaN        1880
# 2683  Marsh et al. (1977) Composition of foods: spic...      NaN        1374
# 2704  Marsh et al. (1977) Composition of foods: spic...      NaN        1383
# 2790      Vegetables, Herbs and Spices Supplement, 1991      NaN        1467
# 2707            Fish and Fish Products Supplement, 1993      NaN         358
# 2749            Fish and Fish Products Supplement, 1993      NaN         470
# 2757  DH, Nutrient analysis of fish and fish product...      NaN         460
# 2784  LGC, Nutrient analysis of chicken and turkey, ...      NaN         560
# 2729  MW4 (1978). Values reviewed for Meat, Poultry ...      NaN         801
# 2747  LGC, Nutritional analysis of meat and poultry ...      NaN         140
# 2765  LGC, Nutritional analysis of meat and poultry ...      NaN         481
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2739           289      5.7           2.5             49.1        1.9
# 2690           416     16.8          6.94             62.2       43.4
# 2795            77      5.5          3.58              3.4          3
# 2715            73      4.2           0.5              0.6        0.2
# 2721            22      0.1          0.01              3.8        3.8
# 2726            17      0.1          0.03                3          3
# 2793            31      0.3             0              4.8        4.6
# 2669           639     58.9           8.4              0.8        0.4
# 2706           435     23.8             4             42.2       15.3
# 2740           451     28.5          5.37             37.1         37
# 2683           326      7.2          1.88             38.9        8.2
# 2704           332      7.4           2.7             38.7        1.7
# 2790           350      7.0           2.9             53.7        3.2
# 2707            85      1.5           0.3                0          0
# 2749           112      3.8          0.84                0          0
# 2757           109      1.0           0.3                0          0
# 2784           133      5.2           1.7                0          0
# 2729           193     14.6          6.63                0          0
# 2747            33      0.5           0.2                0          0
# 2765           114      1.9           0.6              1.1        0.4
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# 2739       47.2       3.6          8.6     1.56  Cereals and cereal products
# 2690       18.8       1.1          3.4     0.33  Cereals and cereal products
# 2795        0.4       0.3          3.4     0.92       Milk and milk products
# 2715        0.3       0.4          8.1     0.01                   Vegetables
# 2721          0       0.8          1.1     0.01                   Vegetables
# 2726          0         1          0.5     0.01                   Vegetables
# 2793        0.2       2.4          0.9     0.04                   Vegetables
# 2669        0.5       9.3         21.8     0.05               Nuts and seeds
# 2706       26.9      17.4          4.3        0               Nuts and seeds
# 2740        0.1       5.1          9.1     0.07               Nuts and seeds
# 2683       30.7       7.4         22.8     0.16             Herbs and spices
# 2704         37        37          9.1     0.14             Herbs and spices
# 2790       50.5      22.7          6.7     0.08             Herbs and spices
# 2707          0         0         17.8     0.13       Fish and fish products
# 2749          0         0         19.4     0.14       Fish and fish products
# 2757          0         0         24.9     0.73       Fish and fish products
# 2784          0         0         21.6     0.18       Meat and meat products
# 2729          0         0         15.3     1.05       Meat and meat products
# 2747          0         0          7.1     0.13       Meat and meat products
# 2765        0.4         0         23.0     1.48       Meat and meat products

# %%
Red12 = pd.concat([Red11,paa], axis=0, join='inner')
Red12
# Out:
#      Food Code                         Food Name  \
# 2739    11-925             Tortilla, wheat, soft
# 2690    11-845     Tarts, bakewell, iced, retail
# 2795    12-547                          Tzatziki
# 2715    13-570          Tofu, soya bean, steamed
# 2721    13-530  Tomatoes, canned, whole contents
# 2726    13-517           Tomatoes, standard, raw
# 2793    13-389           Turnip, flesh only, raw
# 2669    14-847                      Tahini paste
# 2706    14-848                         Tigernuts
# 2740    14-849                         Trail mix
# 2683    13-858           Tarragon, dried, ground
# 2704    13-883              Thyme, dried, ground
# 2790    13-861                  Turmeric, ground
# 2707    16-154                      Tilapia, raw
# 2749    16-224                 Trout, brown, raw
# 2757    16-416    Tuna, canned in brine, drained
# 2784    18-352                Turkey, whole, raw
# 2729    18-423                 Tongue, lamb, raw
# 2747    18-428               Tripe, dressed, raw
# 2765    19-543                     Turkey slices
# 2694    17-165     Tea, black, infusion, average
#
#                                             Description Group  Previous  \
# 2739                              8 samples, 6 products    AF   11-632
# 2690  10 samples, 7 products, including large, slice...    AS   11-426
# 2795                 Yogurt-based Greek starter. Recipe    BN   12-410
# 2715                 Soya bean curd; 7 assorted samples    DB   13-119
# 2721  12 samples, 9 brands, whole and chopped, no ad...    DG   13-461
# 2726  22 samples, autumn and winter, UK grown and im...    DG   13-460
# 2793                                      Peeled thinly    DG   50-833
# 2669     Literature sources and calculation from 14-844    GA   50-996
# 2706                                 Literature sources    GA       NaN
# 2740            10 samples; mix of nuts and dried fruit    GA  50-1041
# 2683                                 Literature sources     H       NaN
# 2704                                 Literature sources     H   13-860
# 2790                                 Literature sources     H       NaN
# 2707                  Literature sources. Type of bream    JA       NaN
# 2749                  Analytical and literature sources    JC       NaN
# 2757                            11 samples, 10 products    JC   16-339
# 2784  Calculated from 49% light meat, 39% dark meat ...   MCO       NaN
# 2729                                         20 samples    MG   50-497
# 2747                                          6 samples    MG   50-501
# 2765  13 samples including honey roast and wafer thi...    MI   19-157
# 2694  15g leaves per litre water, strained after 5 m...   PAA       NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2739  LGC, Nutrient analysis of bread and morning go...      NaN        1220
# 2690  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1746
# 2795                                       Updated 2013      NaN         321
# 2715      Vegetables, Herbs and Spices Supplement, 1991      NaN         305
# 2721  DH, Nutrient analysis of fruit and vegetables,...      NaN          94
# 2726  DH, Nutrient analysis of fruit and vegetables,...      NaN          71
# 2793  As Vegetables, Herbs and Spices Supplement, 19...      NaN         128
# 2669  Reviewed 2013. McCarthy and Matthews (1984) Co...      NaN        2639
# 2706                    Fruit and Nuts Supplement, 1992      NaN        1811
# 2740  Reviewed 2013. LGC, Nutritional composition of...      NaN        1880
# 2683  Marsh et al. (1977) Composition of foods: spic...      NaN        1374
# 2704  Marsh et al. (1977) Composition of foods: spic...      NaN        1383
# 2790      Vegetables, Herbs and Spices Supplement, 1991      NaN        1467
# 2707            Fish and Fish Products Supplement, 1993      NaN         358
# 2749            Fish and Fish Products Supplement, 1993      NaN         470
# 2757  DH, Nutrient analysis of fish and fish product...      NaN         460
# 2784  LGC, Nutrient analysis of chicken and turkey, ...      NaN         560
# 2729  MW4 (1978). Values reviewed for Meat, Poultry ...      NaN         801
# 2747  LGC, Nutritional analysis of meat and poultry ...      NaN         140
# 2765  LGC, Nutritional analysis of meat and poultry ...      NaN         481
# 2694  Reviewed 2013. LGC, Alcoholic beverages, soft ...      NaN           0
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2739           289      5.7           2.5             49.1        1.9
# 2690           416     16.8          6.94             62.2       43.4
# 2795            77      5.5          3.58              3.4          3
# 2715            73      4.2           0.5              0.6        0.2
# 2721            22      0.1          0.01              3.8        3.8
# 2726            17      0.1          0.03                3          3
# 2793            31      0.3             0              4.8        4.6
# 2669           639     58.9           8.4              0.8        0.4
# 2706           435     23.8             4             42.2       15.3
# 2740           451     28.5          5.37             37.1         37
# 2683           326      7.2          1.88             38.9        8.2
# 2704           332      7.4           2.7             38.7        1.7
# 2790           350      7.0           2.9             53.7        3.2
# 2707            85      1.5           0.3                0          0
# 2749           112      3.8          0.84                0          0
# 2757           109      1.0           0.3                0          0
# 2784           133      5.2           1.7                0          0
# 2729           193     14.6          6.63                0          0
# 2747            33      0.5           0.2                0          0
# 2765           114      1.9           0.6              1.1        0.4
# 2694             0      0.0             0                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# 2739       47.2       3.6          8.6     1.56  Cereals and cereal products
# 2690       18.8       1.1          3.4     0.33  Cereals and cereal products
# 2795        0.4       0.3          3.4     0.92       Milk and milk products
# 2715        0.3       0.4          8.1     0.01                   Vegetables
# 2721          0       0.8          1.1     0.01                   Vegetables
# 2726          0         1          0.5     0.01                   Vegetables
# 2793        0.2       2.4          0.9     0.04                   Vegetables
# 2669        0.5       9.3         21.8     0.05               Nuts and seeds
# 2706       26.9      17.4          4.3        0               Nuts and seeds
# 2740        0.1       5.1          9.1     0.07               Nuts and seeds
# 2683       30.7       7.4         22.8     0.16             Herbs and spices
# 2704         37        37          9.1     0.14             Herbs and spices
# 2790       50.5      22.7          6.7     0.08             Herbs and spices
# 2707          0         0         17.8     0.13       Fish and fish products
# 2749          0         0         19.4     0.14       Fish and fish products
# 2757          0         0         24.9     0.73       Fish and fish products
# 2784          0         0         21.6     0.18       Meat and meat products
# 2729          0         0         15.3     1.05       Meat and meat products
# 2747          0         0          7.1     0.13       Meat and meat products
# 2765        0.4         0         23.0     1.48       Meat and meat products
# 2694          0         0          0.0        0                    Beverages

# %%
Red13 = pd.concat([Red12,pca], axis=0, join='inner')
Red13
# Out:
#      Food Code                         Food Name  \
# 2739    11-925             Tortilla, wheat, soft
# 2690    11-845     Tarts, bakewell, iced, retail
# 2795    12-547                          Tzatziki
# 2715    13-570          Tofu, soya bean, steamed
# 2721    13-530  Tomatoes, canned, whole contents
# 2726    13-517           Tomatoes, standard, raw
# 2793    13-389           Turnip, flesh only, raw
# 2669    14-847                      Tahini paste
# 2706    14-848                         Tigernuts
# 2740    14-849                         Trail mix
# 2683    13-858           Tarragon, dried, ground
# 2704    13-883              Thyme, dried, ground
# 2790    13-861                  Turmeric, ground
# 2707    16-154                      Tilapia, raw
# 2749    16-224                 Trout, brown, raw
# 2757    16-416    Tuna, canned in brine, drained
# 2784    18-352                Turkey, whole, raw
# 2729    18-423                 Tongue, lamb, raw
# 2747    18-428               Tripe, dressed, raw
# 2765    19-543                     Turkey slices
# 2694    17-165     Tea, black, infusion, average
# 2734    17-736                       Tonic water
#
#                                             Description Group  Previous  \
# 2739                              8 samples, 6 products    AF   11-632
# 2690  10 samples, 7 products, including large, slice...    AS   11-426
# 2795                 Yogurt-based Greek starter. Recipe    BN   12-410
# 2715                 Soya bean curd; 7 assorted samples    DB   13-119
# 2721  12 samples, 9 brands, whole and chopped, no ad...    DG   13-461
# 2726  22 samples, autumn and winter, UK grown and im...    DG   13-460
# 2793                                      Peeled thinly    DG   50-833
# 2669     Literature sources and calculation from 14-844    GA   50-996
# 2706                                 Literature sources    GA       NaN
# 2740            10 samples; mix of nuts and dried fruit    GA  50-1041
# 2683                                 Literature sources     H       NaN
# 2704                                 Literature sources     H   13-860
# 2790                                 Literature sources     H       NaN
# 2707                  Literature sources. Type of bream    JA       NaN
# 2749                  Analytical and literature sources    JC       NaN
# 2757                            11 samples, 10 products    JC   16-339
# 2784  Calculated from 49% light meat, 39% dark meat ...   MCO       NaN
# 2729                                         20 samples    MG   50-497
# 2747                                          6 samples    MG   50-501
# 2765  13 samples including honey roast and wafer thi...    MI   19-157
# 2694  15g leaves per litre water, strained after 5 m...   PAA       NaN
# 2734                                 Literature sources   PCA   17-184
#
#                                    Main data references Footnote Energy (kJ)  \
# 2739  LGC, Nutrient analysis of bread and morning go...      NaN        1220
# 2690  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1746
# 2795                                       Updated 2013      NaN         321
# 2715      Vegetables, Herbs and Spices Supplement, 1991      NaN         305
# 2721  DH, Nutrient analysis of fruit and vegetables,...      NaN          94
# 2726  DH, Nutrient analysis of fruit and vegetables,...      NaN          71
# 2793  As Vegetables, Herbs and Spices Supplement, 19...      NaN         128
# 2669  Reviewed 2013. McCarthy and Matthews (1984) Co...      NaN        2639
# 2706                    Fruit and Nuts Supplement, 1992      NaN        1811
# 2740  Reviewed 2013. LGC, Nutritional composition of...      NaN        1880
# 2683  Marsh et al. (1977) Composition of foods: spic...      NaN        1374
# 2704  Marsh et al. (1977) Composition of foods: spic...      NaN        1383
# 2790      Vegetables, Herbs and Spices Supplement, 1991      NaN        1467
# 2707            Fish and Fish Products Supplement, 1993      NaN         358
# 2749            Fish and Fish Products Supplement, 1993      NaN         470
# 2757  DH, Nutrient analysis of fish and fish product...      NaN         460
# 2784  LGC, Nutrient analysis of chicken and turkey, ...      NaN         560
# 2729  MW4 (1978). Values reviewed for Meat, Poultry ...      NaN         801
# 2747  LGC, Nutritional analysis of meat and poultry ...      NaN         140
# 2765  LGC, Nutritional analysis of meat and poultry ...      NaN         481
# 2694  Reviewed 2013. LGC, Alcoholic beverages, soft ...      NaN           0
# 2734  Cutrufelli and Matthews (1986) Composition of ...      NaN          95
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2739           289      5.7           2.5             49.1        1.9
# 2690           416     16.8          6.94             62.2       43.4
# 2795            77      5.5          3.58              3.4          3
# 2715            73      4.2           0.5              0.6        0.2
# 2721            22      0.1          0.01              3.8        3.8
# 2726            17      0.1          0.03                3          3
# 2793            31      0.3             0              4.8        4.6
# 2669           639     58.9           8.4              0.8        0.4
# 2706           435     23.8             4             42.2       15.3
# 2740           451     28.5          5.37             37.1         37
# 2683           326      7.2          1.88             38.9        8.2
# 2704           332      7.4           2.7             38.7        1.7
# 2790           350      7.0           2.9             53.7        3.2
# 2707            85      1.5           0.3                0          0
# 2749           112      3.8          0.84                0          0
# 2757           109      1.0           0.3                0          0
# 2784           133      5.2           1.7                0          0
# 2729           193     14.6          6.63                0          0
# 2747            33      0.5           0.2                0          0
# 2765           114      1.9           0.6              1.1        0.4
# 2694             0      0.0             0                0          0
# 2734            22      0.0             0              5.6        5.6
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# 2739       47.2       3.6          8.6     1.56  Cereals and cereal products
# 2690       18.8       1.1          3.4     0.33  Cereals and cereal products
# 2795        0.4       0.3          3.4     0.92       Milk and milk products
# 2715        0.3       0.4          8.1     0.01                   Vegetables
# 2721          0       0.8          1.1     0.01                   Vegetables
# 2726          0         1          0.5     0.01                   Vegetables
# 2793        0.2       2.4          0.9     0.04                   Vegetables
# 2669        0.5       9.3         21.8     0.05               Nuts and seeds
# 2706       26.9      17.4          4.3        0               Nuts and seeds
# 2740        0.1       5.1          9.1     0.07               Nuts and seeds
# 2683       30.7       7.4         22.8     0.16             Herbs and spices
# 2704         37        37          9.1     0.14             Herbs and spices
# 2790       50.5      22.7          6.7     0.08             Herbs and spices
# 2707          0         0         17.8     0.13       Fish and fish products
# 2749          0         0         19.4     0.14       Fish and fish products
# 2757          0         0         24.9     0.73       Fish and fish products
# 2784          0         0         21.6     0.18       Meat and meat products
# 2729          0         0         15.3     1.05       Meat and meat products
# 2747          0         0          7.1     0.13       Meat and meat products
# 2765        0.4         0         23.0     1.48       Meat and meat products
# 2694          0         0          0.0        0                    Beverages
# 2734          0         0          0.0     0.01                    Beverages

# %%
Red14 = pd.concat([Red13,pe], axis=0, join='inner')
Red14
# Out:
#      Food Code                         Food Name  \
# 2739    11-925             Tortilla, wheat, soft
# 2690    11-845     Tarts, bakewell, iced, retail
# 2795    12-547                          Tzatziki
# 2715    13-570          Tofu, soya bean, steamed
# 2721    13-530  Tomatoes, canned, whole contents
# 2726    13-517           Tomatoes, standard, raw
# 2793    13-389           Turnip, flesh only, raw
# 2669    14-847                      Tahini paste
# 2706    14-848                         Tigernuts
# 2740    14-849                         Trail mix
# 2683    13-858           Tarragon, dried, ground
# 2704    13-883              Thyme, dried, ground
# 2790    13-861                  Turmeric, ground
# 2707    16-154                      Tilapia, raw
# 2749    16-224                 Trout, brown, raw
# 2757    16-416    Tuna, canned in brine, drained
# 2784    18-352                Turkey, whole, raw
# 2729    18-423                 Tongue, lamb, raw
# 2747    18-428               Tripe, dressed, raw
# 2765    19-543                     Turkey slices
# 2694    17-165     Tea, black, infusion, average
# 2734    17-736                       Tonic water
# 2717    13-382                      Tomato juice
#
#                                             Description Group  Previous  \
# 2739                              8 samples, 6 products    AF   11-632
# 2690  10 samples, 7 products, including large, slice...    AS   11-426
# 2795                 Yogurt-based Greek starter. Recipe    BN   12-410
# 2715                 Soya bean curd; 7 assorted samples    DB   13-119
# 2721  12 samples, 9 brands, whole and chopped, no ad...    DG   13-461
# 2726  22 samples, autumn and winter, UK grown and im...    DG   13-460
# 2793                                      Peeled thinly    DG   50-833
# 2669     Literature sources and calculation from 14-844    GA   50-996
# 2706                                 Literature sources    GA       NaN
# 2740            10 samples; mix of nuts and dried fruit    GA  50-1041
# 2683                                 Literature sources     H       NaN
# 2704                                 Literature sources     H   13-860
# 2790                                 Literature sources     H       NaN
# 2707                  Literature sources. Type of bream    JA       NaN
# 2749                  Analytical and literature sources    JC       NaN
# 2757                            11 samples, 10 products    JC   16-339
# 2784  Calculated from 49% light meat, 39% dark meat ...   MCO       NaN
# 2729                                         20 samples    MG   50-497
# 2747                                          6 samples    MG   50-501
# 2765  13 samples including honey roast and wafer thi...    MI   19-157
# 2694  15g leaves per litre water, strained after 5 m...   PAA       NaN
# 2734                                 Literature sources   PCA   17-184
# 2717                               10 samples, 9 brands    PE  50-1093
#
#                                    Main data references Footnote Energy (kJ)  \
# 2739  LGC, Nutrient analysis of bread and morning go...      NaN        1220
# 2690  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1746
# 2795                                       Updated 2013      NaN         321
# 2715      Vegetables, Herbs and Spices Supplement, 1991      NaN         305
# 2721  DH, Nutrient analysis of fruit and vegetables,...      NaN          94
# 2726  DH, Nutrient analysis of fruit and vegetables,...      NaN          71
# 2793  As Vegetables, Herbs and Spices Supplement, 19...      NaN         128
# 2669  Reviewed 2013. McCarthy and Matthews (1984) Co...      NaN        2639
# 2706                    Fruit and Nuts Supplement, 1992      NaN        1811
# 2740  Reviewed 2013. LGC, Nutritional composition of...      NaN        1880
# 2683  Marsh et al. (1977) Composition of foods: spic...      NaN        1374
# 2704  Marsh et al. (1977) Composition of foods: spic...      NaN        1383
# 2790      Vegetables, Herbs and Spices Supplement, 1991      NaN        1467
# 2707            Fish and Fish Products Supplement, 1993      NaN         358
# 2749            Fish and Fish Products Supplement, 1993      NaN         470
# 2757  DH, Nutrient analysis of fish and fish product...      NaN         460
# 2784  LGC, Nutrient analysis of chicken and turkey, ...      NaN         560
# 2729  MW4 (1978). Values reviewed for Meat, Poultry ...      NaN         801
# 2747  LGC, Nutritional analysis of meat and poultry ...      NaN         140
# 2765  LGC, Nutritional analysis of meat and poultry ...      NaN         481
# 2694  Reviewed 2013. LGC, Alcoholic beverages, soft ...      NaN           0
# 2734  Cutrufelli and Matthews (1986) Composition of ...      NaN          95
# 2717  Reviewed 2013. LGC, Canned and other processed...      NaN          70
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2739           289      5.7           2.5             49.1        1.9
# 2690           416     16.8          6.94             62.2       43.4
# 2795            77      5.5          3.58              3.4          3
# 2715            73      4.2           0.5              0.6        0.2
# 2721            22      0.1          0.01              3.8        3.8
# 2726            17      0.1          0.03                3          3
# 2793            31      0.3             0              4.8        4.6
# 2669           639     58.9           8.4              0.8        0.4
# 2706           435     23.8             4             42.2       15.3
# 2740           451     28.5          5.37             37.1         37
# 2683           326      7.2          1.88             38.9        8.2
# 2704           332      7.4           2.7             38.7        1.7
# 2790           350      7.0           2.9             53.7        3.2
# 2707            85      1.5           0.3                0          0
# 2749           112      3.8          0.84                0          0
# 2757           109      1.0           0.3                0          0
# 2784           133      5.2           1.7                0          0
# 2729           193     14.6          6.63                0          0
# 2747            33      0.5           0.2                0          0
# 2765           114      1.9           0.6              1.1        0.4
# 2694             0      0.0             0                0          0
# 2734            22      0.0             0              5.6        5.6
# 2717            16      0.0             0                3          3
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# 2739       47.2       3.6          8.6     1.56  Cereals and cereal products
# 2690       18.8       1.1          3.4     0.33  Cereals and cereal products
# 2795        0.4       0.3          3.4     0.92       Milk and milk products
# 2715        0.3       0.4          8.1     0.01                   Vegetables
# 2721          0       0.8          1.1     0.01                   Vegetables
# 2726          0         1          0.5     0.01                   Vegetables
# 2793        0.2       2.4          0.9     0.04                   Vegetables
# 2669        0.5       9.3         21.8     0.05               Nuts and seeds
# 2706       26.9      17.4          4.3        0               Nuts and seeds
# 2740        0.1       5.1          9.1     0.07               Nuts and seeds
# 2683       30.7       7.4         22.8     0.16             Herbs and spices
# 2704         37        37          9.1     0.14             Herbs and spices
# 2790       50.5      22.7          6.7     0.08             Herbs and spices
# 2707          0         0         17.8     0.13       Fish and fish products
# 2749          0         0         19.4     0.14       Fish and fish products
# 2757          0         0         24.9     0.73       Fish and fish products
# 2784          0         0         21.6     0.18       Meat and meat products
# 2729          0         0         15.3     1.05       Meat and meat products
# 2747          0         0          7.1     0.13       Meat and meat products
# 2765        0.4         0         23.0     1.48       Meat and meat products
# 2694          0         0          0.0        0                    Beverages
# 2734          0         0          0.0     0.01                    Beverages
# 2717          0       0.6          0.8     0.58                    Beverages

# %%
Red15 = pd.concat([Red14,sc], axis=0, join='inner')
Red15
# Out:
#      Food Code                         Food Name  \
# 2739    11-925             Tortilla, wheat, soft
# 2690    11-845     Tarts, bakewell, iced, retail
# 2795    12-547                          Tzatziki
# 2715    13-570          Tofu, soya bean, steamed
# 2721    13-530  Tomatoes, canned, whole contents
# 2726    13-517           Tomatoes, standard, raw
# 2793    13-389           Turnip, flesh only, raw
# 2669    14-847                      Tahini paste
# 2706    14-848                         Tigernuts
# 2740    14-849                         Trail mix
# 2683    13-858           Tarragon, dried, ground
# 2704    13-883              Thyme, dried, ground
# 2790    13-861                  Turmeric, ground
# 2707    16-154                      Tilapia, raw
# 2749    16-224                 Trout, brown, raw
# 2757    16-416    Tuna, canned in brine, drained
# 2784    18-352                Turkey, whole, raw
# 2729    18-423                 Tongue, lamb, raw
# 2747    18-428               Tripe, dressed, raw
# 2765    19-543                     Turkey slices
# 2694    17-165     Tea, black, infusion, average
# 2734    17-736                       Tonic water
# 2717    13-382                      Tomato juice
# 2742    17-826                    Treacle, black
#
#                                             Description Group  Previous  \
# 2739                              8 samples, 6 products    AF   11-632
# 2690  10 samples, 7 products, including large, slice...    AS   11-426
# 2795                 Yogurt-based Greek starter. Recipe    BN   12-410
# 2715                 Soya bean curd; 7 assorted samples    DB   13-119
# 2721  12 samples, 9 brands, whole and chopped, no ad...    DG   13-461
# 2726  22 samples, autumn and winter, UK grown and im...    DG   13-460
# 2793                                      Peeled thinly    DG   50-833
# 2669     Literature sources and calculation from 14-844    GA   50-996
# 2706                                 Literature sources    GA       NaN
# 2740            10 samples; mix of nuts and dried fruit    GA  50-1041
# 2683                                 Literature sources     H       NaN
# 2704                                 Literature sources     H   13-860
# 2790                                 Literature sources     H       NaN
# 2707                  Literature sources. Type of bream    JA       NaN
# 2749                  Analytical and literature sources    JC       NaN
# 2757                            11 samples, 10 products    JC   16-339
# 2784  Calculated from 49% light meat, 39% dark meat ...   MCO       NaN
# 2729                                         20 samples    MG   50-497
# 2747                                          6 samples    MG   50-501
# 2765  13 samples including honey roast and wafer thi...    MI   19-157
# 2694  15g leaves per litre water, strained after 5 m...   PAA       NaN
# 2734                                 Literature sources   PCA   17-184
# 2717                               10 samples, 9 brands    PE  50-1093
# 2742                                          3 samples    SC   17-068
#
#                                    Main data references Footnote Energy (kJ)  \
# 2739  LGC, Nutrient analysis of bread and morning go...      NaN        1220
# 2690  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1746
# 2795                                       Updated 2013      NaN         321
# 2715      Vegetables, Herbs and Spices Supplement, 1991      NaN         305
# 2721  DH, Nutrient analysis of fruit and vegetables,...      NaN          94
# 2726  DH, Nutrient analysis of fruit and vegetables,...      NaN          71
# 2793  As Vegetables, Herbs and Spices Supplement, 19...      NaN         128
# 2669  Reviewed 2013. McCarthy and Matthews (1984) Co...      NaN        2639
# 2706                    Fruit and Nuts Supplement, 1992      NaN        1811
# 2740  Reviewed 2013. LGC, Nutritional composition of...      NaN        1880
# 2683  Marsh et al. (1977) Composition of foods: spic...      NaN        1374
# 2704  Marsh et al. (1977) Composition of foods: spic...      NaN        1383
# 2790      Vegetables, Herbs and Spices Supplement, 1991      NaN        1467
# 2707            Fish and Fish Products Supplement, 1993      NaN         358
# 2749            Fish and Fish Products Supplement, 1993      NaN         470
# 2757  DH, Nutrient analysis of fish and fish product...      NaN         460
# 2784  LGC, Nutrient analysis of chicken and turkey, ...      NaN         560
# 2729  MW4 (1978). Values reviewed for Meat, Poultry ...      NaN         801
# 2747  LGC, Nutritional analysis of meat and poultry ...      NaN         140
# 2765  LGC, Nutritional analysis of meat and poultry ...      NaN         481
# 2694  Reviewed 2013. LGC, Alcoholic beverages, soft ...      NaN           0
# 2734  Cutrufelli and Matthews (1986) Composition of ...      NaN          95
# 2717  Reviewed 2013. LGC, Canned and other processed...      NaN          70
# 2742  LGC Analysis of Assorted Foods, 1994. Iodine u...      NaN        1129
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2739           289      5.7           2.5             49.1        1.9
# 2690           416     16.8          6.94             62.2       43.4
# 2795            77      5.5          3.58              3.4          3
# 2715            73      4.2           0.5              0.6        0.2
# 2721            22      0.1          0.01              3.8        3.8
# 2726            17      0.1          0.03                3          3
# 2793            31      0.3             0              4.8        4.6
# 2669           639     58.9           8.4              0.8        0.4
# 2706           435     23.8             4             42.2       15.3
# 2740           451     28.5          5.37             37.1         37
# 2683           326      7.2          1.88             38.9        8.2
# 2704           332      7.4           2.7             38.7        1.7
# 2790           350      7.0           2.9             53.7        3.2
# 2707            85      1.5           0.3                0          0
# 2749           112      3.8          0.84                0          0
# 2757           109      1.0           0.3                0          0
# 2784           133      5.2           1.7                0          0
# 2729           193     14.6          6.63                0          0
# 2747            33      0.5           0.2                0          0
# 2765           114      1.9           0.6              1.1        0.4
# 2694             0      0.0             0                0          0
# 2734            22      0.0             0              5.6        5.6
# 2717            16      0.0             0                3          3
# 2742           266      0.0             0             65.2       65.2
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                   Super Group
# 2739       47.2       3.6          8.6     1.56   Cereals and cereal products
# 2690       18.8       1.1          3.4     0.33   Cereals and cereal products
# 2795        0.4       0.3          3.4     0.92        Milk and milk products
# 2715        0.3       0.4          8.1     0.01                    Vegetables
# 2721          0       0.8          1.1     0.01                    Vegetables
# 2726          0         1          0.5     0.01                    Vegetables
# 2793        0.2       2.4          0.9     0.04                    Vegetables
# 2669        0.5       9.3         21.8     0.05                Nuts and seeds
# 2706       26.9      17.4          4.3        0                Nuts and seeds
# 2740        0.1       5.1          9.1     0.07                Nuts and seeds
# 2683       30.7       7.4         22.8     0.16              Herbs and spices
# 2704         37        37          9.1     0.14              Herbs and spices
# 2790       50.5      22.7          6.7     0.08              Herbs and spices
# 2707          0         0         17.8     0.13        Fish and fish products
# 2749          0         0         19.4     0.14        Fish and fish products
# 2757          0         0         24.9     0.73        Fish and fish products
# 2784          0         0         21.6     0.18        Meat and meat products
# 2729          0         0         15.3     1.05        Meat and meat products
# 2747          0         0          7.1     0.13        Meat and meat products
# 2765        0.4         0         23.0     1.48        Meat and meat products
# 2694          0         0          0.0        0                     Beverages
# 2734          0         0          0.0     0.01                     Beverages
# 2717          0       0.6          0.8     0.58                     Beverages
# 2742          0         0          1.2     0.45  Sugars, preserves and snacks

# %%
Red16 = pd.concat([Red15,filt_sea], axis=0, join='inner')
Red16
# Out:
#      Food Code                                 Food Name  \
# 2739    11-925                     Tortilla, wheat, soft
# 2690    11-845             Tarts, bakewell, iced, retail
# 2795    12-547                                  Tzatziki
# 2715    13-570                  Tofu, soya bean, steamed
# 2721    13-530          Tomatoes, canned, whole contents
# 2726    13-517                   Tomatoes, standard, raw
# 2793    13-389                   Turnip, flesh only, raw
# 2669    14-847                              Tahini paste
# 2706    14-848                                 Tigernuts
# 2740    14-849                                 Trail mix
# 2683    13-858                   Tarragon, dried, ground
# 2704    13-883                      Thyme, dried, ground
# 2790    13-861                          Turmeric, ground
# 2707    16-154                              Tilapia, raw
# 2749    16-224                         Trout, brown, raw
# 2757    16-416            Tuna, canned in brine, drained
# 2784    18-352                        Turkey, whole, raw
# 2729    18-423                         Tongue, lamb, raw
# 2747    18-428                       Tripe, dressed, raw
# 2765    19-543                             Turkey slices
# 2694    17-165             Tea, black, infusion, average
# 2734    17-736                               Tonic water
# 2717    13-382                              Tomato juice
# 2742    17-826                            Treacle, black
# 2735    17-670  Topic/Snickers and own brand equivalents
# 2755    17-098                 Truffles, mocha, homemade
#
#                                             Description Group  Previous  \
# 2739                              8 samples, 6 products    AF   11-632
# 2690  10 samples, 7 products, including large, slice...    AS   11-426
# 2795                 Yogurt-based Greek starter. Recipe    BN   12-410
# 2715                 Soya bean curd; 7 assorted samples    DB   13-119
# 2721  12 samples, 9 brands, whole and chopped, no ad...    DG   13-461
# 2726  22 samples, autumn and winter, UK grown and im...    DG   13-460
# 2793                                      Peeled thinly    DG   50-833
# 2669     Literature sources and calculation from 14-844    GA   50-996
# 2706                                 Literature sources    GA       NaN
# 2740            10 samples; mix of nuts and dried fruit    GA  50-1041
# 2683                                 Literature sources     H       NaN
# 2704                                 Literature sources     H   13-860
# 2790                                 Literature sources     H       NaN
# 2707                  Literature sources. Type of bream    JA       NaN
# 2749                  Analytical and literature sources    JC       NaN
# 2757                            11 samples, 10 products    JC   16-339
# 2784  Calculated from 49% light meat, 39% dark meat ...   MCO       NaN
# 2729                                         20 samples    MG   50-497
# 2747                                          6 samples    MG   50-501
# 2765  13 samples including honey roast and wafer thi...    MI   19-157
# 2694  15g leaves per litre water, strained after 5 m...   PAA       NaN
# 2734                                 Literature sources   PCA   17-184
# 2717                               10 samples, 9 brands    PE  50-1093
# 2742                                          3 samples    SC   17-068
# 2735  16 samples, 3 brands, including standard, snac...   SEA   17-549
# 2755                                             Recipe   SEA       NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2739  LGC, Nutrient analysis of bread and morning go...      NaN        1220
# 2690  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1746
# 2795                                       Updated 2013      NaN         321
# 2715      Vegetables, Herbs and Spices Supplement, 1991      NaN         305
# 2721  DH, Nutrient analysis of fruit and vegetables,...      NaN          94
# 2726  DH, Nutrient analysis of fruit and vegetables,...      NaN          71
# 2793  As Vegetables, Herbs and Spices Supplement, 19...      NaN         128
# 2669  Reviewed 2013. McCarthy and Matthews (1984) Co...      NaN        2639
# 2706                    Fruit and Nuts Supplement, 1992      NaN        1811
# 2740  Reviewed 2013. LGC, Nutritional composition of...      NaN        1880
# 2683  Marsh et al. (1977) Composition of foods: spic...      NaN        1374
# 2704  Marsh et al. (1977) Composition of foods: spic...      NaN        1383
# 2790      Vegetables, Herbs and Spices Supplement, 1991      NaN        1467
# 2707            Fish and Fish Products Supplement, 1993      NaN         358
# 2749            Fish and Fish Products Supplement, 1993      NaN         470
# 2757  DH, Nutrient analysis of fish and fish product...      NaN         460
# 2784  LGC, Nutrient analysis of chicken and turkey, ...      NaN         560
# 2729  MW4 (1978). Values reviewed for Meat, Poultry ...      NaN         801
# 2747  LGC, Nutritional analysis of meat and poultry ...      NaN         140
# 2765  LGC, Nutritional analysis of meat and poultry ...      NaN         481
# 2694  Reviewed 2013. LGC, Alcoholic beverages, soft ...      NaN           0
# 2734  Cutrufelli and Matthews (1986) Composition of ...      NaN          95
# 2717  Reviewed 2013. LGC, Canned and other processed...      NaN          70
# 2742  LGC Analysis of Assorted Foods, 1994. Iodine u...      NaN        1129
# 2735  DH, Nutrient analysis of a range of processed ...      NaN        2058
# 2755            As Miscellaneous Foods Supplement, 1994      NaN        2073
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2739           289      5.7           2.5             49.1        1.9
# 2690           416     16.8          6.94             62.2       43.4
# 2795            77      5.5          3.58              3.4          3
# 2715            73      4.2           0.5              0.6        0.2
# 2721            22      0.1          0.01              3.8        3.8
# 2726            17      0.1          0.03                3          3
# 2793            31      0.3             0              4.8        4.6
# 2669           639     58.9           8.4              0.8        0.4
# 2706           435     23.8             4             42.2       15.3
# 2740           451     28.5          5.37             37.1         37
# 2683           326      7.2          1.88             38.9        8.2
# 2704           332      7.4           2.7             38.7        1.7
# 2790           350      7.0           2.9             53.7        3.2
# 2707            85      1.5           0.3                0          0
# 2749           112      3.8          0.84                0          0
# 2757           109      1.0           0.3                0          0
# 2784           133      5.2           1.7                0          0
# 2729           193     14.6          6.63                0          0
# 2747            33      0.5           0.2                0          0
# 2765           114      1.9           0.6              1.1        0.4
# 2694             0      0.0             0                0          0
# 2734            22      0.0             0              5.6        5.6
# 2717            16      0.0             0                3          3
# 2742           266      0.0             0             65.2       65.2
# 2735           493     28.2          9.15             49.7       44.1
# 2755           495     24.9            15             60.6       59.9
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                   Super Group
# 2739       47.2       3.6          8.6     1.56   Cereals and cereal products
# 2690       18.8       1.1          3.4     0.33   Cereals and cereal products
# 2795        0.4       0.3          3.4     0.92        Milk and milk products
# 2715        0.3       0.4          8.1     0.01                    Vegetables
# 2721          0       0.8          1.1     0.01                    Vegetables
# 2726          0         1          0.5     0.01                    Vegetables
# 2793        0.2       2.4          0.9     0.04                    Vegetables
# 2669        0.5       9.3         21.8     0.05                Nuts and seeds
# 2706       26.9      17.4          4.3        0                Nuts and seeds
# 2740        0.1       5.1          9.1     0.07                Nuts and seeds
# 2683       30.7       7.4         22.8     0.16              Herbs and spices
# 2704         37        37          9.1     0.14              Herbs and spices
# 2790       50.5      22.7          6.7     0.08              Herbs and spices
# 2707          0         0         17.8     0.13        Fish and fish products
# 2749          0         0         19.4     0.14        Fish and fish products
# 2757          0         0         24.9     0.73        Fish and fish products
# 2784          0         0         21.6     0.18        Meat and meat products
# 2729          0         0         15.3     1.05        Meat and meat products
# 2747          0         0          7.1     0.13        Meat and meat products
# 2765        0.4         0         23.0     1.48        Meat and meat products
# 2694          0         0          0.0        0                     Beverages
# 2734          0         0          0.0     0.01                     Beverages
# 2717          0       0.6          0.8     0.58                     Beverages
# 2742          0         0          1.2     0.45  Sugars, preserves and snacks
# 2735        5.5       2.8          8.7     0.47  Sugars, preserves and snacks
# 2755        0.7         2          6.2     0.09  Sugars, preserves and snacks

# %%
Red17 = pd.concat([Red16,filt_sec], axis=0, join='inner')
Red17
# Out:
#      Food Code                                 Food Name  \
# 2739    11-925                     Tortilla, wheat, soft
# 2690    11-845             Tarts, bakewell, iced, retail
# 2795    12-547                                  Tzatziki
# 2715    13-570                  Tofu, soya bean, steamed
# 2721    13-530          Tomatoes, canned, whole contents
# 2726    13-517                   Tomatoes, standard, raw
# 2793    13-389                   Turnip, flesh only, raw
# 2669    14-847                              Tahini paste
# 2706    14-848                                 Tigernuts
# 2740    14-849                                 Trail mix
# 2683    13-858                   Tarragon, dried, ground
# 2704    13-883                      Thyme, dried, ground
# 2790    13-861                          Turmeric, ground
# 2707    16-154                              Tilapia, raw
# 2749    16-224                         Trout, brown, raw
# 2757    16-416            Tuna, canned in brine, drained
# 2784    18-352                        Turkey, whole, raw
# 2729    18-423                         Tongue, lamb, raw
# 2747    18-428                       Tripe, dressed, raw
# 2765    19-543                             Turkey slices
# 2694    17-165             Tea, black, infusion, average
# 2734    17-736                               Tonic water
# 2717    13-382                              Tomato juice
# 2742    17-826                            Treacle, black
# 2735    17-670  Topic/Snickers and own brand equivalents
# 2755    17-098                 Truffles, mocha, homemade
# 2712    17-646                            Toffees, mixed
# 2788    17-593      Turkish delight, with nuts, homemade
#
#                                             Description Group  Previous  \
# 2739                              8 samples, 6 products    AF   11-632
# 2690  10 samples, 7 products, including large, slice...    AS   11-426
# 2795                 Yogurt-based Greek starter. Recipe    BN   12-410
# 2715                 Soya bean curd; 7 assorted samples    DB   13-119
# 2721  12 samples, 9 brands, whole and chopped, no ad...    DG   13-461
# 2726  22 samples, autumn and winter, UK grown and im...    DG   13-460
# 2793                                      Peeled thinly    DG   50-833
# 2669     Literature sources and calculation from 14-844    GA   50-996
# 2706                                 Literature sources    GA       NaN
# 2740            10 samples; mix of nuts and dried fruit    GA  50-1041
# 2683                                 Literature sources     H       NaN
# 2704                                 Literature sources     H   13-860
# 2790                                 Literature sources     H       NaN
# 2707                  Literature sources. Type of bream    JA       NaN
# 2749                  Analytical and literature sources    JC       NaN
# 2757                            11 samples, 10 products    JC   16-339
# 2784  Calculated from 49% light meat, 39% dark meat ...   MCO       NaN
# 2729                                         20 samples    MG   50-497
# 2747                                          6 samples    MG   50-501
# 2765  13 samples including honey roast and wafer thi...    MI   19-157
# 2694  15g leaves per litre water, strained after 5 m...   PAA       NaN
# 2734                                 Literature sources   PCA   17-184
# 2717                               10 samples, 9 brands    PE  50-1093
# 2742                                          3 samples    SC   17-068
# 2735  16 samples, 3 brands, including standard, snac...   SEA   17-549
# 2755                                             Recipe   SEA       NaN
# 2712  8 samples, 8 products, including liquorice and...   SEC   17-120
# 2788                                             Recipe   SEC   17-121
#
#                                    Main data references Footnote Energy (kJ)  \
# 2739  LGC, Nutrient analysis of bread and morning go...      NaN        1220
# 2690  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1746
# 2795                                       Updated 2013      NaN         321
# 2715      Vegetables, Herbs and Spices Supplement, 1991      NaN         305
# 2721  DH, Nutrient analysis of fruit and vegetables,...      NaN          94
# 2726  DH, Nutrient analysis of fruit and vegetables,...      NaN          71
# 2793  As Vegetables, Herbs and Spices Supplement, 19...      NaN         128
# 2669  Reviewed 2013. McCarthy and Matthews (1984) Co...      NaN        2639
# 2706                    Fruit and Nuts Supplement, 1992      NaN        1811
# 2740  Reviewed 2013. LGC, Nutritional composition of...      NaN        1880
# 2683  Marsh et al. (1977) Composition of foods: spic...      NaN        1374
# 2704  Marsh et al. (1977) Composition of foods: spic...      NaN        1383
# 2790      Vegetables, Herbs and Spices Supplement, 1991      NaN        1467
# 2707            Fish and Fish Products Supplement, 1993      NaN         358
# 2749            Fish and Fish Products Supplement, 1993      NaN         470
# 2757  DH, Nutrient analysis of fish and fish product...      NaN         460
# 2784  LGC, Nutrient analysis of chicken and turkey, ...      NaN         560
# 2729  MW4 (1978). Values reviewed for Meat, Poultry ...      NaN         801
# 2747  LGC, Nutritional analysis of meat and poultry ...      NaN         140
# 2765  LGC, Nutritional analysis of meat and poultry ...      NaN         481
# 2694  Reviewed 2013. LGC, Alcoholic beverages, soft ...      NaN           0
# 2734  Cutrufelli and Matthews (1986) Composition of ...      NaN          95
# 2717  Reviewed 2013. LGC, Canned and other processed...      NaN          70
# 2742  LGC Analysis of Assorted Foods, 1994. Iodine u...      NaN        1129
# 2735  DH, Nutrient analysis of a range of processed ...      NaN        2058
# 2755            As Miscellaneous Foods Supplement, 1994      NaN        2073
# 2712  DH, Nutrient analysis of a range of processed ...      NaN        1637
# 2788  Recipe as Miscellaneous Foods Supplement (1994...      NaN        1506
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2739           289      5.7           2.5             49.1        1.9
# 2690           416     16.8          6.94             62.2       43.4
# 2795            77      5.5          3.58              3.4          3
# 2715            73      4.2           0.5              0.6        0.2
# 2721            22      0.1          0.01              3.8        3.8
# 2726            17      0.1          0.03                3          3
# 2793            31      0.3             0              4.8        4.6
# 2669           639     58.9           8.4              0.8        0.4
# 2706           435     23.8             4             42.2       15.3
# 2740           451     28.5          5.37             37.1         37
# 2683           326      7.2          1.88             38.9        8.2
# 2704           332      7.4           2.7             38.7        1.7
# 2790           350      7.0           2.9             53.7        3.2
# 2707            85      1.5           0.3                0          0
# 2749           112      3.8          0.84                0          0
# 2757           109      1.0           0.3                0          0
# 2784           133      5.2           1.7                0          0
# 2729           193     14.6          6.63                0          0
# 2747            33      0.5           0.2                0          0
# 2765           114      1.9           0.6              1.1        0.4
# 2694             0      0.0             0                0          0
# 2734            22      0.0             0              5.6        5.6
# 2717            16      0.0             0                3          3
# 2742           266      0.0             0             65.2       65.2
# 2735           493     28.2          9.15             49.7       44.1
# 2755           495     24.9            15             60.6       59.9
# 2712           390     15.9           8.6             59.6       37.5
# 2788           355      2.6          0.35             78.1       77.9
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                   Super Group
# 2739       47.2       3.6          8.6     1.56   Cereals and cereal products
# 2690       18.8       1.1          3.4     0.33   Cereals and cereal products
# 2795        0.4       0.3          3.4     0.92        Milk and milk products
# 2715        0.3       0.4          8.1     0.01                    Vegetables
# 2721          0       0.8          1.1     0.01                    Vegetables
# 2726          0         1          0.5     0.01                    Vegetables
# 2793        0.2       2.4          0.9     0.04                    Vegetables
# 2669        0.5       9.3         21.8     0.05                Nuts and seeds
# 2706       26.9      17.4          4.3        0                Nuts and seeds
# 2740        0.1       5.1          9.1     0.07                Nuts and seeds
# 2683       30.7       7.4         22.8     0.16              Herbs and spices
# 2704         37        37          9.1     0.14              Herbs and spices
# 2790       50.5      22.7          6.7     0.08              Herbs and spices
# 2707          0         0         17.8     0.13        Fish and fish products
# 2749          0         0         19.4     0.14        Fish and fish products
# 2757          0         0         24.9     0.73        Fish and fish products
# 2784          0         0         21.6     0.18        Meat and meat products
# 2729          0         0         15.3     1.05        Meat and meat products
# 2747          0         0          7.1     0.13        Meat and meat products
# 2765        0.4         0         23.0     1.48        Meat and meat products
# 2694          0         0          0.0        0                     Beverages
# 2734          0         0          0.0     0.01                     Beverages
# 2717          0       0.6          0.8     0.58                     Beverages
# 2742          0         0          1.2     0.45  Sugars, preserves and snacks
# 2735        5.5       2.8          8.7     0.47  Sugars, preserves and snacks
# 2755        0.7         2          6.2     0.09  Sugars, preserves and snacks
# 2712          0         0          2.1     0.78  Sugars, preserves and snacks
# 2788        0.2       0.3          4.7     0.21  Sugars, preserves and snacks

# %%
Red18 = pd.concat([Red10,sn], axis=0, join='inner')
Red18
# Out:
#      Food Code                              Food Name  \
# 2739    11-925                  Tortilla, wheat, soft
# 2690    11-845          Tarts, bakewell, iced, retail
# 2795    12-547                               Tzatziki
# 2715    13-570               Tofu, soya bean, steamed
# 2721    13-530       Tomatoes, canned, whole contents
# 2726    13-517                Tomatoes, standard, raw
# 2793    13-389                Turnip, flesh only, raw
# 2669    14-847                           Tahini paste
# 2706    14-848                              Tigernuts
# 2740    14-849                              Trail mix
# 2683    13-858                Tarragon, dried, ground
# 2704    13-883                   Thyme, dried, ground
# 2790    13-861                       Turmeric, ground
# 2707    16-154                           Tilapia, raw
# 2749    16-224                      Trout, brown, raw
# 2757    16-416         Tuna, canned in brine, drained
# 2784    18-352                     Turkey, whole, raw
# 2729    18-423                      Tongue, lamb, raw
# 2747    18-428                    Tripe, dressed, raw
# 2738    17-644  Tortilla chips fried in sunflower oil
# 2794    17-694                               Twiglets
#
#                                             Description Group  Previous  \
# 2739                              8 samples, 6 products    AF   11-632
# 2690  10 samples, 7 products, including large, slice...    AS   11-426
# 2795                 Yogurt-based Greek starter. Recipe    BN   12-410
# 2715                 Soya bean curd; 7 assorted samples    DB   13-119
# 2721  12 samples, 9 brands, whole and chopped, no ad...    DG   13-461
# 2726  22 samples, autumn and winter, UK grown and im...    DG   13-460
# 2793                                      Peeled thinly    DG   50-833
# 2669     Literature sources and calculation from 14-844    GA   50-996
# 2706                                 Literature sources    GA       NaN
# 2740            10 samples; mix of nuts and dried fruit    GA  50-1041
# 2683                                 Literature sources     H       NaN
# 2704                                 Literature sources     H   13-860
# 2790                                 Literature sources     H       NaN
# 2707                  Literature sources. Type of bream    JA       NaN
# 2749                  Analytical and literature sources    JC       NaN
# 2757                            11 samples, 10 products    JC   16-339
# 2784  Calculated from 49% light meat, 39% dark meat ...   MCO       NaN
# 2729                                         20 samples    MG   50-497
# 2747                                          6 samples    MG   50-501
# 2738  7 samples, 6 products, assorted flavours, frie...    SN   17-497
# 2794              20 samples, savoury wholewheat sticks    SN   17-150
#
#                                    Main data references Footnote Energy (kJ)  \
# 2739  LGC, Nutrient analysis of bread and morning go...      NaN        1220
# 2690  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1746
# 2795                                       Updated 2013      NaN         321
# 2715      Vegetables, Herbs and Spices Supplement, 1991      NaN         305
# 2721  DH, Nutrient analysis of fruit and vegetables,...      NaN          94
# 2726  DH, Nutrient analysis of fruit and vegetables,...      NaN          71
# 2793  As Vegetables, Herbs and Spices Supplement, 19...      NaN         128
# 2669  Reviewed 2013. McCarthy and Matthews (1984) Co...      NaN        2639
# 2706                    Fruit and Nuts Supplement, 1992      NaN        1811
# 2740  Reviewed 2013. LGC, Nutritional composition of...      NaN        1880
# 2683  Marsh et al. (1977) Composition of foods: spic...      NaN        1374
# 2704  Marsh et al. (1977) Composition of foods: spic...      NaN        1383
# 2790      Vegetables, Herbs and Spices Supplement, 1991      NaN        1467
# 2707            Fish and Fish Products Supplement, 1993      NaN         358
# 2749            Fish and Fish Products Supplement, 1993      NaN         470
# 2757  DH, Nutrient analysis of fish and fish product...      NaN         460
# 2784  LGC, Nutrient analysis of chicken and turkey, ...      NaN         560
# 2729  MW4 (1978). Values reviewed for Meat, Poultry ...      NaN         801
# 2747  LGC, Nutritional analysis of meat and poultry ...      NaN         140
# 2738  DH, Nutrient analysis of a range of processed ...      NaN        2126
# 2794  LGC, Survey of the composition of savoury snac...      NaN        1744
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2739           289      5.7           2.5             49.1        1.9
# 2690           416     16.8          6.94             62.2       43.4
# 2795            77      5.5          3.58              3.4          3
# 2715            73      4.2           0.5              0.6        0.2
# 2721            22      0.1          0.01              3.8        3.8
# 2726            17      0.1          0.03                3          3
# 2793            31      0.3             0              4.8        4.6
# 2669           639     58.9           8.4              0.8        0.4
# 2706           435     23.8             4             42.2       15.3
# 2740           451     28.5          5.37             37.1         37
# 2683           326      7.2          1.88             38.9        8.2
# 2704           332      7.4           2.7             38.7        1.7
# 2790           350      7.0           2.9             53.7        3.2
# 2707            85      1.5           0.3                0          0
# 2749           112      3.8          0.84                0          0
# 2757           109      1.0           0.3                0          0
# 2784           133      5.2           1.7                0          0
# 2729           193     14.6          6.63                0          0
# 2747            33      0.5           0.2                0          0
# 2738           509     27.4          2.89             55.4        2.4
# 2794           415     11.8           1.6             57.6        0.6
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                   Super Group
# 2739       47.2       3.6          8.6     1.56   Cereals and cereal products
# 2690       18.8       1.1          3.4     0.33   Cereals and cereal products
# 2795        0.4       0.3          3.4     0.92        Milk and milk products
# 2715        0.3       0.4          8.1     0.01                    Vegetables
# 2721          0       0.8          1.1     0.01                    Vegetables
# 2726          0         1          0.5     0.01                    Vegetables
# 2793        0.2       2.4          0.9     0.04                    Vegetables
# 2669        0.5       9.3         21.8     0.05                Nuts and seeds
# 2706       26.9      17.4          4.3        0                Nuts and seeds
# 2740        0.1       5.1          9.1     0.07                Nuts and seeds
# 2683       30.7       7.4         22.8     0.16              Herbs and spices
# 2704         37        37          9.1     0.14              Herbs and spices
# 2790       50.5      22.7          6.7     0.08              Herbs and spices
# 2707          0         0         17.8     0.13        Fish and fish products
# 2749          0         0         19.4     0.14        Fish and fish products
# 2757          0         0         24.9     0.73        Fish and fish products
# 2784          0         0         21.6     0.18        Meat and meat products
# 2729          0         0         15.3     1.05        Meat and meat products
# 2747          0         0          7.1     0.13        Meat and meat products
# 2738         53       5.9          7.3     1.59  Sugars, preserves and snacks
# 2794         57      12.4         13.5        2  Sugars, preserves and snacks

# %%
Red19 = pd.concat([Red18,filt_wcn], axis=0, join='inner')
Red19
# Out:
#      Food Code                              Food Name  \
# 2739    11-925                  Tortilla, wheat, soft
# 2690    11-845          Tarts, bakewell, iced, retail
# 2795    12-547                               Tzatziki
# 2715    13-570               Tofu, soya bean, steamed
# 2721    13-530       Tomatoes, canned, whole contents
# 2726    13-517                Tomatoes, standard, raw
# 2793    13-389                Turnip, flesh only, raw
# 2669    14-847                           Tahini paste
# 2706    14-848                              Tigernuts
# 2740    14-849                              Trail mix
# 2683    13-858                Tarragon, dried, ground
# 2704    13-883                   Thyme, dried, ground
# 2790    13-861                       Turmeric, ground
# 2707    16-154                           Tilapia, raw
# 2749    16-224                      Trout, brown, raw
# 2757    16-416         Tuna, canned in brine, drained
# 2784    18-352                     Turkey, whole, raw
# 2729    18-423                      Tongue, lamb, raw
# 2747    18-428                    Tripe, dressed, raw
# 2738    17-644  Tortilla chips fried in sunflower oil
# 2794    17-694                               Twiglets
# 2688    17-722                          Tartare sauce
# 2718    17-709                         Tomato ketchup
#
#                                             Description Group  Previous  \
# 2739                              8 samples, 6 products    AF   11-632
# 2690  10 samples, 7 products, including large, slice...    AS   11-426
# 2795                 Yogurt-based Greek starter. Recipe    BN   12-410
# 2715                 Soya bean curd; 7 assorted samples    DB   13-119
# 2721  12 samples, 9 brands, whole and chopped, no ad...    DG   13-461
# 2726  22 samples, autumn and winter, UK grown and im...    DG   13-460
# 2793                                      Peeled thinly    DG   50-833
# 2669     Literature sources and calculation from 14-844    GA   50-996
# 2706                                 Literature sources    GA       NaN
# 2740            10 samples; mix of nuts and dried fruit    GA  50-1041
# 2683                                 Literature sources     H       NaN
# 2704                                 Literature sources     H   13-860
# 2790                                 Literature sources     H       NaN
# 2707                  Literature sources. Type of bream    JA       NaN
# 2749                  Analytical and literature sources    JC       NaN
# 2757                            11 samples, 10 products    JC   16-339
# 2784  Calculated from 49% light meat, 39% dark meat ...   MCO       NaN
# 2729                                         20 samples    MG   50-497
# 2747                                          6 samples    MG   50-501
# 2738  7 samples, 6 products, assorted flavours, frie...    SN   17-497
# 2794              20 samples, savoury wholewheat sticks    SN   17-150
# 2688                               10 samples, 4 brands   WCN   17-337
# 2718                               10 samples, 5 brands   WCN   17-513
#
#                                    Main data references Footnote Energy (kJ)  \
# 2739  LGC, Nutrient analysis of bread and morning go...      NaN        1220
# 2690  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1746
# 2795                                       Updated 2013      NaN         321
# 2715      Vegetables, Herbs and Spices Supplement, 1991      NaN         305
# 2721  DH, Nutrient analysis of fruit and vegetables,...      NaN          94
# 2726  DH, Nutrient analysis of fruit and vegetables,...      NaN          71
# 2793  As Vegetables, Herbs and Spices Supplement, 19...      NaN         128
# 2669  Reviewed 2013. McCarthy and Matthews (1984) Co...      NaN        2639
# 2706                    Fruit and Nuts Supplement, 1992      NaN        1811
# 2740  Reviewed 2013. LGC, Nutritional composition of...      NaN        1880
# 2683  Marsh et al. (1977) Composition of foods: spic...      NaN        1374
# 2704  Marsh et al. (1977) Composition of foods: spic...      NaN        1383
# 2790      Vegetables, Herbs and Spices Supplement, 1991      NaN        1467
# 2707            Fish and Fish Products Supplement, 1993      NaN         358
# 2749            Fish and Fish Products Supplement, 1993      NaN         470
# 2757  DH, Nutrient analysis of fish and fish product...      NaN         460
# 2784  LGC, Nutrient analysis of chicken and turkey, ...      NaN         560
# 2729  MW4 (1978). Values reviewed for Meat, Poultry ...      NaN         801
# 2747  LGC, Nutritional analysis of meat and poultry ...      NaN         140
# 2738  DH, Nutrient analysis of a range of processed ...      NaN        2126
# 2794  LGC, Survey of the composition of savoury snac...      NaN        1744
# 2688  LFRA, Nutrient analysis of miscellaneous foods...      NaN        1236
# 2718  LFRA, Nutrient analysis of miscellaneous foods...      NaN         511
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2739           289      5.7           2.5             49.1        1.9
# 2690           416     16.8          6.94             62.2       43.4
# 2795            77      5.5          3.58              3.4          3
# 2715            73      4.2           0.5              0.6        0.2
# 2721            22      0.1          0.01              3.8        3.8
# 2726            17      0.1          0.03                3          3
# 2793            31      0.3             0              4.8        4.6
# 2669           639     58.9           8.4              0.8        0.4
# 2706           435     23.8             4             42.2       15.3
# 2740           451     28.5          5.37             37.1         37
# 2683           326      7.2          1.88             38.9        8.2
# 2704           332      7.4           2.7             38.7        1.7
# 2790           350      7.0           2.9             53.7        3.2
# 2707            85      1.5           0.3                0          0
# 2749           112      3.8          0.84                0          0
# 2757           109      1.0           0.3                0          0
# 2784           133      5.2           1.7                0          0
# 2729           193     14.6          6.63                0          0
# 2747            33      0.5           0.2                0          0
# 2738           509     27.4          2.89             55.4        2.4
# 2794           415     11.8           1.6             57.6        0.6
# 2688           298     24.6           1.6             17.6         16
# 2718           120      0.1             0             27.8       26.8
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)  \
# 2739       47.2       3.6          8.6     1.56
# 2690       18.8       1.1          3.4     0.33
# 2795        0.4       0.3          3.4     0.92
# 2715        0.3       0.4          8.1     0.01
# 2721          0       0.8          1.1     0.01
# 2726          0         1          0.5     0.01
# 2793        0.2       2.4          0.9     0.04
# 2669        0.5       9.3         21.8     0.05
# 2706       26.9      17.4          4.3        0
# 2740        0.1       5.1          9.1     0.07
# 2683       30.7       7.4         22.8     0.16
# 2704         37        37          9.1     0.14
# 2790       50.5      22.7          6.7     0.08
# 2707          0         0         17.8     0.13
# 2749          0         0         19.4     0.14
# 2757          0         0         24.9     0.73
# 2784          0         0         21.6     0.18
# 2729          0         0         15.3     1.05
# 2747          0         0          7.1     0.13
# 2738         53       5.9          7.3     1.59
# 2794         57      12.4         13.5        2
# 2688        1.5       0.6          1.3      2.7
# 2718          1       0.9          1.6        2
#
#                                 Super Group
# 2739            Cereals and cereal products
# 2690            Cereals and cereal products
# 2795                 Milk and milk products
# 2715                             Vegetables
# 2721                             Vegetables
# 2726                             Vegetables
# 2793                             Vegetables
# 2669                         Nuts and seeds
# 2706                         Nuts and seeds
# 2740                         Nuts and seeds
# 2683                       Herbs and spices
# 2704                       Herbs and spices
# 2790                       Herbs and spices
# 2707                 Fish and fish products
# 2749                 Fish and fish products
# 2757                 Fish and fish products
# 2784                 Meat and meat products
# 2729                 Meat and meat products
# 2747                 Meat and meat products
# 2738           Sugars, preserves and snacks
# 2794           Sugars, preserves and snacks
# 2688  Soups, sauces and miscellaneous foods
# 2718  Soups, sauces and miscellaneous foods

# %% [markdown]
#                                                        Export

# %%
Red19.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced_T.csv')
