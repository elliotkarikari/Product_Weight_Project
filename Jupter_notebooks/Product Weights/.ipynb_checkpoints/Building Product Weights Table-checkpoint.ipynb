# %% [markdown]
#                                             Building Product Weights Table

# %% [markdown]
# ##### Import Librarys

# %%
import pandas as pd

# %% [markdown]
# ##### *Reading In Data*

# %% [markdown]
#         Reduced List

# %%
Red_List = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\1PReduced_Labelling2021.csv')
Red_List
# Out:
#      Unnamed: 0 Food Code                                          Food Name  \
# 0             0    11-001                                          Arrowroot
# 1             1    13-145                             Ackee, canned, drained
# 2             2    13-146                                        Agar, dried
# 3             3    13-148                               Alfalfa sprouts, raw
# 4             4    13-149                               Amaranth leaves, raw
# ..          ...       ...                                                ...
# 592           0   11-1135  Yorkshire pudding, made with skimmed milk, hom...
# 593           1    12-555                         Yogurt, Greek style, plain
# 594           2    12-375                          Yogurt, whole milk, fruit
# 595           3    13-398                                         Yam, baked
# 596           4    17-517                                      Yeast extract
#
#     Group                            Super Group Sale format(s) VJ comments
# 0      AA            Cereals and cereal products            NaN         NaN
# 1      DG                             Vegetables            tin         NaN
# 2      DG                             Vegetables            NaN         NaN
# 3      DG                             Vegetables            NaN         NaN
# 4      DG                             Vegetables            NaN         NaN
# ..    ...                                    ...            ...         ...
# 592    AT            Cereals and cereal products            NaN         NaN
# 593    BN                 Milk and milk products            NaN         NaN
# 594    BN                 Milk and milk products            NaN         NaN
# 595    DG                             Vegetables            NaN         NaN
# 596    WY  Soups, sauces and miscellaneous foods            jar         NaN
#
# [597 rows x 7 columns]

# %% [markdown]
#         Raw Data - Labelled McCance and Widdowson

# %% [markdown]
# Portions with comments

# %%
Comm = Red_List.loc[~Red_List['VJ comments'].isna()]
Comm
# Out:
#      Unnamed: 0 Food Code                                          Food Name  \
# 12           12    14-363  Apples, cooking, raw, flesh only, weighed with...
# 28           28    17-851                              Apple sauce, homemade
# 41           12   11-1145                              Bread, white, average
# 71           42    13-041                    Beans, aduki, whole, dried, raw
# 76           47    13-667   Beans, edamame, frozen, boiled in unsalted water
# 101          72    14-318                                Bananas, flesh only
# 140         111    17-769                           Barbecue sauce, homemade
# 184          37    13-496                                  Carrots, old, raw
# 193          46    13-668                                   Courgette, dried
# 347           4    14-371                        Kiwi fruit, flesh only, raw
# 356           3    13-089        Lentils, green and brown, whole, dried, raw
# 362           9    14-131                                  Limes, flesh only
# 393          15    13-273                    Mango, unripe, green flesh, raw
# 397          19    14-378                     Mangoes, ripe, flesh only, raw
# 429           4    14-327                                Oranges, flesh only
# 443           2    11-450                        Pasta, plain, fresh, boiled
# 444           3    11-735          Pasta, spaghetti, canned, in tomato sauce
# 457          16    13-564          Peas, canned in water, re-heated, drained
# 465          24    14-365                    Pears, average, raw, flesh only
# 468          27    14-376                         Pineapple, flesh only, raw
# 469          28    14-222              Plums, Victoria, stewed without sugar
# 512           1    11-955   Sandwich, white bread, bacon, lettuce and tomato
# 518           7    13-359                             Swede, flesh only, raw
# 519           8    13-672                                Sweet potato, baked
# 520           9    13-529        Sweetcorn kernels, canned in water, drained
# 521          10    13-622                            Sweetcorn, kernels, raw
# 559           6    13-389                            Turnip, flesh only, raw
# 568          15    16-416                     Tuna, canned in brine, drained
# 576           0    13-543  Vegetables, mixed, frozen, boiled in unsalted ...
#
#     Group                            Super Group             Sale format(s)  \
# 12      F                                  Fruit              home-prepared
# 28     WC  Soups, sauces and miscellaneous foods                        jar
# 41     AF            Cereals and cereal products                       loaf
# 71     DB                             Vegetables                     packet
# 76     DB                             Vegetables                        NaN
# 101    FA                                  Fruit    loose, individual/bunch
# 140    WC  Soups, sauces and miscellaneous foods                        NaN
# 184    DG                             Vegetables                        NaN
# 193    DI                             Vegetables                        NaN
# 347    FA                                  Fruit  loose, individual, punnet
# 356    DB                             Vegetables                        NaN
# 362    FA                                  Fruit     loose, individual, net
# 393    DG                             Vegetables          loose, individual
# 397    FA                                  Fruit          loose, individual
# 429    FA                                  Fruit     loose, individual, net
# 443    AD            Cereals and cereal products                        NaN
# 444    AD            Cereals and cereal products                        tin
# 457    DF                             Vegetables                        tin
# 465     F                                  Fruit     loose, individual, bag
# 468    FA                                  Fruit          loose, individual
# 469    FA                                  Fruit                        NaN
# 512    AB            Cereals and cereal products                        NaN
# 518    DG                             Vegetables                        NaN
# 519    DG                             Vegetables                        NaN
# 520    DG                             Vegetables                        tin
# 521    DG                             Vegetables                        NaN
# 559    DG                                    NaN                        NaN
# 568    JC                                    NaN                        NaN
# 576    DG                             Vegetables                        NaN
#
#                                            VJ comments
# 12   Would be good to include an eating apple varia...
# 28   Suggest this should be a retail option if avai...
# 41   There is some old legislation which specified ...
# 71   for beans, where there are options for canned ...
# 76             Is there a version which is not boiled?
# 101  for fruits, better to include version with ski...
# 140  I'd suggest removing this one as we only reall...
# 184  I'd be inclined to remove this one and just ke...
# 193  Suggest removing this one, I've never seen dri...
# 347    include version with skin included if available
# 356           include canned version too, if available
# 362    include version with skin included if available
# 393  suggest removing this one as we have the ripe ...
# 397    include version with skin included if available
# 429    include version with skin included if available
# 443  include uncooked version and uncooked dried pa...
# 444                        include dried spaghetti too
# 457                include undrained version (as sold)
# 465    include version with core included if available
# 468    include version with skin included if available
# 469  suggest removing, this would be made at home a...
# 512  I suggest for purposes of weight data info, ch...
# 518         include version with skin too if available
# 519                   include raw version if available
# 520                include undrained version (as sold)
# 521                include raw corn on the cob instead
# 559         include version with skin too if available
# 568             include undrained version if available
# 576          include unboiled raw version if available

# %% [markdown]
#         Open Food Facts

# %%
OFF = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\OpenFoodFacts.csv')
OFF.head()
# Out:
#    Unnamed: 0                     product_name_en  product_quantity  \
# 0           0               Ketchup 5 Ingrédients         468.00000
# 1           6                Chocolat noir fruité         100.00000
# 2          19  Golden sunflower oil cooking spray         190.00000
# 3          24             Tuna in olive oil blend          95.00000
# 4          26                            Pringles          18.99418
#
#                                            packaging  \
# 0  OPERCULE A JETER, BOUTEILLE PLASTIQUE ET SON B...
# 1                                           Tablette
# 2                       Plastic, Bottle, Hdpe-bottle
# 3                                          Tin steel
# 4                                       Plastic, Tub
#
#                                                  url  \
# 0  https://world.openfoodfacts.org/product/871052...
# 1  https://world.openfoodfacts.org/product/761303...
# 2  https://world.openfoodfacts.org/product/500044...
# 3  https://world.openfoodfacts.org/product/930046...
# 4  https://world.openfoodfacts.org/product/038083...
#
#                                   stores                         countries
# 0                 E.Leclerc,carrefour.fr                            France
# 1           Carrefour,Leclerc,Magasins U                     France,Guyane
# 2  Asda,Tesco,Iceland,Waitrose,Morrisons             France,United Kingdom
# 3                      Woolworths, Coles  Australia,Singapore,en:singapore
# 4                                 Kroger                     United States
