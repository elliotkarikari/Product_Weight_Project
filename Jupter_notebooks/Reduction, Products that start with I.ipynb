# %% [markdown]
# # Product Weighting Project

# %% [markdown]
#                                          Data Reduction - Food Purchased In Store

# %% [markdown]
# ###### Import Necessary Libraries

# %%
import pandas as pd

# %% [markdown]
# Read in Data

# %%
Labelled = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Labelling2021_watercress.csv')

# %% [markdown]
# ### Products beginning with a 'H'

# %%
Prod_I = Labelled.loc[Labelled['Food Name'].str.startswith('I')]
Prod_I
# Out:
#      Food Code                                          Food Name  \
# 1330    12-510  Ice cream bars/choc ices, chocolate coated, lu...
# 1331    12-384  Ice cream bars/choc ices, non-dairy, with choc...
# 1332    12-385                         Ice cream desserts, frozen
# 1333    17-689  Ice cream sauce, topping, strawberry and choco...
# 1334    12-581            Ice cream with cone, non-dairy, vanilla
# 1335    12-582          Ice cream with wafers, non-dairy, vanilla
# 1336    12-511   Ice cream, dairy, luxury, with chocolate/caramel
# 1337    12-508              Ice cream, dairy, vanilla, soft scoop
# 1338    12-509          Ice cream, non dairy, vanilla, soft scoop
# 1339    12-482          Ice cream, virtually fat free alternative
# 1340    11-828                                  Iced buns, retail
# 1341    17-783                            Icing, butter, homemade
# 1342    17-804                           Icing, fondant, homemade
# ...

# %% [markdown]
# Products within a Group (provide identification of the food group and food type to which the food belongs)

# %%
Prod_I.groupby('Group')['Food Name'].count()
# Out:
# Group
# AN     1
# BP     9
# BR     2
# PAA    2
# S      2
# SC     3
# Name: Food Name, dtype: int64

# %% [markdown]
# ## *Reducing products based on its most basic form. Improve as you go on*

# %% [markdown]
#                                                  Cereals and cereal products

# %% [markdown]
# Remove AN - Cakes

# %% [markdown]
#                                                    Milk and milk products

# %% [markdown]
# Ice creams

# %%
BP = Prod_I.loc[Prod_I['Group']== 'BP']
BP
# Out:
#      Food Code                                          Food Name  \
# 1330    12-510  Ice cream bars/choc ices, chocolate coated, lu...
# 1331    12-384  Ice cream bars/choc ices, non-dairy, with choc...
# 1332    12-385                         Ice cream desserts, frozen
# 1334    12-581            Ice cream with cone, non-dairy, vanilla
# 1335    12-582          Ice cream with wafers, non-dairy, vanilla
# 1336    12-511   Ice cream, dairy, luxury, with chocolate/caramel
# 1337    12-508              Ice cream, dairy, vanilla, soft scoop
# 1338    12-509          Ice cream, non dairy, vanilla, soft scoop
# 1339    12-482          Ice cream, virtually fat free alternative
#
#                                             Description Group        Previous  \
# 1330   11 samples, 5 products, including Magnum, Galaxy    BP         12-391
# 1331                             10 samples, 6 products    BP  12-200 50-263
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_BP = [ 'Ice cream, dairy, vanilla, soft scoop','Ice cream, non dairy, vanilla, soft scoop',]

# %%
Filt_BP = BP[BP['Food Name'].isin(Priority_BP)]
Filt_BP
# Out:
#      Food Code                                  Food Name  \
# 1337    12-508      Ice cream, dairy, vanilla, soft scoop
# 1338    12-509  Ice cream, non dairy, vanilla, soft scoop
#
#                                             Description Group Previous  \
# 1337  10 samples, 7 products, including Wall's, Mack...    BP  12-387
# 1338  10 samples, 8 products, including Wall's, Cart...    BP  12-388
#
#                                    Main data references Footnote Energy (kJ)  \
# 1337  DH, Nutrient analysis of a range of processed ...      NaN         720
# 1338  DH, Nutrient analysis of a range of processed ...      NaN         816
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1337           172      8.2          5.19             21.2       21.2
# 1338           194      7.7          5.01             28.6       22.8
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1337          0       0.2          3.2     0.16
# ...

# %%
Filt_BP['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_25796\4191555766.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_BP['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Removed BR - Puddings and chilled desserts

# %% [markdown]
#                                                        Beverages

# %% [markdown]
# Removed PAA - Powdered drinks and essences

# %% [markdown]
#                                             Sugars, preserves and snacks

# %% [markdown]
# Sugars, syrups and preserves

# %%
S = Prod_I.loc[Prod_I['Group']== 'S']
S
# Out:
#      Food Code                 Food Name Description Group Previous  \
# 1341    17-783   Icing, butter, homemade      Recipe     S  17-556
# 1342    17-804  Icing, fondant, homemade      Recipe     S  17-582
#
#      Main data references Footnote Energy (kJ) Energy (kcal)  Fat (g)  \
# 1341         Updated 2014      NaN        2136           511     29.4
# 1342         Updated 2014      NaN        1444           340      0.0
#
#      Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1341         18.61             60.4       59.7        0.6         0
# 1342             0             83.6       83.6          0         0
#
#       Protein (g) Salt (g)
# 1341          0.3     0.67
# 1342          1.3     0.08

# %% [markdown]
# **Reduced**

# %%
Filt_S = S.loc[S['Food Name'] == 'Icing, butter, homemade']
Filt_S
# Out:
#      Food Code                Food Name Description Group Previous  \
# 1341    17-783  Icing, butter, homemade      Recipe     S  17-556
#
#      Main data references Footnote Energy (kJ) Energy (kcal)  Fat (g)  \
# 1341         Updated 2014      NaN        2136           511     29.4
#
#      Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1341         18.61             60.4       59.7        0.6         0
#
#       Protein (g) Salt (g)
# 1341          0.3     0.67

# %%
Filt_S['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_25796\1889954277.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_S['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
# 2

# %%
SC = Prod_I.loc[Prod_I['Group']== 'SC']
SC
# Out:
#      Food Code                                          Food Name  \
# 1333    17-689  Ice cream sauce, topping, strawberry and choco...
# 1343    17-583                             Icing, glace, homemade
# 1344    17-805                             Icing, Royal, homemade
#
#                                             Description Group Previous  \
# 1333  8 samples, 3 brands; strawberry and chocolate ...    SC  17-053
# 1343                                             Recipe    SC  17-056
# 1344                                             Recipe    SC  17-584
#
#                                    Main data references Footnote Energy (kJ)  \
# 1333  Proximates and Na from label data. Inorganics ...      NaN        1205
# 1343                                       Updated 2014      NaN        1439
# 1344                                       Updated 2014      NaN        1531
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# ...

# %%
SC['Food Name'].unique()
# Out:
# array(['Ice cream sauce, topping, strawberry and chocolate flavours',
#        'Icing, glace, homemade', 'Icing, Royal, homemade'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Filt_SC = SC.loc[SC['Food Name']== 'Ice cream sauce, topping, strawberry and chocolate flavours']
Filt_SC
# Out:
#      Food Code                                          Food Name  \
# 1333    17-689  Ice cream sauce, topping, strawberry and choco...
#
#                                             Description Group Previous  \
# 1333  8 samples, 3 brands; strawberry and chocolate ...    SC  17-053
#
#                                    Main data references Footnote Energy (kJ)  \
# 1333  Proximates and Na from label data. Inorganics ...      NaN        1205
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1333           284      0.2             0             69.2       61.9
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1333        1.8       1.8          0.4        0

# %%
Filt_SC['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_25796\266286910.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_SC['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
#                                               **Join Reduced Tables**

# %%
Red = pd.concat([AP,DB], axis=0, join='inner')
Red
# Out:
#      Food Code                 Food Name       Description Group Previous  \
# 1327   11-1084  Hot cross buns, homemade            Recipe    AP  11-590
# 1329    13-556                   Houmous  Chick pea spread    DB  13-433
#
#      Main data references Footnote Energy (kJ) Energy (kcal)  Fat (g)  \
# 1327         Updated 2014      NaN        1280           303      5.8
# 1329  Industry data, 2013      NaN        1306           316     26.7
#
#      Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1327          1.95             53.9       22.1       31.7       1.9
# 1329          2.48              9.6        0.6        8.5       4.9
#
#       Protein (g) Salt (g)                  Super Group
# 1327          7.9     0.19  Cereals and cereal products
# 1329          6.8     1.03                   Vegetables

# %%
Red2 = pd.concat([Red,DG], axis=0, join='inner')
Red2
# Out:
#      Food Code                 Food Name       Description Group Previous  \
# 1327   11-1084  Hot cross buns, homemade            Recipe    AP  11-590
# 1329    13-556                   Houmous  Chick pea spread    DB  13-433
# 1326    13-258          Horseradish, raw     Flesh of root    DG      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1327                                       Updated 2014      NaN        1280
# 1329                                Industry data, 2013      NaN        1306
# 1326  MW4, 1978. Values revised for Vegetables, Herb...      NaN         324
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1327           303      5.8          1.95             53.9       22.1
# 1329           316     26.7          2.48              9.6        0.6
# 1326            77      0.3           0.1             10.4          7
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# ...

# %%
Red3 = pd.concat([Red2,Filt_GA], axis=0, join='inner')
Red3
# Out:
#      Food Code                 Food Name       Description Group  \
# 1327   11-1084  Hot cross buns, homemade            Recipe    AP
# 1329    13-556                   Houmous  Chick pea spread    DB
# 1326    13-258          Horseradish, raw     Flesh of root    DG
# 1300    14-874    Hazelnuts, kernel only        10 samples    GA
#
#                     Previous  \
# 1327                 11-590
# 1329                 13-433
# 1326                     NaN
# 1300  14-821 14-869 50-980
#
#                                    Main data references Footnote Energy (kJ)  \
# 1327                                       Updated 2014      NaN        1280
# 1329                                Industry data, 2013      NaN        1306
# 1326  MW4, 1978. Values revised for Vegetables, Herb...      NaN         324
# 1300  Reviewed 2013. LGC, Fruit and vegetables, 1989...      NaN        2783
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# ...

# %%
Red4 = pd.concat([Red3,Filt_JA], axis=0, join='inner')
Red4
# Out:
#      Food Code                 Food Name  \
# 1327   11-1084  Hot cross buns, homemade
# 1329    13-556                   Houmous
# 1326    13-258          Horseradish, raw
# 1300    14-874    Hazelnuts, kernel only
# 1271    16-375  Haddock, flesh only, raw
# 1286    16-070     Hake, flesh only, raw
#
#                                       Description Group  \
# 1327                                       Recipe    AP
# 1329                             Chick pea spread    DB
# 1326                                Flesh of root    DG
# 1300                                   10 samples    GA
# 1271  11 samples, 11 products, frozen and chilled    JA
# 1286                           Literature sources    JA
#
#                     Previous  \
# 1327                 11-590
# 1329                 13-433
# 1326                     NaN
# 1300  14-821 14-869 50-980
# 1271          16-044 16-051
# 1286                     NaN
#
# ...

# %%
Red5 = pd.concat([Red4,Filt_MAA], axis=0, join='inner')
Red5
# Out:
#      Food Code                 Food Name  \
# 1327   11-1084  Hot cross buns, homemade
# 1329    13-556                   Houmous
# 1326    13-258          Horseradish, raw
# 1300    14-874    Hazelnuts, kernel only
# 1271    16-375  Haddock, flesh only, raw
# 1286    16-070     Hake, flesh only, raw
# 1294    19-496                       Ham
#
#                                             Description Group  \
# 1327                                             Recipe    AP
# 1329                                   Chick pea spread    DB
# 1326                                      Flesh of root    DG
# 1300                                         10 samples    GA
# 1271        11 samples, 11 products, frozen and chilled    JA
# 1286                                 Literature sources    JA
# 1294  10 samples, 9 brands; loose and prepacked incl...   MAA
#
#                     Previous  \
# 1327                 11-590
# 1329                 13-433
# 1326                     NaN
# ...

# %%
Red6 = pd.concat([Red5,MI], axis=0, join='inner')
Red6
# Out:
#      Food Code                 Food Name  \
# 1327   11-1084  Hot cross buns, homemade
# 1329    13-556                   Houmous
# 1326    13-258          Horseradish, raw
# 1300    14-874    Hazelnuts, kernel only
# 1271    16-375  Haddock, flesh only, raw
# 1286    16-070     Hake, flesh only, raw
# 1294    19-496                       Ham
# 1283    19-132            Haggis, boiled
#
#                                             Description Group  \
# 1327                                             Recipe    AP
# 1329                                   Chick pea spread    DB
# 1326                                      Flesh of root    DG
# 1300                                         10 samples    GA
# 1271        11 samples, 11 products, frozen and chilled    JA
# 1286                                 Literature sources    JA
# 1294  10 samples, 9 brands; loose and prepacked incl...   MAA
# 1283                                          8 samples    MI
#
# ...

# %%
Red7 = pd.concat([Red6,MR], axis=0, join='inner')
Red7
# Out:
#      Food Code                                          Food Name  \
# 1327   11-1084                           Hot cross buns, homemade
# 1329    13-556                                            Houmous
# 1326    13-258                                   Horseradish, raw
# 1300    14-874                             Hazelnuts, kernel only
# 1271    16-375                           Haddock, flesh only, raw
# 1286    16-070                              Hake, flesh only, raw
# 1294    19-496                                                Ham
# 1283    19-132                                     Haggis, boiled
# 1328    19-522  Hot pot, lamb/beef with potatoes, retail, rehe...
#
#                                             Description Group  \
# 1327                                             Recipe    AP
# 1329                                   Chick pea spread    DB
# 1326                                      Flesh of root    DG
# ...

# %%
Red8 = pd.concat([Red7,Filt_PAA], axis=0, join='inner')
Red8
# Out:
#      Food Code                                          Food Name  \
# 1327   11-1084                           Hot cross buns, homemade
# 1329    13-556                                            Houmous
# 1326    13-258                                   Horseradish, raw
# 1300    14-874                             Hazelnuts, kernel only
# 1271    16-375                           Haddock, flesh only, raw
# 1286    16-070                              Hake, flesh only, raw
# 1294    19-496                                                Ham
# 1283    19-132                                     Haggis, boiled
# 1328    19-522  Hot pot, lamb/beef with potatoes, retail, rehe...
# 1324    17-731                                   Horlicks, powder
#
#                                             Description Group  \
# 1327                                             Recipe    AP
# 1329                                   Chick pea spread    DB
# ...

# %%
Red9 = pd.concat([Red8,Filt_SC], axis=0, join='inner')
Red9
# Out:
#      Food Code                                          Food Name  \
# 1327   11-1084                           Hot cross buns, homemade
# 1329    13-556                                            Houmous
# 1326    13-258                                   Horseradish, raw
# 1300    14-874                             Hazelnuts, kernel only
# 1271    16-375                           Haddock, flesh only, raw
# 1286    16-070                              Hake, flesh only, raw
# 1294    19-496                                                Ham
# 1283    19-132                                     Haggis, boiled
# 1328    19-522  Hot pot, lamb/beef with potatoes, retail, rehe...
# 1324    17-731                                   Horlicks, powder
# 1319    17-050                                              Honey
#
#                                             Description Group  \
# 1327                                             Recipe    AP
# ...

# %%
Red10 = pd.concat([Red9,WC], axis=0, join='inner')
Red10
# Out:
#      Food Code                                          Food Name  \
# 1327   11-1084                           Hot cross buns, homemade
# 1329    13-556                                            Houmous
# 1326    13-258                                   Horseradish, raw
# 1300    14-874                             Hazelnuts, kernel only
# 1271    16-375                           Haddock, flesh only, raw
# 1286    16-070                              Hake, flesh only, raw
# 1294    19-496                                                Ham
# 1283    19-132                                     Haggis, boiled
# 1328    19-522  Hot pot, lamb/beef with potatoes, retail, rehe...
# 1324    17-731                                   Horlicks, powder
# 1319    17-050                                              Honey
# 1318    17-800                        Hollandaise sauce, homemade
#
#                                             Description Group  \
# ...

# %% [markdown]
#                                                        Export

# %%
Red10.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced_H.csv')
