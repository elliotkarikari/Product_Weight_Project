# %% [markdown]
# # Product Weighting Project

# %% [markdown]
#                                          Data Reduction - Food Purchased In Store

# %% [markdown]
# ###### Import Necessary Libraries

# %%
import pandas as pd

# %% [markdown]
# Read in Data

# %%
Labelled = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Labelling2021_watercress.csv')

# %% [markdown]
# ### Products beginning with a 'H'

# %%
Prod_H = Labelled.loc[Labelled['Food Name'].str.startswith('H')]
Prod_H
# Out:
#      Food Code                                          Food Name  \
# 1259    16-063  Haddock, coated in crumbs, frozen, fried in bl...
# 1260    16-064  Haddock, coated in crumbs, frozen, fried in bl...
# 1261    16-062             Haddock, coated in crumbs, frozen, raw
# 1262    16-057  Haddock, fillets, flesh only, in flour, fried ...
# 1263    16-058  Haddock, fillets, flesh only, in flour, fried ...
# ...        ...                                                ...
# 1325    17-314                                  Horseradish sauce
# 1326    13-258                                   Horseradish, raw
# 1327   11-1084                           Hot cross buns, homemade
# 1328    19-522  Hot pot, lamb/beef with potatoes, retail, rehe...
# 1329    13-556                                            Houmous
#
#                                             Description Group   Previous  \
# 1259  10 samples, 7 brands; shallow fried in blended...    JA    50-580
# ...

# %% [markdown]
# Products within a Group (provide identification of the food group and food type to which the food belongs)

# %%
Prod_H.groupby('Group')['Food Name'].count()
# Out:
# Group
# AP      1
# DB      1
# DG      1
# GA      2
# JA     34
# JC      5
# MAA     4
# MEA     2
# MG      6
# MI      1
# MR      1
# PAA     4
# PCC     3
# SC      2
# SEC     2
# WC      1
# WCN     1
# Name: Food Name, dtype: int64

# %% [markdown]
# ## *Reducing products based on its most basic form. Improve as you go on*

# %% [markdown]
#                                                  Cereals and cereal products

# %% [markdown]
# Buns and pastries

# %%
AP = Prod_H.loc[Prod_H['Group']== 'AP']
AP
# Out:
#      Food Code                 Food Name Description Group Previous  \
# 1327   11-1084  Hot cross buns, homemade      Recipe    AP  11-590
#
#      Main data references Footnote Energy (kJ) Energy (kcal)  Fat (g)  \
# 1327         Updated 2014      NaN        1280           303      5.8
#
#      Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1327          1.95             53.9       22.1       31.7       1.9
#
#       Protein (g) Salt (g)
# 1327          7.9     0.19

# %%
AP['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27344\4095834454.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AP['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
#                                                        Vegetables

# %% [markdown]
# Beans and lentils

# %%
DB = Prod_H.loc[Prod_H['Group']== 'DB']
DB
# Out:
#      Food Code Food Name       Description Group Previous  \
# 1329    13-556   Houmous  Chick pea spread    DB  13-433
#
#      Main data references Footnote Energy (kJ) Energy (kcal)  Fat (g)  \
# 1329  Industry data, 2013      NaN        1306           316     26.7
#
#      Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1329          2.48              9.6        0.6        8.5       4.9
#
#       Protein (g) Salt (g)
# 1329          6.8     1.03

# %%
DB['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27344\1974533126.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DB['Super Group'] = 'Vegetables'

# %% [markdown]
# Vegetables, general

# %%
DG = Prod_H.loc[Prod_H['Group']== 'DG']
DG
# Out:
#      Food Code         Food Name    Description Group Previous  \
# 1326    13-258  Horseradish, raw  Flesh of root    DG      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1326  MW4, 1978. Values revised for Vegetables, Herb...      NaN         324
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1326            77      0.3           0.1             10.4          7
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1326        3.4       7.5          4.5     0.02

# %%
DG['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27344\3358340864.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DG['Super Group'] = 'Vegetables'

# %% [markdown]
#                                                     Nuts and seeds

# %%
GA = Prod_H.loc[Prod_H['Group']== 'GA']
GA
# Out:
#      Food Code                                    Food Name  \
# 1300    14-874                       Hazelnuts, kernel only
# 1301    14-885  Hazelnuts, kernel only, weighed with shells
#
#                  Description Group                Previous  \
# 1300              10 samples    GA  14-821 14-869 50-980
# 1301  Calculated from 14-874    GA          14-822 50-981
#
#                                    Main data references Footnote Energy (kJ)  \
# 1300  Reviewed 2013. LGC, Fruit and vegetables, 1989...      NaN        2783
# 1301  As Fruit and Nuts Supplement, 1992 (14-822) wi...      NaN        1057
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1300           674     63.5          4.55              5.6        3.8
# 1301           256     24.1          1.73              2.2        1.4
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1300        1.8       6.9         16.6     0.02
# 1301        0.7       2.6          6.3     0.01

# %% [markdown]
# **Reduced**

# %%
Filt_GA = GA.loc[GA['Food Name'] == 'Hazelnuts, kernel only' ]
Filt_GA
# Out:
#      Food Code               Food Name Description Group  \
# 1300    14-874  Hazelnuts, kernel only  10 samples    GA
#
#                     Previous  \
# 1300  14-821 14-869 50-980
#
#                                    Main data references Footnote Energy (kJ)  \
# 1300  Reviewed 2013. LGC, Fruit and vegetables, 1989...      NaN        2783
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1300           674     63.5          4.55              5.6        3.8
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)     Super Group
# 1300        1.8       6.9         16.6     0.02  Nuts and seeds

# %%
Filt_GA['Super Group'] = 'Nuts and seeds'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27344\4029859601.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_GA['Super Group'] = 'Nuts and seeds'

# %% [markdown]
#                                                     Fish and fish products

# %%
JA = Prod_H.loc[Prod_H['Group']== 'JA']
JA
# Out:
#      Food Code                                          Food Name  \
# 1259    16-063  Haddock, coated in crumbs, frozen, fried in bl...
# 1260    16-064  Haddock, coated in crumbs, frozen, fried in bl...
# 1261    16-062             Haddock, coated in crumbs, frozen, raw
# 1262    16-057  Haddock, fillets, flesh only, in flour, fried ...
# 1263    16-058  Haddock, fillets, flesh only, in flour, fried ...
# 1264    16-059  Haddock, fillets, flesh only, in flour, fried ...
# 1265    16-060  Haddock, fillets, flesh only, in flour, fried ...
# 1266    16-061  Haddock, fillets, flesh only, in flour, fried ...
# 1267    16-376                       Haddock, flesh only, grilled
# 1268    16-471  Haddock, flesh only, grilled, fillets weighed ...
# 1269    16-473                       Haddock, flesh only, poached
# 1270    16-474  Haddock, flesh only, poached, fillets weighed ...
# 1271    16-375                           Haddock, flesh only, raw
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_JA = ['Haddock, flesh only, raw','Hake, flesh only, raw']

# %%
Filt_JA = JA[JA['Food Name'].isin(Priority_JA)]
Filt_JA
# Out:
#      Food Code                 Food Name  \
# 1271    16-375  Haddock, flesh only, raw
# 1286    16-070     Hake, flesh only, raw
#
#                                       Description Group        Previous  \
# 1271  11 samples, 11 products, frozen and chilled    JA  16-044 16-051
# 1286                           Literature sources    JA             NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1271  DH, Nutrient analysis of fish and fish product...      NaN         318
# 1286            Fish and Fish Products Supplement, 1993      NaN         387
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1271            75      0.4          0.09                0          0
# 1286            92      2.2           0.3                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1271          0         0         17.8     0.17
# 1286          0         0         18.0     0.25

# %%
Filt_JA['Super Group'] = 'Fish and fish products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27344\3467222932.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_JA['Super Group'] = 'Fish and fish products'

# %% [markdown]
# Removed - JC - Fatty fish

# %% [markdown]
#                                                 Meat and meat products

# %% [markdown]
# Bacon

# %%
MAA = Prod_H.loc[Prod_H['Group']== 'MAA']
MAA
# Out:
#      Food Code                     Food Name  \
# 1294    19-496                           Ham
# 1295    19-021     Ham, gammon joint, boiled
# 1296    19-020        Ham, gammon joint, raw
# 1297    19-505  Ham, gammon rashers, grilled
#
#                                             Description Group  Previous  \
# 1294  10 samples, 9 brands; loose and prepacked incl...   MAA   19-308
# 1295  10 samples; smoked and unsmoked, prepacked Bri...   MAA  50-345
# 1296  10 samples; smoked and unsmoked, prepacked Bri...   MAA  50-344
# 1297                 5 samples; unsmoked British gammon   MAA   19-022
#
#                                    Main data references Footnote Energy (kJ)  \
# 1294  LGC, Nutrient analysis of foods important in e...      NaN         452
# 1295  Reviewed 2013. LGC, Nutrient analysis of retai...      NaN         851
# 1296  Reviewed 2013. LGC, Nutrient analysis of retai...      NaN         575
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_MAA = MAA.loc[MAA['Food Name'] == 'Ham']
Filt_MAA
# Out:
#      Food Code Food Name                                        Description  \
# 1294    19-496       Ham  10 samples, 9 brands; loose and prepacked incl...
#
#      Group Previous                               Main data references  \
# 1294   MAA  19-308   LGC, Nutrient analysis of foods important in e...
#
#      Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 1294      NaN         452           107      3.3           1.1
#
#      Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1294                1          1          0       0.1         18.4        2

# %%
Filt_MAA['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27344\11230460.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_MAA['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Removed Meat products -Grouse MEA

# %% [markdown]
# Removed Meat products - Offal MG

# %% [markdown]
# Meat products

# %%
MI = Prod_H.loc[Prod_H['Group']== 'MI']
MI
# Out:
#      Food Code       Food Name Description Group Previous  \
# 1283    19-132  Haggis, boiled   8 samples    MI  50-512
#
#           Main data references Footnote Energy (kJ) Energy (kcal)  Fat (g)  \
# 1283  Reviewed 2013. MW4, 1978      NaN        1289           310     21.7
#
#      Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1283           7.6             17.5          0       17.5         1
#
#       Protein (g) Salt (g)
# 1283         10.7     1.93

# %%
MI['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27344\3120306835.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MI['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Meat dishes

# %%
MR = Prod_H.loc[Prod_H['Group']== 'MR']
MR
# Out:
#      Food Code                                          Food Name  \
# 1328    19-522  Hot pot, lamb/beef with potatoes, retail, rehe...
#
#                                             Description Group Previous  \
# 1328  10 samples, 6 brands of beef, lamb and Lancash...    MR  19-231
#
#                                    Main data references Footnote Energy (kJ)  \
# 1328  LGC, Nutritional analysis of meat and poultry ...      NaN         465
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1328           111      4.4           1.7              9.7          1
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1328        8.7       1.9          7.2      0.5

# %%
MR['Food Name'].unique()
# Out:
# array(['Hot pot, lamb/beef with potatoes, retail, reheated'], dtype=object)

# %%
MR['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27344\2165351713.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MR['Super Group'] = 'Meat and meat products'

# %% [markdown]
#                                                        Beverages

# %% [markdown]
# Powdered drinks and essences

# %%
PAA = Prod_H.loc[Prod_H['Group']== 'PAA']
PAA
# Out:
#      Food Code                                        Food Name  \
# 1321    17-801  Horlicks powder, made up with semi-skimmed milk
# 1322    17-802       Horlicks powder, made up with skimmed milk
# 1323    17-803         Horlicks powder, made up with whole milk
# 1324    17-731                                 Horlicks, powder
#
#                                            Description Group Previous  \
# 1321  Recipe. Calculated from 25g powder to 200ml milk   PAA  17-561
# 1322  Recipe. Calculated from 25g powder to 200ml milk   PAA  17-562
# 1323  Recipe, Calculated from 25g powder to 200ml milk   PAA  17-560
# 1324             Manufacturer's data (GlaxoSmithKline)   PAA  17-503
#
#                                    Main data references Footnote Energy (kJ)  \
# 1321  Updated 2014. N values present due to N values...      NaN         354
# 1322  Updated 2014. N values present due to N values...      NaN         310
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_PAA = ['Horlicks, powder']

# %%
Filt_PAA = PAA[PAA['Food Name'].isin(Priority_PAA)]
Filt_PAA
# Out:
#      Food Code         Food Name                            Description Group  \
# 1324    17-731  Horlicks, powder  Manufacturer's data (GlaxoSmithKline)   PAA
#
#      Previous                               Main data references Footnote  \
# 1324  17-503   Industry data, 2013; and MW5, 1991 (50-1069) f...      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 1324        1623           383      3.1           1.3             77.7
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1324         37       40.7       3.4          9.4     1.25

# %%
Filt_PAA['Super Group'] = 'Beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27344\5251205.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_PAA['Super Group'] = 'Beverages'

# %% [markdown]
# Removed Squash and cordial PCC

# %% [markdown]
#                                             Sugars, preserves and snacks

# %% [markdown]
# Sugars, syrups and preserves

# %%
SC = Prod_H.loc[Prod_H['Group']== 'SC']
SC
# Out:
#      Food Code       Food Name                         Description Group  \
# 1319    17-050           Honey           8 samples; assorted types    SC
# 1320    17-051  Honey and comb  2 samples, honey and comb together    SC
#
#       Previous                               Main data references Footnote  \
# 1319  50-1001   Reviewed 2013. LFRA, Nutrient analysis of misc...      NaN
# 1320  50-1002   MW4, 1978. Values reviewed for Miscellaneous F...      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 1319        1305           307      0.0             0             76.4
# 1320        1445           341      4.6             0             74.4
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1319       76.4          0         0          0.4     0.03
# 1320       74.4          0         0          0.6     0.02

# %% [markdown]
# **Reduced**

# %%
Filt_SC = SC.loc[SC['Food Name']== 'Honey']
Filt_SC
# Out:
#      Food Code Food Name                Description Group  Previous  \
# 1319    17-050     Honey  8 samples; assorted types    SC  50-1001
#
#                                    Main data references Footnote Energy (kJ)  \
# 1319  Reviewed 2013. LFRA, Nutrient analysis of misc...      NaN        1305
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1319           307      0.0             0             76.4       76.4
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1319          0         0          0.4     0.03

# %%
Filt_SC['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27344\266286910.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_SC['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
# Removed SEC - Non-chocolate confectionery

# %% [markdown]
#                                             Soups, sauces and miscellaneous foods

# %% [markdown]
# Sauces

# %%
WC = Prod_H.loc[Prod_H['Group']== 'WC']
WC
# Out:
#      Food Code                    Food Name Description Group Previous  \
# 1318    17-800  Hollandaise sauce, homemade      Recipe    WC  17-610
#
#      Main data references Footnote Energy (kJ) Energy (kcal)  Fat (g)  \
# 1318         Updated 2014      NaN        2977           723     77.9
#
#      Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1318         46.36              0.5        0.5          0       0.1
#
#       Protein (g) Salt (g)
# 1318          5.1     1.58

# %%
WC['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27344\959050155.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WC['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
# Miscellaneous foods

# %%
WCN = Prod_H.loc[Prod_H['Group']== 'WCN']
WCN
# Out:
#      Food Code          Food Name  \
# 1325    17-314  Horseradish sauce
#
#                                          Description Group   Previous  \
# 1325  8 samples, 5 brands; creamed and plain samples   WCN  50-1168
#
#                                    Main data references Footnote Energy (kJ)  \
# 1325  Reviewed 2013. LFRA, Nutrient analysis of misc...      NaN         669
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1325           160      8.4           1.1             17.4       14.6
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1325        2.7       2.5          2.5     2.28

# %%
WCN['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27344\1581429497.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WCN['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
#                                               **Join Reduced Tables**

# %%
Red = pd.concat([Filt_AN,BTM], axis=0, join='inner')
Red
# Out:
#      Food Code                     Food Name            Description Group  \
# 1217   11-1079         Gingerbread, homemade                 Recipe    AN
# 1208    12-502  Ghee made from vegetable oil  5 samples, 3 products   BTM
#
#      Previous                               Main data references Footnote  \
# 1217  11-644                                        Updated 2014      NaN
# 1208  17-009   DH, Nutrient analysis of a range of processed ...      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 1217        1587           377     11.3          3.74               62
# 1208        3702           901    100.0         46.72                0
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1217       33.5       28.5       1.7          6.0     0.63
# 1208          0          0         0          0.1        0

# %%
Red2 = pd.concat([Red,Filt_DG], axis=0, join='inner')
Red2
# Out:
#      Food Code                     Food Name              Description Group  \
# 1217   11-1079         Gingerbread, homemade                   Recipe    AN
# 1208    12-502  Ghee made from vegetable oil    5 samples, 3 products   BTM
# 1204    13-244                   Garlic, raw            Peeled cloves    DG
# 1211    13-245                 Gherkins, raw  5 samples. Ends trimmed    DG
#
#      Previous                               Main data references Footnote  \
# 1217  11-644                                        Updated 2014      NaN
# 1208  17-009   DH, Nutrient analysis of a range of processed ...      NaN
# 1204  50-772   Reviewed 2013. IFR, The nutritional compositio...      NaN
# 1211      NaN      Vegetables, Herbs and Spices Supplement, 1991      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 1217        1587           377     11.3          3.74               62
# ...

# %%
Red3 = pd.concat([Red2,DI], axis=0, join='inner')
Red3
# Out:
#      Food Code                     Food Name  \
# 1217   11-1079         Gingerbread, homemade
# 1208    12-502  Ghee made from vegetable oil
# 1204    13-244                   Garlic, raw
# 1211    13-245                 Gherkins, raw
# 1244    13-608            Green beans, dried
#
#                              Description Group Previous  \
# 1217                              Recipe    AN  11-644
# 1208               5 samples, 3 products   BTM  17-009
# 1204                       Peeled cloves    DG  50-772
# 1211             5 samples. Ends trimmed    DG      NaN
# 1244  Calculated from raw beans (13-514)    DI  17-415
#
#                                    Main data references Footnote Energy (kJ)  \
# 1217                                       Updated 2014      NaN        1587
# 1208  DH, Nutrient analysis of a range of processed ...      NaN        3702
# 1204  Reviewed 2013. IFR, The nutritional compositio...      NaN         444
# ...

# %%
Red4 = pd.concat([Red3,Filt_FA], axis=0, join='inner')
Red4
# Out:
#      Food Code                     Food Name  \
# 1217   11-1079         Gingerbread, homemade
# 1208    12-502  Ghee made from vegetable oil
# 1204    13-244                   Garlic, raw
# 1211    13-245                 Gherkins, raw
# 1244    13-608            Green beans, dried
# 1221    14-100    Gooseberries, cooking, raw
# 1236    14-384   Grapefruit, flesh only, raw
# 1240    14-322                 Grapes, green
# 1255    14-118        Guava, flesh only, raw
#
#                                             Description Group Previous  \
# 1217                                             Recipe    AN  11-644
# 1208                              5 samples, 3 products   BTM  17-009
# 1204                                      Peeled cloves    DG  50-772
# 1211                            5 samples. Ends trimmed    DG      NaN
# 1244                 Calculated from raw beans (13-514)    DI  17-415
# 1221                             Tops and tails removed    FA  50-895
# ...

# %%
Red5 = pd.concat([Red4,H], axis=0, join='inner')
Red5
# Out:
#      Food Code                     Food Name  \
# 1217   11-1079         Gingerbread, homemade
# 1208    12-502  Ghee made from vegetable oil
# 1204    13-244                   Garlic, raw
# 1211    13-245                 Gherkins, raw
# 1244    13-608            Green beans, dried
# 1221    14-100    Gooseberries, cooking, raw
# 1236    14-384   Grapefruit, flesh only, raw
# 1240    14-322                 Grapes, green
# 1255    14-118        Guava, flesh only, raw
# 1201    13-829                  Garam masala
# 1203    13-830                 Garlic powder
# 1215    13-890                 Ginger, fresh
# 1216    13-832                Ginger, ground
#
#                                             Description Group Previous  \
# 1217                                             Recipe    AN  11-644
# 1208                              5 samples, 3 products   BTM  17-009
# 1204                                      Peeled cloves    DG  50-772
# ...

# %%
Red6 = pd.concat([Red5,OF], axis=0, join='inner')
Red6
# Out:
#      Food Code                     Food Name  \
# 1217   11-1079         Gingerbread, homemade
# 1208    12-502  Ghee made from vegetable oil
# 1204    13-244                   Garlic, raw
# 1211    13-245                 Gherkins, raw
# 1244    13-608            Green beans, dried
# 1221    14-100    Gooseberries, cooking, raw
# 1236    14-384   Grapefruit, flesh only, raw
# 1240    14-322                 Grapes, green
# 1255    14-118        Guava, flesh only, raw
# 1201    13-829                  Garam masala
# 1203    13-830                 Garlic powder
# 1215    13-890                 Ginger, fresh
# 1216    13-832                Ginger, ground
# 1209    17-640                  Ghee, butter
#
#                                             Description Group Previous  \
# 1217                                             Recipe    AN  11-644
# 1208                              5 samples, 3 products   BTM  17-009
# ...

# %%
Red7 = pd.concat([Red6,Filt_PE], axis=0, join='inner')
Red7
# Out:
#      Food Code                     Food Name  \
# 1217   11-1079         Gingerbread, homemade
# 1208    12-502  Ghee made from vegetable oil
# 1204    13-244                   Garlic, raw
# 1211    13-245                 Gherkins, raw
# 1244    13-608            Green beans, dried
# 1221    14-100    Gooseberries, cooking, raw
# 1236    14-384   Grapefruit, flesh only, raw
# 1240    14-322                 Grapes, green
# 1255    14-118        Guava, flesh only, raw
# 1201    13-829                  Garam masala
# 1203    13-830                 Garlic powder
# 1215    13-890                 Ginger, fresh
# 1216    13-832                Ginger, ground
# 1209    17-640                  Ghee, butter
# 1233    17-745      Grape juice, unsweetened
#
#                                             Description Group Previous  \
# 1217                                             Recipe    AN  11-644
# 1208                              5 samples, 3 products   BTM  17-009
# ...

# %%
Red8 = pd.concat([Red7,SC], axis=0, join='inner')
Red8
# Out:
#      Food Code                     Food Name  \
# 1217   11-1079         Gingerbread, homemade
# 1208    12-502  Ghee made from vegetable oil
# 1204    13-244                   Garlic, raw
# 1211    13-245                 Gherkins, raw
# 1244    13-608            Green beans, dried
# 1221    14-100    Gooseberries, cooking, raw
# 1236    14-384   Grapefruit, flesh only, raw
# 1240    14-322                 Grapes, green
# 1255    14-118        Guava, flesh only, raw
# 1201    13-829                  Garam masala
# 1203    13-830                 Garlic powder
# 1215    13-890                 Ginger, fresh
# 1216    13-832                Ginger, ground
# 1209    17-640                  Ghee, butter
# 1233    17-745      Grape juice, unsweetened
# 1218    17-049            Glucose liquid, BP
#
#                                             Description Group  Previous  \
# 1217                                             Recipe    AN   11-644
# ...

# %%
Red9 = pd.concat([Red8,WC], axis=0, join='inner')
Red9
# Out:
#      Food Code                     Food Name  \
# 1217   11-1079         Gingerbread, homemade
# 1208    12-502  Ghee made from vegetable oil
# 1204    13-244                   Garlic, raw
# 1211    13-245                 Gherkins, raw
# 1244    13-608            Green beans, dried
# 1221    14-100    Gooseberries, cooking, raw
# 1236    14-384   Grapefruit, flesh only, raw
# 1240    14-322                 Grapes, green
# 1255    14-118        Guava, flesh only, raw
# 1201    13-829                  Garam masala
# 1203    13-830                 Garlic powder
# 1215    13-890                 Ginger, fresh
# 1216    13-832                Ginger, ground
# 1209    17-640                  Ghee, butter
# 1233    17-745      Grape juice, unsweetened
# 1218    17-049            Glucose liquid, BP
# 1254    17-797           Guacamole, homemade
#
#                                             Description Group  Previous  \
# ...

# %%
Red10 = pd.concat([Red9,Filt_WY], axis=0, join='inner')
Red10
# Out:
#      Food Code                     Food Name  \
# 1217   11-1079         Gingerbread, homemade
# 1208    12-502  Ghee made from vegetable oil
# 1204    13-244                   Garlic, raw
# 1211    13-245                 Gherkins, raw
# 1244    13-608            Green beans, dried
# 1221    14-100    Gooseberries, cooking, raw
# 1236    14-384   Grapefruit, flesh only, raw
# 1240    14-322                 Grapes, green
# 1255    14-118        Guava, flesh only, raw
# 1201    13-829                  Garam masala
# 1203    13-830                 Garlic powder
# 1215    13-890                 Ginger, fresh
# 1216    13-832                Ginger, ground
# 1209    17-640                  Ghee, butter
# 1233    17-745      Grape juice, unsweetened
# 1218    17-049            Glucose liquid, BP
# 1254    17-797           Guacamole, homemade
# 1207    17-360                      Gelatine
# 1242    17-724        Gravy instant granules
#
# ...

# %% [markdown]
#                                                        Export

# %%
Red10.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced_G.csv')
