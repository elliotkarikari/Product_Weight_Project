# %% [markdown]
# # Product Weighting Project

# %% [markdown]
#                                          Data Reduction - Food Purchased In Store

# %% [markdown]
# ###### Import Necessary Libraries

# %%
import pandas as pd

# %% [markdown]
# Read in Data

# %%
Labelled = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Labelling2021_watercress.csv')

# %% [markdown]
# ### Products beginning with a 'M'

# %%
Prod_M = Labelled.loc[Labelled['Food Name'].str.startswith('M')]
Prod_M
# Out:
#      Food Code                      Food Name  \
# 1593    14-891         Macadamia nuts, salted
# 1594    11-954      Macaroni cheese, homemade
# 1595    12-951             Macaroon, homemade
# 1596    13-834                   Mace, ground
# 1597    16-394  Mackerel, flesh only, grilled
# ...        ...                            ...
# 1742    17-362                 Mustard powder
# 1743    13-839                  Mustard seeds
# 1744    17-363       Mustard, powder, made up
# 1745    17-364                Mustard, smooth
# 1746    17-365            Mustard, wholegrain
#
#                                            Description Group  \
# 1593                                         8 samples     G
# 1594                                            Recipe    AD
# 1595                                            Recipe   CDH
# 1596                                Literature sources     H
# 1597         7 samples, 7 products, frozen and chilled    JC
# ...

# %% [markdown]
# Products within a Group (provide identification of the food group and food type to which the food belongs)

# %%
Prod_M.groupby('Group')['Food Name'].count()
# Out:
# Group
# AD      1
# AF      2
# AI      2
# AM      1
# AN      3
# AP      4
# AS      1
# BA      1
# BAB     3
# BAE     4
# BAH     4
# BAK     4
# BAR     7
# BC      7
# BH      4
# BR      4
# CDH     1
# DG     22
# DI      1
# DR      4
# FA     23
# G       1
# GA      3
# H       7
# JA      9
# JC      4
# JM      3
# MI      1
# MR      5
# PAA     1
# S       1
# SC      3
# SEA     3
# SEC     1
# WC      2
# WCG     2
# WCN     1
# WY      4
# Name: Food Name, dtype: int64

# %% [markdown]
# ## *Reducing products based on its most basic form. Improve as you go on*

# %% [markdown]
#                                                 Cereals and cereal products

# %% [markdown]
# Pasta

# %%
AD = Prod_M.loc[Prod_M['Group']== 'AD']
AD
# Out:
#      Food Code                  Food Name Description Group Previous  \
# 1594    11-954  Macaroni cheese, homemade      Recipe    AD  11-562
#
#               Main data references Footnote Energy (kJ) Energy (kcal)  \
# 1594  As MW6. Recalculated in 2013      NaN         768           183
#
#       Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1594      8.6          4.47               18        2.7       15.4       1.1
#
#       Protein (g) Salt (g)
# 1594          7.9     0.37

# %%
AD['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\646763092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AD['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Removed AF - Breads

# %% [markdown]
# Breakfast cereals

# %%
AI = Prod_M.loc[Prod_M['Group']== 'AI']
AI
# Out:
#      Food Code                                          Food Name  \
# 1705    11-781  Muesli, Swiss style, no added sugar or salt, u...
# 1706    11-780                   Muesli, Swiss style, unfortified
#
#                                             Description Group        Previous  \
# 1705  6 samples, 5 products, including Jordans Natur...    AI         11-495
# 1706  11 samples, 9 products, including Alpen and ow...    AI  11-494 11-369
#
#                                  Main data references Footnote Energy (kJ)  \
# 1705  LGC, Nutrient survey of breakfast cereals, 2004      NaN        1575
# 1706  LGC, Nutrient survey of breakfast cereals, 2004      NaN        1617
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1705           373      5.9          1.19             65.3       12.8
# 1706           383      6.3          1.27             67.4       20.8
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_AI = AI[AI['Food Name'] == 'Muesli, Swiss style, unfortified']
Filt_AI
# Out:
#      Food Code                         Food Name  \
# 1706    11-780  Muesli, Swiss style, unfortified
#
#                                             Description Group        Previous  \
# 1706  11 samples, 9 products, including Alpen and ow...    AI  11-494 11-369
#
#                                  Main data references Footnote Energy (kJ)  \
# 1706  LGC, Nutrient survey of breakfast cereals, 2004      NaN        1617
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1706           383      6.3          1.27             67.4       20.8
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1706       46.6       8.8          9.9     0.35

# %%
Filt_AI['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\2672708786.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AI['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Removed AM - Biscuits

# %% [markdown]
# Cakes

# %%
AN = Prod_M.loc[Prod_M['Group']== 'AN']
AN
# Out:
#      Food Code                                          Food Name  \
# 1707   11-1094  Muffins, American style, chocolate chip, homemade
# 1708    11-737               Muffins, American, chocolate, retail
# 1709    11-738           Muffins, American, not chocolate, retail
#
#                                             Description Group Previous  \
# 1707                                             Recipe    AN  11-608
# 1708                             10 samples, 9 products    AN      NaN
# 1709  10 samples, 10 products, including blueberry, ...    AN      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1707             Based on generic recpe'.  Updated 2014      NaN        1617
# 1708  Direct Laboratories, Nutrient analysis catch u...      NaN        1839
# 1709  Direct Laboratories, Nutrient analysis catch u...      NaN        1591
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_AN = AN[AN['Food Name'] == 'Muffins, American, chocolate, retail']
Filt_AN
# Out:
#      Food Code                             Food Name             Description  \
# 1708    11-737  Muffins, American, chocolate, retail  10 samples, 9 products
#
#      Group Previous                               Main data references  \
# 1708    AN      NaN  Direct Laboratories, Nutrient analysis catch u...
#
#      Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 1708      NaN        1839           440     25.4          4.83
#
#      Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1708             46.4       29.5       16.7         1          6.1     0.99

# %%
Filt_AN['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\569209402.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AN['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Buns and Pastries

# %% [markdown]
# Removed AP

# %% [markdown]
# Puddings

# %%
AS = Prod_M.loc[Prod_M['Group']== 'AS']
AS
# Out:
#      Food Code           Food Name             Description Group Previous  \
# 1684    11-848  Mince pies, retail  10 samples, 8 products    AS      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1684  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1632
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1684           389     14.9          5.97             58.1       35.2
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1684       22.9       2.6          4.3     0.25

# %%
AS['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\2859841636.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AS['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
#                                                    Milk and milk products

# %% [markdown]
# Cow milk

# %%
BA = Prod_M.loc[Prod_M['Group']== 'BA']
BA
# Out:
#      Food Code                  Food Name  \
# 1652    12-512  Milk, 1% fat, pasteurised
#
#                                             Description Group Previous  \
# 1652  Average of skimmed (12-307) and semi-skimmed (...    BA      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1652  ADAS Laboratories, Nutrient analysis of pasteu...      NaN         173
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1652            41      1.0           0.6              4.6        4.6
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1652          0         0          3.4     0.11

# %%
BA['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\2739075003.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BA['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Breakfast Milk

# %%
BAB = Prod_M.loc[Prod_M['Group']== 'BAB']
BAB
# Out:
#      Food Code                                  Food Name  \
# 1653    12-321  Milk, Channel Islands, whole, pasteurised
# 1654    12-322       Milk, Channel islands, whole, summer
# 1655    12-323       Milk, Channel islands, whole, winter
#
#                                             Description Group  \
# 1653  Breakfast milk, average of 6 samples of summer...   BAB
# 1654                                          3 samples   BAB
# 1655                                          3 samples   BAB
#
#                    Previous  \
# 1653  12-885 12-078 50-194
# 1654         12-019 50-195
# 1655         12-019 50-195
#
#                                    Main data references Footnote Energy (kJ)  \
# 1653  Reviewed 2013. LGC, Nutrient analysis of ‘othe...      NaN         303
# 1654  LGC, Nutrient analysis of ‘other’ milk and cre...      NaN         305
# 1655  LGC, Nutrient analysis of ‘other’ milk and cre...      NaN         298
#
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_BAB = BAB.loc[BAB['Food Name'] == 'Milk, Channel islands, whole, summer']
Filt_BAB
# Out:
#      Food Code                             Food Name Description Group  \
# 1654    12-322  Milk, Channel islands, whole, summer   3 samples   BAB
#
#             Previous                               Main data references  \
# 1654  12-019 50-195   LGC, Nutrient analysis of ‘other’ milk and cre...
#
#      Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 1654      NaN         305            73      4.7          2.99
#
#      Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1654              3.9        3.9          0         0          3.8      0.1

# %%
Filt_BAB['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\2247885743.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_BAB['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Skimmed milk

# %%
BAE = Prod_M.loc[Prod_M['Group']== 'BAE']
BAE
# Out:
#      Food Code                            Food Name  \
# 1671    12-307  Milk, skimmed, pasteurised, average
# 1672    12-308   Milk, skimmed, pasteurised, summer
# 1673    12-309   Milk, skimmed, pasteurised, winter
# 1674    12-554                   Milk, skimmed, UHT
#
#                                             Description Group  \
# 1671  Average of summer and winter milk. Samples fro...   BAE
# 1672  Average of glass bottles, plastic containers a...   BAE
# 1673  Average of glass bottles, plastic containers a...   BAE
# 1674  22 samples, summer (June/Sep) and winter (Jan/...   BAE
#
#                       Previous  \
# 1671    12-002 12-831 50-182
# 1672  12-002 84 12-831 50-182
# 1673  12-002 84 12-831 50-182
# 1674            12-310 12-004
#
#                                    Main data references Footnote Energy (kJ)  \
# 1671  Reviewed 2013. ADAS Laboratory Services, Nutri...      NaN         147
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_BAE = BAE.loc[BAE['Food Name'] == 'Milk, skimmed, pasteurised, average']
Filt_BAE
# Out:
#      Food Code                            Food Name  \
# 1671    12-307  Milk, skimmed, pasteurised, average
#
#                                             Description Group  \
# 1671  Average of summer and winter milk. Samples fro...   BAE
#
#                     Previous  \
# 1671  12-002 12-831 50-182
#
#                                    Main data references Footnote Energy (kJ)  \
# 1671  Reviewed 2013. ADAS Laboratory Services, Nutri...      NaN         147
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1671            35      0.3          0.13              4.6        4.6
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1671          0         0          3.4     0.11

# %%
Filt_BAE['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\540732809.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_BAE['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Semi-skimmed milk

# %%
BAH = Prod_M.loc[Prod_M['Group']== 'BAH']
BAH
# Out:
#      Food Code                                          Food Name  \
# 1665    12-313           Milk, semi-skimmed, pasteurised, average
# 1666    12-418  Milk, semi-skimmed, pasteurised, summer and au...
# 1667    12-419  Milk, semi-skimmed, pasteurised, winter and sp...
# 1668    12-314                            Milk, semi-skimmed, UHT
#
#                                             Description Group  \
# 1665  Average of summer/autumn and winter/spring mil...   BAH
# 1666                Samples taken in June and September   BAH
# 1667                 Samples taken in January and March   BAH
# 1668           22 samples, average of winter and summer   BAH
#
#                    Previous  \
# 1665  12-009 12-832 50-186
# 1666  12-009 12-832 50-186
# 1667  12-009 12-832 50-186
# 1668  12-011 40-130 50-188
#
#                                    Main data references Footnote Energy (kJ)  \
# 1665  Reviewed 2013. ADAS Laboratory Services, Nutri...      NaN         196
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_BAH = BAH.loc[BAH['Food Name'] == 'Milk, semi-skimmed, pasteurised, average']
Filt_BAH
# Out:
#      Food Code                                 Food Name  \
# 1665    12-313  Milk, semi-skimmed, pasteurised, average
#
#                                             Description Group  \
# 1665  Average of summer/autumn and winter/spring mil...   BAH
#
#                    Previous  \
# 1665  12-009 12-832 50-186
#
#                                    Main data references Footnote Energy (kJ)  \
# 1665  Reviewed 2013. ADAS Laboratory Services, Nutri...      NaN         196
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1665            47      1.7          1.07              4.5        4.5
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1665          0         0          3.4     0.11

# %%
Filt_BAH['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\1128413593.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_BAH['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Whole Milk

# %%
BAK = Prod_M.loc[Prod_M['Group']== 'BAK']
BAK
# Out:
#      Food Code                                    Food Name  \
# 1677    12-596            Milk, whole, pasteurised, average
# 1678    12-598  Milk, whole, pasteurised, summer and autumn
# 1679    12-597  Milk, whole, pasteurised, winter and spring
# 1680    12-320                             Milk, whole, UHT
#
#                                             Description Group        Previous  \
# 1677  Average of summer/autumn and winter/spring sta...   BAK         12-316
# 1678  Standardised milk. Samples taken in June and S...   BAK         12-317
# 1679  Standardised milk. Samples taken in January an...   BAK         12-318
# 1680  22 samples, summer (Jun/Sep) and winter (Jan/Mar)   BAK  12-016 12-835
#
#                                    Main data references Footnote Energy (kJ)  \
# 1677  ADAS, Nutrient analysis of pasteurised liquid ...      NaN         264
# 1678  ADAS Laboratory Services, Nutrient analysis of...      NaN         257
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_BAK = BAK[BAK['Food Name'] == 'Milk, whole, pasteurised, average']
Filt_BAK
# Out:
#      Food Code                          Food Name  \
# 1677    12-596  Milk, whole, pasteurised, average
#
#                                             Description Group Previous  \
# 1677  Average of summer/autumn and winter/spring sta...   BAK  12-316
#
#                                    Main data references Footnote Energy (kJ)  \
# 1677  ADAS, Nutrient analysis of pasteurised liquid ...      NaN         264
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1677            63      3.6          2.29              4.4        4.4
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1677          0         0          3.3     0.11

# %%
Filt_BAK['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\3723756211.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_BAK['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Processed Milk

# %%
BAR = Prod_M.loc[Prod_M['Group']== 'BAR']
BAR
# Out:
#      Food Code                                         Food Name  \
# 1656    12-520                 Milk, condensed, whole, sweetened
# 1657    12-324                           Milk, evaporated, light
# 1658    12-522                           Milk, evaporated, whole
# 1659    12-535           Milk, flavoured, pasteurised, chocolate
# 1660    12-326  Milk, flavoured, pasteurised, strawberry, banana
# 1670    12-521                   Milk, skimmed, dried, fortified
# 1681    12-327                        Milkshake, thick, takeaway
#
#                                             Description Group  \
# 1656                                  10 cans, 2 brands   BAR
# 1657                                7 samples, 4 brands   BAR
# 1658        12 samples, Ideal, Carnation and own brands   BAR
# 1659  9 samples, 6 brands, including low fat, semi-s...   BAR
# 1660  10 samples, 6 brands, including low fat and se...   BAR
# 1670                               20 samples, 7 brands   BAR
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_BAR = ['Milk, condensed, whole, sweetened','Milk, evaporated, whole']

# %%
Filt_BAR = BAR[BAR['Food Name'].isin(Priority_BAR)]
Filt_BAR
# Out:
#      Food Code                          Food Name  \
# 1656    12-520  Milk, condensed, whole, sweetened
# 1658    12-522            Milk, evaporated, whole
#
#                                       Description Group Previous  \
# 1656                            10 cans, 2 brands   BAR  12-029
# 1658  12 samples, Ideal, Carnation and own brands   BAR  12-033
#
#                                    Main data references Footnote Energy (kJ)  \
# 1656  Milk Products and Eggs Supplement, 1989; Vitam...      NaN        1318
# 1658  Milk Products and Eggs Supplement, 1989; and i...      NaN         694
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1656           312      8.0          4.99             52.9       52.9
# 1658           166      9.4           5.9             12.1       12.1
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1656          0         0          7.3     0.23
# 1658          0         0          8.3     0.45

# %%
Filt_BAR['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\1534974581.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_BAR['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Other milks

# %%
BC = Prod_M.loc[Prod_M['Group']== 'BC']
BC
# Out:
#      Food Code                                          Food Name  \
# 1661    12-328                           Milk, goats, pasteurised
# 1662    12-038                             Milk, human, colostrum
# 1663    12-536                                Milk, human, mature
# 1664    12-039                          Milk, human, transitional
# 1669    12-329                                  Milk, sheeps, raw
# 1675    12-523  Milk, soya, non-dairy alternative to milk, swe...
# 1676    12-524  Milk, soya, non-dairy alternative to milk, uns...
#
#                                             Description Group  \
# 1661    20 samples from one herd and literature sources    BC
# 1662                                 Literature sources    BC
# 1663                                 Literature sources    BC
# 1664  Mixed sample, 15 mothers at 10th day post part...    BC
# 1669     30 samples from 2 herds and literature sources    BC
# 1675                               10 samples, 9 brands    BC
# ...

# %%
BC['Food Name'].unique()
# Out:
# array(['Milk, goats, pasteurised', 'Milk, human, colostrum',
#        'Milk, human, mature', 'Milk, human, transitional',
#        'Milk, sheeps, raw',
#        'Milk, soya, non-dairy alternative to milk, sweetened, fortified',
#        'Milk, soya, non-dairy alternative to milk, unsweetened, fortified'],
#       dtype=object)

# %% [markdown]
# **Reduced**

# %%
Filt_BC = BC[BC['Food Name'] == 'Milk, soya, non-dairy alternative to milk, unsweetened, fortified']
Filt_BC
# Out:
#      Food Code                                          Food Name  \
# 1676    12-524  Milk, soya, non-dairy alternative to milk, uns...
#
#                Description Group Previous  \
# 1676  10 samples, 8 brands    BC  12-331
#
#                                    Main data references Footnote Energy (kJ)  \
# 1676  LGC 'Nutrient analysis of other milk and cream...      NaN         116
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1676            28      1.6          0.24              0.5        0.2
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1676          0       0.5          2.6        0

# %%
Filt_BC['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\2963720121.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_BC['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Removed BH - Milk based drinks

# %% [markdown]
# Puddings and chilled desserts

# %%
BR = Prod_M.loc[Prod_M['Group']== 'BR']
BR
# Out:
#      Food Code                       Food Name  \
# 1643    12-517              Meringue, homemade
# 1644    12-585  Meringue, with cream, homemade
# 1703    12-401      Mousse, chocolate, low fat
# 1704    12-402                   Mousse, fruit
#
#                               Description Group        Previous  \
# 1643                Without cream. Recipe    BR         12-414
# 1644     Recipe. Ref. Wiles et al. (1980)    BR         12-415
# 1703                  7 samples, 4 brands    BR         12-914
# 1704  8 samples, assorted flavours, fresh    BR  50-286 12-246
#
#                                    Main data references Footnote Energy (kJ)  \
# 1643                                       Updated 2013      NaN        1662
# 1644                                       Updated 2014      NaN        1385
# 1703  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN           N
# 1704  Reviewed 2013. Milk Products and Eggs Suppleme...      NaN           N
#
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_BR = ['Meringue, homemade', 'Mousse, chocolate, low fat']

# %%
Filt_BR = BR[BR['Food Name'].isin(Priority_BR)]
Filt_BR
# Out:
#      Food Code                   Food Name            Description Group  \
# 1643    12-517          Meringue, homemade  Without cream. Recipe    BR
# 1703    12-401  Mousse, chocolate, low fat    7 samples, 4 brands    BR
#
#      Previous                               Main data references Footnote  \
# 1643  12-414                                        Updated 2013      NaN
# 1703  12-914   Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 1643        1662           391      0.0             0             91.4
# 1703           N             N      3.7          2.54             17.3
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1643       91.4          0         0          6.3     0.28
# 1703       15.3          2         N          5.4     0.17

# %%
Filt_BR['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\3725017385.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_BR['Super Group'] = 'Milk and milk products'

# %% [markdown]
#                                                           Eggs

# %%
CDH = Prod_M.loc[Prod_M['Group']== 'CDH']
CDH
# Out:
#      Food Code           Food Name Description Group Previous  \
# 1595    12-951  Macaroon, homemade      Recipe   CDH  12-935
#
#      Main data references Footnote Energy (kJ) Energy (kcal)  Fat (g)  \
# 1595         Updated 2014      NaN        1937           461     17.8
#
#      Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1595          1.41             62.8         59        3.7       2.4
#
#       Protein (g) Salt (g)
# 1595         11.3     0.15

# %%
CDH['Super Group'] = 'Eggs'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\2481589696.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CDH['Super Group'] = 'Eggs'

# %% [markdown]
#                                                         Vegetables

# %% [markdown]
# Vegetables, general

# %%
DG = Prod_M.loc[Prod_M['Group']== 'DG']
DG
# Out:
#      Food Code                                         Food Name  \
# 1604    13-273                   Mango, unripe, green flesh, raw
# 1610    13-276                  Marrow, boiled in unsalted water
# 1611    13-277                               Marrow, parwal, raw
# 1612    13-274                                       Marrow, raw
# 1617    13-588                  Matoki, boiled in unsalted water
# 1618    13-279                                       Matoki, raw
# 1723    13-288                    Mushrooms, Chinese, dried, raw
# 1724    13-289          Mushrooms, Jew's ear, tender, dried, raw
# 1725    13-290  Mushrooms, Jew's ear, tender, dried, soaked, raw
# 1726    13-291           Mushrooms, Jew's ear, tough, dried, raw
# 1727    13-292   Mushrooms, Jew's ear, tough, dried, soaked, raw
# 1728    13-293                            Mushrooms, oyster, raw
# 1729    13-295                       Mushrooms, shiitake, cooked
# ...

# %%
DG['Food Name'].unique()
# Out:
# array(['Mango, unripe, green flesh, raw',
#        'Marrow, boiled in unsalted water', 'Marrow, parwal, raw',
#        'Marrow, raw', 'Matoki, boiled in unsalted water', 'Matoki, raw',
#        'Mushrooms, Chinese, dried, raw',
#        "Mushrooms, Jew's ear, tender, dried, raw",
#        "Mushrooms, Jew's ear, tender, dried, soaked, raw",
#        "Mushrooms, Jew's ear, tough, dried, raw",
#        "Mushrooms, Jew's ear, tough, dried, soaked, raw",
#        'Mushrooms, oyster, raw', 'Mushrooms, shiitake, cooked',
#        'Mushrooms, shiitake, dried, raw',
#        'Mushrooms, white, fried in corn oil',
#        'Mushrooms, white, fried in rapeseed oil',
#        'Mushrooms, white, fried in salted butter',
#        'Mushrooms, white, raw',
#        'Mushrooms, white, stewed in unsalted water',
#        'Mustard and cress, raw',
#        'Mustard leaves, boiled in unsalted water', 'Mustard leaves, raw'],
#       dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_DG = ['Mango, unripe, green flesh, raw','Mushrooms, white, raw','Mustard leaves, raw']

# %%
Filt_DG = DG[DG['Food Name'].isin(Priority_DG)]
Filt_DG
# Out:
#      Food Code                        Food Name  \
# 1604    13-273  Mango, unripe, green flesh, raw
# 1734    13-505            Mushrooms, white, raw
# 1741    13-298              Mustard leaves, raw
#
#                                             Description Group Previous  \
# 1604                                Literature sources.    DG      NaN
# 1734  11 samples, closed cap and button, UK grown an...    DG  13-284
# 1741                                Literature sources;    DG      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1604      Vegetables, Herbs and Spices Supplement, 1991      NaN         230
# 1734  DH, Nutrient analysis of fruit and vegetables,...      NaN          88
# 1741  Haytowitz and Matthews (1984) Composition of f...      NaN         141
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1604            55      0.2           0.1             10.7        5.6
# ...

# %%
Filt_DG['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\1311392366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DG['Super Group'] = 'Vegetables'

# %% [markdown]
# Removed DI - Vegetables Dried

# %% [markdown]
# Vegetable dishes

# %%
DR = Prod_M.loc[Prod_M['Group']== 'DR']
DR
# Out:
#      Food Code                      Food Name  \
# 1622    15-822              Mchicha, homemade
# 1645    15-628           Methi aloo, homemade
# 1701    15-734  Moussaka, vegetable, homemade
# 1702    15-652    Moussaka, vegetable, retail
#
#                                             Description Group Previous  \
# 1622  Recipe. West Indian dish. Steamed spinach with...    DR  15-541
# 1645                  6 samples, fenugreek and potatoes    DR      NaN
# 1701                                             Recipe    DR  15-542
# 1702  7 samples, 3 brands; cooked in conventional an...    DR  15-206
#
#                                    Main data references Footnote Energy (kJ)  \
# 1622                                       Updated 2014      NaN         315
# 1645  University of Leeds, Nutritional analysis of c...      NaN         612
# 1701                                       Updated 2014      NaN         539
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_DR = DR[DR['Food Name'] == 'Moussaka, vegetable, retail']
Filt_DR
# Out:
#      Food Code                    Food Name  \
# 1702    15-652  Moussaka, vegetable, retail
#
#                                             Description Group Previous  \
# 1702  7 samples, 3 brands; cooked in conventional an...    DR  15-206
#
#                                    Main data references Footnote Energy (kJ)  \
# 1702  LGC, Fruit and vegetables, 1989-1990; and indu...      NaN           N
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1702             N      4.9             N              7.6        4.4
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1702        3.2         N          5.9     0.53

# %%
Filt_DR['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\2508077319.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DR['Super Group'] = 'Vegetables'

# %% [markdown]
#                                                            Fruit

# %% [markdown]
# Fruit, general

# %%
FA = Prod_M.loc[Prod_M['Group']== 'FA']
FA
# Out:
#      Food Code                                          Food Name  \
# 1602    14-145                           Mammie apple, flesh only
# 1603    14-146  Mandarin oranges, canned in juice, whole contents
# 1605    14-378                     Mangoes, ripe, flesh only, raw
# 1606    14-379  Mangoes, ripe, flesh only, raw, weighed with s...
# 1607    14-151                             Mangosteen, flesh only
# 1627    14-152                                Medlars, flesh only
# 1629    14-339                 Melon, Canteloupe-type, flesh only
# 1630    14-352  Melon, Canteloupe-type, flesh only, weighed whole
# 1631    14-353  Melon, Canteloupe-type, flesh only, weighed wi...
# 1632    14-354                         Melon, flesh only, average
# 1633    14-355          Melon, flesh only, average, weighed whole
# 1634    14-356      Melon, flesh only, average, weighed with skin
# 1635    14-159                           Melon, Galia, flesh only
# ...

# %%
FA['Food Name'].unique()
# Out:
# array(['Mammie apple, flesh only',
#        'Mandarin oranges, canned in juice, whole contents',
#        'Mangoes, ripe, flesh only, raw',
#        'Mangoes, ripe, flesh only, raw, weighed with skin and stone',
#        'Mangosteen, flesh only', 'Medlars, flesh only',
#        'Melon, Canteloupe-type, flesh only',
#        'Melon, Canteloupe-type, flesh only, weighed whole',
#        'Melon, Canteloupe-type, flesh only, weighed with skin',
#        'Melon, flesh only, average',
#        'Melon, flesh only, average, weighed whole',
#        'Melon, flesh only, average, weighed with skin',
#        'Melon, Galia, flesh only',
#        'Melon, Galia, flesh only, weighed whole',
#        'Melon, Galia, flesh only, weighed with skin',
#        'Melon, Honeydew, flesh only, weighed whole',
#        'Melon, Honeydew, flesh only, weighed with skin',
#        'Melon, watermelon, flesh only',
#        'Melon, watermelon, flesh only, weighed whole',
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_FA = ['Mangoes, ripe, flesh only, raw','Melon, Canteloupe-type, flesh only','Mulberries, whole fruit, raw']

# %%
Filt_FA = FA[FA['Food Name'].isin(Priority_FA)]
Filt_FA
# Out:
#      Food Code                           Food Name  \
# 1605    14-378      Mangoes, ripe, flesh only, raw
# 1629    14-339  Melon, Canteloupe-type, flesh only
# 1713    14-168        Mulberries, whole fruit, raw
#
#                                            Description Group Previous  \
# 1605  11 samples, imported, whole and prepacked chunks    FA   14-294
# 1629      10 samples, Canteloupe, Charantais and Rock;    FA  14-295
# 1713                                       Whole fruit    FA      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1605  PHE, Nutrient analysis of fresh and processed ...      NaN         227
# 1629  Reviewed 2013. LGC, Nutritional composition of...      NaN         100
# 1713  MW4, 1978. Values revised for Fruit and Nuts S...      NaN         170
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1605            54      0.6          0.15             10.4       10.1
# ...

# %%
Filt_FA['Super Group'] = 'Fruit'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\3797725470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_FA['Super Group'] = 'Fruit'

# %% [markdown]
#                                                     Nuts and seeds

# %%
G = Prod_M.loc[Prod_M['Group']== 'G']
G
# Out:
#      Food Code               Food Name Description Group Previous  \
# 1593    14-891  Macadamia nuts, salted   8 samples     G  14-823
#
#                          Main data references Footnote Energy (kJ)  \
# 1593  LGC, Savoury snacks and nuts, 1989-1991      NaN        3161
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1593           767     77.6          11.2              4.5        3.8
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1593        0.7       6.4          9.3        1

# %%
G['Super Group'] = 'Nuts and seeds'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\2156891443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   G['Super Group'] = 'Nuts and seeds'

# %% [markdown]
# Nut and seeds, general

# %%
GA = Prod_M.loc[Prod_M['Group']== 'GA']
GA
# Out:
#      Food Code                           Food Name         Description Group  \
# 1615    14-893                  Marzipan, homemade              Recipe    GA
# 1616    14-875  Marzipan, white and yellow, retail          10 samples    GA
# 1628    14-826                         Melon seeds  Literature sources    GA
#
#                     Previous  \
# 1615                 14-881
# 1616  14-825 14-861 50-984
# 1628                     NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1615                                       Updated 2014      NaN        1997
# 1616  Reviewed 2013. LGC, Fruit and vegetables, 1989...      NaN        1695
# 1628                    Fruit and Nuts Supplement, 1992      NaN        2445
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1615           478     25.7          2.17             47.6       46.3
# 1616           403     12.7          1.03             64.6       64.6
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_GA = GA[GA['Food Name'] == 'Marzipan, white and yellow, retail']
Filt_GA
# Out:
#      Food Code                           Food Name Description Group  \
# 1616    14-875  Marzipan, white and yellow, retail  10 samples    GA
#
#                     Previous  \
# 1616  14-825 14-861 50-984
#
#                                    Main data references Footnote Energy (kJ)  \
# 1616  Reviewed 2013. LGC, Fruit and vegetables, 1989...      NaN        1695
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1616           403     12.7          1.03             64.6       64.6
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1616          0       2.4          6.4     0.05

# %%
Filt_GA['Super Group'] = 'Nuts and seeds'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\4029859601.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_GA['Super Group'] = 'Nuts and seeds'

# %% [markdown]
#                                                     Herbs and Spices

# %%
H = Prod_M.loc[Prod_M['Group']== 'H']
H
# Out:
#      Food Code           Food Name  \
# 1596    13-834        Mace, ground
# 1608    13-835     Marjoram, dried
# 1690    13-837         Mint, dried
# 1691    13-836         Mint, fresh
# 1692    13-886  Mixed curry spices
# 1693    13-884  Mixed herbs, dried
# 1743    13-839       Mustard seeds
#
#                                             Description Group Previous  \
# 1596                                 Literature sources     H      NaN
# 1608                                 Literature sources     H      NaN
# 1690              10 samples and calculation from fresh     H      NaN
# 1691                                 Literature sources     H  50-842
# 1692  Recipe, equal quantities of curry powder, gara...     H  13-872
# 1693  Recipe; Equal quantities of Marjoram, Parsley,...     H  13-871
# 1743                                 Literature sources     H      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# ...

# %%
H['Food Name'].unique()
# Out:
# array(['Mace, ground', 'Marjoram, dried', 'Mint, dried', 'Mint, fresh',
#        'Mixed curry spices', 'Mixed herbs, dried', 'Mustard seeds'],
#       dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_H = ['Marjoram, dried','Mint, fresh','Mixed curry spices', 'Mixed herbs, dried','Mustard seeds']

# %%
Filt_H = H[H['Food Name'].isin(Priority_H)]
Filt_H
# Out:
#      Food Code           Food Name  \
# 1608    13-835     Marjoram, dried
# 1691    13-836         Mint, fresh
# 1692    13-886  Mixed curry spices
# 1693    13-884  Mixed herbs, dried
# 1743    13-839       Mustard seeds
#
#                                             Description Group Previous  \
# 1608                                 Literature sources     H      NaN
# 1691                                 Literature sources     H  50-842
# 1692  Recipe, equal quantities of curry powder, gara...     H  13-872
# 1693  Recipe; Equal quantities of Marjoram, Parsley,...     H  13-871
# 1743                                 Literature sources     H      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1608  Marsh et al. (1977) Composition of foods: spic...      NaN        1348
# 1691  Reviewed 2013. Vegetables, Herbs and Spices Su...      NaN         157
# 1692         Produced for use in VD recipe calculations      NaN        1370
# ...

# %%
Filt_H['Super Group'] = 'Herbs and Spices'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\854041242.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_H['Super Group'] = 'Herbs and Spices'

# %% [markdown]
#                                                 Fish and fish products

# %% [markdown]
# Removed JA -White Fish

# %%
JC = Prod_M.loc[Prod_M['Group']== 'JC']
JC
# Out:
#      Food Code                                          Food Name  \
# 1597    16-394                      Mackerel, flesh only, grilled
# 1598    16-479  Mackerel, flesh only, grilled, fillets weighed...
# 1599    16-393                          Mackerel, flesh only, raw
# 1600    16-414                       Mackerel, flesh only, smoked
#
#                                             Description Group Previous  \
# 1597          7 samples, 7 products, frozen and chilled    JC  16-325
# 1598  Calculated from 16-394 using 0.98 edible conve...    JC      NaN
# 1599          7 samples, 7 products, frozen and chilled    JC  16-324
# 1600                11 samples, 11 products, flesh only    JC  16-196
#
#                                    Main data references Footnote Energy (kJ)  \
# 1597  DH, Nutrient analysis of fish and fish product...      NaN        1174
# 1598  DH, Nutrient analysis of fish and fish product...      NaN        1152
# ...

# %%
JC['Food Name'].unique()
# Out:
# array(['Mackerel, flesh only, grilled',
#        'Mackerel, flesh only, grilled, fillets weighed with bones and skin',
#        'Mackerel, flesh only, raw', 'Mackerel, flesh only, smoked'],
#       dtype=object)

# %% [markdown]
# **Reduced**

# %%
Filt_JC = JC[JC['Food Name'] ==  'Mackerel, flesh only, raw' ]
Filt_JC
# Out:
#      Food Code                  Food Name  \
# 1599    16-393  Mackerel, flesh only, raw
#
#                                     Description Group Previous  \
# 1599  7 samples, 7 products, frozen and chilled    JC  16-324
#
#                                    Main data references Footnote Energy (kJ)  \
# 1599  DH, Nutrient analysis of fish and fish product...      NaN         968
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1599           233     17.9          3.85                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1599          0         0         18.0     0.38

# %%
Filt_JC['Super Group'] = 'Fish and fish products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\3872156250.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_JC['Super Group'] = 'Fish and fish products'

# %% [markdown]
# Crustacea

# %%
JM = Prod_M.loc[Prod_M['Group']== 'JM']
JM
# Out:
#      Food Code                            Food Name  \
# 1736    16-411  Mussels in white wine sauce, cooked
# 1737    16-390            Mussels, purchased cooked
# 1738    16-497                         Mussels, raw
#
#                                     Description Group Previous  \
# 1736  6 samples, 6 products, frozen and chilled    JM      NaN
# 1737  7 samples, 6 products, frozen and chilled    JM  16-256
# 1738                            Purchased alive    JM  16-255
#
#                                    Main data references Footnote Energy (kJ)  \
# 1736  DH, Nutrient analysis of fish and fish product...      NaN         347
# 1737  DH, Nutrient analysis of fish and fish product...      NaN         382
# 1738  Fish and Fish Products Supplement, 1993; Fe an...      NaN         272
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1736            83      3.2          1.26              3.4        0.8
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_JM = JM[JM['Food Name'] == 'Mussels, raw']
Filt_JM
# Out:
#      Food Code     Food Name      Description Group Previous  \
# 1738    16-497  Mussels, raw  Purchased alive    JM  16-255
#
#                                    Main data references Footnote Energy (kJ)  \
# 1738  Fish and Fish Products Supplement, 1993; Fe an...      NaN         272
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1738            64      1.8           0.4                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1738          0         0         12.1     0.73

# %%
Filt_JM['Super Group'] = 'Fish and fish products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\2475319276.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_JM['Super Group'] = 'Fish and fish products'

# %% [markdown]
#                                             Meat and meat products

# %% [markdown]
# Removed MI - Meat productsf

# %%
MR = Prod_M.loc[Prod_M['Group']== 'MR']
MR
# Out:
#      Food Code                                          Food Name  \
# 1623    19-605                                Meat loaf, homemade
# 1624    19-326                             Meat samosas, takeaway
# 1626    19-613  Meatballs, pork and beef, in tomato sauce, hom...
# 1699    19-609                                 Moussaka, homemade
# 1700    19-507                         Moussaka, retail, reheated
#
#                                             Description Group  \
# 1623                                             Recipe    MR
# 1624                 10 samples from Indian restaurants    MR
# 1626                                             Recipe    MR
# 1699                                             Recipe    MR
# 1700  8 samples, 4 brands of beef and lamb. 20-23% m...    MR
#
#                           Previous  \
# 1623                       19-368
# 1624  19-059 19-289 11-353 50-174
# 1626                       19-415
# 1699                       19-412
# ...

# %% [markdown]
# **Reduced**

# %%
for c in MR['Food Name']:
    print(c)
# Out:
# Meat loaf, homemade
# Meat samosas, takeaway
# Meatballs, pork and beef, in tomato sauce, homemade
# Moussaka, homemade
# Moussaka, retail, reheated

# %%
Priority_MR = ['Meat loaf, homemade','Meat samosas, takeaway','Meatballs, pork and beef, in tomato sauce, homemade']

# %%
Filt_MR = MR[MR['Food Name'].isin(Priority_MR)]
Filt_MR
# Out:
#      Food Code                                          Food Name  \
# 1623    19-605                                Meat loaf, homemade
# 1624    19-326                             Meat samosas, takeaway
# 1626    19-613  Meatballs, pork and beef, in tomato sauce, hom...
#
#                              Description Group                      Previous  \
# 1623                              Recipe    MR                       19-368
# 1624  10 samples from Indian restaurants    MR  19-059 19-289 11-353 50-174
# 1626                              Recipe    MR                       19-415
#
#                                    Main data references Footnote Energy (kJ)  \
# 1623                                       Updated 2014      NaN         879
# 1624  Reviewed 2013. Aspland and James Ltd, Nutrient...      NaN        1147
# 1626                                       Updated 2014      NaN         514
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# ...

# %%
Filt_MR['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\3346374556.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_MR['Super Group'] = 'Meat and meat products'

# %% [markdown]
#                                                         Beverages

# %% [markdown]
# Soft Drinks

# %%
PAA = Prod_M.loc[Prod_M['Group']== 'PAA']
PAA
# Out:
#      Food Code           Food Name                      Description Group  \
# 1648    17-733  Milk shake, powder  6 samples (Nesquik), 3 flavours   PAA
#
#      Previous                               Main data references Footnote  \
# 1648  12-104   Milk Products and Eggs Supplement, 1989; and  ...      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 1648        1673           394      1.6             N             93.6
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1648       93.6          0         0          1.3     0.05

# %%
PAA['Super Group'] = 'Beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\2213136320.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PAA['Super Group'] = 'Beverages'

# %% [markdown]
#                                             Sugars, preserves and snacks

# %% [markdown]
# Removed S

# %%
SC = Prod_M.loc[Prod_M['Group']== 'SC']
SC
# Out:
#      Food Code  Food Name                   Description Group  Previous  \
# 1609    17-078  Marmalade                      4 brands    SC  50-1008
# 1685    17-765  Mincemeat  10 samples of the same brand    SC   17-080
# 1694    17-059   Molasses            Literature sources    SC       NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1609  Reviewed 2013. LGC, Analysis of assorted foods...      NaN        1166
# 1685  Reviewed 2013. LGC, Nutritional composition of...      NaN        1235
# 1694                 Ref. Cutrufelli and Pehrsson, 1991      NaN         987
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1609           274      0.0             0             68.1       68.1
# 1685           292      4.3          0.28             62.1       62.1
# 1694           232      0.1             0             57.8       57.8
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_SC = SC[SC['Food Name'] == 'Marmalade']
Filt_SC
# Out:
#      Food Code  Food Name Description Group  Previous  \
# 1609    17-078  Marmalade    4 brands    SC  50-1008
#
#                                    Main data references Footnote Energy (kJ)  \
# 1609  Reviewed 2013. LGC, Analysis of assorted foods...      NaN        1166
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1609           274      0.0             0             68.1       68.1
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1609          0       0.5          0.1     0.16

# %%
Filt_SC['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\266286910.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_SC['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
# Chocolate confectionery

# %%
SEA = Prod_M.loc[Prod_M['Group']== 'SEA']
SEA
# Out:
#      Food Code                            Food Name  \
# 1601    17-651       Maltesers and similar products
# 1613    17-668   Mars bar and own brand equivalents
# 1682    17-669  Milky Way and own brand equivalents
#
#                                             Description Group Previous  \
# 1601                              9 samples, 3 products   SEA      NaN
# 1613  16 samples, 3 brands, including standard, snac...   SEA  17-547
# 1682  16 samples, 3 brands, including standard and f...   SEA  17-548
#
#                                    Main data references Footnote Energy (kJ)  \
# 1601  DH, Nutrient analysis of a range of processed ...      NaN        2018
# 1613  DH, Nutrient analysis of a range of processed ...      NaN        1730
# 1682  DH, Nutrient analysis of a range of processed ...      NaN        1893
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1601           482     23.3         14.16             59.8         53
# ...

# %%
SEA['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\2163827241.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SEA['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
# Non chocolate confectionery

# %%
SEC = Prod_M.loc[Prod_M['Group']== 'SEC']
SEC
# Out:
#      Food Code     Food Name                    Description Group Previous  \
# 1614    17-114  Marshmallows  7 samples of different brands   SEC      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1614  Reviewed 2013. LGC, Nutritional analysis of fo...      NaN        1412
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1614           332      0.0             0             79.2         62
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1614        4.1         0          3.9     0.07

# %%
SEC['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\382276731.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SEC['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
#                                         Soups, sauces and miscellaneous foods

# %% [markdown]
# Removed WC

# %% [markdown]
# Salad sauces, dressings and pickles

# %%
WCG = Prod_M.loc[Prod_M['Group']== 'WCG']
WCG
# Out:
#      Food Code                     Food Name            Description Group  \
# 1620    17-679       Mayonnaise, reduced fat   12 samples, 8 brands   WCG
# 1621    17-654  Mayonnaise, standard, retail  11 samples,7 products   WCG
#
#      Previous                               Main data references Footnote  \
# 1620  17-511   RHM Technology, Nutrient analysis of selected ...      NaN
# 1621  17-510   DH, Nutrient analysis of a range of processed ...      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 1620        1189           288     28.1          2.12              7.8
# 1621        2825           687     74.8          5.65              2.3
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1620        4.5        3.3         0          1.0      1.7
# 1621        2.3          0         0          1.1     0.33

# %% [markdown]
# **Reduced**

# %%
Filt_WCG = WCG[WCG['Food Name'] == 'Mayonnaise, standard, retail']
Filt_WCG
# Out:
#      Food Code                     Food Name            Description Group  \
# 1621    17-654  Mayonnaise, standard, retail  11 samples,7 products   WCG
#
#      Previous                               Main data references Footnote  \
# 1621  17-510   DH, Nutrient analysis of a range of processed ...      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 1621        2825           687     74.8          5.65              2.3
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1621        2.3          0         0          1.1     0.33

# %%
Filt_WCG['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\3841529321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_WCG['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
# Removed WCN - Non-salad sauces

# %%
WY = Prod_M.loc[Prod_M['Group']== 'WY']
WY
# Out:
#      Food Code                 Food Name  \
# 1742    17-362            Mustard powder
# 1744    17-363  Mustard, powder, made up
# 1745    17-364           Mustard, smooth
# 1746    17-365       Mustard, wholegrain
#
#                                            Description Group  \
# 1742                                          2 brands    WY
# 1744             Made up with an equal volume of water    WY
# 1745  10 samples, 7 types including English and French    WY
# 1746                               9 samples, 5 brands    WY
#
#                    Previous  \
# 1742  50-843 13-866 13-838
# 1744                    NaN
# 1745               50-1180
# 1746               50-1181
#
#                                    Main data references Footnote Energy (kJ)  \
# 1742  Reviewed 2013. Miscellaneous Foods, 1994 and V...      NaN        2027
# 1744               Miscellaneous Foods Supplement, 1994      NaN         992
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_WY = WY[WY['Food Name'] == 'Mustard, smooth']
Filt_WY
# Out:
#      Food Code        Food Name  \
# 1745    17-364  Mustard, smooth
#
#                                            Description Group  Previous  \
# 1745  10 samples, 7 types including English and French    WY  50-1180
#
#                                    Main data references Footnote Energy (kJ)  \
# 1745  Reviewed 2013. LFRA, Nutrient analysis of misc...      NaN         599
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1745           144      8.2           0.5              9.5        7.7
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1745        1.7       1.7          7.1     7.38

# %%
Filt_WY['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\2934381568.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_WY['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
#                                               **Join Reduced Tables**

# %%
Red = pd.concat([AD,Filt_AI], axis=0, join='inner')
Red
# Out:
#      Food Code                         Food Name  \
# 1594    11-954         Macaroni cheese, homemade
# 1706    11-780  Muesli, Swiss style, unfortified
#
#                                             Description Group        Previous  \
# 1594                                             Recipe    AD         11-562
# 1706  11 samples, 9 products, including Alpen and ow...    AI  11-494 11-369
#
#                                  Main data references Footnote Energy (kJ)  \
# 1594                     As MW6. Recalculated in 2013      NaN         768
# 1706  LGC, Nutrient survey of breakfast cereals, 2004      NaN        1617
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1594           183      8.6          4.47               18        2.7
# 1706           383      6.3          1.27             67.4       20.8
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# ...

# %%
Red2 = pd.concat([Red,Filt_AN], axis=0, join='inner')
Red2
# Out:
#      Food Code                             Food Name  \
# 1594    11-954             Macaroni cheese, homemade
# 1706    11-780      Muesli, Swiss style, unfortified
# 1708    11-737  Muffins, American, chocolate, retail
#
#                                             Description Group        Previous  \
# 1594                                             Recipe    AD         11-562
# 1706  11 samples, 9 products, including Alpen and ow...    AI  11-494 11-369
# 1708                             10 samples, 9 products    AN             NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1594                       As MW6. Recalculated in 2013      NaN         768
# 1706    LGC, Nutrient survey of breakfast cereals, 2004      NaN        1617
# 1708  Direct Laboratories, Nutrient analysis catch u...      NaN        1839
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# ...

# %%
Red3 = pd.concat([Red2,AS], axis=0, join='inner')
Red3
# Out:
#      Food Code                             Food Name  \
# 1594    11-954             Macaroni cheese, homemade
# 1706    11-780      Muesli, Swiss style, unfortified
# 1708    11-737  Muffins, American, chocolate, retail
# 1684    11-848                    Mince pies, retail
#
#                                             Description Group        Previous  \
# 1594                                             Recipe    AD         11-562
# 1706  11 samples, 9 products, including Alpen and ow...    AI  11-494 11-369
# 1708                             10 samples, 9 products    AN             NaN
# 1684                             10 samples, 8 products    AS             NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1594                       As MW6. Recalculated in 2013      NaN         768
# 1706    LGC, Nutrient survey of breakfast cereals, 2004      NaN        1617
# ...

# %%
Red4 = pd.concat([Red3,BA], axis=0, join='inner')
Red4
# Out:
#      Food Code                             Food Name  \
# 1594    11-954             Macaroni cheese, homemade
# 1706    11-780      Muesli, Swiss style, unfortified
# 1708    11-737  Muffins, American, chocolate, retail
# 1684    11-848                    Mince pies, retail
# 1652    12-512             Milk, 1% fat, pasteurised
#
#                                             Description Group        Previous  \
# 1594                                             Recipe    AD         11-562
# 1706  11 samples, 9 products, including Alpen and ow...    AI  11-494 11-369
# 1708                             10 samples, 9 products    AN             NaN
# 1684                             10 samples, 8 products    AS             NaN
# 1652  Average of skimmed (12-307) and semi-skimmed (...    BA             NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1594                       As MW6. Recalculated in 2013      NaN         768
# ...

# %%
Red5 = pd.concat([Red4,Filt_BAB], axis=0, join='inner')
Red5
# Out:
#      Food Code                             Food Name  \
# 1594    11-954             Macaroni cheese, homemade
# 1706    11-780      Muesli, Swiss style, unfortified
# 1708    11-737  Muffins, American, chocolate, retail
# 1684    11-848                    Mince pies, retail
# 1652    12-512             Milk, 1% fat, pasteurised
# 1654    12-322  Milk, Channel islands, whole, summer
#
#                                             Description Group        Previous  \
# 1594                                             Recipe    AD         11-562
# 1706  11 samples, 9 products, including Alpen and ow...    AI  11-494 11-369
# 1708                             10 samples, 9 products    AN             NaN
# 1684                             10 samples, 8 products    AS             NaN
# 1652  Average of skimmed (12-307) and semi-skimmed (...    BA             NaN
# 1654                                          3 samples   BAB  12-019 50-195
#
# ...

# %%
Red6 = pd.concat([Red5,Filt_BAE], axis=0, join='inner')
Red6
# Out:
#      Food Code                             Food Name  \
# 1594    11-954             Macaroni cheese, homemade
# 1706    11-780      Muesli, Swiss style, unfortified
# 1708    11-737  Muffins, American, chocolate, retail
# 1684    11-848                    Mince pies, retail
# 1652    12-512             Milk, 1% fat, pasteurised
# 1654    12-322  Milk, Channel islands, whole, summer
# 1671    12-307   Milk, skimmed, pasteurised, average
#
#                                             Description Group  \
# 1594                                             Recipe    AD
# 1706  11 samples, 9 products, including Alpen and ow...    AI
# 1708                             10 samples, 9 products    AN
# 1684                             10 samples, 8 products    AS
# 1652  Average of skimmed (12-307) and semi-skimmed (...    BA
# 1654                                          3 samples   BAB
# 1671  Average of summer and winter milk. Samples fro...   BAE
#
#                     Previous  \
# ...

# %%
Red7 = pd.concat([Red6,Filt_BAH], axis=0, join='inner')
Red7
# Out:
#      Food Code                                 Food Name  \
# 1594    11-954                 Macaroni cheese, homemade
# 1706    11-780          Muesli, Swiss style, unfortified
# 1708    11-737      Muffins, American, chocolate, retail
# 1684    11-848                        Mince pies, retail
# 1652    12-512                 Milk, 1% fat, pasteurised
# 1654    12-322      Milk, Channel islands, whole, summer
# 1671    12-307       Milk, skimmed, pasteurised, average
# 1665    12-313  Milk, semi-skimmed, pasteurised, average
#
#                                             Description Group  \
# 1594                                             Recipe    AD
# 1706  11 samples, 9 products, including Alpen and ow...    AI
# 1708                             10 samples, 9 products    AN
# 1684                             10 samples, 8 products    AS
# 1652  Average of skimmed (12-307) and semi-skimmed (...    BA
# 1654                                          3 samples   BAB
# ...

# %%
Red8 = pd.concat([Red7,Filt_BAK], axis=0, join='inner')
Red8
# Out:
#      Food Code                                 Food Name  \
# 1594    11-954                 Macaroni cheese, homemade
# 1706    11-780          Muesli, Swiss style, unfortified
# 1708    11-737      Muffins, American, chocolate, retail
# 1684    11-848                        Mince pies, retail
# 1652    12-512                 Milk, 1% fat, pasteurised
# 1654    12-322      Milk, Channel islands, whole, summer
# 1671    12-307       Milk, skimmed, pasteurised, average
# 1665    12-313  Milk, semi-skimmed, pasteurised, average
# 1677    12-596         Milk, whole, pasteurised, average
#
#                                             Description Group  \
# 1594                                             Recipe    AD
# 1706  11 samples, 9 products, including Alpen and ow...    AI
# 1708                             10 samples, 9 products    AN
# 1684                             10 samples, 8 products    AS
# 1652  Average of skimmed (12-307) and semi-skimmed (...    BA
# ...

# %%
Red9 = pd.concat([Red8,Filt_BAR], axis=0, join='inner')
Red9
# Out:
#      Food Code                                 Food Name  \
# 1594    11-954                 Macaroni cheese, homemade
# 1706    11-780          Muesli, Swiss style, unfortified
# 1708    11-737      Muffins, American, chocolate, retail
# 1684    11-848                        Mince pies, retail
# 1652    12-512                 Milk, 1% fat, pasteurised
# 1654    12-322      Milk, Channel islands, whole, summer
# 1671    12-307       Milk, skimmed, pasteurised, average
# 1665    12-313  Milk, semi-skimmed, pasteurised, average
# 1677    12-596         Milk, whole, pasteurised, average
# 1656    12-520         Milk, condensed, whole, sweetened
# 1658    12-522                   Milk, evaporated, whole
#
#                                             Description Group  \
# 1594                                             Recipe    AD
# 1706  11 samples, 9 products, including Alpen and ow...    AI
# 1708                             10 samples, 9 products    AN
# ...

# %%
Red10 = pd.concat([Red9,Filt_BC], axis=0, join='inner')
Red10
# Out:
#      Food Code                                          Food Name  \
# 1594    11-954                          Macaroni cheese, homemade
# 1706    11-780                   Muesli, Swiss style, unfortified
# 1708    11-737               Muffins, American, chocolate, retail
# 1684    11-848                                 Mince pies, retail
# 1652    12-512                          Milk, 1% fat, pasteurised
# 1654    12-322               Milk, Channel islands, whole, summer
# 1671    12-307                Milk, skimmed, pasteurised, average
# 1665    12-313           Milk, semi-skimmed, pasteurised, average
# 1677    12-596                  Milk, whole, pasteurised, average
# 1656    12-520                  Milk, condensed, whole, sweetened
# 1658    12-522                            Milk, evaporated, whole
# 1676    12-524  Milk, soya, non-dairy alternative to milk, uns...
#
#                                             Description Group  \
# ...

# %%
Red11 = pd.concat([Red10,Filt_BR], axis=0, join='inner')
Red11
# Out:
#      Food Code                                          Food Name  \
# 1594    11-954                          Macaroni cheese, homemade
# 1706    11-780                   Muesli, Swiss style, unfortified
# 1708    11-737               Muffins, American, chocolate, retail
# 1684    11-848                                 Mince pies, retail
# 1652    12-512                          Milk, 1% fat, pasteurised
# 1654    12-322               Milk, Channel islands, whole, summer
# 1671    12-307                Milk, skimmed, pasteurised, average
# 1665    12-313           Milk, semi-skimmed, pasteurised, average
# 1677    12-596                  Milk, whole, pasteurised, average
# 1656    12-520                  Milk, condensed, whole, sweetened
# 1658    12-522                            Milk, evaporated, whole
# 1676    12-524  Milk, soya, non-dairy alternative to milk, uns...
# 1643    12-517                                 Meringue, homemade
# ...

# %%
Red12 = pd.concat([Red11,CDH], axis=0, join='inner')
Red12
# Out:
#      Food Code                                          Food Name  \
# 1594    11-954                          Macaroni cheese, homemade
# 1706    11-780                   Muesli, Swiss style, unfortified
# 1708    11-737               Muffins, American, chocolate, retail
# 1684    11-848                                 Mince pies, retail
# 1652    12-512                          Milk, 1% fat, pasteurised
# 1654    12-322               Milk, Channel islands, whole, summer
# 1671    12-307                Milk, skimmed, pasteurised, average
# 1665    12-313           Milk, semi-skimmed, pasteurised, average
# 1677    12-596                  Milk, whole, pasteurised, average
# 1656    12-520                  Milk, condensed, whole, sweetened
# 1658    12-522                            Milk, evaporated, whole
# 1676    12-524  Milk, soya, non-dairy alternative to milk, uns...
# 1643    12-517                                 Meringue, homemade
# ...

# %%
Red13 = pd.concat([Red12,Filt_DG], axis=0, join='inner')
Red13
# Out:
#      Food Code                                          Food Name  \
# 1594    11-954                          Macaroni cheese, homemade
# 1706    11-780                   Muesli, Swiss style, unfortified
# 1708    11-737               Muffins, American, chocolate, retail
# 1684    11-848                                 Mince pies, retail
# 1652    12-512                          Milk, 1% fat, pasteurised
# 1654    12-322               Milk, Channel islands, whole, summer
# 1671    12-307                Milk, skimmed, pasteurised, average
# 1665    12-313           Milk, semi-skimmed, pasteurised, average
# 1677    12-596                  Milk, whole, pasteurised, average
# 1656    12-520                  Milk, condensed, whole, sweetened
# 1658    12-522                            Milk, evaporated, whole
# 1676    12-524  Milk, soya, non-dairy alternative to milk, uns...
# 1643    12-517                                 Meringue, homemade
# ...

# %%
Red14 = pd.concat([Red13,Filt_DR], axis=0, join='inner')
Red14
# Out:
#      Food Code                                          Food Name  \
# 1594    11-954                          Macaroni cheese, homemade
# 1706    11-780                   Muesli, Swiss style, unfortified
# 1708    11-737               Muffins, American, chocolate, retail
# 1684    11-848                                 Mince pies, retail
# 1652    12-512                          Milk, 1% fat, pasteurised
# 1654    12-322               Milk, Channel islands, whole, summer
# 1671    12-307                Milk, skimmed, pasteurised, average
# 1665    12-313           Milk, semi-skimmed, pasteurised, average
# 1677    12-596                  Milk, whole, pasteurised, average
# 1656    12-520                  Milk, condensed, whole, sweetened
# 1658    12-522                            Milk, evaporated, whole
# 1676    12-524  Milk, soya, non-dairy alternative to milk, uns...
# 1643    12-517                                 Meringue, homemade
# ...

# %%
Red15 = pd.concat([Red14,Filt_FA], axis=0, join='inner')
Red15
# Out:
#      Food Code                                          Food Name  \
# 1594    11-954                          Macaroni cheese, homemade
# 1706    11-780                   Muesli, Swiss style, unfortified
# 1708    11-737               Muffins, American, chocolate, retail
# 1684    11-848                                 Mince pies, retail
# 1652    12-512                          Milk, 1% fat, pasteurised
# 1654    12-322               Milk, Channel islands, whole, summer
# 1671    12-307                Milk, skimmed, pasteurised, average
# 1665    12-313           Milk, semi-skimmed, pasteurised, average
# 1677    12-596                  Milk, whole, pasteurised, average
# 1656    12-520                  Milk, condensed, whole, sweetened
# 1658    12-522                            Milk, evaporated, whole
# 1676    12-524  Milk, soya, non-dairy alternative to milk, uns...
# 1643    12-517                                 Meringue, homemade
# ...

# %%
Red16 = pd.concat([Red15,G], axis=0, join='inner')
Red16
# Out:
#      Food Code                                          Food Name  \
# 1594    11-954                          Macaroni cheese, homemade
# 1706    11-780                   Muesli, Swiss style, unfortified
# 1708    11-737               Muffins, American, chocolate, retail
# 1684    11-848                                 Mince pies, retail
# 1652    12-512                          Milk, 1% fat, pasteurised
# 1654    12-322               Milk, Channel islands, whole, summer
# 1671    12-307                Milk, skimmed, pasteurised, average
# 1665    12-313           Milk, semi-skimmed, pasteurised, average
# 1677    12-596                  Milk, whole, pasteurised, average
# 1656    12-520                  Milk, condensed, whole, sweetened
# 1658    12-522                            Milk, evaporated, whole
# 1676    12-524  Milk, soya, non-dairy alternative to milk, uns...
# 1643    12-517                                 Meringue, homemade
# ...

# %%
Red17 = pd.concat([Red16,Filt_GA], axis=0, join='inner')
Red17
# Out:
#      Food Code                                          Food Name  \
# 1594    11-954                          Macaroni cheese, homemade
# 1706    11-780                   Muesli, Swiss style, unfortified
# 1708    11-737               Muffins, American, chocolate, retail
# 1684    11-848                                 Mince pies, retail
# 1652    12-512                          Milk, 1% fat, pasteurised
# 1654    12-322               Milk, Channel islands, whole, summer
# 1671    12-307                Milk, skimmed, pasteurised, average
# 1665    12-313           Milk, semi-skimmed, pasteurised, average
# 1677    12-596                  Milk, whole, pasteurised, average
# 1656    12-520                  Milk, condensed, whole, sweetened
# 1658    12-522                            Milk, evaporated, whole
# 1676    12-524  Milk, soya, non-dairy alternative to milk, uns...
# 1643    12-517                                 Meringue, homemade
# ...

# %%
Red18 = pd.concat([Red17,Filt_H], axis=0, join='inner')
Red18
# Out:
#      Food Code                                          Food Name  \
# 1594    11-954                          Macaroni cheese, homemade
# 1706    11-780                   Muesli, Swiss style, unfortified
# 1708    11-737               Muffins, American, chocolate, retail
# 1684    11-848                                 Mince pies, retail
# 1652    12-512                          Milk, 1% fat, pasteurised
# 1654    12-322               Milk, Channel islands, whole, summer
# 1671    12-307                Milk, skimmed, pasteurised, average
# 1665    12-313           Milk, semi-skimmed, pasteurised, average
# 1677    12-596                  Milk, whole, pasteurised, average
# 1656    12-520                  Milk, condensed, whole, sweetened
# 1658    12-522                            Milk, evaporated, whole
# 1676    12-524  Milk, soya, non-dairy alternative to milk, uns...
# 1643    12-517                                 Meringue, homemade
# ...

# %%
Red19 = pd.concat([Red18,Filt_JC], axis=0, join='inner')
Red19
# Out:
#      Food Code                                          Food Name  \
# 1594    11-954                          Macaroni cheese, homemade
# 1706    11-780                   Muesli, Swiss style, unfortified
# 1708    11-737               Muffins, American, chocolate, retail
# 1684    11-848                                 Mince pies, retail
# 1652    12-512                          Milk, 1% fat, pasteurised
# 1654    12-322               Milk, Channel islands, whole, summer
# 1671    12-307                Milk, skimmed, pasteurised, average
# 1665    12-313           Milk, semi-skimmed, pasteurised, average
# 1677    12-596                  Milk, whole, pasteurised, average
# 1656    12-520                  Milk, condensed, whole, sweetened
# 1658    12-522                            Milk, evaporated, whole
# 1676    12-524  Milk, soya, non-dairy alternative to milk, uns...
# 1643    12-517                                 Meringue, homemade
# ...

# %%
Red20 = pd.concat([Red19,Filt_JM], axis=0, join='inner')
Red20
# Out:
#      Food Code                                          Food Name  \
# 1594    11-954                          Macaroni cheese, homemade
# 1706    11-780                   Muesli, Swiss style, unfortified
# 1708    11-737               Muffins, American, chocolate, retail
# 1684    11-848                                 Mince pies, retail
# 1652    12-512                          Milk, 1% fat, pasteurised
# 1654    12-322               Milk, Channel islands, whole, summer
# 1671    12-307                Milk, skimmed, pasteurised, average
# 1665    12-313           Milk, semi-skimmed, pasteurised, average
# 1677    12-596                  Milk, whole, pasteurised, average
# 1656    12-520                  Milk, condensed, whole, sweetened
# 1658    12-522                            Milk, evaporated, whole
# 1676    12-524  Milk, soya, non-dairy alternative to milk, uns...
# 1643    12-517                                 Meringue, homemade
# ...

# %%
Red21 = pd.concat([Red20,Filt_MR], axis=0, join='inner')
Red21
# Out:
#      Food Code                                          Food Name  \
# 1594    11-954                          Macaroni cheese, homemade
# 1706    11-780                   Muesli, Swiss style, unfortified
# 1708    11-737               Muffins, American, chocolate, retail
# 1684    11-848                                 Mince pies, retail
# 1652    12-512                          Milk, 1% fat, pasteurised
# 1654    12-322               Milk, Channel islands, whole, summer
# 1671    12-307                Milk, skimmed, pasteurised, average
# 1665    12-313           Milk, semi-skimmed, pasteurised, average
# 1677    12-596                  Milk, whole, pasteurised, average
# 1656    12-520                  Milk, condensed, whole, sweetened
# 1658    12-522                            Milk, evaporated, whole
# 1676    12-524  Milk, soya, non-dairy alternative to milk, uns...
# 1643    12-517                                 Meringue, homemade
# ...

# %%
Red22 = pd.concat([Red21,PAA], axis=0, join='inner')
Red22
# Out:
#      Food Code                                          Food Name  \
# 1594    11-954                          Macaroni cheese, homemade
# 1706    11-780                   Muesli, Swiss style, unfortified
# 1708    11-737               Muffins, American, chocolate, retail
# 1684    11-848                                 Mince pies, retail
# 1652    12-512                          Milk, 1% fat, pasteurised
# 1654    12-322               Milk, Channel islands, whole, summer
# 1671    12-307                Milk, skimmed, pasteurised, average
# 1665    12-313           Milk, semi-skimmed, pasteurised, average
# 1677    12-596                  Milk, whole, pasteurised, average
# 1656    12-520                  Milk, condensed, whole, sweetened
# 1658    12-522                            Milk, evaporated, whole
# 1676    12-524  Milk, soya, non-dairy alternative to milk, uns...
# 1643    12-517                                 Meringue, homemade
# ...

# %%
Red23 = pd.concat([Red22,Filt_SC], axis=0, join='inner')
Red23
# Out:
#      Food Code                                          Food Name  \
# 1594    11-954                          Macaroni cheese, homemade
# 1706    11-780                   Muesli, Swiss style, unfortified
# 1708    11-737               Muffins, American, chocolate, retail
# 1684    11-848                                 Mince pies, retail
# 1652    12-512                          Milk, 1% fat, pasteurised
# 1654    12-322               Milk, Channel islands, whole, summer
# 1671    12-307                Milk, skimmed, pasteurised, average
# 1665    12-313           Milk, semi-skimmed, pasteurised, average
# 1677    12-596                  Milk, whole, pasteurised, average
# 1656    12-520                  Milk, condensed, whole, sweetened
# 1658    12-522                            Milk, evaporated, whole
# 1676    12-524  Milk, soya, non-dairy alternative to milk, uns...
# 1643    12-517                                 Meringue, homemade
# ...

# %%
Red24 = pd.concat([Red23,SEA], axis=0, join='inner')
Red24
# Out:
#      Food Code                                          Food Name  \
# 1594    11-954                          Macaroni cheese, homemade
# 1706    11-780                   Muesli, Swiss style, unfortified
# 1708    11-737               Muffins, American, chocolate, retail
# 1684    11-848                                 Mince pies, retail
# 1652    12-512                          Milk, 1% fat, pasteurised
# 1654    12-322               Milk, Channel islands, whole, summer
# 1671    12-307                Milk, skimmed, pasteurised, average
# 1665    12-313           Milk, semi-skimmed, pasteurised, average
# 1677    12-596                  Milk, whole, pasteurised, average
# 1656    12-520                  Milk, condensed, whole, sweetened
# 1658    12-522                            Milk, evaporated, whole
# 1676    12-524  Milk, soya, non-dairy alternative to milk, uns...
# 1643    12-517                                 Meringue, homemade
# ...

# %%
Red25 = pd.concat([Red24,SEC], axis=0, join='inner')
Red25
# Out:
#      Food Code                                          Food Name  \
# 1594    11-954                          Macaroni cheese, homemade
# 1706    11-780                   Muesli, Swiss style, unfortified
# 1708    11-737               Muffins, American, chocolate, retail
# 1684    11-848                                 Mince pies, retail
# 1652    12-512                          Milk, 1% fat, pasteurised
# 1654    12-322               Milk, Channel islands, whole, summer
# 1671    12-307                Milk, skimmed, pasteurised, average
# 1665    12-313           Milk, semi-skimmed, pasteurised, average
# 1677    12-596                  Milk, whole, pasteurised, average
# 1656    12-520                  Milk, condensed, whole, sweetened
# 1658    12-522                            Milk, evaporated, whole
# 1676    12-524  Milk, soya, non-dairy alternative to milk, uns...
# 1643    12-517                                 Meringue, homemade
# ...

# %%
Red26 = pd.concat([Red25,Filt_WCG], axis=0, join='inner')
Red26
# Out:
#      Food Code                                          Food Name  \
# 1594    11-954                          Macaroni cheese, homemade
# 1706    11-780                   Muesli, Swiss style, unfortified
# 1708    11-737               Muffins, American, chocolate, retail
# 1684    11-848                                 Mince pies, retail
# 1652    12-512                          Milk, 1% fat, pasteurised
# 1654    12-322               Milk, Channel islands, whole, summer
# 1671    12-307                Milk, skimmed, pasteurised, average
# 1665    12-313           Milk, semi-skimmed, pasteurised, average
# 1677    12-596                  Milk, whole, pasteurised, average
# 1656    12-520                  Milk, condensed, whole, sweetened
# 1658    12-522                            Milk, evaporated, whole
# 1676    12-524  Milk, soya, non-dairy alternative to milk, uns...
# 1643    12-517                                 Meringue, homemade
# ...

# %%
Red27 = pd.concat([Red26,Filt_WY], axis=0, join='inner')
Red27
# Out:
#      Food Code                                          Food Name  \
# 1594    11-954                          Macaroni cheese, homemade
# 1706    11-780                   Muesli, Swiss style, unfortified
# 1708    11-737               Muffins, American, chocolate, retail
# 1684    11-848                                 Mince pies, retail
# 1652    12-512                          Milk, 1% fat, pasteurised
# 1654    12-322               Milk, Channel islands, whole, summer
# 1671    12-307                Milk, skimmed, pasteurised, average
# 1665    12-313           Milk, semi-skimmed, pasteurised, average
# 1677    12-596                  Milk, whole, pasteurised, average
# 1656    12-520                  Milk, condensed, whole, sweetened
# 1658    12-522                            Milk, evaporated, whole
# 1676    12-524  Milk, soya, non-dairy alternative to milk, uns...
# 1643    12-517                                 Meringue, homemade
# ...

# %% [markdown]
#                                                        Export

# %%
Red27.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced_M.csv')
