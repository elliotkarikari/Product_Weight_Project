# %% [markdown]
# # Product Weighting Project

# %% [markdown]
#                                          Data Reduction - Food Purchased In Store

# %% [markdown]
# ###### Import Necessary Libraries

# %%
import pandas as pd

# %% [markdown]
# Read in Data

# %%
Labelled = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Labelling2021_watercress.csv')

# %% [markdown]
# ### Products beginning with a 'M'

# %%
Prod_M = Labelled.loc[Labelled['Food Name'].str.startswith('M')]
Prod_M
# Out:
#      Food Code                      Food Name  \
# 1593    14-891         Macadamia nuts, salted
# 1594    11-954      Macaroni cheese, homemade
# 1595    12-951             Macaroon, homemade
# 1596    13-834                   Mace, ground
# 1597    16-394  Mackerel, flesh only, grilled
# ...        ...                            ...
# 1742    17-362                 Mustard powder
# 1743    13-839                  Mustard seeds
# 1744    17-363       Mustard, powder, made up
# 1745    17-364                Mustard, smooth
# 1746    17-365            Mustard, wholegrain
#
#                                            Description Group  \
# 1593                                         8 samples     G
# 1594                                            Recipe    AD
# 1595                                            Recipe   CDH
# 1596                                Literature sources     H
# 1597         7 samples, 7 products, frozen and chilled    JC
# ...

# %% [markdown]
# Products within a Group (provide identification of the food group and food type to which the food belongs)

# %%
Prod_M.groupby('Group')['Food Name'].count()
# Out:
# Group
# AD      1
# AF      2
# AI      2
# AM      1
# AN      3
# AP      4
# AS      1
# BA      1
# BAB     3
# BAE     4
# BAH     4
# BAK     4
# BAR     7
# BC      7
# BH      4
# BR      4
# CDH     1
# DG     22
# DI      1
# DR      4
# FA     23
# G       1
# GA      3
# H       7
# JA      9
# JC      4
# JM      3
# MI      1
# MR      5
# PAA     1
# S       1
# SC      3
# SEA     3
# SEC     1
# WC      2
# WCG     2
# WCN     1
# WY      4
# Name: Food Name, dtype: int64

# %% [markdown]
# ## *Reducing products based on its most basic form. Improve as you go on*

# %% [markdown]
#                                                 Cereals and cereal products

# %% [markdown]
# Pasta

# %%
AD = Prod_M.loc[Prod_M['Group']== 'AD']
AD
# Out:
#      Food Code                  Food Name Description Group Previous  \
# 1594    11-954  Macaroni cheese, homemade      Recipe    AD  11-562
#
#               Main data references Footnote Energy (kJ) Energy (kcal)  \
# 1594  As MW6. Recalculated in 2013      NaN         768           183
#
#       Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1594      8.6          4.47               18        2.7       15.4       1.1
#
#       Protein (g) Salt (g)
# 1594          7.9     0.37

# %%
AD['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\646763092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AD['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Removed AF - Breads

# %% [markdown]
# Breakfast cereals

# %%
AI = Prod_M.loc[Prod_M['Group']== 'AI']
AI
# Out:
#      Food Code                                          Food Name  \
# 1705    11-781  Muesli, Swiss style, no added sugar or salt, u...
# 1706    11-780                   Muesli, Swiss style, unfortified
#
#                                             Description Group        Previous  \
# 1705  6 samples, 5 products, including Jordans Natur...    AI         11-495
# 1706  11 samples, 9 products, including Alpen and ow...    AI  11-494 11-369
#
#                                  Main data references Footnote Energy (kJ)  \
# 1705  LGC, Nutrient survey of breakfast cereals, 2004      NaN        1575
# 1706  LGC, Nutrient survey of breakfast cereals, 2004      NaN        1617
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1705           373      5.9          1.19             65.3       12.8
# 1706           383      6.3          1.27             67.4       20.8
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_AI = AI[AI['Food Name'] == 'Muesli, Swiss style, unfortified']
Filt_AI
# Out:
#      Food Code                         Food Name  \
# 1706    11-780  Muesli, Swiss style, unfortified
#
#                                             Description Group        Previous  \
# 1706  11 samples, 9 products, including Alpen and ow...    AI  11-494 11-369
#
#                                  Main data references Footnote Energy (kJ)  \
# 1706  LGC, Nutrient survey of breakfast cereals, 2004      NaN        1617
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1706           383      6.3          1.27             67.4       20.8
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1706       46.6       8.8          9.9     0.35

# %%
Filt_AI['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\2672708786.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AI['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Removed AM - Biscuits

# %% [markdown]
# Cakes

# %%
AN = Prod_M.loc[Prod_M['Group']== 'AN']
AN
# Out:
#      Food Code                                          Food Name  \
# 1707   11-1094  Muffins, American style, chocolate chip, homemade
# 1708    11-737               Muffins, American, chocolate, retail
# 1709    11-738           Muffins, American, not chocolate, retail
#
#                                             Description Group Previous  \
# 1707                                             Recipe    AN  11-608
# 1708                             10 samples, 9 products    AN      NaN
# 1709  10 samples, 10 products, including blueberry, ...    AN      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1707             Based on generic recpe'.  Updated 2014      NaN        1617
# 1708  Direct Laboratories, Nutrient analysis catch u...      NaN        1839
# 1709  Direct Laboratories, Nutrient analysis catch u...      NaN        1591
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_AN = AN[AN['Food Name'] == 'Muffins, American, chocolate, retail']
Filt_AN
# Out:
#      Food Code                             Food Name             Description  \
# 1708    11-737  Muffins, American, chocolate, retail  10 samples, 9 products
#
#      Group Previous                               Main data references  \
# 1708    AN      NaN  Direct Laboratories, Nutrient analysis catch u...
#
#      Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 1708      NaN        1839           440     25.4          4.83
#
#      Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1708             46.4       29.5       16.7         1          6.1     0.99

# %%
Filt_AN['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\569209402.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AN['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Buns and Pastries

# %% [markdown]
# Removed AP

# %% [markdown]
# Puddings

# %%
AS = Prod_M.loc[Prod_M['Group']== 'AS']
AS
# Out:
#      Food Code           Food Name             Description Group Previous  \
# 1684    11-848  Mince pies, retail  10 samples, 8 products    AS      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1684  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1632
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1684           389     14.9          5.97             58.1       35.2
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1684       22.9       2.6          4.3     0.25

# %%
AS['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\2859841636.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AS['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
#                                                    Milk and milk products

# %% [markdown]
# Cow milk

# %%
BA = Prod_M.loc[Prod_M['Group']== 'BA']
BA
# Out:
#      Food Code                  Food Name  \
# 1652    12-512  Milk, 1% fat, pasteurised
#
#                                             Description Group Previous  \
# 1652  Average of skimmed (12-307) and semi-skimmed (...    BA      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1652  ADAS Laboratories, Nutrient analysis of pasteu...      NaN         173
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1652            41      1.0           0.6              4.6        4.6
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1652          0         0          3.4     0.11

# %%
BA['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\2739075003.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BA['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Breakfast Milk

# %%
BAB = Prod_M.loc[Prod_M['Group']== 'BAB']
BAB
# Out:
#      Food Code                                  Food Name  \
# 1653    12-321  Milk, Channel Islands, whole, pasteurised
# 1654    12-322       Milk, Channel islands, whole, summer
# 1655    12-323       Milk, Channel islands, whole, winter
#
#                                             Description Group  \
# 1653  Breakfast milk, average of 6 samples of summer...   BAB
# 1654                                          3 samples   BAB
# 1655                                          3 samples   BAB
#
#                    Previous  \
# 1653  12-885 12-078 50-194
# 1654         12-019 50-195
# 1655         12-019 50-195
#
#                                    Main data references Footnote Energy (kJ)  \
# 1653  Reviewed 2013. LGC, Nutrient analysis of ‘othe...      NaN         303
# 1654  LGC, Nutrient analysis of ‘other’ milk and cre...      NaN         305
# 1655  LGC, Nutrient analysis of ‘other’ milk and cre...      NaN         298
#
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_BAB = BAB.loc[BAB['Food Name'] == 'Milk, Channel islands, whole, summer']
Filt_BAB
# Out:
#      Food Code                             Food Name Description Group  \
# 1654    12-322  Milk, Channel islands, whole, summer   3 samples   BAB
#
#             Previous                               Main data references  \
# 1654  12-019 50-195   LGC, Nutrient analysis of ‘other’ milk and cre...
#
#      Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 1654      NaN         305            73      4.7          2.99
#
#      Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1654              3.9        3.9          0         0          3.8      0.1

# %%
Filt_BAB['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\2247885743.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_BAB['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Skimmed milk

# %%
BAE = Prod_M.loc[Prod_M['Group']== 'BAE']
BAE
# Out:
#      Food Code                            Food Name  \
# 1671    12-307  Milk, skimmed, pasteurised, average
# 1672    12-308   Milk, skimmed, pasteurised, summer
# 1673    12-309   Milk, skimmed, pasteurised, winter
# 1674    12-554                   Milk, skimmed, UHT
#
#                                             Description Group  \
# 1671  Average of summer and winter milk. Samples fro...   BAE
# 1672  Average of glass bottles, plastic containers a...   BAE
# 1673  Average of glass bottles, plastic containers a...   BAE
# 1674  22 samples, summer (June/Sep) and winter (Jan/...   BAE
#
#                       Previous  \
# 1671    12-002 12-831 50-182
# 1672  12-002 84 12-831 50-182
# 1673  12-002 84 12-831 50-182
# 1674            12-310 12-004
#
#                                    Main data references Footnote Energy (kJ)  \
# 1671  Reviewed 2013. ADAS Laboratory Services, Nutri...      NaN         147
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_BAE = BAE.loc[BAE['Food Name'] == 'Milk, skimmed, pasteurised, average']
Filt_BAE
# Out:
#      Food Code                            Food Name  \
# 1671    12-307  Milk, skimmed, pasteurised, average
#
#                                             Description Group  \
# 1671  Average of summer and winter milk. Samples fro...   BAE
#
#                     Previous  \
# 1671  12-002 12-831 50-182
#
#                                    Main data references Footnote Energy (kJ)  \
# 1671  Reviewed 2013. ADAS Laboratory Services, Nutri...      NaN         147
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1671            35      0.3          0.13              4.6        4.6
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1671          0         0          3.4     0.11

# %%
Filt_BAE['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\540732809.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_BAE['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Semi-skimmed milk

# %%
BAH = Prod_M.loc[Prod_M['Group']== 'BAH']
BAH
# Out:
#      Food Code                                          Food Name  \
# 1665    12-313           Milk, semi-skimmed, pasteurised, average
# 1666    12-418  Milk, semi-skimmed, pasteurised, summer and au...
# 1667    12-419  Milk, semi-skimmed, pasteurised, winter and sp...
# 1668    12-314                            Milk, semi-skimmed, UHT
#
#                                             Description Group  \
# 1665  Average of summer/autumn and winter/spring mil...   BAH
# 1666                Samples taken in June and September   BAH
# 1667                 Samples taken in January and March   BAH
# 1668           22 samples, average of winter and summer   BAH
#
#                    Previous  \
# 1665  12-009 12-832 50-186
# 1666  12-009 12-832 50-186
# 1667  12-009 12-832 50-186
# 1668  12-011 40-130 50-188
#
#                                    Main data references Footnote Energy (kJ)  \
# 1665  Reviewed 2013. ADAS Laboratory Services, Nutri...      NaN         196
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_BAH = BAH.loc[BAH['Food Name'] == 'Milk, semi-skimmed, pasteurised, average']
Filt_BAH
# Out:
#      Food Code                                 Food Name  \
# 1665    12-313  Milk, semi-skimmed, pasteurised, average
#
#                                             Description Group  \
# 1665  Average of summer/autumn and winter/spring mil...   BAH
#
#                    Previous  \
# 1665  12-009 12-832 50-186
#
#                                    Main data references Footnote Energy (kJ)  \
# 1665  Reviewed 2013. ADAS Laboratory Services, Nutri...      NaN         196
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1665            47      1.7          1.07              4.5        4.5
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1665          0         0          3.4     0.11

# %%
Filt_BAH['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4144\1128413593.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_BAH['Super Group'] = 'Milk and milk products'

# %% [markdown]
#                                                         Vegetables

# %% [markdown]
# Beans and lentils

# %%
DB = Prod_L.loc[Prod_L['Group']== 'DB']
DB
# Out:
#      Food Code                                          Food Name  \
# 1548    13-661  Lentils, green and brown, whole, dried, boiled...
# 1549    13-089        Lentils, green and brown, whole, dried, raw
# 1550    13-658  Lentils, red, split, dried, boiled in unsalted...
# 1551    13-657                    Lentils, red, split, dried, raw
#
#                                             Description Group Previous  \
# 1548  11 samples, 10 products, soaked and boiled for...    DB   13-090
# 1549             10 samples, 6 brands. Continental type    DB  50-710
# 1550  10 samples, 10 products, boiled for 15-40 minutes    DB   13-434
# 1551              10 samples, 10 products, as purchased    DB   13-091
#
#                                    Main data references Footnote Energy (kJ)  \
# 1548  PHE, Nutrient analysis of fresh and processed ...      NaN         441
# 1549               LGC, Fruit and Vegetables, 1989-1990      NaN        1263
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_DB = DB[DB['Food Name'] == 'Lentils, green and brown, whole, dried, raw']
Filt_DB
# Out:
#      Food Code                                    Food Name  \
# 1549    13-089  Lentils, green and brown, whole, dried, raw
#
#                                  Description Group Previous  \
# 1549  10 samples, 6 brands. Continental type    DB  50-710
#
#                       Main data references Footnote Energy (kJ) Energy (kcal)  \
# 1549  LGC, Fruit and Vegetables, 1989-1990      NaN        1263           299
#
#       Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1549      1.9           0.2             41.6        1.1       40.5      17.3
#
#       Protein (g) Salt (g)
# 1549         24.4     0.03

# %%
Filt_DB['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11660\2223481409.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DB['Super Group'] = 'Vegetables'

# %% [markdown]
# Vegetables, general

# %%
DG = Prod_L.loc[Prod_L['Group']== 'DG']
DG
# Out:
#      Food Code                        Food Name  \
# 1520    13-625  Leeks, boiled in unsalted water
# 1521    13-624                       Leeks, raw
# 1522    13-626   Leeks, roasted in rapeseed oil
# 1552    13-520            Lettuce, average, raw
# 1588    13-271                Lotus tubers, raw
#
#                                             Description Group Previous  \
# 1520  11 samples, UK, trimmed and damaged outer leav...    DG   13-452
# 1521  11 samples, UK, trimmed and damaged outer leav...    DG   13-466
# 1522  Calculated from raw. Water and fat analysed, 2...    DG      NaN
# 1552  22 samples, autumn and winter, UK grown and im...    DG  13-453
# 1588                                 Literature sources    DG      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1520  PHE, Nutrient analysis of fresh and processed ...      NaN          85
# 1521  PHE, Nutrient analysis of fresh and processed ...      NaN         124
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_DG = ['Leeks, raw','Lettuce, average, raw','Lotus tubers, raw']

# %%
Filt_DG = DG[DG['Food Name'].isin(Priority_DG)]
Filt_DG
# Out:
#      Food Code              Food Name  \
# 1521    13-624             Leeks, raw
# 1552    13-520  Lettuce, average, raw
# 1588    13-271      Lotus tubers, raw
#
#                                             Description Group Previous  \
# 1521  11 samples, UK, trimmed and damaged outer leav...    DG   13-466
# 1552  22 samples, autumn and winter, UK grown and im...    DG  13-453
# 1588                                 Literature sources    DG      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1521  PHE, Nutrient analysis of fresh and processed ...      NaN         124
# 1552  DH, Nutrient analysis of fruit and vegetables,...      NaN          60
# 1588      Vegetables, Herbs and Spices Supplement, 1991      NaN         258
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1521            30      0.2          0.04              4.1        3.8
# ...

# %%
Filt_DG['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11660\1311392366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DG['Super Group'] = 'Vegetables'

# %% [markdown]
# Vegetable dishes

# %%
DR = Prod_L.loc[Prod_L['Group']== 'DR']
DR
# Out:
#      Food Code                                          Food Name  \
# 1512    15-186              Lasagne, spinach, wholemeal, homemade
# 1513    15-651                         Lasagne, vegetable, retail
# 1514    15-188            Lasagne, vegetable, wholemeal, homemade
# 1516    15-190                                         Laverbread
# 1517    15-813  Leeks in cheese sauce, made with semi-skimmed ...
# 1518    15-814  Leeks in cheese sauce, made with skimmed milk,...
# 1519    15-815  Leeks in cheese sauce, made with whole milk, h...
# 1539    15-200                     Lentil and nut roast, homemade
# 1540    15-201           Lentil and nut roast, with egg, homemade
# 1541    15-817                    Lentil and potato pie, homemade
# 1542    15-818                    Lentil and rice roast, homemade
# 1543    15-819          Lentil and rice roast, with egg, homemade
# 1544    15-820   Lentil cutlets, fried in vegetable oil, homemade
# ...

# %%
DR['Food Name'].unique()
# Out:
# array(['Lasagne, spinach, wholemeal, homemade',
#        'Lasagne, vegetable, retail',
#        'Lasagne, vegetable, wholemeal, homemade', 'Laverbread',
#        'Leeks in cheese sauce, made with semi-skimmed milk, homemade',
#        'Leeks in cheese sauce, made with skimmed milk, homemade',
#        'Leeks in cheese sauce, made with whole milk, homemade',
#        'Lentil and nut roast, homemade',
#        'Lentil and nut roast, with egg, homemade',
#        'Lentil and potato pie, homemade',
#        'Lentil and rice roast, homemade',
#        'Lentil and rice roast, with egg, homemade',
#        'Lentil cutlets, fried in vegetable oil, homemade',
#        'Lentil pie, homemade', 'Lentil roast, homemade',
#        'Lentil roast, with egg, homemade'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Filt_DR = DR[DR['Food Name'] == 'Lasagne, vegetable, retail']
Filt_DR
# Out:
#      Food Code                   Food Name  \
# 1513    15-651  Lasagne, vegetable, retail
#
#                                             Description Group Previous  \
# 1513  8 assorted samples; cooked in conventional and...    DR  15-189
#
#                                    Main data references Footnote Energy (kJ)  \
# 1513  LGC, Fruit and vegetables, 1989-1990; and indu...      NaN           N
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1513             N      5.3             N             12.4        4.3
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1513        8.2         N          4.8     0.53

# %%
Filt_DR['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11660\2508077319.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DR['Super Group'] = 'Vegetables'

# %% [markdown]
#                                                            Fruit

# %% [markdown]
# Fruit, general

# %%
FA = Prod_L.loc[Prod_L['Group']== 'FA']
FA
# Out:
#      Food Code                                          Food Name  \
# 1528    14-337                                         Lemon peel
# 1536    14-130  Lemons, flesh only, raw, weighed with peel and...
# 1537    14-129                         Lemons, peeled, flesh only
# 1538    14-128                        Lemons, whole, without pips
# 1556    14-131                                  Limes, flesh only
# 1557    14-132      Limes, flesh only, weighed with peel and pips
# 1579    14-133                                  Loganberries, raw
# 1580    14-134                    Loganberries, stewed with sugar
# 1581    14-135                 Loganberries, stewed without sugar
# 1584    14-138                  Longans, canned in syrup, drained
# 1585    14-139           Longans, canned in syrup, whole contents
# 1586    14-137                         Longans, flesh only, dried
# 1587    14-140                           Loquats, flesh only, raw
# ...

# %%
FA['Food Name'].unique()
# Out:
# array(['Lemon peel',
#        'Lemons, flesh only, raw, weighed with peel and pips',
#        'Lemons, peeled, flesh only', 'Lemons, whole, without pips',
#        'Limes, flesh only',
#        'Limes, flesh only, weighed with peel and pips',
#        'Loganberries, raw', 'Loganberries, stewed with sugar',
#        'Loganberries, stewed without sugar',
#        'Longans, canned in syrup, drained',
#        'Longans, canned in syrup, whole contents',
#        'Longans, flesh only, dried', 'Loquats, flesh only, raw',
#        'Lychees, flesh only, raw, weighed with skin and stone',
#        'Lychees, raw, flesh only'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_FA = ['Lemons, whole, without pips','Limes, flesh only','Loganberries, raw',]

# %%
Filt_FA = FA[FA['Food Name'].isin(Priority_FA)]
Filt_FA
# Out:
#      Food Code                    Food Name  \
# 1538    14-128  Lemons, whole, without pips
# 1556    14-131            Limes, flesh only
# 1579    14-133            Loganberries, raw
#
#                                             Description Group Previous  \
# 1538  Includes peel but no pips. Analysis and litera...    FA  50-910
# 1556                                Literature sources;    FA      NaN
# 1579                                        Whole fruit    FA      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1538     Reviewed 2013. Fruit and Nuts Supplement, 1992      NaN         181
# 1556                    Fruit and Nuts Supplement, 1992      NaN         121
# 1579  MW4, 1978. Values revised for Fruit and Nuts S...      NaN         152
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1538            43      0.3           0.1              3.2        3.2
# ...

# %%
Filt_FA['Super Group'] = 'Fruit'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11660\3797725470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_FA['Super Group'] = 'Fruit'

# %% [markdown]
# Fruit juices

# %%
FC = Prod_L.loc[Prod_L['Group']== 'FC']
FC
# Out:
#      Food Code                                   Food Name  \
# 1527    14-278  Lemon juice, fresh, weighed as whole fruit
# 1555    14-279                           Lime juice, fresh
#
#                  Description Group Previous  \
# 1527  Calculated from 14-277    FC      NaN
# 1555      Literature sources    FC      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1527  MW4, 1978. Values reviewed and revised for Fru...      NaN          33
# 1555  Gebhardt et al. (1982) Composition of foods: f...      NaN          94
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1527             8      0.0             0              0.6        0.6
# 1555            22      0.1             0              1.6        1.6
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1527          0       0.1          0.1        0
# 1555          0       0.4          0.4        0

# %%
FC['Food Name'].unique()
# Out:
# array(['Lemon juice, fresh, weighed as whole fruit', 'Lime juice, fresh'],
#       dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_FC = ['Lemon juice, fresh, weighed as whole fruit']

# %%
Filt_FC = FC[FC['Food Name'].isin(Priority_FC)]
Filt_FC
# Out:
#      Food Code                                   Food Name  \
# 1527    14-278  Lemon juice, fresh, weighed as whole fruit
#
#                  Description Group Previous  \
# 1527  Calculated from 14-277    FC      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1527  MW4, 1978. Values reviewed and revised for Fru...      NaN          33
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1527             8      0.0             0              0.6        0.6
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1527          0       0.1          0.1        0

# %%
Filt_FC['Super Group'] = 'Fruit'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11660\1834057886.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_FC['Super Group'] = 'Fruit'

# %% [markdown]
# Removed H

# %% [markdown]
#                                                 Fish and fish products

# %% [markdown]
# Removed JA

# %% [markdown]
# Crustacea

# %%
JK = Prod_L.loc[Prod_L['Group']== 'JK']
JK
# Out:
#      Food Code                            Food Name  \
# 1507    16-425                  Langoustine, boiled
# 1577    16-332                      Lobster, boiled
# 1578    16-343  Lobster, boiled, weighed with shell
#
#                                        Description Group        Previous  \
# 1507  Small, medium and large from 3 fishing areas    JK             NaN
# 1577                         Boiled in fresh water    JK  16-236 50-637
# 1578                 Calculated from boiled 16-332    JK  16-237 50-638
#
#                                    Main data references Footnote Energy (kJ)  \
# 1507  DH, Nutrient analysis of fish and fish product...      NaN         364
# 1577  Fish and Fish Products Supplement, 1993; selen...      NaN         435
# 1578  Fish and Fish Products Supplement, 1993; selen...      NaN         157
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1507            86      0.8          0.15                0          0
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_JK = JK[JK['Food Name'] == 'Lobster, boiled']
Filt_JK
# Out:
#      Food Code        Food Name            Description Group        Previous  \
# 1577    16-332  Lobster, boiled  Boiled in fresh water    JK  16-236 50-637
#
#                                    Main data references Footnote Energy (kJ)  \
# 1577  Fish and Fish Products Supplement, 1993; selen...      NaN         435
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1577           103      1.6           0.2                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1577          0         0         22.1     0.83

# %%
Filt_JK['Super Group'] = 'Fish and fish products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11660\3956454164.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_JK['Super Group'] = 'Fish and fish products'

# %% [markdown]
#                                             Meat and meat products

# %% [markdown]
# Lamb

# %%
MAE = Prod_L.loc[Prod_L['Group']== 'MAE']
MAE
# Out:
#      Food Code                                          Food Name  \
# 1399    18-478                   Lamb, average, raw, lean and fat
# 1400    18-103       Lamb, best end neck cutlets, barbecued, lean
# 1401    18-105  Lamb, best end neck cutlets, barbecued, lean a...
# 1402    18-106  Lamb, best end neck cutlets, barbecued, lean a...
# 1403    18-104  Lamb, best end neck cutlets, barbecued, lean, ...
# ...        ...                                                ...
# 1500    18-185       Lamb, stewing, pressure cooked, lean and fat
# 1501    18-182                   Lamb, stewing, raw, lean and fat
# 1502    18-183  Lamb, stewing, raw, lean and fat, weighed with...
# 1503    18-186                        Lamb, stewing, stewed, lean
# 1504    18-187                Lamb, stewing, stewed, lean and fat
#
#                                Description Group         Previous  \
# 1399  Calculated from 83% lean and 17% fat   MAE  18-123 50-404
# ...

# %% [markdown]
# **Reduced**

# %%
for c in MAE['Food Name']:
    print(c)
# Out:
# Lamb, average, raw, lean and fat
# Lamb, best end neck cutlets, barbecued, lean
# Lamb, best end neck cutlets, barbecued, lean and fat
# Lamb, best end neck cutlets, barbecued, lean and fat, weighed with bone
# Lamb, best end neck cutlets, barbecued, lean, weighed with fat and bone
# Lamb, best end neck cutlets, grilled, lean
# Lamb, best end neck cutlets, grilled, lean and fat
# Lamb, best end neck cutlets, grilled, lean and fat, weighed with bone
# Lamb, best end neck cutlets, grilled, lean, weighed with fat and bone
# Lamb, best end neck cutlets, raw, lean and fat
# Lamb, best end neck cutlets, raw, lean and fat, weighed with bone
# Lamb, breast, raw, lean
# Lamb, breast, raw, lean and fat
# Lamb, breast, roasted, lean
# Lamb, breast, roasted, lean and fat
# Lamb, chump chops, fried, lean
# Lamb, chump chops, fried, lean and fat
# Lamb, chump chops, fried, lean and fat, weighed with bone
# Lamb, chump chops, fried, lean, weighed with fat and bone
# ...

# %%
Priority_MAE = ['Lamb, average, raw, lean and fat','Lamb, breast, raw, lean','Lamb, chump chops, raw, lean and fat','Lamb, mince, raw']

# %%
Filt_MAE = MAE[MAE['Food Name'].isin(Priority_MAE)]
Filt_MAE
# Out:
#      Food Code                             Food Name  \
# 1399    18-478      Lamb, average, raw, lean and fat
# 1410    18-111               Lamb, breast, raw, lean
# 1418    18-115  Lamb, chump chops, raw, lean and fat
# 1461    18-481                      Lamb, mince, raw
#
#                                Description Group         Previous  \
# 1399  Calculated from 83% lean and 17% fat   MAE  18-123 50-404
# 1410                            10 samples   MAE              NaN
# 1418  Calculated from 77% lean and 23% fat   MAE              NaN
# 1461                            10 samples   MAE          18-158
#
#                                    Main data references Footnote Energy (kJ)  \
# 1399  Reviewed 2013. LGC, Nutrient analysis of retai...      NaN         779
# 1410  LGC, Nutrient analysis of retail cuts of lamb,...      NaN         748
# 1418  LGC, Nutrient analysis of retail cuts of lamb,...      NaN        1006
# ...

# %%
Filt_MAE['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11660\2487956584.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_MAE['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Offal

# %%
MG = Prod_L.loc[Prod_L['Group']== 'MG']
MG
# Out:
#      Food Code                          Food Name  \
# 1567    18-410     Liver, calf, fried in corn oil
# 1568    18-409                   Liver, calf, raw
# 1569    18-412  Liver, chicken, fried in corn oil
# 1570    18-411                Liver, chicken, raw
# 1571    18-494     Liver, lamb, fried in corn oil
# 1572    18-413                   Liver, lamb, raw
# 1573    18-415                     Liver, ox, raw
# 1574    18-416                  Liver, ox, stewed
# 1575    18-417                    Liver, pig, raw
# 1576    18-418                 Liver, pig, stewed
#
#                                Description Group        Previous  \
# 1567                            10 samples    MG         50-484
# 1568                            10 samples    MG         50-483
# 1569                            10 samples    MG         50-486
# 1570                            10 samples    MG  50-485 18-441
# 1571                            10 samples    MG  18-414 50-488
# ...

# %%
MG['Food Name'].unique()
# Out:
# array(['Liver, calf, fried in corn oil', 'Liver, calf, raw',
#        'Liver, chicken, fried in corn oil', 'Liver, chicken, raw',
#        'Liver, lamb, fried in corn oil', 'Liver, lamb, raw',
#        'Liver, ox, raw', 'Liver, ox, stewed', 'Liver, pig, raw',
#        'Liver, pig, stewed'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Filt_MG = MG.loc[MG['Food Name']== 'Liver, lamb, raw']
Filt_MG
# Out:
#      Food Code         Food Name Description Group        Previous  \
# 1572    18-413  Liver, lamb, raw  10 samples    MG  50-487 18-442
#
#                                    Main data references Footnote Energy (kJ)  \
# 1572  LGC, Carcase meat and offal survey, 1982-1983;...      NaN         575
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1572           137      6.2           1.7                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1572          0         0         20.3     0.18

# %%
Filt_MG['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11660\297719860.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_MG['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Meat products

# %%
MI = Prod_L.loc[Prod_L['Group']== 'MI']
MI
# Out:
#      Food Code                        Food Name  \
# 1566    19-106                    Liver sausage
# 1590    19-136  Luncheon meat, Chinese, steamed
#
#                                             Description Group Previous  \
# 1566                               10 samples, 4 brands    MI  50-514
# 1590  10 samples from different shops, steamed for 1...    MI      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1566  Reviewed 2013. Meat Products and Dishes Supple...      NaN         961
# 1590          Meat Products and Dishes Supplement, 1996      NaN        1097
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1566           231     16.7           5.3              5.5          1
# 1590           265     22.3           8.7              4.1          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1566        4.5       2.7         13.4     2.03
# 1590        4.1         0         11.9      1.7

# %%
MI['Food Name'].unique()
# Out:
# array(['Liver sausage', 'Luncheon meat, Chinese, steamed'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Filt_MI = MI.loc[MI['Food Name']== 'Luncheon meat, Chinese, steamed']
Filt_MI
# Out:
#      Food Code                        Food Name  \
# 1590    19-136  Luncheon meat, Chinese, steamed
#
#                                             Description Group Previous  \
# 1590  10 samples from different shops, steamed for 1...    MI      NaN
#
#                            Main data references Footnote Energy (kJ)  \
# 1590  Meat Products and Dishes Supplement, 1996      NaN        1097
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1590           265     22.3           8.7              4.1          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1590        4.1         0         11.9      1.7

# %%
Filt_MI['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11660\1350248321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_MI['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Removed MR

# %% [markdown]
#                                                       Fats and oils

# %%
OF = Prod_L.loc[Prod_L['Group']== 'OF']
OF
# Out:
#      Food Code Food Name          Description Group  Previous  \
# 1508    17-010      Lard  6 samples, 3 brands    OF  50-318
#
#                                    Main data references Footnote Energy (kJ)  \
# 1508  Reviewed 2013. MW1, 1940; Miscellaneous Foods ...      NaN        3663
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1508           891     99.0          40.3                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1508          0         0          0.0     0.01

# %%
OF['Super Group'] = 'Fats and oils'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11660\4089108550.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   OF['Super Group'] = 'Fats and oils'

# %% [markdown]
#                                                         Beverages

# %% [markdown]
# Soft Drinks

# %%
PCA = Prod_L.loc[Prod_L['Group']== 'PCA']
PCA
# Out:
#      Food Code Food Name                                    Description Group  \
# 1534    17-179  Lemonade                           10 samples, 8 brands   PCA
# 1589    17-761  Lucozade  Including lemon, orange and tropical flavours   PCA
#
#       Previous                               Main data references Footnote  \
# 1534  50-1081   Reviewed 2013. LFRA, Nutritional analysis of s...      NaN
# 1589   17-543       MSF supplement, 1994; and industry data, 2013      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 1534          96            23      0.0             0              5.7
# 1589         266            63      0.0             0             15.6
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1534        5.7          0         0          0.0     0.02
# 1589       11.1          0         0          0.0     0.07

# %%
PCA['Super Group'] = 'Beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11660\876566208.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PCA['Super Group'] = 'Beverages'

# %% [markdown]
# Removed PCC

# %% [markdown]
# Removed PE

# %% [markdown]
#                                                 Alcoholic beverages

# %%
QA = Prod_L.loc[Prod_L['Group']== 'QA']
QA
# Out:
#      Food Code            Food Name  \
# 1393    17-212  Lager, alcohol-free
# 1394    17-676  Lager, extra strong
# 1395    17-750   Lager, low alcohol
# 1396    17-751       Lager, premium
# 1397    17-749      Lager, standard
#
#                                             Description Group Previous  \
# 1393  10 samples, including Kaliber, Beck's Blue, Eq...    QA      NaN
# 1394  Approx. 9% ABV, including Carlsberg Special Br...    QA  17-214
# 1395  2-3% ABV. 10 samples, including  Bavaria Permi...    QA  17-213
# 1396  Approx. 5% ABV, 10 samples including Bitburger...    QA  17-211
# 1397  <4.5% ABV, canned and draught, including Skol,...    QA
#
#                                    Main data references Footnote Energy (kJ)  \
# 1393  Reviewed 2013. LFRA, Nutritional analysis of s...      NaN          27
# 1394  Estimated from premium lager (analytical data ...      NaN         251
# 1395  Estimated from standard lager and industry dat...      NaN          69
# ...

# %%
QA['Food Name'].unique()
# Out:
# array(['Lager, alcohol-free', 'Lager, extra strong', 'Lager, low alcohol',
#        'Lager, premium', 'Lager, standard'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_QA = ['Lager, premium']

# %%
Filt_QA = QA[QA['Food Name'].isin(Priority_QA)]
Filt_QA
# Out:
#      Food Code       Food Name  \
# 1396    17-751  Lager, premium
#
#                                             Description Group Previous  \
# 1396  Approx. 5% ABV, 10 samples including Bitburger...    QA  17-211
#
#                                    Main data references Footnote Energy (kJ)  \
# 1396  Estimated from standard lager and industry dat...      NaN         118
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1396            29      0.0             0                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1396          0         0          0.3     0.02

# %%
Filt_QA['Super Group'] = 'Beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11660\3546061937.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_QA['Super Group'] = 'Beverages'

# %% [markdown]
# Liqueurs

# %%
QI = Prod_L.loc[Prod_L['Group']== 'QI']
QI
# Out:
#      Food Code                      Food Name  \
# 1559    17-768                Liqueurs, cream
# 1560    17-244        Liqueurs, high strength
# 1561    17-245  Liqueurs, low-medium strength
#
#                                             Description Group Previous  \
# 1559  17% ABV, 2 samples of Baileys Original Irish C...    QI  17-242
# 1560  30-40% ABV. 5 samples including Pernod, Drambu...    QI      NaN
# 1561  20-28% ABV. 10 samples including cherry brandy...    QI      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1559  LGC, Alcoholic beverages, soft drinks and tea ...      NaN        1275
# 1560  Reviewed 2013. LGC, Alcoholic beverages, soft ...      NaN        1321
# 1561  Reviewed 2013. LGC, Alcoholic beverages, soft ...      NaN        1115
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1559           306     13.0           8.2             20.8       20.8
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_QI = QI[QI['Food Name'] == 'Liqueurs, high strength']
Filt_QI
# Out:
#      Food Code                Food Name  \
# 1560    17-244  Liqueurs, high strength
#
#                                             Description Group Previous  \
# 1560  30-40% ABV. 5 samples including Pernod, Drambu...    QI      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1560  Reviewed 2013. LGC, Alcoholic beverages, soft ...      NaN        1321
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1560           316      0.0             0             23.5       23.5
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1560          0         0          0.0     0.02

# %%
Filt_QI['Super Group'] = 'Beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11660\3133629212.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_QI['Super Group'] = 'Beverages'

# %% [markdown]
#                                             Sugars, preserves and snacks

# %% [markdown]
# Removed S

# %% [markdown]
# Removed SC

# %%
SEC = Prod_L.loc[Prod_L['Group']== 'SEC']
SEC
# Out:
#      Food Code           Food Name          Description Group Previous  \
# 1562    17-777  Liquorice allsorts  7 samples, 4 brands   SEC  17-112
#
#                                    Main data references Footnote Energy (kJ)  \
# 1562  Reviewed 2013. LGC, Nutritional analysis of fo...      NaN        1433
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1562           339      5.2           3.6             68.4       59.8
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1562        8.5         2          3.7     0.14

# %%
SEC['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11660\382276731.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SEC['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
#                                               **Join Reduced Tables**

# %%
Red = pd.concat([BN,BP], axis=0, join='inner')
Red
# Out:
#      Food Code                       Food Name  \
# 1515    12-373                Lassi, sweetened
# 1582    12-390   Lollies, containing ice-cream
# 1583    12-389  Lollies, with real fruit juice
#
#                                   Description Group Previous  \
# 1515           5 samples, takeaway and retail    BN  12-892
# 1582                                3 samples    BP      NaN
# 1583  10 samples, 6 brands, assorted flavours    BP      NaN
#
#                                    Main data references  \
# 1515  Reviewed 2013. LGC, Nutrient analysis of ‘othe...
# 1582  Reviewed 2013. LGC, Nutritional analysis of fo...
# 1583  Reviewed 2013. ADAS Laboratories, Nutrient ana...
#
#                                                Footnote Energy (kJ)  \
# 1515  Yakult (fermented skimmed milk drink) contains...         276
# 1582                                                NaN         502
# 1583                                                NaN         316
#
# ...

# %%
Red2 = pd.concat([Red,Filt_DB], axis=0, join='inner')
Red2
# Out:
#      Food Code                                    Food Name  \
# 1515    12-373                             Lassi, sweetened
# 1582    12-390                Lollies, containing ice-cream
# 1583    12-389               Lollies, with real fruit juice
# 1549    13-089  Lentils, green and brown, whole, dried, raw
#
#                                   Description Group Previous  \
# 1515           5 samples, takeaway and retail    BN  12-892
# 1582                                3 samples    BP      NaN
# 1583  10 samples, 6 brands, assorted flavours    BP      NaN
# 1549   10 samples, 6 brands. Continental type    DB  50-710
#
#                                    Main data references  \
# 1515  Reviewed 2013. LGC, Nutrient analysis of ‘othe...
# 1582  Reviewed 2013. LGC, Nutritional analysis of fo...
# 1583  Reviewed 2013. ADAS Laboratories, Nutrient ana...
# 1549               LGC, Fruit and Vegetables, 1989-1990
#
# ...

# %%
Red3 = pd.concat([Red2,Filt_DG], axis=0, join='inner')
Red3
# Out:
#      Food Code                                    Food Name  \
# 1515    12-373                             Lassi, sweetened
# 1582    12-390                Lollies, containing ice-cream
# 1583    12-389               Lollies, with real fruit juice
# 1549    13-089  Lentils, green and brown, whole, dried, raw
# 1521    13-624                                   Leeks, raw
# 1552    13-520                        Lettuce, average, raw
# 1588    13-271                            Lotus tubers, raw
#
#                                             Description Group Previous  \
# 1515                     5 samples, takeaway and retail    BN  12-892
# 1582                                          3 samples    BP      NaN
# 1583            10 samples, 6 brands, assorted flavours    BP      NaN
# 1549             10 samples, 6 brands. Continental type    DB  50-710
# 1521  11 samples, UK, trimmed and damaged outer leav...    DG   13-466
# ...

# %%
Red4 = pd.concat([Red3,Filt_DR], axis=0, join='inner')
Red4
# Out:
#      Food Code                                    Food Name  \
# 1515    12-373                             Lassi, sweetened
# 1582    12-390                Lollies, containing ice-cream
# 1583    12-389               Lollies, with real fruit juice
# 1549    13-089  Lentils, green and brown, whole, dried, raw
# 1521    13-624                                   Leeks, raw
# 1552    13-520                        Lettuce, average, raw
# 1588    13-271                            Lotus tubers, raw
# 1513    15-651                   Lasagne, vegetable, retail
#
#                                             Description Group Previous  \
# 1515                     5 samples, takeaway and retail    BN  12-892
# 1582                                          3 samples    BP      NaN
# 1583            10 samples, 6 brands, assorted flavours    BP      NaN
# 1549             10 samples, 6 brands. Continental type    DB  50-710
# ...

# %%
Red5 = pd.concat([Red4,Filt_FA], axis=0, join='inner')
Red5
# Out:
#      Food Code                                    Food Name  \
# 1515    12-373                             Lassi, sweetened
# 1582    12-390                Lollies, containing ice-cream
# 1583    12-389               Lollies, with real fruit juice
# 1549    13-089  Lentils, green and brown, whole, dried, raw
# 1521    13-624                                   Leeks, raw
# 1552    13-520                        Lettuce, average, raw
# 1588    13-271                            Lotus tubers, raw
# 1513    15-651                   Lasagne, vegetable, retail
# 1538    14-128                  Lemons, whole, without pips
# 1556    14-131                            Limes, flesh only
# 1579    14-133                            Loganberries, raw
#
#                                             Description Group Previous  \
# 1515                     5 samples, takeaway and retail    BN  12-892
# 1582                                          3 samples    BP      NaN
# ...

# %%
Red6 = pd.concat([Red5,Filt_FC], axis=0, join='inner')
Red6
# Out:
#      Food Code                                    Food Name  \
# 1515    12-373                             Lassi, sweetened
# 1582    12-390                Lollies, containing ice-cream
# 1583    12-389               Lollies, with real fruit juice
# 1549    13-089  Lentils, green and brown, whole, dried, raw
# 1521    13-624                                   Leeks, raw
# 1552    13-520                        Lettuce, average, raw
# 1588    13-271                            Lotus tubers, raw
# 1513    15-651                   Lasagne, vegetable, retail
# 1538    14-128                  Lemons, whole, without pips
# 1556    14-131                            Limes, flesh only
# 1579    14-133                            Loganberries, raw
# 1527    14-278   Lemon juice, fresh, weighed as whole fruit
#
#                                             Description Group Previous  \
# 1515                     5 samples, takeaway and retail    BN  12-892
# ...

# %%
Red7 = pd.concat([Red6,Filt_JK], axis=0, join='inner')
Red7
# Out:
#      Food Code                                    Food Name  \
# 1515    12-373                             Lassi, sweetened
# 1582    12-390                Lollies, containing ice-cream
# 1583    12-389               Lollies, with real fruit juice
# 1549    13-089  Lentils, green and brown, whole, dried, raw
# 1521    13-624                                   Leeks, raw
# 1552    13-520                        Lettuce, average, raw
# 1588    13-271                            Lotus tubers, raw
# 1513    15-651                   Lasagne, vegetable, retail
# 1538    14-128                  Lemons, whole, without pips
# 1556    14-131                            Limes, flesh only
# 1579    14-133                            Loganberries, raw
# 1527    14-278   Lemon juice, fresh, weighed as whole fruit
# 1577    16-332                              Lobster, boiled
#
#                                             Description Group        Previous  \
# ...

# %%
Red8 = pd.concat([Red7,Filt_MAE], axis=0, join='inner')
Red8
# Out:
#      Food Code                                    Food Name  \
# 1515    12-373                             Lassi, sweetened
# 1582    12-390                Lollies, containing ice-cream
# 1583    12-389               Lollies, with real fruit juice
# 1549    13-089  Lentils, green and brown, whole, dried, raw
# 1521    13-624                                   Leeks, raw
# 1552    13-520                        Lettuce, average, raw
# 1588    13-271                            Lotus tubers, raw
# 1513    15-651                   Lasagne, vegetable, retail
# 1538    14-128                  Lemons, whole, without pips
# 1556    14-131                            Limes, flesh only
# 1579    14-133                            Loganberries, raw
# 1527    14-278   Lemon juice, fresh, weighed as whole fruit
# 1577    16-332                              Lobster, boiled
# 1399    18-478             Lamb, average, raw, lean and fat
# 1410    18-111                      Lamb, breast, raw, lean
# ...

# %%
Red9 = pd.concat([Red8,Filt_MG], axis=0, join='inner')
Red9
# Out:
#      Food Code                                    Food Name  \
# 1515    12-373                             Lassi, sweetened
# 1582    12-390                Lollies, containing ice-cream
# 1583    12-389               Lollies, with real fruit juice
# 1549    13-089  Lentils, green and brown, whole, dried, raw
# 1521    13-624                                   Leeks, raw
# 1552    13-520                        Lettuce, average, raw
# 1588    13-271                            Lotus tubers, raw
# 1513    15-651                   Lasagne, vegetable, retail
# 1538    14-128                  Lemons, whole, without pips
# 1556    14-131                            Limes, flesh only
# 1579    14-133                            Loganberries, raw
# 1527    14-278   Lemon juice, fresh, weighed as whole fruit
# 1577    16-332                              Lobster, boiled
# 1399    18-478             Lamb, average, raw, lean and fat
# 1410    18-111                      Lamb, breast, raw, lean
# ...

# %%
Red10 = pd.concat([Red9,Filt_MI], axis=0, join='inner')
Red10
# Out:
#      Food Code                                    Food Name  \
# 1515    12-373                             Lassi, sweetened
# 1582    12-390                Lollies, containing ice-cream
# 1583    12-389               Lollies, with real fruit juice
# 1549    13-089  Lentils, green and brown, whole, dried, raw
# 1521    13-624                                   Leeks, raw
# 1552    13-520                        Lettuce, average, raw
# 1588    13-271                            Lotus tubers, raw
# 1513    15-651                   Lasagne, vegetable, retail
# 1538    14-128                  Lemons, whole, without pips
# 1556    14-131                            Limes, flesh only
# 1579    14-133                            Loganberries, raw
# 1527    14-278   Lemon juice, fresh, weighed as whole fruit
# 1577    16-332                              Lobster, boiled
# 1399    18-478             Lamb, average, raw, lean and fat
# 1410    18-111                      Lamb, breast, raw, lean
# ...

# %%
Red11 = pd.concat([Red10,OF], axis=0, join='inner')
Red11
# Out:
#      Food Code                                    Food Name  \
# 1515    12-373                             Lassi, sweetened
# 1582    12-390                Lollies, containing ice-cream
# 1583    12-389               Lollies, with real fruit juice
# 1549    13-089  Lentils, green and brown, whole, dried, raw
# 1521    13-624                                   Leeks, raw
# 1552    13-520                        Lettuce, average, raw
# 1588    13-271                            Lotus tubers, raw
# 1513    15-651                   Lasagne, vegetable, retail
# 1538    14-128                  Lemons, whole, without pips
# 1556    14-131                            Limes, flesh only
# 1579    14-133                            Loganberries, raw
# 1527    14-278   Lemon juice, fresh, weighed as whole fruit
# 1577    16-332                              Lobster, boiled
# 1399    18-478             Lamb, average, raw, lean and fat
# 1410    18-111                      Lamb, breast, raw, lean
# ...

# %%
Red12 = pd.concat([Red11,PCA], axis=0, join='inner')
Red12
# Out:
#      Food Code                                    Food Name  \
# 1515    12-373                             Lassi, sweetened
# 1582    12-390                Lollies, containing ice-cream
# 1583    12-389               Lollies, with real fruit juice
# 1549    13-089  Lentils, green and brown, whole, dried, raw
# 1521    13-624                                   Leeks, raw
# 1552    13-520                        Lettuce, average, raw
# 1588    13-271                            Lotus tubers, raw
# 1513    15-651                   Lasagne, vegetable, retail
# 1538    14-128                  Lemons, whole, without pips
# 1556    14-131                            Limes, flesh only
# 1579    14-133                            Loganberries, raw
# 1527    14-278   Lemon juice, fresh, weighed as whole fruit
# 1577    16-332                              Lobster, boiled
# 1399    18-478             Lamb, average, raw, lean and fat
# 1410    18-111                      Lamb, breast, raw, lean
# ...

# %%
Red13 = pd.concat([Red12,Filt_QA], axis=0, join='inner')
Red13
# Out:
#      Food Code                                    Food Name  \
# 1515    12-373                             Lassi, sweetened
# 1582    12-390                Lollies, containing ice-cream
# 1583    12-389               Lollies, with real fruit juice
# 1549    13-089  Lentils, green and brown, whole, dried, raw
# 1521    13-624                                   Leeks, raw
# 1552    13-520                        Lettuce, average, raw
# 1588    13-271                            Lotus tubers, raw
# 1513    15-651                   Lasagne, vegetable, retail
# 1538    14-128                  Lemons, whole, without pips
# 1556    14-131                            Limes, flesh only
# 1579    14-133                            Loganberries, raw
# 1527    14-278   Lemon juice, fresh, weighed as whole fruit
# 1577    16-332                              Lobster, boiled
# 1399    18-478             Lamb, average, raw, lean and fat
# 1410    18-111                      Lamb, breast, raw, lean
# ...

# %%
Red14 = pd.concat([Red13,Filt_QI], axis=0, join='inner')
Red14
# Out:
#      Food Code                                    Food Name  \
# 1515    12-373                             Lassi, sweetened
# 1582    12-390                Lollies, containing ice-cream
# 1583    12-389               Lollies, with real fruit juice
# 1549    13-089  Lentils, green and brown, whole, dried, raw
# 1521    13-624                                   Leeks, raw
# 1552    13-520                        Lettuce, average, raw
# 1588    13-271                            Lotus tubers, raw
# 1513    15-651                   Lasagne, vegetable, retail
# 1538    14-128                  Lemons, whole, without pips
# 1556    14-131                            Limes, flesh only
# 1579    14-133                            Loganberries, raw
# 1527    14-278   Lemon juice, fresh, weighed as whole fruit
# 1577    16-332                              Lobster, boiled
# 1399    18-478             Lamb, average, raw, lean and fat
# 1410    18-111                      Lamb, breast, raw, lean
# ...

# %%
Red15 = pd.concat([Red14,SEC], axis=0, join='inner')
Red15
# Out:
#      Food Code                                    Food Name  \
# 1515    12-373                             Lassi, sweetened
# 1582    12-390                Lollies, containing ice-cream
# 1583    12-389               Lollies, with real fruit juice
# 1549    13-089  Lentils, green and brown, whole, dried, raw
# 1521    13-624                                   Leeks, raw
# 1552    13-520                        Lettuce, average, raw
# 1588    13-271                            Lotus tubers, raw
# 1513    15-651                   Lasagne, vegetable, retail
# 1538    14-128                  Lemons, whole, without pips
# 1556    14-131                            Limes, flesh only
# 1579    14-133                            Loganberries, raw
# 1527    14-278   Lemon juice, fresh, weighed as whole fruit
# 1577    16-332                              Lobster, boiled
# 1399    18-478             Lamb, average, raw, lean and fat
# 1410    18-111                      Lamb, breast, raw, lean
# ...

# %% [markdown]
#                                                        Export

# %%
Red15.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced_L.csv')
