# %% [markdown]
# # Product Weighting Project

# %% [markdown]
#                                          Data Reduction - Food Purchased In Store

# %% [markdown]
# ###### Import Necessary Libraries

# %%
import pandas as pd

# %% [markdown]
# Read in Data

# %%
Labelled = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Labelling2021_watercress.csv')

# %% [markdown]
# ### Products beginning with a 'N'

# %%
Prod_P = Labelled.loc[Labelled['Food Name'].str.startswith('P')]
Prod_P
# Out:
#      Food Code                                          Food Name  \
# 1836    13-516                                  Pak choi, steamed
# 1837    15-620         Pakora, vegetable, takeaway and restaurant
# 1838    15-826  Pakora/bhajia, aubergine, fried in vegetable o...
# 1839    15-827  Pakora/bhajia, cauliflower, fried in vegetable...
# 1840    15-828  Pakora/bhajia, onion, fried in vegetable oil, ...
# ...        ...                                                ...
# 2274   11-1124                            Pudding, suet, homemade
# 2275    14-842                                      Pumpkin seeds
# 2276    13-549      Pumpkin, flesh only, boiled in unsalted water
# 2277    13-326                           Pumpkin, flesh only, raw
# 2278    11-911                                     Puri, homemade
#
#                                             Description Group Previous  \
# 1836  16 samples, autumn and winter, UK grown and im...    DG      NaN
# ...

# %% [markdown]
# Products within a Group (provide identification of the food group and food type to which the food belongs)

# %%
Prod_P.groupby('Group')['Food Name'].count()
# Out:
# Group
# A       3
# AD     20
# AE      6
# AF      3
# AI      3
# AO     15
# AP      7
# AS     30
# AT      7
# BP      1
# BR      9
# BV      1
# DA      2
# DAE     4
# DAM    14
# DAP    17
# DAR    10
# DF     16
# DG     20
# DR     33
# F       4
# FA     47
# FC      3
# G       1
# GA     13
# H       6
# JA     17
# JK      6
# JR      4
# MAG    66
# MCA     2
# MCI     2
# MCK     2
# MCM     2
# MG      1
# MI      5
# MR     22
# PE      1
# Q       1
# QF      1
# SEC     3
# SN      7
# SNA     2
# WC      2
# WCG     1
# WCN     1
# Name: Food Name, dtype: int64

# %% [markdown]
# ## *Reducing products based on its most basic form. Improve as you go on*

# %% [markdown]
#                                                 Cereals and cereal products

# %%
A = Prod_P.loc[Prod_P['Group']== 'A']
A
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 2175    11-789  Porridge oats, unfortified, cooked, made up wi...
#
#                                             Description Group Previous  \
# 2050  11 samples, 10 products, frozen and chilled, a...     A  11-553
# 2174  18 samples, 10 products, Quaker and other/own ...     A  11-017
# 2175  18 samples, 10 products, Quaker and other/own ...     A      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2050  DH, Nutrient analysis of a range of processed ...      NaN        1154
# 2174    LGC, Nutrient survey of breakfast cereals, 2004      NaN        1654
# 2175    LGC, Nutrient survey of breakfast cereals, 2004      NaN         361
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# ...

# %%
A['Food Name'].unique()
# Out:
# array(['Pizza, cheese and tomato, retail', 'Porridge oats, unfortified',
#        'Porridge oats, unfortified, cooked, made up with semi-skimmed milk'],
#       dtype=object)

# %% [markdown]
# **Reduced**

# %%
remove = ['Porridge oats, unfortified, cooked, made up with semi-skimmed milk']

# %%
Filt_A = A[~A['Food Name'].isin(remove)]
Filt_A
# Out:
#      Food Code                         Food Name  \
# 2050    11-936  Pizza, cheese and tomato, retail
# 2174    11-788        Porridge oats, unfortified
#
#                                             Description Group Previous  \
# 2050  11 samples, 10 products, frozen and chilled, a...     A  11-553
# 2174  18 samples, 10 products, Quaker and other/own ...     A  11-017
#
#                                    Main data references Footnote Energy (kJ)  \
# 2050  DH, Nutrient analysis of a range of processed ...      NaN        1154
# 2174    LGC, Nutrient survey of breakfast cereals, 2004      NaN        1654
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2050           275      9.8          4.12               33        3.7
# 2174           392      8.1          1.28             64.3        0.3
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2050       29.3       2.9         12.2     0.99
# 2174         64       7.8         11.7        0

# %%
Filt_A['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\105808842.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_A['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Pasta

# %%
AD = Prod_P.loc[Prod_P['Group']== 'AD']
AD
# Out:
#      Food Code                                          Food Name  \
# 1876    11-734                  Pasta and sauce mixes, dried, raw
# 1877    11-717      Pasta shapes, coloured, flavoured, dried, raw
# 1880    11-729  Pasta, egg, fresh, filled with cheese and toma...
# 1881    11-728  Pasta, egg, fresh, filled with cheese only, bo...
# 1882    11-731  Pasta, egg, fresh, filled with green vegetable...
# 1883    11-732  Pasta, egg, fresh, filled with meat, boiled in...
# 1884    11-730  Pasta, egg, fresh, filled with mushrooms, boil...
# 1885    11-726                             Pasta, egg, fresh, raw
# 1886    11-715                      Pasta, egg, white, dried, raw
# 1887    11-727  Pasta, egg, white, tagliatelle, fresh, boiled ...
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1889    11-736  Pasta, ravioli, meat filling, canned in tomato...
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# ...

# %%
AD['Food Name'].unique()
# Out:
# array(['Pasta and sauce mixes, dried, raw',
#        'Pasta shapes, coloured, flavoured, dried, raw',
#        'Pasta, egg, fresh, filled with cheese and tomato, boiled in unsalted water',
#        'Pasta, egg, fresh, filled with cheese only, boiled in unsalted water',
#        'Pasta, egg, fresh, filled with green vegetables/herbs and cheese, boiled in unsalted water',
#        'Pasta, egg, fresh, filled with meat, boiled in unsalted water',
#        'Pasta, egg, fresh, filled with mushrooms, boiled in unsalted water',
#        'Pasta, egg, fresh, raw', 'Pasta, egg, white, dried, raw',
#        'Pasta, egg, white, tagliatelle, fresh, boiled in unsalted water',
#        'Pasta, plain, fresh, boiled',
#        'Pasta, ravioli, meat filling, canned in tomato sauce',
#        'Pasta, spaghetti, canned, in tomato sauce',
#        'Pasta, white,  twists, fusilli, dried, boiled in unsalted water',
#        'Pasta, white, dried, boiled in unsalted water',
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_AD = ['Pasta, spaghetti, canned, in tomato sauce', 'Pasta, plain, fresh, boiled']

# %%
Filt_AD = AD[AD['Food Name'].isin(Priority_AD)]
Filt_AD
# Out:
#      Food Code                                  Food Name  \
# 1888    11-450                Pasta, plain, fresh, boiled
# 1890    11-735  Pasta, spaghetti, canned, in tomato sauce
#
#                                             Description Group  Previous  \
# 1888  12 Samples, 8 brands including spaghetti, tagl...    AD  11-397
# 1890                             10 samples, 9 products    AD   11-357
#
#                                    Main data references Footnote Energy (kJ)  \
# 1888  RHM (1995) Nutrient content of selected foods,...      NaN         675
# 1890  LGC, Nutrient analysis of pasta and pasta sauc...      NaN         314
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1888           160      1.5          0.28             28.9        0.6
# 1890            74      0.3          0.05             15.1        5.4
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1888       27.9       1.9          6.6     0.04
# ...

# %%
Filt_AD['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\1539937252.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AD['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Removed AE - Pizzas

# %% [markdown]
# Breads

# %%
AF = Prod_P.loc[Prod_P['Group']== 'AF']
AF
# Out:
#      Food Code           Food Name  \
# 1859    11-998  Papadums, takeaway
# 1864   11-1104   Paratha, homemade
# 2278    11-911      Puri, homemade
#
#                                             Description Group Previous  \
# 1859                  10 samples from different outlets    AF  11-464
# 1864                                             Recipe    AF  11-630
# 2278  9 samples; 6 homemade, 3 café. Deep fried chapati    AF      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1859  Aspland and James, Nutrient analysis of ethnic...      NaN        2119
# 1864                                       Updated 2014      NaN        1428
# 2278  University of Leeds, Nutritional analysis of c...      NaN        1539
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1859           511     38.8          7.95             25.7          0
# 1864           341     14.4          8.51             41.8        0.8
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_AF = AF[AF['Food Name'] == 'Papadums, takeaway']
Filt_AF
# Out:
#      Food Code           Food Name                        Description Group  \
# 1859    11-998  Papadums, takeaway  10 samples from different outlets    AF
#
#      Previous                               Main data references Footnote  \
# 1859  11-464   Aspland and James, Nutrient analysis of ethnic...      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 1859        2119           511     38.8          7.95             25.7
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1859          0       25.7       6.3         11.5        N

# %%
Filt_AF['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\2620942196.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AF['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Removed AI - Breakfast cereals

# %% [markdown]
# Biscuits

# %%
AO = Prod_P.loc[Prod_P['Group']== 'AO']
AO
# Out:
#      Food Code                               Food Name  \
# 1905    11-992    Pastry, cheese, shortcrust, homemade
# 1906   11-1049         Pastry, choux, cooked, homemade
# 1907   11-1048       Pastry, choux, uncooked, homemade
# 1908    11-856            Pastry, filo, retail, cooked
# 1909    11-855          Pastry, filo, retail, uncooked
# 1910   11-1139         Pastry, flaky, cooked, homemade
# 1911   11-1140       Pastry, flaky, uncooked, homemade
# 1912    11-854      Pastry, flaky/puff, retail, cooked
# 1913    11-852    Pastry, flaky/puff, retail, uncooked
# 1914   11-1052    Pastry, shortcrust, cooked, homemade
# 1915    11-853      Pastry, shortcrust, retail, cooked
# 1916    11-851    Pastry, shortcrust, retail, uncooked
# 1917   11-1017  Pastry, shortcrust, uncooked, homemade
# 1918    11-961     Pastry, wholemeal, cooked, homemade
# 1919   11-1010   Pastry, wholemeal, uncooked, homemade
#
#                                             Description Group Previous  \
# ...

# %%
AO['Food Name'].unique()
# Out:
# array(['Pastry, cheese, shortcrust, homemade',
#        'Pastry, choux, cooked, homemade',
#        'Pastry, choux, uncooked, homemade',
#        'Pastry, filo, retail, cooked', 'Pastry, filo, retail, uncooked',
#        'Pastry, flaky, cooked, homemade',
#        'Pastry, flaky, uncooked, homemade',
#        'Pastry, flaky/puff, retail, cooked',
#        'Pastry, flaky/puff, retail, uncooked',
#        'Pastry, shortcrust, cooked, homemade',
#        'Pastry, shortcrust, retail, cooked',
#        'Pastry, shortcrust, retail, uncooked',
#        'Pastry, shortcrust, uncooked, homemade',
#        'Pastry, wholemeal, cooked, homemade',
#        'Pastry, wholemeal, uncooked, homemade'], dtype=object)

# %%
Priority_AO = ['Pastry, shortcrust, retail, cooked']

# %% [markdown]
# **Reduced**

# %%
Filt_AO = AO[AO['Food Name'].isin(Priority_AO)]
Filt_AO
# Out:
#      Food Code                           Food Name  \
# 1915    11-853  Pastry, shortcrust, retail, cooked
#
#                                             Description Group Previous  \
# 1915  Calculated from uncooked, using weight loss of...    AO      NaN
#
#                                    Main data references  \
# 1915  DH, Nutrient analysis of biscuits, buns, cakes...
#
#                                               Footnote Energy (kJ)  \
# 1915  Calculated from uncooked using 17.2% weight loss        2299
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1915           553     37.9          14.1             43.2          1
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1915       42.3       4.1          7.6     0.68

# %%
Filt_AO['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\1595727596.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AO['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Buns and pastries

# %%
AP = Prod_P.loc[Prod_P['Group']== 'AP']
AP
# Out:
#      Food Code                                          Food Name  \
# 1899    11-230                                    Pastries, Asian
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1901   11-1064       Pastries, chocolate eclairs, fresh, homemade
# 1902    11-843                     Pastries, cream filled, retail
# 1903    11-841                           Pastries, Danish, retail
# 1904    11-842                   Pastries, Greek, baklava, retail
# 2046   11-1105                                    Pinni, homemade
#
#                                             Description Group        Previous  \
# 1899                  5 samples, assorted sata pastries    AP             NaN
# 1900                             10 samples, 7 products    AP         11-247
# 1901                                             Recipe    AP         11-657
# 1902  10 samples, 6 products, including fresh cream ...    AP  11-654 11-690
# ...

# %%
AP['Food Name'].unique()
# Out:
# array(['Pastries, Asian',
#        'Pastries, chocolate eclairs, cream filled, retail',
#        'Pastries, chocolate eclairs, fresh, homemade',
#        'Pastries, cream filled, retail', 'Pastries, Danish, retail',
#        'Pastries, Greek, baklava, retail', 'Pinni, homemade'],
#       dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_AP = ['Pastries, chocolate eclairs, cream filled, retail']

# %%
Filt_AP = AP[AP['Food Name'].isin(Priority_AP)]
Filt_AP
# Out:
#      Food Code                                          Food Name  \
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
#
#                  Description Group Previous  \
# 1900  10 samples, 7 products    AP  11-247
#
#                                    Main data references Footnote Energy (kJ)  \
# 1900  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1624
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1900           391     28.5         13.59             26.8         23
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1900        3.8       1.4          6.1     0.31

# %%
Filt_AP['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\739656524.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AP['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Puddings

# %%
AS = Prod_P.loc[Prod_P['Group']== 'AS']
AS
# Out:
#      Food Code                                          Food Name  \
# 1853   11-1143  Pancakes, sweet, made with semi skimmed milk, ...
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1855   11-1142    Pancakes, sweet, made with whole milk, homemade
# 1995   11-1024                    Pie, apple, one crust, homemade
# 1996   11-1025        Pie, apple, pastry top and bottom, homemade
# 1997    11-920  Pie, apple, pastry, double crust, deep filled,...
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 1999   11-1026         Pie, apple, wholemeal, one crust, homemade
# 2000   11-1027  Pie, apple, wholemeal, pastry top and bottom, ...
# 2011    11-847                     Pie, fruit, individual, retail
# 2012   11-1007                    Pie, fruit, one crust, homemade
# 2013   11-1073  Pie, fruit, pastry top and bottom, blackcurran...
# 2014   11-1008        Pie, fruit, pastry top and bottom, homemade
# ...

# %%
AS['Food Name'].unique()
# Out:
# array(['Pancakes, sweet, made with semi skimmed milk, homemade',
#        'Pancakes, sweet, made with skimmed milk, homemade',
#        'Pancakes, sweet, made with whole milk, homemade',
#        'Pie, apple, one crust, homemade',
#        'Pie, apple, pastry top and bottom, homemade',
#        'Pie, apple, pastry, double crust, deep filled, retail',
#        'Pie, apple, pastry, double crust, retail',
#        'Pie, apple, wholemeal, one crust, homemade',
#        'Pie, apple, wholemeal, pastry top and bottom, homemade',
#        'Pie, fruit, individual, retail',
#        'Pie, fruit, one crust, homemade',
#        'Pie, fruit, pastry top and bottom, blackcurrant, homemade',
#        'Pie, fruit, pastry top and bottom, homemade',
#        'Pie, fruit, wholemeal, one crust, homemade',
#        'Pie, fruit, wholemeal, pastry top and bottom, blackcurrant, homemade',
#        'Pie, fruit, wholemeal, pastry top and bottom, homemade',
# ...

# %% [markdown]
# **Removed**

# %%
Priority_AS = ['Pancakes, sweet, made with skimmed milk, homemade','Pie, apple, pastry, double crust, retail','Pie, fruit, individual, retail', 'Pudding, sponge, homemade']

# %%
Filt_AS = AS[AS['Food Name'].isin(Priority_AS)]
Filt_AS
# Out:
#      Food Code                                          Food Name  \
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
#
#                                             Description Group Previous  \
# 1854                                             Recipe    AS  11-702
# 1998        11 samples, 11 products, chilled and frozen    AS      NaN
# 2011  10 samples, 7 products, including apple, apple...    AS  11-547
# 2270                                             Recipe    AS  11-706
#
#                                    Main data references Footnote Energy (kJ)  \
# 1854                                       Updated 2014      NaN         992
# 1998  ADAS Laboratories, Nutrient analysis of ice cr...      NaN        1038
# ...

# %%
Filt_AS['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\346938166.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AS['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Savouries

# %%
AT = Prod_P.loc[Prod_P['Group']== 'AT']
AT
# Out:
#      Food Code                                          Food Name  \
# 1846   11-1101                                  Pakoras, homemade
# 1847    11-922  Pancakes (served with crispy duck), pancakes o...
# 1848    11-959  Pancakes, savoury, made with semi-skimmed milk...
# 1849   11-1102  Pancakes, savoury, made with skimmed milk, hom...
# 1850   11-1103  Pancakes, savoury, wholemeal, made with whole ...
# 2080    11-905                             Polenta, hydrated, raw
# 2239   11-1023                           Prawn crackers, takeaway
#
#                                             Description Group Previous  \
# 1846                                             Recipe    AT  11-711
# 1847  10 sub-samples, 2 from different establishment...    AT      NaN
# 1848                                             Recipe    AT      NaN
# 1849                                             Recipe    AT  11-712
# 1850                                             Recipe    AT  11-714
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_AT = ['Prawn crackers, takeaway']

# %%
Filt_AT = AT[AT['Food Name'].isin(Priority_AT)]

# %%
Filt_AT['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\2561790092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AT['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
#                                                   Milk and milk products

# %% [markdown]
# Removed BP

# %%
BR = Prod_P.loc[Prod_P['Group']== 'BR']
BR
# Out:
#      Food Code                                        Food Name  \
# 1926    12-475              Pavlova, toffee/chocolate, no fruit
# 1927    12-552                    Pavlova, with fruit and cream
# 2001    12-394                                    Pie, banoffee
# 2248    12-405                  Profiteroles with sauce, frozen
# 2264    12-580                            Pudding, rice, canned
# 2265    12-553                   Pudding, rice, canned, low fat
# 2266    12-514  Pudding, rice, homemade, with semi-skimmed milk
# 2267    12-607       Pudding, rice, homemade, with skimmed milk
# 2268    12-608         Pudding, rice, homemade, with whole milk
#
#                                             Description Group Previous  \
# 1926                     10 samples, 6 products, frozen    BR  12-403
# 1927  12 samples, 7 brands, including raspberry, str...    BR  12-404
# 2001  10 samples, 6 brands including two Mississippi...    BR      NaN
# ...

# %%
BR['Food Name'].unique()
# Out:
# array(['Pavlova, toffee/chocolate, no fruit',
#        'Pavlova, with fruit and cream', 'Pie, banoffee',
#        'Profiteroles with sauce, frozen', 'Pudding, rice, canned',
#        'Pudding, rice, canned, low fat',
#        'Pudding, rice, homemade, with semi-skimmed milk',
#        'Pudding, rice, homemade, with skimmed milk',
#        'Pudding, rice, homemade, with whole milk'], dtype=object)

# %%
Filt_BR = BR[BR['Food Name'] ==  'Pudding, rice, canned, low fat' ]

# %%
Filt_BR['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\3725017385.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_BR['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Removed BV - Savoury dishes and sauces

# %% [markdown]
#                                                         Vegetables

# %% [markdown]
# Potatoes

# %%
DA = Prod_P.loc[Prod_P['Group']== 'DA']
DA
# Out:
#      Food Code                               Food Name  \
# 2211    13-533  Potato products, shaped, frozen, baked
# 2234    13-534  Potatoes, old, roasted in rapeseed oil
#
#                                             Description Group Previous  \
# 2211  Frozen, including waffles, smiley faces and le...    DA  13-425
# 2234  Calculated from raw, parboiled for 5-10 minute...    DA      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2211  DH, Nutrient analysis of fruit and vegetables,...      NaN         806
# 2234  DH, Nutrient analysis of fruit and vegetables,...      NaN         687
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2211           192      8.3          0.89             25.6        0.4
# 2234           164      5.7           0.4             24.1        1.2
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2211       25.2       2.7          2.5     0.64
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_DA = DA[DA['Food Name'] == 'Potatoes, old, roasted in rapeseed oil']
Filt_DA
# Out:
#      Food Code                               Food Name  \
# 2234    13-534  Potatoes, old, roasted in rapeseed oil
#
#                                             Description Group Previous  \
# 2234  Calculated from raw, parboiled for 5-10 minute...    DA      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2234  DH, Nutrient analysis of fruit and vegetables,...      NaN         687
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2234           164      5.7           0.4             24.1        1.2
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2234       22.9       2.7          2.6     0.01

# %%
Filt_DA['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\3204905869.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DA['Super Group'] = 'Vegetables'

# %% [markdown]
# Removed DAE - Early potatoes

# %% [markdown]
# Removed DAM

# %%
DAP = Prod_P.loc[Prod_P['Group']== 'DAP']
DAP
# Out:
#      Food Code                                          Food Name  \
# 2183    13-024  Potato chips, crinkle cut, frozen, fried in co...
# 2184    13-486     Potato chips, fine cut, from fast food outlets
# 2185    50-684  Potato chips, fine cut, frozen, fried in blend...
# 2186    13-026  Potato chips, fine cut, frozen, fried in corn oil
# 2187    50-686  Potato chips, fine cut, frozen, fried in dripping
# 2189    13-485  Potato chips, fried in commercial oil, from ta...
# 2192    13-595          Potato chips, homemade, fried in corn oil
# 2193    13-596          Potato chips, homemade, fried in dripping
# 2194    13-555      Potato chips, homemade, fried in rapeseed oil
# 2195    13-597     Potato chips, homemade, fried in sunflower oil
# 2196    13-557                    Potato chips, microwave, cooked
# 2197    13-487         Potato chips, oven ready, no batter, baked
# 2198    13-488       Potato chips, oven ready, with batter, baked
# ...

# %%
DAP['Food Name'].unique()
# Out:
# array(['Potato chips, crinkle cut, frozen, fried in corn oil',
#        'Potato chips, fine cut, from fast food outlets',
#        'Potato chips, fine cut, frozen, fried in blended vegetable oil',
#        'Potato chips, fine cut, frozen, fried in corn oil',
#        'Potato chips, fine cut, frozen, fried in dripping',
#        'Potato chips, fried in commercial oil, from takeaway fish and chip shops',
#        'Potato chips, homemade, fried in corn oil',
#        'Potato chips, homemade, fried in dripping',
#        'Potato chips, homemade, fried in rapeseed oil',
#        'Potato chips, homemade, fried in sunflower oil',
#        'Potato chips, microwave, cooked',
#        'Potato chips, oven ready, no batter, baked',
#        'Potato chips, oven ready, with batter, baked',
#        'Potato chips, straight cut, frozen, fried in blended oil',
#        'Potato chips, straight cut, frozen, fried in corn oil',
#        'Potato chips, straight cut, frozen, fried in dripping',
# ...

# %%
Filt_DAP = DAP[DAP['Food Name'] == 'Potato chips, oven ready, no batter, baked']

# %%
Filt_DAP['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\2948675600.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DAP['Super Group'] = 'Vegetables'

# %% [markdown]
# Potato products

# %%
DAR = Prod_P.loc[Prod_P['Group']== 'DAR']
DAR
# Out:
#      Food Code                                          Food Name  \
# 2188    13-613  Potato chips, fried in beef dripping, from tak...
# 2190    13-612  Potato chips, fried in palm oil, from takeaway...
# 2191    13-614  Potato chips, fried in rapeseed oil, from take...
# 2205    13-038            Potato croquettes, fried in blended oil
# 2206    13-615  Potato powder, instant, made up with semi-skim...
# 2207    13-616  Potato powder, instant, made up with skimmed milk
# 2208    13-558         Potato powder, instant, made up with water
# 2209    13-617    Potato powder, instant, made up with whole milk
# 2210    13-598                        Potato powder, instant, raw
# 2214    13-483                      Potato wedges, retail, cooked
#
#                                             Description Group Previous  \
# 2188  10 samples with fatty acids calculated from be...   DAR      NaN
# 2190  10 samples with fatty acids calculated from pa...   DAR      NaN
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_DAR = DAR[DAR['Food Name'] == 'Potato wedges, retail, cooked']

# %%
Filt_DAR['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\2238748411.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DAR['Super Group'] = 'Vegetables'

# %% [markdown]
# Peas

# %%
DF = Prod_P.loc[Prod_P['Group']== 'DF']
DF
# Out:
#      Food Code                                     Food Name  \
# 1951    13-439                Peas, boiled in unsalted water
# 1952    13-564     Peas, canned in water, re-heated, drained
# 1953    13-131         Peas, dried, boiled in unsalted water
# 1954    13-130                              Peas, dried, raw
# 1955    13-536        Peas, frozen, boiled in unsalted water
# 1956    13-528                      Peas, frozen, microwaved
# 1957    13-527                             Peas, frozen, raw
# 1958    13-641    Peas, mange-tout, boiled in unsalted water
# 1959    13-122                         Peas, mange-tout, raw
# 1960    13-642  Peas, mange-tout, stir-fried in rapeseed oil
# 1961    13-562   Peas, marrowfat, canned, re-heated, drained
# 1962    13-563                Peas, mushy, canned, re-heated
# 1963    13-438                                     Peas, raw
# 1964    13-142  Peas, split, dried, boiled in unsalted water
# ...

# %%
DF['Food Name'].unique()
# Out:
# array(['Peas, boiled in unsalted water',
#        'Peas, canned in water, re-heated, drained',
#        'Peas, dried, boiled in unsalted water', 'Peas, dried, raw',
#        'Peas, frozen, boiled in unsalted water',
#        'Peas, frozen, microwaved', 'Peas, frozen, raw',
#        'Peas, mange-tout, boiled in unsalted water',
#        'Peas, mange-tout, raw',
#        'Peas, mange-tout, stir-fried in rapeseed oil',
#        'Peas, marrowfat, canned, re-heated, drained',
#        'Peas, mushy, canned, re-heated', 'Peas, raw',
#        'Peas, split, dried, boiled in unsalted water',
#        'Peas, split, dried, raw', 'Peas, sugar-snap, raw'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_DF = ['Peas, frozen, raw', 'Peas, canned in water, re-heated, drained']

# %%
Filt_DF = DF[DF['Food Name'].isin(Priority_DF)]

# %%
Filt_DF['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\3331425488.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DF['Super Group'] = 'Vegetables'

# %% [markdown]
# Veg general

# %%
DG = Prod_P.loc[Prod_P['Group']== 'DG']
DG
# Out:
#      Food Code                                          Food Name  \
# 1836    13-516                                  Pak choi, steamed
# 1862    13-311                   Papaya, unripe, green flesh, raw
# 1868    13-631                  Parsnip, boiled in unsalted water
# 1869    13-312                                       Parsnip, raw
# 1870    13-632                   Parsnip, roasted in rapeseed oil
# 1925    13-315                                  Patra leaves, raw
# 1966    13-594         Peas, sugar-snap, boiled in unsalted water
# 1972    13-525    Pepper, capsicum, red, boiled in unsalted water
# 1973    13-524                         Pepper, capsicum, red, raw
# 1974    13-537  Pepper, capsicum, yellow, boiled in unsalted w...
# 1975    13-526                      Pepper, capsicum, yellow, raw
# 1980    13-316              Peppers, capsicum, chilli, green, raw
# 1981    13-317                Peppers, capsicum, chilli, red, raw
# ...

# %%
DG['Food Name'].unique()
# Out:
# array(['Pak choi, steamed', 'Papaya, unripe, green flesh, raw',
#        'Parsnip, boiled in unsalted water', 'Parsnip, raw',
#        'Parsnip, roasted in rapeseed oil', 'Patra leaves, raw',
#        'Peas, sugar-snap, boiled in unsalted water',
#        'Pepper, capsicum, red, boiled in unsalted water',
#        'Pepper, capsicum, red, raw',
#        'Pepper, capsicum, yellow, boiled in unsalted water',
#        'Pepper, capsicum, yellow, raw',
#        'Peppers, capsicum, chilli, green, raw',
#        'Peppers, capsicum, chilli, red, raw',
#        'Peppers, capsicum, green, boiled in unsalted water',
#        'Peppers, capsicum, green, raw',
#        'Plantain, boiled in unsalted water, flesh only',
#        'Plantain, green flesh, raw',
#        'Plantain, ripe, fried in rapeseed oil',
#        'Pumpkin, flesh only, boiled in unsalted water',
#        'Pumpkin, flesh only, raw'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_DG = ['Pak choi, steamed', 'Papaya, unripe, green flesh, raw','Parsnip, raw','Pepper, capsicum, red, raw', 'Plantain, green flesh, raw','Pumpkin, flesh only, raw']

# %%
Filt_DG = DG[DG['Food Name'].isin(Priority_DG)]
Filt_DG
# Out:
#      Food Code                         Food Name  \
# 1836    13-516                 Pak choi, steamed
# 1862    13-311  Papaya, unripe, green flesh, raw
# 1869    13-312                      Parsnip, raw
# 1973    13-524        Pepper, capsicum, red, raw
# 2066    13-323        Plantain, green flesh, raw
# 2277    13-326          Pumpkin, flesh only, raw
#
#                                             Description Group Previous  \
# 1836  16 samples, autumn and winter, UK grown and im...    DG      NaN
# 1862                                 Literature sources    DG      NaN
# 1869                            Ends trimmed and peeled    DG  50-799
# 1973  22 samples, autumn and winter, UK grown and im...    DG  13-320
# 2066                                Literature sources.    DG  50-806
# 2277                      Peeled thickly, seeds removed    DG  50-809
#
#                                    Main data references Footnote Energy (kJ)  \
# ...

# %%
Filt_DG['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\1311392366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DG['Super Group'] = 'Vegetables'

# %% [markdown]
# Removed DR - Vegetables dishes

# %% [markdown]
#                                                            Fruit

# %%
F = Prod_P.loc[Prod_P['Group']== 'F']
F
# Out:
#      Food Code                                          Food Name  \
# 1942    14-365                    Pears, average, raw, flesh only
# 1943    14-367                  Pears, average, stewed with sugar
# 1944    14-368               Pears, average, stewed without sugar
# 1950    14-366  Pears, raw, flesh only, peeled, weighed with s...
#
#                                             Description Group Previous  \
# 1942  22 samples, autumn and winter, UK grown and im...     F  14-192
# 1943  Calculation from 1000g fruit, 190g water, 120g...     F  14-194
# 1944           Calculation from 1000g fruit, 190g water     F  14-195
# 1950  Calculated from raw, flesh only using edible c...     F  14-193
#
#                                    Main data references Footnote Energy (kJ)  \
# 1942  Nutrient analysis of fresh and processed fruit...      NaN         249
# 1943                                  Recalculated 2014      NaN         338
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_F = F[F['Food Name'] == 'Pears, average, raw, flesh only']

# %%
Filt_F['Super Group'] = 'Fruit'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\4228301647.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_F['Super Group'] = 'Fruit'

# %% [markdown]
# Fruit, general

# %%
FA = Prod_P.loc[Prod_P['Group']== 'FA']
FA
# Out:
#      Food Code                                          Food Name  \
# 1860    14-390                            Papaya, flesh only, raw
# 1861    14-397  Papaya, flesh only, raw, weighed with skin and...
# 1874    14-178                      Passion fruit, flesh and pips
# 1875    14-179   Passion fruit, flesh and pips, weighed with skin
# 1929    14-188           Peaches, canned in juice, whole contents
# 1930    14-189           Peaches, canned in syrup, whole contents
# 1931    14-312   Peaches, flesh and skin, raw, weighed with stone
# 1932    14-299                       Peaches, raw, flesh and skin
# 1941    14-361  Pears, average, flesh and skin, raw, weighed w...
# 1945    14-197             Pears, canned in juice, whole contents
# 1946    14-196                                       Pears, dried
# 1947    14-205                  Pears, Nashi, flesh and skin, raw
# 1948    14-206  Pears, Nashi, flesh and skin, raw, weighed wit...
# ...

# %%
FA['Food Name'].unique()
# Out:
# array(['Papaya, flesh only, raw',
#        'Papaya, flesh only, raw, weighed with skin and pips',
#        'Passion fruit, flesh and pips',
#        'Passion fruit, flesh and pips, weighed with skin',
#        'Peaches, canned in juice, whole contents',
#        'Peaches, canned in syrup, whole contents',
#        'Peaches, flesh and skin, raw, weighed with stone',
#        'Peaches, raw, flesh and skin',
#        'Pears, average, flesh and skin, raw, weighed with core and stalk',
#        'Pears, canned in juice, whole contents', 'Pears, dried',
#        'Pears, Nashi, flesh and skin, raw',
#        'Pears, Nashi, flesh and skin, raw, weighed with core',
#        'Pears, raw, flesh and skin', 'Peel, mixed',
#        'Physalis, fruit only',
#        'Pineapple, canned in juice, whole contents',
#        'Pineapple, canned in syrup, whole contents', 'Pineapple, dried',
#        'Pineapple, flesh only, raw',
#        'Pineapple, flesh only, raw, weighed with skin and top',
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_FA = ['Peaches, canned in juice, whole contents','Pears, dried', 'Pineapple, flesh only, raw','Plums, Victoria, stewed without sugar','Pomegranate, flesh and pips',]

# %%
Filt_FA = FA[FA['Food Name'].isin(Priority_FA)]
Filt_FA
# Out:
#      Food Code                                 Food Name  \
# 1929    14-188  Peaches, canned in juice, whole contents
# 1946    14-196                              Pears, dried
# 2044    14-376                Pineapple, flesh only, raw
# 2076    14-222     Plums, Victoria, stewed without sugar
# 2085    14-226               Pomegranate, flesh and pips
#
#                                             Description Group Previous  \
# 1929  10 samples, 7 brands; halves and slices. Drain...    FA  50-940
# 1946    3 samples, 3 brands and calculation from 14-192    FA      NaN
# 2044   11 samples, imported, whole and prepacked chunks    FA   14-208
# 2076             700g fruit, 100g water; stones removed    FA      NaN
# 2085                   Analysis and literature sources;    FA      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1929  Reviewed 2013. LGC, Nutritional composition of...      NaN         194
# ...

# %%
Filt_FA['Super Group'] = 'Fruit'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\3797725470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_FA['Super Group'] = 'Fruit'

# %% [markdown]
# Fruit Juice

# %%
FC = Prod_P.loc[Prod_P['Group']== 'FC']
FC
# Out:
#      Food Code                Food Name                  Description Group  \
# 1873    14-285      Passion fruit juice           Literature sources    FC
# 2084    14-341  Pomegranate juice drink             with added sugar    FC
# 2249    14-289              Prune juice  4 bottled samples; 2 brands    FC
#
#      Previous                               Main data references Footnote  \
# 1873      NaN  Gebhardt et al. (1982) Comoposition of foods: ...      NaN
# 2084  14-288                  MW1, 1940; and industry data, 2013      NaN
# 2249      NaN               LGC, Fruit and vegetables, 1989-1990      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 1873         238            56      0.1             0             10.6
# 2084         204            48      0.0             0             11.6
# 2249         351            82      0.1             0             14.4
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# ...

# %%
FC['Super Group'] = 'Fruit'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\4233848853.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FC['Super Group'] = 'Fruit'

# %% [markdown]
#                                                      Nuts and seeds

# %% [markdown]
# Removed G

# %%
GA = Prod_P.loc[Prod_P['Group']== 'GA']
GA
# Out:
#      Food Code                                          Food Name  \
# 1934    14-892                              Peanut butter, smooth
# 1935    14-882                                Peanuts and raisins
# 1936    14-878                               Peanuts, dry roasted
# 1937    14-877              Peanuts, kernel only, plain, unsalted
# 1938    14-886   Peanuts, kernel only, plain, weighed with shells
# 1939    14-894               Peanuts, raisins and chocolate chips
# 1940    14-834                        Peanuts, roasted and salted
# 1968    14-837                            Pecan nuts, kernel only
# 1969    14-838       Pecan nuts, kernel only, weighed with shells
# 2039    14-839                             Pine nuts, kernel only
# 2047    14-840    Pistachio nuts, kernel only, roasted and salted
# 2048    14-841  Pistachio nuts, kernel only, roasted and salte...
# 2275    14-842                                      Pumpkin seeds
#
# ...

# %%
GA['Food Name'].unique()
# Out:
# array(['Peanut butter, smooth', 'Peanuts and raisins',
#        'Peanuts, dry roasted', 'Peanuts, kernel only, plain, unsalted',
#        'Peanuts, kernel only, plain, weighed with shells',
#        'Peanuts, raisins and chocolate chips',
#        'Peanuts, roasted and salted', 'Pecan nuts, kernel only',
#        'Pecan nuts, kernel only, weighed with shells',
#        'Pine nuts, kernel only',
#        'Pistachio nuts, kernel only, roasted and salted',
#        'Pistachio nuts, kernel only, roasted and salted, weighed with shells',
#        'Pumpkin seeds'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_GA = ['Peanut butter, smooth', 'Peanuts and raisins','Pistachio nuts, kernel only, roasted and salted']

# %%
Filt_GA = GA[GA['Food Name'].isin(Priority_GA)]

# %%
Filt_GA['Super Group'] = 'Nuts and seeds'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\4029859601.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_GA['Super Group'] = 'Nuts and seeds'

# %% [markdown]
#                                                     Herbs and Spices

# %%
H = Prod_P.loc[Prod_P['Group']== 'H']
H
# Out:
#      Food Code                Food Name           Description Group Previous  \
# 1863    13-879                  Paprika    Literature sources     H  13-843
# 1866    13-845           Parsley, dried    Literature sources     H      NaN
# 1867    13-844           Parsley, fresh  Tough stalks removed     H  50-846
# 1971    13-880            Pepper, black    Literature sources     H  13-846
# 1976    13-847  Pepper, cayenne, ground    Literature sources     H      NaN
# 1977    13-881            Pepper, white    Literature sources     H  13-848
#
#                                    Main data references Footnote Energy (kJ)  \
# 1863                                    USDA SR26, 2013      NaN        1321
# 1866  Marsh et al. (1977) Composition of foods: spic...      NaN         986
# 1867  Reviewed 2013. IFR, The nutritional values of ...      NaN         183
# 1971                                    USDA SR26, 2013      NaN         511
# ...

# %%
H['Food Name'].unique()
# Out:
# array(['Paprika', 'Parsley, dried', 'Parsley, fresh', 'Pepper, black',
#        'Pepper, cayenne, ground', 'Pepper, white'], dtype=object)

# %%
Priority_H = ['Paprika','Parsley, fresh', 'Pepper, black']

# %% [markdown]
# **Reduced**

# %%
Filt_H = H[H['Food Name'].isin(Priority_H)]
Filt_H
# Out:
#      Food Code       Food Name           Description Group Previous  \
# 1863    13-879         Paprika    Literature sources     H  13-843
# 1867    13-844  Parsley, fresh  Tough stalks removed     H  50-846
# 1971    13-880   Pepper, black    Literature sources     H  13-846
#
#                                    Main data references Footnote Energy (kJ)  \
# 1863                                    USDA SR26, 2013      NaN        1321
# 1867  Reviewed 2013. IFR, The nutritional values of ...      NaN         183
# 1971                                    USDA SR26, 2013      NaN         511
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1863           319     12.9          2.14             19.1       10.3
# 1867            44      1.3          0.16              2.7        2.3
# 1971           124      3.3          1.39              0.6        0.6
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1863        8.8      34.9         14.1     0.17
# ...

# %%
Filt_H['Super Group'] = 'Herbs and Spices'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\854041242.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_H['Super Group'] = 'Herbs and Spices'

# %% [markdown]
#                                                 Fish and fish products

# %% [markdown]
# White fish

# %%
JA = Prod_P.loc[Prod_P['Group']== 'JA']
JA
# Out:
#      Food Code                                          Food Name  \
# 1856    16-432                       Pangasius, flesh only, baked
# 1857    16-433                     Pangasius, flesh only, poached
# 1858    16-382                         Pangasius, flesh only, raw
# 1865    16-101                                   Parrot fish, raw
# 2057    16-434                          Plaice, flesh only, baked
# 2058    16-381                            Plaice, flesh only, raw
# 2059    16-435                        Plaice, flesh only, steamed
# 2060    16-480  Plaice, flesh only, steamed, fillets weighed w...
# 2061    16-498            Plaice, in batter, fried in blended oil
# 2062    16-499       Plaice, in batter, fried in retail blend oil
# 2063    16-500          Plaice, in batter, fried in sunflower oil
# 2064    16-403                      Plaice, in breadcrumbs, baked
# 2081    16-436                Pollock, Alaskan, flesh only, baked
# ...

# %%
JA['Food Name'].unique()
# Out:
# array(['Pangasius, flesh only, baked', 'Pangasius, flesh only, poached',
#        'Pangasius, flesh only, raw', 'Parrot fish, raw',
#        'Plaice, flesh only, baked', 'Plaice, flesh only, raw',
#        'Plaice, flesh only, steamed',
#        'Plaice, flesh only, steamed, fillets weighed with bones and skin',
#        'Plaice, in batter, fried in blended oil',
#        'Plaice, in batter, fried in retail blend oil',
#        'Plaice, in batter, fried in sunflower oil',
#        'Plaice, in breadcrumbs, baked',
#        'Pollock, Alaskan, flesh only, baked',
#        'Pollock, Alaskan, flesh only, raw',
#        'Pollock, Alaskan, flesh only, steamed', 'Pomfret, black, raw',
#        'Pomfret, white, raw'], dtype=object)

# %%
Filt_JA = JA[JA['Food Name'] == 'Pollock, Alaskan, flesh only, raw']

# %%
Filt_JA['Super Group'] = 'Fish and fish products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\3467222932.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_JA['Super Group'] = 'Fish and fish products'

# %% [markdown]
# Crustacea

# %%
JK = Prod_P.loc[Prod_P['Group']== 'JK']
JK
# Out:
#      Food Code                                          Food Name  \
# 2240    16-388                     Prawns, king, grilled from raw
# 2241    16-389                     Prawns, king, purchased cooked
# 2242    16-481  Prawns, king, purchased cooked, weighed with s...
# 2243    16-387                                  Prawns, king, raw
# 2244    16-482                            Prawns, standard, dried
# 2245    16-384                 Prawns, standard, purchased cooked
#
#                                             Description Group Previous  \
# 2240  9 samples, 9 products, warm-water prawns (Pana...    JK      NaN
# 2241  11 samples, 11 products, warm-water prawns (Pe...    JK      NaN
# 2242  Calculated from 16-389 using edible portion of...    JK  16-240
# 2243  9 samples, 9 products, warm-water prawns (Pana...    JK      NaN
# 2244                             Calculated from 16-384    JK  16-242
# 2245  15 samples, 15 products, cold-water/Atlantic p...    JK  16-239
#
# ...

# %%
JK['Food Name'].unique()
# Out:
# array(['Prawns, king, grilled from raw', 'Prawns, king, purchased cooked',
#        'Prawns, king, purchased cooked, weighed with shells',
#        'Prawns, king, raw', 'Prawns, standard, dried',
#        'Prawns, standard, purchased cooked'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Filt_JK = JK[JK['Food Name'] == 'Prawns, king, raw']

# %%
Filt_JK['Super Group'] = 'Fish and fish products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\3956454164.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_JK['Super Group'] = 'Fish and fish products'

# %% [markdown]
# Removed JR - Fish products and dishes

# %% [markdown]
#                                                Meat and meat products

# %% [markdown]
# Pork

# %%
MAG = Prod_P.loc[Prod_P['Group']== 'MAG']
MAG
# Out:
#      Food Code                                          Food Name  \
# 2098    18-555           Pork, belly joint, roasted, lean and fat
# 2099    18-556    Pork, belly joint/slices, grilled, lean and fat
# 2100    18-557        Pork, belly joint/slices, raw, lean and fat
# 2101    18-558  Pork, belly joint/slices, raw, lean and fat, w...
# 2102    18-216                            Pork, crackling, cooked
# ...        ...                                                ...
# 2159    18-552  Pork, shoulder steaks (collar), grilled, lean ...
# 2160    18-554  Pork, shoulder steaks (collar), raw, lean and fat
# 2161    18-553  Pork, shoulder steaks (collar), raw, lean and ...
# 2166    18-499       Pork, spare ribs, Chinese barbecue, takeaway
# 2169    18-609                Pork, spare ribs, raw, lean and fat
#
#                                             Description Group       Previous  \
# 2098                   10 samples, 65% lean and 35% fat   MAG     243 18-208
# ...

# %%
MAG['Food Name'].unique()
# Out:
# array(['Pork, belly joint, roasted, lean and fat',
#        'Pork, belly joint/slices, grilled, lean and fat',
#        'Pork, belly joint/slices, raw, lean and fat',
#        'Pork, belly joint/slices, raw, lean and fat, weighed with bone',
#        'Pork, crackling, cooked', 'Pork, diced, casseroled, lean',
#        'Pork, diced, casseroled, lean and fat',
#        'Pork, diced, kebabs, grilled, lean',
#        'Pork, diced, kebabs, grilled, lean and fat',
#        'Pork, diced, raw, lean', 'Pork, diced, raw, lean and fat',
#        'Pork, fat, average, cooked', 'Pork, fat, average, raw',
#        'Pork, fillet medallions, grilled lean',
#        'Pork, fillet medallions, grilled, lean and fat',
#        'Pork, fillet medallions, raw, lean',
#        'Pork, fillet medallions, raw, lean and fat',
#        'Pork, fillet strips, stir-fried in rapeseed oil, lean',
#        'Pork, hand, shoulder joint, raw, lean',
#        'Pork, hand, shoulder joint, raw, lean and fat',
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_MAG = MAG[MAG['Food Name'] == 'Pork, spare ribs, raw, lean and fat']

# %%
Filt_MAG['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\3809497956.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_MAG['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Removed MCA

# %% [markdown]
# Removed MCI

# %% [markdown]
# Removed MCK

# %% [markdown]
# Removed MCM

# %% [markdown]
# Removed MG

# %% [markdown]
# Removed MI

# %% [markdown]
# Removed MR

# %% [markdown]
# Removed PE

# %% [markdown]
# Removed Q

# %% [markdown]
#                                                    Alcoholic beverages

# %% [markdown]
# Fortified wines

# %%
QF = Prod_P.loc[Prod_P['Group']== 'QF']
QF
# Out:
#      Food Code Food Name            Description Group  Previous  \
# 2179    17-234      Port  19-21% ABV, 2 samples    QF  50-1113
#
#                                    Main data references Footnote Energy (kJ)  \
# 2179  Reviewed 2013. MW4, 1978. Additional data from...      NaN         665
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2179           159      0.0             0             11.9       11.9
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2179          0         0          0.1     0.01

# %%
QF['Super Group'] = 'Alcoholic beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\3269962276.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   QF['Super Group'] = 'Alcoholic beverages'

# %% [markdown]
#                                                 Sugars, preserves and snacks

# %%
SEC = Prod_P.loc[Prod_P['Group']== 'SEC']
SEC
# Out:
#      Food Code                    Food Name  \
# 1933    17-116     Peanut brittle, homemade
# 1978    17-830  Peppermint creams, homemade
# 1979    17-117                  Peppermints
#
#                                 Description Group  Previous  \
# 1933                                 Recipe   SEC       NaN
# 1978                                 Recipe   SEC   17-587
# 1979  Several samples of 6 different brands   SEC  50-1029
#
#                       Main data references Footnote Energy (kJ) Energy (kcal)  \
# 1933  Miscellaneous Foods Supplement, 1994      NaN        2067           492
# 1978                          Updated 2014      NaN        1580           372
# 1979              Reviewed 2013. MW3, 1960      NaN        1698           400
#
#       Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1933     19.0           5.3             70.7       68.7        1.9         2
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_SEC = SEC[SEC['Food Name'] == 'Peppermints']
Filt_SEC
# Out:
#      Food Code    Food Name                            Description Group  \
# 1979    17-117  Peppermints  Several samples of 6 different brands   SEC
#
#       Previous      Main data references Footnote Energy (kJ) Energy (kcal)  \
# 1979  50-1029   Reviewed 2013. MW3, 1960      NaN        1698           400
#
#       Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1979      0.7             N             97.9       97.9          0         0
#
#       Protein (g) Salt (g)
# 1979          0.5     0.02

# %%
Filt_SEC['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\1700206133.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_SEC['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
# Savoury snacks

# %%
SN = Prod_P.loc[Prod_P['Group']== 'SN']
SN
# Out:
#      Food Code                Food Name  \
# 2091    17-691         Popcorn, candied
# 2092    17-692  Popcorn, salted, retail
# 2097    17-132         Pork scratchings
# 2180    17-849            Pot savouries
# 2181    17-682   Pot savouries, made up
# 2204    17-693   Potato crisps, low fat
# 2212    17-643             Potato rings
#
#                                             Description Group Previous  \
# 2091                     Estimated from 2013 label data    SN  17-130
# 2092                          Estimated from label data    SN  17-131
# 2097                               19 samples, 4 brands    SN  17-477
# 2180  6 samples including assorted flavours of noodl...    SN  17-143
# 2181               85g product made up with 215ml water    SN  17-144
# 2204  20 samples of different brands, plain and flav...    SN  17-496
# 2212  10 samples, 7 products, including Hula Hoops a...    SN  17-142
#
# ...

# %%
SN['Food Name'].unique()
# Out:
# array(['Popcorn, candied', 'Popcorn, salted, retail', 'Pork scratchings',
#        'Pot savouries', 'Pot savouries, made up',
#        'Potato crisps, low fat', 'Potato rings'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_SN = ['Popcorn, salted, retail', 'Pork scratchings','Potato crisps, low fat']

# %%
Filt_SN = SN[SN['Food Name'].isin(Priority_SN)]

# %%
Filt_SN['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\3282033976.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_SN['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
# Removed SNA

# %% [markdown]
#                                         Soups, sauces and miscellaneous foods

# %% [markdown]
# Sauces

# %%
WC = Prod_P.loc[Prod_P['Group']== 'WC']
WC
# Out:
#      Food Code     Food Name             Description Group Previous  \
# 1988    17-622  Pesto, green  10 samples, 6 products    WC      NaN
# 1989    17-623    Pesto, red   8 samples, 7 products    WC      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1988  LGC, Nutrient analysis of pasta and pasta sauc...      NaN        1708
# 1989  LGC, Nutrient analysis of pasta and pasta sauc...      NaN        1339
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1988           414     42.5           6.5              3.7        2.3
# 1989           324     30.6          4.68              5.7        5.1
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1988        1.5       1.3          3.6      2.1
# 1989        0.6       3.3          4.9     1.93

# %%
Filt_WC = WC[WC['Food Name'] == 'Pesto, red']

# %%
Filt_WC['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\181086650.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_WC['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
# Salad sauces, dressings and pickles

# %%
WCG = Prod_P.loc[Prod_P['Group']== 'WCG']
WCG
# Out:
#      Food Code      Food Name          Description Group Previous  \
# 1994    17-718  Pickle, sweet  9 samples, 4 brands   WCG  17-352
#
#                                    Main data references Footnote Energy (kJ)  \
# 1994  LFRA, Nutrient analysis of miscellaneous foods...      NaN         514
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1994           121      0.1             0             27.3       24.2
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1994        3.1       1.2          0.6     2.83

# %%
WCG['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\2463262898.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WCG['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
# Non-salad sauces

# %%
WCN = Prod_P.loc[Prod_P['Group']== 'WCN']
WCN
# Out:
#      Food Code   Food Name                                        Description  \
# 1993    17-702  Piccalilli  9 samples, 4 brands; mild, saucy and sweet var...
#
#      Group Previous                               Main data references  \
# 1993   WCN  17-347   Miscellaneous Foods Supplement, 1994; and indu...
#
#      Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 1993      NaN         363            86      0.5           0.1
#
#      Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1993             17.3       14.7        2.5         1          1.0     1.85

# %%
WCN['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_24608\1581429497.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WCN['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
#                                               **Join Reduced Tables**

# %%
Red = pd.concat([Filt_A,Filt_AD], axis=0, join='inner')
Red
# Out:
#      Food Code                                  Food Name  \
# 2050    11-936           Pizza, cheese and tomato, retail
# 2174    11-788                 Porridge oats, unfortified
# 1888    11-450                Pasta, plain, fresh, boiled
# 1890    11-735  Pasta, spaghetti, canned, in tomato sauce
#
#                                             Description Group  Previous  \
# 2050  11 samples, 10 products, frozen and chilled, a...     A   11-553
# 2174  18 samples, 10 products, Quaker and other/own ...     A   11-017
# 1888  12 Samples, 8 brands including spaghetti, tagl...    AD  11-397
# 1890                             10 samples, 9 products    AD   11-357
#
#                                    Main data references Footnote Energy (kJ)  \
# 2050  DH, Nutrient analysis of a range of processed ...      NaN        1154
# 2174    LGC, Nutrient survey of breakfast cereals, 2004      NaN        1654
# 1888  RHM (1995) Nutrient content of selected foods,...      NaN         675
# ...

# %%
Red2 = pd.concat([Red,Filt_AF], axis=0, join='inner')
Red2
# Out:
#      Food Code                                  Food Name  \
# 2050    11-936           Pizza, cheese and tomato, retail
# 2174    11-788                 Porridge oats, unfortified
# 1888    11-450                Pasta, plain, fresh, boiled
# 1890    11-735  Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                         Papadums, takeaway
#
#                                             Description Group  Previous  \
# 2050  11 samples, 10 products, frozen and chilled, a...     A   11-553
# 2174  18 samples, 10 products, Quaker and other/own ...     A   11-017
# 1888  12 Samples, 8 brands including spaghetti, tagl...    AD  11-397
# 1890                             10 samples, 9 products    AD   11-357
# 1859                  10 samples from different outlets    AF   11-464
#
#                                    Main data references Footnote Energy (kJ)  \
# 2050  DH, Nutrient analysis of a range of processed ...      NaN        1154
# ...

# %%
Red3 = pd.concat([Red2,Filt_AO], axis=0, join='inner')
Red3
# Out:
#      Food Code                                  Food Name  \
# 2050    11-936           Pizza, cheese and tomato, retail
# 2174    11-788                 Porridge oats, unfortified
# 1888    11-450                Pasta, plain, fresh, boiled
# 1890    11-735  Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                         Papadums, takeaway
# 1915    11-853         Pastry, shortcrust, retail, cooked
#
#                                             Description Group  Previous  \
# 2050  11 samples, 10 products, frozen and chilled, a...     A   11-553
# 2174  18 samples, 10 products, Quaker and other/own ...     A   11-017
# 1888  12 Samples, 8 brands including spaghetti, tagl...    AD  11-397
# 1890                             10 samples, 9 products    AD   11-357
# 1859                  10 samples from different outlets    AF   11-464
# 1915  Calculated from uncooked, using weight loss of...    AO       NaN
#
# ...

# %%
Red4 = pd.concat([Red3,Filt_AP], axis=0, join='inner')
Red4
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
#
#                                             Description Group  Previous  \
# 2050  11 samples, 10 products, frozen and chilled, a...     A   11-553
# 2174  18 samples, 10 products, Quaker and other/own ...     A   11-017
# 1888  12 Samples, 8 brands including spaghetti, tagl...    AD  11-397
# 1890                             10 samples, 9 products    AD   11-357
# 1859                  10 samples from different outlets    AF   11-464
# ...

# %%
Red5 = pd.concat([Red4,Filt_AS], axis=0, join='inner')
Red5
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
#
#                                             Description Group  Previous  \
# 2050  11 samples, 10 products, frozen and chilled, a...     A   11-553
# ...

# %%
Red6 = pd.concat([Red5,Filt_AT], axis=0, join='inner')
Red6
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
# 2239   11-1023                           Prawn crackers, takeaway
#
#                                             Description Group  Previous  \
# ...

# %%
Red7 = pd.concat([Red6,Filt_BR], axis=0, join='inner')
Red7
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
# 2239   11-1023                           Prawn crackers, takeaway
# 2265    12-553                     Pudding, rice, canned, low fat
#
# ...

# %%
Red8 = pd.concat([Red7,Filt_DA], axis=0, join='inner')
Red8
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
# 2239   11-1023                           Prawn crackers, takeaway
# 2265    12-553                     Pudding, rice, canned, low fat
# ...

# %%
Red9 = pd.concat([Red8,Filt_DAP], axis=0, join='inner')
Red9
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
# 2239   11-1023                           Prawn crackers, takeaway
# 2265    12-553                     Pudding, rice, canned, low fat
# ...

# %%
Red10 = pd.concat([Red9,Filt_DAR], axis=0, join='inner')
Red10
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
# 2239   11-1023                           Prawn crackers, takeaway
# 2265    12-553                     Pudding, rice, canned, low fat
# ...

# %%
Red11 = pd.concat([Red10,Filt_DF], axis=0, join='inner')
Red11
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
# 2239   11-1023                           Prawn crackers, takeaway
# 2265    12-553                     Pudding, rice, canned, low fat
# ...

# %%
Red12 = pd.concat([Red11,Filt_DG], axis=0, join='inner')
Red12
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
# 2239   11-1023                           Prawn crackers, takeaway
# 2265    12-553                     Pudding, rice, canned, low fat
# ...

# %%
Red13 = pd.concat([Red12,Filt_F], axis=0, join='inner')
Red13
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
# 2239   11-1023                           Prawn crackers, takeaway
# 2265    12-553                     Pudding, rice, canned, low fat
# ...

# %%
Red14 = pd.concat([Red13,Filt_FA], axis=0, join='inner')
Red14
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
# 2239   11-1023                           Prawn crackers, takeaway
# 2265    12-553                     Pudding, rice, canned, low fat
# ...

# %%
Red15 = pd.concat([Red14,FC], axis=0, join='inner')
Red15
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
# 2239   11-1023                           Prawn crackers, takeaway
# 2265    12-553                     Pudding, rice, canned, low fat
# ...

# %%
Red16 = pd.concat([Red15,Filt_GA], axis=0, join='inner')
Red16
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
# 2239   11-1023                           Prawn crackers, takeaway
# 2265    12-553                     Pudding, rice, canned, low fat
# ...

# %%
Red17 = pd.concat([Red16,Filt_H], axis=0, join='inner')
Red17
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
# 2239   11-1023                           Prawn crackers, takeaway
# 2265    12-553                     Pudding, rice, canned, low fat
# ...

# %%
Red18 = pd.concat([Red17,Filt_JA], axis=0, join='inner')
Red18
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
# 2239   11-1023                           Prawn crackers, takeaway
# 2265    12-553                     Pudding, rice, canned, low fat
# ...

# %%
Red19 = pd.concat([Red18,Filt_JK], axis=0, join='inner')
Red19
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
# 2239   11-1023                           Prawn crackers, takeaway
# 2265    12-553                     Pudding, rice, canned, low fat
# ...

# %%
Red20 = pd.concat([Red19,Filt_MAG], axis=0, join='inner')
Red20
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
# 2239   11-1023                           Prawn crackers, takeaway
# 2265    12-553                     Pudding, rice, canned, low fat
# ...

# %%
Red21 = pd.concat([Red20,QF], axis=0, join='inner')
Red21
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
# 2239   11-1023                           Prawn crackers, takeaway
# 2265    12-553                     Pudding, rice, canned, low fat
# ...

# %%
Red22 = pd.concat([Red21,Filt_SEC], axis=0, join='inner')
Red22
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
# 2239   11-1023                           Prawn crackers, takeaway
# 2265    12-553                     Pudding, rice, canned, low fat
# ...

# %%
Red23 = pd.concat([Red22,Filt_SN], axis=0, join='inner')
Red23
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
# 2239   11-1023                           Prawn crackers, takeaway
# 2265    12-553                     Pudding, rice, canned, low fat
# ...

# %%
Red24 = pd.concat([Red23,Filt_WC], axis=0, join='inner')
Red24
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
# 2239   11-1023                           Prawn crackers, takeaway
# 2265    12-553                     Pudding, rice, canned, low fat
# ...

# %%
Red25 = pd.concat([Red24,WCG], axis=0, join='inner')
Red25
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
# 2239   11-1023                           Prawn crackers, takeaway
# 2265    12-553                     Pudding, rice, canned, low fat
# ...

# %%
Red26 = pd.concat([Red25,WCN], axis=0, join='inner')
Red26
# Out:
#      Food Code                                          Food Name  \
# 2050    11-936                   Pizza, cheese and tomato, retail
# 2174    11-788                         Porridge oats, unfortified
# 1888    11-450                        Pasta, plain, fresh, boiled
# 1890    11-735          Pasta, spaghetti, canned, in tomato sauce
# 1859    11-998                                 Papadums, takeaway
# 1915    11-853                 Pastry, shortcrust, retail, cooked
# 1900    11-844  Pastries, chocolate eclairs, cream filled, retail
# 1854   11-1141  Pancakes, sweet, made with skimmed milk, homemade
# 1998    11-921           Pie, apple, pastry, double crust, retail
# 2011    11-847                     Pie, fruit, individual, retail
# 2270   11-1119                          Pudding, sponge, homemade
# 2239   11-1023                           Prawn crackers, takeaway
# 2265    12-553                     Pudding, rice, canned, low fat
# ...

# %% [markdown]
#                                                        Export

# %%
Red26.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced_P.csv')
