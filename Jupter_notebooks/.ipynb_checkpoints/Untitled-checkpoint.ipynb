# %% [markdown]
# # Product Weighting Project

# %% [markdown]
#                                          Data Reduction - Food Purchased In Store

# %% [markdown]
# ###### Import Necessary Libraries

# %%
import pandas as pd
import os
import glob

# %% [markdown]
# Read in Data

# %%
Labelled = pd.read_csv(r'C:\Users\medek5bar\Desktop\Product_Weight_Project\Data\Processed\Labelling2021_watercress.csv')

# %% [markdown]
# ### Total Size of original Table

# %%
Labelled.shape
# Out:
# (2887, 17)

# %% [markdown]
# ## *Reading In all reduced Tables*

# %%
# Get a list of all the CSV files in the current directory.
csv_files = glob.glob(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\*.csv')
print(csv_files)

# Loop through the list of CSV files and read each file into a Pandas DataFrame.
df = pd.DataFrame()
for csv_file in csv_files:
    df = df.append(pd.read_csv(csv_file))

# Did it work ?.
print('This worked ')
# Out:
# ['C:\\Users\\medekar\\Desktop\\Product_Weight_Project\\Data\\Processed\\Reduced_A.csv', 'C:\\Users\\medekar\\Desktop\\Product_Weight_Project\\Data\\Processed\\Reduced_B.csv', 'C:\\Users\\medekar\\Desktop\\Product_Weight_Project\\Data\\Processed\\Reduced_C.csv', 'C:\\Users\\medekar\\Desktop\\Product_Weight_Project\\Data\\Processed\\Reduced_D.csv', 'C:\\Users\\medekar\\Desktop\\Product_Weight_Project\\Data\\Processed\\Reduced_E.csv', 'C:\\Users\\medekar\\Desktop\\Product_Weight_Project\\Data\\Processed\\Reduced_F.csv', 'C:\\Users\\medekar\\Desktop\\Product_Weight_Project\\Data\\Processed\\Reduced_G.csv', 'C:\\Users\\medekar\\Desktop\\Product_Weight_Project\\Data\\Processed\\Reduced_H.csv', 'C:\\Users\\medekar\\Desktop\\Product_Weight_Project\\Data\\Processed\\Reduced_I.csv', 'C:\\Users\\medekar\\Desktop\\Product_Weight_Project\\Data\\Processed\\Reduced_J.csv', 'C:\\Users\\medekar\\Desktop\\Product_Weight_Project\\Data\\Processed\\Reduced_K.csv', 'C:\\Users\\medekar\\Desktop\\Product_We
# ...

# %% [markdown]
#                                               **Reduced Table**

# %%
df
# Out:
#     Unnamed: 0 Food Code                                          Food Name  \
# 0           40    11-001                                          Arrowroot
# 1            0    13-145                             Ackee, canned, drained
# 2            1    13-146                                        Agar, dried
# 3            3    13-148                               Alfalfa sprouts, raw
# 4           10    13-149                               Amaranth leaves, raw
# ..         ...       ...                                                ...
# 0         2885   11-1135  Yorkshire pudding, made with skimmed milk, hom...
# 1         2871    12-555                         Yogurt, Greek style, plain
# 2         2879    12-375                          Yogurt, whole milk, fruit
# 3         2863    13-398                                         Yam, baked
# 4         2867    17-517                                      Yeast extract
#
# ...

# %%
df.shape
# Out:
# (597, 19)

# %% [markdown]
# Percentage of Reduced food

# %%
f'My food reduction process left me with {round ((597/2887)*100, 2)}% of products'
# Out:
# 'My food reduction process left me with 20.68% of products'

# %% [markdown]
#                                                  Infomation to Focus on.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Food Code', 'Food Name', 'Description', 'Group',
#        'Previous', 'Main data references', 'Footnote', 'Energy (kJ)',
#        'Energy (kcal)', 'Fat (g)', 'Saturates (g)', 'Carbohydrate (g)',
#        'Sugars (g)', 'Starch (g)', 'Fibre (g)', 'Protein (g)', 'Salt (g)',
#        'Super Group'],
#       dtype='object')

# %%
Red_Table = df.drop(axis=1, columns=['Unnamed: 0','Previous', 'Main data references', 'Footnote', 'Energy (kJ)',
       'Energy (kcal)', 'Fat (g)', 'Saturates (g)', 'Carbohydrate (g)',
       'Sugars (g)', 'Starch (g)', 'Fibre (g)', 'Protein (g)', 'Salt (g)','Description'])
Red_Table
# Out:
#    Food Code                                          Food Name Group  \
# 0     11-001                                          Arrowroot    AA
# 1     13-145                             Ackee, canned, drained    DG
# 2     13-146                                        Agar, dried    DG
# 3     13-148                               Alfalfa sprouts, raw    DG
# 4     13-149                               Amaranth leaves, raw    DG
# ..       ...                                                ...   ...
# 0    11-1135  Yorkshire pudding, made with skimmed milk, hom...    AT
# 1     12-555                         Yogurt, Greek style, plain    BN
# 2     12-375                          Yogurt, whole milk, fruit    BN
# 3     13-398                                         Yam, baked    DG
# 4     17-517                                      Yeast extract    WY
#
#                               Super Group
# 0             Cereals and cereal products
# ...

# %%
Red_Table.to
