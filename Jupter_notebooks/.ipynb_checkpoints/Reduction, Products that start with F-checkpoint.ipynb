# %% [markdown]
# # Product Weighting Project

# %% [markdown]
#                                          Data Reduction - Food Purchased In Store

# %% [markdown]
# ###### Import Necessary Libraries

# %%
import pandas as pd

# %% [markdown]
# Read in Data

# %%
Labelled = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Labelling2021_watercress.csv')

# %% [markdown]
# ### Products beginning with a 'F'

# %%
Prod_F = Labelled.loc[Labelled['Food Name'].str.startswith('F')]
Prod_F.head()
# Out:
#      Food Code                                          Food Name  \
# 1104    19-131                 Faggots in gravy, retail, reheated
# 1105    19-464  Fajita, chicken, meat only, takeaway and resta...
# 1106    15-795           Falafel, fried in rapeseed oil, homemade
# 1107    12-497  Fat spread, low fat (26-39%), not polyunsatura...
# 1108    12-498  Fat spread, low fat (26-39%), not polyunsatura...
#
#                                             Description Group        Previous  \
# 1104  8 samples, 3 brands. 11-35% meat, chilled and ...    MR        50-509
# 1105  10 sub-samples, 2 from different establishment...    MR             NaN
# 1106  Recipe. Middle-Eastern dish. Deep fried chick ...    DR         15-514
# 1107  7 samples, 5 products, vegetable oil/dairy ble...    OA  17-552 17-017
# 1108  8 samples, 4 products, including Bertolli Ligh...    OA             NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# ...

# %% [markdown]
# Products within a Group (provide identification of the food group and food type to which the food belongs)

# %%
Prod_F.groupby('Group')['Food Name'].count()
# Out:
# Group
# AA     17
# AM      4
# AS      4
# BN      2
# BNS     1
# BR      1
# DG      3
# DR     13
# FA      9
# H       2
# JA      5
# JR     10
# MI      3
# MR      2
# OA      8
# PCA     2
# PCC     6
# PE      1
# SEC     3
# Name: Food Name, dtype: int64

# %% [markdown]
# ## *Reducing products based on its most basic form. Improve as you go on*

# %% [markdown]
#                                                  Cereals and cereal products

# %% [markdown]
# Flours, grains and starches

# %%
AA = Prod_F.loc[Prod_F['Group']== 'AA']
AA
# Out:
#      Food Code                              Food Name  \
# 1158    11-895                  Flour, chapati, brown
# 1159    11-894                  Flour, chapati, white
# 1160   11-1045                            Flour, corn
# 1161    11-899            Flour, gari (cassava flour)
# 1162    11-896                            Flour, gram
# 1163    11-016                 Flour, millet, foxtail
# 1164    11-021                            Flour, rice
# 1165    11-897                             Flour, rye
# 1166    11-898                            Flour, soya
# 1167    11-887      Flour, wheat, bread/strong, white
# 1168    11-892                    Flour, wheat, brown
# 1169    11-893      Flour, wheat, brown, bread/strong
# 1170    11-886       Flour, wheat, white, plain, soft
# 1171    11-888      Flour, wheat, white, self raising
# 1172    11-889                Flour, wheat, wholemeal
# 1173    11-890  Flour, wheat, wholemeal, bread/strong
# ...

# %%
AA['Food Name'].unique()
# Out:
# array(['Flour, chapati, brown', 'Flour, chapati, white', 'Flour, corn',
#        'Flour, gari (cassava flour)', 'Flour, gram',
#        'Flour, millet, foxtail', 'Flour, rice', 'Flour, rye',
#        'Flour, soya', 'Flour, wheat, bread/strong, white',
#        'Flour, wheat, brown', 'Flour, wheat, brown, bread/strong',
#        'Flour, wheat, white, plain, soft',
#        'Flour, wheat, white, self raising', 'Flour, wheat, wholemeal',
#        'Flour, wheat, wholemeal, bread/strong',
#        'Flour, wheat, wholemeal, self raising'], dtype=object)

# %%
Priority_AA = ['Flour, gari (cassava flour)', 'Flour, wheat, white, plain, soft']

# %% [markdown]
# **Reduced**

# %%
Filt_AA = AA[AA['Food Name'].isin(Priority_AA)]
Filt_AA
# Out:
#      Food Code                         Food Name              Description  \
# 1161    11-899       Flour, gari (cassava flour)    4 samples, 2 products
# 1170    11-886  Flour, wheat, white, plain, soft  14 samples, 12 products
#
#      Group Previous                             Main data references Footnote  \
# 1161    AA      NaN                   Flours and grains project 2005      NaN
# 1170    AA  11-439   LGC, Nutrient survey of flours and grains, 2005      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 1161        1528           360      0.2          0.04             86.5
# 1170        1505           355      1.4          0.44             73.6
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1161          0       82.5       4.6          0.8     0.01
# 1170        0.6         73         4         10.0     0.01

# %%
Filt_AA['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_25628\3855606877.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AA['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Biscuits

# %%
AM = Prod_F.loc[Prod_F['Group']== 'AM']
AM
# Out:
#      Food Code                             Food Name             Description  \
# 1121    11-805                             Fig Rolls  10 samples, 5 products
# 1152   11-1071                   Flapjacks, homemade                  Recipe
# 1153    11-814                     Flapjacks, retail  10 samples, 9 products
# 1154   11-1128  Flapjacks, retail, chocolate covered                  Recipe
#
#      Group Previous                               Main data references  \
# 1121    AM  11-409   DH, Nutrient analysis of biscuits, buns, cakes...
# 1152    AM  11-571                                        Updated 2014
# 1153    AM      NaN  DH, Nutrient analysis of biscuits, buns, cakes...
# 1154    AM      NaN                                       Updated 2014
#
#      Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 1121      NaN        1584           376     10.6          4.76
# 1152      NaN        1974           472     24.0          7.45
# ...

# %%
AM['Food Name'].unique()
# Out:
# array(['Fig Rolls', 'Flapjacks, homemade', 'Flapjacks, retail',
#        'Flapjacks, retail, chocolate covered'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_AM = ['Fig Rolls', 'Flapjacks, retail']

# %%
Filt_AM = AM[AM['Food Name'].isin(Priority_AM)]
Filt_AM
# Out:
#      Food Code          Food Name             Description Group Previous  \
# 1121    11-805          Fig Rolls  10 samples, 5 products    AM  11-409
# 1153    11-814  Flapjacks, retail  10 samples, 9 products    AM      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1121  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1584
# 1153  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1867
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1121           376     10.6          4.76             63.6       42.7
# 1153           447     22.8         10.25             52.3       28.2
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1121       20.9       3.9          4.6     0.68
# 1153       24.1       5.2          5.4     0.49

# %%
Filt_AM['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_25628\1616565383.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AM['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Removed AS. I have other puddings from earlier

# %% [markdown]
#                                                     Milk and milk products

# %% [markdown]
# Yogurts

# %%
BN = Prod_F.loc[Prod_F['Group']== 'BN']
BN
# Out:
#      Food Code                                   Food Name  \
# 1180    12-372    Fromage frais, virtually fat free, fruit
# 1181    12-528  Fromage frais, virtually fat free, natural
#
#                                             Description Group        Previous  \
# 1180  11 samples, 6 brands, including strawberry, ra...    BN  50-241 12-160
# 1181                                7 samples, 6 brands    BN         12-371
#
#                                    Main data references Footnote Energy (kJ)  \
# 1180  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN         218
# 1181  Campden and Chorleywood FRA, Nutrient analysis...      NaN         206
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1180            52      0.2           0.1              5.4        4.8
# 1181            48      0.1           0.1              4.4        4.2
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1180        0.6       0.7          6.7     0.08
# ...

# %%
BN['Food Name'].unique()
# Out:
# array(['Fromage frais, virtually fat free, fruit',
#        'Fromage frais, virtually fat free, natural'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Filt_BN = BN.loc[BN['Food Name'] == 'Fromage frais, virtually fat free, natural']
Filt_BN
# Out:
#      Food Code                                   Food Name  \
# 1181    12-528  Fromage frais, virtually fat free, natural
#
#               Description Group Previous  \
# 1181  7 samples, 6 brands    BN  12-371
#
#                                    Main data references Footnote Energy (kJ)  \
# 1181  Campden and Chorleywood FRA, Nutrient analysis...      NaN         206
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1181            48      0.1           0.1              4.4        4.2
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1181        0.2         0          7.5     0.09

# %%
Filt_BN['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_25628\1830459702.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_BN['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Removed BNS - Fromage frais, fruit, children's, fortified

# %% [markdown]
# Puddings and chilled desserts

# %%
BR = Prod_F.loc[Prod_F['Group']== 'BR']
BR
# Out:
#      Food Code             Food Name Description Group Previous  \
# 1184    12-232  Fruit fool, homemade      Recipe    BR  12-913
#
#                                    Main data references Footnote Energy (kJ)  \
# 1184  As Milk Products and Eggs Supplement (1989) 12...      NaN         702
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1184           168      9.3           5.8               19       15.3
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1184        3.7       1.2          1.0     0.03

# %%
BR['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_25628\1314462780.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BR['Super Group'] = 'Milk and milk products'

# %% [markdown]
#                                                        Vegetables

# %% [markdown]
# Vegetables, general

# %%
DG = Prod_F.loc[Prod_F['Group']== 'DG']
DG
# Out:
#      Food Code                                   Food Name  \
# 1117    13-542  Fennel, Florence, boiled in unsalted water
# 1118    13-241                       Fennel, Florence, raw
# 1119    13-243                       Fenugreek leaves, raw
#
#                                             Description Group Previous  \
# 1117  As raw, boiled for 14 minutes, based on boiled...    DG      NaN
# 1118                         Inner leaves and bulb only    DG  50-770
# 1119                                 Literature sources    DG      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1117  Reviewed 2013. IFR, The nutritional compositio...      NaN          79
# 1118  Reviewed 2013. IFR, The nutritional compositio...      NaN          83
# 1119      Vegetables, Herbs and Spices Supplement, 1991      NaN         203
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# ...

# %%
DG['Food Name'].unique()
# Out:
# array(['Fennel, Florence, boiled in unsalted water',
#        'Fennel, Florence, raw', 'Fenugreek leaves, raw'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_DG = ['Fennel, Florence, raw', 'Fenugreek leaves, raw']

# %%
Filt_DG = DG[DG['Food Name'].isin(Priority_DG)]
Filt_DG
# Out:
#      Food Code              Food Name                 Description Group  \
# 1118    13-241  Fennel, Florence, raw  Inner leaves and bulb only    DG
# 1119    13-243  Fenugreek leaves, raw          Literature sources    DG
#
#      Previous                               Main data references Footnote  \
# 1118  50-770   Reviewed 2013. IFR, The nutritional compositio...      NaN
# 1119      NaN      Vegetables, Herbs and Spices Supplement, 1991      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 1118          83            20      0.2             0              1.8
# 1119         203            49      0.2          0.05              4.6
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1118        1.7        0.1       3.1          0.9     0.03
# 1119        2.8        1.8       4.9          4.6     0.19

# %%
Filt_DG['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_25628\1311392366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DG['Super Group'] = 'Vegetables'

# %% [markdown]
# Vegetable dishes

# %%
DR = Prod_F.loc[Prod_F['Group']== 'DR']
DR
# Out:
#      Food Code                                          Food Name  \
# 1106    15-795           Falafel, fried in rapeseed oil, homemade
# 1140    15-796                Flan, cheese and mushroom, homemade
# 1141    15-797     Flan, cheese and mushroom, wholemeal, homemade
# 1142    15-798           Flan, cheese, onion and potato, homemade
# 1143    15-799  Flan, cheese, onion and potato, wholemeal, hom...
# 1144    15-800                  Flan, lentil and tomato, homemade
# 1145    15-801       Flan, lentil and tomato, wholemeal, homemade
# 1147    15-802                            Flan, spinach, homemade
# 1148    15-803                 Flan, spinach, wholemeal, homemade
# 1150    15-804                          Flan, vegetable, homemade
# 1151    15-805               Flan, vegetable, wholemeal, homemade
# 1198    15-806                      Fu-fu, sweet potato, homemade
# 1199    15-807                               Fu-fu, yam, homemade
#
# ...

# %%
DR['Food Name'].unique()
# Out:
# array(['Falafel, fried in rapeseed oil, homemade',
#        'Flan, cheese and mushroom, homemade',
#        'Flan, cheese and mushroom, wholemeal, homemade',
#        'Flan, cheese, onion and potato, homemade',
#        'Flan, cheese, onion and potato, wholemeal, homemade',
#        'Flan, lentil and tomato, homemade',
#        'Flan, lentil and tomato, wholemeal, homemade',
#        'Flan, spinach, homemade', 'Flan, spinach, wholemeal, homemade',
#        'Flan, vegetable, homemade',
#        'Flan, vegetable, wholemeal, homemade',
#        'Fu-fu, sweet potato, homemade', 'Fu-fu, yam, homemade'],
#       dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_DR = ['Flan, vegetable, homemade', 'Fu-fu, yam, homemade']

# %%
Filt_DR = DR[DR['Food Name'].isin(Priority_DR)]
Filt_DR
# Out:
#      Food Code                  Food Name  \
# 1150    15-804  Flan, vegetable, homemade
# 1199    15-807       Fu-fu, yam, homemade
#
#                                             Description Group Previous  \
# 1150  Recipe from dietary survey records and dissect...    DR  15-372
# 1199  Recipe. West Indian/African dish. Yam and rice...    DR  15-525
#
#                                    Main data references Footnote Energy (kJ)  \
# 1150  Updated 2014. Vitamin K1 from Bolton-Smith et ...      NaN         969
# 1199                                       Updated 2014      NaN         640
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1150           233     15.6          6.68             16.3        2.5
# 1199           151      0.3          0.09             34.1        0.6
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1150       13.8       2.5          5.5     0.39
# 1199       33.5       1.5          2.2     0.04

# %%
Filt_DR['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_25628\2508077319.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DR['Super Group'] = 'Vegetables'

# %% [markdown]
#                                                             Fruit

# %% [markdown]
# Fruit, general

# %%
FA = Prod_F.loc[Prod_F['Group']== 'FA']
FA
# Out:
#      Food Code                                        Food Name  \
# 1115    14-090                               Feijoa, flesh only
# 1122    14-093                   Figs, dried, stewed with sugar
# 1123    14-094                Figs, dried, stewed without sugar
# 1124    14-395                   Figs, ready-to-eat, semi-dried
# 1125    14-092                         Figs, whole fruit, dried
# 1126    14-091                     Figs, whole green fruit, raw
# 1182    14-336  Fruit cocktail, canned in juice, whole contents
# 1183    14-097  Fruit cocktail, canned in syrup, whole contents
# 1196    14-333                            Fruit salad, homemade
#
#                                             Description Group Previous  \
# 1115                                 Literature sources    FA      NaN
# 1122  Calculated from 450g fruit, 450g water, 54g sugar    FA      NaN
# 1123             Calculated from 450g fruit, 450g water    FA      NaN
# ...

# %%
FA['Food Name'].unique()
# Out:
# array(['Feijoa, flesh only', 'Figs, dried, stewed with sugar',
#        'Figs, dried, stewed without sugar',
#        'Figs, ready-to-eat, semi-dried', 'Figs, whole fruit, dried',
#        'Figs, whole green fruit, raw',
#        'Fruit cocktail, canned in juice, whole contents',
#        'Fruit cocktail, canned in syrup, whole contents',
#        'Fruit salad, homemade'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_FA = ['Figs, whole green fruit, raw', 'Fruit cocktail, canned in juice, whole contents','Fruit salad, homemade']

# %%
Filt_FA = FA[FA['Food Name'].isin(Priority_FA)]
Filt_FA
# Out:
#      Food Code                                        Food Name  \
# 1126    14-091                     Figs, whole green fruit, raw
# 1182    14-336  Fruit cocktail, canned in juice, whole contents
# 1196    14-333                            Fruit salad, homemade
#
#                                             Description Group Previous  \
# 1126                   Analysis and literature sources;    FA      NaN
# 1182   10 samples, 6 brands.  Drained proportion = 0.65    FA  14-096
# 1196  Recipe, including apples, oranges, bananas, ki...    FA  14-303
#
#                                    Main data references Footnote Energy (kJ)  \
# 1126                    Fruit and Nuts Supplement, 1992      NaN         210
# 1182  LGC, Nutritional composition of fruit products...      NaN         221
# 1196             Recipe from NDNS survey. Updated  2013      NaN         284
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# ...

# %%
Filt_FA['Super Group'] = 'Fruit'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_25628\3797725470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_FA['Super Group'] = 'Fruit'

# %% [markdown]
#                                                 Fish and fish products

# %% [markdown]
# Removed JA.

# %%
JR = Prod_F.loc[Prod_F['Group']== 'JR']
JR
# Out:
#      Food Code                                        Food Name  \
# 1127    16-279                              Fish balls, steamed
# 1128    16-444         Fish fingers, cod, fried in rapeseed oil
# 1129    16-445        Fish fingers, cod, fried in sunflower oil
# 1130    16-405                 Fish fingers, cod, grilled/baked
# 1131    16-371                   Fish fingers, pollock, grilled
# 1132    16-406              Fish fingers, salmon, grilled/baked
# 1133    16-450                                       Fish paste
# 1134    16-458                         Fishcakes, cod, homemade
# 1135    16-408  Fishcakes, salmon, coated in breadcrumbs, baked
# 1136    16-459                      Fishcakes, salmon, homemade
#
#                                             Description Group Previous  \
# 1127           7 varieties from different Chinese shops    JR      NaN
# 1128  Calculated from grilled/baked 16-405 using ana...    JR  16-289
# ...

# %%
JR['Food Name'].unique()
# Out:
# array(['Fish balls, steamed', 'Fish fingers, cod, fried in rapeseed oil',
#        'Fish fingers, cod, fried in sunflower oil',
#        'Fish fingers, cod, grilled/baked',
#        'Fish fingers, pollock, grilled',
#        'Fish fingers, salmon, grilled/baked', 'Fish paste',
#        'Fishcakes, cod, homemade',
#        'Fishcakes, salmon, coated in breadcrumbs, baked',
#        'Fishcakes, salmon, homemade'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_JR = ['Fishcakes, cod, homemade','Fish fingers, cod, grilled/baked']

# %%
Filt_JR = JR[JR['Food Name'].isin(Priority_JR)]
Filt_JR
# Out:
#      Food Code                         Food Name  \
# 1130    16-405  Fish fingers, cod, grilled/baked
# 1134    16-458          Fishcakes, cod, homemade
#
#                          Description Group Previous  \
# 1130  10 samples, 7 products, frozen    JR  16-288
# 1134                          Recipe    JR  16-352
#
#                                    Main data references Footnote Energy (kJ)  \
# 1130  DH, Nutrient analysis of fish and fish product...      NaN         942
# 1134                                       Updated 2014      NaN         978
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1130           225      9.2          1.19             20.2        1.4
# 1134           235     14.7          1.31             13.8        0.6
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1130       18.7         2         14.3     0.79
# 1134       13.2       0.7         11.4     0.23

# %%
Filt_JR['Super Group'] = 'Fish and fish products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_25628\2834644775.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_JR['Super Group'] = 'Fish and fish products'

# %% [markdown]
#                                                 Meat and meat products

# %% [markdown]
# Meat products

# %%
MI = Prod_F.loc[Prod_F['Group']== 'MI']
MI
# Out:
#      Food Code                                          Food Name  \
# 1176    19-495                                        Frankfurter
# 1177    19-581                               Frankfurter with bun
# 1178    19-582  Frankfurter with bun, ketchup, fried onions an...
#
#                                             Description Group Previous  \
# 1176  10 samples, 7 brands of continental style fran...    MI      NaN
# 1177                                             Recipe    MI  19-581
# 1178                                             Recipe    MI  19-367
#
#                                    Main data references Footnote Energy (kJ)  \
# 1176  LGC, Analytical survey of meat products, 1990-...      NaN        1189
# 1177                                       Updated 2014      NaN        1117
# 1178                                       Updated 2014      NaN         815
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# ...

# %%
MI['Food Name'].unique()
# Out:
# array(['Frankfurter', 'Frankfurter with bun',
#        'Frankfurter with bun, ketchup, fried onions and mustard'],
#       dtype=object)

# %% [markdown]
# **Reduced**

# %%
Filt_MI = MI.loc[MI['Food Name'] == 'Frankfurter']
Filt_MI
# Out:
#      Food Code    Food Name  \
# 1176    19-495  Frankfurter
#
#                                             Description Group Previous  \
# 1176  10 samples, 7 brands of continental style fran...    MI      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1176  LGC, Analytical survey of meat products, 1990-...      NaN        1189
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1176           287     25.4           9.2              1.1        1.1
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1176          0       0.1         13.6     1.83

# %%
Filt_MI['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_25628\1350248321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_MI['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Meat dishes

# %%
MR = Prod_F.loc[Prod_F['Group']== 'MR']
MR
# Out:
#      Food Code                                          Food Name  \
# 1104    19-131                 Faggots in gravy, retail, reheated
# 1105    19-464  Fajita, chicken, meat only, takeaway and resta...
#
#                                             Description Group  Previous  \
# 1104  8 samples, 3 brands. 11-35% meat, chilled and ...    MR  50-509
# 1105  10 sub-samples, 2 from different establishment...    MR       NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1104  Reviewed 2013. LGC, Nutritional analysis of me...      NaN         615
# 1105  Reviewed 2013. Aspland and James Ltd, Nutrient...      NaN         530
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1104           147      7.5           2.5             11.6        1.7
# 1105           127      6.3          2.12              0.3          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1104        9.8       0.2          8.2     1.35
# ...

# %% [markdown]
# **Reduced**

# %%
MR['Food Name'].unique()
# Out:
# array(['Faggots in gravy, retail, reheated',
#        'Fajita, chicken, meat only, takeaway and restaurant'],
#       dtype=object)

# %%
Filt_MR = MR.loc[MR['Food Name'] == 'Faggots in gravy, retail, reheated']
Filt_MR
# Out:
#      Food Code                           Food Name  \
# 1104    19-131  Faggots in gravy, retail, reheated
#
#                                             Description Group  Previous  \
# 1104  8 samples, 3 brands. 11-35% meat, chilled and ...    MR  50-509
#
#                                    Main data references Footnote Energy (kJ)  \
# 1104  Reviewed 2013. LGC, Nutritional analysis of me...      NaN         615
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1104           147      7.5           2.5             11.6        1.7
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1104        9.8       0.2          8.2     1.35

# %%
Filt_MR['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_25628\3346374556.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_MR['Super Group'] = 'Meat and meat products'

# %% [markdown]
# removed OA

# %% [markdown]
#                                                        Beverages

# %% [markdown]
# Soft drinks/Carbonated drinks

# %%
PCA = Prod_F.loc[Prod_F['Group']== 'PCA']
PCA
# Out:
#      Food Code                                          Food Name  \
# 1186    17-673  Fruit juice drink, carbonated, no added sugar,...
# 1187    17-735      Fruit juice drink, carbonated, ready to drink
#
#                                             Description Group Previous  \
# 1186  Estimated from fruit juice drink, carbonated a...   PCA      NaN
# 1187  Bottles and cans; orange, lemon, apple and tro...   PCA  17-177
#
#               Main data references Footnote Energy (kJ) Energy (kcal)  \
# 1186           Industry data, 2013      NaN          10             2
# 1187  Industry data, 1999 and 2013      NaN         117            28
#
#       Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1186      0.0             0              0.6        0.6          0         0
# 1187      0.0             0              6.9        6.9          0         0
#
#       Protein (g) Salt (g)
# 1186          0.0        0
# 1187          0.0     0.02

# %% [markdown]
# **Reduced**

# %%
Filt_PCA = PCA.loc[PCA['Food Name'] == 'Fruit juice drink, carbonated, ready to drink']
Filt_PCA
# Out:
#      Food Code                                      Food Name  \
# 1187    17-735  Fruit juice drink, carbonated, ready to drink
#
#                                             Description Group Previous  \
# 1187  Bottles and cans; orange, lemon, apple and tro...   PCA  17-177
#
#               Main data references Footnote Energy (kJ) Energy (kcal)  \
# 1187  Industry data, 1999 and 2013      NaN         117            28
#
#       Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1187      0.0             0              6.9        6.9          0         0
#
#       Protein (g) Salt (g)
# 1187          0.0     0.02

# %%
Filt_PCA['Super Group'] = 'Beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_25628\1940018051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_PCA['Super Group'] = 'Beverages'

# %% [markdown]
# Squash and cordials

# %%
PCC = Prod_F.loc[Prod_F['Group']== 'PCC']
PCC
# Out:
#      Food Code                                          Food Name  \
# 1188    17-742  Fruit juice drink, no added sugar, ready to drink
# 1189    17-847                  Fruit juice drink/squash, diluted
# 1190    17-846  Fruit juice drink/squash, no sugar added, diluted
# 1191    17-739  Fruit juice drink/squash, no sugar added, undi...
# 1192    17-741           Fruit juice drink/squash, ready to drink
# 1193    17-738                Fruit juice drink/squash, undiluted
#
#                                             Description Group Previous  \
# 1188  Typically less than 3% sugar, as purchased. 10...   PCC  17-196
# 1189     Calculated from 50g concentrate to 200ml water   PCC  17-190
# 1190     Calculated from 50g concentrate to 200ml water   PCC  17-192
# 1191  10 samples, 2 brands; lemon, orange and mixed ...   PCC  17-191
# 1192  Lemon, orange, apple and mixed fruit flavours,...   PCC  17-195
# 1193      Lemon, orange, apple and mixed fruit flavours   PCC  17-189
#
# ...

# %%
PCC['Food Name'].unique()
# Out:
# array(['Fruit juice drink, no added sugar, ready to drink',
#        'Fruit juice drink/squash, diluted',
#        'Fruit juice drink/squash, no sugar added, diluted',
#        'Fruit juice drink/squash, no sugar added, undiluted',
#        'Fruit juice drink/squash, ready to drink',
#        'Fruit juice drink/squash, undiluted'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Filt_PCC = PCC.loc[PCC['Food Name'] == 'Fruit juice drink/squash, undiluted']
Filt_PCC
# Out:
#      Food Code                            Food Name  \
# 1193    17-738  Fruit juice drink/squash, undiluted
#
#                                         Description Group Previous  \
# 1193  Lemon, orange, apple and mixed fruit flavours   PCC  17-189
#
#                                    Main data references Footnote Energy (kJ)  \
# 1193  LFRA, Nutritional analysis of soft drinks, 199...      NaN         152
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1193            36      0.0             0              8.8        8.8
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1193          0         0          0.1      0.1

# %%
Filt_PCC['Super Group'] = 'Beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_25628\801278599.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_PCC['Super Group'] = 'Beverages'

# %% [markdown]
# Removed PE

# %% [markdown]
#                                             Sugars, preserves and snacks

# %% [markdown]
# Non-chocolate confectionery

# %%
SEC = Prod_F.loc[Prod_F['Group']== 'SEC']
SEC
# Out:
#      Food Code           Food Name  \
# 1185    17-107  Fruit gums/jellies
# 1195    17-824     Fruit pastilles
# 1197    17-683     Fudge, homemade
#
#                                            Description Group  Previous  \
# 1185          11 samples, 10 brands; assorted flavours   SEC  50-1026
# 1195  6 samples of different brands; assorted flavours   SEC   17-108
# 1197                                            Recipe   SEC   17-518
#
#                                    Main data references Footnote Energy (kJ)  \
# 1185  Reviewed 2013. LGC, Nutritional analysis of fo...      NaN           N
# 1195  Reviewed 2013. LGC, Nutritional analysis of fo...      NaN           N
# 1197                                       Updated 2013      NaN        1849
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1185             N      0.0             0             57.9       56.2
# 1195             N      0.0             0               60       56.9
# ...

# %%
SEC['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_25628\382276731.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SEC['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
#                                               **Join Reduced Tables**

# %%
Red = pd.concat([Filt_AA,Filt_AM], axis=0, join='inner')
Red
# Out:
#      Food Code                         Food Name              Description  \
# 1161    11-899       Flour, gari (cassava flour)    4 samples, 2 products
# 1170    11-886  Flour, wheat, white, plain, soft  14 samples, 12 products
# 1121    11-805                         Fig Rolls   10 samples, 5 products
# 1153    11-814                 Flapjacks, retail   10 samples, 9 products
#
#      Group Previous                               Main data references  \
# 1161    AA      NaN                     Flours and grains project 2005
# 1170    AA  11-439     LGC, Nutrient survey of flours and grains, 2005
# 1121    AM  11-409   DH, Nutrient analysis of biscuits, buns, cakes...
# 1153    AM      NaN  DH, Nutrient analysis of biscuits, buns, cakes...
#
#      Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 1161      NaN        1528           360      0.2          0.04
# 1170      NaN        1505           355      1.4          0.44
# ...

# %%
Red2 = pd.concat([Red,Filt_BN], axis=0, join='inner')
Red2
# Out:
#      Food Code                                   Food Name  \
# 1161    11-899                 Flour, gari (cassava flour)
# 1170    11-886            Flour, wheat, white, plain, soft
# 1121    11-805                                   Fig Rolls
# 1153    11-814                           Flapjacks, retail
# 1181    12-528  Fromage frais, virtually fat free, natural
#
#                   Description Group Previous  \
# 1161    4 samples, 2 products    AA      NaN
# 1170  14 samples, 12 products    AA  11-439
# 1121   10 samples, 5 products    AM  11-409
# 1153   10 samples, 9 products    AM      NaN
# 1181      7 samples, 6 brands    BN  12-371
#
#                                    Main data references Footnote Energy (kJ)  \
# 1161                     Flours and grains project 2005      NaN        1528
# 1170    LGC, Nutrient survey of flours and grains, 2005      NaN        1505
# 1121  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1584
# ...

# %%
Red3 = pd.concat([Red2,BR], axis=0, join='inner')
Red3
# Out:
#      Food Code                                   Food Name  \
# 1161    11-899                 Flour, gari (cassava flour)
# 1170    11-886            Flour, wheat, white, plain, soft
# 1121    11-805                                   Fig Rolls
# 1153    11-814                           Flapjacks, retail
# 1181    12-528  Fromage frais, virtually fat free, natural
# 1184    12-232                        Fruit fool, homemade
#
#                   Description Group Previous  \
# 1161    4 samples, 2 products    AA      NaN
# 1170  14 samples, 12 products    AA  11-439
# 1121   10 samples, 5 products    AM  11-409
# 1153   10 samples, 9 products    AM      NaN
# 1181      7 samples, 6 brands    BN  12-371
# 1184                   Recipe    BR  12-913
#
#                                    Main data references Footnote Energy (kJ)  \
# 1161                     Flours and grains project 2005      NaN        1528
# ...

# %%
Red4 = pd.concat([Red3,Filt_DG], axis=0, join='inner')
Red4
# Out:
#      Food Code                                   Food Name  \
# 1161    11-899                 Flour, gari (cassava flour)
# 1170    11-886            Flour, wheat, white, plain, soft
# 1121    11-805                                   Fig Rolls
# 1153    11-814                           Flapjacks, retail
# 1181    12-528  Fromage frais, virtually fat free, natural
# 1184    12-232                        Fruit fool, homemade
# 1118    13-241                       Fennel, Florence, raw
# 1119    13-243                       Fenugreek leaves, raw
#
#                      Description Group Previous  \
# 1161       4 samples, 2 products    AA      NaN
# 1170     14 samples, 12 products    AA  11-439
# 1121      10 samples, 5 products    AM  11-409
# 1153      10 samples, 9 products    AM      NaN
# 1181         7 samples, 6 brands    BN  12-371
# 1184                      Recipe    BR  12-913
# 1118  Inner leaves and bulb only    DG  50-770
# ...

# %%
Red5 = pd.concat([Red4,Filt_DR], axis=0, join='inner')
Red5
# Out:
#      Food Code                                   Food Name  \
# 1161    11-899                 Flour, gari (cassava flour)
# 1170    11-886            Flour, wheat, white, plain, soft
# 1121    11-805                                   Fig Rolls
# 1153    11-814                           Flapjacks, retail
# 1181    12-528  Fromage frais, virtually fat free, natural
# 1184    12-232                        Fruit fool, homemade
# 1118    13-241                       Fennel, Florence, raw
# 1119    13-243                       Fenugreek leaves, raw
# 1150    15-804                   Flan, vegetable, homemade
# 1199    15-807                        Fu-fu, yam, homemade
#
#                                             Description Group Previous  \
# 1161                              4 samples, 2 products    AA      NaN
# 1170                            14 samples, 12 products    AA  11-439
# 1121                             10 samples, 5 products    AM  11-409
# ...

# %%
Red6 = pd.concat([Red5,Filt_FA], axis=0, join='inner')
Red6
# Out:
#      Food Code                                        Food Name  \
# 1161    11-899                      Flour, gari (cassava flour)
# 1170    11-886                 Flour, wheat, white, plain, soft
# 1121    11-805                                        Fig Rolls
# 1153    11-814                                Flapjacks, retail
# 1181    12-528       Fromage frais, virtually fat free, natural
# 1184    12-232                             Fruit fool, homemade
# 1118    13-241                            Fennel, Florence, raw
# 1119    13-243                            Fenugreek leaves, raw
# 1150    15-804                        Flan, vegetable, homemade
# 1199    15-807                             Fu-fu, yam, homemade
# 1126    14-091                     Figs, whole green fruit, raw
# 1182    14-336  Fruit cocktail, canned in juice, whole contents
# 1196    14-333                            Fruit salad, homemade
#
# ...

# %%
Red7 = pd.concat([Red6,Filt_JR], axis=0, join='inner')
Red7
# Out:
#      Food Code                                        Food Name  \
# 1161    11-899                      Flour, gari (cassava flour)
# 1170    11-886                 Flour, wheat, white, plain, soft
# 1121    11-805                                        Fig Rolls
# 1153    11-814                                Flapjacks, retail
# 1181    12-528       Fromage frais, virtually fat free, natural
# 1184    12-232                             Fruit fool, homemade
# 1118    13-241                            Fennel, Florence, raw
# 1119    13-243                            Fenugreek leaves, raw
# 1150    15-804                        Flan, vegetable, homemade
# 1199    15-807                             Fu-fu, yam, homemade
# 1126    14-091                     Figs, whole green fruit, raw
# 1182    14-336  Fruit cocktail, canned in juice, whole contents
# 1196    14-333                            Fruit salad, homemade
# 1130    16-405                 Fish fingers, cod, grilled/baked
# ...

# %%
Red8 = pd.concat([Red7,Filt_MI], axis=0, join='inner')
Red8
# Out:
#      Food Code                                        Food Name  \
# 1161    11-899                      Flour, gari (cassava flour)
# 1170    11-886                 Flour, wheat, white, plain, soft
# 1121    11-805                                        Fig Rolls
# 1153    11-814                                Flapjacks, retail
# 1181    12-528       Fromage frais, virtually fat free, natural
# 1184    12-232                             Fruit fool, homemade
# 1118    13-241                            Fennel, Florence, raw
# 1119    13-243                            Fenugreek leaves, raw
# 1150    15-804                        Flan, vegetable, homemade
# 1199    15-807                             Fu-fu, yam, homemade
# 1126    14-091                     Figs, whole green fruit, raw
# 1182    14-336  Fruit cocktail, canned in juice, whole contents
# 1196    14-333                            Fruit salad, homemade
# 1130    16-405                 Fish fingers, cod, grilled/baked
# ...

# %%
Red9 = pd.concat([Red8,Filt_MR], axis=0, join='inner')
Red9
# Out:
#      Food Code                                        Food Name  \
# 1161    11-899                      Flour, gari (cassava flour)
# 1170    11-886                 Flour, wheat, white, plain, soft
# 1121    11-805                                        Fig Rolls
# 1153    11-814                                Flapjacks, retail
# 1181    12-528       Fromage frais, virtually fat free, natural
# 1184    12-232                             Fruit fool, homemade
# 1118    13-241                            Fennel, Florence, raw
# 1119    13-243                            Fenugreek leaves, raw
# 1150    15-804                        Flan, vegetable, homemade
# 1199    15-807                             Fu-fu, yam, homemade
# 1126    14-091                     Figs, whole green fruit, raw
# 1182    14-336  Fruit cocktail, canned in juice, whole contents
# 1196    14-333                            Fruit salad, homemade
# 1130    16-405                 Fish fingers, cod, grilled/baked
# ...

# %%
Red10 = pd.concat([Red9,Filt_PCA], axis=0, join='inner')
Red10
# Out:
#      Food Code                                        Food Name  \
# 1161    11-899                      Flour, gari (cassava flour)
# 1170    11-886                 Flour, wheat, white, plain, soft
# 1121    11-805                                        Fig Rolls
# 1153    11-814                                Flapjacks, retail
# 1181    12-528       Fromage frais, virtually fat free, natural
# 1184    12-232                             Fruit fool, homemade
# 1118    13-241                            Fennel, Florence, raw
# 1119    13-243                            Fenugreek leaves, raw
# 1150    15-804                        Flan, vegetable, homemade
# 1199    15-807                             Fu-fu, yam, homemade
# 1126    14-091                     Figs, whole green fruit, raw
# 1182    14-336  Fruit cocktail, canned in juice, whole contents
# 1196    14-333                            Fruit salad, homemade
# 1130    16-405                 Fish fingers, cod, grilled/baked
# ...

# %%
Red11 = pd.concat([Red10,Filt_PCC], axis=0, join='inner')
Red11
# Out:
#      Food Code                                        Food Name  \
# 1161    11-899                      Flour, gari (cassava flour)
# 1170    11-886                 Flour, wheat, white, plain, soft
# 1121    11-805                                        Fig Rolls
# 1153    11-814                                Flapjacks, retail
# 1181    12-528       Fromage frais, virtually fat free, natural
# 1184    12-232                             Fruit fool, homemade
# 1118    13-241                            Fennel, Florence, raw
# 1119    13-243                            Fenugreek leaves, raw
# 1150    15-804                        Flan, vegetable, homemade
# 1199    15-807                             Fu-fu, yam, homemade
# 1126    14-091                     Figs, whole green fruit, raw
# 1182    14-336  Fruit cocktail, canned in juice, whole contents
# 1196    14-333                            Fruit salad, homemade
# 1130    16-405                 Fish fingers, cod, grilled/baked
# ...

# %%
Red12 = pd.concat([Red11,SEC], axis=0, join='inner')
Red12
# Out:
#      Food Code                                        Food Name  \
# 1161    11-899                      Flour, gari (cassava flour)
# 1170    11-886                 Flour, wheat, white, plain, soft
# 1121    11-805                                        Fig Rolls
# 1153    11-814                                Flapjacks, retail
# 1181    12-528       Fromage frais, virtually fat free, natural
# 1184    12-232                             Fruit fool, homemade
# 1118    13-241                            Fennel, Florence, raw
# 1119    13-243                            Fenugreek leaves, raw
# 1150    15-804                        Flan, vegetable, homemade
# 1199    15-807                             Fu-fu, yam, homemade
# 1126    14-091                     Figs, whole green fruit, raw
# 1182    14-336  Fruit cocktail, canned in juice, whole contents
# 1196    14-333                            Fruit salad, homemade
# 1130    16-405                 Fish fingers, cod, grilled/baked
# ...

# %% [markdown]
#                                                        Export

# %%
Red12.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced_F.csv')
