# %% [markdown]
# # Product Weighting Project

# %% [markdown]
#                                          Data Reduction - Food Purchased In Store

# %% [markdown]
# ###### Import Necessary Libraries

# %%
import pandas as pd

# %% [markdown]
# Read in Data

# %%
Labelled = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Labelling2021_watercress.csv')

# %% [markdown]
# ### Products beginning with a 'G'

# %%
Prod_G = Labelled.loc[Labelled['Food Name'].str.startswith('G')]
Prod_G
# Out:
#      Food Code                                          Food Name  \
# 1200    11-913                                         Gajjeralla
# 1201    13-829                                       Garam masala
# 1202    15-642             Garlic mushrooms, not coated, homemade
# 1203    13-830                                      Garlic powder
# 1204    13-244                                        Garlic, raw
# 1205    11-526                    Gateau, chocolate based, frozen
# 1206    11-530                              Gateau, fruit, frozen
# 1207    17-360                                           Gelatine
# 1208    12-502                       Ghee made from vegetable oil
# 1209    17-640                                       Ghee, butter
# 1210    13-246                         Gherkins, pickled, drained
# 1211    13-245                                      Gherkins, raw
# 1212    18-394                           Giblets, chicken, boiled
# ...

# %% [markdown]
# Products within a Group (provide identification of the food group and food type to which the food belongs)

# %%
Prod_G.groupby('Group')['Food Name'].count()
# Out:
# Group
# AN      3
# AP      2
# AS      1
# BTM     1
# DG     10
# DI      1
# DR      1
# FA     20
# H       4
# MCE     2
# MCG     2
# MG      3
# MR      1
# OF      1
# PE      2
# SC      1
# WC      1
# WY      3
# Name: Food Name, dtype: int64

# %% [markdown]
# ## *Reducing products based on its most basic form. Improve as you go on*

# %% [markdown]
#                                                  Cereals and cereal products

# %% [markdown]
# Cakes

# %%
AN = Prod_G.loc[Prod_G['Group']== 'AN']
AN
# Out:
#      Food Code                        Food Name  \
# 1205    11-526  Gateau, chocolate based, frozen
# 1206    11-530            Gateau, fruit, frozen
# 1217   11-1079            Gingerbread, homemade
#
#                                             Description Group Previous  \
# 1205         11 samples, including Black Forest gateau.    AN  11-421
# 1206  10 samples; fruit and cream sponge including s...    AN  11-420
# 1217                                             Recipe    AN  11-644
#
#                                    Main data references Footnote Energy (kJ)  \
# 1205  RHM, Nutrient content of selected foods, 1995;...      NaN        1237
# 1206  RHM, Nutrient content of selected foods, 1995;...      NaN        1042
# 1217                                       Updated 2014      NaN        1587
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1205           296     15.7          10.3             34.7       16.7
# ...

# %%
AN['Food Name'].unique()
# Out:
# array(['Gateau, chocolate based, frozen', 'Gateau, fruit, frozen',
#        'Gingerbread, homemade'], dtype=object)

# %%
Priority_AN = ['Gingerbread, homemade']

# %% [markdown]
# **Reduced**

# %%
Filt_AN = AN[AN['Food Name'].isin(Priority_AN)]
Filt_AN
# Out:
#      Food Code              Food Name Description Group Previous  \
# 1217   11-1079  Gingerbread, homemade      Recipe    AN  11-644
#
#      Main data references Footnote Energy (kJ) Energy (kcal)  Fat (g)  \
# 1217         Updated 2014      NaN        1587           377     11.3
#
#      Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1217          3.74               62       33.5       28.5       1.7
#
#       Protein (g) Salt (g)
# 1217          6.0     0.63

# %%
Filt_AN['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_25628\3855606877.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AA['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Removed AP

# %% [markdown]
# Removed AS

# %% [markdown]
#                                                     Milk and milk products

# %% [markdown]
# Yogurts

# %%
BTM = Prod_G.loc[Prod_G['Group']== 'BTM']
BTM
# Out:
#      Food Code                     Food Name            Description Group  \
# 1208    12-502  Ghee made from vegetable oil  5 samples, 3 products   BTM
#
#      Previous                               Main data references Footnote  \
# 1208  17-009   DH, Nutrient analysis of a range of processed ...      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 1208        3702           901    100.0         46.72                0
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1208          0          0         0          0.1        0

# %%
BTM['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8904\338318624.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BTM['Super Group'] = 'Milk and milk products'

# %% [markdown]
#                                                        Vegetables

# %% [markdown]
# Vegetables, general

# %%
DG = Prod_G.loc[Prod_G['Group']== 'DG']
DG
# Out:
#      Food Code                   Food Name  \
# 1204    13-244                 Garlic, raw
# 1210    13-246  Gherkins, pickled, drained
# 1211    13-245               Gherkins, raw
# 1226    13-248             Gourd, ash, raw
# 1227    13-249          Gourd, bottle, raw
# 1228    13-250         Gourd, kantola, raw
# 1229    13-252          Gourd, karela, raw
# 1230    13-254           Gourd, ridge, raw
# 1231    13-255           Gourd, snake, raw
# 1232    13-256           Gourd, tinda, raw
#
#                                  Description Group Previous  \
# 1204                           Peeled cloves    DG  50-772
# 1210                    10 samples, 5 brands    DG  50-773
# 1211                 5 samples. Ends trimmed    DG      NaN
# 1226                      Literature sources    DG      NaN
# 1227                      Literature sources    DG      NaN
# 1228  3 samples. Ends trimmed, seeds removed    DG      NaN
# 1229                 5 samples. Ends trimmed    DG  50-774
# ...

# %%
DG['Food Name'].unique()
# Out:
# array(['Garlic, raw', 'Gherkins, pickled, drained', 'Gherkins, raw',
#        'Gourd, ash, raw', 'Gourd, bottle, raw', 'Gourd, kantola, raw',
#        'Gourd, karela, raw', 'Gourd, ridge, raw', 'Gourd, snake, raw',
#        'Gourd, tinda, raw'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_DG = ['Garlic, raw', 'Gherkins, raw']

# %%
Filt_DG = DG[DG['Food Name'].isin(Priority_DG)]
Filt_DG
# Out:
#      Food Code      Food Name              Description Group Previous  \
# 1204    13-244    Garlic, raw            Peeled cloves    DG  50-772
# 1211    13-245  Gherkins, raw  5 samples. Ends trimmed    DG      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1204  Reviewed 2013. IFR, The nutritional compositio...      NaN         444
# 1211      Vegetables, Herbs and Spices Supplement, 1991      NaN          61
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1204           105      0.6           0.1             14.9        1.6
# 1211            15      0.1             0              1.8        1.6
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1204       13.4       4.1          7.9     0.01
# 1211        0.2       1.3          1.0     0.03

# %%
Filt_DG['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8904\1311392366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DG['Super Group'] = 'Vegetables'

# %% [markdown]
# Vegetables, dried

# %%
DI = Prod_G.loc[Prod_G['Group']== 'DI']
DI
# Out:
#      Food Code           Food Name                         Description Group  \
# 1244    13-608  Green beans, dried  Calculated from raw beans (13-514)    DI
#
#      Previous                               Main data references Footnote  \
# 1244  17-415   DH, Nutrient analysis of fruit and vegetables,...      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 1244        1331           319      4.4          0.82             31.1
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1244       22.6        8.5        35         21.2        0

# %%
DI['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8904\2839694359.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DI['Super Group'] = 'Vegetables'

# %% [markdown]
# Vegetable dishes

# %%
DR = Prod_G.loc[Prod_G['Group']== 'DR']
DR
# Out:
#      Food Code                               Food Name  \
# 1202    15-642  Garlic mushrooms, not coated, homemade
#
#                                   Description Group Previous  \
# 1202  Recipe from review of recipe collection    DR  15-373
#
#      Main data references Footnote Energy (kJ) Energy (kcal)  Fat (g)  \
# 1202         Updated 2013      NaN         588           143     14.1
#
#      Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1202          8.85              0.5        0.4        0.1       1.3
#
#       Protein (g) Salt (g)
# 1202          2.8     0.32

# %%
DR['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8904\1901232877.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DR['Super Group'] = 'Vegetables'

# %% [markdown]
#                                                             Fruit

# %% [markdown]
# Fruit, general

# %%
FA = Prod_G.loc[Prod_G['Group']== 'FA']
FA
# Out:
#      Food Code                                          Food Name  \
# 1221    14-100                         Gooseberries, cooking, raw
# 1222    14-101           Gooseberries, cooking, stewed with sugar
# 1223    14-102        Gooseberries, cooking, stewed without sugar
# 1224    14-103                         Gooseberries, dessert, raw
# 1235    14-107        Grapefruit, canned in juice, whole contents
# 1236    14-384                        Grapefruit, flesh only, raw
# 1237    14-385  Grapefruit, flesh only, raw, weighed with peel...
# 1238    14-350                                    Grapes, average
# 1239    14-351                 Grapes, average, weighed with pips
# 1240    14-322                                      Grapes, green
# 1241    14-323                                        Grapes, red
# 1245    14-111                                    Greengages, raw
# 1246    14-112               Greengages, raw, weighed with stones
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_FA = ['Gooseberries, cooking, raw','Grapefruit, flesh only, raw','Grapes, green', 'Guava, flesh only, raw']

# %%
Filt_FA = FA[FA['Food Name'].isin(Priority_FA)]
Filt_FA
# Out:
#      Food Code                    Food Name  \
# 1221    14-100   Gooseberries, cooking, raw
# 1236    14-384  Grapefruit, flesh only, raw
# 1240    14-322                Grapes, green
# 1255    14-118       Guava, flesh only, raw
#
#                                             Description Group Previous  \
# 1221                             Tops and tails removed    FA  50-895
# 1236          11 samples, imported, pink, red and white    FA   14-292
# 1240  21 samples, seedless, autumn and winter, inclu...    FA      NaN
# 1255                                 Literature sources    FA  50-905
#
#                                    Main data references Footnote Energy (kJ)  \
# 1221  LGC, Nutritional composition of fresh fruit, 1...      NaN         136
# 1236  PHE, Nutrient analysis of fresh and processed ...      NaN         173
# 1240  DH, Nutrient analysis of fruit and vegetables,...      NaN         300
# ...

# %%
Filt_FA['Super Group'] = 'Fruit'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8904\3797725470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_FA['Super Group'] = 'Fruit'

# %% [markdown]
#                                                     Herbs and spices

# %%
H = Prod_G.loc[Prod_G['Group']== 'H']
H
# Out:
#      Food Code       Food Name                                    Description  \
# 1201    13-829    Garam masala                             Literature sources
# 1203    13-830   Garlic powder  Literature sources and calculation from fresh
# 1215    13-890   Ginger, fresh                             Literature sources
# 1216    13-832  Ginger, ground               3 samples and literature sources
#
#      Group Previous                               Main data references  \
# 1201     H  50-841   Wharton et al. (1983) Sorrento Asian food tabl...
# 1203     H      NaN  Marsh et al. (1977) Composition of foods: spic...
# 1215     H  13-831                                     USDA SR26, 2013
# 1216     H  13-865   Reviewed 2013. Vegetables, Herbs and Spices Su...
#
#      Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 1201      NaN        1668           399     15.1           2.2
# 1203      NaN        1108           262      1.2           0.2
# ...

# %%
H['Super Group'] = 'Herbs and spices'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8904\1932536701.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   H['Super Group'] = 'Herbs and spices'

# %% [markdown]
#                                                 Meat and meat products

# %% [markdown]
# Removed Meat products - MCE

# %% [markdown]
# Removed Meat products -Grouse MCG

# %% [markdown]
# Remove Meat products - Offal

# %% [markdown]
# Remove Meat products - Meat dishes

# %% [markdown]
#                                                     Fats and oils

# %% [markdown]
# Cooking fats

# %%
OF = Prod_G.loc[Prod_G['Group']== 'OF']
OF
# Out:
#      Food Code     Food Name                       Description Group Previous  \
# 1209    17-640  Ghee, butter  10 samples, 7 retail, 3 homemade    OF  17-007
#
#                                    Main data references Footnote Energy (kJ)  \
# 1209  University of Leeds, Nutritional analysis of c...      NaN        3613
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1209           879     97.6         58.42                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1209          0         0          0.1        0

# %%
OF['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8904\1629779085.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   OF['Super Group'] = 'Meat and meat products'

# %% [markdown]
#                                                        Beverages

# %% [markdown]
# Soft drinks/Carbonated drinks

# %%
PE = Prod_G.loc[Prod_G['Group']== 'PE']
PE
# Out:
#      Food Code                      Food Name  \
# 1233    17-745       Grape juice, unsweetened
# 1234    14-275  Grapefruit juice, unsweetened
#
#                                           Description Group  Previous  \
# 1233             10 samples, 6 brands; 100% red juice    PE   14-273
# 1234  50 samples; cartons, canned, bottled and frozen    PE  50-1089
#
#                                    Main data references  \
# 1233  LGC, Fruit and vegetables, 1989-1990; and indu...
# 1234  Reviewed 2013. LGC, Fruit and vegetables, 1989...
#
#                                                Footnote Energy (kJ)  \
# 1233                                                NaN         298
# 1234  Frozen samples were diluted as per manufacture...         168
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1233            70      0.1             0               16         16
# 1234            39      0.1             0              8.2        8.2
#
# ...

# %% [markdown]
# **Reduced**

# %%
Filt_PE = PE.loc[PE['Food Name'] == 'Grape juice, unsweetened']
Filt_PE
# Out:
#      Food Code                 Food Name  \
# 1233    17-745  Grape juice, unsweetened
#
#                                Description Group Previous  \
# 1233  10 samples, 6 brands; 100% red juice    PE  14-273
#
#                                    Main data references Footnote Energy (kJ)  \
# 1233  LGC, Fruit and vegetables, 1989-1990; and indu...      NaN         298
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1233            70      0.1             0               16         16
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1233          0         0          0.3     0.02

# %%
Filt_PE['Super Group'] = 'Beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8904\230205806.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_PE['Super Group'] = 'Beverages'

# %% [markdown]
#                                             Sugars, preserves and snacks

# %% [markdown]
# Sugars, syrups and preserves

# %%
SC = Prod_G.loc[Prod_G['Group']== 'SC']
SC
# Out:
#      Food Code           Food Name Description Group  Previous  \
# 1218    17-049  Glucose liquid, BP    1 sample    SC  50-1000
#
#                                    Main data references Footnote Energy (kJ)  \
# 1218  MW4, 1978. Values reviewed for Miscellaneous F...      NaN        1372
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1218           323      0.0             0             80.7         33
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1218          0         0          0.0     0.38

# %%
SC['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8904\2223454829.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SC['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
#                                             Soups, sauces and miscellaneous foods

# %% [markdown]
# Sauces

# %%
WC = Prod_G.loc[Prod_G['Group']== 'WC']
WC
# Out:
#      Food Code            Food Name Description Group Previous  \
# 1254    17-797  Guacamole, homemade      Recipe    WC  17-580
#
#      Main data references Footnote Energy (kJ) Energy (kcal)  Fat (g)  \
# 1254         Updated 2014      NaN         535           130     12.7
#
#      Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1254          2.67              1.3        1.3          0       2.5
#
#       Protein (g) Salt (g)
# 1254          1.4     0.01

# %%
WC['Super Group'] = 'Sugars, preserves and snacks'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8904\1512108822.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WC['Super Group'] = 'Sugars, preserves and snacks'

# %% [markdown]
# Miscellaneous foods

# %%
WY = Prod_G.loc[Prod_G['Group']== 'WY']
WY
# Out:
#      Food Code                                   Food Name  \
# 1207    17-360                                    Gelatine
# 1242    17-724                      Gravy instant granules
# 1243    17-725  Gravy instant granules, made up with water
#
#                                         Description Group  Previous  \
# 1207                             Literature sources    WY  50-1176
# 1242                            7 samples, 3 brands    WY   17-310
# 1243  Calculated from 23.5g granules to 300ml water    WY   17-311
#
#                                    Main data references Footnote Energy (kJ)  \
# 1207  Reviewed 2013. Lewis and English (1990) Compos...      NaN        1615
# 1242  LFRA, Nutrient analysis of miscellaneous foods...      NaN        1691
# 1243  LFRA, Nutrient analysis of miscellaneous foods...      NaN         130
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1207           380      0.0             0                0          0
# ...

# %% [markdown]
# **Reduced**

# %%
Remove_WY = ['Gravy instant granules, made up with water']

# %%
Filt_WY = WY[~WY['Food Name'].isin(Remove_WY)]
Filt_WY
# Out:
#      Food Code               Food Name          Description Group  Previous  \
# 1207    17-360                Gelatine   Literature sources    WY  50-1176
# 1242    17-724  Gravy instant granules  7 samples, 3 brands    WY   17-310
#
#                                    Main data references Footnote Energy (kJ)  \
# 1207  Reviewed 2013. Lewis and English (1990) Compos...      NaN        1615
# 1242  LFRA, Nutrient analysis of miscellaneous foods...      NaN        1691
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1207           380      0.0             0                0          0
# 1242           403     16.1         10.66             59.3          5
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1207          0         0         95.0     0.83
# 1242          N       1.6          4.4    13.25

# %%
Filt_WY['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8904\2934381568.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_WY['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
#                                               **Join Reduced Tables**

# %%
Red = pd.concat([Filt_AN,BTM], axis=0, join='inner')
Red
# Out:
#      Food Code                     Food Name            Description Group  \
# 1217   11-1079         Gingerbread, homemade                 Recipe    AN
# 1208    12-502  Ghee made from vegetable oil  5 samples, 3 products   BTM
#
#      Previous                               Main data references Footnote  \
# 1217  11-644                                        Updated 2014      NaN
# 1208  17-009   DH, Nutrient analysis of a range of processed ...      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 1217        1587           377     11.3          3.74               62
# 1208        3702           901    100.0         46.72                0
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1217       33.5       28.5       1.7          6.0     0.63
# 1208          0          0         0          0.1        0

# %%
Red2 = pd.concat([Red,Filt_DG], axis=0, join='inner')
Red2
# Out:
#      Food Code                     Food Name              Description Group  \
# 1217   11-1079         Gingerbread, homemade                   Recipe    AN
# 1208    12-502  Ghee made from vegetable oil    5 samples, 3 products   BTM
# 1204    13-244                   Garlic, raw            Peeled cloves    DG
# 1211    13-245                 Gherkins, raw  5 samples. Ends trimmed    DG
#
#      Previous                               Main data references Footnote  \
# 1217  11-644                                        Updated 2014      NaN
# 1208  17-009   DH, Nutrient analysis of a range of processed ...      NaN
# 1204  50-772   Reviewed 2013. IFR, The nutritional compositio...      NaN
# 1211      NaN      Vegetables, Herbs and Spices Supplement, 1991      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 1217        1587           377     11.3          3.74               62
# ...

# %%
Red3 = pd.concat([Red2,DI], axis=0, join='inner')
Red3
# Out:
#      Food Code                     Food Name  \
# 1217   11-1079         Gingerbread, homemade
# 1208    12-502  Ghee made from vegetable oil
# 1204    13-244                   Garlic, raw
# 1211    13-245                 Gherkins, raw
# 1244    13-608            Green beans, dried
#
#                              Description Group Previous  \
# 1217                              Recipe    AN  11-644
# 1208               5 samples, 3 products   BTM  17-009
# 1204                       Peeled cloves    DG  50-772
# 1211             5 samples. Ends trimmed    DG      NaN
# 1244  Calculated from raw beans (13-514)    DI  17-415
#
#                                    Main data references Footnote Energy (kJ)  \
# 1217                                       Updated 2014      NaN        1587
# 1208  DH, Nutrient analysis of a range of processed ...      NaN        3702
# 1204  Reviewed 2013. IFR, The nutritional compositio...      NaN         444
# ...

# %%
Red4 = pd.concat([Red3,Filt_FA], axis=0, join='inner')
Red4
# Out:
#      Food Code                     Food Name  \
# 1217   11-1079         Gingerbread, homemade
# 1208    12-502  Ghee made from vegetable oil
# 1204    13-244                   Garlic, raw
# 1211    13-245                 Gherkins, raw
# 1244    13-608            Green beans, dried
# 1221    14-100    Gooseberries, cooking, raw
# 1236    14-384   Grapefruit, flesh only, raw
# 1240    14-322                 Grapes, green
# 1255    14-118        Guava, flesh only, raw
#
#                                             Description Group Previous  \
# 1217                                             Recipe    AN  11-644
# 1208                              5 samples, 3 products   BTM  17-009
# 1204                                      Peeled cloves    DG  50-772
# 1211                            5 samples. Ends trimmed    DG      NaN
# 1244                 Calculated from raw beans (13-514)    DI  17-415
# 1221                             Tops and tails removed    FA  50-895
# ...

# %%
Red5 = pd.concat([Red4,H], axis=0, join='inner')
Red5
# Out:
#      Food Code                     Food Name  \
# 1217   11-1079         Gingerbread, homemade
# 1208    12-502  Ghee made from vegetable oil
# 1204    13-244                   Garlic, raw
# 1211    13-245                 Gherkins, raw
# 1244    13-608            Green beans, dried
# 1221    14-100    Gooseberries, cooking, raw
# 1236    14-384   Grapefruit, flesh only, raw
# 1240    14-322                 Grapes, green
# 1255    14-118        Guava, flesh only, raw
# 1201    13-829                  Garam masala
# 1203    13-830                 Garlic powder
# 1215    13-890                 Ginger, fresh
# 1216    13-832                Ginger, ground
#
#                                             Description Group Previous  \
# 1217                                             Recipe    AN  11-644
# 1208                              5 samples, 3 products   BTM  17-009
# 1204                                      Peeled cloves    DG  50-772
# ...

# %%
Red6 = pd.concat([Red5,OF], axis=0, join='inner')
Red6
# Out:
#      Food Code                     Food Name  \
# 1217   11-1079         Gingerbread, homemade
# 1208    12-502  Ghee made from vegetable oil
# 1204    13-244                   Garlic, raw
# 1211    13-245                 Gherkins, raw
# 1244    13-608            Green beans, dried
# 1221    14-100    Gooseberries, cooking, raw
# 1236    14-384   Grapefruit, flesh only, raw
# 1240    14-322                 Grapes, green
# 1255    14-118        Guava, flesh only, raw
# 1201    13-829                  Garam masala
# 1203    13-830                 Garlic powder
# 1215    13-890                 Ginger, fresh
# 1216    13-832                Ginger, ground
# 1209    17-640                  Ghee, butter
#
#                                             Description Group Previous  \
# 1217                                             Recipe    AN  11-644
# 1208                              5 samples, 3 products   BTM  17-009
# ...

# %%
Red7 = pd.concat([Red6,Filt_PE], axis=0, join='inner')
Red7
# Out:
#      Food Code                     Food Name  \
# 1217   11-1079         Gingerbread, homemade
# 1208    12-502  Ghee made from vegetable oil
# 1204    13-244                   Garlic, raw
# 1211    13-245                 Gherkins, raw
# 1244    13-608            Green beans, dried
# 1221    14-100    Gooseberries, cooking, raw
# 1236    14-384   Grapefruit, flesh only, raw
# 1240    14-322                 Grapes, green
# 1255    14-118        Guava, flesh only, raw
# 1201    13-829                  Garam masala
# 1203    13-830                 Garlic powder
# 1215    13-890                 Ginger, fresh
# 1216    13-832                Ginger, ground
# 1209    17-640                  Ghee, butter
# 1233    17-745      Grape juice, unsweetened
#
#                                             Description Group Previous  \
# 1217                                             Recipe    AN  11-644
# 1208                              5 samples, 3 products   BTM  17-009
# ...

# %%
Red8 = pd.concat([Red7,SC], axis=0, join='inner')
Red8
# Out:
#      Food Code                     Food Name  \
# 1217   11-1079         Gingerbread, homemade
# 1208    12-502  Ghee made from vegetable oil
# 1204    13-244                   Garlic, raw
# 1211    13-245                 Gherkins, raw
# 1244    13-608            Green beans, dried
# 1221    14-100    Gooseberries, cooking, raw
# 1236    14-384   Grapefruit, flesh only, raw
# 1240    14-322                 Grapes, green
# 1255    14-118        Guava, flesh only, raw
# 1201    13-829                  Garam masala
# 1203    13-830                 Garlic powder
# 1215    13-890                 Ginger, fresh
# 1216    13-832                Ginger, ground
# 1209    17-640                  Ghee, butter
# 1233    17-745      Grape juice, unsweetened
# 1218    17-049            Glucose liquid, BP
#
#                                             Description Group  Previous  \
# 1217                                             Recipe    AN   11-644
# ...

# %%
Red9 = pd.concat([Red8,WC], axis=0, join='inner')
Red9
# Out:
#      Food Code                     Food Name  \
# 1217   11-1079         Gingerbread, homemade
# 1208    12-502  Ghee made from vegetable oil
# 1204    13-244                   Garlic, raw
# 1211    13-245                 Gherkins, raw
# 1244    13-608            Green beans, dried
# 1221    14-100    Gooseberries, cooking, raw
# 1236    14-384   Grapefruit, flesh only, raw
# 1240    14-322                 Grapes, green
# 1255    14-118        Guava, flesh only, raw
# 1201    13-829                  Garam masala
# 1203    13-830                 Garlic powder
# 1215    13-890                 Ginger, fresh
# 1216    13-832                Ginger, ground
# 1209    17-640                  Ghee, butter
# 1233    17-745      Grape juice, unsweetened
# 1218    17-049            Glucose liquid, BP
# 1254    17-797           Guacamole, homemade
#
#                                             Description Group  Previous  \
# ...

# %%
Red10 = pd.concat([Red9,Filt_WY], axis=0, join='inner')
Red10
# Out:
#      Food Code                     Food Name  \
# 1217   11-1079         Gingerbread, homemade
# 1208    12-502  Ghee made from vegetable oil
# 1204    13-244                   Garlic, raw
# 1211    13-245                 Gherkins, raw
# 1244    13-608            Green beans, dried
# 1221    14-100    Gooseberries, cooking, raw
# 1236    14-384   Grapefruit, flesh only, raw
# 1240    14-322                 Grapes, green
# 1255    14-118        Guava, flesh only, raw
# 1201    13-829                  Garam masala
# 1203    13-830                 Garlic powder
# 1215    13-890                 Ginger, fresh
# 1216    13-832                Ginger, ground
# 1209    17-640                  Ghee, butter
# 1233    17-745      Grape juice, unsweetened
# 1218    17-049            Glucose liquid, BP
# 1254    17-797           Guacamole, homemade
# 1207    17-360                      Gelatine
# 1242    17-724        Gravy instant granules
#
# ...

# %% [markdown]
#                                                        Export

# %%
Red10.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced_G.csv')
