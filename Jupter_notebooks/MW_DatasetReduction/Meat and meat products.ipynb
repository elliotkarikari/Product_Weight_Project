# %% [markdown]
#                                           SelfScale DataBase Meat and meat products

# %% [markdown]
# Libraries Imported

# %%
import pandas as pd
import re

# %% [markdown]
# Reading in Updated List

# %%
#Red_List = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Total\Updated2_RedLab2021.csv', index_col=0)

# %% [markdown]
# ###### Selecting all Fruits in Reduced List

# %%
#MMp = Red_List.loc[Red_List['Super Group'] == 'Meat and meat products']

# %%
#MMp.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Meat and meat products.csv')

# %% [markdown]
#                                                        Fruit

# %%
Mmp = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Meat and meat products.csv', index_col=0)

# %%
Mmp.shape
# Out:
# (46, 6)

# %% [markdown]
# ##### Reviewing Veg List

# %% [markdown]
# Most of Review done in Excel

# %%
#Loop through dataframe and print comments
for comment in Mmp:
    pd.set_option('display.max_colwidth', None)
    #pd.set_option('display.max_rows', None)
Mmp
# Out:
#    Food Code                                  Food Name Group  \
# 1     19-646      Bacon rashers, back, fat trimmed, raw   MAA
# 2     18-006            Beef, braising steak, raw, lean   MAC
# 3     18-003                    Beef, fat, average, raw   MAC
# 4     18-016              Beef, fillet steak, raw, lean   MAC
# 5     18-024                     Beef, flank, raw, lean   MAC
# 6     18-468                   Beef, lean, average, raw   MAC
# 7     18-469                           Beef, mince, raw   MAC
# 8     18-054                Beef, silverside, raw, lean   MAC
# 9     18-064             Beef, sirloin steak, raw, lean   MAC
# 10    18-084                   Beef, topside, raw, lean   MAC
# 11    18-504        Chicken breast/steak, coated, baked   MCA
# 12    18-501           Chicken pieces, coated, takeaway   MCA
# 13    18-293   Chicken, leg quarter, raw, meat and skin   MCA
# 14    18-488                Chicken, meat, average, raw   MCA
# ...

# %%
Mmp.drop('VJ comments', axis=1, inplace=True)

# %%
Mmp.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Cleaned\Meat and meat products_Cleaned.csv')
