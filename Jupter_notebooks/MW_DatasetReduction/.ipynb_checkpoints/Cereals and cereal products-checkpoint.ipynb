# %% [markdown]
#                                                SelfScale DataBase Cereals

# %% [markdown]
# Libraries Imported

# %%
import pandas as pd
import re

# %% [markdown]
# Reading in Updated List

# %%
#Red_List = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Total\Updated2_RedLab2021.csv', index_col=0)

# %% [markdown]
# ###### Selecting all Fruits in Reduced List

# %%
#CCp = Red_List.loc[Red_List['Super Group'] == 'Cereals and cereal products']

# %%
#CCp.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Cereals and cereal products.csv')

# %% [markdown]
#                                                        Fruit

# %%
CCP = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Cereals and cereal products.csv', index_col=0)

# %%
CCP.shape
# Out:
# (89, 6)

# %% [markdown]
# ##### Reviewing Veg List

# %%
#Loop through dataframe and print comments
for comment in CCP:
    pd.set_option('display.max_colwidth', None)
    pd.set_option('display.max_rows', None)
CCP.head(127)
# Out:
#    Food Code  \
# 1     11-001
# 2     11-002
# 3     11-906
# 4     11-006
# 5    11-1144
# 6    11-1006
# 7     11-971
# 8     11-969
# 9     11-937
# 10    11-910
# 11    11-973
# 12    11-974
# 13    11-947
# 14   11-1145
# 15    11-977
# 16    11-978
# 17    11-980
# 18    11-981
# 19    11-983
# 20    11-984
# 21    11-985
# 22    11-986
# 23    11-763
# 24    11-742
# 25    11-779
# 26    11-755
# 27    11-792
# 28    11-753
# 29    11-778
# 30    11-773
# 31    11-821
# 32    11-815
# 33    11-799
# 34    11-809
# 35    11-801
# 36    11-826
# 37       NaN
# 38       NaN
# 39       NaN
# 40    11-970
# 41       NaN
# 42    11-011
# 43    11-988
# 44    11-820
# 45    11-839
# 46   11-1020
# 47    11-850
# 48    11-849
# 49       NaN
# 50       NaN
# 51       NaN
# 52    11-739
# 53    11-846
# 54       NaN
# 55    11-780
# 56    11-737
# 57    11-848
# 58    11-719
# 59    11-823
# 60    11-936
# 61    11-788
# 62    11-726
# 63    11-718
# 64    11-735
# 65       NaN
# ...

# %%
CCP.drop('VJ comments', axis=1, inplace=True)

# %%
CCP.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced Super Group\Cleaned\Cereals_Cleaned.csv')
