# %% [markdown]
# # Product Weighting Project

# %% [markdown]
#                                          Data Reduction - Food Purchased In Store

# %% [markdown]
# ###### Import Necessary Libraries

# %%
import pandas as pd

# %% [markdown]
# Read in Data

# %%
Labelled = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Labelling2021_watercress.csv')

# %% [markdown]
# No products start with an X. Moving on to Y

# %% [markdown]
# ### Products beginning with a 'Y'

# %%
prod_y = Labelled.loc[Labelled['Food Name'].str.startswith('Y')]
prod_y
# Out:
#      Food Code                                          Food Name  \
# 2863    13-398                                         Yam, baked
# 2864    13-655          Yam, flesh only, boiled in unsalted water
# 2865    13-397                               Yam, flesh only, raw
# 2866    13-401                                       Yam, steamed
# 2867    17-517                                      Yeast extract
# 2868    17-378                          Yeast, bakers, compressed
# 2869    17-379                                       Yeast, dried
# 2870    12-377                         Yogurt, Greek style, fruit
# 2871    12-555                         Yogurt, Greek style, plain
# 2872    12-380                             Yogurt, low fat, fruit
# 2873    12-904                          Yogurt, low fat, hazelnut
# 2874    12-379                             Yogurt, low fat, plain
# 2875    12-905                            Yogurt, low fat, toffee
# 2876    12-609  Yogurt, soya, non-dairy alternative to yogurt,...
# 2877    12-532             Yogurt, virtually fat free/diet, fruit
# 2878    12-533             Yogurt, virtually fat free/diet, plain
# 2879    12-375                          Yogurt, whole milk, fruit
# 2880    12-530          Yogurt, whole milk, infant, fruit flavour
# 2881    12-184                          Yogurt, whole milk, plain
# 2882    12-515            Yogurt, whole milk, twin pot, not fruit
# 2883    12-531  Yogurt, whole milk, twin pot, thick and creamy...
# 2884    11-960  Yorkshire pudding, made with semi-skimmed milk...
# 2885   11-1135  Yorkshire pudding, made with skimmed milk, hom...
# 2886   11-1146            Yorkshire pudding, made with whole milk
#
#                                             Description Group  \
# 2863  Literature sources and calculation from raw; b...    DG
# 2864  8 samples, fresh, imported. Peeled, cut into c...    DG
# 2865                                         flesh only    DG
# 2866  Literature sources and calculation from raw, s...    DG
# 2867      Mixed sample including Marmite and own brands    WY
# 2868                                 Literature sources    WY
# 2869                                 Literature sources    WY
# 2870  6 samples, 4 brands, including peach, apricot,...    BN
# 2871          7 samples, 6 brands, made with whole milk    BN
# 2872         21 samples, 9 brands, including French set    BN
# 2873                                8 samples, 5 brands   BNH
# 2874                                8 samples, 5 brands    BN
# 2875                                8 samples, 4 brands   BNH
# 2876                                          3 samples    BN
# 2877  14 samples, 10 brands, including bio varieties...    BN
# 2878       6 samples, 4 brands, including bio varieties    BN
# 2879  9 samples, 5 brands, assorted flavours includi...    BN
# 2880               8 samples, 4 brands, no fruit pieces    BN
# 2881                               22 samples, 2 brands   BNE
# 2882  With biscuit pieces and chocolate-coated cerea...    BN
# 2883             11 samples, 8 brands, various flavours    BN
# 2884                                             Recipe    AT
# 2885                                             Recipe    AT
# 2886                                             Recipe    AT
#
#                    Previous  \
# 2863                    NaN
# 2864                 13-400
# 2865                50-836
# 2866                    NaN
# 2867        17-380 50-1179
# 2868               50-1187
# 2869               50-1188
# 2870                    NaN
# 2871                12-376
# 2872         12-190 50-257
# 2873                    140
# 2874  12-188 12-870 50-255
# 2875                    141
# 2876          12-381 12-529
# 2877                12-382
# 2878                12-383
# 2879  12-185 12-869 50-261
# 2880                12-378
# 2881         12-868 50-260
# 2882                    NaN
# 2883                12-374
# 2884                    NaN
# 2885                11-713
# 2886                11-607
#
#                                    Main data references Footnote Energy (kJ)  \
# 2863      Vegetables, Herbs and Spices Supplement, 1991      NaN         654
# 2864  PHE, Nutrient analysis of fresh and processed ...      NaN         507
# 2865      Vegetables, Herbs and Spices Supplement, 1991      NaN         493
# 2866      Vegetables, Herbs and Spices Supplement, 1991      NaN         493
# 2867  As Miscellaneous Foods Supplement 17-380 with ...      NaN         793
# 2868                           Reviewed 2013. MW4, 1978      NaN         304
# 2869                           Reviewed 2013. MW4, 1978      NaN         996
# 2870  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN         574
# 2871  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN         551
# 2872  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN         336
# 2873  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN         397
# 2874  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN         245
# 2875  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN         388
# 2876  Campden and Chorleywood FRA, Nutrient analysis...      NaN         325
# 2877  Reviewed 2013. Data from CCFRA, Nutrient analy...      NaN         256
# 2878  Updated 2013. Campden and Chorleywood FRA, Nut...      NaN         232
# 2879  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN         471
# 2880  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN         382
# 2881  Reviewed 2013. Milk Products and Eggs Suppleme...      NaN         334
# 2882      Estimated from 2013 product label information      NaN         625
# 2883  Reviewed 2013. LGC, Nutritional analysis of fo...      NaN         469
# 2884           As MW6. Recalculated from 11-607 in 2013      NaN         829
# 2885                                       Updated 2014      NaN         803
# 2886                                  Recalculated 2014      NaN         889
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2863           154      0.4           0.1             34.1        0.9
# 2864           120      0.2          0.07             26.7        1.8
# 2865           116      0.3           0.1             25.7        0.7
# 2866           116      0.3           0.1             25.7        0.7
# 2867           187      0.4          0.04              3.4        1.7
# 2868            73      0.4          0.26                1          0
# 2869           238      1.5          0.47              3.2          0
# 2870           138      8.4          5.57             10.7       10.1
# 2871           133     10.2          6.75              4.6        4.3
# 2872            79      1.1           0.8             13.1       12.2
# 2873            94      1.5          0.58             15.3       14.3
# 2874            58      1.0          0.66              7.6        7.3
# 2875            92      0.9          0.62             17.1         16
# 2876            77      2.0          0.32             10.7       10.4
# 2877            60      0.2           0.1              9.7        9.1
# 2878            55      0.2           0.1              7.9        7.7
# 2879           112      3.0          2.01             17.1       16.1
# 2880            91      3.7          2.45             10.6         10
# 2881            80      3.0          1.91              7.6        7.6
# 2882           149      5.6           3.2             20.3       17.3
# 2883           112      3.2             N             15.7       15.2
# 2884           198      8.3          1.89             23.3        3.2
# 2885           191      7.4          1.23             23.6        3.3
# 2886           212      9.8          2.78             23.5        3.2
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2863       33.2       3.1          2.1     0.01
# 2864       24.9       2.3          1.6        0
# 2865         25       2.3          1.6     0.01
# 2866         25       2.3          1.6        0
# 2867        1.7         0         42.4    10.75
# 2868          1       7.2         12.6     0.04
# 2869        3.2      26.9         39.5     0.13
# 2870        0.6         0          4.8     0.16
# 2871        0.3         0          5.6     0.17
# 2872        0.9       0.3          4.1     0.16
# 2873          1       0.9          4.4     0.15
# 2874        0.3         0          4.7     0.16
# 2875        1.1         0          3.8     0.17
# 2876        0.3         1          3.6     0.06
# 2877        0.6       0.4          4.7     0.16
# 2878        0.3         0          5.3     0.18
# 2879          1       0.3          3.9     0.15
# 2880        0.6       0.2          3.7     0.12
# 2881          0         0          5.6      0.2
# 2882          3       0.3          4.1     0.25
# 2883        0.5         1          4.4     0.13
# 2884       20.1       1.1          6.9     0.13
# 2885       20.3       1.1          7.0     0.14
# 2886       20.3       1.1          6.9     0.13

# %% [markdown]
# Products within a Group (provide identification of the food group and food type to which the food belongs)

# %%
prod_y.groupby('Group')['Food Name'].count()
# Out:
# Group
# AT      3
# BN     11
# BNE     1
# BNH     2
# DG      4
# WY      3
# Name: Food Name, dtype: int64

# %% [markdown]
# ## *Reducing products based on its most basic form. Improve as you go on*

# %% [markdown]
#                                                 Cereals and cereal products

# %% [markdown]
# Savouries

# %%
at = prod_y.loc[prod_y['Group']== 'AT']
at
# Out:
#      Food Code                                          Food Name Description  \
# 2884    11-960  Yorkshire pudding, made with semi-skimmed milk...      Recipe
# 2885   11-1135  Yorkshire pudding, made with skimmed milk, hom...      Recipe
# 2886   11-1146            Yorkshire pudding, made with whole milk      Recipe
#
#      Group Previous                      Main data references Footnote  \
# 2884    AT      NaN  As MW6. Recalculated from 11-607 in 2013      NaN
# 2885    AT  11-713                               Updated 2014      NaN
# 2886    AT  11-607                          Recalculated 2014      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 2884         829           198      8.3          1.89             23.3
# 2885         803           191      7.4          1.23             23.6
# 2886         889           212      9.8          2.78             23.5
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2884        3.2       20.1       1.1          6.9     0.13
# 2885        3.3       20.3       1.1          7.0     0.14
# 2886        3.2       20.3       1.1          6.9     0.13

# %%
at['Food Name'].unique()
# Out:
# array(['Yorkshire pudding, made with semi-skimmed milk, homemade',
#        'Yorkshire pudding, made with skimmed milk, homemade',
#        'Yorkshire pudding, made with whole milk'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
filt_at = at[at['Food Name'] == 'Yorkshire pudding, made with skimmed milk, homemade']
filt_at
# Out:
#      Food Code                                          Food Name Description  \
# 2885   11-1135  Yorkshire pudding, made with skimmed milk, hom...      Recipe
#
#      Group Previous Main data references Footnote Energy (kJ) Energy (kcal)  \
# 2885    AT  11-713          Updated 2014      NaN         803           191
#
#       Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 2885      7.4          1.23             23.6        3.3       20.3       1.1
#
#       Protein (g) Salt (g)
# 2885          7.0     0.14

# %%
filt_at['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_71184\2533386253.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_at['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
#                                     Milk and milk products

# %% [markdown]
# Yogurts

# %%
bn = prod_y.loc[prod_y['Group']== 'BN']
bn
# Out:
#      Food Code                                          Food Name  \
# 2870    12-377                         Yogurt, Greek style, fruit
# 2871    12-555                         Yogurt, Greek style, plain
# 2872    12-380                             Yogurt, low fat, fruit
# 2874    12-379                             Yogurt, low fat, plain
# 2876    12-609  Yogurt, soya, non-dairy alternative to yogurt,...
# 2877    12-532             Yogurt, virtually fat free/diet, fruit
# 2878    12-533             Yogurt, virtually fat free/diet, plain
# 2879    12-375                          Yogurt, whole milk, fruit
# 2880    12-530          Yogurt, whole milk, infant, fruit flavour
# 2882    12-515            Yogurt, whole milk, twin pot, not fruit
# 2883    12-531  Yogurt, whole milk, twin pot, thick and creamy...
#
#                                             Description Group  \
# 2870  6 samples, 4 brands, including peach, apricot,...    BN
# 2871          7 samples, 6 brands, made with whole milk    BN
# 2872         21 samples, 9 brands, including French set    BN
# 2874                                8 samples, 5 brands    BN
# 2876                                          3 samples    BN
# 2877  14 samples, 10 brands, including bio varieties...    BN
# 2878       6 samples, 4 brands, including bio varieties    BN
# 2879  9 samples, 5 brands, assorted flavours includi...    BN
# 2880               8 samples, 4 brands, no fruit pieces    BN
# 2882  With biscuit pieces and chocolate-coated cerea...    BN
# 2883             11 samples, 8 brands, various flavours    BN
#
#                    Previous  \
# 2870                    NaN
# 2871                12-376
# 2872         12-190 50-257
# 2874  12-188 12-870 50-255
# 2876          12-381 12-529
# 2877                12-382
# 2878                12-383
# 2879  12-185 12-869 50-261
# 2880                12-378
# 2882                    NaN
# 2883                12-374
#
#                                    Main data references Footnote Energy (kJ)  \
# 2870  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN         574
# 2871  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN         551
# 2872  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN         336
# 2874  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN         245
# 2876  Campden and Chorleywood FRA, Nutrient analysis...      NaN         325
# 2877  Reviewed 2013. Data from CCFRA, Nutrient analy...      NaN         256
# 2878  Updated 2013. Campden and Chorleywood FRA, Nut...      NaN         232
# 2879  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN         471
# 2880  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN         382
# 2882      Estimated from 2013 product label information      NaN         625
# 2883  Reviewed 2013. LGC, Nutritional analysis of fo...      NaN         469
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2870           138      8.4          5.57             10.7       10.1
# 2871           133     10.2          6.75              4.6        4.3
# 2872            79      1.1           0.8             13.1       12.2
# 2874            58      1.0          0.66              7.6        7.3
# 2876            77      2.0          0.32             10.7       10.4
# 2877            60      0.2           0.1              9.7        9.1
# 2878            55      0.2           0.1              7.9        7.7
# 2879           112      3.0          2.01             17.1       16.1
# 2880            91      3.7          2.45             10.6         10
# 2882           149      5.6           3.2             20.3       17.3
# 2883           112      3.2             N             15.7       15.2
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2870        0.6         0          4.8     0.16
# 2871        0.3         0          5.6     0.17
# 2872        0.9       0.3          4.1     0.16
# 2874        0.3         0          4.7     0.16
# 2876        0.3         1          3.6     0.06
# 2877        0.6       0.4          4.7     0.16
# 2878        0.3         0          5.3     0.18
# 2879          1       0.3          3.9     0.15
# 2880        0.6       0.2          3.7     0.12
# 2882          3       0.3          4.1     0.25
# 2883        0.5         1          4.4     0.13

# %%
bn['Food Name'].unique()
# Out:
# array(['Yogurt, Greek style, fruit', 'Yogurt, Greek style, plain',
#        'Yogurt, low fat, fruit', 'Yogurt, low fat, plain',
#        'Yogurt, soya, non-dairy alternative to yogurt, fruit, fortified',
#        'Yogurt, virtually fat free/diet, fruit',
#        'Yogurt, virtually fat free/diet, plain',
#        'Yogurt, whole milk, fruit',
#        'Yogurt, whole milk, infant, fruit flavour',
#        'Yogurt, whole milk, twin pot, not fruit',
#        'Yogurt, whole milk, twin pot, thick and creamy with fruit'],
#       dtype=object)

# %% [markdown]
# **Reduced**

# %%
priority_bn = ['Yogurt, Greek style, plain','Yogurt, whole milk, fruit']

# %%
filt_bn = bn[bn['Food Name'].isin(priority_bn)]
filt_bn
# Out:
#      Food Code                   Food Name  \
# 2871    12-555  Yogurt, Greek style, plain
# 2879    12-375   Yogurt, whole milk, fruit
#
#                                             Description Group  \
# 2871          7 samples, 6 brands, made with whole milk    BN
# 2879  9 samples, 5 brands, assorted flavours includi...    BN
#
#                    Previous  \
# 2871                12-376
# 2879  12-185 12-869 50-261
#
#                                    Main data references Footnote Energy (kJ)  \
# 2871  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN         551
# 2879  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN         471
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2871           133     10.2          6.75              4.6        4.3
# 2879           112      3.0          2.01             17.1       16.1
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2871        0.3         0          5.6     0.17
# 2879          1       0.3          3.9     0.15

# %%
filt_bn['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_71184\4097512455.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_bn['Super Group'] = 'Milk and milk products'

# %% [markdown]
# Removed BNE

# %% [markdown]
# Removed BNH

# %% [markdown]
#                                                         Vegetables

# %% [markdown]
# Vegetables general

# %%
dg = prod_y.loc[prod_y['Group']== 'DG']
dg
# Out:
#      Food Code                                  Food Name  \
# 2863    13-398                                 Yam, baked
# 2864    13-655  Yam, flesh only, boiled in unsalted water
# 2865    13-397                       Yam, flesh only, raw
# 2866    13-401                               Yam, steamed
#
#                                             Description Group Previous  \
# 2863  Literature sources and calculation from raw; b...    DG      NaN
# 2864  8 samples, fresh, imported. Peeled, cut into c...    DG   13-400
# 2865                                         flesh only    DG  50-836
# 2866  Literature sources and calculation from raw, s...    DG      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2863      Vegetables, Herbs and Spices Supplement, 1991      NaN         654
# 2864  PHE, Nutrient analysis of fresh and processed ...      NaN         507
# 2865      Vegetables, Herbs and Spices Supplement, 1991      NaN         493
# 2866      Vegetables, Herbs and Spices Supplement, 1991      NaN         493
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2863           154      0.4           0.1             34.1        0.9
# 2864           120      0.2          0.07             26.7        1.8
# 2865           116      0.3           0.1             25.7        0.7
# 2866           116      0.3           0.1             25.7        0.7
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2863       33.2       3.1          2.1     0.01
# 2864       24.9       2.3          1.6        0
# 2865         25       2.3          1.6     0.01
# 2866         25       2.3          1.6        0

# %%
dg['Food Name'].unique()
# Out:
# array(['Yam, baked', 'Yam, flesh only, boiled in unsalted water',
#        'Yam, flesh only, raw', 'Yam, steamed'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
filt_dg = dg[dg['Food Name'] == 'Yam, baked']
filt_dg
# Out:
#      Food Code   Food Name                                        Description  \
# 2863    13-398  Yam, baked  Literature sources and calculation from raw; b...
#
#      Group Previous                           Main data references Footnote  \
# 2863    DG      NaN  Vegetables, Herbs and Spices Supplement, 1991      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 2863         654           154      0.4           0.1             34.1
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2863        0.9       33.2       3.1          2.1     0.01

# %%
filt_dg['Super Group'] = ' Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_71184\2807567293.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_dg['Super Group'] = ' Vegetables'

# %% [markdown]
#                                         Soups, sauces and miscellaneous foods

# %% [markdown]
# Miscellaneous foods

# %%
wy = prod_y.loc[prod_y['Group']== 'WY']
wy
# Out:
#      Food Code                  Food Name  \
# 2867    17-517              Yeast extract
# 2868    17-378  Yeast, bakers, compressed
# 2869    17-379               Yeast, dried
#
#                                         Description Group         Previous  \
# 2867  Mixed sample including Marmite and own brands    WY  17-380 50-1179
# 2868                             Literature sources    WY         50-1187
# 2869                             Literature sources    WY         50-1188
#
#                                    Main data references Footnote Energy (kJ)  \
# 2867  As Miscellaneous Foods Supplement 17-380 with ...      NaN         793
# 2868                           Reviewed 2013. MW4, 1978      NaN         304
# 2869                           Reviewed 2013. MW4, 1978      NaN         996
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2867           187      0.4          0.04              3.4        1.7
# 2868            73      0.4          0.26                1          0
# 2869           238      1.5          0.47              3.2          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2867        1.7         0         42.4    10.75
# 2868          1       7.2         12.6     0.04
# 2869        3.2      26.9         39.5     0.13

# %% [markdown]
# **Reduced**

# %%
filt_wy = wy[wy['Food Name'] == 'Yeast extract']
filt_wy
# Out:
#      Food Code      Food Name                                    Description  \
# 2867    17-517  Yeast extract  Mixed sample including Marmite and own brands
#
#      Group         Previous  \
# 2867    WY  17-380 50-1179
#
#                                    Main data references Footnote Energy (kJ)  \
# 2867  As Miscellaneous Foods Supplement 17-380 with ...      NaN         793
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2867           187      0.4          0.04              3.4        1.7
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 2867        1.7         0         42.4    10.75

# %%
filt_wy['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_71184\2693890349.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt_wy['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
#                                               **Join Reduced Tables**

# %%
Red = pd.concat([filt_at, filt_bn], axis=0, join='inner')
Red
# Out:
#      Food Code                                          Food Name  \
# 2885   11-1135  Yorkshire pudding, made with skimmed milk, hom...
# 2871    12-555                         Yogurt, Greek style, plain
# 2879    12-375                          Yogurt, whole milk, fruit
#
#                                             Description Group  \
# 2885                                             Recipe    AT
# 2871          7 samples, 6 brands, made with whole milk    BN
# 2879  9 samples, 5 brands, assorted flavours includi...    BN
#
#                    Previous  \
# 2885                11-713
# 2871                12-376
# 2879  12-185 12-869 50-261
#
#                                    Main data references Footnote Energy (kJ)  \
# 2885                                       Updated 2014      NaN         803
# 2871  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN         551
# 2879  Reviewed 2013. Campden and Chorleywood FRA, Nu...      NaN         471
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2885           191      7.4          1.23             23.6        3.3
# 2871           133     10.2          6.75              4.6        4.3
# 2879           112      3.0          2.01             17.1       16.1
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# 2885       20.3       1.1          7.0     0.14  Cereals and cereal products
# 2871        0.3         0          5.6     0.17       Milk and milk products
# 2879          1       0.3          3.9     0.15       Milk and milk products

# %%
Red2 = pd.concat([Red,filt_fa], axis=0, join='inner')
Red2
# Out:
#      Food Code                                   Food Name  \
# 2817    11-800  Wafers, plain ice cream wafers, not filled
# 2823    13-673                             Watercress, raw
# 2840    14-268                          Whitecurrants, raw
#
#                                             Description Group Previous  \
# 2817  10 samples, 9 products, including cones, corne...    AM  12-212
# 2823                        11 samples, UK and imported    DG   13-653
# 2840                        Whole fruit, stalks removed    FA      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 2817  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1568
# 2823  PHE, Nutrient analysis of fresh and processed ...      NaN          55
# 2840  MW4, 1978. Values revised for Fruit and Nuts S...      NaN         149
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2817           370      3.0          0.59             72.6        3.3
# 2823            13      0.3          0.09                0          0
# 2840            35      0.0             0              5.5        5.5
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# 2817       69.3       3.4         11.5     0.48  Cereals and cereal products
# 2823          0       1.5          1.9     0.09                   Vegetables
# 2840          0       4.3          1.3     0.01                        Fruit

# %%
Red3 = pd.concat([Red2,filt_ga], axis=0, join='inner')
Red3
# Out:
#      Food Code                                   Food Name  \
# 2817    11-800  Wafers, plain ice cream wafers, not filled
# 2823    13-673                             Watercress, raw
# 2840    14-268                          Whitecurrants, raw
# 2819    14-879                        Walnuts, kernel only
#
#                                             Description Group  \
# 2817  10 samples, 9 products, including cones, corne...    AM
# 2823                        11 samples, UK and imported    DG
# 2840                        Whole fruit, stalks removed    FA
# 2819                                         10 samples    GA
#
#                     Previous  \
# 2817                 12-212
# 2823                  13-653
# 2840                     NaN
# 2819  14-850 14-860 50-997
#
#                                    Main data references Footnote Energy (kJ)  \
# 2817  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1568
# 2823  PHE, Nutrient analysis of fresh and processed ...      NaN          55
# 2840  MW4, 1978. Values revised for Fruit and Nuts S...      NaN         149
# 2819  Reviewed 2013. LGC, Savoury snacks and nuts, 1...      NaN        2936
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2817           370      3.0          0.59             72.6        3.3
# 2823            13      0.3          0.09                0          0
# 2840            35      0.0             0              5.5        5.5
# 2819           712     68.5          7.47              3.1        2.5
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# 2817       69.3       3.4         11.5     0.48  Cereals and cereal products
# 2823          0       1.5          1.9     0.09                   Vegetables
# 2840          0       4.3          1.3     0.01                        Fruit
# 2819        0.6       6.7         17.3     0.02               Nuts and seeds

# %%
Red4 = pd.concat([Red3,jc], axis=0, join='inner')
Red4
# Out:
#      Food Code                                   Food Name  \
# 2817    11-800  Wafers, plain ice cream wafers, not filled
# 2823    13-673                             Watercress, raw
# 2840    14-268                          Whitecurrants, raw
# 2819    14-879                        Walnuts, kernel only
# 2839    16-231                  Whitebait, in flour, fried
#
#                                             Description Group  \
# 2817  10 samples, 9 products, including cones, corne...    AM
# 2823                        11 samples, UK and imported    DG
# 2840                        Whole fruit, stalks removed    FA
# 2819                                         10 samples    GA
# 2839              Whole fish; rolled in flour and fried    JC
#
#                     Previous  \
# 2817                 12-212
# 2823                  13-653
# 2840                     NaN
# 2819  14-850 14-860 50-997
# 2839                 50-633
#
#                                    Main data references Footnote Energy (kJ)  \
# 2817  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1568
# 2823  PHE, Nutrient analysis of fresh and processed ...      NaN          55
# 2840  MW4, 1978. Values revised for Fruit and Nuts S...      NaN         149
# 2819  Reviewed 2013. LGC, Savoury snacks and nuts, 1...      NaN        2936
# 2839  MW4, 1978. Estimated values and fibre from Fis...      NaN        2171
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2817           370      3.0          0.59             72.6        3.3
# 2823            13      0.3          0.09                0          0
# 2840            35      0.0             0              5.5        5.5
# 2819           712     68.5          7.47              3.1        2.5
# 2839           525     47.5             N              4.7          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# 2817       69.3       3.4         11.5     0.48  Cereals and cereal products
# 2823          0       1.5          1.9     0.09                   Vegetables
# 2840          0       4.3          1.3     0.01                        Fruit
# 2819        0.6       6.7         17.3     0.02               Nuts and seeds
# 2839        4.7       0.2         19.5     0.58       Fish and fish products

# %%
Red5 = pd.concat([Red4,filt_qe], axis=0, join='inner')
Red5
# Out:
#      Food Code                                   Food Name  \
# 2817    11-800  Wafers, plain ice cream wafers, not filled
# 2823    13-673                             Watercress, raw
# 2840    14-268                          Whitecurrants, raw
# 2819    14-879                        Walnuts, kernel only
# 2839    16-231                  Whitebait, in flour, fried
# 2854    17-752                                   Wine, red
# 2857    17-756                         Wine, white, medium
#
#                                             Description Group  \
# 2817  10 samples, 9 products, including cones, corne...    AM
# 2823                        11 samples, UK and imported    DG
# 2840                        Whole fruit, stalks removed    FA
# 2819                                         10 samples    GA
# 2839              Whole fish; rolled in flour and fried    JC
# 2854  Typically 11-15% ABV. Mixed sample from differ...    QE
# 2857   8-13% ABV. Mixed sample from different countries    QE
#
#                     Previous  \
# 2817                 12-212
# 2823                  13-653
# 2840                     NaN
# 2819  14-850 14-860 50-997
# 2839                 50-633
# 2854                 17-228
# 2857                 17-231
#
#                                    Main data references Footnote Energy (kJ)  \
# 2817  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1568
# 2823  PHE, Nutrient analysis of fresh and processed ...      NaN          55
# 2840  MW4, 1978. Values revised for Fruit and Nuts S...      NaN         149
# 2819  Reviewed 2013. LGC, Savoury snacks and nuts, 1...      NaN        2936
# 2839  MW4, 1978. Estimated values and fibre from Fis...      NaN        2171
# 2854  Industry data 2010, 2013; and calculated from ...      NaN         317
# 2857  Industry data 2010, 2013; and calculated from ...      NaN         317
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2817           370      3.0          0.59             72.6        3.3
# 2823            13      0.3          0.09                0          0
# 2840            35      0.0             0              5.5        5.5
# 2819           712     68.5          7.47              3.1        2.5
# 2839           525     47.5             N              4.7          0
# 2854            76      0.0             0              0.2        0.2
# 2857            76      0.0             0                3          3
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)                  Super Group
# 2817       69.3       3.4         11.5     0.48  Cereals and cereal products
# 2823          0       1.5          1.9     0.09                   Vegetables
# 2840          0       4.3          1.3     0.01                        Fruit
# 2819        0.6       6.7         17.3     0.02               Nuts and seeds
# 2839        4.7       0.2         19.5     0.58       Fish and fish products
# 2854          0         0          0.2     0.02          Alcoholic beverages
# 2857          0         0          0.1     0.03          Alcoholic beverages

# %%
Red6 = pd.concat([Red5,filt_wcd], axis=0, join='inner')
Red6
# Out:
#      Food Code                                          Food Name  \
# 2817    11-800         Wafers, plain ice cream wafers, not filled
# 2823    13-673                                    Watercress, raw
# 2840    14-268                                 Whitecurrants, raw
# 2819    14-879                               Walnuts, kernel only
# 2839    16-231                         Whitebait, in flour, fried
# 2854    17-752                                          Wine, red
# 2857    17-756                                Wine, white, medium
# 2834    17-778  White sauce, savoury, made with skimmed milk, ...
#
#                                             Description Group  \
# 2817  10 samples, 9 products, including cones, corne...    AM
# 2823                        11 samples, UK and imported    DG
# 2840                        Whole fruit, stalks removed    FA
# 2819                                         10 samples    GA
# 2839              Whole fish; rolled in flour and fried    JC
# 2854  Typically 11-15% ABV. Mixed sample from differ...    QE
# 2857   8-13% ABV. Mixed sample from different countries    QE
# 2834                                             Recipe   WCD
#
#                     Previous  \
# 2817                 12-212
# 2823                  13-653
# 2840                     NaN
# 2819  14-850 14-860 50-997
# 2839                 50-633
# 2854                 17-228
# 2857                 17-231
# 2834                 17-573
#
#                                    Main data references Footnote Energy (kJ)  \
# 2817  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1568
# 2823  PHE, Nutrient analysis of fresh and processed ...      NaN          55
# 2840  MW4, 1978. Values revised for Fruit and Nuts S...      NaN         149
# 2819  Reviewed 2013. LGC, Savoury snacks and nuts, 1...      NaN        2936
# 2839  MW4, 1978. Estimated values and fibre from Fis...      NaN        2171
# 2854  Industry data 2010, 2013; and calculated from ...      NaN         317
# 2857  Industry data 2010, 2013; and calculated from ...      NaN         317
# 2834                                       Updated 2014      NaN         493
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2817           370      3.0          0.59             72.6        3.3
# 2823            13      0.3          0.09                0          0
# 2840            35      0.0             0              5.5        5.5
# 2819           712     68.5          7.47              3.1        2.5
# 2839           525     47.5             N              4.7          0
# 2854            76      0.0             0              0.2        0.2
# 2857            76      0.0             0                3          3
# 2834           118      6.5          4.03             10.2        4.9
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)  \
# 2817       69.3       3.4         11.5     0.48
# 2823          0       1.5          1.9     0.09
# 2840          0       4.3          1.3     0.01
# 2819        0.6       6.7         17.3     0.02
# 2839        4.7       0.2         19.5     0.58
# 2854          0         0          0.2     0.02
# 2857          0         0          0.1     0.03
# 2834        5.4       0.3          4.5     0.26
#
#                                 Super Group
# 2817            Cereals and cereal products
# 2823                             Vegetables
# 2840                                  Fruit
# 2819                         Nuts and seeds
# 2839                 Fish and fish products
# 2854                    Alcoholic beverages
# 2857                    Alcoholic beverages
# 2834  Soups, sauces and miscellaneous foods

# %%
Red7 = pd.concat([Red6,wcn], axis=0, join='inner')
Red7
# Out:
#      Food Code                                          Food Name  \
# 2817    11-800         Wafers, plain ice cream wafers, not filled
# 2823    13-673                                    Watercress, raw
# 2840    14-268                                 Whitecurrants, raw
# 2819    14-879                               Walnuts, kernel only
# 2839    16-231                         Whitebait, in flour, fried
# 2854    17-752                                          Wine, red
# 2857    17-756                                Wine, white, medium
# 2834    17-778  White sauce, savoury, made with skimmed milk, ...
# 2862    17-723                               Worcestershire sauce
#
#                                             Description Group  \
# 2817  10 samples, 9 products, including cones, corne...    AM
# 2823                        11 samples, UK and imported    DG
# 2840                        Whole fruit, stalks removed    FA
# 2819                                         10 samples    GA
# 2839              Whole fish; rolled in flour and fried    JC
# 2854  Typically 11-15% ABV. Mixed sample from differ...    QE
# 2857   8-13% ABV. Mixed sample from different countries    QE
# 2834                                             Recipe   WCD
# 2862                                7 samples, 3 brands   WCN
#
#                     Previous  \
# 2817                 12-212
# 2823                  13-653
# 2840                     NaN
# 2819  14-850 14-860 50-997
# 2839                 50-633
# 2854                 17-228
# 2857                 17-231
# 2834                 17-573
# 2862                 17-340
#
#                                    Main data references Footnote Energy (kJ)  \
# 2817  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1568
# 2823  PHE, Nutrient analysis of fresh and processed ...      NaN          55
# 2840  MW4, 1978. Values revised for Fruit and Nuts S...      NaN         149
# 2819  Reviewed 2013. LGC, Savoury snacks and nuts, 1...      NaN        2936
# 2839  MW4, 1978. Estimated values and fibre from Fis...      NaN        2171
# 2854  Industry data 2010, 2013; and calculated from ...      NaN         317
# 2857  Industry data 2010, 2013; and calculated from ...      NaN         317
# 2834                                       Updated 2014      NaN         493
# 2862  LFRA, Nutrient analysis of miscellaneous foods...      NaN         413
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2817           370      3.0          0.59             72.6        3.3
# 2823            13      0.3          0.09                0          0
# 2840            35      0.0             0              5.5        5.5
# 2819           712     68.5          7.47              3.1        2.5
# 2839           525     47.5             N              4.7          0
# 2854            76      0.0             0              0.2        0.2
# 2857            76      0.0             0                3          3
# 2834           118      6.5          4.03             10.2        4.9
# 2862            97      0.1             0             22.7       20.5
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)  \
# 2817       69.3       3.4         11.5     0.48
# 2823          0       1.5          1.9     0.09
# 2840          0       4.3          1.3     0.01
# 2819        0.6       6.7         17.3     0.02
# 2839        4.7       0.2         19.5     0.58
# 2854          0         0          0.2     0.02
# 2857          0         0          0.1     0.03
# 2834        5.4       0.3          4.5     0.26
# 2862        2.2         0          1.4     3.75
#
#                                 Super Group
# 2817            Cereals and cereal products
# 2823                             Vegetables
# 2840                                  Fruit
# 2819                         Nuts and seeds
# 2839                 Fish and fish products
# 2854                    Alcoholic beverages
# 2857                    Alcoholic beverages
# 2834  Soups, sauces and miscellaneous foods
# 2862  Soups, sauces and miscellaneous foods

# %%
Red8 = pd.concat([Red7,wy], axis=0, join='inner')
Red8
# Out:
#      Food Code                                          Food Name  \
# 2817    11-800         Wafers, plain ice cream wafers, not filled
# 2823    13-673                                    Watercress, raw
# 2840    14-268                                 Whitecurrants, raw
# 2819    14-879                               Walnuts, kernel only
# 2839    16-231                         Whitebait, in flour, fried
# 2854    17-752                                          Wine, red
# 2857    17-756                                Wine, white, medium
# 2834    17-778  White sauce, savoury, made with skimmed milk, ...
# 2862    17-723                               Worcestershire sauce
# 2822    17-377                                   Water, distilled
#
#                                             Description Group  \
# 2817  10 samples, 9 products, including cones, corne...    AM
# 2823                        11 samples, UK and imported    DG
# 2840                        Whole fruit, stalks removed    FA
# 2819                                         10 samples    GA
# 2839              Whole fish; rolled in flour and fried    JC
# 2854  Typically 11-15% ABV. Mixed sample from differ...    QE
# 2857   8-13% ABV. Mixed sample from different countries    QE
# 2834                                             Recipe   WCD
# 2862                                7 samples, 3 brands   WCN
# 2822                    Included for recipe calculation    WY
#
#                     Previous  \
# 2817                 12-212
# 2823                  13-653
# 2840                     NaN
# 2819  14-850 14-860 50-997
# 2839                 50-633
# 2854                 17-228
# 2857                 17-231
# 2834                 17-573
# 2862                 17-340
# 2822                50-1186
#
#                                    Main data references Footnote Energy (kJ)  \
# 2817  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1568
# 2823  PHE, Nutrient analysis of fresh and processed ...      NaN          55
# 2840  MW4, 1978. Values revised for Fruit and Nuts S...      NaN         149
# 2819  Reviewed 2013. LGC, Savoury snacks and nuts, 1...      NaN        2936
# 2839  MW4, 1978. Estimated values and fibre from Fis...      NaN        2171
# 2854  Industry data 2010, 2013; and calculated from ...      NaN         317
# 2857  Industry data 2010, 2013; and calculated from ...      NaN         317
# 2834                                       Updated 2014      NaN         493
# 2862  LFRA, Nutrient analysis of miscellaneous foods...      NaN         413
# 2822  Reviewed 2013. Miscellaneous Foods Supplement,...      NaN           0
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 2817           370      3.0          0.59             72.6        3.3
# 2823            13      0.3          0.09                0          0
# 2840            35      0.0             0              5.5        5.5
# 2819           712     68.5          7.47              3.1        2.5
# 2839           525     47.5             N              4.7          0
# 2854            76      0.0             0              0.2        0.2
# 2857            76      0.0             0                3          3
# 2834           118      6.5          4.03             10.2        4.9
# 2862            97      0.1             0             22.7       20.5
# 2822             0      0.0             0                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)  \
# 2817       69.3       3.4         11.5     0.48
# 2823          0       1.5          1.9     0.09
# 2840          0       4.3          1.3     0.01
# 2819        0.6       6.7         17.3     0.02
# 2839        4.7       0.2         19.5     0.58
# 2854          0         0          0.2     0.02
# 2857          0         0          0.1     0.03
# 2834        5.4       0.3          4.5     0.26
# 2862        2.2         0          1.4     3.75
# 2822          0         0          0.0        0
#
#                                 Super Group
# 2817            Cereals and cereal products
# 2823                             Vegetables
# 2840                                  Fruit
# 2819                         Nuts and seeds
# 2839                 Fish and fish products
# 2854                    Alcoholic beverages
# 2857                    Alcoholic beverages
# 2834  Soups, sauces and miscellaneous foods
# 2862  Soups, sauces and miscellaneous foods
# 2822  Soups, sauces and miscellaneous foods

# %% [markdown]
#                                                        Export

# %%
Red8.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced_W.csv')
