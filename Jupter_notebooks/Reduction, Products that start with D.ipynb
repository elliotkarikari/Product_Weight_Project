# %% [markdown]
# # Product Weighting Project

# %% [markdown]
#                                          Data Reduction - Food Purchased In Store

# %% [markdown]
# ###### Import Necessary Libraries

# %%
import pandas as pd

# %% [markdown]
# Read in Data

# %%
Labelled = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Labelling2021_watercress.csv')

# %% [markdown]
# ### Products beginning with a 'D'

# %%
Prod_D = Labelled.loc[Labelled['Food Name'].str.startswith('D')]
Prod_D.head()
# Out:
#      Food Code                                          Food Name  \
# 1020    16-038                                           Dab, raw
# 1021    13-484                              Dahl, mixed, homemade
# 1022    15-511                              Dal Dhokari, homemade
# 1023    14-077                       Damsons, flesh and skin, raw
# 1024    14-078  Damsons, flesh and skin, raw, weighed with stones
#
#                                             Description Group Previous  \
# 1020                                 Literature sources    JA      NaN
# 1021                 5 samples, mixed lentils in spices    DB      NaN
# 1022  Recipe. Gujerati dish. Pastry shapes in pigeon...    DR  15-159
# 1023                                     Flesh and skin    FA      NaN
# 1024                             Calculated from 14-077    FA  50-884
#
#                                    Main data references Footnote Energy (kJ)  \
# ...

# %% [markdown]
# Products within a Group (provide identification of the food group and food type to which the food belongs)

# %%
Prod_D.groupby('Group')['Food Name'].count()
# Out:
# Group
# AP      2
# AT      1
# BR      1
# DB      1
# DG      4
# DR      2
# FA     12
# H       3
# JA      2
# MCC     7
# MR      6
# OF      1
# PAA     5
# WC      3
# WCG     6
# Name: Food Name, dtype: int64

# %% [markdown]
# ## *Reducing products based on its most basic form. Improve as you go on*

# %% [markdown]
#                                               Cereals and cereal products

# %% [markdown]
# Buns and pastries

# %%
AP = Prod_D.loc[Prod_D['Group']== 'AP']
AP
# Out:
#      Food Code              Food Name                        Description  \
# 1043    11-850  Doughnuts, ring, iced  10 samples, branded and own brand
# 1044    11-849    Doughnuts, with jam  10 samples, branded and own brand
#
#      Group Previous                               Main data references  \
# 1043    AP  11-244   DH, Nutrient analysis of biscuits, buns, cakes...
# 1044    AP  11-242   DH, Nutrient analysis of biscuits, buns, cakes...
#
#      Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 1043      NaN        1751           420     25.7         14.14
# 1044      NaN        1377           328     13.1          4.96
#
#      Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1043             39.4       15.5       23.8       2.7          6.4     0.82
# 1044             45.8       20.1       25.6       1.7          5.9     1.01

# %%
AP['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27584\4095834454.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AP['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Savouries

# %%
AT = Prod_D.loc[Prod_D['Group']== 'AT']
AT
# Out:
#      Food Code            Food Name Description Group Previous  \
# 1074    11-962  Dumplings, homemade      Recipe    AT  11-603
#
#               Main data references Footnote Energy (kJ) Energy (kcal)  \
# 1074  As MW6. Recalculated in 2013      NaN         884           211
#
#       Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1074     11.7          6.63               23        0.1       22.9       1.2
#
#       Protein (g) Salt (g)
# 1074          2.9     0.35

# %%
AT['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27584\2815507821.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AT['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
#                                                   Milk and milk products

# %% [markdown]
# Puddings and chilled desserts

# %%
BR = Prod_D.loc[Prod_D['Group']== 'BR']
BR
# Out:
#      Food Code                   Food Name  \
# 1033    12-398  Desserts, dairy, chocolate
#
#                                             Description Group Previous  \
# 1033  8 samples, 4 brands including milk chocolate a...    BR  12-912
#
#                                    Main data references Footnote Energy (kJ)  \
# 1033  Reviewed 2013. LGC, Nutritional analysis of fo...      NaN         899
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1033           215     10.7          6.26             25.3       22.9
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1033        2.5         0          4.3     0.19

# %%
BR['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27584\1314462780.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BR['Super Group'] = 'Milk and milk products'

# %% [markdown]
#                                                        Vegetables

# %% [markdown]
# Removed DG - Drumstick leaves and pods. Couldn't find them in tesco database

# %% [markdown]
# Removed DR - Dal Dhorkar and Dosa. Couldn't find them in tesco database

# %% [markdown]
#                                                         Fruit

# %% [markdown]
# Fruit General

# %%
FA = Prod_D.loc[Prod_D['Group']== 'FA']
FA
# Out:
#      Food Code                                          Food Name  \
# 1023    14-077                       Damsons, flesh and skin, raw
# 1024    14-078  Damsons, flesh and skin, raw, weighed with stones
# 1025    14-079                         Damsons, stewed with sugar
# 1026    14-080    Damsons, stewed with sugar, weighed with stones
# 1027    14-081                      Damsons, stewed without sugar
# 1028    14-082  Damsons, stewed without sugar, weighed with st...
# 1029    14-394                       Dates, dried, flesh and skin
# 1030    14-399  Dates, dried, flesh and skin, weighed with stones
# 1031    14-083                         Dates, raw, flesh and skin
# 1032    14-084    Dates, raw, flesh and skin, weighed with stones
# 1053    14-087                                  Dried mixed fruit
# 1075    14-088                                 Durian, flesh only
#
#                                             Description Group Previous  \
# ...

# %%
FA['Food Name'].unique()
# Out:
# array(['Damsons, flesh and skin, raw',
#        'Damsons, flesh and skin, raw, weighed with stones',
#        'Damsons, stewed with sugar',
#        'Damsons, stewed with sugar, weighed with stones',
#        'Damsons, stewed without sugar',
#        'Damsons, stewed without sugar, weighed with stones',
#        'Dates, dried, flesh and skin',
#        'Dates, dried, flesh and skin, weighed with stones',
#        'Dates, raw, flesh and skin',
#        'Dates, raw, flesh and skin, weighed with stones',
#        'Dried mixed fruit', 'Durian, flesh only'], dtype=object)

# %% [markdown]
# ##### Reduced

# %%
Priority_FA = ['Damsons, flesh and skin, raw','Dates, raw, flesh and skin','Cranberries', 'Currants','Dried mixed fruit']

# %%
Filt_FA = FA[FA['Food Name'].isin(Priority_FA)]
Filt_FA
# Out:
#      Food Code                     Food Name  \
# 1023    14-077  Damsons, flesh and skin, raw
# 1031    14-083    Dates, raw, flesh and skin
# 1053    14-087             Dried mixed fruit
#
#                                             Description Group Previous  \
# 1023                                     Flesh and skin    FA      NaN
# 1031                                         5 samples;    FA      NaN
# 1053  Calculated as sultanas 49%, currants 24%, rais...    FA  50-888
#
#                                    Main data references Footnote Energy (kJ)  \
# 1023  MW4, 1978. Values revised for Fruit and Nuts S...      NaN         200
# 1031  LGC, Fruit and vegetables, 1989-1990; vitamin ...      NaN         590
# 1053     Reviewed 2013. Fruit and Nuts Supplement, 1992      NaN        1231
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1023            47      0.0             0              9.6        9.6
# ...

# %%
Filt_FA['Super Group'] = 'Fruit'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27584\3797725470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_FA['Super Group'] = 'Fruit'

# %% [markdown]
#                                                    Herbs and Spices

# %%
H = Prod_D.loc[Prod_D['Group']== 'H']
H
# Out:
#      Food Code    Food Name                       Description Group Previous  \
# 1035    13-826   Dill seeds                Literature sources     H      NaN
# 1036    13-825  Dill, dried                Literature sources     H      NaN
# 1037    13-824  Dill, fresh  6 samples and literature sources     H      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1035  Marsh et al. (1977) Composition of foods: spic...      NaN        1557
# 1036      Vegetables, Herbs and Spices Supplement, 1991      NaN        1309
# 1037      Vegetables, Herbs and Spices Supplement, 1991      NaN         127
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1035           373     14.5           0.7             34.1       30.4
# 1036           311      4.4          0.23             41.1       36.9
# 1037            30      0.8          0.06              0.9        0.8
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_H = ['Dill, fresh']

# %%
Filt_H = H[H['Food Name'].isin(Priority_H)]
Filt_H
# Out:
#      Food Code    Food Name                       Description Group Previous  \
# 1037    13-824  Dill, fresh  6 samples and literature sources     H      NaN
#
#                                Main data references Footnote Energy (kJ)  \
# 1037  Vegetables, Herbs and Spices Supplement, 1991      NaN         127
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1037            30      0.8          0.06              0.9        0.8
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1037        0.1       2.5          3.7     0.07

# %%
Filt_H['Super Group'] = 'Herbs and Spices'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27584\854041242.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_H['Super Group'] = 'Herbs and Spices'

# %% [markdown]
#                                                    Fish and Fish Products

# %% [markdown]
# Removed JA - Dab and Dover sole - Couldn't find them in tesco database. Also I have lots of fish products from previous products

# %% [markdown]
#                                                   Meat and meat products

# %% [markdown]
# Duck

# %%
MCC = Prod_D.loc[Prod_D['Group']== 'MCC']
MCC
# Out:
#      Food Code                                          Food Name  \
# 1067    18-490         Duck, crispy, chinese style, meat and skin
# 1068    18-489                               Duck, meat only, raw
# 1069    18-495  Duck, raw, meat only, weighed with fat, skin a...
# 1070    18-371                      Duck, raw, meat, fat and skin
# 1071    18-372                           Duck, roasted, meat only
# 1072    18-373  Duck, roasted, meat only, weighed with fat, sk...
# 1073    18-374                  Duck, roasted, meat, fat and skin
#
#                                             Description Group  \
# 1067  10 samples from chinese takeaways, seasoned ro...   MCC
# 1068              19 samples, meat from dressed carcase   MCC
# 1069                             Calculated from 18-489   MCC
# 1070  10 samples; meat, fat and skin = 0.57 of dress...   MCC
# 1071                    10 samples from dressed carcase   MCC
# 1072                             Calculated from 18-372   MCC
# ...

# %%
MCC['Food Name'].unique()
# Out:
# array(['Duck, crispy, chinese style, meat and skin',
#        'Duck, meat only, raw',
#        'Duck, raw, meat only, weighed with fat, skin and bone',
#        'Duck, raw, meat, fat and skin', 'Duck, roasted, meat only',
#        'Duck, roasted, meat only, weighed with fat, skin and bone',
#        'Duck, roasted, meat, fat and skin'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_MCC = ['Duck, meat only, raw']

# %%
Filt_MCC = MCC[MCC['Food Name'].isin(Priority_MCC)]
Filt_MCC
# Out:
#      Food Code             Food Name                            Description  \
# 1068    18-489  Duck, meat only, raw  19 samples, meat from dressed carcase
#
#      Group                      Previous  \
# 1068   MCC  18-369 40-327 50-445 18-461
#
#                                    Main data references Footnote Energy (kJ)  \
# 1068  Reviewed 2013. LGC, Poultry and game surveys, ...      NaN         575
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1068           137      6.5             2                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1068          0         0         19.7     0.28

# %%
Filt_MCC['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27584\1301449510.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_MCC['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Meat dishes

# %%
MR = Prod_D.loc[Prod_D['Group']== 'MR']
MR
# Out:
#      Food Code                                          Food Name  \
# 1034    19-576                         Devilled kidneys, homemade
# 1040    19-526              Doner kebab in pitta bread with salad
# 1041    19-539                            Doner kebabs, meat only
# 1064    19-578  Duck a l'orange, excluding fat and skin, homemade
# 1065    19-579  Duck a l'orange, including fat and skin, homemade
# 1066    19-580                      Duck with pineapple, homemade
#
#                                             Description Group Previous  \
# 1034                                             Recipe    MR  19-392
# 1040  Calculated from 50% doner kebab (19-129), 22% ...    MR  19-130
# 1041                 20 samples from assorted takeaways    MR  19-129
# 1064                                             Recipe    MR  19-393
# 1065                                             Recipe    MR  19-394
# 1066                                             Recipe    MR  19-396
#
# ...

# %%
MR['Food Name'].unique()
# Out:
# array(['Devilled kidneys, homemade',
#        'Doner kebab in pitta bread with salad', 'Doner kebabs, meat only',
#        "Duck a l'orange, excluding fat and skin, homemade",
#        "Duck a l'orange, including fat and skin, homemade",
#        'Duck with pineapple, homemade'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_MR = ['Doner kebabs, meat only']

# %%
Filt_MR = MR[MR['Food Name'].isin(Priority_MR)]
Filt_MR
# Out:
#      Food Code                Food Name                         Description  \
# 1041    19-539  Doner kebabs, meat only  20 samples from assorted takeaways
#
#      Group Previous                               Main data references  \
# 1041    MR  19-129   Reviewed 2013. LGC, Nutrient analysis of retai...
#
#      Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 1041      NaN        1561           377     31.4         14.98
#
#      Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1041                0          0          0         0         23.5        N

# %%
Filt_MR['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27584\3346374556.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_MR['Super Group'] = 'Meat and meat products'

# %% [markdown]
#                                                    Fats and Oils

# %% [markdown]
# Cooking fats

# %%
OF = Prod_D.loc[Prod_D['Group']== 'OF']
OF
# Out:
#      Food Code       Food Name                  Description Group  \
# 1059    17-487  Dripping, beef  5 samples, different brands    OF
#
#                     Previous  \
# 1059  17-006 17-472 50-317
#
#                                    Main data references Footnote Energy (kJ)  \
# 1059  Reviewed 2013. MW1, 1940 with fatty acids from...      NaN        3663
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1059           891     99.0         50.62                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1059          0         0          0.0     0.01

# %%
OF['Super Group'] = 'Fats and Oils'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27584\1888974168.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   OF['Super Group'] = 'Fats and Oils'

# %% [markdown]
#                                                         Beverages

# %% [markdown]
# Powdered drinks and essences

# %%
PAA = Prod_D.loc[Prod_D['Group']== 'PAA']
PAA
# Out:
#      Food Code                                          Food Name  \
# 1054    17-790  Drinking chocolate powder, made up with semi-s...
# 1055    17-791  Drinking chocolate powder, made up with skimme...
# 1056    17-792  Drinking chocolate powder, made up with whole ...
# 1057    17-498                         Drinking chocolate, powder
# 1058    17-499            Drinking chocolate, powder, reduced fat
#
#                                             Description Group  \
# 1054           Calculated from 18g powder to 200ml milk   PAA
# 1055  Recipe. Made up according to packet directions...   PAA
# 1056           Calculated from 18g powder to 200ml milk   PAA
# 1057                                  10 tins, 3 brands   PAA
# 1058                               10 samples, 4 brands   PAA
#
#                      Previous  \
# 1054                  17-532
# 1055                  17-559
# 1056                  17-533
# 1057  12-093 12-883 50-1064
# 1058                      NaN
#
# ...

# %%
PAA['Food Name'].unique()
# Out:
# array(['Drinking chocolate powder, made up with semi-skimmed milk',
#        'Drinking chocolate powder, made up with skimmed milk',
#        'Drinking chocolate powder, made up with whole milk',
#        'Drinking chocolate, powder',
#        'Drinking chocolate, powder, reduced fat'], dtype=object)

# %%
Priority_PAA = ['Drinking chocolate, powder']

# %%
Filt_PAA = PAA[PAA['Food Name'].isin(Priority_PAA)]
Filt_PAA
# Out:
#      Food Code                   Food Name        Description Group  \
# 1057    17-498  Drinking chocolate, powder  10 tins, 3 brands   PAA
#
#                      Previous  \
# 1057  12-093 12-883 50-1064
#
#                                    Main data references Footnote Energy (kJ)  \
# 1057  Reviewed 2013. RHM, Nutrient content of select...      NaN        1687
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1057           400      5.8          3.41             75.9         74
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1057          0       9.3          6.4     0.57

# %%
Filt_PAA['Super Group'] = 'Beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27584\5251205.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_PAA['Super Group'] = 'Beverages'

# %% [markdown]
#                                         Soups, sauces and miscellaneous foods

# %% [markdown]
# Removed WC - Frech dressing was an item below. Didn't find the other items in tesco database

# %% [markdown]
# Salad sauces, dressings and pickles

# %%
WCG = Prod_D.loc[Prod_D['Group']== 'WCG']
WCG
# Out:
#      Food Code                                  Food Name  \
# 1038    17-299  Dips, sour-cream based, assorted flavours
# 1039    17-677        Dips, sour-cream based, reduced fat
# 1046    17-715                      Dressing, blue cheese
# 1047    17-701                           Dressing, French
# 1048    17-716                 Dressing, French, fat free
# 1051    17-717                  Dressing, thousand island
#
#                       Description Group Previous  \
# 1038         7 samples, 4 brands;   WCG      NaN
# 1039                   Label data   WCG      NaN
# 1046          7 samples, 2 brands   WCG  17-300
# 1047          8 samples, 6 brands   WCG  17-509
# 1048  Manufacturer's data (Kraft)   WCG  17-538
# 1051          7 samples, 4 brands   WCG  17-306
#
#                                    Main data references Footnote Energy (kJ)  \
# 1038  Reviewed 2013. RHM Technology, Nutrient analys...      NaN           N
# ...

# %%
WCG['Food Name'].unique()
# Out:
# array(['Dips, sour-cream based, assorted flavours',
#        'Dips, sour-cream based, reduced fat', 'Dressing, blue cheese',
#        'Dressing, French', 'Dressing, French, fat free',
#        'Dressing, thousand island'], dtype=object)

# %% [markdown]
# **Reduced**

# %%
Priority_WCG = ['Dressing, blue cheese','Dressing, French','Dressing, thousand island']

# %%
Filt_WCG = WCG[WCG['Food Name'].isin(Priority_WCG)]
Filt_WCG
# Out:
#      Food Code                  Food Name          Description Group Previous  \
# 1046    17-715      Dressing, blue cheese  7 samples, 2 brands   WCG  17-300
# 1047    17-701           Dressing, French  8 samples, 6 brands   WCG  17-509
# 1051    17-717  Dressing, thousand island  7 samples, 4 brands   WCG  17-306
#
#                                    Main data references Footnote Energy (kJ)  \
# 1046  LFRA, Nutrient analysis of miscellaneous foods...      NaN        1535
# 1047  LFRA, Nutrient analysis of miscellaneous foods...      NaN        1336
# 1051  LFRA, Nutrient analysis of miscellaneous foods...      NaN         878
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1046           372     35.9          6.59              9.6        7.7
# 1047           324     32.2             N              7.9        3.4
# 1051           211     16.4          2.04             15.1       12.8
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# ...

# %%
Filt_WCG['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27584\2275349619.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_WCG['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
#                                               **Join Reduced Tables**

# %%
Red = pd.concat([AP,AT], axis=0, join='inner')
Red
# Out:
#      Food Code              Food Name                        Description  \
# 1043    11-850  Doughnuts, ring, iced  10 samples, branded and own brand
# 1044    11-849    Doughnuts, with jam  10 samples, branded and own brand
# 1074    11-962    Dumplings, homemade                             Recipe
#
#      Group Previous                               Main data references  \
# 1043    AP  11-244   DH, Nutrient analysis of biscuits, buns, cakes...
# 1044    AP  11-242   DH, Nutrient analysis of biscuits, buns, cakes...
# 1074    AT  11-603                        As MW6. Recalculated in 2013
#
#      Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 1043      NaN        1751           420     25.7         14.14
# 1044      NaN        1377           328     13.1          4.96
# 1074      NaN         884           211     11.7          6.63
#
#      Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)  \
# ...

# %%
Red2 = pd.concat([Red,BR], axis=0, join='inner')
Red2
# Out:
#      Food Code                   Food Name  \
# 1043    11-850       Doughnuts, ring, iced
# 1044    11-849         Doughnuts, with jam
# 1074    11-962         Dumplings, homemade
# 1033    12-398  Desserts, dairy, chocolate
#
#                                             Description Group Previous  \
# 1043                  10 samples, branded and own brand    AP  11-244
# 1044                  10 samples, branded and own brand    AP  11-242
# 1074                                             Recipe    AT  11-603
# 1033  8 samples, 4 brands including milk chocolate a...    BR  12-912
#
#                                    Main data references Footnote Energy (kJ)  \
# 1043  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1751
# 1044  DH, Nutrient analysis of biscuits, buns, cakes...      NaN        1377
# 1074                       As MW6. Recalculated in 2013      NaN         884
# 1033  Reviewed 2013. LGC, Nutritional analysis of fo...      NaN         899
#
# ...

# %%
Red3 = pd.concat([Red2,Filt_FA], axis=0, join='inner')
Red3
# Out:
#      Food Code                     Food Name  \
# 1043    11-850         Doughnuts, ring, iced
# 1044    11-849           Doughnuts, with jam
# 1074    11-962           Dumplings, homemade
# 1033    12-398    Desserts, dairy, chocolate
# 1023    14-077  Damsons, flesh and skin, raw
# 1031    14-083    Dates, raw, flesh and skin
# 1053    14-087             Dried mixed fruit
#
#                                             Description Group Previous  \
# 1043                  10 samples, branded and own brand    AP  11-244
# 1044                  10 samples, branded and own brand    AP  11-242
# 1074                                             Recipe    AT  11-603
# 1033  8 samples, 4 brands including milk chocolate a...    BR  12-912
# 1023                                     Flesh and skin    FA      NaN
# 1031                                         5 samples;    FA      NaN
# 1053  Calculated as sultanas 49%, currants 24%, rais...    FA  50-888
#
# ...

# %%
Red4 = pd.concat([Red3,Filt_H], axis=0, join='inner')
Red4
# Out:
#      Food Code                     Food Name  \
# 1043    11-850         Doughnuts, ring, iced
# 1044    11-849           Doughnuts, with jam
# 1074    11-962           Dumplings, homemade
# 1033    12-398    Desserts, dairy, chocolate
# 1023    14-077  Damsons, flesh and skin, raw
# 1031    14-083    Dates, raw, flesh and skin
# 1053    14-087             Dried mixed fruit
# 1037    13-824                   Dill, fresh
#
#                                             Description Group Previous  \
# 1043                  10 samples, branded and own brand    AP  11-244
# 1044                  10 samples, branded and own brand    AP  11-242
# 1074                                             Recipe    AT  11-603
# 1033  8 samples, 4 brands including milk chocolate a...    BR  12-912
# 1023                                     Flesh and skin    FA      NaN
# 1031                                         5 samples;    FA      NaN
# ...

# %%
Red5 = pd.concat([Red4,Filt_MCC], axis=0, join='inner')
Red5
# Out:
#      Food Code                     Food Name  \
# 1043    11-850         Doughnuts, ring, iced
# 1044    11-849           Doughnuts, with jam
# 1074    11-962           Dumplings, homemade
# 1033    12-398    Desserts, dairy, chocolate
# 1023    14-077  Damsons, flesh and skin, raw
# 1031    14-083    Dates, raw, flesh and skin
# 1053    14-087             Dried mixed fruit
# 1037    13-824                   Dill, fresh
# 1068    18-489          Duck, meat only, raw
#
#                                             Description Group  \
# 1043                  10 samples, branded and own brand    AP
# 1044                  10 samples, branded and own brand    AP
# 1074                                             Recipe    AT
# 1033  8 samples, 4 brands including milk chocolate a...    BR
# 1023                                     Flesh and skin    FA
# 1031                                         5 samples;    FA
# 1053  Calculated as sultanas 49%, currants 24%, rais...    FA
# ...

# %%
Red6 = pd.concat([Red5,Filt_MR], axis=0, join='inner')
Red6
# Out:
#      Food Code                     Food Name  \
# 1043    11-850         Doughnuts, ring, iced
# 1044    11-849           Doughnuts, with jam
# 1074    11-962           Dumplings, homemade
# 1033    12-398    Desserts, dairy, chocolate
# 1023    14-077  Damsons, flesh and skin, raw
# 1031    14-083    Dates, raw, flesh and skin
# 1053    14-087             Dried mixed fruit
# 1037    13-824                   Dill, fresh
# 1068    18-489          Duck, meat only, raw
# 1041    19-539       Doner kebabs, meat only
#
#                                             Description Group  \
# 1043                  10 samples, branded and own brand    AP
# 1044                  10 samples, branded and own brand    AP
# 1074                                             Recipe    AT
# 1033  8 samples, 4 brands including milk chocolate a...    BR
# 1023                                     Flesh and skin    FA
# 1031                                         5 samples;    FA
# ...

# %%
Red7 = pd.concat([Red6,OF], axis=0, join='inner')
Red7
# Out:
#      Food Code                     Food Name  \
# 1043    11-850         Doughnuts, ring, iced
# 1044    11-849           Doughnuts, with jam
# 1074    11-962           Dumplings, homemade
# 1033    12-398    Desserts, dairy, chocolate
# 1023    14-077  Damsons, flesh and skin, raw
# 1031    14-083    Dates, raw, flesh and skin
# 1053    14-087             Dried mixed fruit
# 1037    13-824                   Dill, fresh
# 1068    18-489          Duck, meat only, raw
# 1041    19-539       Doner kebabs, meat only
# 1059    17-487                Dripping, beef
#
#                                             Description Group  \
# 1043                  10 samples, branded and own brand    AP
# 1044                  10 samples, branded and own brand    AP
# 1074                                             Recipe    AT
# 1033  8 samples, 4 brands including milk chocolate a...    BR
# 1023                                     Flesh and skin    FA
# ...

# %%
Red8 = pd.concat([Red7,Filt_PAA], axis=0, join='inner')
Red8
# Out:
#      Food Code                     Food Name  \
# 1043    11-850         Doughnuts, ring, iced
# 1044    11-849           Doughnuts, with jam
# 1074    11-962           Dumplings, homemade
# 1033    12-398    Desserts, dairy, chocolate
# 1023    14-077  Damsons, flesh and skin, raw
# 1031    14-083    Dates, raw, flesh and skin
# 1053    14-087             Dried mixed fruit
# 1037    13-824                   Dill, fresh
# 1068    18-489          Duck, meat only, raw
# 1041    19-539       Doner kebabs, meat only
# 1059    17-487                Dripping, beef
# 1057    17-498    Drinking chocolate, powder
#
#                                             Description Group  \
# 1043                  10 samples, branded and own brand    AP
# 1044                  10 samples, branded and own brand    AP
# 1074                                             Recipe    AT
# 1033  8 samples, 4 brands including milk chocolate a...    BR
# ...

# %%
Red9 = pd.concat([Red8,Filt_WCG], axis=0, join='inner')
Red9
# Out:
#      Food Code                     Food Name  \
# 1043    11-850         Doughnuts, ring, iced
# 1044    11-849           Doughnuts, with jam
# 1074    11-962           Dumplings, homemade
# 1033    12-398    Desserts, dairy, chocolate
# 1023    14-077  Damsons, flesh and skin, raw
# 1031    14-083    Dates, raw, flesh and skin
# 1053    14-087             Dried mixed fruit
# 1037    13-824                   Dill, fresh
# 1068    18-489          Duck, meat only, raw
# 1041    19-539       Doner kebabs, meat only
# 1059    17-487                Dripping, beef
# 1057    17-498    Drinking chocolate, powder
# 1046    17-715         Dressing, blue cheese
# 1047    17-701              Dressing, French
# 1051    17-717     Dressing, thousand island
#
#                                             Description Group  \
# 1043                  10 samples, branded and own brand    AP
# 1044                  10 samples, branded and own brand    AP
# ...

# %% [markdown]
#                                                        Export

# %%
Red9.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced_D.csv')
