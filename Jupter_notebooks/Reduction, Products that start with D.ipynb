# %% [markdown]
# # Product Weighting Project

# %% [markdown]
#                                          Data Reduction - Food Purchased In Store

# %% [markdown]
# ###### Import Necessary Libraries

# %%
import pandas as pd

# %% [markdown]
# Read in Data

# %%
Labelled = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Labelling2021_watercress.csv')

# %% [markdown]
# ### Products beginning with a 'D'

# %%
Prod_D = Labelled.loc[Labelled['Food Name'].str.startswith('D')]
Prod_D.head()
# Out:
#      Food Code                                          Food Name  \
# 1020    16-038                                           Dab, raw
# 1021    13-484                              Dahl, mixed, homemade
# 1022    15-511                              Dal Dhokari, homemade
# 1023    14-077                       Damsons, flesh and skin, raw
# 1024    14-078  Damsons, flesh and skin, raw, weighed with stones
#
#                                             Description Group Previous  \
# 1020                                 Literature sources    JA      NaN
# 1021                 5 samples, mixed lentils in spices    DB      NaN
# 1022  Recipe. Gujerati dish. Pastry shapes in pigeon...    DR  15-159
# 1023                                     Flesh and skin    FA      NaN
# 1024                             Calculated from 14-077    FA  50-884
#
#                                    Main data references Footnote Energy (kJ)  \
# ...

# %% [markdown]
# Products within a Group (provide identification of the food group and food type to which the food belongs)

# %%
Prod_D.groupby('Group')['Food Name'].count()
# Out:
# Group
# AP      2
# AT      1
# BR      1
# DB      1
# DG      4
# DR      2
# FA     12
# H       3
# JA      2
# MCC     7
# MR      6
# OF      1
# PAA     5
# WC      3
# WCG     6
# Name: Food Name, dtype: int64

# %% [markdown]
# ## *Reducing products based on its most basic form. Improve as you go on*

# %% [markdown]
#                                               Cereals and cereal products

# %% [markdown]
# Flours, grains and starches

# %%
AP = Prod_D.loc[Prod_D['Group']== 'AP']
AP
# Out:
#      Food Code              Food Name                        Description  \
# 1043    11-850  Doughnuts, ring, iced  10 samples, branded and own brand
# 1044    11-849    Doughnuts, with jam  10 samples, branded and own brand
#
#      Group Previous                               Main data references  \
# 1043    AP  11-244   DH, Nutrient analysis of biscuits, buns, cakes...
# 1044    AP  11-242   DH, Nutrient analysis of biscuits, buns, cakes...
#
#      Footnote Energy (kJ) Energy (kcal)  Fat (g) Saturates (g)  \
# 1043      NaN        1751           420     25.7         14.14
# 1044      NaN        1377           328     13.1          4.96
#
#      Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1043             39.4       15.5       23.8       2.7          6.4     0.82
# 1044             45.8       20.1       25.6       1.7          5.9     1.01

# %%
AA['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8040\2826330813.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AA['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
# Savouries

# %%
AT = Prod_D.loc[Prod_D['Group']== 'AT']
AT
# Out:
#      Food Code            Food Name Description Group Previous  \
# 1074    11-962  Dumplings, homemade      Recipe    AT  11-603
#
#               Main data references Footnote Energy (kJ) Energy (kcal)  \
# 1074  As MW6. Recalculated in 2013      NaN         884           211
#
#       Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1074     11.7          6.63               23        0.1       22.9       1.2
#
#       Protein (g) Salt (g)
# 1074          2.9     0.35

# %%
Filt_AT['Super Group'] = 'Cereals and cereal products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8040\2561790092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_AT['Super Group'] = 'Cereals and cereal products'

# %% [markdown]
#                                                   Milk and milk products

# %% [markdown]
# Puddings and chilled desserts

# %%
BR = Prod_D.loc[Prod_D['Group']== 'BR']
BR
# Out:
#      Food Code                   Food Name  \
# 1033    12-398  Desserts, dairy, chocolate
#
#                                             Description Group Previous  \
# 1033  8 samples, 4 brands including milk chocolate a...    BR  12-912
#
#                                    Main data references Footnote Energy (kJ)  \
# 1033  Reviewed 2013. LGC, Nutritional analysis of fo...      NaN         899
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1033           215     10.7          6.26             25.3       22.9
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1033        2.5         0          4.3     0.19

# %%
BR['Food Name'].unique()
# Out:
# array(['Desserts, dairy, chocolate'], dtype=object)

# %%
Filt_BR['Super Group'] = 'Milk and milk products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8040\3725017385.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_BR['Super Group'] = 'Milk and milk products'

# %% [markdown]
#                                                        Vegetables

# %% [markdown]
# Vegetables, general

# %%
DG = Prod_D.loc[Prod_D['Group']== 'DG']
DG
# Out:
#      Food Code                                   Food Name  \
# 1060    13-237  Drumstick leaves, boiled in unsalted water
# 1061    13-236                       Drumstick leaves, raw
# 1062    13-239    Drumstick pods, boiled in unsalted water
# 1063    13-238                         Drumstick pods, raw
#
#              Description Group Previous  \
# 1060  Literature sources    DG      NaN
# 1061  Literature sources    DG      NaN
# 1062  Literature sources    DG      NaN
# 1063  Literature sources    DG      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1060  Wu Leung et al. (1972) Food composition table ...      NaN         361
# 1061  Wu Leung et al. (1972) Food composition table ...      NaN         363
# 1062  Haytowitz and Matthews (1984) Composition of f...      NaN         170
# 1063  Haytowitz and Matthews (1984) Composition of f...      NaN         181
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_DG = ['Cabbage, average, raw', 'Cabbage, Chinese, raw','Cabbage, green, raw','Cabbage, red, raw','Cabbage, white, raw',
              'Carrots, old, raw','Carrots, young, raw','Cauliflower, raw','Celeriac, raw','Celery, raw','Chard, Swiss, raw',
              'Chicory, pale variety, raw','Courgette, raw','Curly kale, raw']

# %%
Filt_DG = DG[DG['Food Name'].isin(Priority_DG)]
Filt_DG
# Out:
#     Food Code                   Food Name  \
# 487    13-582       Cabbage, average, raw
# 488    13-187       Cabbage, Chinese, raw
# 490    13-510         Cabbage, green, raw
# 493    13-190           Cabbage, red, raw
# 495    13-509         Cabbage, white, raw
# 537    13-496           Carrots, old, raw
# 540    13-448         Carrots, young, raw
# 570    13-512            Cauliflower, raw
# 573    13-219               Celeriac, raw
# 576    13-636                 Celery, raw
# 582    13-223           Chard, Swiss, raw
# 732    13-225  Chicory, pale variety, raw
# 860    13-627              Courgette, raw
# 906    13-234             Curly kale, raw
#
#                                            Description Group        Previous  \
# 487  Average of white (13-509) and green (13-510) c...    DG         13-468
# 488                 Base trimmed, outer leaves removed    DG             NaN
# 490  22 samples, autumn and winter, UK grown and im...    DG         13-468
# ...

# %%
Filt_DG['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8040\1311392366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DG['Super Group'] = 'Vegetables'

# %% [markdown]
# Vegetable Dishes

# %%
DR = Prod_D.loc[Prod_D['Group']== 'DR']
DR
# Out:
#      Food Code                           Food Name  \
# 1022    15-511               Dal Dhokari, homemade
# 1042    15-513  Dosa, filling, vegetable, homemade
#
#                                             Description Group Previous  \
# 1022  Recipe. Gujerati dish. Pastry shapes in pigeon...    DR  15-159
# 1042                 Recipe. Filling for Dosa pancakes.    DR  15-161
#
#                    Main data references Footnote Energy (kJ) Energy (kcal)  \
# 1022                                NaN      NaN           N             N
# 1042  Recipe as Vegetable Dishes 15-161      NaN         437           105
#
#       Fat (g) Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1022      3.3          0.51             17.3          1         16         N
# 1042      6.3          0.74              9.4        3.9        4.7       1.5
#
#       Protein (g) Salt (g)
# 1022          5.8     0.86
# 1042          1.9     1.12

# %% [markdown]
# **Reduced**

# %%
Priority_DR = ['Casserole, vegetable, homemade','Cauliflower cheese, retail','Chilli, bean and lentil, homemade','Coleslaw, not low calorie, retail',
               'Curry, chick pea, UK type, homemade','Curry, egg, in sweet sauce, UK type, homemade', 'Curry, red kidney bean, Punjabi, homemade']

# %%
Filt_DR = DR[DR['Food Name'].isin(Priority_DR)]
Filt_DR
# Out:
#     Food Code                                      Food Name  \
# 557    15-638                 Casserole, vegetable, homemade
# 564    15-637                     Cauliflower cheese, retail
# 738    15-719              Chilli, bean and lentil, homemade
# 822    15-635              Coleslaw, not low calorie, retail
# 932    15-748            Curry, chick pea, UK type, homemade
# 953    15-752  Curry, egg, in sweet sauce, UK type, homemade
# 999    15-146      Curry, red kidney bean, Punjabi, homemade
#
#                                            Description Group Previous  \
# 557                 Recipe from dietary survey records    DR  15-368
# 564                           Recipe and industry data    DR      NaN
# 738                                             Recipe    DR  15-439
# 822                              8 samples, 7 products    DR      NaN
# 932                                             Recipe    DR  15-464
# ...

# %%
Filt_DR['Super Group'] = 'Vegetables'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8040\2508077319.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_DR['Super Group'] = 'Vegetables'

# %% [markdown]
#                                                         Fruit

# %% [markdown]
# Fruit General

# %%
FA = Prod_D.loc[Prod_D['Group']== 'FA']
FA
# Out:
#      Food Code                                          Food Name  \
# 1023    14-077                       Damsons, flesh and skin, raw
# 1024    14-078  Damsons, flesh and skin, raw, weighed with stones
# 1025    14-079                         Damsons, stewed with sugar
# 1026    14-080    Damsons, stewed with sugar, weighed with stones
# 1027    14-081                      Damsons, stewed without sugar
# 1028    14-082  Damsons, stewed without sugar, weighed with st...
# 1029    14-394                       Dates, dried, flesh and skin
# 1030    14-399  Dates, dried, flesh and skin, weighed with stones
# 1031    14-083                         Dates, raw, flesh and skin
# 1032    14-084    Dates, raw, flesh and skin, weighed with stones
# 1053    14-087                                  Dried mixed fruit
# 1075    14-088                                 Durian, flesh only
#
#                                             Description Group Previous  \
# ...

# %% [markdown]
# ##### Reduced

# %%
Priority_FA = ['Cherries, flesh and skin, raw','Citrus fruit, soft/easy peelers, flesh only','Cranberries', 'Currants',]

# %%
Filt_FA = FA[FA['Food Name'].isin(Priority_FA)]
Filt_FA
# Out:
#     Food Code                                    Food Name  \
# 642    14-382                Cherries, flesh and skin, raw
# 772    14-326  Citrus fruit, soft/easy peelers, flesh only
# 871    14-073                                  Cranberries
# 909    14-074                                     Currants
#
#                                            Description Group Previous  \
# 642                        11 samples, UK and imported    FA   14-061
# 772  22 samples, early and late winter, including c...    FA      NaN
# 871       Analysis and literature sources; whole fruit    FA      NaN
# 909                               10 samples, 9 brands    FA  50-883
#
#                                   Main data references Footnote Energy (kJ)  \
# 642  PHE, Nutrient analysis of fresh and processed ...      NaN         310
# 772  DH, Nutrient analysis of fruit and vegetables,...      NaN         206
# 871                    Fruit and Nuts Supplement, 1992      NaN         122
# ...

# %%
Filt_FA['Super Group'] = 'Fruit'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8040\3797725470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_FA['Super Group'] = 'Fruit'

# %% [markdown]
#                                                    Herbs and Spices

# %%
H = Prod_D.loc[Prod_D['Group']== 'H']
H
# Out:
#      Food Code    Food Name                       Description Group Previous  \
# 1035    13-826   Dill seeds                Literature sources     H      NaN
# 1036    13-825  Dill, dried                Literature sources     H      NaN
# 1037    13-824  Dill, fresh  6 samples and literature sources     H      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1035  Marsh et al. (1977) Composition of foods: spic...      NaN        1557
# 1036      Vegetables, Herbs and Spices Supplement, 1991      NaN        1309
# 1037      Vegetables, Herbs and Spices Supplement, 1991      NaN         127
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1035           373     14.5           0.7             34.1       30.4
# 1036           311      4.4          0.23             41.1       36.9
# 1037            30      0.8          0.06              0.9        0.8
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_H = ['Caraway seeds', 'Cardamom, ground', 'Celery seeds',
       'Chervil, dried', 'Chilli powder', 'Chinese 5 spice',
       'Chives, fresh', 'Cinnamon, ground', 'Cloves, dried',
       'Coriander leaves, dried','Cumin seeds','Curry powder']

# %%
Filt_H = H[H['Food Name'].isin(Priority_H)]
Filt_H
# Out:
#     Food Code                Food Name             Description Group Previous  \
# 530    13-808            Caraway seeds      Literature sources     H      NaN
# 532    13-809         Cardamom, ground      Literature sources     H      NaN
# 574    13-810             Celery seeds      Literature sources     H      NaN
# 650    13-811           Chervil, dried      Literature sources     H      NaN
# 736    13-873            Chilli powder      Literature sources     H  13-812
# 741    13-813          Chinese 5 spice  Calculated from recipe     H      NaN
# 743    13-887            Chives, fresh      Literature sources     H  13-814
# 771    13-874         Cinnamon, ground      Literature sources     H  13-815
# 774    13-816            Cloves, dried      Literature sources     H      NaN
# 841    13-818  Coriander leaves, dried      Literature sources     H      NaN
# 904    13-889              Cumin seeds      Literature sources     H  13-820
# ...

# %%
Filt_H['Super Group'] = 'Herbs and Spices'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8040\854041242.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_H['Super Group'] = 'Herbs and Spices'

# %% [markdown]
#                                                    Fish and Fish Products

# %% [markdown]
# White Fish

# %%
JA = Prod_D.loc[Prod_D['Group']== 'JA']
JA
# Out:
#      Food Code        Food Name         Description Group Previous  \
# 1020    16-038         Dab, raw  Literature sources    JA      NaN
# 1045    16-039  Dover sole, raw  Literature sources    JA      NaN
#
#                                    Main data references Footnote Energy (kJ)  \
# 1020  Souci-Fachman-Kraut (1989) Food composition an...      NaN         311
# 1045  Souci-Fachman-Kraut (1989) Food composition an...      NaN         375
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1020            74      1.2          0.16                0          0
# 1045            89      1.8          0.33                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1020          0         0         15.7     0.19
# 1045          0         0         18.1     0.25

# %%
JA['Food Name'].unique()
# Out:
# array(['Carp, raw', 'Catfish, flesh only, steamed',
#        'Catfish, flesh only, steamed, weighed with bones', 'Catfish, raw',
#        'Chital, raw', 'Cod, dried, salted, boiled',
#        'Cod, flesh only, baked',
#        'Cod, flesh only, baked, weighed with bones and skin',
#        'Cod, flesh only, grilled', 'Cod, flesh only, microwaved',
#        'Cod, flesh only, poached in milk, butter and salt added',
#        'Cod, flesh only, poached in milk, butter and salt added, weighed with bones and skin',
#        'Cod, flesh only, raw', 'Cod, flesh only, salted and smoked, raw',
#        'Cod, flesh only, steamed',
#        'Cod, flesh only, steamed, weighed with bones and skin',
#        'Cod, in batter, baked',
#        'Cod, in batter, fried in dripping, takeaway',
#        'Cod, in batter, fried in rapeseed oil',
#        'Cod, in batter, fried, takeaway', 'Cod, in breadcrumbs, baked',
#        'Coley, flesh only, baked', 'Coley, flesh only, grilled',
# ...

# %% [markdown]
# **Reduced**

# %%
Priortiy_JA = ['Carp, raw','Catfish, raw','Chital, raw', 'Cod, flesh only, baked', 'Coley, flesh only, baked']

# %%
Filt_JA = JA[JA['Food Name'].isin(Priortiy_JA)]
Filt_JA
# Out:
#     Food Code                 Food Name  \
# 533    16-172                 Carp, raw
# 560    16-007              Catfish, raw
# 742    16-011               Chital, raw
# 789    16-373    Cod, flesh only, baked
# 824    16-429  Coley, flesh only, baked
#
#                                            Description Group Previous  \
# 533                                 Literature sources    JA      NaN
# 560                                 Literature sources    JA      NaN
# 742  Literature sources. Imported frozen from Bangl...    JA      NaN
# 789        11 samples, 11 products, frozen and chilled    JA  16-013
# 824     Calculated from 16-383 using 26.1% weight loss    JA      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 533            Fish and Fish Products Supplement, 1993      NaN         471
# 560            Fish and Fish Products Supplement, 1993      NaN         403
# ...

# %%
Filt_JA['Super Group'] = 'Fish and Fish Products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8040\2823660487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_JA['Super Group'] = 'Fish and Fish Products'

# %% [markdown]
#                                                   Meat and meat products

# %% [markdown]
# Duck

# %%
MCC = Prod_D.loc[Prod_D['Group']== 'MCC']
MCC
# Out:
#      Food Code                                          Food Name  \
# 1067    18-490         Duck, crispy, chinese style, meat and skin
# 1068    18-489                               Duck, meat only, raw
# 1069    18-495  Duck, raw, meat only, weighed with fat, skin a...
# 1070    18-371                      Duck, raw, meat, fat and skin
# 1071    18-372                           Duck, roasted, meat only
# 1072    18-373  Duck, roasted, meat only, weighed with fat, sk...
# 1073    18-374                  Duck, roasted, meat, fat and skin
#
#                                             Description Group  \
# 1067  10 samples from chinese takeaways, seasoned ro...   MCC
# 1068              19 samples, meat from dressed carcase   MCC
# 1069                             Calculated from 18-489   MCC
# 1070  10 samples; meat, fat and skin = 0.57 of dress...   MCC
# 1071                    10 samples from dressed carcase   MCC
# 1072                             Calculated from 18-372   MCC
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_MCC = ['Chicken, meat, average, raw','Chicken, whole, raw, meat and skin','Chicken, wing quarter, raw, meat and skin','Chicken breast/steak, coated, baked','Chicken pieces, coated, takeaway','Chicken, corn-fed, raw, meat only''Chicken, drumsticks, roasted, meat and skin', 'Chicken, leg quarter, raw, meat and skin', 'Chicken/turkey pieces, coated, baked']

# %%
Filt_MCC = MCA[MCA['Food Name'].isin(Priority_MCA)]
Filt_MCC
# Out:
#     Food Code                                  Food Name  \
# 655    18-504        Chicken breast/steak, coated, baked
# 662    18-501           Chicken pieces, coated, takeaway
# 694    18-293   Chicken, leg quarter, raw, meat and skin
# 700    18-488                Chicken, meat, average, raw
# 718    18-297         Chicken, whole, raw, meat and skin
# 725    18-295  Chicken, wing quarter, raw, meat and skin
# 730    18-503       Chicken/turkey pieces, coated, baked
#
#                                            Description Group        Previous  \
# 655        8 samples, 7 products, breaded and battered   MCA         19-119
# 662  8 samples, 7 products, including chicken nugge...   MCA         19-124
# 694         Calculated from 77% dark meat and 23% skin   MCA             NaN
# 700   Calculated from 44% light meat and 56% dark meat   MCA  18-291 50-431
# 718  Calculated from 33% light meat, 42% dark meat ...   MCA             NaN
# ...

# %%
Filt_MCC['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8040\3262525810.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_MCA['Super Group'] = 'Meat and meat products'

# %% [markdown]
# Meat dishes

# %%
MR = Prod_D.loc[Prod_D['Group']== 'MR']
MR
# Out:
#      Food Code                                          Food Name  \
# 1034    19-576                         Devilled kidneys, homemade
# 1040    19-526              Doner kebab in pitta bread with salad
# 1041    19-539                            Doner kebabs, meat only
# 1064    19-578  Duck a l'orange, excluding fat and skin, homemade
# 1065    19-579  Duck a l'orange, including fat and skin, homemade
# 1066    19-580                      Duck with pineapple, homemade
#
#                                             Description Group Previous  \
# 1034                                             Recipe    MR  19-392
# 1040  Calculated from 50% doner kebab (19-129), 22% ...    MR  19-130
# 1041                 20 samples from assorted takeaways    MR  19-129
# 1064                                             Recipe    MR  19-393
# 1065                                             Recipe    MR  19-394
# 1066                                             Recipe    MR  19-396
#
# ...

# %% [markdown]
# **Reduced**

# %%
Priority_MR = ['Casserole, sausage, homemade','Chow mein, chicken, takeaway','Cornish pasty, retail','Coronation chicken, homemade']

# %%
Filt_MR = MR[MR['Food Name'].isin(Priority_MR)]
Filt_MR
# Out:
#     Food Code                     Food Name              Description Group  \
# 555    19-484  Casserole, sausage, homemade                   Recipe    MR
# 761    19-321  Chow mein, chicken, takeaway               10 samples    MR
# 851    19-466         Cornish pasty, retail  11 samples, 10 products    MR
# 853    19-477  Coronation chicken, homemade                   Recipe    MR
#
#     Previous                               Main data references Footnote  \
# 555  19-351                                        Updated 2013      NaN
# 761      NaN  Reviewed 2013. Aspland and James Ltd, Nutrient...      NaN
# 851  19-316   DH, Nutrient analysis of a range of processed ...      NaN
# 853  19-339                                        Updated 2013      NaN
#
#     Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 555         702           169     10.9          3.65              4.9
# 761         621           148      7.2          1.17             11.7
# ...

# %%
Filt_MR['Super Group'] = 'Meat and meat products'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8040\3346374556.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_MR['Super Group'] = 'Meat and meat products'

# %% [markdown]
#                                                    Fats and Oils

# %% [markdown]
# Cooking fats

# %%
OF = Prod_D.loc[Prod_D['Group']== 'OF']
OF
# Out:
#      Food Code       Food Name                  Description Group  \
# 1059    17-487  Dripping, beef  5 samples, different brands    OF
#
#                     Previous  \
# 1059  17-006 17-472 50-317
#
#                                    Main data references Footnote Energy (kJ)  \
# 1059  Reviewed 2013. MW1, 1940 with fatty acids from...      NaN        3663
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 1059           891     99.0         50.62                0          0
#
#      Starch (g) Fibre (g)  Protein (g) Salt (g)
# 1059          0         0          0.0     0.01

# %%
OF['Super Group'] = 'Fats and Oils'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8040\660970776.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   OE['Super Group'] = 'Fats and Oils'

# %% [markdown]
#                                                         Beverages

# %% [markdown]
# Powdered drinks and essences

# %%
PAA = Prod_D.loc[Prod_D['Group']== 'PAA']
PAA
# Out:
#      Food Code                                          Food Name  \
# 1054    17-790  Drinking chocolate powder, made up with semi-s...
# 1055    17-791  Drinking chocolate powder, made up with skimme...
# 1056    17-792  Drinking chocolate powder, made up with whole ...
# 1057    17-498                         Drinking chocolate, powder
# 1058    17-499            Drinking chocolate, powder, reduced fat
#
#                                             Description Group  \
# 1054           Calculated from 18g powder to 200ml milk   PAA
# 1055  Recipe. Made up according to packet directions...   PAA
# 1056           Calculated from 18g powder to 200ml milk   PAA
# 1057                                  10 tins, 3 brands   PAA
# 1058                               10 samples, 4 brands   PAA
#
#                      Previous  \
# 1054                  17-532
# 1055                  17-559
# 1056                  17-533
# 1057  12-093 12-883 50-1064
# 1058                      NaN
#
# ...

# %%
P['Super Group'] = 'Beverages'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8040\3697906943.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   P['Super Group'] = 'Beverages'

# %% [markdown]
#                                         Soups, sauces and miscellaneous foods

# %% [markdown]
# Sauces

# %%
WC = Prod_D.loc[Prod_D['Group']== 'WC']
WC
# Out:
#      Food Code                          Food Name Description Group Previous  \
# 1049    17-787         Dressing, French, homemade      Recipe    WC  17-579
# 1050    17-788  Dressing, oil and lemon, homemade      Recipe    WC  17-611
# 1052    17-789         Dressing, yogurt, homemade      Recipe    WC  17-612
#
#      Main data references Footnote Energy (kJ) Energy (kcal)  Fat (g)  \
# 1049         Updated 2014      NaN        2777           675     74.9
# 1050         Updated 2014      NaN        2737           665     72.4
# 1052         Updated 2014      NaN         259            62      2.7
#
#      Saturates (g) Carbohydrate (g) Sugars (g) Starch (g) Fibre (g)  \
# 1049         10.73              0.2        0.2          0         0
# 1050          4.79              3.3        3.3          0       0.1
# 1052          1.73              4.1        4.1          0       0.1
#
#       Protein (g) Salt (g)
# 1049          0.1        0
# 1050          0.1        0
# ...

# %%
Filt_WC = WC[WC['Food Name'] == 'Chilli sauce']
Filt_WC
# Out:
#     Food Code     Food Name  \
# 737    17-719  Chilli sauce
#
#                                            Description Group Previous  \
# 737  8 samples; assorted types, including garlic ch...    WC  17-294
#
#                                   Main data references Footnote Energy (kJ)  \
# 737  LFRA, Nutrient analysis of miscellaneous foods...      NaN         193
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 737            46      0.8             0              7.3        6.9
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 737        0.4       2.2          1.3     3.13

# %%
Filt_WC['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8040\3218677465.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_WC['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
# Salad sauces, dressings and pickles

# %%
WCG = Prod_D.loc[Prod_D['Group']== 'WCG']
WCG
# Out:
#      Food Code                                  Food Name  \
# 1038    17-299  Dips, sour-cream based, assorted flavours
# 1039    17-677        Dips, sour-cream based, reduced fat
# 1046    17-715                      Dressing, blue cheese
# 1047    17-701                           Dressing, French
# 1048    17-716                 Dressing, French, fat free
# 1051    17-717                  Dressing, thousand island
#
#                       Description Group Previous  \
# 1038         7 samples, 4 brands;   WCG      NaN
# 1039                   Label data   WCG      NaN
# 1046          7 samples, 2 brands   WCG  17-300
# 1047          8 samples, 6 brands   WCG  17-509
# 1048  Manufacturer's data (Kraft)   WCG  17-538
# 1051          7 samples, 4 brands   WCG  17-306
#
#                                    Main data references Footnote Energy (kJ)  \
# 1038  Reviewed 2013. RHM Technology, Nutrient analys...      NaN           N
# ...

# %% [markdown]
# **Reduced**

# %%
Remove_WCG = ['Chutney, apple, homemade']

# %%
Filt_WCG = WCG[~WCG['Food Name'].isin(Remove_WCG)]
Filt_WCG
# Out:
#     Food Code        Food Name          Description Group Previous  \
# 765    17-345  Chutney, tomato  9 samples, 5 brands   WCG      NaN
#
#                                   Main data references Footnote Energy (kJ)  \
# 765  Reviewed 2013. LFRA, Nutrient analysis of misc...      NaN         561
#
#     Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 765           132      0.2             0             30.7       28.1
#
#     Starch (g) Fibre (g)  Protein (g) Salt (g)
# 765        2.6       1.4          1.2     1.03

# %%
Filt_WCG['Super Group'] = 'Soups, sauces and miscellaneous foods'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_8040\2275349619.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Filt_WCG['Super Group'] = 'Soups, sauces and miscellaneous foods'

# %% [markdown]
#                                               **Join Reduced Tables**

# %%
Red = pd.concat([AA,Filt_AF], axis=0, join='inner')
Red
# Out:
#      Food Code                        Food Name  \
# 852     11-011                 Cornmeal, sifted
# 1012   11-1138                   Custard powder
# 579     11-987  Chapatis, made with fat, retail
#
#                                             Description Group Previous  \
# 852                   Analytical and literature sources    AA      NaN
# 1012  Taken as cornflour (11-1045) except Na, Cl and Cu    AA      NaN
# 579                                           6 samples    AF  11-458
#
#                                    Main data references Footnote Energy (kJ)  \
# 852   Wu Leung et al. (1968) Food composition table ...      NaN        1586
# 1012  LGC, Nutrient survey of flours and grains, 200...      NaN        1457
# 579   MW4, 1978; and industry data, 2013. Selenium f...      NaN        1390
#
#      Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g) Sugars (g)  \
# 852            375      3.3          0.41             74.9        1.6
# ...

# %%
Red2 = pd.concat([Red,AG], axis=0, join='inner')
Red2
# Out:
#      Food Code                        Food Name  \
# 852     11-011                 Cornmeal, sifted
# 1012   11-1138                   Custard powder
# 579     11-987  Chapatis, made with fat, retail
# 892     11-988                       Croissants
#
#                                             Description Group Previous  \
# 852                   Analytical and literature sources    AA      NaN
# 1012  Taken as cornflour (11-1045) except Na, Cl and Cu    AA      NaN
# 579                                           6 samples    AF  11-458
# 892                                10 samples, 7 brands    AG  11-480
#
#                                    Main data references Footnote Energy (kJ)  \
# 852   Wu Leung et al. (1968) Food composition table ...      NaN        1586
# 1012  LGC, Nutrient survey of flours and grains, 200...      NaN        1457
# 579   MW4, 1978; and industry data, 2013. Selenium f...      NaN        1390
# ...

# %%
Red3 = pd.concat([Red2,Filt_AM], axis=0, join='inner')
Red3
# Out:
#      Food Code                                          Food Name  \
# 852     11-011                                   Cornmeal, sifted
# 1012   11-1138                                     Custard powder
# 579     11-987                    Chapatis, made with fat, retail
# 892     11-988                                         Croissants
# 497     11-916                                         Cake rusks
# 577     11-819  Cereal bars, with fruit and/or nuts, no chocol...
# 593     11-824                       Cheese straws/twists, retail
# 874     11-820                                     Cream crackers
# 891     11-822                                    Crispbread, rye
#
#                                             Description Group        Previous  \
# 852                   Analytical and literature sources    AA             NaN
# 1012  Taken as cornflour (11-1045) except Na, Cl and Cu    AA             NaN
# ...

# %%
Red4 = pd.concat([Red3,Filt_AN], axis=0, join='inner')
Red4
# Out:
#      Food Code                                          Food Name  \
# 852     11-011                                   Cornmeal, sifted
# 1012   11-1138                                     Custard powder
# 579     11-987                    Chapatis, made with fat, retail
# 892     11-988                                         Croissants
# 497     11-916                                         Cake rusks
# 577     11-819  Cereal bars, with fruit and/or nuts, no chocol...
# 593     11-824                       Cheese straws/twists, retail
# 874     11-820                                     Cream crackers
# 891     11-822                                    Crispbread, rye
# 515     11-832                    Cake, sponge, soft iced, retail
# 521     11-840                 Cakes from 'healthy eating' ranges
# 523     11-839              Cakes, fancy iced, individual, retail
#
#                                             Description Group        Previous  \
# ...

# %%
Red5 = pd.concat([Red4,Filt_AP], axis=0, join='inner')
Red5
# Out:
#      Food Code                                          Food Name  \
# 852     11-011                                   Cornmeal, sifted
# 1012   11-1138                                     Custard powder
# 579     11-987                    Chapatis, made with fat, retail
# 892     11-988                                         Croissants
# 497     11-916                                         Cake rusks
# 577     11-819  Cereal bars, with fruit and/or nuts, no chocol...
# 593     11-824                       Cheese straws/twists, retail
# 874     11-820                                     Cream crackers
# 891     11-822                                    Crispbread, rye
# 515     11-832                    Cake, sponge, soft iced, retail
# 521     11-840                 Cakes from 'healthy eating' ranges
# 523     11-839              Cakes, fancy iced, individual, retail
# 902     11-989                                  Crumpets, toasted
#
# ...

# %%
Red6 = pd.concat([Red5,Filt_AS], axis=0, join='inner')
Red6
# Out:
#      Food Code                                          Food Name  \
# 852     11-011                                   Cornmeal, sifted
# 1012   11-1138                                     Custard powder
# 579     11-987                    Chapatis, made with fat, retail
# 892     11-988                                         Croissants
# 497     11-916                                         Cake rusks
# 577     11-819  Cereal bars, with fruit and/or nuts, no chocol...
# 593     11-824                       Cheese straws/twists, retail
# 874     11-820                                     Cream crackers
# 891     11-822                                    Crispbread, rye
# 515     11-832                    Cake, sponge, soft iced, retail
# 521     11-840                 Cakes from 'healthy eating' ranges
# 523     11-839              Cakes, fancy iced, individual, retail
# 902     11-989                                  Crumpets, toasted
# ...

# %%
Red7 = pd.concat([Red6,Filt_AT], axis=0, join='inner')
Red7
# Out:
#      Food Code                                          Food Name  \
# 852     11-011                                   Cornmeal, sifted
# 1012   11-1138                                     Custard powder
# 579     11-987                    Chapatis, made with fat, retail
# 892     11-988                                         Croissants
# 497     11-916                                         Cake rusks
# 577     11-819  Cereal bars, with fruit and/or nuts, no chocol...
# 593     11-824                       Cheese straws/twists, retail
# 874     11-820                                     Cream crackers
# 891     11-822                                    Crispbread, rye
# 515     11-832                    Cake, sponge, soft iced, retail
# 521     11-840                 Cakes from 'healthy eating' ranges
# 523     11-839              Cakes, fancy iced, individual, retail
# 902     11-989                                  Crumpets, toasted
# ...

# %%
Red8 = pd.concat([Red7,Filt_BH], axis=0, join='inner')
Red8
# Out:
#      Food Code                                          Food Name  \
# 852     11-011                                   Cornmeal, sifted
# 1012   11-1138                                     Custard powder
# 579     11-987                    Chapatis, made with fat, retail
# 892     11-988                                         Croissants
# 497     11-916                                         Cake rusks
# 577     11-819  Cereal bars, with fruit and/or nuts, no chocol...
# 593     11-824                       Cheese straws/twists, retail
# 874     11-820                                     Cream crackers
# 891     11-822                                    Crispbread, rye
# 515     11-832                    Cake, sponge, soft iced, retail
# 521     11-840                 Cakes from 'healthy eating' ranges
# 523     11-839              Cakes, fancy iced, individual, retail
# 902     11-989                                  Crumpets, toasted
# ...

# %%
Red9 = pd.concat([Red8,Filt_BJC], axis=0, join='inner')
Red9
# Out:
#      Food Code                                          Food Name  \
# 852     11-011                                   Cornmeal, sifted
# 1012   11-1138                                     Custard powder
# 579     11-987                    Chapatis, made with fat, retail
# 892     11-988                                         Croissants
# 497     11-916                                         Cake rusks
# 577     11-819  Cereal bars, with fruit and/or nuts, no chocol...
# 593     11-824                       Cheese straws/twists, retail
# 874     11-820                                     Cream crackers
# 891     11-822                                    Crispbread, rye
# 515     11-832                    Cake, sponge, soft iced, retail
# 521     11-840                 Cakes from 'healthy eating' ranges
# 523     11-839              Cakes, fancy iced, individual, retail
# 902     11-989                                  Crumpets, toasted
# ...

# %%
Red10 = pd.concat([Red9,Filt_BJP], axis=0, join='inner')
Red10
# Out:
#      Food Code                                          Food Name  \
# 852     11-011                                   Cornmeal, sifted
# 1012   11-1138                                     Custard powder
# 579     11-987                    Chapatis, made with fat, retail
# 892     11-988                                         Croissants
# 497     11-916                                         Cake rusks
# 577     11-819  Cereal bars, with fruit and/or nuts, no chocol...
# 593     11-824                       Cheese straws/twists, retail
# 874     11-820                                     Cream crackers
# 891     11-822                                    Crispbread, rye
# 515     11-832                    Cake, sponge, soft iced, retail
# 521     11-840                 Cakes from 'healthy eating' ranges
# 523     11-839              Cakes, fancy iced, individual, retail
# 902     11-989                                  Crumpets, toasted
# ...

# %%
Red11 = pd.concat([Red10,Filt_BL], axis=0, join='inner')
Red11
# Out:
#      Food Code                                          Food Name  \
# 852     11-011                                   Cornmeal, sifted
# 1012   11-1138                                     Custard powder
# 579     11-987                    Chapatis, made with fat, retail
# 892     11-988                                         Croissants
# 497     11-916                                         Cake rusks
# 577     11-819  Cereal bars, with fruit and/or nuts, no chocol...
# 593     11-824                       Cheese straws/twists, retail
# 874     11-820                                     Cream crackers
# 891     11-822                                    Crispbread, rye
# 515     11-832                    Cake, sponge, soft iced, retail
# 521     11-840                 Cakes from 'healthy eating' ranges
# 523     11-839              Cakes, fancy iced, individual, retail
# 902     11-989                                  Crumpets, toasted
# ...

# %%
Red12 = pd.concat([Red11,Filt_BP], axis=0, join='inner')
Red12
# Out:
#      Food Code                                          Food Name  \
# 852     11-011                                   Cornmeal, sifted
# 1012   11-1138                                     Custard powder
# 579     11-987                    Chapatis, made with fat, retail
# 892     11-988                                         Croissants
# 497     11-916                                         Cake rusks
# 577     11-819  Cereal bars, with fruit and/or nuts, no chocol...
# 593     11-824                       Cheese straws/twists, retail
# 874     11-820                                     Cream crackers
# 891     11-822                                    Crispbread, rye
# 515     11-832                    Cake, sponge, soft iced, retail
# 521     11-840                 Cakes from 'healthy eating' ranges
# 523     11-839              Cakes, fancy iced, individual, retail
# 902     11-989                                  Crumpets, toasted
# ...

# %%
Red13 = pd.concat([Red12,Filt_BR], axis=0, join='inner')
Red13
# Out:
#      Food Code                                          Food Name  \
# 852     11-011                                   Cornmeal, sifted
# 1012   11-1138                                     Custard powder
# 579     11-987                    Chapatis, made with fat, retail
# 892     11-988                                         Croissants
# 497     11-916                                         Cake rusks
# 577     11-819  Cereal bars, with fruit and/or nuts, no chocol...
# 593     11-824                       Cheese straws/twists, retail
# 874     11-820                                     Cream crackers
# 891     11-822                                    Crispbread, rye
# 515     11-832                    Cake, sponge, soft iced, retail
# 521     11-840                 Cakes from 'healthy eating' ranges
# 523     11-839              Cakes, fancy iced, individual, retail
# 902     11-989                                  Crumpets, toasted
# ...

# %%
Red14 = pd.concat([Red13,Filt_DG], axis=0, join='inner')
Red14
# Out:
#      Food Code                                          Food Name  \
# 852     11-011                                   Cornmeal, sifted
# 1012   11-1138                                     Custard powder
# 579     11-987                    Chapatis, made with fat, retail
# 892     11-988                                         Croissants
# 497     11-916                                         Cake rusks
# 577     11-819  Cereal bars, with fruit and/or nuts, no chocol...
# 593     11-824                       Cheese straws/twists, retail
# 874     11-820                                     Cream crackers
# 891     11-822                                    Crispbread, rye
# 515     11-832                    Cake, sponge, soft iced, retail
# 521     11-840                 Cakes from 'healthy eating' ranges
# 523     11-839              Cakes, fancy iced, individual, retail
# 902     11-989                                  Crumpets, toasted
# ...

# %%
Red15 = pd.concat([Red14,DI], axis=0, join='inner')
Red15
# Out:
#      Food Code                                          Food Name  \
# 852     11-011                                   Cornmeal, sifted
# 1012   11-1138                                     Custard powder
# 579     11-987                    Chapatis, made with fat, retail
# 892     11-988                                         Croissants
# 497     11-916                                         Cake rusks
# 577     11-819  Cereal bars, with fruit and/or nuts, no chocol...
# 593     11-824                       Cheese straws/twists, retail
# 874     11-820                                     Cream crackers
# 891     11-822                                    Crispbread, rye
# 515     11-832                    Cake, sponge, soft iced, retail
# 521     11-840                 Cakes from 'healthy eating' ranges
# 523     11-839              Cakes, fancy iced, individual, retail
# 902     11-989                                  Crumpets, toasted
# ...

# %%
Red16 = pd.concat([Red15,Filt_DR], axis=0, join='inner')
Red16
# Out:
#      Food Code                                          Food Name  \
# 852     11-011                                   Cornmeal, sifted
# 1012   11-1138                                     Custard powder
# 579     11-987                    Chapatis, made with fat, retail
# 892     11-988                                         Croissants
# 497     11-916                                         Cake rusks
# 577     11-819  Cereal bars, with fruit and/or nuts, no chocol...
# 593     11-824                       Cheese straws/twists, retail
# 874     11-820                                     Cream crackers
# 891     11-822                                    Crispbread, rye
# 515     11-832                    Cake, sponge, soft iced, retail
# 521     11-840                 Cakes from 'healthy eating' ranges
# 523     11-839              Cakes, fancy iced, individual, retail
# 902     11-989                                  Crumpets, toasted
# ...

# %% [markdown]
#                                                        Export

# %%
Red42.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Reduced_C.csv')
