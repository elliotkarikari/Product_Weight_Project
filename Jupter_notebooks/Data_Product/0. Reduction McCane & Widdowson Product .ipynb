# %% [markdown]
# # McCane & Widdowson Product Reduction

# %% [markdown]
# Reading in Librarys

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re #regular expressions 
from fuzzywuzzy import process, fuzz
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os 
import glob

# %% [markdown]
# Reduced Food List

# %% [markdown]
#                                                      Decisions Made

# %% [markdown]
# - Focuses on raw ingredients like fruits, vegetables, meats, dairy products, grains, etc. These make up a large part of grocery store sales.
#
# - Includes commonly purchased prepared/packaged foods like bread, cereal, cheese, canned goods, jars, frozen foods, snacks, sweets, spreads, oils, spices, etc. These are staples people buy at supermarkets.
#
# - Contains different variations of the same base ingredient (e.g. yogurt plain/fruit/Greek, milk whole/semi-skimmed/skimmed). Retailers sell multiple varieties.
#
# - Excludes less common items or items typically made at home rather than store-bought.
#
# - Limits the variations of each item to 2-3 options. Retail shelves cannot fit every possible variety.
#
# - Covers foods from all the major categories - produce, dairy, meats, seafood, pantry items, frozen foods, snacks, etc.

# %% [markdown]
#                          List of items most likely sold in food retial store based on M&W food items

# %%
food_list = [
  ['Ackee, canned', 'Can'],
  ['Agar, dried', 'Bag'],
  ['Almonds, whole', 'Bag'],
  ['Amaranth leaves, raw', 'Bagged produce'],
  ['Anchovies, canned', 'Can'],
  ['Apple juice, ambient', 'Carton'],
  ['Apples, cooking, raw', 'Loose produce'],
  ['Apples, eating, raw', 'Loose produce'],
  ['Apricots, raw', 'Loose produce'],
  ['Arrowroot', 'Box'],
  ['Artichoke, raw', 'Loose produce'], 
  ['Asparagus, raw', 'Bunched produce'],
  ['Aubergine, raw', 'Loose produce'],
  ['Avocado, raw', 'Loose produce'],
  ['Bacon, back rashers, raw', 'Fresh meat counter'],
  ['Bagels, plain', 'Fresh bakery'],
  ['Baked beans, canned', 'Can'],
  ['Baking powder', 'Box'],
  ['Bananas, raw', 'Loose produce'],
  ['Barley, pearl, raw', 'Bag'],
  ['Basil, dried', 'Bag/jar'],
  ['Beans, butter, canned', 'Can'],
  ['Beef, braising steak, raw', 'Fresh meat counter'],
  ['Beef, fillet steak, raw', 'Fresh meat counter'],
  ['Beetroot, raw', 'Loose produce'],
  ['Biscuits, digestives', 'Pack'],
  ['Biscuits, shortbread', 'Pack'],
  ['Blackberries, raw', 'Punnet'],
  ['Blackcurrants, raw', 'Punnet'],
  ['Bread, naan', 'Fresh bakery'],
  ['Bread, pitta', 'Bag'],
  ['Bread, soda', 'Loaf'],
  ['Bread, tortilla, wheat', 'Pack'],
  ['Bread, white', 'Loaf'],
  ['Bread, wholemeal', 'Loaf'],  
  ['Broccoli, raw', 'Loose produce'],
  ['Brussels sprouts, raw', 'Loose produce'],
  ['Bubble and squeak, homemade', 'Prepared food counter'],
  ['Bulgur wheat, raw', 'Bag'],
  ['Butter','Block'],
  ['Butter, spreadable','Tub'],
  ['Cabbage, raw', 'Loose produce'],
  ['Cake, madeira', 'Fresh bakery'],
  ['Cake, fruit', 'Fresh bakery'], 
  ['Cake, chocolate fudge', 'Fresh bakery'],
  ['Canned fish, tuna', 'Can'],
  ['Canned fish, sardines', 'Can'],
  ['Canned meat, corned beef', 'Can'],
  ['Canned vegetables, sweetcorn', 'Can'],
  ['Canned vegetables, carrots', 'Can'],
  ['Canned vegetables, peas', 'Can'],
  ['Carrots, raw', 'Loose produce'],
  ['Cauliflower, raw', 'Loose produce'],
  ['Celery, raw', 'Loose produce'],
  ['Cereal, cornflakes', 'Box'],
  ['Cereal, muesli', 'Bag'],
  ['Cereal, porridge oats', 'Bag'],
  ['Cheddar cheese', 'Wedge'],
  ['Cheese, brie', 'Wedge'],
  ['Cheese, feta', 'Pack'],
  ['Cheese, mozzarella', 'Pack'],
  ['Cheese, parmesan', 'Wedge'],
  ['Cherries, raw', 'Punnet'],
  ['Chicken, roast', 'Fresh meat counter'],
  ['Chicken, stir-fry strips', 'Fresh meat counter'],
  ['Chickpeas, canned', 'Can'],
  ['Chocolate, milk', 'Bar'],
  ['Chocolate, dark', 'Bar'],
  ['Chocolate, white', 'Bar'],
  ['Coconut, desiccated', 'Bag'],
  ['Coconut milk', 'Can'],
  ['Coffee, instant', 'Jar'],
  ['Cola drink', 'Bottle/can'],
  ['Cookies, chocolate chip', 'Pack'],
  ['Cookies, shortbread', 'Pack'],
  ['Courgettes, raw', 'Loose produce'], 
  ['Couscous, plain', 'Box'],
  ['Crackers, wholemeal', 'Box'],
  ['Crisps, potato', 'Bag'],
  ['Cucumber, raw', 'Loose produce'],
  ['Custard, canned', 'Can'],
  ['Dates, ready to eat', 'Pack aged dried fruit'],
  ['Drinking chocolate powder', 'Tin'],
  ['Dried fruit, raisins', 'Bag'],
  ['Dried fruit, prunes', 'Bag'],
  ['Dried fruit, apricots', 'Bag'],
  ['Duck, roast', 'Fresh meat counter'],
  ['Edam cheese', 'Wedge'],
  ['Eggs', 'Carton'],
  ['Fajita kits', 'Box'],
  ['Falafel mix', 'Box'],
  ['Figs, ready to eat', 'Packaged dried fruit'],
  ['Fish fingers, cod', 'Frozen pack'],
  ['Flour, plain', 'Bag'],
  ['Flour, self-raising', 'Bag'],
  ['Fresh fish, salmon', 'Fresh seafood counter'],
  ['Fresh fish, cod', 'Fresh seafood counter'],
  ['Fresh fish, haddock', 'Fresh seafood counter'],
  ['Fresh meat, beef', 'Fresh meat counter'],
  ['Fresh meat, lamb', 'Fresh meat counter'],  
  ['Fresh meat, pork', 'Fresh meat counter'],
  ['Fresh meat, chicken', 'Fresh meat counter'],
  ['Fruit juices', 'Carton'],
  ['Fruit squash', 'Bottle'],
  ['Fruits, satsumas', 'Bagged produce'],
  ['Fruits, plums', 'Punnet'],
  ['Garam masala', 'Jar'],
  ['Gherkins, pickled', 'Jar'],
  ['Ginger, ground', 'Bag'],
  ['Grapes, seedless', 'Punnet'],
  ['Green beans, raw', 'Bagged produce'],
  ['Herbs, mixed dried', 'Jar'],
  ['Herbs, fresh basil', 'Pot'],
  ['Herbs, fresh parsley', 'Bunched produce'],
  ['Honey', 'Squeeze bottle'],
  ['Horseradish sauce', 'Bottle'],
  ['Hot chocolate powder', 'Tin'],
  ['Ice cream, vanilla', 'Tub'],
  ['Ice cream, strawberry', 'Tub'],
  ['Ice cream, chocolate', 'Tub'],
  ['Instant noodle snacks', 'Cup'],
  ['Jams', 'Jar'], 
  ['Ketchup', 'Bottle'],
  ['Kiwi fruit', 'Loose produce'], 
  ['Lager, canned', 'Can'],
  ['Lamb, leg, raw', 'Fresh meat counter'],
  ['Lamb, shoulder, raw', 'Fresh meat counter'],
  ['Leek, raw', 'Loose produce'],
  ['Lemons', 'Loose produce'],
  ['Lentils, dried', 'Bag'], 
  ['Lettuce, average', 'Loose produce'],
  ['Limes', 'Bagged produce'],
  ['Mackerel, canned', 'Can'],
  ['Mangetout, raw', 'Bagged produce'],
  ['Margarine','Tub'],
  ['Marmalade', 'Jar'],
  ['Marzipan', 'Block'],
  ['Mayonnaise', 'Bottle'],
  ['Milk, whole', 'Bottle'],
  ['Milk, semi-skimmed', 'Bottle'], 
  ['Milk, skimmed', 'Bottle'],
  ['Mince pies', 'Pack'],
  ['Mints, sweets', 'Pack'],
  ['Muesli, no added sugar', 'Bag'],
  ['Mushrooms, raw', 'Closed cup/pack'],
  ['Mussels, raw', 'Fresh seafood counter'],
  ['Mustard', 'Squeeze bottle'],
  ['Noodles, dried', 'Pack'],
  ['Nuts, peanuts', 'Bag'],
  ['Nuts, cashew', 'Bag'],
  ['Nuts, almond', 'Bag'],
  ['Oats, rolled', 'Bag'],
  ['Oils, vegetable', 'Bottle'],
  ['Oils, olive', 'Bottle'], 
  ['Olives, canned', 'Jar'],
  ['Onions, raw', 'Mesh bag'],
  ['Oranges', 'Bag'],
  ['Pasta, dried', 'Box'],
  ['Pasta sauce, jar', 'Jar'],
  ['Pastry, frozen', 'Pack'],
  ['Peaches, canned', 'Can'],
  ['Peanut butter', 'Jar'],
  ['Pears, canned', 'Can'],
  ['Peas, frozen', 'Frozen pack'],
  ['Peas, canned', 'Can'],
  ['Pepper, black', 'Grinder'],
  ['Peppers, raw', 'Loose produce'],
  ['Pickles', 'Jar'],
  ['Pies, meat', 'Fresh bakery'],
  ['Pies, fruit', 'Fresh bakery'],
  ['Pineapple, canned', 'Can'],
  ['Pineapple, fresh','Whole produce'],
  ['Pistachios', 'Bag'], 
  ['Pizza, refrigerated', 'Packaged fresh'],
  ['Plums, raw', 'Punnet'],
  ['Porridge oats', 'Bag'],
  ['Pork sausages', 'Fresh meat counter'],
  ['Pork pies', 'Fresh bakery'], 
  ['Potatoes, old, raw', 'Loose produce'],
  ['Potatoes, new, raw', 'Bagged produce'],
  ['Prawns, frozen', 'Frozen pack'],
  ['Prunes, ready to eat', 'Packaged dried fruit'],
  ['Pulses, dried', 'Bag'],
  ['Quinoa', 'Box'],
  ['Rice, basmati', 'Bag'],
  ['Rice, easy cook', 'Bag'],
  ['Rice, long grain', 'Bag'],
  ['Rocket leaves', 'Bagged produce'],
  ['Rye bread', 'Loaf'],
  ['Salad dressing', 'Bottle'],
  ['Salmon, smoked', 'Fresh seafood counter'],
  ['Sardines, canned', 'Can'],
  ['Sausages, pork', 'Fresh meat counter'],
  ['Sausages, vegetarian', 'Pack'], 
  ['Scotch broth, dried', 'Box'],
  ['Seeds, sunflower', 'Bag'],
  ['Seeds, pumpkin', 'Bag'],
  ['Self-raising flour', 'Bag'], 
  ['Semi-skimmed milk', 'Bottle'],
  ['Sesame seeds', 'Bag'],
  ['Smoked fish, mackerel', 'Pack'],
  ['Smoked meat, ham', 'Sliced deli counter'],
  ['Smoked salmon', 'Pack'],
  ['Soup, canned', 'Can'],
  ['Soya milk', 'Carton'], 
  ['Spaghetti, dried', 'Box'],
  ['Spices, garlic powder', 'Jar'],
  ['Spices, cinnamon', 'Jar'],
  ['Spinach, raw', 'Bagged produce'],
  ['Spring greens, raw', 'Loose produce'],
  ['Spring onions', 'Bunched produce'],
  ['Sprouts, alfalfa', 'Bagged produce'], 
  ['Squash, butternut', 'Whole produce'],
  ['Stews, canned', 'Can'],
  ['Stilton cheese', 'Wedge'],
  ['Strawberries', 'Punnet'],
  ['Sugar, white', 'Bag'],
  ['Sugar, brown', 'Bag'],
  ['Sultanas', 'Bag'], 
  ['Sunflower oil', 'Bottle'],
  ['Sunflower seeds', 'Bag'],
  ['Swede, raw', 'Loose produce'],
  ['Sweetcorn, canned', 'Can'],
  ['Sweetcorn, frozen', 'Frozen pack'],
  ['Sweets, liquorice allsorts', 'Bag'],
  ['Sweets, jelly babies', 'Bag'],
  ['Sweets, mints', 'Pack'],
  ['Swede, raw', 'Loose produce'],
  ['Tea bags', 'Box'],
  ['Tinned tomatoes', 'Can'],
  ['Tinned tuna', 'Can'],
  ['Tofu', 'Pack'],
  ['Tomatoes, raw', 'Loose produce'],
  ['Tomatoes, canned', 'Can'], 
  ['Tuna, canned', 'Can'],
  ['Turkey, whole', 'Fresh meat counter'],
  ['Turmeric', 'Jar'],
  ['Vegetables, frozen mix', 'Frozen pack'],
  ['Vegetable oil', 'Bottle'],
  ['Vegetarian sausages', 'Pack'],
  ['Vinegar, balsamic', 'Bottle'], 
  ['Walnuts', 'Bag'],
  ['Water, still', 'Bottle'],
  ['Wheat biscuits', 'Box'],
  ['Wheatgerm', 'Bag'],
  ['Whiting, raw', 'Fresh seafood counter'],
  ['Wine, red', 'Bottle'],
  ['Wine, white', 'Bottle'],
  ['Yeast, dried', 'Jar'],
  ['Yogurt, fruit', 'Pot'],
  ['Yogurt, plain', 'Pot'],
  ['Yogurt, Greek', 'Pot']
]

# %%
len(food_list)
# Out:
# 252

# %%
food_list2 = [
  ['Apricots, dried', 'Packaged dried fruit'],
  ['Apricots, canned', 'Canned'],
  ['Baking fat, hard margarine', 'Tub'], 
  ['Beef, corned, canned', 'Canned'],
  ['Beef, minced', 'Fresh meat counter'],
  ['Beef, roast', 'Fresh meat counter'],
  ['Beer, lager', 'Bottled/canned'],
  ['Biscuits, chocolate coated', 'Packaged'],
  ['Biscuits, cream filled', 'Packaged'],
  ['Bread, baguettes', 'Fresh bakery'],
  ['Bread, wraps', 'Packaged'],
  ['Buns, burger', 'Fresh bakery'],
  ['Buns, hot dog', 'Fresh bakery'],
  ['Butter, salted', 'Tub'],
  ['Cake bars, snack', 'Packaged snacks'],
  ['Cake, madeira, iced', 'Fresh bakery'],
  ['Cake, sponge', 'Fresh bakery'],
  ['Cereal bars', 'Packaged snacks'],
  ['Cereal, shredded wheat', 'Box'],
  ['Cereal, crunchy nut cornflakes', 'Box'],
  ['Cheese, cheddar, reduced fat', 'Packaged'],
  ['Cheese, cream cheese', 'Tub'],
  ['Cheese, goat cheese', 'Packaged'],
  ['Cheese, halloumi', 'Packaged'],
  ['Cheese, ricotta', 'Tub'],
  ['Chicken, boneless breasts', 'Fresh meat counter'],
  ['Chicken, drumsticks', 'Fresh meat counter'],
  ['Chicken, thigh', 'Fresh meat counter'],
  ['Chicken, turkey, deli meat', 'Fresh meat counter'],
  ['Chickpeas, dried', 'Bag'],
  ['Chocolate bars', 'Packaged snacks'], 
  ['Chutney', 'Jar'],
  ['Coleslaw, prepackaged', 'Tub'],
  ['Cookies, oat', 'Packaged'],
  ['Cous cous, flavored, plain', 'Box'],
  ['Crackers, savory', 'Box'],
  ['Crisps, tortilla', 'Bag'],
  ['Croissants', 'Fresh bakery'],
  ['Curry paste', 'Jar'],
  ['Dips, hummus', 'Tub'],
  ['Dips, salsa', 'Jar'],
  ['Duck, boneless breasts', 'Fresh meat counter'],
  ['Eggs, free range', 'Carton'],
  ['Filo pastry', 'Pack'],
  ['Fish, batter', 'Frozen pack'],
  ['Fish, breaded', 'Frozen pack'],
  ['Fish, pollock', 'Fresh seafood counter'],
  ['Fish, prawns', 'Fresh seafood counter'],
  ['Fish, smoked haddock', 'Fresh seafood counter'],
  ['Fish, tuna, canned in oil', 'Can'],
  ['Fish, whitefish fillets', 'Fresh seafood counter'],
  ['Flour, whole wheat', 'Bag'],
  ['Fruit, canned', 'Can'], 
  ['Fruit, dried', 'Packaged dried fruit'],
  ['Fruit, prepared', 'Packaged produce'],
  ['Gelatine, powder', 'Box'],
  ['Gherkins', 'Jar'],
  ['Gravy mix', 'Jar'],
  ['Ham, sliced', 'Fresh meat counter'],
  ['Herbs, dried mixed', 'Jar'],
  ['Honey, clear', 'Squeeze bottle'], 
  ['Hummus', 'Tub'],
  ['Ice cream cones', 'Box'],
  ['Jelly, powder', 'Box'],
  ['Juices, fruit', 'Carton'],
  ['Ketchup, reduced sugar', 'Squeeze bottle'],
  ['Kitchen towels', 'Pack'],
  ['Lamb, diced for stew', 'Fresh meat counter'],
  ['Lamb, minced', 'Fresh meat counter'],
  ['Lemonade', 'Bottle'], 
  ['Lentils, green, dried', 'Bag'],
  ['Lentils, red, dried', 'Bag'], 
  ['Lettuce, bagged salad', 'Bag'],
  ['Lollipops', 'Packaged candy'],
  ['Meat, deli sliced', 'Fresh meat counter'],
  ['Milk, almond', 'Carton'],
  ['Milk, coconut', 'Carton'],
  ['Milk, lactose free', 'Carton'],
  ['Mincemeat', 'Jar'],
  ['Muesli, no added sugar', 'Bag'],
  ['Muesli, sweetened', 'Bag'],
  ['Mushrooms, chestnut, dried', 'Bag'],
  ['Mushrooms, oyster, dried', 'Bag'],
  ['Mushrooms, shiitake, dried', 'Bag'],
  ['Mustard, wholegrain', 'Jar'],
  ['Noodles, fresh', 'Pack'],
  ['Nuts, mixed', 'Bag'],
  ['Oil, canola', 'Bottle'],
  ['Oil, coconut', 'Bottle'],
  ['Oil, corn', 'Bottle'],
  ['Oil, sunflower', 'Bottle'],
  ['Olives, black', 'Jar'],
  ['Pasta, fresh filled', 'Pack'], 
  ['Pasta, gluten-free', 'Box'],
  ['Pasta, lasagna sheets', 'Box'],
  ['Pasta, wholewheat', 'Box'],
  ['Pastry, shortcrust', 'Pack'],
  ['Pastry, sweet shortcrust', 'Pack'],
  ['Peanut butter, crunchy', 'Jar'],
  ['Peanut butter, smooth', 'Jar'],
  ['Peas, frozen', 'Frozen pack'],
  ['Peppers, assorted', 'Fresh produce'],
  ['Pickles, pickled onions', 'Jar'],
  ['Pies, pork pies', 'Fresh bakery'],
  ['Pineapple, chunks, canned', 'Can'],
  ['Pineapple, crushed, canned', 'Can'],
  ['Pizza, fresh', 'Packaged fresh'],
  ['Pizza, frozen', 'Frozen pack'],
  ['Popcorn', 'Bag'],
  ['Pork, baby back ribs', 'Fresh meat counter'],
  ['Pork, chops', 'Fresh meat counter'],
  ['Pork, diced', 'Fresh meat counter'],
  ['Pork, leg steaks', 'Fresh meat counter'],
  ['Pork, loin chops', 'Fresh meat counter'],
  ['Pork, shoulder', 'Fresh meat counter'],
  ['Potatoes, baked', 'Fresh produce'],
  ['Potatoes, mashed', 'Packaged produce'],
  ['Prawns, cooked', 'Fresh seafood counter'],
  ['Prawns, raw', 'Fresh seafood counter'],
  ['Quiche', 'Fresh bakery'],
  ['Rice, arborio', 'Bag'],
  ['Rice, brown', 'Bag'],
  ['Rice, microwave pouches', 'Pouch'],
  ['Rice, white', 'Bag'], 
  ['Salmon, smoked, sliced', 'Fresh seafood counter'],
  ['Salsa', 'Jar'],
  ['Sardines, in oil or sauce', 'Can'],
  ['Sauces, pasta', 'Jar'],
  ['Sausages, beef', 'Fresh meat counter'],
  ['Sausages, turkey', 'Fresh meat counter'],
  ['Seasonings, mixed', 'Jar'],
  ['Seeds, chia', 'Bag'],
  ['Seeds, sesame', 'Bag'],
  ['Soup, cup of', 'Cup'],
  ['Soup, instant sachets', 'Pouch'],
  ['Soy sauce', 'Bottle'],
  ['Spices, allspice', 'Jar'],
  ['Spices, paprika', 'Jar'],
  ['Spreads, chocolate', 'Jar'],
  ['Spreads, honey', 'Squeeze bottle'], 
  ['Spreads, jam','Jar'],
  ['Spreads, yeast extract', 'Jar'], 
  ['Squash, butternut', 'Fresh produce'],
  ['Sugar, caster', 'Bag'],
  ['Sugar, icing', 'Bag'],
  ['Sugar, muscovado', 'Bag'],
  ['Sultanas, golden', 'Bag'],
  ['Sweetener, granulated', 'Pouch'],
  ['Sweetener, tablets', 'Box'],
  ['Sweets, boiled', 'Bag'],
  ['Sweets, candy', 'Bag'],
  ['Sweets, chewing gum', 'Pack'],
  ['Sweets, fudge', 'Packaged candy'],
  ['Sweets, gummies', 'Bag'],
  ['Sweets, lollipops', 'Packaged candy'],
  ['Tea, black', 'Box'],
  ['Tea, camomile', 'Box'],
  ['Tea, decaffeinated', 'Box'],
  ['Tea, fruit', 'Box'],
  ['Tea, green', 'Box'],
  ['Toilet paper', 'Pack'],
  ['Tomatoes, cherry', 'Packaged produce'],
  ['Tomatoes, plum', 'Packaged produce'],
  ['Tomatoes, sun dried', 'Packaged dried produce'],
  ['Tortillas, corn', 'Pack'],
  ['Tortillas, flour', 'Pack'],
  ['Tuna, canned in spring water', 'Can'],
  ['Vinegar, white wine', 'Bottle'],
  ['Vinegar, red wine', 'Bottle'],
  ['Water, carbonated', 'Bottle'],
  ['Water, flavored', 'Bottle'],
  ['Yeast, fresh', 'Pack'],
  ['Yogurt, frozen', 'Tub'],
  ['Yogurt, low fat varieties', 'Pot'],
  ['Yogurt, organic', 'Pot'],
  ['Yogurt, soy', 'Pot']  
]

# %%
len(food_list2)
# Out:
# 176

# %%
176 + 252
# Out:
# 428

# %% [markdown]
#                                             Combine into single dataframe

# %%
newlist = food_list + food_list2

# %%
reduce= pd.DataFrame(newlist)
reduce.rename(columns={0:'Food Name', 1:'Sales Format'}, inplace=True)
reduce
# Out:
#                      Food Name    Sales Format
# 0                Ackee, canned             Can
# 1                  Agar, dried             Bag
# 2               Almonds, whole             Bag
# 3         Amaranth leaves, raw  Bagged produce
# 4            Anchovies, canned             Can
# ..                         ...             ...
# 423               Yeast, fresh            Pack
# 424             Yogurt, frozen             Tub
# 425  Yogurt, low fat varieties             Pot
# 426            Yogurt, organic             Pot
# 427                Yogurt, soy             Pot
#
# [428 rows x 2 columns]

# %% [markdown]
#                                            Matching my new list with M&W Database

# %% [markdown]
# Previously Reduced List

# %%
mFood = pd.read_csv(r"C:\Users\medekar\Desktop\Product_Weight_Project\Data\Raw Data\Labelling2021_watercress2.csv", index_col = 0)

# %%
mFood.drop(['Description','Previous', 'Main data references', 'Footnote', 'Energy (kJ)','Energy (kcal)', 
           'Fat (g)', 'Saturates (g)', 'Carbohydrate (g)','Sugars (g)', 'Starch (g)', 'Fibre (g)', 
           'Protein (g)', 'Salt (g)'], axis=1, inplace=True)

# %%
mFood#.head()
# Out:
#      Food Code                                          Food Name  \
# 0       13-145                             Ackee, canned, drained
# 1       13-146                                        Agar, dried
# 2       13-147                    Agar, dried, soaked and drained
# 3       13-148                               Alfalfa sprouts, raw
# 4       13-801                                   Allspice, ground
# ...        ...                                                ...
# 2882    12-515            Yogurt, whole milk, twin pot, not fruit
# 2883    12-531  Yogurt, whole milk, twin pot, thick and creamy...
# 2884    11-960  Yorkshire pudding, made with semi-skimmed milk...
# 2885   11-1135  Yorkshire pudding, made with skimmed milk, hom...
# 2886   11-1146            Yorkshire pudding, made with whole milk
#
#      Food sub-group codes                    FoodGroup
# 0                      DG                   Vegetables
# 1                      DG                   Vegetables
# 2                      DG                   Vegetables
# 3                      DG                   Vegetables
# 4                       H             Herbs and spices
# ...                   ...                          ...
# 2882                   BN       Milk and milk products
# 2883                   BN       Milk and milk products
# 2884                   AT  Cereals and cereal products
# 2885                   AT  Cereals and cereal products
# 2886                   AT  Cereals and cereal products
#
# [2887 rows x 4 columns]

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
#                                                        Matching Algo

# %%
# %%time
# Preprocess strings
def preprocess_string(s):
    s = s.lower()  # Convert to lowercase
    s = ' '.join(s.split())  # Remove extra spaces
    s = s.strip()  # Remove leading/trailing spaces
    return s

# Create a set to keep track of matched indices
matched_indices = set()

# Preprocess food names in both DataFrames
reduce['Food Name'] = reduce['Food Name'].apply(preprocess_string)
mFood['Food Name'] = mFood['Food Name'].apply(preprocess_string)

# Create new columns to store matches, similarity scores, and sales format
mFood['Matches'] = ""
mFood['Similarity Score'] = 0
mFood['Sales Format'] = ""

# Set a similarity threshold
similarity_threshold = 70  # Adjust as needed

# Loop through the food names and perform fuzzy matching
for index, row in reduce.iterrows():
    if index in matched_indices:
        continue  # Skip already matched rows
    food_name = row['Food Name']
    sales_format = row['Sales Format']

    best_similarity = 0
    best_match_index = None

    for mIndex, mRow in mFood.iterrows():
        similarity = fuzz.token_sort_ratio(food_name, mRow['Food Name'])
        if similarity > best_similarity and similarity >= similarity_threshold:
            best_similarity = similarity
            best_match_index = mIndex

    if best_match_index is not None:
        mFood.at[best_match_index, 'Matches'] += f"{food_name}, "
        mFood.at[best_match_index, 'Similarity Score'] = best_similarity
        mFood.at[best_match_index, 'Sales Format'] = sales_format

# Remove the trailing comma and whitespace from the "Matches" column
mFood['Matches'] = mFood['Matches'].str.rstrip(', ')
# Out:
# CPU times: total: 1min 38s
# Wall time: 1min 38s

# %%
mFood.columns
# Out:
# Index(['Food Code', 'Food Name', 'Food sub-group codes', 'FoodGroup',
#        'Matches', 'Similarity Score', 'Sales Format'],
#       dtype='object')

# %%
fFood = mFood[mFood['Matches'] != '']
fFood['Food Name'].count()
# Out:
# 215

# %% [markdown]
# ## 215 items from New list matched previously reduced List

# %%
fFood.rename(columns={'FoodGroup':'Food Group'}, inplace=True)
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_26660\1288575859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fFood.rename(columns={'FoodGroup':'Food Group'}, inplace=True)

# %%
fFood.head()
# Out:
#    Food Code               Food Name Food sub-group codes      Food Group  \
# 0     13-145  ackee, canned, drained                   DG      Vegetables
# 1     13-146             agar, dried                   DG      Vegetables
# 3     13-148    alfalfa sprouts, raw                   DG      Vegetables
# 8     14-896  almonds, whole kernels                   GA  Nuts and seeds
# 10    13-149    amaranth leaves, raw                   DG      Vegetables
#
#                  Matches  Similarity Score    Sales Format
# 0          ackee, canned                75             Can
# 1            agar, dried               100             Bag
# 3       sprouts, alfalfa                88  Bagged produce
# 8         almonds, whole                76             Bag
# 10  amaranth leaves, raw               100  Bagged produce

# %%
# Create a set of values from fFood['Matches'] column
fFood_matches = set(fFood['Matches'])

# Filter out rows from reduce where the Food Name is in fFood_matches
unmatched_rows = reduce[~reduce['Food Name'].isin(fFood_matches)]

# %%
unmatched_rows['Food Name'].count()
# Out:
# 253

# %%
unmatched_rows#.head()
# Out:
#                           Food Name            Sales Format
# 4                 anchovies, canned                     Can
# 5              apple juice, ambient                  Carton
# 6              apples, cooking, raw           Loose produce
# 8                     apricots, raw           Loose produce
# 13                     avocado, raw           Loose produce
# 16              baked beans, canned                     Can
# 18                     bananas, raw           Loose produce
# 27                blackberries, raw                  Punnet
# 42                    cake, madeira            Fresh bakery
# 45                canned fish, tuna                     Can
# 46            canned fish, sardines                     Can
# 47         canned meat, corned beef                     Can
# 48     canned vegetables, sweetcorn                     Can
# 49       canned vegetables, carrots                     Can
# 50          canned vegetables, peas                     Can
# 54               cereal, cornflakes                     Box
# 55                   cereal, muesli                     Bag
# 56            cereal, porridge oats                     Bag
# 58                     cheese, brie                   Wedge
# 62                    cherries, raw                  Punnet
# 64         chicken, stir-fry strips      Fresh meat counter
# 65                chickpeas, canned                     Can
# 66                  chocolate, milk                     Bar
# 67                  chocolate, dark                     Bar
# 70                     coconut milk                     Can
# 79                    cucumber, raw           Loose produce
# 80                  custard, canned                     Can
# 81              dates, ready to eat   Pack aged dried fruit
# 82        drinking chocolate powder                     Tin
# 84              dried fruit, prunes                     Bag
# 85            dried fruit, apricots                     Bag
# 86                      duck, roast      Fresh meat counter
# 88                             eggs                  Carton
# 89                      fajita kits                     Box
# 90                      falafel mix                     Box
# 93                     flour, plain                     Bag
# 94              flour, self-raising                     Bag
# 95               fresh fish, salmon   Fresh seafood counter
# 96                  fresh fish, cod   Fresh seafood counter
# 97              fresh fish, haddock   Fresh seafood counter
# 99                 fresh meat, lamb      Fresh meat counter
# 100                fresh meat, pork      Fresh meat counter
# 102                    fruit juices                  Carton
# 103                    fruit squash                  Bottle
# 104                fruits, satsumas          Bagged produce
# 105                   fruits, plums                  Punnet
# 111              herbs, mixed dried                     Jar
# 116            hot chocolate powder                     Tin
# 117              ice cream, vanilla                     Tub
# 118           ice cream, strawberry                     Tub
# 119            ice cream, chocolate                     Tub
# 120           instant noodle snacks                     Cup
# 121                            jams                     Jar
# 122                         ketchup                  Bottle
# 123                      kiwi fruit           Loose produce
# 124                   lager, canned                     Can
# 128                          lemons           Loose produce
# 131                           limes          Bagged produce
# 132                mackerel, canned                     Can
# 134                       margarine                     Tub
# 136                        marzipan                   Block
# 137                      mayonnaise                  Bottle
# 139              milk, semi-skimmed                  Bottle
# 142                   mints, sweets                    Pack
# 143          muesli, no added sugar                     Bag
# 148                   nuts, peanuts                     Bag
# 149                    nuts, cashew                     Bag
# 150                    nuts, almond                     Bag
# 151                    oats, rolled                     Bag
# 152                 oils, vegetable                  Bottle
# 154                  olives, canned                     Jar
# 155                     onions, raw                Mesh bag
# 156                         oranges                     Bag
# 157                    pasta, dried                     Box
# 158                pasta sauce, jar                     Jar
# 159                  pastry, frozen                    Pack
# 160                 peaches, canned                     Can
# 161                   peanut butter                     Jar
# 162                   pears, canned                     Can
# 163                    peas, frozen             Frozen pack
# 164                    peas, canned                     Can
# 166                    peppers, raw           Loose produce
# 168                      pies, meat            Fresh bakery
# 170               pineapple, canned                     Can
# 171                pineapple, fresh           Whole produce
# 173             pizza, refrigerated          Packaged fresh
# 174                      plums, raw                  Punnet
# 175                   porridge oats                     Bag
# 176                   pork sausages      Fresh meat counter
# 177                       pork pies            Fresh bakery
# 179              potatoes, new, raw          Bagged produce
# 180                  prawns, frozen             Frozen pack
# 182                   pulses, dried                     Bag
# 190                  salmon, smoked   Fresh seafood counter
# 191                sardines, canned                     Can
# 192                  sausages, pork      Fresh meat counter
# 193            sausages, vegetarian                    Pack
# 195                seeds, sunflower                     Bag
# 197              self-raising flour                     Bag
# 198               semi-skimmed milk                  Bottle
# 199                    sesame seeds                     Bag
# 201                smoked meat, ham     Sliced deli counter
# 202                   smoked salmon                    Pack
# 207                spices, cinnamon                     Jar
# 210                   spring onions         Bunched produce
# 212               squash, butternut           Whole produce
# 213                   stews, canned                     Can
# 218                        sultanas                     Bag
# 219                   sunflower oil                  Bottle
# 220                 sunflower seeds                     Bag
# 221                      swede, raw           Loose produce
# 222               sweetcorn, canned                     Can
# 223               sweetcorn, frozen             Frozen pack
# 225            sweets, jelly babies                     Bag
# 226                   sweets, mints                    Pack
# 227                      swede, raw           Loose produce
# 228                        tea bags                     Box
# 229                 tinned tomatoes                     Can
# 230                     tinned tuna                     Can
# 231                            tofu                    Pack
# 232                   tomatoes, raw           Loose produce
# 233                tomatoes, canned                     Can
# 234                    tuna, canned                     Can
# 237          vegetables, frozen mix             Frozen pack
# 238                   vegetable oil                  Bottle
# 239             vegetarian sausages                    Pack
# 240               vinegar, balsamic                  Bottle
# 245                    whiting, raw   Fresh seafood counter
# 247                     wine, white                  Bottle
# 250                   yogurt, plain                     Pot
# 251                   yogurt, greek                     Pot
# 252                 apricots, dried    Packaged dried fruit
# 253                apricots, canned                  Canned
# 255            beef, corned, canned                  Canned
# 258                     beer, lager          Bottled/canned
# 261                bread, baguettes            Fresh bakery
# 262                    bread, wraps                Packaged
# 263                    buns, burger            Fresh bakery
# 264                   buns, hot dog            Fresh bakery
# 266                cake bars, snack         Packaged snacks
# 267             cake, madeira, iced            Fresh bakery
# 269                     cereal bars         Packaged snacks
# 270          cereal, shredded wheat                     Box
# 271  cereal, crunchy nut cornflakes                     Box
# 277       chicken, boneless breasts      Fresh meat counter
# 279                  chicken, thigh      Fresh meat counter
# 281                chickpeas, dried                     Bag
# 283                         chutney                     Jar
# 284           coleslaw, prepackaged                     Tub
# 285                    cookies, oat                Packaged
# 286      cous cous, flavored, plain                     Box
# 287                crackers, savory                     Box
# 288                crisps, tortilla                     Bag
# 291                    dips, hummus                     Tub
# 292                     dips, salsa                     Jar
# 293          duck, boneless breasts      Fresh meat counter
# 294                eggs, free range                  Carton
# 295                     filo pastry                    Pack
# 296                    fish, batter             Frozen pack
# 298                   fish, pollock   Fresh seafood counter
# 301       fish, tuna, canned in oil                     Can
# 302         fish, whitefish fillets   Fresh seafood counter
# 304                   fruit, canned                     Can
# 305                    fruit, dried    Packaged dried fruit
# 306                 fruit, prepared        Packaged produce
# 309                       gravy mix                     Jar
# 310                     ham, sliced      Fresh meat counter
# 311              herbs, dried mixed                     Jar
# 312                    honey, clear          Squeeze bottle
# 314                 ice cream cones                     Box
# 316                   juices, fruit                  Carton
# 318                  kitchen towels                    Pack
# 319            lamb, diced for stew      Fresh meat counter
# 321                        lemonade                  Bottle
# 322           lentils, green, dried                     Bag
# 324           lettuce, bagged salad                     Bag
# 325                       lollipops          Packaged candy
# 326               meat, deli sliced      Fresh meat counter
# 327                    milk, almond                  Carton
# 328                   milk, coconut                  Carton
# 329              milk, lactose free                  Carton
# 331          muesli, no added sugar                     Bag
# 337                  noodles, fresh                    Pack
# 339                     oil, canola                  Bottle
# 341                       oil, corn                  Bottle
# 342                  oil, sunflower                  Bottle
# 343                   olives, black                     Jar
# 345              pasta, gluten-free                     Box
# 346           pasta, lasagna sheets                     Box
# 347               pasta, wholewheat                     Box
# 349        pastry, sweet shortcrust                    Pack
# 350          peanut butter, crunchy                     Jar
# 351           peanut butter, smooth                     Jar
# 352                    peas, frozen             Frozen pack
# 353               peppers, assorted           Fresh produce
# 354         pickles, pickled onions                     Jar
# 355                 pies, pork pies            Fresh bakery
# 356       pineapple, chunks, canned                     Can
# 357      pineapple, crushed, canned                     Can
# 358                    pizza, fresh          Packaged fresh
# 359                   pizza, frozen             Frozen pack
# 360                         popcorn                     Bag
# 361            pork, baby back ribs      Fresh meat counter
# 362                     pork, chops      Fresh meat counter
# 363                     pork, diced      Fresh meat counter
# 366                  pork, shoulder      Fresh meat counter
# 368                potatoes, mashed        Packaged produce
# 369                  prawns, cooked   Fresh seafood counter
# 371                          quiche            Fresh bakery
# 372                   rice, arborio                     Bag
# 374         rice, microwave pouches                   Pouch
# 376          salmon, smoked, sliced   Fresh seafood counter
# 378       sardines, in oil or sauce                     Can
# 379                   sauces, pasta                     Jar
# 382               seasonings, mixed                     Jar
# 383                     seeds, chia                     Bag
# 384                   seeds, sesame                     Bag
# 385                    soup, cup of                     Cup
# 386           soup, instant sachets                   Pouch
# 387                       soy sauce                  Bottle
# 388                spices, allspice                     Jar
# 389                 spices, paprika                     Jar
# 390              spreads, chocolate                     Jar
# 391                  spreads, honey          Squeeze bottle
# 392                    spreads, jam                     Jar
# 394               squash, butternut           Fresh produce
# 395                   sugar, caster                     Bag
# 397                sugar, muscovado                     Bag
# 398                sultanas, golden                     Bag
# 399           sweetener, granulated                   Pouch
# 400              sweetener, tablets                     Box
# 402                   sweets, candy                     Bag
# 403             sweets, chewing gum                    Pack
# 404                   sweets, fudge          Packaged candy
# 405                 sweets, gummies                     Bag
# 406               sweets, lollipops          Packaged candy
# 408                   tea, camomile                     Box
# 409              tea, decaffeinated                     Box
# 410                      tea, fruit                     Box
# 412                    toilet paper                    Pack
# 413                tomatoes, cherry        Packaged produce
# 415             tomatoes, sun dried  Packaged dried produce
# 416                 tortillas, corn                    Pack
# 417                tortillas, flour                    Pack
# 418    tuna, canned in spring water                     Can
# 419             vinegar, white wine                  Bottle
# 420               vinegar, red wine                  Bottle
# 421               water, carbonated                  Bottle
# 422                 water, flavored                  Bottle
# 424                  yogurt, frozen                     Tub
# 425       yogurt, low fat varieties                     Pot
# 426                 yogurt, organic                     Pot
# 427                     yogurt, soy                     Pot

# %% [markdown]
#                               Match against origional Dataproduct list with Matched Newlist/M&W

# %%
fFood.drop(['Matches','Similarity Score'], axis=1, inplace=True)
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_26660\323510823.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fFood.drop(['Matches','Similarity Score'], axis=1, inplace=True)

# %% [markdown]
# M&W List

# %%
bFood = pd.read_csv(r"C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\ReducedwithWeights\dataproduct2.csv", index_col = 0)

# %%
bFood.head()
# Out:
#   Food Code                 Food Name Food sub-group codes  \
# 0    17-208  beer bitter best premium                   QA
# 1    17-224               cider sweet                   QC
# 2    17-234                      port                   QF
# 3    17-236             sherry medium                   QF
# 4    17-247        spirits 40% volume                   QK
#
#             Food Group                                Sale format(s)  Source  \
# 0  Alcoholic beverages  can, can multipack, bottle, bottle multipack     NaN
# 1  Alcoholic beverages  can, can multipack, bottle, bottle multipack     NaN
# 2  Alcoholic beverages                                        bottle     NaN
# 3  Alcoholic beverages                                        bottle     NaN
# 4  Alcoholic beverages                             bottle, miniature     NaN
#
#    Similarity Score Weight PurEqualCon Portion Consumed
# 0          0.601799   333g           Y        small can
# 1          0.000000    NaN         NaN              NaN
# 2          0.000000    NaN         NaN              NaN
# 3          0.792070   200g           Y           medium
# 4          0.707107    29g           Y      1 miniature

# %%
bFood.drop(['Source', 'Similarity Score', 'Weight', 'PurEqualCon','Portion Consumed'], axis=1, inplace=True)

# %%
# %%time
# Create a set to keep track of matched indices
matched_indices = set()

# Preprocess food names in both DataFrames
fFood['Food Name'] = fFood['Food Name'].apply(preprocess_string)
bFood['Food Name'] = bFood['Food Name'].apply(preprocess_string)

# Create new columns to store matches, similarity scores, and sales format
bFood['Matches'] = ""
bFood['Similarity Score1'] = 0
bFood['Sales Format'] = ""

# Set a similarity threshold
similarity_threshold = 60  # Adjust as needed

# Loop through the food names and perform fuzzy matching
for index, row in fFood.iterrows():
    if index in matched_indices:
        continue  # Skip already matched rows

    food_name = row['Food Name']
    sales_format = row['Sales Format']

    best_similarity = 0
    best_match_index = None

    for mIndex, mRow in bFood.iterrows():
        if mIndex in matched_indices:
            continue  # Skip already matched rows

        similarity = fuzz.token_sort_ratio(food_name, mRow['Food Name'])
        if similarity > best_similarity and similarity >= similarity_threshold:
            best_similarity = similarity
            best_match_index = mIndex

    if best_match_index is not None:
        matched_indices.add(index)
        matched_indices.add(best_match_index)

        bFood.at[best_match_index, 'Matches'] += f"{food_name}, "
        bFood.at[best_match_index, 'Similarity Score1'] = best_similarity
        bFood.at[best_match_index, 'Sales Format'] = sales_format

# Remove the trailing comma and whitespace from the "Matches" column
bFood['Matches'] = bFood['Matches'].str.rstrip(', ')
# Out:
# <timed exec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# CPU times: total: 7.91 s
# Wall time: 7.9 s

# %%
bFood['Food Name'].count()
# Out:
# 537

# %%
fFood.columns
# Out:
# Index(['Food Code', 'Food Name', 'Food sub-group codes', 'Food Group',
#        'Sales Format'],
#       dtype='object')

# %%
redlist = bFood[bFood['Matches'] == '']

# %%
redlist.drop(['Matches','Similarity Score1','Sales Format'], axis=1, inplace=True)
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_26660\1849740050.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   redlist.drop(['Matches','Similarity Score1','Sales Format'], axis=1, inplace=True)

# %%
redlist.rename(columns={'Sale format(s)':'Sales Format'}, inplace=True)
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_26660\3333984185.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   redlist.rename(columns={'Sale format(s)':'Sales Format'}, inplace=True)

# %%
redlist.head()
# Out:
#   Food Code                 Food Name Food sub-group codes  \
# 0    17-208  beer bitter best premium                   QA
# 1    17-224               cider sweet                   QC
# 2    17-234                      port                   QF
# 3    17-236             sherry medium                   QF
# 4    17-247        spirits 40% volume                   QK
#
#             Food Group                                  Sales Format
# 0  Alcoholic beverages  can, can multipack, bottle, bottle multipack
# 1  Alcoholic beverages  can, can multipack, bottle, bottle multipack
# 2  Alcoholic beverages                                        bottle
# 3  Alcoholic beverages                                        bottle
# 4  Alcoholic beverages                             bottle, miniature

# %%
# Create a set of values from fFood['Matches'] column
Food_matched = set(fFood['Food Name'])

# Filter out rows from reduce where the Food Name is in fFood_matches
redunmatched = redlist[~redlist['Food Name'].isin(Food_matched)]

# %%
redunmatched.count()
# Out:
# Food Code               315
# Food Name               376
# Food sub-group codes    376
# Food Group              376
# Sales Format            234
# dtype: int64

# %%
gfood = pd.concat([fFood,redunmatched], ignore_index=True)

# %%
# Convert the 'Food Name' column to lowercase for case-insensitive comparison
gfood['Food Name'] = gfood['Food Name'].str.lower()

# Define a function to find similar food names using fuzzy matching
def find_similar_names(name, name_list, threshold=90):
    similar_names = process.extract(name, name_list, scorer=fuzz.token_sort_ratio)
    return [s[0] for s in similar_names if s[1] >= threshold]

# Create a list of unique normalized food names
unique_normalized_names = gfood['Food Name'].apply(normalize_food_name).unique()

# Identify similar names with extra words attached
similar_names = []
for name in unique_normalized_names:
    similar_names.extend(find_similar_names(name, unique_normalized_names))

similar_names = list(set(similar_names))  # Remove duplicates from the list

# %%
dp = gfood[~gfood['Food Name'].isin(similar_names)]

# %%
dp#['Food Group'].value_counts().sum()
# Out:
#     Food Code                                          Food Name  \
# 0      13-145                             ackee, canned, drained
# 1      13-146                                        agar, dried
# 2      13-148                               alfalfa sprouts, raw
# 3      14-896                             almonds, whole kernels
# 4      13-149                               amaranth leaves, raw
# 5      17-851                              apple sauce, homemade
# 6      14-016                              apples, eating, dried
# 7      14-031                                    apricots, dried
# 9      13-153                              artichoke, globe, raw
# 10     13-157                                     asparagus, raw
# 11     13-161                                     aubergine, raw
# 12     16-169                                         bacha, raw
# 13     19-497                           bacon rashers, back, raw
# 14     11-970                                      bagels, plain
# 15     12-500  baking fat and margarine (75-90% fat), hard block
# 16     17-355                                      baking powder
# 17     11-002                                 barley, pearl, raw
# 18     13-805                               basil, dried, ground
# 19     13-804                                       basil, fresh
# 20     13-070                          beans, butter, dried, raw
# 21     13-514                                  beans, green, raw
# 22     17-514                                       beef extract
# 23     18-006                    beef, braising steak, raw, lean
# 24     18-016                      beef, fillet steak, raw, lean
# 25     18-469                                   beef, mince, raw
# 26     13-164                                      beetroot, raw
# 27     13-807                                betel leaves, fresh
# 28     11-815        biscuits, cookies, chocolate chip, standard
# 29     11-799                         biscuits, digestive, plain
# 30     11-809              biscuits, fully coated with chocolate
# 31     11-808                                     biscuits, iced
# 32     11-804                               biscuits, jam filled
# 33     11-796                             biscuits, short, sweet
# 34     14-388                                  blackberries, raw
# 35     14-053                                 blackcurrants, raw
# 36     11-986                             bread rolls, wholemeal
# 37     11-969                                    bread, ciabatta
# 38     11-973                                bread, naan, retail
# 39     11-974                                bread, pitta, white
# 40     11-947                                      bread, seeded
# 41     11-980                               bread, white, sliced
# 42     13-502                               broccoli, green, raw
# 43     13-177                              brussels sprouts, raw
# 44     17-685                                     butter, salted
# 45     17-655                    butter, spreadable (75-80% fat)
# 46     13-190                                  cabbage, red, raw
# 47     11-740                               cake bars, chocolate
# 48     11-527                              cake, chocolate fudge
# 49     11-829                                cake, fruit, retail
# 50     11-956                             cake, sponge, homemade
# 51     13-496                                  carrots, old, raw
# 52     13-512                                   cauliflower, raw
# 53     13-636                                        celery, raw
# 54     12-548               cheese, cheddar type, '30% less fat'
# 55     12-346                           cheese, cheddar, english
# 56     12-355                                       cheese, edam
# 57     12-525                                       cheese, feta
# 58     12-496                                   cheese, halloumi
# 59     12-360                          cheese, mozzarella, fresh
# 60     12-526                            cheese, parmesan, fresh
# 61     12-485                              cheese, red leicester
# 62     12-176                                    cheese, ricotta
# 63     12-367                              cheese, stilton, blue
# 64     12-486                             cheese, white cheshire
# 65     19-538                                     chicken slices
# 66     18-289                            chicken, dark meat, raw
# 67     18-290                           chicken, light meat, raw
# 68     18-292                                 chicken, skin, raw
# 69     13-873                                      chilli powder
# 70     17-659                                   chocolate spread
# 71     17-648                                    chocolate, milk
# 72     17-091                                   chocolate, white
# 73     17-224                                       cider, sweet
# 74     14-820                                       coconut milk
# 75     14-873                                coconut, desiccated
# 76     17-158                            coffee, powder, instant
# 77     17-505                                         cola, diet
# 78     19-128                                corned beef, canned
# 79     13-627                                     courgette, raw
# 80     11-901                               couscous, plain, raw
# 81    11-1134                      crackers, wholemeal, homemade
# 82     11-822                                    crispbread, rye
# 84     13-889                                        cumin seeds
# 85     17-720                                        curry paste
# 86     14-087                                  dried mixed fruit
# 87     17-498                         drinking chocolate, powder
# 88     14-395                     figs, ready-to-eat, semi-dried
# 89     16-405                   fish fingers, cod, grilled/baked
# 90     16-450                                         fish paste
# 91     11-888                  flour, wheat, white, self raising
# 92     11-889                            flour, wheat, wholemeal
# 93     17-824                                    fruit pastilles
# 94     13-829                                       garam masala
# 95     13-830                                      garlic powder
# 96     17-640                                       ghee, butter
# 97     13-245                                      gherkins, raw
# 98     13-832                                     ginger, ground
# 99     14-323                                        grapes, red
# 100    16-492                   haddock, flesh only, smoked, raw
# 101    16-183                                   herring, pickled
# 103    17-314                                  horseradish sauce
# 105    17-075                                 jam, reduced sugar
# 106    18-481                                   lamb, mince, raw
# 107    12-373                                   lassi, sweetened
# 108    13-624                                         leeks, raw
# 110    13-657                    lentils, red, split, dried, raw
# 111    13-520                              lettuce, average, raw
# 112    17-777                                 liquorice allsorts
# 113    18-413                                   liver, lamb, raw
# 114    16-414                       mackerel, flesh only, smoked
# 116    13-279                                        matoki, raw
# 117    19-506                                        meat spread
# 118    12-314                            milk, semi-skimmed, uht
# 119    12-554                                 milk, skimmed, uht
# 120    12-320                                   milk, whole, uht
# 121    11-848                                 mince pies, retail
# 123    13-837                                        mint, dried
# 124    13-884                                 mixed herbs, dried
# 125    17-416                                    mushroom, dried
# 126    13-288                     mushrooms, chinese, dried, raw
# 127    13-294                    mushrooms, shiitake, dried, raw
# 128    13-505                              mushrooms, white, raw
# 129    16-497                                       mussels, raw
# 130    13-839                                      mustard seeds
# 131    17-365                                mustard, wholegrain
# 132    11-719                           noodles, egg, dried, raw
# 133    14-880                                        nuts, mixed
# 134    17-031                                       oil, coconut
# 135    17-033                                          oil, corn
# 136    17-038                                         oil, olive
# 137    17-044                                          oil, soya
# 138    17-045                                     oil, sunflower
# 139    17-047                                        oil, walnut
# 140    13-499                                        onions, raw
# 141    17-734                                   ovaltine, powder
# 142    13-844                                     parsley, fresh
# 143    14-285                                passion fruit juice
# 144    11-450                        pasta, plain, fresh, boiled
# 146    11-853                 pastry, shortcrust, retail, cooked
# 147    16-451                                         pate, tuna
# 148    14-892                              peanut butter, smooth
# 149    14-196                                       pears, dried
# 150    13-527                                  peas, frozen, raw
# 151    13-438                                          peas, raw
# 152    13-880                                      pepper, black
# 153    17-622                                       pesto, green
# 154    17-718                                      pickle, sweet
# 155    14-396                                   pineapple, dried
# 156    18-534                    pork, loin chops, grilled, lean
# 157    18-521                       pork, loin steaks, raw, lean
# 158    17-693                             potato crisps, low fat
# 159    13-489                     potatoes, old, raw, flesh only
# 160    16-387                                  prawns, king, raw
# 161    14-391                   prunes, ready-to-eat, semi-dried
# 162    14-842                                      pumpkin seeds
# 163    14-843                                        quinoa, raw
# 164    14-393                                     raisins, dried
# 165    16-131                                       redfish, raw
# 166    11-866                          rice, brown, basmati, raw
# 167    11-870                        rice, brown, easy cook, raw
# 168    11-861                       rice, white, long grain, raw
# 169    13-522                                        rocket, raw
# 170    15-648                                       salad, green
# 171    15-875                                 salad, rice, brown
# 173    16-413                        salmon, smoked (hot-smoked)
# 174    19-656                                sausages, beef, raw
# 175    19-510                                sausages, pork, raw
# 176    15-658                sausages, vegetarian, baked/grilled
# 177    17-835                             scotch broth, homemade
# 178    14-844                                       sesame seeds
# 180    17-698                               soup, lentil, canned
# 181    17-712                            soup, vegetable, canned
# 182    13-521                                 spinach, baby, raw
# 183    17-417                                     spinach, dried
# 184    13-348                                 spring greens, raw
# 185    13-355                             squash, butternut, raw
# 186    14-059                                         star fruit
# 187    14-324                                  strawberries, raw
# 188    17-060                                       sugar, brown
# 189    17-062                                       sugar, icing
# 190    17-063                                       sugar, white
# 192    14-845                                    sunflower seeds
# 193    15-617                                   sushi, vegetable
# 194    13-672                                sweet potato, baked
# 195    13-609                                   sweetcorn, dried
# 196    17-101                                     sweets, boiled
# 197    13-893                                       thyme, fresh
# 198    13-531                                       tomato puree
# 199    13-519                              tomatoes, cherry, raw
# 200    18-423                                  tongue, lamb, raw
# 201    12-408                                       torte, fruit
# 202    11-925                              tortilla, wheat, soft
# 203    17-826                                     treacle, black
# 204    19-543                                      turkey slices
# 205    18-352                                 turkey, whole, raw
# 206    13-861                                   turmeric, ground
# 207    17-377                                   water, distilled
# 208    11-904                                 wheat, bulgur, raw
# 210    17-752                                          wine, red
# 211    17-755                                   wine, white, dry
# 212    17-517                                      yeast extract
# 213    17-379                                       yeast, dried
# 214    12-379                             yogurt, low fat, plain
# 215    17-208                           beer bitter best premium
# 216    17-224                                        cider sweet
# 218    17-236                                      sherry medium
# 219    17-247                                 spirits 40% volume
# 220    17-239                                       vermouth dry
# 221    14-272     apple juice concentrate unsweetened commerical
# 222    17-632                            coffee cappuccino latte
# 224    17-744                        cranberry fruit juice drink
# 225    17-672                            energy drink carbonated
# 226    17-745                            grape juice unsweetened
# 227    17-751                                      lager premium
# 228    17-244                             liqueurs high strength
# 229    17-733                                  milk shake powder
# 230    11-006                                   buckwheat groats
# 231   11-1144                           bread rolls brown crusty
# 232   11-1006                             bread rolls white soft
# 233    11-971                                bread brown average
# 234    11-937                              bread garlic and herb
# 235    11-910              bread naan peshwari naan takeaway and
# 236   11-1145                                bread white average
# 237    11-977                 bread white farmhouse or split tin
# 238    11-978                           bread white french stick
# 239    11-983                             bread rolls brown soft
# 240    11-984                           bread rolls malted wheat
# 241    11-985                           bread rolls white crusty
# 242    11-986                              bread rolls wholemeal
# 243    11-763             breakfast cereal bran flakes fortified
# 244    11-742              breakfast cereal cornflakes fortified
# 245    11-779    breakfast cereal fruit and fibre type fortified
# 246    11-755  breakfast cereal honey loops and hoops includi...
# 247    11-792         breakfast cereal instant hot oat fortified
# 248    11-753  breakfast cereal rice chocolate flavoured fort...
# 249    11-778   breakfast cereal shredded wheat honey nut nestle
# 250    11-773  breakfast cereal wheat biscuits weetabix type ...
# 251    11-821                          biscuits cheese flavoured
# 252    11-809               biscuits fully coated with chocolate
# 254       NaN                                       banana bread
# 255       NaN                      brownies chocolate baking mix
# 256       NaN                           bread and butter pudding
# 257    11-011                                    cornmeal sifted
# 258    11-820                                     cream crackers
# 259    11-839                        cakes fancy iced individual
# 260   11-1020                                      crumble fruit
# 261    11-850                                doughnuts ring iced
# 262    11-849                                 doughnuts with jam
# 264       NaN                                biscuit gingerbread
# 265       NaN                                     hot cross buns
# 266    11-739                                        jaffa cakes
# 267    11-846                                          jam tarts
# 268    11-780                     muesli swiss style unfortified
# 270    11-936                            pizza cheese and tomato
# 271    11-788                          porridge oats unfortified
# 272    11-718                   pasta wholewheat spaghetti dried
# 273    11-735                    pasta spaghetti in tomato sauce
# 275    11-853                           pastry shortcrust cooked
# 276    11-844            pastries chocolate eclairs cream filled
# 278    11-544                                    scotch pancakes
# 279    11-921                      pie apple pastry double crust
# 280    11-847                               pie fruit individual
# 281       NaN                                     pudding sponge
# 282   11-1021                                     pudding sponge
# 283       NaN                                     prawn crackers
# 284    11-874                                 rice thai fragrant
# 288       NaN                               sandwich white bread
# 289       NaN                               sandwich brown bread
# 290    11-544                                    scotch pancakes
# 291    11-919                        strudel fruit filled frozen
# 292    17-371                                 stuffing mix dried
# 293    11-800                 wafers ice cream wafers not filled
# 294       NaN                                  yorkshire pudding
# 295    12-937                                 eggs chicken whole
# 297    17-487                                      dripping beef
# 299    17-686                                        oil average
# 301       NaN                                   anchovies in oil
# 302    16-385                                bass sea flesh only
# 305    16-005                                        bombay duck
# 306    16-372                                     cod flesh only
# 310    16-383                                   coley flesh only
# 312       NaN                                    crab white meat
# 316    16-173                                         eel yellow
# 317    16-070                                    hake flesh only
# 320       NaN                                 kippers flesh only
# 323    16-378                         pollock alaskan flesh only
# 324    14-363  apples cooking flesh only weighed with skin an...
# 325    14-319                       apples eating flesh and skin
# 326    14-025                            apricots flesh and skin
# 327    14-040  avocado fuerte flesh only weighed with skin an...
# 328    14-387  avocado hass flesh only weighed with skin and ...
# 329    14-331              apple juice clear ambient and chilled
# 330    14-043                                  babaco flesh only
# 331    14-318                             bananas flesh and skin
# 333    14-382                            cherries flesh and skin
# 334    14-326     citrus fruit soft/easy peelers flesh with skin
# 337    14-077                             damsons flesh and skin
# 338    14-083                               dates flesh and skin
# 339    14-089                           elderberries whole fruit
# 340    14-100                               gooseberries cooking
# 341    14-384                              grapefruit flesh only
# 342    14-322                                       grapes green
# 343    14-118                                   guava flesh only
# 344    14-371                              kiwi fruit flesh only
# 345    14-373            kiwi fruit flesh only weighed with skin
# 346    14-125                               kumquats whole fruit
# 347    14-128                          lemons whole without pips
# 348    14-131                                   limes flesh only
# 349    14-132                               limes flesh and skin
# 351    14-277                                  lemon juice fresh
# 352    14-378                            mangoes ripe flesh only
# 353    14-379                mangoes weighed with skin and stone
# 354    14-339                   melon canteloupe-type flesh only
# 355    14-353               melon canteloupe-type flesh and skin
# 356    14-356                               melon flesh and skin
# 357    14-168                             mulberries whole fruit
# 358    14-380                          nectarines flesh and skin
# 360    14-327                                 oranges flesh only
# 361    14-360                   oranges flesh with peel and pips
# 362    14-369                      orange juice freshly squeezed
# 363    14-361  pears average flesh and skin weighed with core...
# 364    14-188                    peaches in juice whole contents
# 365    14-321                               pears flesh and skin
# 366    14-377                  pineapple flesh with skin and top
# 367    14-211                  pineapple in juice whole contents
# 368    14-220                      plums victoria flesh and skin
# 369    14-227       pomegranate flesh and pips weighed with skin
# 370    14-179     passion fruit flesh and pips weighed with skin
# 371    14-341                            pomegranate juice drink
# 372    14-227       pomegranate flesh and pips weighed with skin
# 373    14-289                                        prune juice
# 374    14-237                     prunes in juice whole contents
# 375    14-231                              prunes flesh and skin
# 376    14-391                     prunes ready-to-eat semi-dried
# 379    14-252                                 rhubarb stems only
# 381    13-801                                    allspice ground
# 382    13-802                                        anise seeds
# 384    13-808                                      caraway seeds
# 385    13-809                                    cardamom ground
# 386    13-810                                       celery seeds
# 387    13-811                                      chervil dried
# 388    13-813                                    chinese 5 spice
# 389    13-887                                       chives fresh
# 390    13-874                                    cinnamon ground
# 391    13-818                             coriander leaves dried
# 392    13-824                                         dill fresh
# 393    13-890                                       ginger fresh
# 394    13-886                                 mixed curry spices
# 395    13-878                               oregano dried ground
# 398    13-854                                  sage dried ground
# 399    18-024                                         beef flank
# 400    18-468                                       beef average
# 401    18-054                                    beef silverside
# 402    18-064                                 beef sirloin steak
# 403    18-084                                       beef topside
# 404    18-504                  chicken breast/steak coated baked
# 405    18-501                     chicken pieces coated takeaway
# 406    18-488                               chicken meat average
# 407    18-297                        chicken whole meat and skin
# 408    18-295                 chicken wing quarter meat and skin
# 409    18-503                 chicken/turkey pieces coated baked
# 411    19-449                                curry chicken balti
# 412       NaN                                  casserole sausage
# 413    19-466                                      cornish pasty
# 414       NaN                                 coronation chicken
# 415    18-489                                     duck meat only
# 416    19-539                             doner kebabs meat only
# 417       NaN                                enchiladas meal kit
# 420       NaN                    hot pot lamb/beef with potatoes
# 421    18-402                                        kidney lamb
# 422    18-478                               lamb average and fat
# 423    18-111                                        lamb breast
# 424    18-115                           lamb chump chops and fat
# 425    19-326                              meat samosas takeaway
# 426       NaN                         meatballs in tomatoe sauce
# 428    18-609                            pork spare ribs and fat
# 429    18-387                                   rabbit meat only
# 430    18-390                                  venison meat only
# 431    12-333                               cream fresh whipping
# 432    12-357         cheese goats milk full fat soft white rind
# 433    12-549                cheese processed slices reduced fat
# 434    12-507                       cornetto type ice cream cone
# 435    12-542                        cheesecake fruit individual
# 436    12-461                           tarts custard individual
# 437    12-508                 ice cream dairy vanilla soft scoop
# 438    12-509             ice cream non dairy vanilla soft scoop
# 440    12-390                       lollies containing ice-cream
# 441    12-389                      lollies with real fruit juice
# 442    12-512                            milk 1% fat pasteurised
# 443    12-322                  milk channel islands whole summer
# 444    12-313              milk semi-skimmed pasteurised average
# 445    12-596                     milk whole pasteurised average
# 446    12-520                     milk condensed whole sweetened
# 447    12-522                              milk evaporated whole
# 448    12-524  milk soya non-dairy alternative to milk unswee...
# 449    12-401                           mousse chocolate low fat
# 451    12-555                                 yogurt greek style
# 452    12-375                            yogurt whole milk fruit
# 453    14-870                          almonds flaked and ground
# 454    14-897                                    almonds toasted
# 455    14-895                               breadnut seeds dried
# 456    14-806                                         betel nuts
# 457    14-813                              chestnuts kernel only
# 458    14-874                              hazelnuts kernel only
# 459    14-891                              macadamia nuts salted
# 460    14-875                          marzipan white and yellow
# 461    14-882                                peanuts and raisins
# 462    14-840      pistachio nuts kernel only roasted and salted
# 463    14-879                                walnuts kernel only
# 464    17-705                                     barbecue sauce
# 465    17-697          chicken soup cream of condensed as served
# 466    17-719                                       chilli sauce
# 467    17-345                                     chutney tomato
# 468    17-358                                    cream of tartar
# 469    17-701                                    dressing french
# 470    17-717                           dressing thousand island
# 473    17-724                             gravy instant granules
# 474       NaN                                  hollandaise sauce
# 475       NaN                            hollandaise sauce vegan
# 476    17-654                                mayonnaise standard
# 477    17-364                                     mustard smooth
# 479    17-354                                relish tomato based
# 480    17-711                                    soup minestrone
# 481    17-695                              soup chicken cream of
# 482    17-652                               soup cream of tomato
# 483    17-700                                        soup oxtail
# 485    17-653                    soup instant dried as purchased
# 486    17-628                 sauce chinese cook in sweet & sour
# 487    17-629                             sauce chinese stir fry
# 488    17-721                 soy sauce light and dark varieties
# 490    17-515                                   stock cubes beef
# 491    17-681                           stock chicken ready made
# 493       NaN                                        white sauce
# 494       NaN                                  white sauce vegan
# 495    17-723                               worcestershire sauce
# 496    17-658      chocolate covered bar with caramel and cereal
# 497    17-763                                          creme egg
# 498    17-645                                        corn snacks
# 499       NaN                               chevda/chevra/chewra
# 500    17-049                                  glucose liquid bp
# 501    17-689  ice cream sauce topping strawberry and chocola...
# 502    17-651                     maltesers and similar products
# 503    17-668                 mars bar and own brand equivalents
# 504    17-669                milky way and own brand equivalents
# 508    17-132                                   pork scratchings
# 509    17-065                                       syrup golden
# 510    17-096                                smartie-type sweets
# 513       NaN                                      artichoke jar
# 514    13-532                        baked beans in tomato sauce
# 515    13-041                            beans aduki whole dried
# 516       NaN                                        beans aduki
# 517    13-062                         beans blackeye whole dried
# 518       NaN                                     beans blackeye
# 519       NaN                                       beans butter
# 520    13-074                beans chick peas kabuli whole dried
# 521       NaN                                   beans chick peas
# 522    13-080                                      beans cluster
# 523       NaN                               beans edamame frozen
# 524       NaN                                      beans edamame
# 525    13-086                          beans haricot whole dried
# 526       NaN                                      beans haricot
# 527    13-098                              beans mung dahl dried
# 528    13-102                      beans pigeon peas whole dried
# 529       NaN                                        beans pinto
# 530    13-109                             beans red kidney dried
# 531       NaN                                   beans red kidney
# 532    13-112                                       beans runner
# 533    13-115                                   beans soya dried
# 534    13-117                                        beans sword
# 535    13-426                                   beansprouts mung
# 536    13-056                   black gram urad gram whole dried
# 538    13-174                          broccoli purple sprouting
# 540    13-067                                  beans broad dried
# 541    13-064                      beans broad whole without pod
# 542       NaN                                   beans cannellini
# 543    13-582                                    cabbage average
# 544    13-187                                    cabbage chinese
# 545    13-510                                      cabbage green
# 547    13-223                                        chard swiss
# 548    13-225                               chicory pale variety
# 549    13-234                                         curly kale
# 551    15-637                                 cauliflower cheese
# 552    15-635                           coleslaw not low calorie
# 553       NaN                                        curry mixed
# 555    13-608                                  green beans dried
# 556       NaN                               green beans in water
# 557    13-261                                          kohl rabi
# 559    13-089                lentils green and brown whole dried
# 561    13-520                                    lettuce average
# 562    13-271                                       lotus tubers
# 564    13-298                                     mustard leaves
# 568       NaN                                       potato chips
# 569       NaN                                      potato wedges
# 570       NaN                                      peas in water
# 571       NaN                                           pak choi
# 572    13-311                          papaya unripe green flesh
# 574    13-524                                pepper capsicum red
# 575    13-323                               plantain green flesh
# 576    13-326                                 pumpkin flesh only
# 577    15-262                                        quorn korma
# 578    13-332                                      radish leaves
# 579    13-359                                   swede flesh only
# 580       NaN                               swede flesh and skin
# 581    13-622                                  sweetcorn kernels
# 582       NaN                                 sweetcorn on a cob
# 583    15-872              salad pasta vegetables and mayonnaise
# 584    15-883                                     shepherd's pie
# 586       NaN                            vegetables mixed frozen
# 587    15-656                                 vegeburger grilled
# 589    13-397                                     yam flesh only
# 590    13-530                   tomatoes, canned, whole contents
#
#     Food sub-group codes                             Food Group  \
# 0                     DG                             Vegetables
# 1                     DG                             Vegetables
# 2                     DG                             Vegetables
# 3                     GA                         Nuts and seeds
# 4                     DG                             Vegetables
# 5                     WC  Soups, sauces and miscellaneous foods
# 6                     FA                                  Fruit
# 7                     FA                                  Fruit
# 9                     DG                             Vegetables
# 10                    DG                             Vegetables
# 11                    DG                             Vegetables
# 12                    JC                 Fish and fish products
# 13                   MAA                 Meat and meat products
# 14                    AP            Cereals and cereal products
# 15                   BTM                 Milk and milk products
# 16                    WY  Soups, sauces and miscellaneous foods
# 17                    AA            Cereals and cereal products
# 18                     H                       Herbs and spices
# 19                     H                       Herbs and spices
# 20                    DB                             Vegetables
# 21                    DB                             Vegetables
# 22                    WY  Soups, sauces and miscellaneous foods
# 23                   MAC                 Meat and meat products
# 24                   MAC                 Meat and meat products
# 25                   MAC                 Meat and meat products
# 26                    DG                             Vegetables
# 27                     H                       Herbs and spices
# 28                    AM            Cereals and cereal products
# 29                    AM            Cereals and cereal products
# 30                    AM            Cereals and cereal products
# 31                    AM            Cereals and cereal products
# 32                    AM            Cereals and cereal products
# 33                    AM            Cereals and cereal products
# 34                    FA                                  Fruit
# 35                    FA                                  Fruit
# 36                    AG            Cereals and cereal products
# 37                    AF            Cereals and cereal products
# 38                    AF            Cereals and cereal products
# 39                    AF            Cereals and cereal products
# 40                    AF            Cereals and cereal products
# 41                    AF            Cereals and cereal products
# 42                    DG                             Vegetables
# 43                    DG                             Vegetables
# 44                    OA                          Fats and oils
# 45                    OA                          Fats and oils
# 46                    DG                             Vegetables
# 47                    AN            Cereals and cereal products
# 48                    AN            Cereals and cereal products
# 49                    AN            Cereals and cereal products
# 50                    AN            Cereals and cereal products
# 51                    DG                             Vegetables
# 52                    DG                             Vegetables
# 53                    DG                             Vegetables
# 54                    BL                 Milk and milk products
# 55                    BL                 Milk and milk products
# 56                    BL                 Milk and milk products
# 57                    BL                 Milk and milk products
# 58                    BL                 Milk and milk products
# 59                    BL                 Milk and milk products
# 60                    BL                 Milk and milk products
# 61                    BL                 Milk and milk products
# 62                    BL                 Milk and milk products
# 63                    BL                 Milk and milk products
# 64                    BL                 Milk and milk products
# 65                    MI                 Meat and meat products
# 66                   MCA                 Meat and meat products
# 67                   MCA                 Meat and meat products
# 68                   MCA                 Meat and meat products
# 69                     H                       Herbs and spices
# 70                    SC           Sugars, preserves and snacks
# 71                   SEA           Sugars, preserves and snacks
# 72                   SEA           Sugars, preserves and snacks
# 73                    QC                    Alcoholic beverages
# 74                    GA                         Nuts and seeds
# 75                    GA                         Nuts and seeds
# 76                   PAA                              Beverages
# 77                   PCA                              Beverages
# 78                    MI                 Meat and meat products
# 79                    DG                             Vegetables
# 80                    AT            Cereals and cereal products
# 81                    AM            Cereals and cereal products
# 82                    AM            Cereals and cereal products
# 84                     H                       Herbs and spices
# 85                    WC  Soups, sauces and miscellaneous foods
# 86                    FA                                  Fruit
# 87                   PAA                              Beverages
# 88                    FA                                  Fruit
# 89                    JR                 Fish and fish products
# 90                    JR                 Fish and fish products
# 91                    AA            Cereals and cereal products
# 92                    AA            Cereals and cereal products
# 93                   SEC           Sugars, preserves and snacks
# 94                     H                       Herbs and spices
# 95                     H                       Herbs and spices
# 96                    OF                 Meat and meat products
# 97                    DG                             Vegetables
# 98                     H                       Herbs and spices
# 99                    FA                                  Fruit
# 100                   JA                 Fish and fish products
# 101                   JC                 Fish and fish products
# 103                  WCN  Soups, sauces and miscellaneous foods
# 105                   SC           Sugars, preserves and snacks
# 106                  MAE                 Meat and meat products
# 107                   BN                 Milk and milk products
# 108                   DG                             Vegetables
# 110                   DB                             Vegetables
# 111                   DG                             Vegetables
# 112                  SEC           Sugars, preserves and snacks
# 113                   MG                 Meat and meat products
# 114                   JC                 Fish and fish products
# 116                   DG                             Vegetables
# 117                   MI                 Meat and meat products
# 118                  BAH                 Milk and milk products
# 119                  BAE                 Milk and milk products
# 120                  BAK                 Milk and milk products
# 121                   AS            Cereals and cereal products
# 123                    H                       Herbs and spices
# 124                    H                       Herbs and spices
# 125                   DI                             Vegetables
# 126                   DG                             Vegetables
# 127                   DG                             Vegetables
# 128                   DG                             Vegetables
# 129                   JM                 Fish and fish products
# 130                    H                       Herbs and spices
# 131                   WY  Soups, sauces and miscellaneous foods
# 132                   AD            Cereals and cereal products
# 133                   GA                         Nuts and seeds
# 134                   OC                          Fats and oils
# 135                   OC                          Fats and oils
# 136                   OC                          Fats and oils
# 137                   OC                          Fats and oils
# 138                   OC                          Fats and oils
# 139                   OC                          Fats and oils
# 140                   DG                             Vegetables
# 141                  PAA                              Beverages
# 142                    H                       Herbs and spices
# 143                   FC                                  Fruit
# 144                   AD            Cereals and cereal products
# 146                   AO            Cereals and cereal products
# 147                   JR                 Fish and fish products
# 148                   GA                         Nuts and seeds
# 149                   FA                                  Fruit
# 150                   DF                             Vegetables
# 151                   DF                             Vegetables
# 152                    H                       Herbs and spices
# 153                   WC  Soups, sauces and miscellaneous foods
# 154                  WCG  Soups, sauces and miscellaneous foods
# 155                   FA                                  Fruit
# 156                  MAG                 Meat and meat products
# 157                  MAG                 Meat and meat products
# 158                   SN           Sugars, preserves and snacks
# 159                  DAM                             Vegetables
# 160                   JK                 Fish and fish products
# 161                   FA                                  Fruit
# 162                   GA                         Nuts and seeds
# 163                   GA                         Nuts and seeds
# 164                   FA                                  Fruit
# 165                   JA                 Fish and fish products
# 166                   AC            Cereals and cereal products
# 167                   AC            Cereals and cereal products
# 168                   AC            Cereals and cereal products
# 169                   DG                             Vegetables
# 170                   DR                             Vegetables
# 171                   DR                             Vegetables
# 173                   JC                 Fish and fish products
# 174                   MI                 Meat and meat products
# 175                   MI                 Meat and meat products
# 176                   DR                             Vegetables
# 177                  WAA  Soups, sauces and miscellaneous foods
# 178                   GA                         Nuts and seeds
# 180                  WAC  Soups, sauces and miscellaneous foods
# 181                  WAC  Soups, sauces and miscellaneous foods
# 182                   DG                             Vegetables
# 183                   DI                             Vegetables
# 184                   DG                             Vegetables
# 185                   DG                             Vegetables
# 186                   FA                                  Fruit
# 187                   FA                                  Fruit
# 188                   SC           Sugars, preserves and snacks
# 189                   SC           Sugars, preserves and snacks
# 190                   SC           Sugars, preserves and snacks
# 192                   GA                         Nuts and seeds
# 193                   DR                             Vegetables
# 194                   DG                             Vegetables
# 195                   DI                             Vegetables
# 196                  SEC           Sugars, preserves and snacks
# 197                    H                       Herbs and spices
# 198                   DG                             Vegetables
# 199                   DG                             Vegetables
# 200                   MG                 Meat and meat products
# 201                   BR                 Milk and milk products
# 202                   AF            Cereals and cereal products
# 203                   SC           Sugars, preserves and snacks
# 204                   MI                 Meat and meat products
# 205                  MCO                 Meat and meat products
# ...
# 245          breakfastcerealfruitandfibretypefortified
# 246  breakfastcerealhoneyloopsandhoopsincludinghone...
# 247              breakfastcerealinstanthotoatfortified
# 248     breakfastcerealricechocolateflavouredfortified
# 249         breakfastcerealshreddedwheathoneynutnestle
# 250  breakfastcerealwheatbiscuitsweetabixtypefortified
# 251                            biscuitscheeseflavoured
# 252                   biscuitsfullycoatedwithchocolate
# 254                                        bananabread
# 255                         brownieschocolatebakingmix
# 256                              breadandbutterpudding
# 257                                     cornmealsifted
# 258                                      creamcrackers
# 259                           cakesfancyicedindividual
# 260                                       crumblefruit
# 261                                  doughnutsringiced
# 262                                   doughnutswithjam
# 264                                 biscuitgingerbread
# 265                                       hotcrossbuns
# 266                                         jaffacakes
# 267                                           jamtarts
# 268                        muesliswissstyleunfortified
# 270                               pizzacheeseandtomato
# 271                            porridgeoatsunfortified
# 272                      pastawholewheatspaghettidried
# 273                        pastaspaghettiintomatosauce
# 275                             pastryshortcrustcooked
# 276                pastrieschocolateeclairscreamfilled
# 278                                     scotchpancakes
# 279                          pieapplepastrydoublecrust
# 280                                 piefruitindividual
# 281                                      puddingsponge
# 282                                      puddingsponge
# 283                                      prawncrackers
# 284                                   ricethaifragrant
# 288                                 sandwichwhitebread
# 289                                 sandwichbrownbread
# 290                                     scotchpancakes
# 291                           strudelfruitfilledfrozen
# 292                                   stuffingmixdried
# 293                      wafersicecreamwafersnotfilled
# 294                                   yorkshirepudding
# 295                                   eggschickenwhole
# 297                                       drippingbeef
# 299                                         oilaverage
# 301                                     anchoviesinoil
# 302                                   bassseafleshonly
# 305                                         bombayduck
# 306                                       codfleshonly
# 310                                     coleyfleshonly
# 312                                      crabwhitemeat
# 316                                          eelyellow
# 317                                      hakefleshonly
# 320                                   kippersfleshonly
# 323                            pollockalaskanfleshonly
# 324       applescookingfleshonlyweighedwithskinandcore
# 325                           appleseatingfleshandskin
# 326                               apricotsfleshandskin
# 327      avocadofuertefleshonlyweighedwithskinandstone
# 328        avocadohassfleshonlyweighedwithskinandstone
# 329                   applejuiceclearambientandchilled
# 330                                    babacofleshonly
# 331                                bananasfleshandskin
# 333                               cherriesfleshandskin
# 334            citrusfruitsofteasypeelersfleshwithskin
# 337                                damsonsfleshandskin
# 338                                  datesfleshandskin
# 339                             elderberrieswholefruit
# 340                                gooseberriescooking
# 341                                grapefruitfleshonly
# 342                                        grapesgreen
# 343                                     guavafleshonly
# 344                                 kiwifruitfleshonly
# 345                  kiwifruitfleshonlyweighedwithskin
# 346                                 kumquatswholefruit
# 347                             lemonswholewithoutpips
# 348                                     limesfleshonly
# 349                                  limesfleshandskin
# 351                                    lemonjuicefresh
# 352                               mangoesripefleshonly
# 353                     mangoesweighedwithskinandstone
# 354                       meloncanteloupetypefleshonly
# 355                    meloncanteloupetypefleshandskin
# 356                                  melonfleshandskin
# 357                               mulberrieswholefruit
# 358                             nectarinesfleshandskin
# 360                                   orangesfleshonly
# 361                        orangesfleshwithpeelandpips
# 362                         orangejuicefreshlysqueezed
# 363    pearsaveragefleshandskinweighedwithcoreandstalk
# 364                        peachesinjuicewholecontents
# 365                                  pearsfleshandskin
# 366                       pineapplefleshwithskinandtop
# 367                      pineappleinjuicewholecontents
# 368                          plumsvictoriafleshandskin
# 369             pomegranatefleshandpipsweighedwithskin
# 370            passionfruitfleshandpipsweighedwithskin
# 371                              pomegranatejuicedrink
# 372             pomegranatefleshandpipsweighedwithskin
# 373                                         prunejuice
# 374                         prunesinjuicewholecontents
# 375                                 prunesfleshandskin
# 376                          prunesreadytoeatsemidried
# 379                                   rhubarbstemsonly
# 381                                     allspiceground
# 382                                         aniseseeds
# 384                                       carawayseeds
# 385                                     cardamomground
# 386                                        celeryseeds
# 387                                       chervildried
# 388                                      chinese5spice
# 389                                        chivesfresh
# 390                                     cinnamonground
# 391                               corianderleavesdried
# 392                                          dillfresh
# 393                                        gingerfresh
# 394                                   mixedcurryspices
# 395                                 oreganodriedground
# 398                                    sagedriedground
# 399                                          beefflank
# 400                                        beefaverage
# 401                                     beefsilverside
# 402                                   beefsirloinsteak
# 403                                        beeftopside
# 404                      chickenbreaststeakcoatedbaked
# 405                        chickenpiecescoatedtakeaway
# 406                                 chickenmeataverage
# 407                            chickenwholemeatandskin
# 408                      chickenwingquartermeatandskin
# 409                     chickenturkeypiecescoatedbaked
# 411                                  currychickenbalti
# 412                                   casserolesausage
# 413                                       cornishpasty
# 414                                  coronationchicken
# 415                                       duckmeatonly
# 416                                donerkebabsmeatonly
# 417                                  enchiladasmealkit
# 420                         hotpotlambbeefwithpotatoes
# 421                                         kidneylamb
# 422                                  lambaverageandfat
# 423                                         lambbreast
# 424                               lambchumpchopsandfat
# 425                                meatsamosastakeaway
# 426                            meatballsintomatoesauce
# 428                                porkspareribsandfat
# 429                                     rabbitmeatonly
# 430                                    venisonmeatonly
# 431                                 creamfreshwhipping
# 432                cheesegoatsmilkfullfatsoftwhiterind
# 433                    cheeseprocessedslicesreducedfat
# 434                           cornettotypeicecreamcone
# 435                          cheesecakefruitindividual
# 436                             tartscustardindividual
# 437                      icecreamdairyvanillasoftscoop
# 438                   icecreamnondairyvanillasoftscoop
# 440                          lolliescontainingicecream
# 441                          lollieswithrealfruitjuice
# 442                                milk1fatpasteurised
# 443                      milkchannelislandswholesummer
# 444                  milksemiskimmedpasteurisedaverage
# 445                        milkwholepasteurisedaverage
# 446                        milkcondensedwholesweetened
# 447                                milkevaporatedwhole
# 448  milksoyanondairyalternativetomilkunsweetenedfo...
# 449                              moussechocolatelowfat
# 451                                   yogurtgreekstyle
# 452                               yogurtwholemilkfruit
# 453                             almondsflakedandground
# 454                                     almondstoasted
# 455                                 breadnutseedsdried
# 456                                          betelnuts
# 457                                chestnutskernelonly
# 458                                hazelnutskernelonly
# 459                                macadamianutssalted
# 460                             marzipanwhiteandyellow
# 461                                  peanutsandraisins
# 462            pistachionutskernelonlyroastedandsalted
# 463                                  walnutskernelonly
# 464                                      barbecuesauce
# 465                chickensoupcreamofcondensedasserved
# 466                                        chillisauce
# 467                                      chutneytomato
# 468                                      creamoftartar
# 469                                     dressingfrench
# 470                             dressingthousandisland
# 473                               gravyinstantgranules
# 474                                   hollandaisesauce
# 475                              hollandaisesaucevegan
# 476                                 mayonnaisestandard
# 477                                      mustardsmooth
# 479                                  relishtomatobased
# 480                                     soupminestrone
# 481                                 soupchickencreamof
# 482                                  soupcreamoftomato
# 483                                         soupoxtail
# 485                        soupinstantdriedaspurchased
# 486                        saucechinesecookinsweetsour
# 487                                saucechinesestirfry
# 488                      soysaucelightanddarkvarieties
# 490                                     stockcubesbeef
# 491                              stockchickenreadymade
# 493                                         whitesauce
# 494                                    whitesaucevegan
# 495                                worcestershiresauce
# 496            chocolatecoveredbarwithcaramelandcereal
# 497                                           cremeegg
# 498                                         cornsnacks
# 499                                 chevdachevrachewra
# 500                                    glucoseliquidbp
# 501  icecreamsaucetoppingstrawberryandchocolateflav...
# 502                        maltesersandsimilarproducts
# 503                      marsbarandownbrandequivalents
# 504                     milkywayandownbrandequivalents
# 508                                    porkscratchings
# 509                                        syrupgolden
# 510                                  smartietypesweets
# 513                                       artichokejar
# 514                            bakedbeansintomatosauce
# 515                               beansadukiwholedried
# 516                                         beansaduki
# 517                            beansblackeyewholedried
# 518                                      beansblackeye
# 519                                        beansbutter
# 520                     beanschickpeaskabuliwholedried
# 521                                     beanschickpeas
# 522                                       beanscluster
# 523                                 beansedamamefrozen
# 524                                       beansedamame
# 525                             beansharicotwholedried
# 526                                       beansharicot
# 527                                 beansmungdahldried
# 528                          beanspigeonpeaswholedried
# 529                                         beanspinto
# 530                                beansredkidneydried
# 531                                     beansredkidney
# 532                                        beansrunner
# 533                                     beanssoyadried
# 534                                         beanssword
# 535                                    beansproutsmung
# 536                        blackgramuradgramwholedried
# 538                            broccolipurplesprouting
# 540                                    beansbroaddried
# 541                          beansbroadwholewithoutpod
# 542                                    beanscannellini
# 543                                     cabbageaverage
# 544                                     cabbagechinese
# 545                                       cabbagegreen
# 547                                         chardswiss
# 548                                 chicorypalevariety
# 549                                          curlykale
# 551                                  cauliflowercheese
# 552                              coleslawnotlowcalorie
# 553                                         currymixed
# 555                                    greenbeansdried
# 556                                  greenbeansinwater
# 557                                           kohlrabi
# 559                     lentilsgreenandbrownwholedried
# 561                                     lettuceaverage
# 562                                        lotustubers
# 564                                      mustardleaves
# 568                                        potatochips
# 569                                       potatowedges
# 570                                        peasinwater
# 571                                            pakchoi
# 572                             papayaunripegreenflesh
# 574                                  peppercapsicumred
# 575                                 plantaingreenflesh
# 576                                   pumpkinfleshonly
# 577                                         quornkorma
# 578                                       radishleaves
# 579                                     swedefleshonly
# 580                                  swedefleshandskin
# 581                                   sweetcornkernels
# 582                                    sweetcornonacob
# 583                  saladpastavegetablesandmayonnaise
# 584                                       shepherdspie
# 586                              vegetablesmixedfrozen
# 587                                  vegeburgergrilled
# 589                                       yamfleshonly
# 590                        tomatoescannedwholecontents

# %% [markdown]
#                                                             Export

# %%
#dp.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\MW_DataReduction\Reduced Total\Updated3_RedLab2021.csv')
