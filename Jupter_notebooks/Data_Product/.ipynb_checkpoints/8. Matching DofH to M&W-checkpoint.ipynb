# %% [markdown]
# # Matching Department of Health data (2011) to M&W

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re #regular expressions 
from fuzzywuzzy import process, fuzz
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os 
import glob

# %% [markdown]
# ###### Read in Data

# %% [markdown]
#                                                            M&W Data

# %%
pd.set_option('display.max_rows', None)
redFood = pd.read_csv(r"C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\ReducedwithWeights\dataproduct3.csv", index_col=0)
redFood.rename(columns={'Similarity Score':'Similarity Score_FPS','Weight':'Weight_FPS','Portion Consumed':'Portion Consumed_FPS'}, inplace=True)
redFood.drop(['Source','PurEqualCon'], axis=1, inplace=True)
redFood['Food Name'] = redFood['Food Name'].str.lower()
redFood.head()
# Out:
#   Food Code                 Food Name Food sub-group codes  \
# 0    17-208  beer bitter best premium                   QA
# 1    17-224               cider sweet                   QC
# 2    17-234                      port                   QF
# 3    17-236             sherry medium                   QF
# 4    17-247        spirits 40% volume                   QK
#
#             Food Group                                Sale format(s)  \
# 0  Alcoholic beverages  can, can multipack, bottle, bottle multipack
# 1  Alcoholic beverages  can, can multipack, bottle, bottle multipack
# 2  Alcoholic beverages                                        bottle
# 3  Alcoholic beverages                                        bottle
# 4  Alcoholic beverages                             bottle, miniature
#
#    Similarity Score_FPS Weight_FPS Portion Consumed_FPS
# 0              0.601799        NaN                  NaN
# 1              0.000000        NaN                  NaN
# 2              0.000000        NaN                  NaN
# 3              0.792070       200g               medium
# 4              0.707107        29g          1 miniature

# %%
redFood['Food Name'] = redFood['Food Name'].str.replace(r'\bdrained\b', '', case=False).str.strip()
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27336\2182989439.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   redFood['Food Name'] = redFood['Food Name'].str.replace(r'\bdrained\b', '', case=False).str.strip()

# %%
redFood['Food Name'] = redFood['Food Name'].str.replace(r'\braw\b', '', case=False).str.strip()
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27336\3194073488.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   redFood['Food Name'] = redFood['Food Name'].str.replace(r'\braw\b', '', case=False).str.strip()

# %%
redFood['Food Name'] = redFood['Food Name'].str.replace(r'\bcanned\b', '', case=False).str.strip()
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27336\2870357712.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   redFood['Food Name'] = redFood['Food Name'].str.replace(r'\bcanned\b', '', case=False).str.strip()

# %%
redFood['Food Name'] = redFood['Food Name'].str.replace(r'\bflesh and skin\b', '', case=False).str.strip()
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27336\2474732052.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   redFood['Food Name'] = redFood['Food Name'].str.replace(r'\bflesh and skin\b', '', case=False).str.strip()

# %%
redFood['Food Name'] = redFood['Food Name'].str.replace(r'\bflesh only\b', '', case=False).str.strip()
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27336\80545494.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   redFood['Food Name'] = redFood['Food Name'].str.replace(r'\bflesh only\b', '', case=False).str.strip()

# %%
# Remove commas from 'Food Name' column
redFood['Food Name'] = redFood['Food Name'].str.replace(',', '').str.strip()

# %% [markdown]
#                                                 Fruit and Vegetables

# %%
fv = redFood[redFood['Food Group'].str.contains('Fruit|Vegetables')]
fv['Food Group'] = fv['Food Group'].fillna('')
fv['Weight_FPS'] = fv['Weight_FPS'].fillna('')
fv['Portion Consumed_FPS'] = fv['Portion Consumed_FPS'].fillna('')
fv
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27336\584547891.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fv['Food Group'] = fv['Food Group'].fillna('')
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27336\584547891.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fv['Weight_FPS'] = fv['Weight_FPS'].fillna('')
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27336\584547891.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fv['Portion Consumed_FPS'] = fv['Portion Consumed_FPS'].fillna('')
#     Food Code                                       Food Name  \
# 153    14-363      apples cooking  weighed with skin and core
# 154    14-319                                   apples eating
# 155    14-001                                            amla
# 156    14-025                                        apricots
# 157    14-392                apricots ready-to-eat semi-dried
# 158    14-040     avocado fuerte  weighed with skin and stone
# 159    14-387       avocado hass  weighed with skin and stone
# 160    14-331           apple juice clear ambient and chilled
# 161    14-043                                          babaco
# 162    14-318                                         bananas
# 163    14-388                                    blackberries
# 164    14-053                                   blackcurrants
# 165    14-325                                     blueberries
# 166    14-382                                        cherries
# 167    14-326  citrus fruit soft/easy peelers flesh with skin
# 168    14-073                                     cranberries
# 169    14-074                                        currants
# 170    14-077                                         damsons
# 171    14-083                                           dates
# 172    14-087                               dried mixed fruit
# 173    14-089                        elderberries whole fruit
# 174    14-100                            gooseberries cooking
# 175    14-384                                      grapefruit
# 176    14-322                                    grapes green
# 177    14-118                                           guava
# 178    14-371                                      kiwi fruit
# 179    14-373                   kiwi fruit  weighed with skin
# 180    14-125                            kumquats whole fruit
# 181    14-128                       lemons whole without pips
# 182    14-131                                           limes
# 183    14-132                                           limes
# 184    14-133                                    loganberries
# 185    14-277                               lemon juice fresh
# 186    14-378                                    mangoes ripe
# 187    14-379             mangoes weighed with skin and stone
# 188    14-339                           melon canteloupe-type
# 189    14-353                           melon canteloupe-type
# 190    14-356                                           melon
# 191    14-168                          mulberries whole fruit
# 192    14-380                                      nectarines
# 193       NaN                                          olives
# 194    14-327                                         oranges
# 195    14-360                oranges flesh with peel and pips
# 196    14-369                   orange juice freshly squeezed
# 197    14-361      pears average  weighed with core and stalk
# 198    14-188                 peaches in juice whole contents
# 199    14-321                                           pears
# 200    14-376                                       pineapple
# 201    14-377               pineapple flesh with skin and top
# 202    14-211               pineapple in juice whole contents
# 203    14-396                                 pineapple dried
# 204    14-220                                  plums victoria
# 205    14-227    pomegranate flesh and pips weighed with skin
# 206    14-285                             passion fruit juice
# 207    14-179  passion fruit flesh and pips weighed with skin
# 208    14-341                         pomegranate juice drink
# 209    14-227    pomegranate flesh and pips weighed with skin
# 210    14-289                                     prune juice
# 211    14-237                  prunes in juice whole contents
# 212    14-231                                          prunes
# 213    14-391                  prunes ready-to-eat semi-dried
# 214    14-393                                   raisins dried
# 215    14-375                                     raspberries
# 216    14-249                                     redcurrants
# 217    14-252                              rhubarb stems only
# 218    14-059                                      star fruit
# 219    14-324                                    strawberries
# 220    14-268                                   whitecurrants
# 421       NaN                                           ackee
# 422    13-146                                      agar dried
# 423    13-148                                 alfalfa sprouts
# 424    13-149                                 amaranth leaves
# 425    13-151                                       arrowhead
# 426    13-153                                 artichoke globe
# 427       NaN                                       artichoke
# 428       NaN                                   artichoke jar
# 429    13-157                                       asparagus
# 430    13-161                                       aubergine
# 431    13-532                     baked beans in tomato sauce
# 432    13-041                         beans aduki whole dried
# 433       NaN                                     beans aduki
# 434    13-062                      beans blackeye whole dried
# 435       NaN                                  beans blackeye
# 436    13-070                              beans butter dried
# 437       NaN                                    beans butter
# 438    13-074             beans chick peas kabuli whole dried
# 439       NaN                                beans chick peas
# 440    13-080                                   beans cluster
# 441       NaN                            beans edamame frozen
# 442       NaN                                   beans edamame
# 443    13-514                                     beans green
# 444    13-086                       beans haricot whole dried
# 445       NaN                                   beans haricot
# 446    13-098                           beans mung dahl dried
# 447    13-102                   beans pigeon peas whole dried
# 448    13-106                               beans pinto dried
# 449       NaN                                     beans pinto
# 450    13-109                          beans red kidney dried
# 451       NaN                                beans red kidney
# 452    13-112                                    beans runner
# 453    13-115                                beans soya dried
# 454    13-117                                     beans sword
# 455    13-426                                beansprouts mung
# 456    13-056                black gram urad gram whole dried
# 457    13-164                                        beetroot
# 458    13-167                                      breadfruit
# 459    13-502                                  broccoli green
# 460    13-174                       broccoli purple sprouting
# 461    13-177                                brussels sprouts
# 462       NaN                                      beanburger
# 463       NaN                           beanburger vegetarian
# 464    13-067                               beans broad dried
# 465       NaN                                     beans broad
# 466    13-064                   beans broad whole without pod
# 467       NaN                                beans cannellini
# 468    13-582                                 cabbage average
# 469    13-187                                 cabbage chinese
# 470    13-510                                   cabbage green
# 471    13-190                                     cabbage red
# 472    13-509                                   cabbage white
# 473    13-448                                   carrots young
# 474    13-512                                     cauliflower
# 475    13-219                                        celeriac
# 476    13-636                                          celery
# 477    13-223                                     chard swiss
# 478    13-225                            chicory pale variety
# 479    13-627                                       courgette
# 480    13-234                                      curly kale
# 481       NaN                                       casserole
# 482    15-637                              cauliflower cheese
# 483    15-635                        coleslaw not low calorie
# 484       NaN                                     curry mixed
# 485    13-244                                          garlic
# 486    13-245                                        gherkins
# 487    13-608                               green beans dried
# 488       NaN                            green beans in water
# 489    13-556                                         houmous
# 490    13-258                                     horseradish
# 491    13-261                                       kohl rabi
# 492    15-809                                          khadhi
# 493    13-089             lentils green and brown whole dried
# 494       NaN                                         lentils
# 495    13-624                                           leeks
# 496    13-520                                 lettuce average
# 497    13-271                                    lotus tubers
# 498    15-651                                         lasagne
# 499    13-505                                 mushrooms white
# 500    13-298                                  mustard leaves
# 501    15-652                                        moussaka
# 502    13-300                                            okra
# 503    13-499                                          onions
# 504       NaN                                        potatoes
# 505       NaN                                    potato chips
# 506       NaN                                   potato wedges
# 507       NaN                                   peas in water
# 508    13-527                                     peas frozen
# 509       NaN                                        pak choi
# 510    13-311                       papaya unripe green flesh
# 511    13-312                                         parsnip
# 512    13-524                             pepper capsicum red
# 513    13-323                            plantain green flesh
# 514    13-326                                         pumpkin
# 515    15-262                                     quorn korma
# 516    13-332                                   radish leaves
# 517    13-522                                          rocket
# 518    15-869                                 roulade spinach
# 519    13-521                                    spinach baby
# 520    13-359                                           swede
# 521       NaN                                           swede
# 522    13-463                                    sweet potato
# 523       NaN                                    sweet potato
# 524       NaN                               sweetcorn kernels
# 525    13-622                               sweetcorn kernels
# 526       NaN                              sweetcorn on a cob
# 527    15-872           salad pasta vegetables and mayonnaise
# 528    15-883                                  shepherd's pie
# 529    15-617                                           sushi
# 530       NaN                         vegetables mixed frozen
# 531    15-656                              vegeburger grilled
# 532       NaN                                    stir fry mix
# 533    13-673                                      watercress
# 534    13-397                                             yam
# 535    13-530                         tomatoes whole contents
# 536    13-517                               tomatoes standard
#
#     Food sub-group codes  Food Group             Sale format(s)  \
# 153                    F       Fruit                        NaN
# 154                    F       Fruit                        NaN
# 155                   FA       Fruit                        NaN
# 156                   FA       Fruit                     punnet
# 157                   FA       Fruit                     packet
# 158                   FA       Fruit          loose, individual
# 159                   FA       Fruit          loose, individual
# 160                   FC       Fruit   carton, tetrapak, bottle
# 161                   FA       Fruit          loose, individual
# 162                   FA       Fruit    loose, individual/bunch
# 163                   FA       Fruit                     punnet
# 164                   FA       Fruit                     punnet
# 165                   FA       Fruit                     punnet
# 166                   FA       Fruit                     punnet
# 167                   FA       Fruit                        net
# 168                   FA       Fruit                     punnet
# 169                   FA       Fruit                     packet
# 170                   FA       Fruit                     punnet
# 171                   FA       Fruit                     packet
# 172                   FA       Fruit                     packet
# 173                   FA       Fruit                     punnet
# 174                   FA       Fruit                     punnet
# 175                   FA       Fruit          loose, individual
# 176                   FA       Fruit                     punnet
# 177                   FA       Fruit          loose, individual
# 178                   FA       Fruit  loose, individual, punnet
# 179                   FA       Fruit                        NaN
# 180                   FA       Fruit                     punnet
# 181                   FA       Fruit     loose, individual, net
# 182                   FA       Fruit     loose, individual, net
# 183                   FA       Fruit                        NaN
# 184                   FA       Fruit                     punnet
# 185                   FC       Fruit                        NaN
# 186                   FA       Fruit          loose, individual
# 187                   FA       Fruit          loose, individual
# 188                   FA       Fruit          loose, individual
# 189                   FA       Fruit          loose, individual
# 190                   FA       Fruit          loose, individual
# 191                   FA       Fruit                     punnet
# 192                   FA       Fruit                     punnet
# 193                   FA       Fruit                   tin, jar
# 194                   FA       Fruit     loose, individual, net
# 195                   FA       Fruit     loose, individual, net
# 196                   FC       Fruit   carton, tetrapak, bottle
# 197                    F       Fruit     loose, individual, bag
# 198                   FA       Fruit                      tin
# 199                   FA       Fruit                     packet
# 200                   FA       Fruit          loose, individual
# 201                   FA       Fruit          loose, individual
# 202                   FA       Fruit          loose, individual
# 203                   FA       Fruit          loose, individual
# 204                   FA       Fruit                        NaN
# 205                   FA       Fruit          loose, individual
# 206                   FC       Fruit   carton, tetrapak, bottle
# 207                   FA       Fruit                        NaN
# 208                   FC       Fruit   carton, tetrapak, bottle
# 209                   FA       Fruit                        NaN
# 210                   FC       Fruit   carton, tetrapak, bottle
# 211                   FA       Fruit                        tin
# 212                   FA       Fruit                        NaN
# 213                   FA       Fruit                        NaN
# 214                   FA       Fruit                     packet
# 215                   FA       Fruit                     punnet
# 216                   FA       Fruit                     punnet
# 217                   FA       Fruit                      bunch
# 218                   FA       Fruit          loose, individual
# 219                   FA       Fruit                     punnet
# 220                   FA       Fruit                     punnet
# 421                   DG  Vegetables                        tin
# 422                   DG  Vegetables                        NaN
# 423                   DG  Vegetables                        NaN
# 424                   DG  Vegetables                        NaN
# 425                   DG  Vegetables                        NaN
# 426                   DG  Vegetables          loose, individual
# 427                   DG  Vegetables                        tin
# 428                   DG  Vegetables                        jar
# 429                   DG  Vegetables              bunch, packet
# 430                   DG  Vegetables          loose, individual
# 431                   DB  Vegetables                        tin
# 432                   DB  Vegetables                     packet
# 433                   DB  Vegetables                        tin
# 434                   DB  Vegetables                     packet
# 435                   DB  Vegetables                        tin
# 436                   DB  Vegetables                     packet
# 437                   DB  Vegetables                        tin
# 438                   DB  Vegetables                     packet
# 439                   DB  Vegetables                        tin
# 440                   DB  Vegetables                     packet
# 441                   DB  Vegetables                     packet
# 442                   DB  Vegetables                        tin
# 443                   DB  Vegetables                     packet
# 444                   DB  Vegetables                        jar
# 445                   DB  Vegetables                        tin
# 446                   DB  Vegetables                     packet
# 447                   DB  Vegetables                     packet
# 448                   DB  Vegetables                     packet
# 449                   DB  Vegetables                        tin
# 450                   DB  Vegetables                     packet
# 451                   DB  Vegetables                        tin
# 452                   DB  Vegetables                     packet
# 453                   DB  Vegetables                     packet
# 454                   DB  Vegetables                     packet
# 455                   DB  Vegetables                     packet
# 456                   DB  Vegetables                     packet
# 457                   DG  Vegetables          loose, individual
# 458                   DG  Vegetables          loose, individual
# 459                   DG  Vegetables          loose, individual
# 460                   DG  Vegetables                     packet
# 461                   DG  Vegetables                     packet
# 462                   DR  Vegetables                     packet
# 463                   DR  Vegetables                     packet
# 464                   DB  Vegetables          loose, individual
# 465                   DB  Vegetables                        tin
# 466                   DB  Vegetables                     packet
# 467                   DB  Vegetables                        can
# 468                   DG  Vegetables          loose, individual
# 469                   DG  Vegetables          loose, individual
# 470                   DG  Vegetables          loose, individual
# 471                   DG  Vegetables          loose, individual
# 472                   DG  Vegetables          loose, individual
# 473                   DG  Vegetables     loose, individual, bag
# 474                   DG  Vegetables          loose, individual
# 475                   DG  Vegetables          loose, individual
# 476                   DG  Vegetables          loose, individual
# 477                   DG  Vegetables          loose, individual
# 478                   DG  Vegetables          loose, individual
# 479                   DG  Vegetables          loose, individual
# 480                   DG  Vegetables                        bag
# 481                   DR  Vegetables                     packet
# 482                   DR  Vegetables                     packet
# 483                   DR  Vegetables                     packet
# 484                   DR  Vegetables                        tin
# 485                   DG  Vegetables           individual, pack
# 486                   DG  Vegetables                        jar
# 487                   DI  Vegetables                     packet
# 488                   DI  Vegetables                        tin
# 489                   DB  Vegetables                     packet
# 490                   DG  Vegetables                        NaN
# 491                   DG  Vegetables          loose, individual
# 492                   DR  Vegetables                        NaN
# 493                   DB  Vegetables                     packet
# 494                   DB  Vegetables                        can
# 495                   DG  Vegetables          loose, individual
# 496                   DG  Vegetables          loose, individual
# 497                   DG  Vegetables                        NaN
# 498                   DR  Vegetables                     packet
# 499                   DG  Vegetables                     packet
# 500                   DG  Vegetables                        NaN
# 501                   DR  Vegetables                     packet
# 502                   DG  Vegetables                     packet
# 503                   DG  Vegetables          loose, individual
# 504                   DA  Vegetables                        NaN
# 505                  DAP  Vegetables                        NaN
# 506                  DAR  Vegetables                        NaN
# 507                   DF  Vegetables                        tin
# 508                   DF  Vegetables                        NaN
# 509                   DG  Vegetables                        NaN
# 510                   DG  Vegetables          loose, individual
# 511                   DG  Vegetables  loose, individual, packet
# 512                   DG  Vegetables          loose, individual
# 513                   DG  Vegetables          loose, individual
# 514                   DG  Vegetables          loose, individual
# 515                   DR  Vegetables                        NaN
# 516                   DG  Vegetables                        NaN
# 517                   DG  Vegetables                     packet
# 518                   DR  Vegetables                        NaN
# 519                   DG  Vegetables                     packet
# 520                   DG  Vegetables                        NaN
# 521                   DG  Vegetables                        NaN
# 522                   DG  Vegetables                     packet
# 523                   DG  Vegetables                     packet
# 524                   DG  Vegetables                        tin
# 525                   DG  Vegetables                     packet
# 526                   DG  Vegetables                     packet
# 527                   DR  Vegetables                        NaN
# 528                   DR  Vegetables                        NaN
# 529                   DR  Vegetables                        NaN
# 530                   DG  Vegetables                        NaN
# 531                   DR  Vegetables                        NaN
# 532                   DR  Vegetables                     packet
# 533                   DG  Vegetables                     packet
# 534                   DG  Vegetables                        NaN
# 535                   DG  Vegetables                        NaN
# 536                   DG  Vegetables                        NaN
#
#      Similarity Score_FPS Weight_FPS Portion Consumed_FPS
# 153              0.350355
# 154              0.267063
# 155              0.000000
# 156              0.324623
# 157              0.695211       125g              per pot
# 158              0.326769
# 159              0.326769
# 160              0.370335
# 161              0.000000
# 162              0.324623
# 163              0.000000
# 164              0.000000
# 165              0.000000
# 166              0.324623
# 167              0.392857
# 168              0.000000
# 169              0.000000
# 170              0.324623
# 171              0.324623
# 172              0.423097
# 173              0.515864
# 174              0.000000
# 175              0.424183
# 176              0.843806       500g                 pack
# 177              0.000000
# 178              0.445366
# 179              0.453672
# 180              0.515864
# 181              0.429971
# 182              0.000000
# 183              0.324623
# 184              0.000000
# 185              0.348651
# 186              0.000000
# 187              0.412167
# 188              0.000000
# 189              0.324623
# 190              0.324623
# 191              0.515864
# 192              0.324623
# 193              0.000000
# 194              0.000000
# 195              0.319790
# 196              0.530214
# 197              0.292930
# 198              0.415927
# 199              0.324623
# 200              0.000000
# 201              0.412167
# 202              0.415927
# 203              0.000000
# 204              0.324623
# 205              0.412167
# 206              0.646407       200g    individual carton
# 207              0.382923
# 208              0.492970
# 209              0.412167
# 210              0.522257
# 211              0.415927
# 212              0.324623
# 213              0.695211       125g              per pot
# 214              0.642767        44g               packet
# 215              0.000000
# 216              0.000000
# 217              0.000000
# 218              0.445366
# 219              0.000000
# 220              0.000000
# 421              0.000000
# 422              0.000000
# 423              0.000000
# 424              0.000000
# 425              0.000000
# 426              0.000000
# 427              0.000000
# 428              0.594410
# 429              0.000000
# 430              0.000000
# 431              0.559229
# 432              0.469653
# 433              0.698585       170g            small can
# 434              0.469653
# 435              0.698585       170g            small can
# 436              0.472677
# 437              0.472677
# 438              0.469653
# 439              0.698585       170g            small can
# 440              0.698585       170g            small can
# 441              0.493974
# 442              0.698585       170g            small can
# 443              0.698585       170g            small can
# 444              0.469653
# 445              0.698585       170g            small can
# 446              0.698585       170g            small can
# 447              0.469653
# 448              0.698585       170g            small can
# 449              0.698585       170g            small can
# 450              0.417556
# 451              0.417556
# 452              0.698585       170g            small can
# 453              0.698585       170g            small can
# 454              0.698585       170g            small can
# 455              0.000000
# 456              0.596422
# 457              0.000000
# 458              0.000000
# 459              0.000000
# 460              0.000000
# 461              0.000000
# 462              0.000000
# 463              0.510222
# 464              0.698585       170g            small can
# 465              0.698585       170g            small can
# 466              0.429161
# 467              0.698585       170g            small can
# 468              0.439411
# 469              0.414588
# 470              0.000000
# 471              0.000000
# 472              0.372787
# 473              0.000000
# 474              0.000000
# 475              0.000000
# 476              0.000000
# 477              0.000000
# 478              0.000000
# 479              0.000000
# 480              0.000000
# 481              0.000000
# 482              0.450275
# 483              0.355268
# 484              0.358754
# 485              0.565405
# 486              0.000000
# 487              0.698585       170g            small can
# 488              0.517497
# 489              0.000000
# 490              0.685131        12g             1 sachet
# 491              0.000000
# 492              0.000000
# 493              0.362730
# 494              0.000000
# 495              0.000000
# 496              0.439411
# 497              0.000000
# 498              0.475067
# 499              0.372787
# 500              0.786443         5g             I sachet
# 501              0.000000
# 502              0.000000
# 503              0.000000
# 504              0.833042        75g                small
# 505              0.374639
# 506              0.332715
# 507              0.513017
# 508              0.483320
# 509              0.000000
# 510              0.000000
# 511              0.000000
# 512              0.000000
# 513              0.000000
# 514              0.000000
# 515              0.281497
# 516              0.000000
# 517              0.000000
# 518              0.000000
# 519              0.713528        60g          Baby Danone
# 520              0.000000
# 521              0.324623
# 522              0.332715
# 523              0.338631
# 524              0.000000
# 525              0.000000
# 526              0.443995
# 527              0.570665
# 528              0.641882       480g                large
# 529              0.000000
# 530              0.385196
# 531              0.000000
# 532              0.446576
# 533              0.000000
# 534              0.000000
# 535              0.596422
# 536              0.571552

# %% [markdown]
#                                                 Department of Health Data

# %% [markdown]
# Converted Text data to a table

# %%
doh = pd.read_csv(r"C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\FV_WeightData\text\DofHealth_text_FV2011.csv", index_col=0)
doh['Composite Sample Name'] = doh['Composite Sample Name'].str.lower()
doh[doh['Composite Sample Name'].str.contains('orange')]#.head()
doh['Sub-sample Number'] = doh['Sub-sample Number'].astype(str)

# %% [markdown]
# Concatinating All excel files into one file

# %%
# Set the directory path where CSV files are located
directory_path = r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\FV_WeightData\tables\2011'

# Use glob to get a list of all CSV files in the directory
csv_files = glob.glob(os.path.join(directory_path, '*.csv'))

# Initialize an empty list to store DataFrames
dataframes = []

# Loop through each CSV file, read it using pandas, and append to the list
for csv_file in csv_files:
    # Read CSV file into a DataFrame
    dataframe = pd.read_csv(csv_file)
    
    # Append DataFrame to the list
    dataframes.append(dataframe)

# Concatenate all DataFrames into a single DataFrame
dataframefull = pd.concat(dataframes, ignore_index=True)

# %% [markdown]
# Minor Cleaning

# %%
dataframefull.drop(['Unnamed: 0'], axis=1, inplace=True)
dataframefull['Composite Sample Name'] = dataframefull['Composite Sample Name'].str.lower()

# %%
dataframefull.rename(columns={'Sub-sample Number':'Sub_sampleNumber'}, inplace = True)
dataframefull['Sub_sampleNumber'] = dataframefull['Sub_sampleNumber'].astype(str)

# %% [markdown]
# Matched DoH data doesn't have good weight data. I am going to go back and look at the PdF to try find better information.
#
#
# Tables at the end of pdf have weight info for all samples used. Get this into text table and try matching again

# %% [markdown]
#                                     Updating DoH text table with Sample weights tables

# %%
# Define your regular expression matching function
def regex_matching(source, target):
    pattern = re.compile(f'.*{source}.*', re.IGNORECASE)
    return target if re.match(pattern, target) else ''

# Create a function to update 'Pack size' and 'Match' column based on the regex match
def update_pack_size_and_match(row):
    sub_sample_number = row['Sub-sample Number']
    
    # Find the best match in 'dataframefull' using regular expression
    best_match = dataframefull[dataframefull['Sub_sampleNumber'].apply(lambda x: regex_matching(sub_sample_number, x)) != '']
    
    if not best_match.empty:
        # Get the first match and update 'Pack size' and 'Match' column
        matched_weight = best_match.iloc[0]['Sample Weight']
        return pd.Series([matched_weight, 1], index=['Pack size', 'Match'])
    
    return pd.Series([row['Pack size'], 0], index=['Pack size', 'Match'])  # If no match, return original 'Pack size' and 'Match' as 0

# Apply the update_pack_size_and_match function to 'doh'
doh[['Pack size', 'Match']] = doh.apply(update_pack_size_and_match, axis=1)

# %%
# # Function to get the sample weight based on common number
# def get_sample_weight(Sub_sampleNumber):
#     return sample_weights.get(Sub_sampleNumber, '')

# # Apply the function to calculate and add sample weights to the doh dataframe
# doh['Sample Weight'] = doh['Sub-sample Number'].apply(get_sample_weight)

# %%
doh[doh['Composite Sample Name'].str.contains('lettuce')]
# Out:
#      Composite Sample Number    Composite Sample Name Sub-sample Number  \
# 517                     32.0   lettuce, average, raw                nan
# 518                     32.0   lettuce, average, raw               32.2
# 519                     32.0   lettuce, average, raw               32.3
# 520                     32.0   lettuce, average, raw               32.4
# 521                     32.0   lettuce, average, raw               32.5
# 522                     32.0   lettuce, average, raw               32.6
# 523                     32.0   lettuce, average, raw                nan
# 524                     32.0   lettuce, average, raw               32.8
# 525                     32.0  lettuce, avera ge, raw               32.9
# 526                     32.0   lettuce, average, raw               32.1
# 527                     32.0   lettuce, average, raw              32.12
# 528                     32.0   lettuce, average, raw              32.13
# 529                     32.0   lettuce, average, raw              32.14
# 530                     32.0   lettuce, average, raw              32.15
# 531                     32.0   lettuce, average, raw              32.16
# 532                     32.0   lettuce, average, raw              32.17
# 533                     32.0   lettuce, average, raw              32.18
# 534                     32.0   lettuce, average, raw              32.19
# 535                     32.0   lettuce, average, raw               32.2
# 536                     32.0   lettuce, average, raw              32.21
# 537                     32.0   lettuce, average, raw              32.22
#
#                             Sub-sample Name                Brand  \
# 517              Tesco, sweet baby romaine                Tesco
# 518           Tesco, sweet iceberg lettuce                Tesco
# 519                                     NaN                Asda
# 520                Asda, lazy leaf lettuce                 Asda
# 521    Sainsb ury’s, British round lettuce          Sainsbury’s
# 522             Morrisons, romaine lettuce            Morrisons
# 523       Marks & Spencer, iceberg lettuce      Marks & Spencer
# 524               Aldi, little gem lettuce                 Aldi
# 525  Sainsbury’s, basics , iceberg lettuce   Sainsbury’s basics
# 526                Market ic eberg lettuce           Pack size:
# 527                 Tesco, romaine lettuce                   NaN
# 528                 Tesco, iceberg lettuce                Tesco
# 529                                     NaN                Asda
# 530        Asda, hearts of romaine lettuce                 Asda
# 531           Sainsbury’s, iceberg lettuce          Sainsbury’s
# 532             Morrisons, iceberg lettuce            Morrisons
# 533     The Co -operative, iceberg lettuce    The Co -operative
# 534                   Oaklands, little gem            Oakla nds
# 535   Tesco, Market Value, iceberg lettuce   Tesco Market Value
# 536                         Market lettuce          Pack s ize:
# 537            Farm Fresh, iceberg lettuce           Farm Fresh
#
#                       Pack size Purchase Date  \
# 517  Purchase Date: 17.10.2011    26.09.2011
# 518    Purchased ready prepared   26.09.2011
# 519    Purchased ready prepared   26.09.2011
# 520                       290.9   26.09.2011
# 521                       183.4   26.09.2011
# 522                       304.1   26.09.2011
# 523  Purchase Date: 17.10.2011    26.09.2011
# 524                       130.2           NaN
# 525  Purchase Date: 26.09.2011    26.09.2011
# 526  Purchase Date: 26.09.2011    26.09.2011
# 527  Purchase Date: 07.11.2011    07.11.2011
# 528  Purchase Date: 07.11.2011    07.11.2011
# 529                       260g    07.11.2011
# 530                    Count 2    07.11.2011
# 531                       200g    07.11.2011
# 532  Purchase Date: 07.11.2011    07.11.2011
# 533  Purchase Date: 07.11.2011    07.11.2011
# 534  Purchase Date: 07.11.2011    07.11.2011
# 535    Purchased ready prepared   07.11.2011
# 536                         NaN   07.11.2011
# 537                   Count x1    07.11.2011
#
#                       Place of Purchase    Display Until Date  \
# 517    Tesco, Harford Bridges, Norwich                 29-Sep
# 518     Tesco, Blue Boar Road, Norwich                 27-Sep
# 519                      Asda, Norwich                 28-Sep
# 520                      Asda, Norwich                   Thu
# 521    Sainsbury’s, Longwater, Norwich     Best Before Date:
# 522                 Morrisons, Norwich                 28-Sep
# 523           Marks & Spencer, Norwich                 29-Sep
# 524                      Aldi, Norwich     Best Before Date:
# 525    Sainsbury’s, Longwater, Norwich                 01-Oct
# 526  Independent market stall, Norwich     Best Before Date:
# 527     Tesco, Blue Boar Road, Norwich                 11-Nov
# 528    Tesco, Bl ue Boar Road, Norwich             Wednesday
# 529                      Asda, Norwich                 11-Nov
# 530                      Asda, Norwich                 13-Nov
# 531    Sainsbury’s, Longwater, Norwich   Use By Date: 11 Nov
# 532                 Morrisons, Norwich                 09-Nov
# 533      The Co -operative , Wymondham                 12-Nov
# 534                 Lidl, Attleborough     Best Before Date:
# 535    Tesco, Blue Boar Road , Norwich                 10-Nov
# 536  Independent market stall, Norwich     Best Before Date:
# 537                    Booker, Norwich     Best Before Date:
#
#                            Best Before Date  \
# 517                                  01-Oct
# 518                                     NaN
# 519                                     NaN
# 520                                    Sat
# 521                Batch Number: 444 11.09
# 522                                  29-Sep
# 523                          Batch Number:
# 524  Batch Number: 3901 supplier code:348A
# 525                                  02-Oct
# 526                          Batch Number:
# 527                                  13-Nov
# 528                     Batch Number: G502
# 529                                     NaN
# 530                                  15-Nov
# 531                                     NaN
# 532                                  10-Nov
# 533                                     NaN
# 534           Batch Number: L-4402 W -0385
# 535                     Batch Number: GS02
# 536                          Batch Number:
# 537         Batch Number: Date code: 33 05
#
#                                      Batch Number Packaging  \
# 517                                        GS 03        NaN
# 518                          SCGD Line 7.1 09:03   Plastic
# 519                             Line 007 S 19:31   Plastic
# 520                                        370000  Plastic
# 521                                    444 11.09   Plastic
# 522                             1677 T31081/0610   Plastic
# 523                          Packaging : Plastic        NaN
# 524                      3901 supplier code:348A   Plastic
# 525                                        G0630   Plastic
# 526                           Packaging: Plastic   Plastic
# 527                                         GS02   Plastic
# 528                                         G502   Plastic
# 529                          Line 01 S 06:48 050   Plastic
# 530                                        470010  Plastic
# 531                Line 01 17:30 S 7282600 04.10   Plastic
# 532  24234 TH1 -ICE1C 30911 LZ 05:04 T29931/0310   Plastic
# 533                              M029 (F) KCA112   Plastic
# 534                               L-4402 W -0385   Plastic
# 535                                         GS02   Plastic
# 536                           Packaging: Plastic   Plastic
# 537                             Date code: 33 05   Plastic
#
#     Sample Condition As Purchased Post Purchase Storage  Match
# 517                      Ambient          Refrigerated     1.0
# 518                      Ambient          Refrigerated     1.0
# 519                      Ambient          Refrigerated     1.0
# 520                      Ambient          Refrigerated     1.0
# 521                      Ambient          Refrigerated     1.0
# 522                      Ambient          Refrigerated     1.0
# 523                      Ambient          Refrigerated     1.0
# 524                      Ambient          Refrigerated     1.0
# 525                      Ambient          Refrigerated     0.0
# 526                      Ambient                    NaN    0.0
# 527                      Ambient                    NaN    0.0
# 528                      Ambient          Refrigerated     0.0
# 529                           NaN         Refrigerated     0.0
# 530                           NaN         Refrigerated     0.0
# 531                      Ambient          Refrigerated     0.0
# 532                      Ambient                    NaN    0.0
# 533                      Ambient          Refrigerated     0.0
# 534                      Ambient         Refriger ated     0.0
# 535                      Ambient          Refrigerated     1.0
# 536                      Ambient          Refrigerated     0.0
# 537                 Refrigerated          Refrigerated     0.0

# %% [markdown]
#                                 Removing samples that didn't have the right weights attached

# %%
rows_to_remove3 = [517,518,519,523,525,526,527,528,
                  530,532,533,534,535,536,537]

doh.drop(rows_to_remove3, axis=0, inplace=True)

# %%
rows_to_remove2 = [333,332,331,330,329,328,327,326,
                  325,324,323,322,321,320,319,318,
                  317,316,340,341,342,344,345,346,
                  347,348,350,351,352,353,354,355,
                  356,357,358,359,360,361,362,363,
                  364,365,366,367,368,369,370,371,
                  371]

doh.drop(rows_to_remove2, axis=0, inplace=True)

# %%
rows_to_remove1 = [659,660,661,668,669,670,671,672,673,674,675,
                   676,677,678,679,680,681,682,683,684,685,686,
                   816,815,814,810,
                   805,804,801,798]

doh.drop(rows_to_remove1, axis=0, inplace=True)

# %%
rows_to_remove = [717,719,722,725,782,729,732,736,738,739,740,742,747,748,753,754,756,757]

doh.drop(rows_to_remove, axis=0, inplace=True)

# %% [markdown]
#                                              Reducing Product list on DOH table

# %%
# List of food names to match
food_names = [
    'potatoes, old, raw',
    'carrots, old, raw',
    'onions, raw',
    'broccoli (calabrese), raw',
    'mushrooms, raw',
    'cabbage, white, raw',
    'cabbage, green, raw',
    'cauliflower, raw',
    'beans, green, raw',
    'tomatoes (standard), grilled',
    'lettuce, average, raw',
    'spinach, baby, raw',
    'cucumber, flesh and skin, raw',
    'peppers, red, raw',
    'peppers, yellow, raw',
    'bananas, raw, flesh only',
    'apples, eating, raw, flesh and skin',
    'apples, cooking, stewed, flesh only',
    'pears, raw, flesh and skin',
    'grapes, green, raw',
    'grapes, red, raw',
    'strawberries, raw',
    'blueberries, raw',
    'citrus fruit, soft/easy peelers, flesh only',
    'oranges, flesh only',
    'melon, yellow flesh, flesh only',
    'peas, frozen, raw',
    'sweetcorn, canned in water, drained',
    'tomatoes, canned, whole contents',
    'tomato puree',
    'baked beans in tomato sauce',
    'potato products, shaped, frozen, baked',
    'orange juice, from concentrate',
    'apple juice, clear, from concentrate'
]

# Create an empty DataFrame to store matched rows
matched_rows = []

# Create an empty DataFrame to store matched rows
matched_rows = []

# Loop through the food names and perform fuzzy matching
for food_name in food_names:
    best_similarity = 0
    best_match = None
    
    for sample_name in doh['Composite Sample Name']:
        similarity = fuzz.partial_ratio(food_name, sample_name)
        if similarity > best_similarity:
            best_similarity = similarity
            best_match = sample_name
    
    if best_match is not None:
        matched_df = doh[doh['Composite Sample Name'].str.contains(best_match, case=False, regex=True)]
        if not matched_df.empty:
            matched_row = matched_df.iloc[0].copy()
            matched_row['Similarity Score'] = best_similarity
            matched_rows.append(matched_row)

# Create a DataFrame from the matched rows
matched_food_df = pd.DataFrame(matched_rows)
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27336\3452392078.py:57: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   matched_df = doh[doh['Composite Sample Name'].str.contains(best_match, case=False, regex=True)]
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27336\3452392078.py:57: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   matched_df = doh[doh['Composite Sample Name'].str.contains(best_match, case=False, regex=True)]

# %%
matched_food_df
# Out:
#      Composite Sample Number  \
# 0                        1.0
# 102                      8.0
# 165                     11.0
# 271                     17.0
# 334                     22.0
# 334                     22.0
# 373                     24.0
# 412                     26.0
# 520                     32.0
# 538                     33.0
# 568                     35.0
# 586                     36.0
# 629                     38.0
# 650                     39.0
# 662                     40.0
# 687                     41.0
# 698                     42.0
# 718                     43.0
# 741                     44.0
# 759                     45.0
# 776                     46.0
# 796                     47.0
# 817                     48.0
# 837                     49.0
# 854                      NaN
# 875                     52.0
# 886                     53.0
# 896                     54.0
# 905                     55.0
# 921                     56.0
# 940                     58.0
# 949                     59.0
#
#                                  Composite Sample Name Sub-sample Number  \
# 0                     potatoes, old, raw , flesh only                1.1
# 102                                 carrots, old, raw                8.1
# 165                                       onions, raw               11.1
# 271                                    mushrooms, raw               17.1
# 334                               cabbage, green, raw               22.1
# 334                               cabbage, green, raw               22.1
# 373                                  cauliflower, raw               24.1
# 412                                beans, green , raw               26.2
# 520                             lettuce, average, raw               32.4
# 538                                spinach, baby, raw               33.1
# 568                     cucumber, flesh and skin, raw               35.1
# 586                                 peppers, red, raw               36.1
# 629                              peppers, yellow, raw               38.1
# 650                          bananas, raw, flesh only               39.1
# 662               apples, eating, raw, flesh and skin               40.4
# 687               apples, cooking, stewed, flesh only               41.1
# 698                        pears, raw, flesh and skin               42.1
# 718                                grapes, green, raw               43.2
# 741                                  grapes, red, raw               44.4
# 759                                 strawberries, raw               45.2
# 776                                  blueberries, raw               46.2
# 796       citrus fruit, soft/easy peelers, flesh only               47.1
# 817                               oranges, flesh only               48.1
# 837                   melon, yellow flesh, flesh only               49.1
# 854                                 peas, frozen, raw               50.2
# 875               sweetcorn, canned in water, drained               52.1
# 886                  tomatoes, canned, whole contents               53.1
# 896                                      tomato puree               54.1
# 905                       baked beans in tomato sauce               55.1
# 921            potato products, shaped, frozen, baked               56.1
# 940           orange juice, from concentrate, ambient               58.1
# 949  apple juice, clear, from concentrate, amb ient...              59.1
#
#                                        Sub-sample Name                Brand  \
# 0           Tesco , Eastern Counties , white potatoes                Tesco
# 102                             Tesco , loose carrots           Pack size:
# 165                       Tesco, Finest, sweet onions         Tesco Finest
# 271               Tesco, British closed cup mushrooms                Tesco
# 334                 Tesco, Lincolnshire green cabbage                Tesco
# 334                 Tesco, Lincolnshire green cabbage                Tesco
# 373       Tesco, Lincolnshire extra large cauliflower                Tesco
# 412                        Tesco, British green beans                Tesco
# 520                           Asda, lazy leaf lettuce                 Asda
# 538                          Tesco, mild baby spinach                Tesco
# 568                     Tesco, fresh cucumber portion                Tesco
# 586                           Tesco, loose red pepper           Pack size:
# 629                        Tesco, loose yellow pepper           Pack size:
# 650                        Tesco, Fair Trade, bananas                Tesco
# 662                                  Pink Lady apples            Pink Lady
# 687                     Select Horeca, Bramley apples        Select Horeca
# 698                     Tesco, loose Conference pears           Pack size:
# 718                      Tesco, seedless green grapes                Tesco
# 741                       Asda, Extra Special, grapes   Asda Extra Special
# 759                                                NaN        Tesco Finest
# 776                                Tesco, blueberries                Tesco
# 796                           Jaffa, juicy tangerines                Jaffa
# 817                              Tesco, large oranges                Tesco
# 837                             Tesco, Honeydew melon                Tesco
# 854                Birds Eye, field fresh garden peas            Birds Eye
# 875           Green Giant, natu rally sweet sweetcorn          Green Giant
# 886  Napolina, chopped tomatoes in a rich tomato ju...            Napolina
# 896        Napolina, double concentrate, tomato puree             Napolina
# 905                                Heinz, 4 snap pots                Heinz
# 921                      Birds Eye, 12 potato waffles            Birds Eye
# 940  Princes, 100% pure orange juice, from concentr...             Princes
# 949  Princes, 100% pure apple juice, from concentrate              Princes
#
#              Pack size Purchase Date                   Place of Purchase  \
# 0                200.5   03.10.2011     Tesco, Harford Bridges, Norwich
# 102               67.2   10.10.2011          Tesco, Blue Boar , Norwich
# 165              200.5   10.10.2011     Tesco, Harford Bridges, Norwich
# 271               23.7   03.10.2011    Tesco, Harford Bridges , Norwich
# 334              890.8   17.10.2011                      Tesco, Dereham
# 334              890.8   17.10.2011                      Tesco, Dereham
# 373             1123.0   17.10.2011    Tesco, Harford Bridges , Norwich
# 412                6.0   19.09.2011                 Tesco, East Dereham
# 520              290.9   26.09.2011                       Asda, Norwich
# 538              200g    28.09.2011     Tesco, Harford Bridges, Norwich
# 568              245.6   26.09.2011      Tesco, Blue Boar Road, Norwich
# 586              158.7   26.09.2011     Tesco, Harford Bridges, Norwich
# 629              181.2   26.09.2011     Tesco, Harford Bridges, Norwich
# 650              174.8   21.11.2011      Tesco, Blue Boar Road, Norwich
# 662              128.4   14.11.2011                       Asda, Norwich
# 687            1.5 kg    14.11.2011                      Makro, Norwich
# 698              201.8   18.11.2011     Tesco, Blue B oar Road, Norwich
# 718              500g    14.11.2011     Tesco, Blue Boar Road , Norwich
# 741              400g    14.11.2011                       Asda, Norwich
# 759               16.7   23.08.2011    Tesco, Harford Bridges , Norwich
# 776              150g    23.08.2011     Tesco, Harford Bridges, Norwich
# 796              867g            NaN     Tesco, Harford Bridges Norwich
# 817              271.3  21.11.201 1      Tesco, Blue Boar Road, Norwich
# 837             1333.8   30.08.2011     Tesco, Harford Bridges, Norwich
# 854              900g    27.01.2012   Sainsbury’s, Longwater , Norw ich
# 875              198g    30.01.2012                  Morrisons, Norwich
# 886              428.9   27.01.2012                       Asda, Norwich
# 896              142g    30.01.2012                  Morrisons, Norwich
# 905  800g (4 x 200 g)    27.01.2012     Sainsbury’s, Longwater, Norwich
# 921              680g    27.01.2012    Sainsbury’s, Longwater , Norwich
# 940           1 litre    27.01.2012    Sainsbury’s, Longwate r, Norwich
# 949           1 litre    27.01.2012     Sainsbury’s, Longwater, Norwich
#
#               Display Until Date  \
# 0                         05-Oct
# 102           Best Before Date:
# 165                       17-Oct
# 271                       04-Oct
# 334                       21-Oct
# 334                       21-Oct
# 373                       20-Oct
# 412                       21-Sep
# 520                         Thu
# 538                       29-Sep
# 568                       27-Sep
# 586           Best Before Date:
# 629           Best Before Date:
# 650                       22-Nov
# 662                       22-Nov
# 687           Best Before Date:
# 698           Best Before Date:
# 718                       15-Nov
# 741                       14-Nov
# 759                       25-Aug
# 776                       26-Aug
# 796                       17-Nov
# 817                       25-Nov
# 837           Best Before Date:
# 854   Best Before Date: 07 2013
# 875   Best Before Date: 07 2015
# 886                          NaN
# 896  Best Before Date: Aug 2013
# 905   Best Before Date: 02-2013
# 921   Best Before Date: 06 2013
# 940       Use By Date: Jan 2013
# 949  Best Before Date: Jan 2013
#
#                                       Best Before Date  \
# 0                                                  NaN
# 102                                     Batch Number:
# 165                             Batch Number: GS11 L2
# 271                                             06-Oct
# 334                                             23-Oct
# 334                                             23-Oct
# 373                   Batch Number: Supplier code: CE
# 412                                             23-Sep
# 520                                               Sat
# 538                                                NaN
# 568                                             28-Sep
# 586                                     Batch Number:
# 629                                     Batch Number:
# 650                                             24-Nov
# 662                                             24-Nov
# 687  Batch Number: Supplier code: 24272 A22624 art ...
# 698                                     Batch Number:
# 718                                             17-Nov
# 741                                             15-Nov
# 759                                Batch Number: KG20
# 776                          Batch Number: BYO5L90316
# 796                                             18-Nov
# 817                                             27-Nov
# 837                                     Batch Number:
# 854                                           07 2013
# 875                                           07 2015
# 886                                             Dec-13
# 896                                             Aug-13
# 905                                             Feb-13
# 921                                           06 2013
# 940                                                NaN
# 949                                             Jan-13
#
#                                           Batch Number  \
# 0                                                  NaN
# 102                                Packaging: Plastic
# 165                                           GS11 L2
# 271                                          232 GS15
# 334                                      PV 002339284
# 334                                      PV 002339284
# 373                                 Supplier code: CE
# 412                                              WD03
# 520                                             370000
# 538                               SCGD Line 7.1 09:13
# 568                                              GN16
# 586                                Packaging: Plastic
# 629                                Packaging: Plastic
# 650                   Supplier: PGS17 DON 12010 02221
# 662                                     375396 909008
# 687  Supplier code: 24272 A22624 art no: 363565 Jul...
# 698                                Packaging: Plastic
# 718                                              LA03
# 741                                    900375 375173
# 759                                              KG20
# 776                                        BYO5L90316
# 796            TC: 40303511 W.O: 42751 22:35 GO3 MZ16
# 817               WO:43258 MZ16 TC:33101889 16:52 XO2
# 837                                        Packaging:
# 854               L 2013 GH 124 06:41 101504 87702162
# 875                                      22:39 2793C5
# 886                                     CO5 LE216  PC
# 896                                  Packaging: Metal
# 905                                     BV 1336 13:14
# 921                           L1349EF124 04:33 024384
# 940                                  J L2004C 08:49 D
# 949                                   V L2005C 19:40C
#
#                                    Packaging Sample Condition As Purchased  \
# 0                                   Plastic                       Ambient
# 102                                 Plastic                       Ambient
# 165                                 Netting                       Ambient
# 271                                 Plastic                       Ambient
# 334                                 Plastic                       Ambient
# 334                                 Plastic                       Ambient
# 373                                 Plastic                       Ambient
# 412                                 Plastic                       Ambient
# 520                                 Plastic                       Ambient
# 538                                 Plastic                       Ambient
# 568                                 Plastic                       Ambient
# 586                                 Plastic                       Ambient
# 629                                 Plastic                       Ambient
# 650                                 Plastic                       Ambient
# 662                                 Plastic                            NaN
# 687                                 Plastic                       Ambient
# 698                                 Plastic                       Ambient
# 718                                 Plastic                       Ambient
# 741                                 Plastic                       Ambient
# 759                                 Plastic                       Ambient
# 776                                 Plastic                       Ambient
# 796                                 Netting                       Ambient
# 817                                 Netting                       Ambient
# 837  Sample Condition As Purchased: Ambient                       Ambient
# 854                                 Plastic                        Frozen
# 875                                   Metal                            NaN
# 886                                   Metal                       Ambient
# 896                                   Metal                       Ambient
# 905                                 Plastic                       Ambient
# 921                               Cardboard                        Frozen
# 940                               Tetra pak                       Ambient
# 949                               Tetra pak                       Ambient
#
#     Post Purchase Storage  Match  Similarity Score
# 0                Ambient     1.0               100
# 102         Refrigerated     1.0               100
# 165              Ambient     1.0               100
# 271         Refrigerated     1.0               100
# 334         Refrigerated     1.0                79
# 334         Refrigerated     1.0               100
# 373         Refrigerated     1.0               100
# 412         Refrigerated     1.0                94
# 520         Refrigerated     1.0               100
# 538                   NaN    0.0               100
# 568                   NaN    1.0               100
# 586         Refrigerated     1.0               100
# 629         Refrigerated     1.0               100
# 650              Ambient     1.0               100
# 662         Refrigerated     1.0               100
# 687         Refrigerated     0.0               100
# 698              Ambient     1.0               100
# 718                   NaN    0.0               100
# 741         Refrigerated     0.0               100
# 759         Refrigerated     1.0               100
# 776         Refrigerated     0.0               100
# 796                   NaN    0.0               100
# 817         Refrigerated     1.0               100
# 837         Refrigerated     1.0               100
# 854               Frozen     0.0               100
# 875              Ambient     0.0               100
# 886              Ambient     1.0               100
# 896              Ambient     0.0               100
# 905              Ambient     0.0               100
# 921                   NaN    0.0               100
# 940              Ambient     0.0               100
# 949              Ambient     0.0               100

# %%
# Remove commas from 'Food Name' column
matched_food_df['Composite Sample Name'] = matched_food_df['Composite Sample Name'].str.replace(',', '').str.strip()

# %%
matched_food_df['Composite Sample Name'] = matched_food_df['Composite Sample Name'].str.replace(r'\bdrained\b', '', case=False).str.strip()
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27336\364710638.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   matched_food_df['Composite Sample Name'] = matched_food_df['Composite Sample Name'].str.replace(r'\bdrained\b', '', case=False).str.strip()

# %%
matched_food_df['Composite Sample Name'] = matched_food_df['Composite Sample Name'].str.replace(r'\braw\b', '', case=False).str.strip()
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27336\2587630719.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   matched_food_df['Composite Sample Name'] = matched_food_df['Composite Sample Name'].str.replace(r'\braw\b', '', case=False).str.strip()

# %%
matched_food_df['Composite Sample Name'] = matched_food_df['Composite Sample Name'].str.replace(r'\bcanned\b', '', case=False).str.strip()
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27336\4285208305.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   matched_food_df['Composite Sample Name'] = matched_food_df['Composite Sample Name'].str.replace(r'\bcanned\b', '', case=False).str.strip()

# %%
matched_food_df['Composite Sample Name'] = matched_food_df['Composite Sample Name'].str.replace(r'\bflesh and skin\b', '', case=False).str.strip()
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27336\2919315305.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   matched_food_df['Composite Sample Name'] = matched_food_df['Composite Sample Name'].str.replace(r'\bflesh and skin\b', '', case=False).str.strip()

# %%
matched_food_df['Composite Sample Name'] = matched_food_df['Composite Sample Name'].str.replace(r'\bwhole contents\b', '', case=False).str.strip()
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_27336\185227798.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   matched_food_df['Composite Sample Name'] = matched_food_df['Composite Sample Name'].str.replace(r'\bwhole contents\b', '', case=False).str.strip()

# %% [markdown]
#                                                     Matching M&W and DoH

# %%
# %%time

def fuzzy_matching_score(source, target):
    return fuzz.partial_token_set_ratio(source, target)

def get_most_similar_indices(tfidf_red_food, tfidf_clean_retail):
    similarities = cosine_similarity(tfidf_red_food, tfidf_clean_retail)
    return similarities.argmax(axis=1)

def hybrid_fuzzy_matching(matched_food_df, fv):
    # Set thresholds for matching
    partial_token_set_ratio_threshold = 100
    cosine_similarity_threshold = 0.90
    min_similarity_threshold = 0.67

    
    # Step 1: Partial Token Set Ratio (Fuzzy Matching)
    matched_food_df['Partial Token Set Ratio'] = matched_food_df['Composite Sample Name'].apply(lambda x: fuzzy_matching_score(x, fv['Food Name']))
    potential_matches = matched_food_df[matched_food_df['Partial Token Set Ratio'] >= partial_token_set_ratio_threshold]
    
    print('Completed 1')

    # Step 2: TF-IDF and Cosine Similarity (Text Matching) - Use combined matches as input
    vectorizer = TfidfVectorizer()
    vectorizer.fit(potential_matches['Composite Sample Name'])
    tfidf_clean_doh = vectorizer.transform(potential_matches['Composite Sample Name'])
    tfidf_red_food = vectorizer.transform(fv['Food Name'])

    # Find the most similar match for each redFood product
    max_sim_indices = get_most_similar_indices(tfidf_red_food, tfidf_clean_doh)
    max_sim_scores = cosine_similarity(tfidf_red_food, tfidf_clean_doh).max(axis=1)
    
    print('Completed 2')

    # Update redFood DataFrame with matched information and sources
    fv['Similarity Score DoH'] = max_sim_scores
    #fv['Weight DoH'] = potential_matches['Sample Weight'].values[max_sim_indices]
    fv['Pack Size11'] = potential_matches['Pack size'].values[max_sim_indices]
    fv['Packaging DoH11'] = potential_matches['Packaging'].values[max_sim_indices]
    fv['Purchase Date DoH11'] = potential_matches['Purchase Date'].values[max_sim_indices]
    
    
    print('Completed 3')

    # Set to NaN for rows where similarity score is below the minimum threshold
    fv.loc[fv['Similarity Score DoH'] < min_similarity_threshold, [ 'Packaging DoH11', 'Pack Size11', 'Purchase Date DoH11']] = ''

    return fv

# Call the hybrid_fuzzy_matching function and get the matched DataFrame
redFood_matched = hybrid_fuzzy_matching(matched_food_df.copy(),fv.copy())
# Out:
# Completed 1
# Completed 2
# Completed 3
# CPU times: total: 188 ms
# Wall time: 166 ms

# %%
redFood_matched#['Food Name'].value_counts().sum()
# Out:
#     Food Code                                       Food Name  \
# 153    14-363      apples cooking  weighed with skin and core
# 154    14-319                                   apples eating
# 155    14-001                                            amla
# 156    14-025                                        apricots
# 157    14-392                apricots ready-to-eat semi-dried
# 158    14-040     avocado fuerte  weighed with skin and stone
# 159    14-387       avocado hass  weighed with skin and stone
# 160    14-331           apple juice clear ambient and chilled
# 161    14-043                                          babaco
# 162    14-318                                         bananas
# 163    14-388                                    blackberries
# 164    14-053                                   blackcurrants
# 165    14-325                                     blueberries
# 166    14-382                                        cherries
# 167    14-326  citrus fruit soft/easy peelers flesh with skin
# 168    14-073                                     cranberries
# 169    14-074                                        currants
# 170    14-077                                         damsons
# 171    14-083                                           dates
# 172    14-087                               dried mixed fruit
# 173    14-089                        elderberries whole fruit
# 174    14-100                            gooseberries cooking
# 175    14-384                                      grapefruit
# 176    14-322                                    grapes green
# 177    14-118                                           guava
# 178    14-371                                      kiwi fruit
# 179    14-373                   kiwi fruit  weighed with skin
# 180    14-125                            kumquats whole fruit
# 181    14-128                       lemons whole without pips
# 182    14-131                                           limes
# 183    14-132                                           limes
# 184    14-133                                    loganberries
# 185    14-277                               lemon juice fresh
# 186    14-378                                    mangoes ripe
# 187    14-379             mangoes weighed with skin and stone
# 188    14-339                           melon canteloupe-type
# 189    14-353                           melon canteloupe-type
# 190    14-356                                           melon
# 191    14-168                          mulberries whole fruit
# 192    14-380                                      nectarines
# 193       NaN                                          olives
# 194    14-327                                         oranges
# 195    14-360                oranges flesh with peel and pips
# 196    14-369                   orange juice freshly squeezed
# 197    14-361      pears average  weighed with core and stalk
# 198    14-188                 peaches in juice whole contents
# 199    14-321                                           pears
# 200    14-376                                       pineapple
# 201    14-377               pineapple flesh with skin and top
# 202    14-211               pineapple in juice whole contents
# 203    14-396                                 pineapple dried
# 204    14-220                                  plums victoria
# 205    14-227    pomegranate flesh and pips weighed with skin
# 206    14-285                             passion fruit juice
# 207    14-179  passion fruit flesh and pips weighed with skin
# 208    14-341                         pomegranate juice drink
# 209    14-227    pomegranate flesh and pips weighed with skin
# 210    14-289                                     prune juice
# 211    14-237                  prunes in juice whole contents
# 212    14-231                                          prunes
# 213    14-391                  prunes ready-to-eat semi-dried
# 214    14-393                                   raisins dried
# 215    14-375                                     raspberries
# 216    14-249                                     redcurrants
# 217    14-252                              rhubarb stems only
# 218    14-059                                      star fruit
# 219    14-324                                    strawberries
# 220    14-268                                   whitecurrants
# 421       NaN                                           ackee
# 422    13-146                                      agar dried
# 423    13-148                                 alfalfa sprouts
# 424    13-149                                 amaranth leaves
# 425    13-151                                       arrowhead
# 426    13-153                                 artichoke globe
# 427       NaN                                       artichoke
# 428       NaN                                   artichoke jar
# 429    13-157                                       asparagus
# 430    13-161                                       aubergine
# 431    13-532                     baked beans in tomato sauce
# 432    13-041                         beans aduki whole dried
# 433       NaN                                     beans aduki
# 434    13-062                      beans blackeye whole dried
# 435       NaN                                  beans blackeye
# 436    13-070                              beans butter dried
# 437       NaN                                    beans butter
# 438    13-074             beans chick peas kabuli whole dried
# 439       NaN                                beans chick peas
# 440    13-080                                   beans cluster
# 441       NaN                            beans edamame frozen
# 442       NaN                                   beans edamame
# 443    13-514                                     beans green
# 444    13-086                       beans haricot whole dried
# 445       NaN                                   beans haricot
# 446    13-098                           beans mung dahl dried
# 447    13-102                   beans pigeon peas whole dried
# 448    13-106                               beans pinto dried
# 449       NaN                                     beans pinto
# 450    13-109                          beans red kidney dried
# 451       NaN                                beans red kidney
# 452    13-112                                    beans runner
# 453    13-115                                beans soya dried
# 454    13-117                                     beans sword
# 455    13-426                                beansprouts mung
# 456    13-056                black gram urad gram whole dried
# 457    13-164                                        beetroot
# 458    13-167                                      breadfruit
# 459    13-502                                  broccoli green
# 460    13-174                       broccoli purple sprouting
# 461    13-177                                brussels sprouts
# 462       NaN                                      beanburger
# 463       NaN                           beanburger vegetarian
# 464    13-067                               beans broad dried
# 465       NaN                                     beans broad
# 466    13-064                   beans broad whole without pod
# 467       NaN                                beans cannellini
# 468    13-582                                 cabbage average
# 469    13-187                                 cabbage chinese
# 470    13-510                                   cabbage green
# 471    13-190                                     cabbage red
# 472    13-509                                   cabbage white
# 473    13-448                                   carrots young
# 474    13-512                                     cauliflower
# 475    13-219                                        celeriac
# 476    13-636                                          celery
# 477    13-223                                     chard swiss
# 478    13-225                            chicory pale variety
# 479    13-627                                       courgette
# 480    13-234                                      curly kale
# 481       NaN                                       casserole
# 482    15-637                              cauliflower cheese
# 483    15-635                        coleslaw not low calorie
# 484       NaN                                     curry mixed
# 485    13-244                                          garlic
# 486    13-245                                        gherkins
# 487    13-608                               green beans dried
# 488       NaN                            green beans in water
# 489    13-556                                         houmous
# 490    13-258                                     horseradish
# 491    13-261                                       kohl rabi
# 492    15-809                                          khadhi
# 493    13-089             lentils green and brown whole dried
# 494       NaN                                         lentils
# 495    13-624                                           leeks
# 496    13-520                                 lettuce average
# 497    13-271                                    lotus tubers
# 498    15-651                                         lasagne
# 499    13-505                                 mushrooms white
# 500    13-298                                  mustard leaves
# 501    15-652                                        moussaka
# 502    13-300                                            okra
# 503    13-499                                          onions
# 504       NaN                                        potatoes
# 505       NaN                                    potato chips
# 506       NaN                                   potato wedges
# 507       NaN                                   peas in water
# 508    13-527                                     peas frozen
# 509       NaN                                        pak choi
# 510    13-311                       papaya unripe green flesh
# 511    13-312                                         parsnip
# 512    13-524                             pepper capsicum red
# 513    13-323                            plantain green flesh
# 514    13-326                                         pumpkin
# 515    15-262                                     quorn korma
# 516    13-332                                   radish leaves
# 517    13-522                                          rocket
# 518    15-869                                 roulade spinach
# 519    13-521                                    spinach baby
# 520    13-359                                           swede
# 521       NaN                                           swede
# 522    13-463                                    sweet potato
# 523       NaN                                    sweet potato
# 524       NaN                               sweetcorn kernels
# 525    13-622                               sweetcorn kernels
# 526       NaN                              sweetcorn on a cob
# 527    15-872           salad pasta vegetables and mayonnaise
# 528    15-883                                  shepherd's pie
# 529    15-617                                           sushi
# 530       NaN                         vegetables mixed frozen
# 531    15-656                              vegeburger grilled
# 532       NaN                                    stir fry mix
# 533    13-673                                      watercress
# 534    13-397                                             yam
# 535    13-530                         tomatoes whole contents
# 536    13-517                               tomatoes standard
#
#     Food sub-group codes  Food Group             Sale format(s)  \
# 153                    F       Fruit                        NaN
# 154                    F       Fruit                        NaN
# 155                   FA       Fruit                        NaN
# 156                   FA       Fruit                     punnet
# 157                   FA       Fruit                     packet
# 158                   FA       Fruit          loose, individual
# 159                   FA       Fruit          loose, individual
# 160                   FC       Fruit   carton, tetrapak, bottle
# 161                   FA       Fruit          loose, individual
# 162                   FA       Fruit    loose, individual/bunch
# 163                   FA       Fruit                     punnet
# 164                   FA       Fruit                     punnet
# 165                   FA       Fruit                     punnet
# 166                   FA       Fruit                     punnet
# 167                   FA       Fruit                        net
# 168                   FA       Fruit                     punnet
# 169                   FA       Fruit                     packet
# 170                   FA       Fruit                     punnet
# 171                   FA       Fruit                     packet
# 172                   FA       Fruit                     packet
# 173                   FA       Fruit                     punnet
# 174                   FA       Fruit                     punnet
# 175                   FA       Fruit          loose, individual
# 176                   FA       Fruit                     punnet
# 177                   FA       Fruit          loose, individual
# 178                   FA       Fruit  loose, individual, punnet
# 179                   FA       Fruit                        NaN
# 180                   FA       Fruit                     punnet
# 181                   FA       Fruit     loose, individual, net
# 182                   FA       Fruit     loose, individual, net
# 183                   FA       Fruit                        NaN
# 184                   FA       Fruit                     punnet
# 185                   FC       Fruit                        NaN
# 186                   FA       Fruit          loose, individual
# 187                   FA       Fruit          loose, individual
# 188                   FA       Fruit          loose, individual
# 189                   FA       Fruit          loose, individual
# 190                   FA       Fruit          loose, individual
# 191                   FA       Fruit                     punnet
# 192                   FA       Fruit                     punnet
# 193                   FA       Fruit                   tin, jar
# 194                   FA       Fruit     loose, individual, net
# 195                   FA       Fruit     loose, individual, net
# 196                   FC       Fruit   carton, tetrapak, bottle
# 197                    F       Fruit     loose, individual, bag
# 198                   FA       Fruit                      tin
# 199                   FA       Fruit                     packet
# 200                   FA       Fruit          loose, individual
# 201                   FA       Fruit          loose, individual
# 202                   FA       Fruit          loose, individual
# 203                   FA       Fruit          loose, individual
# 204                   FA       Fruit                        NaN
# 205                   FA       Fruit          loose, individual
# 206                   FC       Fruit   carton, tetrapak, bottle
# 207                   FA       Fruit                        NaN
# 208                   FC       Fruit   carton, tetrapak, bottle
# 209                   FA       Fruit                        NaN
# 210                   FC       Fruit   carton, tetrapak, bottle
# 211                   FA       Fruit                        tin
# 212                   FA       Fruit                        NaN
# 213                   FA       Fruit                        NaN
# 214                   FA       Fruit                     packet
# 215                   FA       Fruit                     punnet
# 216                   FA       Fruit                     punnet
# 217                   FA       Fruit                      bunch
# 218                   FA       Fruit          loose, individual
# 219                   FA       Fruit                     punnet
# 220                   FA       Fruit                     punnet
# 421                   DG  Vegetables                        tin
# 422                   DG  Vegetables                        NaN
# 423                   DG  Vegetables                        NaN
# 424                   DG  Vegetables                        NaN
# 425                   DG  Vegetables                        NaN
# 426                   DG  Vegetables          loose, individual
# 427                   DG  Vegetables                        tin
# 428                   DG  Vegetables                        jar
# 429                   DG  Vegetables              bunch, packet
# 430                   DG  Vegetables          loose, individual
# 431                   DB  Vegetables                        tin
# 432                   DB  Vegetables                     packet
# 433                   DB  Vegetables                        tin
# 434                   DB  Vegetables                     packet
# 435                   DB  Vegetables                        tin
# 436                   DB  Vegetables                     packet
# 437                   DB  Vegetables                        tin
# 438                   DB  Vegetables                     packet
# 439                   DB  Vegetables                        tin
# 440                   DB  Vegetables                     packet
# 441                   DB  Vegetables                     packet
# 442                   DB  Vegetables                        tin
# 443                   DB  Vegetables                     packet
# 444                   DB  Vegetables                        jar
# 445                   DB  Vegetables                        tin
# 446                   DB  Vegetables                     packet
# 447                   DB  Vegetables                     packet
# 448                   DB  Vegetables                     packet
# 449                   DB  Vegetables                        tin
# 450                   DB  Vegetables                     packet
# 451                   DB  Vegetables                        tin
# 452                   DB  Vegetables                     packet
# 453                   DB  Vegetables                     packet
# 454                   DB  Vegetables                     packet
# 455                   DB  Vegetables                     packet
# 456                   DB  Vegetables                     packet
# 457                   DG  Vegetables          loose, individual
# 458                   DG  Vegetables          loose, individual
# 459                   DG  Vegetables          loose, individual
# 460                   DG  Vegetables                     packet
# 461                   DG  Vegetables                     packet
# 462                   DR  Vegetables                     packet
# 463                   DR  Vegetables                     packet
# 464                   DB  Vegetables          loose, individual
# 465                   DB  Vegetables                        tin
# 466                   DB  Vegetables                     packet
# 467                   DB  Vegetables                        can
# 468                   DG  Vegetables          loose, individual
# 469                   DG  Vegetables          loose, individual
# 470                   DG  Vegetables          loose, individual
# 471                   DG  Vegetables          loose, individual
# 472                   DG  Vegetables          loose, individual
# 473                   DG  Vegetables     loose, individual, bag
# 474                   DG  Vegetables          loose, individual
# 475                   DG  Vegetables          loose, individual
# 476                   DG  Vegetables          loose, individual
# 477                   DG  Vegetables          loose, individual
# 478                   DG  Vegetables          loose, individual
# 479                   DG  Vegetables          loose, individual
# 480                   DG  Vegetables                        bag
# 481                   DR  Vegetables                     packet
# 482                   DR  Vegetables                     packet
# 483                   DR  Vegetables                     packet
# 484                   DR  Vegetables                        tin
# 485                   DG  Vegetables           individual, pack
# 486                   DG  Vegetables                        jar
# 487                   DI  Vegetables                     packet
# 488                   DI  Vegetables                        tin
# 489                   DB  Vegetables                     packet
# 490                   DG  Vegetables                        NaN
# 491                   DG  Vegetables          loose, individual
# 492                   DR  Vegetables                        NaN
# 493                   DB  Vegetables                     packet
# 494                   DB  Vegetables                        can
# 495                   DG  Vegetables          loose, individual
# 496                   DG  Vegetables          loose, individual
# 497                   DG  Vegetables                        NaN
# 498                   DR  Vegetables                     packet
# 499                   DG  Vegetables                     packet
# 500                   DG  Vegetables                        NaN
# 501                   DR  Vegetables                     packet
# 502                   DG  Vegetables                     packet
# 503                   DG  Vegetables          loose, individual
# 504                   DA  Vegetables                        NaN
# 505                  DAP  Vegetables                        NaN
# 506                  DAR  Vegetables                        NaN
# 507                   DF  Vegetables                        tin
# 508                   DF  Vegetables                        NaN
# 509                   DG  Vegetables                        NaN
# 510                   DG  Vegetables          loose, individual
# 511                   DG  Vegetables  loose, individual, packet
# 512                   DG  Vegetables          loose, individual
# 513                   DG  Vegetables          loose, individual
# 514                   DG  Vegetables          loose, individual
# 515                   DR  Vegetables                        NaN
# 516                   DG  Vegetables                        NaN
# 517                   DG  Vegetables                     packet
# 518                   DR  Vegetables                        NaN
# 519                   DG  Vegetables                     packet
# 520                   DG  Vegetables                        NaN
# 521                   DG  Vegetables                        NaN
# 522                   DG  Vegetables                     packet
# 523                   DG  Vegetables                     packet
# 524                   DG  Vegetables                        tin
# 525                   DG  Vegetables                     packet
# 526                   DG  Vegetables                     packet
# 527                   DR  Vegetables                        NaN
# 528                   DR  Vegetables                        NaN
# 529                   DR  Vegetables                        NaN
# 530                   DG  Vegetables                        NaN
# 531                   DR  Vegetables                        NaN
# 532                   DR  Vegetables                     packet
# 533                   DG  Vegetables                     packet
# 534                   DG  Vegetables                        NaN
# 535                   DG  Vegetables                        NaN
# 536                   DG  Vegetables                        NaN
#
#      Similarity Score_FPS Weight_FPS Portion Consumed_FPS  \
# 153              0.350355
# 154              0.267063
# 155              0.000000
# 156              0.324623
# 157              0.695211       125g              per pot
# 158              0.326769
# 159              0.326769
# 160              0.370335
# 161              0.000000
# 162              0.324623
# 163              0.000000
# 164              0.000000
# 165              0.000000
# 166              0.324623
# 167              0.392857
# 168              0.000000
# 169              0.000000
# 170              0.324623
# 171              0.324623
# 172              0.423097
# 173              0.515864
# 174              0.000000
# 175              0.424183
# 176              0.843806       500g                 pack
# 177              0.000000
# 178              0.445366
# 179              0.453672
# 180              0.515864
# 181              0.429971
# 182              0.000000
# 183              0.324623
# 184              0.000000
# 185              0.348651
# 186              0.000000
# 187              0.412167
# 188              0.000000
# 189              0.324623
# 190              0.324623
# 191              0.515864
# 192              0.324623
# 193              0.000000
# 194              0.000000
# 195              0.319790
# 196              0.530214
# 197              0.292930
# 198              0.415927
# 199              0.324623
# 200              0.000000
# 201              0.412167
# 202              0.415927
# 203              0.000000
# 204              0.324623
# 205              0.412167
# 206              0.646407       200g    individual carton
# 207              0.382923
# 208              0.492970
# 209              0.412167
# 210              0.522257
# 211              0.415927
# 212              0.324623
# 213              0.695211       125g              per pot
# 214              0.642767        44g               packet
# 215              0.000000
# 216              0.000000
# 217              0.000000
# 218              0.445366
# 219              0.000000
# 220              0.000000
# 421              0.000000
# 422              0.000000
# 423              0.000000
# 424              0.000000
# 425              0.000000
# 426              0.000000
# 427              0.000000
# 428              0.594410
# 429              0.000000
# 430              0.000000
# 431              0.559229
# 432              0.469653
# 433              0.698585       170g            small can
# 434              0.469653
# 435              0.698585       170g            small can
# 436              0.472677
# 437              0.472677
# 438              0.469653
# 439              0.698585       170g            small can
# 440              0.698585       170g            small can
# 441              0.493974
# 442              0.698585       170g            small can
# 443              0.698585       170g            small can
# 444              0.469653
# 445              0.698585       170g            small can
# 446              0.698585       170g            small can
# 447              0.469653
# 448              0.698585       170g            small can
# 449              0.698585       170g            small can
# 450              0.417556
# 451              0.417556
# 452              0.698585       170g            small can
# 453              0.698585       170g            small can
# 454              0.698585       170g            small can
# 455              0.000000
# 456              0.596422
# 457              0.000000
# 458              0.000000
# 459              0.000000
# 460              0.000000
# 461              0.000000
# 462              0.000000
# 463              0.510222
# 464              0.698585       170g            small can
# 465              0.698585       170g            small can
# 466              0.429161
# 467              0.698585       170g            small can
# 468              0.439411
# 469              0.414588
# 470              0.000000
# 471              0.000000
# 472              0.372787
# 473              0.000000
# 474              0.000000
# 475              0.000000
# 476              0.000000
# 477              0.000000
# 478              0.000000
# 479              0.000000
# 480              0.000000
# 481              0.000000
# 482              0.450275
# 483              0.355268
# 484              0.358754
# 485              0.565405
# 486              0.000000
# 487              0.698585       170g            small can
# 488              0.517497
# 489              0.000000
# 490              0.685131        12g             1 sachet
# 491              0.000000
# 492              0.000000
# 493              0.362730
# 494              0.000000
# 495              0.000000
# 496              0.439411
# 497              0.000000
# 498              0.475067
# 499              0.372787
# 500              0.786443         5g             I sachet
# 501              0.000000
# 502              0.000000
# 503              0.000000
# 504              0.833042        75g                small
# 505              0.374639
# 506              0.332715
# 507              0.513017
# 508              0.483320
# 509              0.000000
# 510              0.000000
# 511              0.000000
# 512              0.000000
# 513              0.000000
# 514              0.000000
# 515              0.281497
# 516              0.000000
# 517              0.000000
# 518              0.000000
# 519              0.713528        60g          Baby Danone
# 520              0.000000
# 521              0.324623
# 522              0.332715
# 523              0.338631
# 524              0.000000
# 525              0.000000
# 526              0.443995
# 527              0.570665
# 528              0.641882       480g                large
# 529              0.000000
# 530              0.385196
# 531              0.000000
# 532              0.446576
# 533              0.000000
# 534              0.000000
# 535              0.596422
# 536              0.571552
#
#      Similarity Score DoH        Pack Size11 Packaging DoH11  \
# 153              0.559708
# 154              1.000000              128.4        Plastic
# 155              0.000000
# 156              0.000000
# 157              0.000000
# 158              0.345343
# 159              0.345343
# 160              0.687877           1 litre       Tetra pak
# 161              0.000000
# 162              0.728406              174.8        Plastic
# 163              0.000000
# 164              0.000000
# 165              1.000000              150g         Plastic
# 166              0.000000
# 167              0.961679              867g         Netting
# 168              0.000000
# 169              0.000000
# 170              0.000000
# 171              0.000000
# 172              0.412227
# 173              0.412227
# 174              0.521306
# 175              0.000000
# 176              1.000000              500g         Plastic
# 177              0.000000
# 178              0.412227
# 179              0.412227
# 180              0.412227
# 181              0.000000
# 182              0.000000
# 183              0.000000
# 184              0.000000
# 185              0.425790
# 186              0.000000
# 187              0.345343
# 188              0.487262
# 189              0.487262
# 190              0.487262
# 191              0.412227
# 192              0.000000
# 193              0.000000
# 194              0.728406              271.3        Netting
# 195              0.672272              271.3        Netting
# 196              0.639806
# 197              0.577350
# 198              0.377113
# 199              1.000000              201.8        Plastic
# 200              0.000000
# 201              0.358958
# 202              0.377113
# 203              0.000000
# 204              0.000000
# 205              0.358958
# 206              0.307686
# 207              0.380459
# 208              0.425790
# 209              0.358958
# 210              0.425790
# 211              0.377113
# 212              0.000000
# 213              0.000000
# 214              0.000000
# 215              0.000000
# 216              0.000000
# 217              0.484471
# 218              0.412227
# 219              1.000000               16.7        Plastic
# 220              0.000000
# 421              0.000000
# 422              0.000000
# 423              0.000000
# 424              0.000000
# 425              0.000000
# 426              0.000000
# 427              0.000000
# 428              0.000000
# 429              0.000000
# 430              0.000000
# 431              1.000000  800g (4 x 200 g)         Plastic
# 432              0.763126                6.0        Plastic
# 433              0.763126                6.0        Plastic
# 434              0.763126                6.0        Plastic
# 435              0.763126                6.0        Plastic
# 436              0.763126                6.0        Plastic
# 437              0.763126                6.0        Plastic
# 438              0.557112
# 439              0.557112
# 440              0.763126                6.0        Plastic
# 441              0.539611
# 442              0.763126                6.0        Plastic
# 443              1.000000                6.0        Plastic
# 444              0.763126                6.0        Plastic
# 445              0.763126                6.0        Plastic
# 446              0.763126                6.0        Plastic
# 447              0.557112
# 448              0.763126                6.0        Plastic
# 449              0.763126                6.0        Plastic
# 450              0.539611
# 451              0.539611
# 452              0.763126                6.0        Plastic
# 453              0.763126                6.0        Plastic
# 454              0.763126                6.0        Plastic
# 455              0.000000
# 456              0.000000
# 457              0.000000
# 458              0.000000
# 459              0.646250
# 460              0.000000
# 461              0.000000
# 462              0.000000
# 463              0.000000
# 464              0.763126                6.0        Plastic
# 465              0.763126                6.0        Plastic
# 466              0.763126                6.0        Plastic
# 467              0.763126                6.0        Plastic
# 468              0.527784
# 469              0.763126              890.8        Plastic
# 470              1.000000              890.8        Plastic
# 471              0.539611
# 472              0.763126              890.8        Plastic
# 473              0.746399               67.2        Plastic
# 474              1.000000             1123.0        Plastic
# 475              0.000000
# 476              0.000000
# 477              0.000000
# 478              0.000000
# 479              0.000000
# 480              0.000000
# 481              0.000000
# 482              1.000000             1123.0        Plastic
# 483              0.000000
# 484              0.000000
# 485              0.000000
# 486              0.000000
# 487              1.000000                6.0        Plastic
# 488              0.657253
# 489              0.000000
# 490              0.000000
# 491              0.000000
# 492              0.000000
# 493              0.389417
# 494              0.000000
# 495              0.000000
# 496              1.000000              290.9        Plastic
# 497              0.000000
# 498              0.000000
# 499              1.000000               23.7        Plastic
# 500              0.000000
# 501              0.000000
# 502              0.000000
# 503              1.000000              200.5        Netting
# 504              0.610879
# 505              0.466763
# 506              0.466763
# 507              0.642214
# 508              1.000000              900g         Plastic
# 509              0.000000
# 510              0.484938
# 511              0.000000
# 512              0.707107              400g         Plastic
# 513              0.484938
# 514              0.000000
# 515              0.000000
# 516              0.000000
# 517              0.000000
# 518              0.707107              200g         Plastic
# 519              1.000000              200g         Plastic
# 520              0.000000
# 521              0.000000
# 522              0.466763
# 523              0.466763
# 524              0.598152
# 525              0.598152
# 526              0.598152
# 527              0.345343
# 528              0.000000
# 529              0.000000
# 530              0.665498
# 531              0.000000
# 532              0.000000
# 533              0.000000
# 534              0.000000
# 535              1.000000              428.9          Metal
# 536              1.000000              428.9          Metal
#
#     Purchase Date DoH11
# 153
# 154         14.11.2011
# 155
# 156
# 157
# 158
# 159
# 160         27.01.2012
# 161
# 162         21.11.2011
# 163
# 164
# 165         23.08.2011
# 166
# 167                 NaN
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176         14.11.2011
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194        21.11.201 1
# 195        21.11.201 1
# 196
# 197
# 198
# 199         18.11.2011
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219         23.08.2011
# 220
# 421
# 422
# 423
# 424
# 425
# 426
# 427
# 428
# 429
# 430
# 431         27.01.2012
# 432         19.09.2011
# 433         19.09.2011
# 434         19.09.2011
# 435         19.09.2011
# 436         19.09.2011
# 437         19.09.2011
# 438
# 439
# 440         19.09.2011
# 441
# 442         19.09.2011
# 443         19.09.2011
# 444         19.09.2011
# 445         19.09.2011
# 446         19.09.2011
# 447
# 448         19.09.2011
# 449         19.09.2011
# 450
# 451
# 452         19.09.2011
# 453         19.09.2011
# 454         19.09.2011
# 455
# 456
# 457
# 458
# 459
# 460
# 461
# 462
# 463
# 464         19.09.2011
# 465         19.09.2011
# 466         19.09.2011
# 467         19.09.2011
# 468
# 469         17.10.2011
# 470         17.10.2011
# 471
# 472         17.10.2011
# 473         10.10.2011
# 474         17.10.2011
# 475
# 476
# 477
# 478
# 479
# 480
# 481
# 482         17.10.2011
# 483
# 484
# 485
# 486
# 487         19.09.2011
# 488
# 489
# 490
# 491
# 492
# 493
# 494
# 495
# 496         26.09.2011
# 497
# 498
# 499         03.10.2011
# 500
# 501
# 502
# 503         10.10.2011
# 504
# 505
# 506
# 507
# 508         27.01.2012
# 509
# 510
# 511
# 512         14.11.2011
# 513
# 514
# 515
# 516
# 517
# 518         28.09.2011
# 519         28.09.2011
# 520
# 521
# 522
# 523
# 524
# 525
# 526
# 527
# 528
# 529
# 530
# 531
# 532
# 533
# 534
# 535         27.01.2012
# 536         27.01.2012

# %% [markdown]
#                                                         Export Data

# %%
#redFood_matched.to_csv(r"C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\ReducedwithWeights\Matched_dataproduct2.csv")

# %% [markdown]
#                                                        Next Notebook
