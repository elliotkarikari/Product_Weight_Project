# %% [markdown]
# # Matching Algorithm - Matching Through Food Description

# %% [markdown]
# ##### Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re #regular expressions 
from fuzzywuzzy import fuzz
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.font_manager as fm

# %%
# %load_ext watermark

# %%
# %watermark --iversion
# Out:
# matplotlib: 3.7.1
# sklearn   : 1.2.2
# seaborn   : 0.12.2
# pandas    : 1.5.3
# re        : 2.2.1
# fuzzywuzzy: 0.18.0
# numpy     : 1.23.5

# %% [markdown]
# ##### Read In Data

# %% [markdown]
#                                                       M&W Reduced

# %%
#pd.set_option('display.max_rows', None)
redFood = pd.read_csv(r"C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\MW_DataReduction\Reduced Super Group\Cleaned\Reduced_SecondClean.csv", index_col=0)
redFood.rename(columns={'Group':'Food sub-group codes'}, inplace=True)
redFood.rename(columns={'Super Group':'Food Group'}, inplace=True)
redFood['Food Name'] = redFood['Food Name'].str.lower()
redFood.head()
# Out:
#   Food Code                    Food Name Food sub-group codes  \
# 0    17-208  beer, bitter, best, premium                   QA
# 1    17-224                 cider, sweet                   QC
# 2    17-234                         port                   QF
# 3    17-236               sherry, medium                   QF
# 4    17-247          spirits, 40% volume                   QK
#
#             Food Group                                Sale format(s)
# 0  Alcoholic beverages  can, can multipack, bottle, bottle multipack
# 1  Alcoholic beverages  can, can multipack, bottle, bottle multipack
# 2  Alcoholic beverages                                        bottle
# 3  Alcoholic beverages                                        bottle
# 4  Alcoholic beverages                             bottle, miniature

# %% [markdown]
#                                Counts of Foods by Food Group Column in reduced M&W Dataset

# %%
#redFood.drop(['Normalized Food Name'], axis=1, inplace=True)

# %%
redFood.groupby('Food Group')['Food Name'].count().sum()
# Out:
# 535

# %% [markdown]
#                                                        M&W Dataset

# %%
mFood = pd.read_csv(r"C:\Users\medekar\Desktop\Product_Weight_Project\Data\Raw Data\Labelling2021_watercress2.csv", index_col=0)
mFood.rename(columns={'Group':'Food sub-group codes'}, inplace=True)
mFood
# Out:
#      Food Code                                          Food Name  \
# 0       13-145                             Ackee, canned, drained
# 1       13-146                                        Agar, dried
# 2       13-147                    Agar, dried, soaked and drained
# 3       13-148                               Alfalfa sprouts, raw
# 4       13-801                                   Allspice, ground
# ...        ...                                                ...
# 2882    12-515            Yogurt, whole milk, twin pot, not fruit
# 2883    12-531  Yogurt, whole milk, twin pot, thick and creamy...
# 2884    11-960  Yorkshire pudding, made with semi-skimmed milk...
# 2885   11-1135  Yorkshire pudding, made with skimmed milk, hom...
# 2886   11-1146            Yorkshire pudding, made with whole milk
#
#                                             Description Food sub-group codes  \
# 0                                                8 cans                   DG
# 1                                    Literature sources                   DG
# 2                                    Literature sources                   DG
# 3                     Analytical and literature sources                   DG
# 4                                    Literature sources                    H
# ...                                                 ...                  ...
# 2882  With biscuit pieces and chocolate-coated cerea...                   BN
# 2883             11 samples, 8 brands, various flavours                   BN
# 2884                                             Recipe                   AT
# 2885                                             Recipe                   AT
# 2886                                             Recipe                   AT
#
#      Previous                               Main data references Footnote  \
# 0         554  MW4, 1978; and Vegetables, Herbs and Spices Su...      NaN
# 1         NaN  Wu Leung et al. (1972) Food composition table ...      NaN
# 2         NaN  Wu Leung et al. (1972) Food composition table ...      NaN
# 3         NaN      Vegetables, Herbs and Spices Supplement, 1991      NaN
# 4         NaN  Marsh et al. (1977) Composition of foods: spic...      NaN
# ...       ...                                                ...      ...
# 2882      NaN      Estimated from 2013 product label information      NaN
# 2883  12-374   Reviewed 2013. LGC, Nutritional analysis of fo...      NaN
# 2884      NaN           As MW6. Recalculated from 11-607 in 2013      NaN
# 2885  11-713                                        Updated 2014      NaN
# 2886  11-607                                   Recalculated 2014      NaN
#
#      Energy (kJ) Energy (kcal)  Fat (g) Saturates (g) Carbohydrate (g)  \
# 0            639           155     15.2          4.44              0.8
# 1            721           180      1.2           0.3                0
# 2            127            32      0.1             0                0
# 3            113            27      0.7          0.07              0.3
# 4           1536           366      8.7           2.5             55.1
# ...          ...           ...      ...           ...              ...
# 2882         625           149      5.6           3.2             20.3
# 2883         469           112      3.2             N             15.7
# 2884         829           198      8.3          1.89             23.3
# 2885         803           191      7.4          1.23             23.6
# 2886         889           212      9.8          2.78             23.5
#
#      Sugars (g) Starch (g) Fibre (g)  Protein (g) Salt (g)  \
# 0           0.8          0       1.8          2.9      0.6
# 1             0          0      81.1          1.6     0.28
# 2             0          0        15          0.2     0.03
# 3           0.3          0       1.7          4.0     0.02
# 4          55.1          0      21.6          6.1     0.19
# ...         ...        ...       ...          ...      ...
# 2882       17.3          3       0.3          4.1     0.25
# 2883       15.2        0.5         1          4.4     0.13
# 2884        3.2       20.1       1.1          6.9     0.13
# 2885        3.3       20.3       1.1          7.0     0.14
# 2886        3.2       20.3       1.1          6.9     0.13
#
#                         FoodGroup
# 0                      Vegetables
# 1                      Vegetables
# 2                      Vegetables
# 3                      Vegetables
# 4                Herbs and spices
# ...                           ...
# 2882       Milk and milk products
# 2883       Milk and milk products
# 2884  Cereals and cereal products
# 2885  Cereals and cereal products
# 2886  Cereals and cereal products
#
# [2887 rows x 18 columns]

# %% [markdown]
# Data Types

# %%
mFood.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2887 entries, 0 to 2886
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Food Code             2887 non-null   object
#  1   Food Name             2887 non-null   object
#  2   Description           2887 non-null   object
#  3   Food sub-group codes  2887 non-null   object
#  4   Previous              1867 non-null   object
#  5   Main data references  2886 non-null   object
#  6   Footnote              12 non-null     object
#  7   Energy (kJ)           2887 non-null   object
#  8   Energy (kcal)         2887 non-null   object
#  9   Fat (g)               2887 non-null   float64
#  10  Saturates (g)         2884 non-null   object
#  11  Carbohydrate (g)      2887 non-null   object
#  12  Sugars (g)            2887 non-null   object
#  13  Starch (g)            2887 non-null   object
#  14  Fibre (g)             2886 non-null   object
#  15  Protein (g)           2887 non-null   float64
#  16  Salt (g)              2887 non-null   object
#  17  FoodGroup             2887 non-null   object
# dtypes: float64(2), object(16)
# memory usage: 428.5+ KB

# %% [markdown]
#                          Joining Foods by Food Group Column to M&W & Counting items per Food Group

# %%
# # Create a dictionary mapping 'Group' to 'SuperGroup'
# group_to_super_group = dict(zip(redFood['Food sub-group codes'], redFood['Food Group']))

# # Add a new column 'SuperGroup' to df1 based on 'Group' match
# mFood['FoodGroup'] = mFood['Food sub-group codes'].map(group_to_super_group)

# #ww = mFood.merge(redFood, on='Group', how='inner').drop_duplicates()
# mFood.groupby('FoodGroup')['Food Name'].count().sum()

# %% [markdown]
# ##### Count should be 2887, Check Matching and Imputation

# %%
#mFood[mFood['FoodGroup'].isna()]

# %% [markdown]
#                                         Filling in blank FoodGroup rows

# %% [markdown]
# Beverages

# %%
# pd.set_option('display.max_rows', None)
# pty = mFood[mFood['FoodGroup'].isna()]
# aa = pty[pty['Food sub-group codes'].str.startswith('P')]
# aa['FoodGroup'] = 'Beverages'

# %%
# mFood.update(aa)

# %% [markdown]
# Meats

# %%
# pd.set_option('display.max_rows', None)
# ty = mFood[mFood['FoodGroup'].isna()]
# ab = pty[pty['Food sub-group codes'].str.startswith('M')]
# ab['FoodGroup'] = 'Meat and meat products'

# %%
# mFood.update(ab)

# %% [markdown]
# Fats and Oils

# %%
# pd.set_option('display.max_rows', None)
# pty = mFood[mFood['FoodGroup'].isna()]
# ac = pty[pty['Food sub-group codes'].str.startswith('O')]
# ac['FoodGroup'] = 'Fats and oils'

# %%
# mFood.update(ac)

# %% [markdown]
# Soups, sauces and miscellaneous foods

# %%
# pd.set_option('display.max_rows', None)
# pty = mFood[mFood['FoodGroup'].isna()]
# ad = pty[pty['Food sub-group codes'].str.startswith('W')]
# ad['FoodGroup'] = 'Soups, sauces and miscellaneous foods'

# %%
# mFood.update(ad)

# %% [markdown]
# Milk and milk products

# %%
# pd.set_option('display.max_rows', None)
# pty = mFood[mFood['FoodGroup'].isna()]
# af = pty[pty['Food sub-group codes'].str.startswith('B')]
# af['FoodGroup'] = 'Milk and milk products'

# %%
# mFood.update(af)

# %% [markdown]
# Fish and fish products

# %%
# pd.set_option('display.max_rows', None)
# pty = mFood[mFood['FoodGroup'].isna()]
# aj = pty[pty['Food sub-group codes'].str.startswith('J')]
# aj['FoodGroup'] = 'Fish and fish products'

# %%
# mFood.update(aj)

# %% [markdown]
# Sugars, preserves and snacks

# %%
# pd.set_option('display.max_rows', None)
# pty = mFood[mFood['FoodGroup'].isna()]
# asb = pty[pty['Food sub-group codes'].str.startswith('S')]
# asb['FoodGroup'] = 'Sugars, preserves and snacks'

# %%
# mFood.update(asb)

# %% [markdown]
# Vegetables

# %%
# pd.set_option('display.max_rows', None)
# pty = mFood[mFood['FoodGroup'].isna()]
# av = pty[pty['Food sub-group codes'].str.startswith('D')]
# av['FoodGroup'] = 'Vegetables'

# %%
# mFood.update(av)

# %% [markdown]
# Eggs

# %%
# pd.set_option('display.max_rows', None)
# pty = mFood[mFood['FoodGroup'].isna()]
# ag = pty[pty['Food sub-group codes'].str.startswith('C')]
# ag['FoodGroup'] = 'Eggs'

# %%
# mFood.update(ag)

# %% [markdown]
# Cereals and cereal products

# %%
# pd.set_option('display.max_rows', None)
# pty = mFood[mFood['FoodGroup'].isna()]
# acc = pty[pty['Food sub-group codes'].str.startswith('A')]
# acc['FoodGroup'] = 'Cereals and cereal products'

# %%
# mFood.update(acc)

# %% [markdown]
# Alcoholic beverages

# %%
# pd.set_option('display.max_rows', None)
# pty = mFood[mFood['FoodGroup'].isna()]
# aq = pty[pty['Food sub-group codes'].str.startswith('Q')]
# aq['FoodGroup'] = 'Alcoholic beverages'

# %%
#mFood.update(aq)

# %% [markdown]
#                                Counts of Foods by Food Group Column in M&W Dataset

# %%
mFood.groupby('FoodGroup')['Food Name'].count()#.sum()
# Out:
# FoodGroup
# Alcoholic beverages                       16
# Beverages                                 89
# Cereals and cereal products              378
# Eggs                                      33
# Fats and oils                             32
# Fish and fish products                   285
# Fruit                                    228
# Herbs and spices                          61
# Meat and meat products                   650
# Milk and milk products                   186
# Nuts and seeds                            50
# Soups, sauces and miscellaneous foods    130
# Sugars, preserves and snacks              76
# Vegetables                               673
# Name: Food Name, dtype: int64

# %%
#mFood.to_csv(r"C:\Users\medekar\Desktop\Product_Weight_Project\Data\Raw Data\Labelling2021_watercress2.csv")

# %% [markdown]
#                                                          FPS Data

# %%
CleanRetai = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\FoodPortionSized\FPS_VJ.csv')
CleanRetai['Food Name'] = CleanRetai['Food Name'].str.lower()
CleanRetai.tail()
# Out:
#                            Group   Brand               Food Name  \
# 2672  YOGHURTS AND FROMAGE FRAIS     NaN                   onken
# 2673  YOGHURTS AND FROMAGE FRAIS     NaN           petit danoneâ
# 2674  YOGHURTS AND FROMAGE FRAIS     NaN  st ivel fiendish faces
# 2675  YOGHURTS AND FROMAGE FRAIS     NaN      baby fromage frais
# 2676  YOGHURTS AND FROMAGE FRAIS  Heinz       baby fromage frais
#
#      Portion Consumed Weight PurEqualCon  Purchased Format Source
# 2672              NaN   200g         NaN        NaN    NaN    NaN
# 2673            small    50g         NaN        NaN    NaN    NaN
# 2674              NaN    50g         NaN        NaN    NaN    NaN
# 2675      Baby Danone    60g           Y        NaN    NaN    NaN
# 2676              Jar   163g           Y        NaN    NaN    NaN

# %%
CleanRetail = CleanRetai[CleanRetai['PurEqualCon'].isin(['Y', 'Y, P'])]
CleanRetail.head()
# Out:
#         Group  Brand                       Food Name Portion Consumed Weight  \
# 0  BABY FOODS  Boots   first harvest,dessert starter              NaN   125g
# 1  BABY FOODS  Boots  first harvest, infant desserts              NaN   125g
# 2  BABY FOODS  Boots  first harvest,infant savouries              NaN   125g
# 3  BABY FOODS  Boots   first harvest,junior desserts              NaN   190g
# 4  BABY FOODS  Boots  first harvest,junior savouries              NaN   190g
#
#   PurEqualCon  Purchased Format Source
# 0           Y        NaN    NaN    NaN
# 1           Y        NaN    NaN    NaN
# 2           Y        NaN    NaN    NaN
# 3           Y        NaN    NaN    NaN
# 4           Y        NaN    NaN    NaN

# %% [markdown]
# ###                                                        Match Data.
#
# ###### Once matched, Import Weight and Unit Columns into Reduced M&W table

# %% [markdown]
# # 1

# %% [markdown]
#                                                    Using Fuzzy Matching

# %%
def preprocess_text(df, column_name):
    # Remove punctuation and convert to lowercase
    return df[column_name].apply(lambda x: re.sub(r'[^\w\s]', '', x.lower()))

def match_food_group(CleanRetail, redFood):
    """
    Matches food groups between two DataFrames using fuzzy matching and updates 
    redFood database with Weight and Unit from CleanRetail dataframe.

    Args:
        CleanRetail (DataFrame): The DataFrame containing the clean retail data.
        redFood (DataFrame): The DataFrame containing the red food data.

    Returns:
        DataFrame: The red food DataFrame with updated weight, unit, and super group values.
    """
    # Set a threshold for fuzzy matching.
    threshold = 65

    # Create a set to store the SKU descriptions that have already been matched.
    matched_skus = set()

    # Create a mapping dictionary for efficient lookups.
    food_mapping = {}
    for _, row in CleanRetail.iterrows():
        food_mapping[row['Food Name']] = {
            'Weight': row['Weight'],
            'PurEqualCon': row['PurEqualCon'],
            'Portion Consumed': row['Portion Consumed'],
        }

    # Add Weight and Unit columns to the redFood DataFrame.
    redFood['Weight'] = ''
    redFood['PurEqualCon'] = ''
    redFood['Portion Consumed'] = ''

    # Loop through the rows in the redFood DataFrame.
    for i, row in redFood.iterrows():
        # Get the food name from the current row.
        product = row['Food Name']

        # Check if the food name has already been matched.
        if product in matched_skus:
            continue

        # Check similarity between the food name and SKU descriptions using fuzzy matching.
        matches = CleanRetail['Food Name'].apply(lambda x: fuzz.token_sort_ratio(x, product) >= threshold)

        # Replace NaN values in the boolean Series with False.
        matches = matches.fillna(False)

        # If any match is found, update the 'Weight', 'Unit', and 'Super Group' values in the redFood DataFrame.
        if matches.any():
            match_indices = matches[matches].index
            match_index = match_indices[0]
            food_info = food_mapping[CleanRetail.at[match_index, 'Food Name']]

            redFood.at[i, 'Weight'] = food_info['Weight']
            redFood.at[i, 'PurEqualCon'] = food_info['PurEqualCon']
            redFood.at[i, 'Portion Consumed'] = food_info['Portion Consumed']

            matched_skus.add(product)

    return redFood


redFood1 = match_food_group(CleanRetail.copy(), redFood.copy())

# %%
redFood1['Source'] = ' '

# %% [markdown]
# ###### Identifying all columns with weights and assigning data source

# %%
pd.set_option('display.max_rows', None)
WeiRdf1 = redFood1.loc[redFood1['Weight'] != '']
WeiRdf1['Source'] = 'FPS'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_21936\2909531313.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WeiRdf1['Source'] = 'FPS'

# %% [markdown]
# ###### Updating Red M&W List with Source indications

# %%
redFood1.update(WeiRdf1)

# %%
a = redFood1.loc[redFood1['Weight'] != '']
a['Weight'].value_counts().sum()
# Out:
# 97

# %% [markdown]
# ### 97 / 535 items Matched Using Algo 1

# %%
f'First Algorithm Matched {round((97/535) * 100, 2)}% of products between McCane and Widdowson df and Food Portion Sizes df'
# Out:
# 'First Algorithm Matched 18.13% of products between McCane and Widdowson df and Food Portion Sizes df'

# %% [markdown]
# # 2

# %% [markdown]
#                                     Using Term Frequency-Inverse Document Frequency
#
# Its a feature extraction technique used in natural language processing and information retrieval. The main purpose of TfidfVectorizer is to transform a collection of text documents into a numerical feature matrix that can be used as input for machine learning algorithms.
#
# Starts with:
#
# Tokenization: The input text is first split into individual words or tokens.
#
# Term Frequency (TF): For each token, the term frequency is calculated, which represents the number of times a token appears in a specific document.
#
# Inverse Document Frequency (IDF): The inverse document frequency measures how important a word is in the entire collection of documents. If a word appears frequently in many documents, its IDF score will be low. But if a word is rare and only appears in a few documents, its IDF score will be high.
#
# TF-IDF Weighting: The TF-IDF score is calculated for each token in each document by multiplying the term frequency (TF) with the inverse document frequency (IDF)(how unique it is among all the documents).
#
# The result is that words that appear often in a document but are rare overall get a high TF-IDF score.

# %%
# %%time

def match_food_groupUTF(CleanRetail, redFood):
    """
    Matches food groups between two DataFrames using TF-IDF and cosine similarity and updates 
    redFood database with Weight and Unit from CleanRetail dataframe.

    Args:
        CleanRetail (DataFrame): The DataFrame containing the clean retail data.
        redFood (DataFrame): The DataFrame containing the red food data.

    Returns:
        DataFrame: The red food DataFrame with updated weight and unit values.
    """
    # Set a threshold for cosine similarity.
    threshold = 0.65

    # Add Weight and Unit columns to the redFood DataFrame.
    redFood['Weight'] = ''
    redFood['PurEqualCon'] = ''
    redFood['Portion Consumed'] = ''

    # Preprocess text data in both DataFrames for the "Food Name" field.
    CleanRetail['Food Name'] = CleanRetail['Food Name'].str.lower()
    redFood['Food Name'] = redFood['Food Name'].str.lower()

    # Create a TF-IDF vectorizer for the "Food Name" field only in the redFood DataFrame.
    vectorizer = TfidfVectorizer()
    vectorizer.fit(CleanRetail['Food Name'])

    # Transform the "Food Name" field into TF-IDF vectors for both DataFrames.
    tfidf_clean_retail = vectorizer.transform(CleanRetail['Food Name'])
    tfidf_red_food = vectorizer.transform(redFood['Food Name'])

    # Loop through the rows in the redFood DataFrame.
    for i, row in redFood.iterrows():
        # Get the food name from the current row.
        product = row['Food Name']

        # Calculate cosine similarity between the food name and all CleanRetail food names.
        similarities = cosine_similarity(tfidf_red_food[i], tfidf_clean_retail)

        # Find the index of the most similar food name based on cosine similarity.
        match_index = similarities.argmax()

        # If the similarity exceeds the threshold, update the 'Weight' and 'PurEqualCon' values in the redFood DataFrame.
        if similarities[0, match_index] >= threshold:
            food = CleanRetail.loc[CleanRetail.index[match_index], 'Weight']
            unit = CleanRetail.loc[CleanRetail.index[match_index], 'PurEqualCon']
            consumed = CleanRetail.loc[CleanRetail.index[match_index], 'Portion Consumed']

            redFood.at[i, 'Weight'] = food
            redFood.at[i, 'PurEqualCon'] = unit
            redFood.at[i, 'Portion Consumed'] = consumed

    return redFood

redFood2 = match_food_groupUTF(CleanRetail.copy(), redFood.copy())
# Out:
# CPU times: total: 641 ms
# Wall time: 633 ms

# %%
redFood2['Source'] = ' '

# %% [markdown]
# ###### Identifying all columns with weights and assigning data source

# %%
pd.set_option('display.max_rows', None)
WeiRdf2 = redFood2.loc[redFood2['Weight'] != '']
WeiRdf2['Source'] = 'FPS'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_21936\1784067148.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WeiRdf2['Source'] = 'FPS'

# %% [markdown]
# ###### Updating Red M&W List with Source indications

# %%
redFood2.update(WeiRdf2)

# %%
#redFood2
b = redFood2.loc[redFood2['Weight'] != '']
b.tail()
# Out:
#     Food Code                   Food Name Food sub-group codes  Food Group  \
# 482    15-637  cauliflower cheese, retail                   DR  Vegetables
# 487    13-608          green beans, dried                   DI  Vegetables
# 500    13-298         mustard leaves, raw                   DG  Vegetables
# 504       NaN                   potatoes,                   DA  Vegetables
# 529    15-617            sushi, vegetable                   DR  Vegetables
#
#     Sale format(s)     Weight PurEqualCon Portion Consumed Source
# 482         packet       185g           Y              NaN    FPS
# 487         packet       170g           Y        small can    FPS
# 500            NaN         5g           Y         I sachet    FPS
# 504            NaN        75g           Y            small    FPS
# 529            NaN  210g/440g           Y              can    FPS

# %%
b['Weight'].value_counts().sum()
# Out:
# 86

# %% [markdown]
# ### 86 / 535 items Matched Using Algo 2

# %%
f'Second Algorithm Matched {round((86/535) * 100, 2)}% of products between McCane and Widdowson df and Food Portion Sizes df. Contains some errors'
# Out:
# 'Second Algorithm Matched 16.07% of products between McCane and Widdowson df and Food Portion Sizes df. Contains some errors'

# %% [markdown]
# # 3

# %% [markdown]
#                                                Using Fuzzy Matching

# %% [markdown]
# Here, I use fuzz.token_set_ratio from the fuzzywuzzy library to calculate a similarity score between each food name in redFood and all food names in CleanRetail. The token_set_ratio function considers the set of unique tokens (words) in the strings and calculates the similarity based on common token matches. The similarity score ranges from 0 to 100, where higher values indicate more similarity.
#
#
# By adjusting the threshold value, you can control the matching sensitivity. Lower threshold values will allow for more leniency in matching, potentially catching more variations, while higher threshold values will require closer matches.

# %%
# %%time

def match_food_groupFuzz(CleanRetail, redFood):
    """
    Matches food groups between two DataFrames using approximate string matching and updates 
    redFood database with Weight and Unit from CleanRetail dataframe.

    Args:
        CleanRetail (DataFrame): The DataFrame containing the clean retail data.
        redFood (DataFrame): The DataFrame containing the red food data.

    Returns:
        DataFrame: The red food DataFrame with updated weight and unit values.
    """
    # Set a threshold for string matching similarity.
    threshold = 65  # You can experiment with different threshold values (0 to 100).

    # Add Weight and Unit columns to the redFood DataFrame.
    redFood['Weight'] = ''
    redFood['PurEqualCon'] = ''
    redFood['Portion Consumed'] = ''
    redFood['Source'] = ''

    # Preprocess text data in both DataFrames for the "Food Name" field.
    CleanRetail['Food Name'] = CleanRetail['Food Name'].str.lower()
    redFood['Food Name'] = redFood['Food Name'].str.lower()

    # Loop through the rows in the redFood DataFrame.
    for i, row in redFood.iterrows():
        # Get the food name from the current row.
        product = row['Food Name']

        # Find the most similar food name in CleanRetail using fuzzy string matching.
        best_match = 60
        best_score = 0

        for _, retail_row in CleanRetail.iterrows():
            retail_product = retail_row['Food Name']
            similarity_score = fuzz.partial_token_set_ratio(product, retail_product)

            if similarity_score > best_score and similarity_score >= threshold:
                best_score = similarity_score
                best_match = retail_row

        # If the similarity exceeds the threshold, update the 'Weight' and 'PurEqualCon' values in the redFood DataFrame.
        if best_match is not 60:
            food = best_match['Weight']
            unit = best_match['PurEqualCon']
            consumed = best_match['Portion Consumed']
            sourced = best_match['Source']

            redFood.at[i, 'Weight'] = food
            redFood.at[i, 'PurEqualCon'] = unit
            redFood.at[i, 'Portion Consumed'] = consumed
            redFood.at[i, 'Source'] = sourced

    return redFood

redFood3 = match_food_groupFuzz(CleanRetail.copy(), redFood.copy())
# Out:
# <timed exec>:44: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# CPU times: total: 50.1 s
# Wall time: 50.2 s

# %% [markdown]
#                               Creating Source column so I can Identify weight Inputs source

# %% [markdown]
# ###### Identifying all columns with weights and assigning data source

# %%
pd.set_option('display.max_rows', None)
WeiRdf3 = redFood3.loc[redFood3['Weight'] != '']

WeiRdf3['Source'] = WeiRdf3['Source'].fillna('FPS')
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_21936\3809329642.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WeiRdf3['Source'] = WeiRdf3['Source'].fillna('FPS')

# %% [markdown]
# ###### Updating Red M&W List with Source indications

# %%
redFood3.update(WeiRdf3)

# %%
redFood3.head()
# Out:
#   Food Code                    Food Name Food sub-group codes  \
# 0    17-208  beer, bitter, best, premium                   QA
# 1    17-224                 cider, sweet                   QC
# 2    17-234                         port                   QF
# 3    17-236               sherry, medium                   QF
# 4    17-247          spirits, 40% volume                   QK
#
#             Food Group                                Sale format(s) Weight  \
# 0  Alcoholic beverages  can, can multipack, bottle, bottle multipack   574g
# 1  Alcoholic beverages  can, can multipack, bottle, bottle multipack   300g
# 2  Alcoholic beverages                                        bottle   161g
# 3  Alcoholic beverages                                        bottle
# 4  Alcoholic beverages                             bottle, miniature    29g
#
#   PurEqualCon                 Portion Consumed Source
# 0           Y                           1 pint    FPS
# 1           Y                              NaN    FPS
# 2           Y  Hot wings, with bones, 5 pieces    FPS
# 3
# 4           Y                      1 miniature    FPS

# %%
c = redFood3.loc[redFood3['Weight'] != '']
c['Food Name'].value_counts().sum()
# Out:
# 523

# %% [markdown]
# ### 523 / 535 items Matched Using Algo 3 with threshold 65 using a fuzz.partial_token_set_ratio

# %%
f'Third Algorithm Matched {round((523/535) * 100, 2)}% of products between McCane and Widdowson df and Food Portion Sizes df at a threshold of 65. Contains some errors'
# Out:
# 'Third Algorithm Matched 97.76% of products between McCane and Widdowson df and Food Portion Sizes df at a threshold of 65. Contains some errors'

# %% [markdown]
# Exporting Updated dataframe

# %%
#redFood3.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\ReducedwithWeights\RedM&Weight.csv')

# %% [markdown]
# ## Not Matched Feeds Into second Algo

# %%
c1 = redFood3.loc[redFood3['Weight'] == '']
c1['Food Name'].value_counts().sum()
# Out:
# 12

# %% [markdown]
#                                             Visualising Matching Efficiency

# %%
# Matched Product Counts.
ax1_count = redFood.groupby('Food Group')['Food Name'].count().rename('Total Prod Count', inplace=True).copy().sort_values(ascending=True)
ax2_count = redFood.groupby('Food Group')['Food Name'].count().rename('Total Prod Count', inplace=True).copy().sort_values(ascending=True)
ax3_count = redFood.groupby('Food Group')['Food Name'].count().rename('Total Prod Count', inplace=True).copy().sort_values(ascending=True)

#Total Product Counts
ax1_s = a.groupby('Food Group')['PurEqualCon'].count().rename('Matched Prod Count', inplace=True).copy().sort_values(ascending=True)
ax2_s = b.groupby('Food Group')['PurEqualCon'].count().rename('Matched Prod Count', inplace=True).copy().sort_values(ascending=True)
ax3_s = c.groupby('Food Group')['PurEqualCon'].count().rename('Matched Prod Count', inplace=True).copy().sort_values(ascending=True)

# %%
#
ax1_nt = pd.DataFrame(ax1_count).reset_index()
ax2_nt = pd.DataFrame(ax2_count).reset_index()
ax3_nt = pd.DataFrame(ax3_count).reset_index()

# Find Total Counts of All Categories 
ax1 = pd.DataFrame(ax1_s).reset_index()
ax2 = pd.DataFrame(ax2_s).reset_index()
ax3 = pd.DataFrame(ax3_s).reset_index()

# Evaluating Percentaged Mapped
ax1_counts = ax1_nt.merge(ax1, on='Food Group', how='left')
ax1_counts['%Matched'] = ax1_counts['Matched Prod Count'] / ax1_counts['Total Prod Count'] * 100 

ax2_counts = ax2_nt.merge(ax2, on='Food Group', how='left')
ax2_counts['%Matched'] = ax2_counts['Matched Prod Count'] / ax2_counts['Total Prod Count'] * 100 

ax3_counts = ax3_nt.merge(ax3, on='Food Group', how='left')
ax3_counts['%Matched'] = ax3_counts['Matched Prod Count'] / ax3_counts['Total Prod Count'] * 100

# %%
# Find the minimum count in each grouped DataFrame.
min_count1 = ax1_counts['%Matched'].min()
min_count2 = ax2_counts['%Matched'].min()
min_count3 = ax3_counts['%Matched'].min()

# Create a list of colors for the bars. If count equals the minimum count, set the color to red; otherwise, set it to teal.
bar_colors1 = ['#f95d6a' if count == min_count1 else 'lightpink' for count in ax1_counts['%Matched']]
bar_colors2 = ['#f95d6a' if count == min_count2 else 'lightpink' for count in ax2_counts['%Matched']]
bar_colors3 = ['#f95d6a' if count == min_count3 else 'lightpink' for count in ax3_counts['%Matched']]

# Create a figure with three subplots (1 row, 3 columns) for each algorithm's matching output evaluation.
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex=True, sharey=True)
fig.set_size_inches(25, 10)

# Plot the bar chart for each algorithm's matching output evaluation.
ax1.barh(ax1_counts['Food Group'], ax1_counts['%Matched'], color=bar_colors1)
ax1.set_title('Evaluating fuzz.token_sort_ratio, Algo1', fontsize=20)

ax2.barh(ax2_counts['Food Group'], ax2_counts['%Matched'], color=bar_colors2)
ax2.set_title('Evaluating TfidfVectorizer, Algo 2', fontsize=20)

ax3.barh(ax3_counts['Food Group'], ax3_counts['%Matched'], color=bar_colors3)
ax3.set_title('Evaluating partial_token_set_ratio, Algo 3', fontsize=20)

# Set the label for the common x-axis and y-axis of the subplots.
fig.supxlabel("Percentage Matched")
fig.supylabel("Super Group")

plt.show()

# %% [markdown]
# ### Algo 3 most successful with Matching but contains errors. Evaluate Success rate of Matching.
#
# I would Use a combination of Algo 2 and 3 for final data product, However set a very high threshold for first algo

# %% [markdown]
# # 4

# %% [markdown]
# ###### Algorithm

# %%
def preprocess_text(df, column_name):
    return df[column_name].str.lower()

def fuzzy_matching_score(source, target):
    return fuzz.partial_token_set_ratio(source, target)

def get_most_similar_indices(tfidf_red_food, tfidf_clean_retail):
    similarities = cosine_similarity(tfidf_red_food, tfidf_clean_retail)
    return similarities.argmax(axis=1)

def hybrid_fuzzy_matching(CleanRetail, redFood):
    # Set thresholds for matching
    partial_token_set_ratio_threshold = 98
    cosine_similarity_threshold = 0.70
    min_similarity_threshold = 0.47

    # Preprocess text data in both DataFrames for the "Food Name" field.
    CleanRetail['Food Name'] = preprocess_text(CleanRetail, 'Food Name')
    redFood['Food Name'] = preprocess_text(redFood, 'Food Name')

    # Step 1: Partial Token Set Ratio (Fuzzy Matching)
    CleanRetail['Partial Token Set Ratio'] = CleanRetail['Food Name'].apply(lambda x: fuzzy_matching_score(x, redFood['Food Name']))
    potential_matches = CleanRetail[CleanRetail['Partial Token Set Ratio'] >= partial_token_set_ratio_threshold]

    # Step 2: TF-IDF and Cosine Similarity (Text Matching) - Use combined matches as input
    vectorizer = TfidfVectorizer()
    vectorizer.fit(potential_matches['Food Name'])
    tfidf_clean_retail = vectorizer.transform(potential_matches['Food Name'])
    tfidf_red_food = vectorizer.transform(redFood['Food Name'])

    # Find the most similar match for each redFood product
    max_sim_indices = get_most_similar_indices(tfidf_red_food, tfidf_clean_retail)
    max_sim_scores = cosine_similarity(tfidf_red_food, tfidf_clean_retail).max(axis=1)

    # Update redFood DataFrame with matched information and sources
    redFood['Similarity Score'] = max_sim_scores
    redFood['Weight'] = potential_matches['Weight'].values[max_sim_indices]
    redFood['PurEqualCon'] = potential_matches['PurEqualCon'].values[max_sim_indices]
    redFood['Portion Consumed'] = potential_matches['Portion Consumed'].values[max_sim_indices]

    # Create a mapping dictionary for matched indices to their sources
    match_indices_to_sources = dict(zip(potential_matches.index, potential_matches['Source']))

    # Map the sources and format to the redFood DataFrame based on matched indices
    redFood['Source'] = redFood.index.map(lambda i: match_indices_to_sources.get(max_sim_indices[i], ''))
    
    # Set to NaN for rows where similarity score is below the minimum threshold
    redFood.loc[redFood['Similarity Score'] < min_similarity_threshold, ['Weight', 'PurEqualCon', 'Portion Consumed', 'Source']] = ''

    return redFood

# Call the hybrid_fuzzy_matching function and get the matched DataFrame
redFood_matched = hybrid_fuzzy_matching(CleanRetail.copy(), redFood.copy())

# %%
redFood_matched
# Out:
#     Food Code                                          Food Name  \
# 0      17-208                        beer, bitter, best, premium
# 1      17-224                                       cider, sweet
# 2      17-234                                               port
# 3      17-236                                     sherry, medium
# 4      17-247                                spirits, 40% volume
# 5      17-239                                      vermouth, dry
# 6      17-752                                          wine, red
# 7      17-756                                wine, white, medium
# 8      14-272   apple juice concentrate, unsweetened, commerical
# 9      17-632                          coffee, cappuccino, latte
# 10     17-175                                               cola
# 11     17-744                        cranberry fruit juice drink
# 12     17-498                         drinking chocolate, powder
# 13     17-672                           energy drink, carbonated
# 14     17-745                           grape juice, unsweetened
# 15     17-731                                   horlicks, powder
# 16     17-179                                           lemonade
# 17     17-761                                           lucozade
# 18     17-751                                     lager, premium
# 19     17-244                            liqueurs, high strength
# 20     17-733                                 milk shake, powder
# 21     17-734                                   ovaltine, powder
# 22     11-001                                          arrowroot
# 23     11-002                                 barley, pearl, raw
# 24     11-906                                        bran, wheat
# 25     11-006                                  buckwheat, groats
# 26    11-1144                         bread rolls, brown, crusty
# 27    11-1006                           bread rolls, white, soft
# 28     11-971                              bread, brown, average
# 29     11-969                                    bread, ciabatta
# 30     11-937                     bread, garlic and herb, retail
# 31     11-910    bread, naan, peshwari naan, takeaway and retail
# 32     11-973                                bread, naan, retail
# 33     11-974                                bread, pitta, white
# 34     11-947                                      bread, seeded
# 35    11-1145                              bread, white, average
# 36     11-977               bread, white, farmhouse or split tin
# 37     11-978                         bread, white, french stick
# 38     11-980                               bread, white, sliced
# 39     11-981                          bread, wholemeal, average
# 40     11-983                           bread rolls, brown, soft
# 41     11-984                          bread rolls, malted wheat
# 42     11-985                         bread rolls, white, crusty
# 43     11-986                             bread rolls, wholemeal
# 44     11-763           breakfast cereal, bran flakes, fortified
# 45     11-742            breakfast cereal, cornflakes, fortified
# 46     11-779  breakfast cereal, fruit and fibre type, fortified
# 47     11-755  breakfast cereal, honey loops and hoops, inclu...
# 48     11-792  breakfast cereal, instant hot oat, plain, raw,...
# 49     11-753  breakfast cereal, rice, chocolate flavoured, f...
# 50     11-778  breakfast cereal, shredded wheat, honey nut, n...
# 51     11-773  breakfast cereal, wheat biscuits, weetabix typ...
# 52     11-821                         biscuits, cheese flavoured
# 53     11-815        biscuits, cookies, chocolate chip, standard
# 54     11-799                         biscuits, digestive, plain
# 55     11-809              biscuits, fully coated with chocolate
# 56     11-801                       biscuits, plain, reduced fat
# 57     11-826                                 breadsticks, plain
# 58        NaN                               banana bread, retail
# 59        NaN                        brownies, chocolate, retail
# 60        NaN                    brownies, chocolate, baking mix
# 61     11-970                                      bagels, plain
# 62        NaN                           bread and butter pudding
# 63     11-011                                   cornmeal, sifted
# 64     11-988                                         croissants
# 65     11-820                                     cream crackers
# 66     11-839              cakes, fancy iced, individual, retail
# 67    11-1020                             crumble, fruit, retail
# 68     11-850                              doughnuts, ring, iced
# 69     11-849                                doughnuts, with jam
# 70        NaN                                         dumplings,
# 71        NaN                               biscuit, gingerbread
# 72        NaN                                   hot cross buns,
# 73     11-739                                        jaffa cakes
# 74     11-846                                  jam tarts, retail
# 75        NaN                            macaroni cheese, retail
# 76     11-780                   muesli, swiss style, unfortified
# 77     11-737               muffins, american, chocolate, retail
# 78     11-848                                 mince pies, retail
# 79     11-719                           noodles, egg, dried, raw
# 80     11-823                            oatcakes, plain, retail
# 81     11-936                   pizza, cheese and tomato, retail
# 82     11-788                         porridge oats, unfortified
# 83     11-726                             pasta, egg, fresh, raw
# 84     11-718           pasta, wholewheat, spaghetti, dried, raw
# 85     11-735          pasta, spaghetti, canned, in tomato sauce
# 86        NaN                                   papadums, retail
# 87     11-853                 pastry, shortcrust, retail, cooked
# 88     11-844  pastries, chocolate eclairs, cream filled, retail
# 89        NaN                                           pancakes
# 90     11-544                            scotch pancakes, retail
# 91     11-921           pie, apple, pastry, double crust, retail
# 92     11-847                     pie, fruit, individual, retail
# 93        NaN                            pudding, sponge, retail
# 94    11-1021                            pudding, sponge, canned
# 95        NaN                                     prawn crackers
# 96     11-866                          rice, brown, basmati, raw
# 97     11-870                        rice, brown, easy cook, raw
# 98     11-874                           rice, thai fragrant, raw
# 99     11-863            rice, white, long grain, easy cook, raw
# 100    11-940                                              rusks
# 101       NaN                                     risotto, plain
# 102    11-903                                      semolina, raw
# 103       NaN                             sandwich, white bread,
# 104       NaN                              sandwich, brown bread
# 105    11-802                                         shortbread
# 106    11-544                            scotch pancakes, retail
# 107    11-919              strudel, fruit filled, retail, frozen
# 108    17-371                                stuffing mix, dried
# 109    11-800         wafers, plain ice cream wafers, not filled
# 110       NaN                                  yorkshire pudding
# 111    12-937                          eggs, chicken, whole, raw
# 112    12-949                          quiche, vegetable, retail
# 113    17-487                                     dripping, beef
# 114    17-010                                               lard
# 115    17-031                                       oil, coconut
# 116    17-039                                          oil, palm
# 117    17-044                                          oil, soya
# 118    17-045                                     oil, sunflower
# 119    17-686                            oil, vegetable, average
# 120    16-001                                           ayr, raw
# 121       NaN                          anchovies, canned in oil,
# 122    16-385                         bass, sea, flesh only, raw
# 123    16-003                                          bele, raw
# 124    16-004                                          boal, raw
# 125    16-005                                        bombay duck
# 126    16-006                                    bream, sea, raw
# 127    16-169                                         bacha, raw
# 128    16-372                               cod, flesh only, raw
# 129    16-172                                          carp, raw
# 130    16-007                                       catfish, raw
# 131    16-011                                        chital, raw
# 132    16-383                             coley, flesh only, raw
# 133       NaN                              crab, canned in brine
# 134       NaN                                               crab
# 135       NaN                                   crab, white meat
# 136    16-235                                      crayfish, raw
# 137       NaN                                           calamari
# 138       NaN                                            cockles
# 139    16-254                                    cuttlefish, raw
# 140       NaN                                            caviare
# 141    16-173                                   eel, yellow, raw
# 142    16-375                           haddock, flesh only, raw
# 143    16-070                              hake, flesh only, raw
# 144    16-081                                      kalabasu, raw
# 145    16-186                                         katla, raw
# 146       NaN                                kippers, flesh only
# 147    16-393                          mackerel, flesh only, raw
# 148    16-497                                       mussels, raw
# 149    16-259                                       octopus, raw
# 150    16-260                                       oysters, raw
# 151    16-378                  pollock, alaskan, flesh only, raw
# 152    16-387                                  prawns, king, raw
# 153    14-363  apples, cooking, raw, flesh only, weighed with...
# 154    14-319                apples, eating, raw, flesh and skin
# 155    14-001                                               amla
# 156    14-025                      apricots, raw, flesh and skin
# 157    14-392                 apricots, ready-to-eat, semi-dried
# 158    14-040  avocado, fuerte, flesh only, weighed with skin...
# 159    14-387  avocado, hass, flesh only, weighed with skin a...
# 160    14-331            apple juice, clear, ambient and chilled
# 161    14-043                                 babaco, flesh only
# 162    14-318                            bananas, flesh and skin
# 163    14-388                                  blackberries, raw
# 164    14-053                                 blackcurrants, raw
# 165    14-325                                        blueberries
# 166    14-382                      cherries, flesh and skin, raw
# 167    14-326   citrus fruit, soft/easy peelers, flesh with skin
# 168    14-073                                        cranberries
# 169    14-074                                           currants
# 170    14-077                       damsons, flesh and skin, raw
# 171    14-083                         dates, raw, flesh and skin
# 172    14-087                                  dried mixed fruit
# 173    14-089                          elderberries, whole fruit
# 174    14-100                         gooseberries, cooking, raw
# 175    14-384                        grapefruit, flesh only, raw
# 176    14-322                                      grapes, green
# 177    14-118                             guava, flesh only, raw
# 178    14-371                        kiwi fruit, flesh only, raw
# 179    14-373     kiwi fruit, flesh only, raw, weighed with skin
# 180    14-125                         kumquats, whole fruit, raw
# 181    14-128                        lemons, whole, without pips
# 182    14-131                                  limes, flesh only
# 183    14-132                              limes, flesh and skin
# 184    14-133                                  loganberries, raw
# 185    14-277                                 lemon juice, fresh
# 186    14-378                     mangoes, ripe, flesh only, raw
# 187    14-379          mangoes, raw, weighed with skin and stone
# 188    14-339                 melon, canteloupe-type, flesh only
# 189    14-353             melon, canteloupe-type, flesh and skin
# 190    14-356                              melon, flesh and skin
# 191    14-168                       mulberries, whole fruit, raw
# 192    14-380                    nectarines, flesh and skin, raw
# 193       NaN                                           olives,
# 194    14-327                                oranges, flesh only
# 195    14-360                  oranges, flesh with peel and pips
# 196    14-369                     orange juice, freshly squeezed
# 197    14-361  pears, average, flesh and skin, raw, weighed w...
# 198    14-188           peaches, canned in juice, whole contents
# 199    14-321                         pears, raw, flesh and skin
# 200    14-376                         pineapple, flesh only, raw
# 201    14-377                 pineapple, flesh with skin and top
# 202    14-211         pineapple, canned in juice, whole contents
# 203    14-396                                   pineapple, dried
# 204    14-220               plums, victoria, flesh and skin, raw
# 205    14-227     pomegranate, flesh and pips, weighed with skin
# 206    14-285                                passion fruit juice
# 207    14-179   passion fruit, flesh and pips, weighed with skin
# 208    14-341                            pomegranate juice drink
# 209    14-227     pomegranate, flesh and pips, weighed with skin
# 210    14-289                                        prune juice
# 211    14-237            prunes, canned in juice, whole contents
# 212    14-231                             prunes, flesh and skin
# 213    14-391                   prunes, ready-to-eat, semi-dried
# 214    14-393                                     raisins, dried
# 215    14-375                                   raspberries, raw
# 216    14-249                                   redcurrants, raw
# 217    14-252                           rhubarb, stems only, raw
# 218    14-059                                         star fruit
# 219    14-324                                  strawberries, raw
# 220    14-268                                 whitecurrants, raw
# 221    13-801                                   allspice, ground
# 222    13-802                                        anise seeds
# 223    13-803                                         asafoetida
# 224    13-805                               basil, dried, ground
# 225    13-804                                       basil, fresh
# 226    13-808                                      caraway seeds
# 227    13-809                                   cardamom, ground
# 228    13-810                                       celery seeds
# 229    13-811                                     chervil, dried
# 230    13-873                                      chilli powder
# 231    13-813                                    chinese 5 spice
# 232    13-887                                      chives, fresh
# 233    13-874                                   cinnamon, ground
# 234    13-816                                      cloves, dried
# 235    13-818                            coriander leaves, dried
# 236    13-889                                        cumin seeds
# 237    13-876                                       curry powder
# 238    13-824                                        dill, fresh
# 239    13-829                                       garam masala
# 240    13-830                                      garlic powder
# 241    13-890                                      ginger, fresh
# 242    13-832                                     ginger, ground
# 243    13-835                                    marjoram, dried
# 244    13-836                                        mint, fresh
# 245    13-886                                 mixed curry spices
# 246    13-884                                 mixed herbs, dried
# 247    13-839                                      mustard seeds
# 248    13-877                                     nutmeg, ground
# 249    13-878                             oregano, dried, ground
# 250    13-879                                            paprika
# 251    13-844                                     parsley, fresh
# 252    13-880                                      pepper, black
# 253    13-892                                    rosemary, fresh
# 254    13-852                                            saffron
# 255    13-854                                sage, dried, ground
# 256    19-646              bacon rashers, back, fat trimmed, raw
# 257    18-006                    beef, braising steak, raw, lean
# 258    18-003                            beef, fat, average, raw
# 259    18-016                      beef, fillet steak, raw, lean
# 260    18-024                             beef, flank, raw, lean
# 261    18-468                           beef, lean, average, raw
# 262    18-469                                   beef, mince, raw
# 263    18-054                        beef, silverside, raw, lean
# 264    18-064                     beef, sirloin steak, raw, lean
# 265    18-084                           beef, topside, raw, lean
# 266    18-504                chicken breast/steak, coated, baked
# 267    18-501                   chicken pieces, coated, takeaway
# 268    18-293           chicken, leg quarter, raw, meat and skin
# 269    18-488                        chicken, meat, average, raw
# 270    18-297                 chicken, whole, raw, meat and skin
# 271    18-295          chicken, wing quarter, raw, meat and skin
# 272    18-503               chicken/turkey pieces, coated, baked
# 273    19-538                                     chicken slices
# 274    19-516                                            chorizo
# 275    19-128                                corned beef, canned
# 276    19-449                       curry, chicken balti, retail
# 277       NaN                          casserole, sausage,retail
# 278       NaN                         chow mein, chicken, retail
# 279    19-466                              cornish pasty, retail
# 280       NaN                         coronation chicken, retail
# 281    18-489                               duck, meat only, raw
# 282    19-539                            doner kebabs, meat only
# 283       NaN                       enchiladas, meal kit, retail
# 284    17-640                                       ghee, butter
# 285    19-496                                                ham
# 286       NaN                                            haggis,
# 287       NaN          hot pot, lamb/beef with potatoes, retail,
# 288    18-402                                  kidney, lamb, raw
# 289    18-478                   lamb, average, raw, lean and fat
# 290    18-111                            lamb, breast, raw, lean
# 291    18-115               lamb, chump chops, raw, lean and fat
# 292    18-481                                   lamb, mince, raw
# 293    18-413                                   liver, lamb, raw
# 294       NaN                                     luncheon meat,
# 295    19-326                             meat samosas, takeaway
# 296       NaN                            meatballs, beef, retail
# 297       NaN                meatballs, in tomatoe sauce, retail
# 298    18-419                                        oxtail, raw
# 299    18-609                pork, spare ribs, raw, lean and fat
# 300    18-387                             rabbit, raw, meat only
# 301    18-390                            venison, meat only, raw
# 302    12-500  baking fat and margarine (75-90% fat), hard block
# 303    12-333                             cream, fresh, whipping
# 304    12-537                  cheese spread, plain, reduced fat
# 305    12-346                           cheese, cheddar, english
# 306    12-354                                cheese, danish blue
# 307    12-357     cheese, goats milk, full fat, soft, white rind
# 308    12-360                          cheese, mozzarella, fresh
# 309    12-549             cheese, processed, slices, reduced fat
# 310    12-486                             cheese, white cheshire
# 311    12-507                       cornetto type ice cream cone
# 312    12-542                      cheesecake, fruit, individual
# 313    12-461                         tarts, custard, individual
# 314    12-543        custard, ready to eat, canned and tetra-pak
# 315    12-398                         desserts, dairy, chocolate
# 316    12-508              ice cream, dairy, vanilla, soft scoop
# 317    12-509          ice cream, non dairy, vanilla, soft scoop
# 318       NaN                                      jelly, retail
# 319    12-373                                   lassi, sweetened
# 320    12-390                      lollies, containing ice-cream
# 321    12-389                     lollies, with real fruit juice
# 322    12-512                          milk, 1% fat, pasteurised
# 323    12-322               milk, channel islands, whole, summer
# 324    12-307                milk, skimmed, pasteurised, average
# 325    12-313           milk, semi-skimmed, pasteurised, average
# 326    12-596                  milk, whole, pasteurised, average
# 327    12-520                  milk, condensed, whole, sweetened
# 328    12-522                            milk, evaporated, whole
# 329    12-524  milk, soya, non-dairy alternative to milk, uns...
# 330    12-401                         mousse, chocolate, low fat
# 331    12-553                     pudding, rice, canned, low fat
# 332       NaN                                      raita, retail
# 333    12-555                         yogurt, greek style, plain
# 334    12-375                          yogurt, whole milk, fruit
# 335    14-870                         almonds, flaked and ground
# 336    14-897                                   almonds, toasted
# 337    14-896                             almonds, whole kernels
# 338    14-895                              breadnut seeds, dried
# 339    14-806                                         betel nuts
# 340    14-813                        chestnuts, kernel only, raw
# 341    14-889                               coconut milk, retail
# 342    14-874                             hazelnuts, kernel only
# 343    14-891                             macadamia nuts, salted
# 344    14-875                 marzipan, white and yellow, retail
# 345    14-880                                        nuts, mixed
# 346    14-892                              peanut butter, smooth
# 347    14-882                                peanuts and raisins
# 348    14-840    pistachio nuts, kernel only, roasted and salted
# 349    14-843                                        quinoa, raw
# 350    14-845                                    sunflower seeds
# 351    14-879                               walnuts, kernel only
# 352       NaN                                apple sauce, retail
# 353    17-705                                     barbecue sauce
# 354    17-678                    brown sauce, reduced salt/sugar
# 355    17-697  chicken soup, cream of, canned, condensed, as ...
# 356    17-719                                       chilli sauce
# 357       NaN                                       cheese sauce
# 358    17-345                                    chutney, tomato
# 359    17-358                                    cream of tartar
# 360    17-715                              dressing, blue cheese
# 361    17-701                                   dressing, french
# 362    17-717                          dressing, thousand island
# 363       NaN                                  guacamole, retail
# 364    17-360                                           gelatine
# 365    17-724                             gravy instant granules
# 366       NaN                          hollandaise sauce, retail
# 367       NaN                   hollandaise sauce, vegan, retail
# 368    17-654                       mayonnaise, standard, retail
# 369    17-364                                    mustard, smooth
# 370    17-623                                         pesto, red
# 371    17-718                                      pickle, sweet
# 372    17-702                                         piccalilli
# 373    17-354                               relish, tomato based
# 374    17-711                           soup, minestrone, canned
# 375    17-695                    soup, chicken, cream of, canned
# 376    17-652                      soup, cream of tomato, canned
# 377    17-698                               soup, lentil, canned
# 378    17-700                               soup, oxtail, canned
# 379    17-712                            soup, vegetable, canned
# 380    17-653                 soup, instant, dried, as purchased
# 381    17-628               sauce, chinese cook in, sweet & sour
# 382    17-629                            sauce, chinese stir fry
# 383    17-703                                        salad cream
# 384       NaN                      sauce, sweet and sour, retail
# 385    17-721                soy sauce, light and dark varieties
# 386    17-367                                               salt
# 387    17-515                                  stock cubes, beef
# 388    17-680                                          stock gel
# 389    17-681                 stock, chicken, ready made, retail
# 390    17-339                                            vinegar
# 391       NaN                                white sauce, retial
# 392       NaN                         white sauce, vegan, retial
# 393    17-723                               worcestershire sauce
# 394    17-377                                   water, distilled
# 395    17-517                                      yeast extract
# 396    17-659                                   chocolate spread
# 397    17-658      chocolate covered bar with caramel and cereal
# 398    17-763                                          creme egg
# 399    17-645                                        corn snacks
# 400       NaN                       chevda/chevra/chewra, retial
# 401    17-049                                 glucose liquid, bp
# 402    17-050                                              honey
# 403    17-689  ice cream sauce, topping, strawberry and choco...
# 404    17-075                                 jam, reduced sugar
# 405    17-777                                 liquorice allsorts
# 406    17-078                                          marmalade
# 407    17-651                     maltesers and similar products
# 408    17-668                 mars bar and own brand equivalents
# 409    17-669                milky way and own brand equivalents
# 410    17-114                                       marshmallows
# 411       NaN                                             nougat
# 412    17-117                                        peppermints
# 413    17-692                            popcorn, salted, retail
# 414    17-132                                   pork scratchings
# 415    17-693                             potato crisps, low fat
# 416    17-060                                       sugar, brown
# 417    17-062                                       sugar, icing
# 418    17-063                                       sugar, white
# 419    17-065                                      syrup, golden
# 420    17-096                                smartie-type sweets
# 421       NaN                                      ackee, canned
# 422    13-146                                        agar, dried
# 423    13-148                               alfalfa sprouts, raw
# 424    13-149                               amaranth leaves, raw
# 425    13-151                                     arrowhead, raw
# 426    13-153                              artichoke, globe, raw
# 427       NaN                                  artichoke, canned
# 428       NaN                                     artichoke, jar
# 429    13-157                                     asparagus, raw
# 430    13-161                                     aubergine, raw
# 431    13-532                baked beans, canned in tomato sauce
# 432    13-041                    beans, aduki, whole, dried, raw
# 433       NaN                               beans, aduki, canned
# 434    13-062                 beans, blackeye, whole, dried, raw
# 435       NaN                            beans, blackeye, canned
# 436    13-070                          beans, butter, dried, raw
# 437       NaN                              beans, butter, canned
# 438    13-074       beans, chick peas, kabuli, whole, dried, raw
# 439       NaN                          beans, chick peas, canned
# 440    13-080                                beans, cluster, raw
# 441       NaN                             beans, edamame, frozen
# 442       NaN                             beans, edamame, canned
# 443    13-514                                  beans, green, raw
# 444    13-086                  beans, haricot, whole, dried, raw
# 445       NaN                             beans, haricot, canned
# 446    13-098                      beans, mung, dahl, dried, raw
# 447    13-102              beans, pigeon peas, whole, dried, raw
# 448    13-106                           beans, pinto, dried, raw
# 449       NaN                             beans, pinto, canned,
# 450    13-109                      beans, red kidney, dried, raw
# 451       NaN                          beans, red kidney, canned
# 452    13-112                                 beans, runner, raw
# 453    13-115                            beans, soya, dried, raw
# 454    13-117                                  beans, sword, raw
# 455    13-426                             beansprouts, mung, raw
# 456    13-056           black gram, urad gram, whole, dried, raw
# 457    13-164                                      beetroot, raw
# 458    13-167                                    breadfruit, raw
# 459    13-502                               broccoli, green, raw
# 460    13-174                    broccoli, purple sprouting, raw
# 461    13-177                              brussels sprouts, raw
# 462       NaN                                 beanburger, retail
# 463       NaN                             beanburger, vegetarian
# 464    13-067                           beans, broad, dried, raw
# 465       NaN                               beans, broad, canned
# 466    13-064              beans, broad, whole, raw, without pod
# 467       NaN                          beans, cannellini, canned
# 468    13-582                              cabbage, average, raw
# 469    13-187                              cabbage, chinese, raw
# 470    13-510                                cabbage, green, raw
# 471    13-190                                  cabbage, red, raw
# 472    13-509                                cabbage, white, raw
# 473    13-448                                carrots, young, raw
# 474    13-512                                   cauliflower, raw
# 475    13-219                                      celeriac, raw
# 476    13-636                                        celery, raw
# 477    13-223                                  chard, swiss, raw
# 478    13-225                         chicory, pale variety, raw
# 479    13-627                                     courgette, raw
# 480    13-234                                    curly kale, raw
# 481       NaN                       casserole, vegetable, retail
# 482    15-637                         cauliflower cheese, retail
# 483    15-635                  coleslaw, not low calorie, retail
# 484       NaN                    curry, vegetable, mixed, canned
# 485    13-244                                        garlic, raw
# 486    13-245                                      gherkins, raw
# 487    13-608                                 green beans, dried
# 488       NaN                     green beans, in water, canned
# 489    13-556                                            houmous
# 490    13-258                                   horseradish, raw
# 491    13-261                                     kohl rabi, raw
# 492    15-809                                             khadhi
# 493    13-089        lentils, green and brown, whole, dried, raw
# 494       NaN                                    lentils, canned
# 495    13-624                                         leeks, raw
# 496    13-520                              lettuce, average, raw
# 497    13-271                                  lotus tubers, raw
# 498    15-651                         lasagne, vegetable, retail
# 499    13-505                              mushrooms, white, raw
# 500    13-298                                mustard leaves, raw
# 501    15-652                        moussaka, vegetable, retail
# 502    13-300                                          okra, raw
# 503    13-499                                        onions, raw
# 504       NaN                                          potatoes,
# 505       NaN                                      potato chips,
# 506       NaN                            potato wedges, retail,
# 507       NaN                              peas, canned in water
# 508    13-527                                  peas, frozen, raw
# 509       NaN                                      pak choi, raw
# 510    13-311                   papaya, unripe, green flesh, raw
# 511    13-312                                       parsnip, raw
# 512    13-524                         pepper, capsicum, red, raw
# 513    13-323                         plantain, green flesh, raw
# 514    13-326                           pumpkin, flesh only, raw
# 515    15-262                                        quorn korma
# 516    13-332                                 radish leaves, raw
# 517    13-522                                        rocket, raw
# 518    15-869                                   roulade, spinach
# 519    13-521                                 spinach, baby, raw
# 520    13-359                             swede, flesh only, raw
# 521       NaN                          swede, raw,flesh and skin
# 522    13-463                      sweet potato, raw, flesh only
# 523       NaN                  sweet potato, raw, flesh and skin
# 524       NaN                          sweetcorn kernels, canned
# 525    13-622                            sweetcorn, kernels, raw
# 526       NaN                                 sweetcorn on a cob
# 527    15-872            salad, pasta, vegetables and mayonnaise
# 528    15-883                          shepherd's pie, vegetable
# 529    15-617                                   sushi, vegetable
# 530       NaN                          vegetables, mixed, frozen
# 531    15-656                        vegeburger, retail, grilled
# 532       NaN                            vegetable stir fry mix,
# 533    13-673                                    watercress, raw
# 534    13-397                               yam, flesh only, raw
#
#     Food sub-group codes                             Food Group  \
# 0                     QA                    Alcoholic beverages
# 1                     QC                    Alcoholic beverages
# 2                     QF                    Alcoholic beverages
# 3                     QF                    Alcoholic beverages
# 4                     QK                    Alcoholic beverages
# 5                     QG                    Alcoholic beverages
# 6                     QE                    Alcoholic beverages
# 7                     QE                    Alcoholic beverages
# 8                     PE                              Beverages
# 9                      P                              Beverages
# 10                   PCA                              Beverages
# 11                    PE                              Beverages
# 12                   PAA                              Beverages
# 13                   PCA                              Beverages
# 14                    PE                              Beverages
# 15                   PAA                              Beverages
# 16                   PCA                              Beverages
# 17                   PCA                              Beverages
# 18                    QA                              Beverages
# 19                    QI                              Beverages
# 20                   PAA                              Beverages
# 21                   PAA                              Beverages
# 22                    AA            Cereals and cereal products
# 23                    AA            Cereals and cereal products
# 24                    AA            Cereals and cereal products
# 25                    AA            Cereals and cereal products
# 26                    AF            Cereals and cereal products
# 27                    AF            Cereals and cereal products
# 28                    AF            Cereals and cereal products
# 29                    AF            Cereals and cereal products
# 30                    AF            Cereals and cereal products
# 31                    AF            Cereals and cereal products
# 32                    AF            Cereals and cereal products
# 33                    AF            Cereals and cereal products
# 34                    AF            Cereals and cereal products
# 35                    AF            Cereals and cereal products
# 36                    AF            Cereals and cereal products
# 37                    AF            Cereals and cereal products
# 38                    AF            Cereals and cereal products
# 39                    AF            Cereals and cereal products
# 40                    AG            Cereals and cereal products
# 41                    AG            Cereals and cereal products
# 42                    AG            Cereals and cereal products
# 43                    AG            Cereals and cereal products
# 44                    AI            Cereals and cereal products
# 45                    AI            Cereals and cereal products
# 46                    AI            Cereals and cereal products
# 47                    AI            Cereals and cereal products
# 48                    AI            Cereals and cereal products
# 49                    AI            Cereals and cereal products
# 50                    AI            Cereals and cereal products
# 51                    AI            Cereals and cereal products
# 52                    AM            Cereals and cereal products
# 53                    AM            Cereals and cereal products
# 54                    AM            Cereals and cereal products
# 55                    AM            Cereals and cereal products
# 56                    AM            Cereals and cereal products
# 57                    AM            Cereals and cereal products
# 58                    AN            Cereals and cereal products
# 59                    AN            Cereals and cereal products
# 60                    AN            Cereals and cereal products
# 61                    AP            Cereals and cereal products
# 62                    AS            Cereals and cereal products
# 63                    AA            Cereals and cereal products
# 64                    AG            Cereals and cereal products
# 65                    AM            Cereals and cereal products
# 66                    AN            Cereals and cereal products
# 67                    AS            Cereals and cereal products
# 68                    AP            Cereals and cereal products
# 69                    AP            Cereals and cereal products
# 70                    AT            Cereals and cereal products
# 71                    AN            Cereals and cereal products
# 72                    AP            Cereals and cereal products
# 73                    AM            Cereals and cereal products
# 74                    AS            Cereals and cereal products
# 75                    AD            Cereals and cereal products
# 76                    AI            Cereals and cereal products
# 77                    AN            Cereals and cereal products
# 78                    AS            Cereals and cereal products
# 79                    AD            Cereals and cereal products
# 80                    AM            Cereals and cereal products
# 81                     A            Cereals and cereal products
# 82                     A            Cereals and cereal products
# 83                    AD            Cereals and cereal products
# 84                    AD            Cereals and cereal products
# 85                    AD            Cereals and cereal products
# 86                    AF            Cereals and cereal products
# 87                    AO            Cereals and cereal products
# 88                    AP            Cereals and cereal products
# 89                    AS            Cereals and cereal products
# 90                    AS            Cereals and cereal products
# 91                    AS            Cereals and cereal products
# 92                    AS            Cereals and cereal products
# 93                    AS            Cereals and cereal products
# 94                    AS            Cereals and cereal products
# 95                    AT            Cereals and cereal products
# 96                    AC            Cereals and cereal products
# 97                    AC            Cereals and cereal products
# 98                    AC            Cereals and cereal products
# 99                    AC            Cereals and cereal products
# 100                   AK            Cereals and cereal products
# 101                   AT            Cereals and cereal products
# 102                   AA            Cereals and cereal products
# 103                   AB            Cereals and cereal products
# 104                   AB            Cereals and cereal products
# 105                   AM            Cereals and cereal products
# 106                   AP            Cereals and cereal products
# 107                   AS            Cereals and cereal products
# 108                   AT            Cereals and cereal products
# 109                   AM            Cereals and cereal products
# 110                   AT            Cereals and cereal products
# 111                   CA                                   Eggs
# 112                   CD                                   Eggs
# 113                   OF                          Fats and oils
# 114                   OF                          Fats and oils
# 115                   OC                          Fats and oils
# 116                   OC                          Fats and oils
# 117                   OC                          Fats and oils
# 118                   OC                          Fats and oils
# 119                   OC                          Fats and oils
# 120                   JA                 Fish and fish products
# 121                   JC                 Fish and fish products
# 122                   JA                 Fish and fish products
# 123                   JA                 Fish and fish products
# 124                   JA                 Fish and fish products
# 125                   JA                 Fish and fish products
# 126                   JA                 Fish and fish products
# 127                   JC                 Fish and fish products
# 128                   JA                 Fish and fish products
# 129                   JA                 Fish and fish products
# 130                   JA                 Fish and fish products
# 131                   JA                 Fish and fish products
# 132                   JA                 Fish and fish products
# 133                   JK                 Fish and fish products
# 134                   JK                 Fish and fish products
# 135                   JK                 Fish and fish products
# 136                   JK                 Fish and fish products
# 137                   JM                 Fish and fish products
# 138                   JM                 Fish and fish products
# 139                   JM                 Fish and fish products
# 140                   JR                 Fish and fish products
# 141                   JC                 Fish and fish products
# 142                   JA                 Fish and fish products
# 143                   JA                 Fish and fish products
# 144                   JA                 Fish and fish products
# 145                   JA                 Fish and fish products
# 146                   JC                 Fish and fish products
# 147                   JC                 Fish and fish products
# 148                   JM                 Fish and fish products
# 149                   JM                 Fish and fish products
# 150                   JM                 Fish and fish products
# 151                   JA                 Fish and fish products
# 152                   JK                 Fish and fish products
# 153                    F                                  Fruit
# 154                    F                                  Fruit
# 155                   FA                                  Fruit
# 156                   FA                                  Fruit
# 157                   FA                                  Fruit
# 158                   FA                                  Fruit
# 159                   FA                                  Fruit
# 160                   FC                                  Fruit
# 161                   FA                                  Fruit
# 162                   FA                                  Fruit
# 163                   FA                                  Fruit
# 164                   FA                                  Fruit
# 165                   FA                                  Fruit
# 166                   FA                                  Fruit
# 167                   FA                                  Fruit
# 168                   FA                                  Fruit
# 169                   FA                                  Fruit
# 170                   FA                                  Fruit
# ...
# 64
# 65
# 66                          NaN
# 67
# 68                          NaN
# 69
# 70
# 71
# 72
# 73
# 74
# 75                Tesco Website
# 76
# 77
# 78                          NaN
# 79
# 80
# 81
# 82
# 83
# 84                          NaN
# 85                          NaN
# 86
# 87
# 88
# 89
# 90
# 91
# 92
# 93
# 94
# 95
# 96
# 97
# 98
# 99
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107                         NaN
# 108
# 109
# 110
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 120                         NaN
# 121
# 122
# 123                         NaN
# 124                         NaN
# 125
# 126                         NaN
# 127                         NaN
# 128
# 129                         NaN
# 130                         NaN
# 131                         NaN
# 132
# 133
# 134
# 135
# 136                         NaN
# 137
# 138
# 139                         NaN
# 140
# 141                         NaN
# 142
# 143
# 144                         NaN
# 145                         NaN
# 146
# 147
# 148                         NaN
# 149                         NaN
# 150
# 151
# 152                         NaN
# 153                         NaN
# 154                         NaN
# 155
# 156                         NaN
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164                         NaN
# 165
# 166                         NaN
# 167                         NaN
# 168
# 169
# 170                         NaN
# 171                         NaN
# 172
# 173
# 174                         NaN
# 175                         NaN
# 176
# 177
# 178
# 179                         NaN
# 180
# 181
# 182
# 183
# 184                         NaN
# 185
# 186
# 187                         NaN
# 188
# 189
# 190
# 191
# 192                         NaN
# 193
# 194
# 195
# 196
# 197                         NaN
# 198
# 199                         NaN
# 200
# 201
# 202
# 203
# 204                         NaN
# 205                         NaN
# 206
# 207                         NaN
# 208                         NaN
# 209                         NaN
# 210
# 211
# 212
# 213
# 214
# 215                         NaN
# 216                         NaN
# 217
# 218
# 219                         NaN
# 220                         NaN
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292                         NaN
# 293                         NaN
# 294  Confirmed on Ocado Website
# 295
# 296
# 297
# 298                         NaN
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 315
# 316
# 317
# 318
# 319
# 320
# 321
# 322                         NaN
# 323
# 324
# 325
# 326
# 327
# 328
# 329                         NaN
# 330
# 331
# 332
# 333
# 334
# 335
# 336
# 337
# 338
# 339
# 340
# 341
# 342
# 343
# 344
# 345               Tesco Website
# 346
# 347
# 348
# 349                         NaN
# 350
# 351
# 352
# 353
# 354
# 355
# 356
# 357
# 358
# 359
# 360
# 361
# 362
# 363
# 364
# 365
# 366
# 367
# 368
# 369
# 370
# 371
# 372
# 373
# 374
# 375
# 376
# 377
# 378
# 379
# 380
# 381
# 382
# 383
# 384
# 385
# 386
# 387
# 388
# 389
# 390
# 391
# 392
# 393
# 394
# 395
# 396
# 397
# 398               Ocado Website
# 399
# 400
# 401
# 402
# 403
# 404
# 405
# 406
# 407
# 408
# 409
# 410
# 411
# 412
# 413
# 414
# 415
# 416
# 417
# 418
# 419
# 420
# 421
# 422
# 423                         NaN
# 424                         NaN
# 425                         NaN
# 426                         NaN
# 427
# 428
# 429                         NaN
# 430                         NaN
# 431
# 432
# 433
# 434
# 435
# 436
# 437
# 438
# 439
# 440
# 441
# 442
# 443
# 444
# 445
# 446
# 447
# 448
# 449
# 450
# 451
# 452
# 453
# 454
# 455                         NaN
# 456
# 457                         NaN
# 458                         NaN
# 459                         NaN
# 460                         NaN
# 461                         NaN
# 462
# 463
# 464
# 465
# 466
# 467
# 468
# 469
# 470                         NaN
# 471                         NaN
# 472
# 473                         NaN
# 474                         NaN
# 475                         NaN
# 476                         NaN
# 477
# 478                         NaN
# 479                         NaN
# 480
# 481
# 482
# 483
# 484
# 485
# 486                         NaN
# 487
# 488
# 489
# 490
# 491                         NaN
# 492
# 493
# 494
# 495                         NaN
# 496
# 497                         NaN
# 498
# 499
# 500
# 501
# 502                         NaN
# 503                         NaN
# 504
# 505
# 506
# 507
# 508
# 509                         NaN
# 510                         NaN
# 511                         NaN
# 512                         NaN
# 513                         NaN
# 514
# 515
# 516                         NaN
# 517                         NaN
# 518
# 519                         NaN
# 520
# 521                         NaN
# 522
# 523
# 524
# 525                         NaN
# 526
# 527
# 528
# 529
# 530
# 531
# 532
# 533                         NaN
# 534

# %%
d = redFood_matched.loc[redFood_matched['Weight'] != '']
d['Food Name'].value_counts().sum()
# Out:
# 320

# %% [markdown]
# #### Export Matched DataSet

# %%
#redFood_matched.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\ReducedwithWeights\dataproduct.csv')

# %% [markdown]
# ### 320 / 535 items Matched Using Algo 4 which is a combination of Algo 2 & It uses the fuzz.partial_token_set_ratio & Term Frequency-Inverse Document Frequency

# %%
f'Fourth Algorithm Matched {round((320/535) * 100, 2)}% of products between McCane and Widdowson df and Food Portion Sizes df at a threshold of 90 and a Cosine threshold of 70. Contains some errors'
# Out:
# 'Fourth Algorithm Matched 59.81% of products between McCane and Widdowson df and Food Portion Sizes df at a threshold of 90 and a Cosine threshold of 70. Contains some errors'

# %% [markdown]
# ## Plotting Matching Rate of Algo 4

# %% [markdown]
# Find total counts of food by Super Group

# %%
ax4_count = redFood_matched.groupby('Food Group')['Food Name'].count().rename('Total Prod Count', inplace=True).copy().sort_values(ascending=True)
ax4_nt = pd.DataFrame(ax4_count).reset_index()
ax4_nt
# Out:
#                                Food Group  Total Prod Count
# 0                                    Eggs                 2
# 1                           Fats and oils                 7
# 2                     Alcoholic beverages                 8
# 3                               Beverages                14
# 4                          Nuts and seeds                17
# 5            Sugars, preserves and snacks                25
# 6                  Fish and fish products                33
# 7                  Milk and milk products                33
# 8                        Herbs and spices                35
# 9   Soups, sauces and miscellaneous foods                44
# 10                 Meat and meat products                46
# 11                                  Fruit                68
# 12            Cereals and cereal products                89
# 13                             Vegetables               114

# %% [markdown]
# Count of Matched items by Super Group

# %%
d = redFood_matched[redFood_matched['Weight'] != '']
ax4_s = d.groupby('Food Group')['Food Name'].count().rename('Matched Prod Count', inplace=True).copy().sort_values(ascending=True)
ax4 = pd.DataFrame(ax4_s).reset_index()
ax4
# Out:
#                                Food Group  Matched Prod Count
# 0                                    Eggs                   1
# 1                           Fats and oils                   4
# 2                     Alcoholic beverages                   6
# 3                        Herbs and spices                   6
# 4                               Beverages                   8
# 5                          Nuts and seeds                   9
# 6            Sugars, preserves and snacks                  18
# 7                  Meat and meat products                  20
# 8                  Milk and milk products                  22
# 9                  Fish and fish products                  24
# 10  Soups, sauces and miscellaneous foods                  30
# 11                                  Fruit                  43
# 12            Cereals and cereal products                  47
# 13                             Vegetables                  82

# %%
# Evaluating Percentaged Mapped
ax4_counts = ax4_nt.merge(ax4, on='Food Group', how='left')
ax4_counts['%Matched'] = ax4_counts['Matched Prod Count'] / ax4_counts['Total Prod Count'] * 100

# %%
# Find the minimum count in the ax4_counts DataFrame.
min_count4 = ax4_counts['%Matched'].min()

# Create a custom color palette.
bar_colors4 = ['lightpink' if count != min_count4 else '#f95d6a' for count in ax4_counts['%Matched']]

# Set the font family and size for the title.
title_font = fm.FontProperties(family='Times New Roman', size=24)

# Set the font family and size for the axes labels.
axis_font = fm.FontProperties(family='Times New Roman', size=18)

# Create the figure and axes objects.
fig, ax = plt.subplots(figsize=(10, 8))

# Plot the horizontal bar chart.
bars = ax.barh(ax4_counts['Food Group'], ax4_counts['%Matched'], color=bar_colors4)

# Add gridlines to the plot.
ax.grid(axis='x', linestyle='--', alpha=0.2)

# Customize the title, x-axis, and y-axis labels.
ax.set_title('Evaluation of Hybrid Matching (Algorithm 4)', fontproperties=title_font)
ax.set_xlabel('Percentage Matched', fontproperties=axis_font)
ax.set_ylabel('Food Group', fontproperties=axis_font)

# Set the maximum value of the x-axis to 100.
ax.set_xlim(0, 100)

# Adjust the spacing around the plot.
plt.tight_layout(pad=1.0)

# Remove the top and right spines from the plot.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Increase the tick label font size.
ax.tick_params(axis='both', which='major', labelsize=13)

# Invert the y-axis to display the highest match on top.
ax.invert_yaxis()

    # Show the plot.
plt.show()

# %% [markdown]
#                                         Matching with Supervised Algorithm

# %% [markdown]
# ###### Predefined List

# %%
# #Alcoholic beverages
# Alcoh_bev = ['Beer','Cider','Port','Sherry','Spirits','Vermouth', 'Wine']
# Alcoh_bev = [item.lower() for item in Alcoh_bev]

# #Beverages
# Bev = ['Juice', 'Cappuccino', 'Cola', 'Drink', 'Chocolate', 'Energy', 
#        'Horlicks', 'Lemonade', 'Lucozade', 'Lager', 'Liqueurs']
# Bev = [item.lower() for item in Bev]


# #Cereals and cereal products
# Cer = ['Bread', 'Cereal', 'Biscuits', 'Cakes', 'Croissants', 
#            'Crackers', 'Pastry', 'Pizza', 'Pies', 'Pudding', 'Rice']
# Cer = [item.lower() for item in Cer]

# #Eggs
# Eg = ['Eggs', 'Quiche']
# Eg = [item.lower() for item in Eg]

# #Fats and oils
# Foils = ['Dripping', 'Lard', 'Oil']
# Foils = [item.lower() for item in Foils]


# #Fish and fish products
# Fsh = ['Ayr', 'Anchovies', 'Bass', 'Bele', 'Boal', 'Bream', 'Bombay', 'Catfish', 'Chital', 'Crab', 
#         'Crayfish', 'Calamari', 'Cockles', 'Cuttlefish', 'Caviare', 'Eel', 'Haddock', 'Hake', 'Kalabasu', 
#         'Katla', 'Kippers', 'Mackerel', 'Mussels', 'Octopus', 'Oysters', 'Pollock', 'Prawns']
# Fsh = [item.lower() for item in Fsh]


# #Fruit
# Frt = ['Apples', 'Apricots', 'Avocado', 'Babaco', 'Bananas', 'Berries','Currants','Cherries', 
#          'Citrus', 'Cranberries', 'Currants', 'Damsons', 'Dates', 'Elderberries', 'Gooseberries', 
#          'Grapefruit', 'Grapes', 'Guava', 'Kiwi', 'Kumquats', 'Lemons', 'Limes', 'Loganberries', 'Mangoes', 
#          'Melon', 'Mulberries', 'Nectarines', 'Olives', 'Oranges', 'Passion fruit', 'Peaches', 'Pears', 'Pineapple', 
#          'Plums', 'Pomegranate', 'Prunes', 'Raisins', 'Raspberries', 'Rhubarb', 'Strawberries']
# Frt = [item.lower() for item in Frt]


# #Herbs and spices
# Heb = ['Allspice', 'Anise', 'Asafoetida', 'Basil', 'Caraway', 'Cardamom', 'Celery', 'Chervil', 'Chilli', 'Chinese 5 spice', 
#          'Chives', 'Cinnamon', 'Cloves', 'Coriander', 'Cumin', 'Curry', 'Dill', 'Garam masala', 'Garlic', 'Ginger', 'Marjoram', 
#          'Mint', 'Mixed herbs', 'Mustard', 'Nutmeg', 'Oregano', 'Paprika', 'Parsley', 'Pepper', 'Rosemary', 'Saffron', 'Sage']
# Heb = [item.lower() for item in Heb]


# #Meat and meat products
# Met = ['Bacon', 'Beef', 'Chicken', 'Duck', 'Gammon', 'Ghee', 'Ham', 'Haggis', 'Kidney', 'Lamb', 'Liver', 'Luncheon meat', 
#        'Mince', 'Oxtail', 'Pork', 'Rabbit', 'Ribs', 'Spare ribs', 'Venison']
# Met = [item.lower() for item in Met]


# #Milk and milk products
# Mlk = ['Butter', 'Cheese', 'Cream', 'Custard', 'Desserts', 'Ice cream', 'Jelly', 
#        'Lassi', 'Lollies', 'Milk', 'milk powder', 'Mousse', 'Pudding', 'Raita', 'Yogurt']
# Mlk = [item.lower() for item in Mlk]


# #Nuts and seeds
# Nts = ['Almonds', 'Breadnut', 'Betel', 'Chestnuts', 'Coconut', 'Hazelnuts', 
#        'Macadamia', 'Marzipan', 'Mixed nuts', 'Peanut butter', 'Peanuts', 
#        'Pistachio', 'Quinoa', 'Sunflower', 'Walnuts']
# Nts = [item.lower() for item in Nts]

# #Soups, sauces and miscellaneous foods
# Sp = ['Apple sauce', 'Barbecue', 'Sauce', 'Soup', 'Dressing', 'Chutney', 'Relish', 'Mayonnaise', 
#        'Mustard', 'Pesto', 'Pickle', 'Salad cream', 'Soy sauce', 'Stock, Vinegar', 'Worcestershire sauce']
# Sp = [item.lower() for item in Sp]

# #Sugars, preserves and snacks
# Sgs = ['Chocolate', 'Creme egg', 'Corn snacks', 'Glucose', 'Honey', 'Jam', 'Liquorice', 'Marmalade', 'Maltesers', 
#        'Mars bar', 'Marshmallows', 'Nougat', 'Peppermints', 'Popcorn', 'Pork scratchings', 'Potato crisps', 
#        'Sugar', 'Syrup', 'Sweets']
# Sgs = [item.lower() for item in Sgs]

# #Vegetables
# Veg = ['Ackee', 'Agar', 'Alfalfa', 'Amaranth', 'Arrowhead', 'Artichoke', 'Asparagus', 'Aubergine', 'Beans', 'Beetroot', 'Bok choy', 
#        'Breadfruit', 'Broccoli', 'Brussels sprouts', 'Cabbage', 'Carrots', 'Cauliflower', 'Celeriac', 'Celery', 'Chard', 'Chicory', 
#        'Courgette', 'Kale', 'Kohl rabi', 'Lentils', 'Leeks', 'Lettuce', 'Lotus', 'Mushrooms', 'Mustard leaves', 'Okra', 'Onions', 
#        'Papaya', 'Parsnip', 'Pepper', 'Plantain', 'Potatoes', 'Pumpkin', 'Radish', 'Rocket', 'Spinach', 'Swede', 'Sweet potato',
#        'Sweetcorn', 'Turnip', 'Watercress', 'Yam']
# Veg = [item.lower() for item in Veg]

# foodLists = [Alcoh_bev,Bev,Cer,Eg,Foils,Fsh,Frt,Heb,Met,Mlk,Nts,Sp,Sgs,Veg]

# %% [markdown]
#                                                   NEXT NOTEBOOK
