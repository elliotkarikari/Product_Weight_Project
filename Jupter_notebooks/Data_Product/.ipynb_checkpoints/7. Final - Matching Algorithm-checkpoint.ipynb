# %% [markdown]
# # Matching Algorithm - Matching with Food Description/Name column

# %% [markdown]
# There is something wrong with the matching algo. When I run it one i get weird results but when I run it the second time I get better results in some categories

# %% [markdown]
# ##### Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re #regular expressions 
from fuzzywuzzy import process, fuzz
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ##### Read In Data

# %% [markdown]
#                                                       M&W Reduced

# %%
#pd.set_option('display.max_rows', None)
redFood = pd.read_csv(r"C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\ReducedwithWeights\dataproduct.csv", index_col=0)
redFood['Food Name'] = redFood['Food Name'].str.lower()
redFood.head()
# Out:
#   Food Code                    Food Name Food sub-group codes  \
# 0    17-208  beer, bitter, best, premium                   QA
# 1    17-224                 cider, sweet                   QC
# 2    17-234                         port                   QF
# 3    17-236               sherry, medium                   QF
# 4    17-247          spirits, 40% volume                   QK
#
#             Food Group                                Sale format(s) Source  \
# 0  Alcoholic beverages  can, can multipack, bottle, bottle multipack    NaN
# 1  Alcoholic beverages  can, can multipack, bottle, bottle multipack    NaN
# 2  Alcoholic beverages                                        bottle    NaN
# 3  Alcoholic beverages                                        bottle    NaN
# 4  Alcoholic beverages                             bottle, miniature    NaN
#
#    Similarity Score Weight PurEqualCon Portion Consumed
# 0          0.572115   333g           Y        small can
# 1          0.569783    25g           Y              NaN
# 2          0.000000    NaN         NaN              NaN
# 3          0.792667   200g           Y           medium
# 4          0.707107    29g           Y      1 miniature

# %%
redFood.columns
# Out:
# Index(['Food Code', 'Food Name', 'Food sub-group codes', 'Food Group',
#        'Sale format(s)', 'Source', 'Similarity Score', 'Weight', 'PurEqualCon',
#        'Portion Consumed'],
#       dtype='object')

# %%
redFood.drop(['Source', 'Similarity Score', 'Weight', 'PurEqualCon',
       'Portion Consumed'], axis=1, inplace=True)

# %% [markdown]
# Creating a Source column to indicate where I got weight data from

# %%
redFood['Source'] = ' '

# %%
redFood.head()
# Out:
#   Food Code                    Food Name Food sub-group codes  \
# 0    17-208  beer, bitter, best, premium                   QA
# 1    17-224                 cider, sweet                   QC
# 2    17-234                         port                   QF
# 3    17-236               sherry, medium                   QF
# 4    17-247          spirits, 40% volume                   QK
#
#             Food Group                                Sale format(s) Source
# 0  Alcoholic beverages  can, can multipack, bottle, bottle multipack
# 1  Alcoholic beverages  can, can multipack, bottle, bottle multipack
# 2  Alcoholic beverages                                        bottle
# 3  Alcoholic beverages                                        bottle
# 4  Alcoholic beverages                             bottle, miniature

# %% [markdown]
# Remove the word raw from all strings

# %%
redFood['Food Name'] = redFood['Food Name'].str.replace(r'\braw\b', '', case=False).str.strip()
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_28268\3194073488.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   redFood['Food Name'] = redFood['Food Name'].str.replace(r'\braw\b', '', case=False).str.strip()

# %% [markdown]
#                                                          FPS Data

# %%
CleanRetai = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\FoodPortionSized\FPS_VJ.csv')
CleanRetai['Food Name'] = CleanRetai['Food Name'].str.lower()
CleanRetai.tail()
# Out:
#                            Group   Brand               Food Name  \
# 2672  YOGHURTS AND FROMAGE FRAIS     NaN                   onken
# 2673  YOGHURTS AND FROMAGE FRAIS     NaN           petit danoneâ
# 2674  YOGHURTS AND FROMAGE FRAIS     NaN  st ivel fiendish faces
# 2675  YOGHURTS AND FROMAGE FRAIS     NaN      baby fromage frais
# 2676  YOGHURTS AND FROMAGE FRAIS  Heinz       baby fromage frais
#
#      Portion Consumed Weight PurEqualCon  Purchased Format Source
# 2672              NaN   200g         NaN        NaN    NaN    NaN
# 2673            small    50g         NaN        NaN    NaN    NaN
# 2674              NaN    50g         NaN        NaN    NaN    NaN
# 2675      Baby Danone    60g           Y        NaN    NaN    NaN
# 2676              Jar   163g           Y        NaN    NaN    NaN

# %% [markdown]
#                             Identify Food Portion Sizes that are equivalent to Retail sold portions

# %%
CleanRetail = CleanRetai[CleanRetai['PurEqualCon'].isin(['Y', 'Y, P'])]
CleanRetail[CleanRetail['Food Name'].str.contains('bread')].head()
# Out:
#         Group  Brand                                Food Name  \
# 138  BISCUITS    M&S  all butter shortbread fingers, organice
# 325     BREAD    NaN                               breadstick
# 337     BREAD    NaN                       danish light bread
# 343     BREAD    NaN                             garlic bread
# 344     BREAD  Tesco                             garlic bread
#
#     Portion Consumed Weight PurEqualCon  Purchased Format         Source
# 138              NaN   175g           Y        NaN    NaN  Ocado Website
# 325         each, 7g   140g           Y        NaN    Box            NaN
# 337             loaf   400g           Y        NaN    NaN  Ocado Website
# 343          1 slice    20g           Y        NaN    NaN            NaN
# 344              NaN   260g        Y, P        NaN    NaN  Tesco Website

# %%
# Merge columns using .str.cat() and create a new column 'Merged_Column'
CleanRetail['Merged Name'] = CleanRetail['Food Name'].astype(str).str.cat(CleanRetail['Portion Consumed'].astype(str), sep=',')
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_28268\3856531053.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CleanRetail['Merged Name'] = CleanRetail['Food Name'].astype(str).str.cat(CleanRetail['Portion Consumed'].astype(str), sep=',')

# %%
CleanRetail['Merged Name'] = CleanRetail['Merged Name'].str.lower()
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_28268\2238590420.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CleanRetail['Merged Name'] = CleanRetail['Merged Name'].str.lower()

# %% [markdown]
# ###                                                        Match Data (Hybrid Algo).
#
# ###### Once matched, Import Weight and Unit Columns into Reduced M&W table

# %% [markdown]
# Seem to work better when run twice. Something isn't working well with the matching process

# %% [markdown]
# ###### Algorithm

# %%
# %%time

def preprocess_text(df, column_name):
    return df[column_name].str.lower()

def fuzzy_matching_score(source, target):
    return fuzz.partial_token_set_ratio(source, target)

def get_most_similar_indices(tfidf_red_food, tfidf_clean_retail):
    similarities = cosine_similarity(tfidf_red_food, tfidf_clean_retail)
    return similarities.argmax(axis=1)

def hybrid_fuzzy_matching(CleanRetail, redFood):
    # Set thresholds for matching
    partial_token_set_ratio_threshold = 100
    cosine_similarity_threshold = 0.75
    min_similarity_threshold = 0.53

    # Preprocess text data in both DataFrames for the "Merged Name" field.
    CleanRetail['Merged Name'] = preprocess_text(CleanRetail, 'Merged Name')
    redFood['Food Name'] = preprocess_text(redFood, 'Food Name')

    # Step 1: Partial Token Set Ratio (Fuzzy Matching)
    CleanRetail['Partial Token Set Ratio'] = CleanRetail['Merged Name'].apply(lambda x: fuzzy_matching_score(x, redFood['Food Name']))
    potential_matches = CleanRetail[CleanRetail['Partial Token Set Ratio'] >= partial_token_set_ratio_threshold]

    # Step 2: TF-IDF and Cosine Similarity (Text Matching) - Use combined matches as input
    vectorizer = TfidfVectorizer()
    vectorizer.fit(potential_matches['Merged Name'])
    tfidf_clean_retail = vectorizer.transform(potential_matches['Merged Name'])
    tfidf_red_food = vectorizer.transform(redFood['Food Name'])

    # Find the most similar match for each redFood product
    max_sim_indices = get_most_similar_indices(tfidf_red_food, tfidf_clean_retail)
    max_sim_scores = cosine_similarity(tfidf_red_food, tfidf_clean_retail).max(axis=1)

    # Update redFood DataFrame with matched information and sources
    redFood['Similarity Score'] = max_sim_scores
    redFood['Weight'] = potential_matches['Weight'].values[max_sim_indices]
    redFood['PurEqualCon'] = potential_matches['PurEqualCon'].values[max_sim_indices]
    redFood['Portion Consumed'] = potential_matches['Portion Consumed'].values[max_sim_indices]

    # Create a mapping dictionary for matched indices to their sources
    match_indices_to_sources = dict(zip(potential_matches.index, potential_matches['Source']))

    # Map the sources and format to the redFood DataFrame based on matched indices
    redFood['Source'] = redFood.index.map(lambda i: match_indices_to_sources.get(max_sim_indices[i], ''))

    # Set to NaN for rows where similarity score is below the minimum threshold
    redFood.loc[redFood['Similarity Score'] < min_similarity_threshold, ['Weight', 'PurEqualCon', 'Portion Consumed', 'Source']] = ''

    return redFood

# Call the hybrid_fuzzy_matching function and get the matched DataFrame
redFood_matched = hybrid_fuzzy_matching(CleanRetail.copy(), redFood.copy())
# Out:
# CPU times: total: 1.12 s
# Wall time: 1.29 s

# %%
pd.set_option('display.max_rows', None)
#redFood_matched.head()

# %% [markdown]
# Identifying Matched Items with weights

# %%
pd.set_option('display.max_rows', None)
d = redFood_matched.loc[redFood_matched['Weight'] != '']
d#['Food Name'].value_counts().sum()
# Out:
#     Food Code                                          Food Name  \
# 0      17-208                        beer, bitter, best, premium
# 1      17-224                                       cider, sweet
# 3      17-236                                     sherry, medium
# 4      17-247                                spirits, 40% volume
# 6      17-752                                          wine, red
# 7      17-756                                wine, white, medium
# 11     17-744                        cranberry fruit juice drink
# 18     17-751                                     lager, premium
# 20     17-733                                 milk shake, powder
# 27    11-1006                           bread rolls, white, soft
# 29     11-969                                    bread, ciabatta
# 30     11-937                     bread, garlic and herb, retail
# 31     11-910    bread, naan, peshwari naan, takeaway and retail
# 32     11-973                                bread, naan, retail
# 33     11-974                                bread, pitta, white
# 34     11-947                                      bread, seeded
# 38     11-980                               bread, white, sliced
# 41     11-984                          bread rolls, malted wheat
# 42     11-985                         bread rolls, white, crusty
# 43     11-986                             bread rolls, wholemeal
# 65     11-820                                     cream crackers
# 85     11-735          pasta, spaghetti, canned, in tomato sauce
# 88     11-844  pastries, chocolate eclairs, cream filled, retail
# 94    11-1021                            pudding, sponge, canned
# 107    11-919              strudel, fruit filled, retail, frozen
# 108    17-371                                stuffing mix, dried
# 111    12-937                              eggs, chicken, whole,
# 113    17-487                                     dripping, beef
# 115    17-031                                       oil, coconut
# 116    17-039                                          oil, palm
# 117    17-044                                          oil, soya
# 118    17-045                                     oil, sunflower
# 121       NaN                          anchovies, canned in oil,
# 125    16-005                                        bombay duck
# 134       NaN                                               crab
# 135       NaN                                   crab, white meat
# 150    16-260                                           oysters,
# 152    16-387                                      prawns, king,
# 167    14-326   citrus fruit, soft/easy peelers, flesh with skin
# 208    14-341                            pomegranate juice drink
# 240    13-830                                      garlic powder
# 257    18-006                       beef, braising steak, , lean
# 259    18-016                         beef, fillet steak, , lean
# 260    18-024                                beef, flank, , lean
# 262    18-469                                       beef, mince,
# 263    18-054                           beef, silverside, , lean
# 264    18-064                        beef, sirloin steak, , lean
# 265    18-084                              beef, topside, , lean
# 266    18-504                chicken breast/steak, coated, baked
# 269    18-488                            chicken, meat, average,
# 272    18-503               chicken/turkey pieces, coated, baked
# 273    19-538                                     chicken slices
# 275    19-128                                corned beef, canned
# 278       NaN                         chow mein, chicken, retail
# 280       NaN                         coronation chicken, retail
# 284    17-640                                       ghee, butter
# 285    19-496                                                ham
# 296       NaN                            meatballs, beef, retail
# 303    12-333                             cream, fresh, whipping
# 311    12-507                       cornetto type ice cream cone
# 316    12-508              ice cream, dairy, vanilla, soft scoop
# 317    12-509          ice cream, non dairy, vanilla, soft scoop
# 320    12-390                      lollies, containing ice-cream
# 323    12-322               milk, channel islands, whole, summer
# 324    12-307                milk, skimmed, pasteurised, average
# 325    12-313           milk, semi-skimmed, pasteurised, average
# 326    12-596                  milk, whole, pasteurised, average
# 327    12-520                  milk, condensed, whole, sweetened
# 328    12-522                            milk, evaporated, whole
# 329    12-524  milk, soya, non-dairy alternative to milk, uns...
# 330    12-401                         mousse, chocolate, low fat
# 334    12-375                          yogurt, whole milk, fruit
# 341    14-889                               coconut milk, retail
# 346    14-892                              peanut butter, smooth
# 354    17-678                    brown sauce, reduced salt/sugar
# 361    17-701                                   dressing, french
# 368    17-654                       mayonnaise, standard, retail
# 374    17-711                           soup, minestrone, canned
# 377    17-698                               soup, lentil, canned
# 378    17-700                               soup, oxtail, canned
# 379    17-712                            soup, vegetable, canned
# 381    17-628               sauce, chinese cook in, sweet & sour
# 383    17-703                                        salad cream
# 384       NaN                      sauce, sweet and sour, retail
# 387    17-515                                  stock cubes, beef
# 397    17-658      chocolate covered bar with caramel and cereal
# 404    17-075                                 jam, reduced sugar
# 415    17-693                             potato crisps, low fat
# 416    17-060                                       sugar, brown
# 417    17-062                                       sugar, icing
# 418    17-063                                       sugar, white
# 421       NaN                                      ackee, canned
# 427       NaN                                  artichoke, canned
# 428       NaN                                     artichoke, jar
# 431    13-532                baked beans, canned in tomato sauce
# 432    13-041                        beans, aduki, whole, dried,
# 434    13-062                     beans, blackeye, whole, dried,
# 438    13-074           beans, chick peas, kabuli, whole, dried,
# 440    13-080                                    beans, cluster,
# 443    13-514                                      beans, green,
# 444    13-086                      beans, haricot, whole, dried,
# 446    13-098                          beans, mung, dahl, dried,
# 447    13-102                  beans, pigeon peas, whole, dried,
# 448    13-106                               beans, pinto, dried,
# 450    13-109                          beans, red kidney, dried,
# 452    13-112                                     beans, runner,
# 453    13-115                                beans, soya, dried,
# 454    13-117                                      beans, sword,
# 464    13-067                               beans, broad, dried,
# 482    15-637                         cauliflower cheese, retail
# 484       NaN                    curry, vegetable, mixed, canned
# 485    13-244                                            garlic,
# 487    13-608                                 green beans, dried
# 490    13-258                                       horseradish,
# 494       NaN                                    lentils, canned
# 504       NaN                                          potatoes,
# 524       NaN                          sweetcorn kernels, canned
# 529    15-617                                   sushi, vegetable
#
#     Food sub-group codes                             Food Group  \
# 0                     QA                    Alcoholic beverages
# 1                     QC                    Alcoholic beverages
# 3                     QF                    Alcoholic beverages
# 4                     QK                    Alcoholic beverages
# 6                     QE                    Alcoholic beverages
# 7                     QE                    Alcoholic beverages
# 11                    PE                              Beverages
# 18                    QA                              Beverages
# 20                   PAA                              Beverages
# 27                    AF            Cereals and cereal products
# 29                    AF            Cereals and cereal products
# 30                    AF            Cereals and cereal products
# 31                    AF            Cereals and cereal products
# 32                    AF            Cereals and cereal products
# 33                    AF            Cereals and cereal products
# 34                    AF            Cereals and cereal products
# 38                    AF            Cereals and cereal products
# 41                    AG            Cereals and cereal products
# 42                    AG            Cereals and cereal products
# 43                    AG            Cereals and cereal products
# 65                    AM            Cereals and cereal products
# 85                    AD            Cereals and cereal products
# 88                    AP            Cereals and cereal products
# 94                    AS            Cereals and cereal products
# 107                   AS            Cereals and cereal products
# 108                   AT            Cereals and cereal products
# 111                   CA                                   Eggs
# 113                   OF                          Fats and oils
# 115                   OC                          Fats and oils
# 116                   OC                          Fats and oils
# 117                   OC                          Fats and oils
# 118                   OC                          Fats and oils
# 121                   JC                 Fish and fish products
# 125                   JA                 Fish and fish products
# 134                   JK                 Fish and fish products
# 135                   JK                 Fish and fish products
# 150                   JM                 Fish and fish products
# 152                   JK                 Fish and fish products
# 167                   FA                                  Fruit
# 208                   FC                                  Fruit
# 240                    H                       Herbs and spices
# 257                  MAC                 Meat and meat products
# 259                  MAC                 Meat and meat products
# 260                  MAC                 Meat and meat products
# 262                  MAC                 Meat and meat products
# 263                  MAC                 Meat and meat products
# 264                  MAC                 Meat and meat products
# 265                  MAC                 Meat and meat products
# 266                  MCA                 Meat and meat products
# 269                  MCA                 Meat and meat products
# 272                  MCA                 Meat and meat products
# 273                   MI                 Meat and meat products
# 275                   MI                 Meat and meat products
# 278                   MR                 Meat and meat products
# 280                   MR                 Meat and meat products
# 284                   OF                 Meat and meat products
# 285                  MAA                 Meat and meat products
# 296                   MR                 Meat and meat products
# 303                  BJC                 Milk and milk products
# 311                   BP                 Milk and milk products
# 316                   BP                 Milk and milk products
# 317                   BP                 Milk and milk products
# 320                   BP                 Milk and milk products
# 323                  BAB                 Milk and milk products
# 324                  BAE                 Milk and milk products
# 325                  BAH                 Milk and milk products
# 326                  BAK                 Milk and milk products
# 327                  BAR                 Milk and milk products
# 328                  BAR                 Milk and milk products
# 329                   BC                 Milk and milk products
# 330                   BR                 Milk and milk products
# 334                   BN                 Milk and milk products
# 341                   GA                         Nuts and seeds
# 346                   GA                         Nuts and seeds
# 354                  WCN  Soups, sauces and miscellaneous foods
# 361                  WCG  Soups, sauces and miscellaneous foods
# 368                  WCG  Soups, sauces and miscellaneous foods
# 374                   WA  Soups, sauces and miscellaneous foods
# 377                  WAC  Soups, sauces and miscellaneous foods
# 378                  WAC  Soups, sauces and miscellaneous foods
# 379                  WAC  Soups, sauces and miscellaneous foods
# 381                   WC  Soups, sauces and miscellaneous foods
# 383                  WCG  Soups, sauces and miscellaneous foods
# 384                  WCN  Soups, sauces and miscellaneous foods
# 387                   WY  Soups, sauces and miscellaneous foods
# 397                  SEA           Sugars, preserves and snacks
# 404                   SC           Sugars, preserves and snacks
# 415                   SN           Sugars, preserves and snacks
# 416                   SC           Sugars, preserves and snacks
# 417                   SC           Sugars, preserves and snacks
# 418                   SC           Sugars, preserves and snacks
# 421                   DG                             Vegetables
# 427                   DG                             Vegetables
# 428                   DG                             Vegetables
# 431                   DB                             Vegetables
# 432                   DB                             Vegetables
# 434                   DB                             Vegetables
# 438                   DB                             Vegetables
# 440                   DB                             Vegetables
# 443                   DB                             Vegetables
# 444                   DB                             Vegetables
# 446                   DB                             Vegetables
# 447                   DB                             Vegetables
# 448                   DB                             Vegetables
# 450                   DB                             Vegetables
# 452                   DB                             Vegetables
# 453                   DB                             Vegetables
# 454                   DB                             Vegetables
# 464                   DB                             Vegetables
# 482                   DR                             Vegetables
# 484                   DR                             Vegetables
# 485                   DG                             Vegetables
# 487                   DI                             Vegetables
# 490                   DG                             Vegetables
# 494                   DB                             Vegetables
# 504                   DA                             Vegetables
# 524                   DG                             Vegetables
# 529                   DR                             Vegetables
#
#                                         Sale format(s)         Source  \
# 0         can, can multipack, bottle, bottle multipack
# 1         can, can multipack, bottle, bottle multipack
# 3                                               bottle
# 4                                    bottle, miniature            NaN
# 6                            bottle, small bottle, box            NaN
# 7                            bottle, small bottle, box            NaN
# 11                            carton, tetrapak, bottle
# 18        can, multipack can, bottle, multipack bottle
# 20                                                 NaN
# 27                    loose, individual\nmultiple pack
# 29                    loose, individual\nmultiple pack
# 30                    loose, individual\nmultiple pack
# 31                    loose, individual\nmultiple pack
# 32                    loose, individual\nmultiple pack
# 33                    loose, individual\nmultiple pack
# 34                                                loaf
# 38                                                loaf
# 41                    loose, individual\nmultiple pack
# 42                    loose, individual\nmultiple pack
# 43                    loose, individual\nmultiple pack
# 65                                      wrapper or box
# 85                                                 tin
# 88                                                 NaN
# 94                                                 NaN
# 107                                                NaN
# 108                                                NaN
# 111                             egg box, 6, 10, 12, 30
# 113                                                jar
# 115                                                jar
# 116                                             bottle
# 117                                             bottle
# 118                                             bottle
# 121                                                tin
# 125                                                NaN
# 134                                                NaN
# 135                                                NaN
# 150                                                NaN
# 152                                                NaN
# 167                                                net
# 208                           carton, tetrapak, bottle
# 240                                          spice jar
# 257                                                NaN
# 259                                                NaN
# 260                                                NaN
# 262                                                NaN
# 263                                                NaN
# 264                                                NaN
# 265                                                NaN
# 266                                                NaN
# 269                                                NaN
# 272                                                NaN
# 273                                                NaN
# 275                                                tin
# 278                                                NaN
# 280                                                NaN
# 284                                                NaN
# 285                                                NaN            NaN
# 296                                                NaN            NaN
# 303                                                tub
# 311                                                box
# 316                                                NaN
# 317                                                NaN
# 320                                                NaN
# 323  bottle 1 pint, 2 pint, 4 pint, 6 pint, carton ...
# 324  bottle 1 pint, 2 pint, 4 pint, 6 pint, carton ...
# 325  bottle 1 pint, 2 pint, 4 pint, 6 pint, carton ...
# 326  bottle 1 pint, 2 pint, 4 pint, 6 pint, carton ...
# 327                                                tin
# 328                                                tin
# 329                                         carton, 1L
# 330                                                NaN
# 334                                                NaN
# 341                                    carton/tetrapak
# 346                                                jar
# 354                                                NaN            NaN
# 361                                                NaN
# 368                                                NaN  Tesco Website
# 374                                                can
# 377                                                can
# 378                                                can
# 379                                                can
# 381                                                NaN
# 383                                                NaN
# 384                                                jar
# 387                                                NaN
# 397                          indiviudal bar, multipack
# 404                                                jar            NaN
# 415                                                bag
# 416                                                bag            NaN
# 417                                                bag            NaN
# 418                                                bag            NaN
# 421                                                tin
# 427                                                tin
# 428                                                jar
# 431                                                tin
# 432                                             packet
# 434                                             packet
# 438                                             packet
# 440                                             packet
# 443                                             packet
# 444                                                jar
# 446                                             packet
# 447                                             packet
# 448                                             packet
# 450                                             packet
# 452                                             packet
# 453                                             packet
# 454                                             packet
# 464                                  loose, individual
# 482                                             packet
# 484                                                tin
# 485                                   individual, pack
# 487                                             packet
# 490                                                NaN
# 494                                                can
# 504                                                NaN
# 524                                                tin
# 529                                                NaN
#
#      Similarity Score     Weight PurEqualCon       Portion Consumed
# 0            0.572115       333g           Y              small can
# 1            0.569783        25g           Y                    NaN
# 3            0.792667       200g           Y                 medium
# 4            0.707107        29g           Y            1 miniature
# 6            0.693251      750ml           Y       1 average bottle
# 7            0.578011      750ml           Y       1 average bottle
# 11           0.570654       150g           Y           Stage 1 jars
# 18           0.572115       333g           Y              small can
# 20           0.707107       585g           Y                 1 pint
# 27           0.546302        20g           Y                1 slice
# 29           0.546302        20g           Y                1 slice
# 30           0.585553        20g           Y                1 slice
# 31           0.553591       260g        Y, P            2 in a pack
# 32           0.614698       260g        Y, P            2 in a pack
# 33           0.546302        20g           Y                1 slice
# 34           0.546302        20g           Y                1 slice
# 38           0.546302        20g           Y                1 slice
# 41           0.546302        20g           Y                1 slice
# 42           0.546302        20g           Y                1 slice
# 43           0.546302        20g           Y                1 slice
# 65           0.638722        12g           Y               1 sachet
# 85           0.579284        55g           Y      1 canned pilchard
# 88           0.607137        50g           Y                    bar
# 94           0.607288       210g           Y                  1 can
# 107          0.587857       600g           Y             6 servings
# 108          0.531195       100g           Y                per bag
# 111          0.781551        70g           Y                    NaN
# 113          0.582216       198g           Y            1 small can
# 115          0.583707       200g           Y            1 small can
# 116          0.583707       200g           Y            1 small can
# 117          0.583707       200g           Y            1 small can
# 118          0.583707       200g           Y            1 small can
# 121          0.578758       200g           Y            1 small can
# 125          0.531195       100g           Y                per bag
# 134          0.750021        85g           Y            1 small can
# 135          0.577969        85g           Y            1 small can
# 150          0.867092       105g           Y   1 can smoked oysters
# 152          0.896965       100g           Y     1 small jar prawns
# 167          0.538421       250g           Y            1 raw small
# 208          0.570654       150g           Y           Stage 1 jars
# 240          0.574085        20g           Y                1 slice
# 257          0.582216       198g           Y            1 small can
# 259          0.582216       198g           Y            1 small can
# 260          0.582216       198g           Y            1 small can
# 262          0.582216       198g           Y            1 small can
# 263          0.582216       198g           Y            1 small can
# 264          0.582216       198g           Y            1 small can
# 265          0.582216       198g           Y            1 small can
# 266          0.535676        70g           Y                    NaN
# 269          0.542768        70g           Y                    NaN
# 272          0.535676        70g           Y                    NaN
# 273          0.781551        70g           Y                    NaN
# 275          0.741514       198g           Y            1 small can
# 278          0.706894       190g           Y                    NaN
# 280          0.706894       190g           Y                    NaN
# 284          0.542625        25g           Y         1 portion pack
# 285          0.554332       180g           Y                    NaN
# 296          0.625702       165g           Y                    NaN
# 303          0.638722        12g           Y               1 sachet
# 311          0.638722        12g           Y               1 sachet
# 316          0.638722        12g           Y               1 sachet
# 317          0.638722        12g           Y               1 sachet
# 320          0.638722        12g           Y               1 sachet
# 323          0.707107       585g           Y                 1 pint
# 324          0.619835       585g           Y                 1 pint
# 325          0.619835       585g           Y                 1 pint
# 326          0.619835       585g           Y                 1 pint
# 327          0.707107       585g           Y                 1 pint
# 328          0.851933       170g           Y            1 small can
# 329          0.577233       585g           Y                 1 pint
# 330          0.590812        32g           Y               1 sachet
# 334          0.707107       585g           Y                 1 pint
# 341          0.545677       585g           Y                 1 pint
# 346          0.799777        25g           Y         1 portion pack
# 354          0.588352        20g           Y         1 portion pack
# 361          0.539282       110g           Y                 medium
# 368          0.685634       165g           Y                    NaN
# 374          0.607288       210g           Y                  1 can
# 377          0.607288       210g           Y                  1 can
# 378          0.607288       210g           Y                  1 can
# 379          0.788135  210g/440g           Y                    can
# 381          0.728643        25g           Y                    NaN
# 383          0.850244        12g           Y               1 sachet
# 384          0.725977        25g           Y                    NaN
# 387          0.582216       198g           Y            1 small can
# 397          0.572963        51g           Y  chocolate covered bar
# 404          0.673736         6g           Y       1 'packet' sugar
# 415          0.558865        32g           Y               1 sachet
# 416          0.648496         6g           Y       1 'packet' sugar
# 417          0.917112         6g           Y       1 'packet' sugar
# 418          0.917112         6g           Y       1 'packet' sugar
# 421          0.607288       210g           Y                  1 can
# 427          0.607288       210g           Y                  1 can
# 428          0.541214        35g           Y            1 small jar
# 431          0.581497  150g/205g           Y            1 small can
# 432          0.600011  150g/205g           Y            1 small can
# 434          0.600011  150g/205g           Y            1 small can
# 438          0.600011  150g/205g           Y            1 small can
# 440          0.600011  150g/205g           Y            1 small can
# 443          0.600011  150g/205g           Y            1 small can
# 444          0.600011  150g/205g           Y            1 small can
# 446          0.600011  150g/205g           Y            1 small can
# 447          0.600011  150g/205g           Y            1 small can
# 448          0.600011  150g/205g           Y            1 small can
# 450          0.600011  150g/205g           Y            1 small can
# 452          0.600011  150g/205g           Y            1 small can
# 453          0.600011  150g/205g           Y            1 small can
# 454          0.600011  150g/205g           Y            1 small can
# 464          0.600011  150g/205g           Y            1 small can
# 482          0.625810       185g           Y                    NaN
# 484          0.533180  210g/440g           Y                    can
# 485          0.574085        20g           Y                1 slice
# 487          0.600011  150g/205g           Y            1 small can
# 490          0.711791        12g           Y               1 sachet
# 494          0.607288       210g           Y                  1 can
# 504          0.539282       110g           Y                 medium
# 524          0.607288       210g           Y                  1 can
# 529          0.597995  210g/440g           Y                    can

# %% [markdown]
# #### Export Matched DataSet

# %%
#redFood_matched.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\ReducedwithWeights\dataproduct.csv')

# %% [markdown]
# ### 320 / 535 items Matched Using Algo 4 which is a combination of Algo 2 & It uses the fuzz.partial_token_set_ratio & Term Frequency-Inverse Document Frequency

# %%
f'Fourth Algorithm Matched {round((118/535) * 100, 2)}% of products between McCane and Widdowson df and Food Portion Sizes df at a threshold of 90 and a Cosine threshold of 70. Contains some errors'
# Out:
# 'Fourth Algorithm Matched 22.06% of products between McCane and Widdowson df and Food Portion Sizes df at a threshold of 90 and a Cosine threshold of 70. Contains some errors'

# %% [markdown]
# ## Plotting Matching Efficiency of Algo 4

# %% [markdown]
# Find total counts of food by Super Group

# %%
d = redFood_matched[redFood_matched['Weight'] != '']
ax4_s = d.groupby('Food Group')['Food Name'].count().rename('Matched Prod Count', inplace=True).copy().sort_values(ascending=True)
ax4 = pd.DataFrame(ax4_s).reset_index()
ax4
# Out:
#                                Food Group  Matched Prod Count
# 0                                    Eggs                   1
# 1                        Herbs and spices                   1
# 2                                   Fruit                   2
# 3                          Nuts and seeds                   2
# 4                               Beverages                   3
# 5                           Fats and oils                   5
# 6                     Alcoholic beverages                   6
# 7                  Fish and fish products                   6
# 8            Sugars, preserves and snacks                   6
# 9   Soups, sauces and miscellaneous foods                  11
# 10                 Milk and milk products                  14
# 11            Cereals and cereal products                  17
# 12                 Meat and meat products                  17
# 13                             Vegetables                  27

# %%
ax4_count = redFood_matched.groupby('Food Group')['Food Name'].count().rename('Total Prod Count', inplace=True).copy().sort_values(ascending=True)
ax4_nt = pd.DataFrame(ax4_count).reset_index()
ax4_nt
# Out:
#                                Food Group  Total Prod Count
# 0                                    Eggs                 2
# 1                           Fats and oils                 7
# 2                     Alcoholic beverages                 8
# 3                               Beverages                14
# 4                          Nuts and seeds                17
# 5            Sugars, preserves and snacks                25
# 6                  Fish and fish products                33
# 7                  Milk and milk products                33
# 8                        Herbs and spices                35
# 9   Soups, sauces and miscellaneous foods                44
# 10                 Meat and meat products                46
# 11                                  Fruit                68
# 12            Cereals and cereal products                89
# 13                             Vegetables               114

# %%
# Evaluating Percentaged Mapped
ax4_counts = ax4_nt.merge(ax4, on='Food Group', how='left')
ax4_counts['%Matched'] = ax4_counts['Matched Prod Count'] / ax4_counts['Total Prod Count'] * 100

# %%
import matplotlib.font_manager as fm

# Find the minimum count in the ax4_counts DataFrame.
min_count4 = ax4_counts['%Matched'].min()

# Create a custom color palette.
bar_colors4 = ['lightpink' if count != min_count4 else '#f95d6a' for count in ax4_counts['%Matched']]

# Set the font family and size for the title.
title_font = fm.FontProperties(family='Times New Roman', size=24)

# Set the font family and size for the axes labels.
axis_font = fm.FontProperties(family='Times New Roman', size=18)

# Create the figure and axes objects.
fig, ax = plt.subplots(figsize=(10, 8))

# Plot the horizontal bar chart.
bars = ax.barh(ax4_counts['Food Group'], ax4_counts['%Matched'], color=bar_colors4)

# Add gridlines to the plot.
ax.grid(axis='x', linestyle='--', alpha=0.2)

# Customize the title, x-axis, and y-axis labels.
ax.set_title('Matching Rate of Hybrid Matching (Algorithm 4)', fontproperties=title_font)
ax.set_xlabel('Percentage Matched', fontproperties=axis_font)
ax.set_ylabel('Food Group', fontproperties=axis_font)

# Set the maximum value of the x-axis to 100.
ax.set_xlim(0, 100)

# Adjust the spacing around the plot.
plt.tight_layout(pad=1.0)

# Remove the top and right spines from the plot.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Increase the tick label font size.
ax.tick_params(axis='both', which='major', labelsize=13)

# Invert the y-axis to display the highest match on top.
ax.invert_yaxis()

    # Show the plot.
plt.show()

# %% [markdown]
#                                                   NEXT NOTEBOOK
