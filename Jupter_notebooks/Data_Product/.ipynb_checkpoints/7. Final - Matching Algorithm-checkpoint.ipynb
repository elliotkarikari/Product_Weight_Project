# %% [markdown]
# # Matching Algorithm - Matching with Food Description/Name column

# %% [markdown]
# There is something wrong with the matching algo. When I run it one i get weird results but when I run it the second time I get better results in some categories

# %% [markdown]
# ##### Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re #regular expressions 
from fuzzywuzzy import process, fuzz
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ##### Read In Data

# %% [markdown]
#                                                       M&W Reduced

# %%
#pd.set_option('display.max_rows', None)
redFood = pd.read_csv(r"C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\ReducedwithWeights\dataproduct2.csv", index_col=0)
redFood['Food Name'] = redFood['Food Name'].str.lower()
redFood.head()
# Out:
#   Food Code                 Food Name Food sub-group codes  \
# 0    17-208  beer bitter best premium                   QA
# 1    17-224               cider sweet                   QC
# 2    17-234                      port                   QF
# 3    17-236             sherry medium                   QF
# 4    17-247        spirits 40% volume                   QK
#
#             Food Group                                Sale format(s)  Source  \
# 0  Alcoholic beverages  can, can multipack, bottle, bottle multipack     NaN
# 1  Alcoholic beverages  can, can multipack, bottle, bottle multipack     NaN
# 2  Alcoholic beverages                                        bottle     NaN
# 3  Alcoholic beverages                                        bottle     NaN
# 4  Alcoholic beverages                             bottle, miniature     NaN
#
#    Similarity Score Weight PurEqualCon Portion Consumed
# 0          0.601799   333g           Y        small can
# 1          0.000000    NaN         NaN              NaN
# 2          0.000000    NaN         NaN              NaN
# 3          0.792070   200g           Y           medium
# 4          0.707107    29g           Y      1 miniature

# %%
redFood.columns
# Out:
# Index(['Food Code', 'Food Name', 'Food sub-group codes', 'Food Group',
#        'Sale format(s)', 'Source', 'Similarity Score', 'Weight', 'PurEqualCon',
#        'Portion Consumed'],
#       dtype='object')

# %%
redFood.drop(['Source', 'Similarity Score', 'Weight', 'PurEqualCon',
       'Portion Consumed'], axis=1, inplace=True)

# %% [markdown]
# Creating a Source column to indicate where I got weight data from

# %%
redFood['Source'] = ' '

# %% [markdown]
# Remove the word raw from all strings

# %%
redFood['Food Name'] = redFood['Food Name'].str.replace(r'\braw\b', '', case=False).str.strip()
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_13412\3194073488.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   redFood['Food Name'] = redFood['Food Name'].str.replace(r'\braw\b', '', case=False).str.strip()

# %%
redFood['Food Name'] = redFood['Food Name'].str.replace(r'\bcanned\b', '', case=False).str.strip()
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_13412\2870357712.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   redFood['Food Name'] = redFood['Food Name'].str.replace(r'\bcanned\b', '', case=False).str.strip()

# %%
redFood['Food Name'] = redFood['Food Name'].str.replace(r'\bretial\b', '', case=False).str.strip()
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_13412\781900119.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   redFood['Food Name'] = redFood['Food Name'].str.replace(r'\bretial\b', '', case=False).str.strip()

# %%
redFood['Food Name'] = redFood['Food Name'].str.replace(r'\bretail\b', '', case=False).str.strip()
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_13412\1532661085.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   redFood['Food Name'] = redFood['Food Name'].str.replace(r'\bretail\b', '', case=False).str.strip()

# %%
redFood['Food Name'] = redFood['Food Name'].str.replace(r'\blean\b', '', case=False).str.strip()
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_13412\1293648092.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   redFood['Food Name'] = redFood['Food Name'].str.replace(r'\blean\b', '', case=False).str.strip()

# %%
redFood['Food Name'] = redFood['Food Name'].str.replace(r'\bvegetable\b', '', case=False).str.strip()
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_13412\2351664628.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   redFood['Food Name'] = redFood['Food Name'].str.replace(r'\bvegetable\b', '', case=False).str.strip()

# %%
redFood['Food Name'] = redFood['Food Name'].str.replace(r'\bplain\b', '', case=False).str.strip()
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_13412\3763956422.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   redFood['Food Name'] = redFood['Food Name'].str.replace(r'\bplain\b', '', case=False).str.strip()

# %%
# Remove commas from 'Food Name' column
redFood['Food Name'] = redFood['Food Name'].str.replace(',', '').str.strip()

# %% [markdown]
#                                                          FPS Data

# %%
CleanRetai = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\FoodPortionSized\FPS_VJ.csv')
CleanRetai['Food Name'] = CleanRetai['Food Name'].str.lower()  # Convert to lowercase
CleanRetai['Food Name'].drop_duplicates(inplace=True)           # Drop duplicate values
CleanRetai['Food Name'].dropna(inplace=True)                   # Drop rows with missing values
#CleanRetai['Portion Consumed'].dropna(inplace=True)

# %%
CleanRetai.dropna(subset=['Portion Consumed'], inplace=True)

# %%
CleanRetai
# Out:
#                            Group         Brand  \
# 7                     BABY FOODS  Cow and Gate
# 8                     BABY FOODS  Cow and Gate
# 9                     BABY FOODS           NaN
# 11                    BABY FOODS         Heinz
# 12                    BABY FOODS         Heinz
# ...                          ...           ...
# 2666  YOGHURTS AND FROMAGE FRAIS           NaN
# 2667  YOGHURTS AND FROMAGE FRAIS           NaN
# 2673  YOGHURTS AND FROMAGE FRAIS           NaN
# 2675  YOGHURTS AND FROMAGE FRAIS           NaN
# 2676  YOGHURTS AND FROMAGE FRAIS        Heinz
#
#                                 Food Name      Portion Consumed Weight  \
# 7               ready to drink baby juice          Stage 1 jars   150g
# 8               ready to drink baby juice          Stage 2 jars   200g
# 9               dried/powdered baby foods  1 average tablespoon     5g
# 11                          fromage frais                   Jar   150g
# 12                               desserts                   Can   128g
# ...                                   ...                   ...    ...
# 2666  tesco, yoplait, fruit on the bottom                  pots  100g
# 2667           tesco, yoplait light fruit                  pots  100g
# 2673                        petit danoneâ                 small    50g
# 2675                   baby fromage frais           Baby Danone    60g
# 2676                   baby fromage frais                   Jar   163g
#
#      PurEqualCon  Purchased Format Source
# 7              Y        NaN    NaN    NaN
# 8              Y        NaN    NaN    NaN
# 9              N        NaN    NaN    NaN
# 11             Y        NaN    NaN    NaN
# 12             Y        NaN    NaN    NaN
# ...          ...        ...    ...    ...
# 2666           Y        NaN    NaN    NaN
# 2667           Y        NaN    NaN    NaN
# 2673         NaN        NaN    NaN    NaN
# 2675           Y        NaN    NaN    NaN
# 2676           Y        NaN    NaN    NaN
#
# [2036 rows x 9 columns]

# %% [markdown]
#                             Identify Food Portion Sizes that are equivalent to Retail sold portions

# %%
CleanRetail = CleanRetai[CleanRetai['PurEqualCon'].isin(['Y', 'Y, P'])]
CleanRetail#[CleanRetail['Food Name'].str.contains('bread')]#.head()
# Out:
#                            Group         Brand  \
# 7                     BABY FOODS  Cow and Gate
# 8                     BABY FOODS  Cow and Gate
# 11                    BABY FOODS         Heinz
# 12                    BABY FOODS         Heinz
# 13                    BABY FOODS         Heinz
# ...                          ...           ...
# 2665  YOGHURTS AND FROMAGE FRAIS           NaN
# 2666  YOGHURTS AND FROMAGE FRAIS           NaN
# 2667  YOGHURTS AND FROMAGE FRAIS           NaN
# 2675  YOGHURTS AND FROMAGE FRAIS           NaN
# 2676  YOGHURTS AND FROMAGE FRAIS        Heinz
#
#                                              Food Name Portion Consumed  \
# 7                            ready to drink baby juice     Stage 1 jars
# 8                            ready to drink baby juice     Stage 2 jars
# 11                                       fromage frais              Jar
# 12                                            desserts              Can
# 13                                            desserts              Jar
# ...                                                ...              ...
# 2665  sainsburys, virtually fat free with fruit pieces             pots
# 2666               tesco, yoplait, fruit on the bottom             pots
# 2667                        tesco, yoplait light fruit             pots
# 2675                                baby fromage frais      Baby Danone
# 2676                                baby fromage frais              Jar
#
#      Weight PurEqualCon  Purchased Format Source
# 7      150g           Y        NaN    NaN    NaN
# 8      200g           Y        NaN    NaN    NaN
# 11     150g           Y        NaN    NaN    NaN
# 12     128g           Y        NaN    NaN    NaN
# 13     163g           Y        NaN    NaN    NaN
# ...     ...         ...        ...    ...    ...
# 2665  100g            Y        NaN    NaN    NaN
# 2666  100g            Y        NaN    NaN    NaN
# 2667  100g            Y        NaN    NaN    NaN
# 2675    60g           Y        NaN    NaN    NaN
# 2676   163g           Y        NaN    NaN    NaN
#
# [596 rows x 9 columns]

# %%
# Merge columns using .str.cat() and create a new column 'Merged_Column'
CleanRetail['Merged Name'] = CleanRetail['Food Name'].astype(str).str.cat(CleanRetail['Portion Consumed'].astype(str), sep=',')
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_13412\3856531053.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CleanRetail['Merged Name'] = CleanRetail['Food Name'].astype(str).str.cat(CleanRetail['Portion Consumed'].astype(str), sep=',')

# %%
CleanRetail['Merged Name'] = CleanRetail['Merged Name'].str.lower()
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_13412\2238590420.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CleanRetail['Merged Name'] = CleanRetail['Merged Name'].str.lower()

# %% [markdown]
# ###                                                        Match Data (Hybrid Algo).
#
# ###### Once matched, Import Weight and Unit Columns into Reduced M&W table

# %% [markdown]
# Seem to work better when run twice. Something isn't working well with the matching process

# %% [markdown]
# ###### Algorithm

# %%
# %%time

def preprocess_text(df, column_name):
    return df[column_name].str.replace(r'\s+', ' ').str.strip().str.lower()

def fuzzy_matching_score(source, target):
    return fuzz.partial_token_set_ratio(source, target)

def get_most_similar_indices(tfidf_red_food, tfidf_clean_retail):
    similarities = cosine_similarity(tfidf_red_food, tfidf_clean_retail)
    return similarities.argmax(axis=1)

def hybrid_fuzzy_matching(CleanRetail, redFood):
    # Set thresholds for matching
    partial_token_set_ratio_threshold = 99
    cosine_similarity_threshold = 0.75
    min_similarity_threshold = 0.62

    # Preprocess text data in both DataFrames for the "Merged Name" field.
    CleanRetail['Merged Name'] = preprocess_text(CleanRetail, 'Merged Name')
    redFood['Food Name'] = preprocess_text(redFood, 'Food Name')

    # Step 1: Partial Token Set Ratio (Fuzzy Matching)
    CleanRetail['Partial Token Set Ratio'] = CleanRetail['Merged Name'].apply(lambda x: fuzzy_matching_score(x, redFood['Food Name']))
    potential_matches = CleanRetail[CleanRetail['Partial Token Set Ratio'] >= partial_token_set_ratio_threshold]

    # Step 2: TF-IDF and Cosine Similarity (Text Matching) - Use combined matches as input
    vectorizer = TfidfVectorizer()
    vectorizer.fit(potential_matches['Merged Name'])
    tfidf_clean_retail = vectorizer.transform(potential_matches['Merged Name'])
    tfidf_red_food = vectorizer.transform(redFood['Food Name'])

    # Find the most similar match for each redFood product
    max_sim_indices = get_most_similar_indices(tfidf_red_food, tfidf_clean_retail)
    max_sim_scores = cosine_similarity(tfidf_red_food, tfidf_clean_retail).max(axis=1)

    # Update redFood DataFrame with matched information and sources
    redFood['Similarity Score'] = max_sim_scores
    redFood['Weight'] = potential_matches['Weight'].values[max_sim_indices]
    redFood['PurEqualCon'] = potential_matches['PurEqualCon'].values[max_sim_indices]
    redFood['Portion Consumed'] = potential_matches['Portion Consumed'].values[max_sim_indices]

    # Create a mapping dictionary for matched indices to their sources
    match_indices_to_sources = dict(zip(potential_matches.index, potential_matches['Source']))

    # Map the sources and format to the redFood DataFrame based on matched indices
    redFood['Source'] = redFood.index.map(lambda i: match_indices_to_sources.get(max_sim_indices[i], ''))

    # Set to NaN for rows where similarity score is below the minimum threshold
    redFood.loc[redFood['Similarity Score'] < min_similarity_threshold, ['Weight', 'PurEqualCon', 'Portion Consumed', 'Source']] = ''

    return redFood

# Call the hybrid_fuzzy_matching function and get the matched DataFrame
redFood_matched = hybrid_fuzzy_matching(CleanRetail.copy(), redFood.copy())
# Out:
# <timed exec>:2: FutureWarning: The default value of regex will change from True to False in a future version.
# CPU times: total: 3.98 s
# Wall time: 4.09 s

# %%
pd.set_option('display.max_rows', None)
#redFood_matched.head()

# %% [markdown]
# Identifying Matched Items with weights

# %%
pd.set_option('display.max_rows', None)
d = redFood_matched.loc[redFood_matched['Weight'] != '']
d#['Food Name'].value_counts().sum()
# Out:
#     Food Code                                Food Name Food sub-group codes  \
# 3      17-236                            sherry medium                   QF
# 4      17-247                       spirits 40% volume                   QK
# 6      17-752                                 wine red                   QE
# 13     17-672                  energy drink carbonated                  PCA
# 19     17-244                   liqueurs high strength                   QI
# 23     11-002                             barley pearl                   AA
# 30     11-937                    bread garlic and herb                   AF
# 31     11-910    bread naan peshwari naan takeaway and                   AF
# 32     11-973                               bread naan                   AF
# 68     11-850                      doughnuts ring iced                   AP
# 75        NaN                          macaroni cheese                   AD
# 88     11-844  pastries chocolate eclairs cream filled                   AP
# 93        NaN                           pudding sponge                   AS
# 94    11-1021                           pudding sponge                   AS
# 95        NaN                           prawn crackers                   AT
# 105    11-802                               shortbread                   AM
# 107    11-919              strudel fruit filled frozen                   AS
# 109    11-800       wafers ice cream wafers not filled                   AM
# 121       NaN                         anchovies in oil                   JC
# 133       NaN                            crab in brine                   JK
# 134       NaN                                     crab                   JK
# 150    16-260                                  oysters                   JM
# 152    16-387                              prawns king                   JK
# 157    14-392         apricots ready-to-eat semi-dried                   FA
# 176    14-322                             grapes green                   FA
# 206    14-285                      passion fruit juice                   FC
# 213    14-391           prunes ready-to-eat semi-dried                   FA
# 214    14-393                            raisins dried                   FA
# 247    13-839                            mustard seeds                    H
# 257    18-006                      beef braising steak                  MAC
# 259    18-016                        beef fillet steak                  MAC
# 264    18-064                       beef sirloin steak                  MAC
# 275    19-128                              corned beef                   MI
# 277       NaN                        casserole sausage                   MR
# 278       NaN                        chow mein chicken                   MR
# 280       NaN                       coronation chicken                   MR
# 297       NaN               meatballs in tomatoe sauce                   MR
# 311    12-507             cornetto type ice cream cone                   BP
# 312    12-542              cheesecake fruit individual                   BR
# 320    12-390             lollies containing ice-cream                   BP
# 324    12-307         milk skimmed pasteurised average                  BAE
# 325    12-313    milk semi-skimmed pasteurised average                  BAH
# 328    12-522                    milk evaporated whole                  BAR
# 346    14-892                     peanut butter smooth                   GA
# 369    17-364                           mustard smooth                   WY
# 371    17-718                             pickle sweet                  WCG
# 374    17-711                          soup minestrone                   WA
# 377    17-698                              soup lentil                  WAC
# 378    17-700                              soup oxtail                  WAC
# 379    17-712                                     soup                  WAC
# 383    17-703                              salad cream                  WCG
# 394    17-377                          water distilled                   WY
# 405    17-777                       liquorice allsorts                  SEC
# 410    17-114                             marshmallows                  SEC
# 411       NaN                                   nougat                  SEC
# 414    17-132                         pork scratchings                   SN
# 416    17-060                              sugar brown                   SC
# 417    17-062                              sugar icing                   SC
# 418    17-063                              sugar white                   SC
# 433       NaN                              beans aduki                   DB
# 435       NaN                           beans blackeye                   DB
# 439       NaN                         beans chick peas                   DB
# 440    13-080                            beans cluster                   DB
# 442       NaN                            beans edamame                   DB
# 443    13-514                              beans green                   DB
# 445       NaN                            beans haricot                   DB
# 446    13-098                    beans mung dahl dried                   DB
# 448    13-106                        beans pinto dried                   DB
# 449       NaN                              beans pinto                   DB
# 452    13-112                             beans runner                   DB
# 453    13-115                         beans soya dried                   DB
# 454    13-117                              beans sword                   DB
# 464    13-067                        beans broad dried                   DB
# 465       NaN                              beans broad                   DB
# 467       NaN                         beans cannellini                   DB
# 487    13-608                        green beans dried                   DI
# 490    13-258                              horseradish                   DG
# 500    13-298                           mustard leaves                   DG
# 504       NaN                                 potatoes                   DA
# 519    13-521                             spinach baby                   DG
# 528    15-883                           shepherd's pie                   DR
#
#                                 Food Group  \
# 3                      Alcoholic beverages
# 4                      Alcoholic beverages
# 6                      Alcoholic beverages
# 13                               Beverages
# 19                               Beverages
# 23             Cereals and cereal products
# 30             Cereals and cereal products
# 31             Cereals and cereal products
# 32             Cereals and cereal products
# 68             Cereals and cereal products
# 75             Cereals and cereal products
# 88             Cereals and cereal products
# 93             Cereals and cereal products
# 94             Cereals and cereal products
# 95             Cereals and cereal products
# 105            Cereals and cereal products
# 107            Cereals and cereal products
# 109            Cereals and cereal products
# 121                 Fish and fish products
# 133                 Fish and fish products
# 134                 Fish and fish products
# 150                 Fish and fish products
# 152                 Fish and fish products
# 157                                  Fruit
# 176                                  Fruit
# 206                                  Fruit
# 213                                  Fruit
# 214                                  Fruit
# 247                       Herbs and spices
# 257                 Meat and meat products
# 259                 Meat and meat products
# 264                 Meat and meat products
# 275                 Meat and meat products
# 277                 Meat and meat products
# 278                 Meat and meat products
# 280                 Meat and meat products
# 297                 Meat and meat products
# 311                 Milk and milk products
# 312                 Milk and milk products
# 320                 Milk and milk products
# 324                 Milk and milk products
# 325                 Milk and milk products
# 328                 Milk and milk products
# 346                         Nuts and seeds
# 369  Soups, sauces and miscellaneous foods
# 371  Soups, sauces and miscellaneous foods
# 374  Soups, sauces and miscellaneous foods
# 377  Soups, sauces and miscellaneous foods
# 378  Soups, sauces and miscellaneous foods
# 379  Soups, sauces and miscellaneous foods
# 383  Soups, sauces and miscellaneous foods
# 394  Soups, sauces and miscellaneous foods
# 405           Sugars, preserves and snacks
# 410           Sugars, preserves and snacks
# 411           Sugars, preserves and snacks
# 414           Sugars, preserves and snacks
# 416           Sugars, preserves and snacks
# 417           Sugars, preserves and snacks
# 418           Sugars, preserves and snacks
# 433                             Vegetables
# 435                             Vegetables
# 439                             Vegetables
# 440                             Vegetables
# 442                             Vegetables
# 443                             Vegetables
# 445                             Vegetables
# 446                             Vegetables
# 448                             Vegetables
# 449                             Vegetables
# 452                             Vegetables
# 453                             Vegetables
# 454                             Vegetables
# 464                             Vegetables
# 465                             Vegetables
# 467                             Vegetables
# 487                             Vegetables
# 490                             Vegetables
# 500                             Vegetables
# 504                             Vegetables
# 519                             Vegetables
# 528                             Vegetables
#
#                                         Sale format(s) Source  \
# 3                                               bottle    NaN
# 4                                    bottle, miniature
# 6                            bottle, small bottle, box    NaN
# 13          can, ready to drink bottle, sharing bottle
# 19                                   bottle, miniature
# 23                                              packet
# 30                    loose, individual\nmultiple pack
# 31                    loose, individual\nmultiple pack
# 32                    loose, individual\nmultiple pack
# 68                                                 NaN    NaN
# 75                                                 NaN
# 88                                                 NaN
# 93                                                 NaN
# 94                                                 NaN
# 95                                              packet
# 105                                     wrapper or box
# 107                                                NaN    NaN
# 109                                                NaN
# 121                                                tin
# 133                                                tin
# 134                                                NaN
# 150                                                NaN
# 152                                                NaN
# 157                                             packet
# 176                                             punnet
# 206                           carton, tetrapak, bottle
# 213                                                NaN
# 214                                             packet
# 247                                          spice jar    NaN
# 257                                                NaN
# 259                                                NaN
# 264                                                NaN
# 275                                                tin
# 277                                                NaN
# 278                                                NaN
# 280                                                NaN
# 297                                                NaN
# 311                                                box
# 312                                                NaN
# 320                                                NaN
# 324  bottle 1 pint, 2 pint, 4 pint, 6 pint, carton ...
# 325  bottle 1 pint, 2 pint, 4 pint, 6 pint, carton ...
# 328                                                tin
# 346                                                jar
# 369                                                jar    NaN
# 371                                                jar
# 374                                                can
# 377                                                can
# 378                                                can
# 379                                                can
# 383                                                NaN    NaN
# 394                                                NaN
# 405                                                bag
# 410                                                NaN
# 411                                                NaN
# 414                                                bag
# 416                                                bag
# 417                                                bag
# 418                                                bag
# 433                                                tin
# 435                                                tin
# 439                                                tin
# 440                                             packet
# 442                                                tin
# 443                                             packet
# 445                                                tin
# 446                                             packet
# 448                                             packet
# 449                                                tin
# 452                                             packet
# 453                                             packet
# 454                                             packet
# 464                                  loose, individual
# 465                                                tin
# 467                                                can
# 487                                             packet
# 490                                                NaN
# 500                                                NaN    NaN
# 504                                                NaN
# 519                                             packet
# 528                                                NaN
#
#      Similarity Score   Weight PurEqualCon      Portion Consumed
# 3            0.792070     200g           Y                medium
# 4            0.707107      29g           Y           1 miniature
# 6            0.711739    750ml           Y      1 average bottle
# 13           0.746239    330ml           Y          standard can
# 19           0.801702     150g           Y                  pots
# 23           0.653898     180g           Y              I bottle
# 30           0.665822      20g           Y               1 slice
# 31           0.675200     260g        Y, P           2 in a pack
# 32           0.747909     260g        Y, P           2 in a pack
# 68           0.633877      30g        Y, P               per bag
# 75           0.762815     210g           Y             small can
# 88           0.703490      46g           Y                  tube
# 93           0.785243     300g           Y                 whole
# 94           0.785243     300g           Y                 whole
# 95           0.874811  30g/40g           Y               per bag
# 105          0.667867      42g           Y          6 shortbread
# 107          0.645084     600g           Y            6 servings
# 109          0.633637      60g           Y                   tub
# 121          0.692248     200g           Y           1 small can
# 133          0.672666      85g           Y           1 small can
# 134          0.791344      85g           Y           1 small can
# 150          0.870746     105g           Y  1 can smoked oysters
# 152          0.674258     100g           Y    1 small jar prawns
# 157          0.695211     125g           Y               per pot
# 176          0.843806     500g        Y, P                  pack
# 206          0.646407     200g           Y     individual carton
# 213          0.695211     125g           Y               per pot
# 214          0.642767      44g           Y                packet
# 247          0.786443       5g           Y              I sachet
# 257          0.712175     213g           Y                 small
# 259          0.712175     213g           Y                 small
# 264          0.712175     213g           Y                 small
# 275          0.879846     198g           Y           1 small can
# 277          0.773615      55g           Y             small can
# 278          0.626980     480g           Y                 large
# 280          0.626980     480g           Y                 large
# 297          0.629859     170g           Y     frozen, purchased
# 311          0.818542      60g           Y                   tub
# 312          0.919092      90g           Y            individual
# 320          0.818542      60g           Y                   tub
# 324          0.720252      50g           Y               average
# 325          0.720252      50g           Y               average
# 328          0.680189     170g           Y           1 small can
# 346          0.814234      25g           Y        1 portion pack
# 369          0.786443       5g           Y              I sachet
# 371          0.712555      20g           Y        1 portion pack
# 374          0.810965     170g           Y  vending machine soup
# 377          0.810965     170g           Y  vending machine soup
# 378          0.810965     170g           Y  vending machine soup
# 379          0.810965     170g           Y  vending machine soup
# 383          0.840663      12g           Y              1 sachet
# 394          0.638044     250g           Y                 small
# 405          0.733722      56g           Y             small bag
# 410          0.899076      40g           Y                   bag
# 411          0.789061      70g           Y             small bar
# 414          0.883367      22g           Y               per bag
# 416          0.712353       6g           Y      1 'packet' sugar
# 417          0.954900       6g           Y      1 'packet' sugar
# 418          0.712353       6g           Y      1 'packet' sugar
# 433          0.698585     170g           Y             small can
# 435          0.698585     170g           Y             small can
# 439          0.698585     170g           Y             small can
# 440          0.698585     170g           Y             small can
# 442          0.698585     170g           Y             small can
# 443          0.698585     170g           Y             small can
# 445          0.698585     170g           Y             small can
# 446          0.698585     170g           Y             small can
# 448          0.698585     170g           Y             small can
# 449          0.698585     170g           Y             small can
# 452          0.698585     170g           Y             small can
# 453          0.698585     170g           Y             small can
# 454          0.698585     170g           Y             small can
# 464          0.698585     170g           Y             small can
# 465          0.698585     170g           Y             small can
# 467          0.698585     170g           Y             small can
# 487          0.698585     170g           Y             small can
# 490          0.685131      12g           Y              1 sachet
# 500          0.786443       5g           Y              I sachet
# 504          0.833042      75g           Y                 small
# 519          0.713528      60g           Y           Baby Danone
# 528          0.641882     480g           Y                 large

# %% [markdown]
# #### Export Matched DataSet

# %%
redFood_matched.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\ReducedwithWeights\dataproduct3.csv')

# %% [markdown]
# ### 320 / 535 items Matched Using Algo 4 which is a combination of Algo 2 & It uses the fuzz.partial_token_set_ratio & Term Frequency-Inverse Document Frequency

# %%
f'Fourth Algorithm Matched {round((81/535) * 100, 2)}% of products between McCane and Widdowson df and Food Portion Sizes df at a threshold of 90 and a Cosine threshold of 70. Contains some errors'
# Out:
# 'Fourth Algorithm Matched 15.14% of products between McCane and Widdowson df and Food Portion Sizes df at a threshold of 90 and a Cosine threshold of 70. Contains some errors'

# %% [markdown]
# ## Plotting Matching Efficiency of Algo 4

# %% [markdown]
# Find total counts of food by Super Group

# %%
d = redFood_matched[redFood_matched['Weight'] != '']
ax4_s = d.groupby('Food Group')['Food Name'].count().rename('Matched Prod Count', inplace=True).copy().sort_values(ascending=True)
ax4 = pd.DataFrame(ax4_s).reset_index()
ax4
# Out:
#                                Food Group  Matched Prod Count
# 0                        Herbs and spices                   1
# 1                          Nuts and seeds                   1
# 2                               Beverages                   2
# 3                     Alcoholic beverages                   3
# 4                  Fish and fish products                   5
# 5                                   Fruit                   5
# 6                  Milk and milk products                   6
# 7            Sugars, preserves and snacks                   7
# 8                  Meat and meat products                   8
# 9   Soups, sauces and miscellaneous foods                   8
# 10            Cereals and cereal products                  13
# 11                             Vegetables                  22

# %%
ax4_count = redFood_matched.groupby('Food Group')['Food Name'].count().rename('Total Prod Count', inplace=True).copy().sort_values(ascending=True)
ax4_nt = pd.DataFrame(ax4_count).reset_index()
ax4_nt
# Out:
#                                Food Group  Total Prod Count
# 0                                    Eggs                 2
# 1                           Fats and oils                 7
# 2                     Alcoholic beverages                 8
# 3                               Beverages                14
# 4                          Nuts and seeds                17
# 5            Sugars, preserves and snacks                25
# 6                  Fish and fish products                33
# 7                  Milk and milk products                33
# 8                        Herbs and spices                35
# 9   Soups, sauces and miscellaneous foods                44
# 10                 Meat and meat products                46
# 11                                  Fruit                68
# 12            Cereals and cereal products                89
# 13                             Vegetables               116

# %%
# Evaluating Percentaged Mapped
ax4_counts = ax4_nt.merge(ax4, on='Food Group', how='left')
ax4_counts['%Matched'] = ax4_counts['Matched Prod Count'] / ax4_counts['Total Prod Count'] * 100

# %%
import matplotlib.font_manager as fm

# Find the minimum count in the ax4_counts DataFrame.
min_count4 = ax4_counts['%Matched'].min()

# Create a custom color palette.
bar_colors4 = ['lightpink' if count != min_count4 else '#f95d6a' for count in ax4_counts['%Matched']]

# Set the font family and size for the title.
title_font = fm.FontProperties(family='Times New Roman', size=24)

# Set the font family and size for the axes labels.
axis_font = fm.FontProperties(family='Times New Roman', size=18)

# Create the figure and axes objects.
fig, ax = plt.subplots(figsize=(10, 8))

# Plot the horizontal bar chart.
bars = ax.barh(ax4_counts['Food Group'], ax4_counts['%Matched'], color=bar_colors4)

# Add gridlines to the plot.
ax.grid(axis='x', linestyle='--', alpha=0.2)

# Customize the title, x-axis, and y-axis labels.
ax.set_title('Matching Rate of Hybrid Matching (Algorithm 4)', fontproperties=title_font)
ax.set_xlabel('Percentage Matched', fontproperties=axis_font)
ax.set_ylabel('Food Group', fontproperties=axis_font)

# Set the maximum value of the x-axis to 100.
ax.set_xlim(0, 100)

# Adjust the spacing around the plot.
plt.tight_layout(pad=1.0)

# Remove the top and right spines from the plot.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Increase the tick label font size.
ax.tick_params(axis='both', which='major', labelsize=13)

# Invert the y-axis to display the highest match on top.
ax.invert_yaxis()

    # Show the plot.
plt.show()

# %% [markdown]
#                                                   NEXT NOTEBOOK
