# %% [markdown]
# # Matching Algorithm - Matching with Food Description/Name column

# %% [markdown]
# There is something wrong with the matching algo. When I run it one i get weird results but when I run it the second time I get better results in some categories

# %% [markdown]
# ##### Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re #regular expressions 
from fuzzywuzzy import process, fuzz
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ##### Read In Data

# %% [markdown]
#                                                       M&W Reduced

# %%
#pd.set_option('display.max_rows', None)
redFood = pd.read_csv(r"C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\ReducedwithWeights\dataproduct.csv")
redFood.rename(columns={'Super Group':'SuperGroup'})
redFood['Food Name'] = redFood['Food Name'].str.lower()
redFood.head()
# Out:
#   Food Code                               Food Name Group  \
# 0    17-208     beer, bitter, best, premium, 1 pint    QA
# 1       NaN     beer, bitter, best, premium, bottle    QA
# 2       NaN  beer, bitter, best, premium, small can    QA
# 3       NaN  beer, bitter, best, premium, large can    QA
# 4    17-224                                   cider    QC
#
#            Super Group                                Sale format(s) Source  \
# 0  Alcoholic beverages                                          pint    FPS
# 1  Alcoholic beverages                                   beer bottle    NaN
# 2  Alcoholic beverages                                     small can    NaN
# 3  Alcoholic beverages                                     large can    NaN
# 4  Alcoholic beverages  can, can multipack, bottle, bottle multipack    NaN
#
#    Similarity Score Weight PurEqualCon Portion Consumed
# 0          0.707107   574g           Y           1 pint
# 1               NaN    NaN         NaN              NaN
# 2               NaN    NaN         NaN              NaN
# 3               NaN    NaN         NaN              NaN
# 4          0.609864    25g           Y              NaN

# %%
redFood.columns
# Out:
# Index(['Food Code', 'Food Name', 'Group', 'Super Group', 'Sale format(s)',
#        'Source', 'Similarity Score', 'Weight', 'PurEqualCon',
#        'Portion Consumed'],
#       dtype='object')

# %%
redFood.drop(['Source', 'Similarity Score', 'Weight', 'PurEqualCon',
       'Portion Consumed'], axis=1, inplace=True)

# %% [markdown]
# Creating a Source column to indicate where I got weight data from

# %%
redFood['Source'] = ' '

# %%
redFood
# Out:
#     Food Code                               Food Name Group  \
# 0      17-208     beer, bitter, best, premium, 1 pint    QA
# 1         NaN     beer, bitter, best, premium, bottle    QA
# 2         NaN  beer, bitter, best, premium, small can    QA
# 3         NaN  beer, bitter, best, premium, large can    QA
# 4      17-224                                   cider    QC
# ..        ...                                     ...   ...
# 528       NaN                vegetables mixed, frozen    DG
# 529    15-656                      vegeburger, retail    DR
# 530       NaN                 vegetable stir fry mix,    DR
# 531    13-673                              watercress    DG
# 532    13-397                                     yam    DG
#
#              Super Group                                Sale format(s) Source
# 0    Alcoholic beverages                                          pint
# 1    Alcoholic beverages                                   beer bottle
# 2    Alcoholic beverages                                     small can
# 3    Alcoholic beverages                                     large can
# 4    Alcoholic beverages  can, can multipack, bottle, bottle multipack
# ..                   ...                                           ...    ...
# 528           Vegetables                                        frozen
# 529           Vegetables                                       grilled
# 530           Vegetables                                        packet
# 531           Vegetables                                        packet
# 532           Vegetables                                           raw
#
# [533 rows x 6 columns]

# %% [markdown]
#                                                          FPS Data

# %%
CleanRetai = pd.read_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\FoodPortionSized\FPS_VJ.csv')
CleanRetai['Food Name'] = CleanRetai['Food Name'].str.lower()
CleanRetai.tail()
# Out:
#                            Group   Brand               Food Name  \
# 2672  YOGHURTS AND FROMAGE FRAIS     NaN                   onken
# 2673  YOGHURTS AND FROMAGE FRAIS     NaN           petit danoneâ
# 2674  YOGHURTS AND FROMAGE FRAIS     NaN  st ivel fiendish faces
# 2675  YOGHURTS AND FROMAGE FRAIS     NaN      baby fromage frais
# 2676  YOGHURTS AND FROMAGE FRAIS  Heinz       baby fromage frais
#
#      Portion Consumed Weight PurEqualCon  Purchased Format Source
# 2672              NaN   200g         NaN        NaN    NaN    NaN
# 2673            small    50g         NaN        NaN    NaN    NaN
# 2674              NaN    50g         NaN        NaN    NaN    NaN
# 2675      Baby Danone    60g           Y        NaN    NaN    NaN
# 2676              Jar   163g           Y        NaN    NaN    NaN

# %% [markdown]
#                             Identify Food Portion Sizes that are equivalent to Retail sold portions

# %%
CleanRetail = CleanRetai[CleanRetai['PurEqualCon'].isin(['Y', 'Y, P'])]
CleanRetail#[CleanRetail['Food Name'].str.contains('bread')]#.head()
# Out:
#                            Group   Brand                            Food Name  \
# 0                     BABY FOODS   Boots        first harvest,dessert starter
# 1                     BABY FOODS   Boots       first harvest, infant desserts
# 2                     BABY FOODS   Boots       first harvest,infant savouries
# 3                     BABY FOODS   Boots        first harvest,junior desserts
# 4                     BABY FOODS   Boots       first harvest,junior savouries
# ...                          ...     ...                                  ...
# 2666  YOGHURTS AND FROMAGE FRAIS     NaN  tesco, yoplait, fruit on the bottom
# 2667  YOGHURTS AND FROMAGE FRAIS     NaN           tesco, yoplait light fruit
# 2668  YOGHURTS AND FROMAGE FRAIS     NaN                  country love, fruit
# 2675  YOGHURTS AND FROMAGE FRAIS     NaN                   baby fromage frais
# 2676  YOGHURTS AND FROMAGE FRAIS  Heinz                    baby fromage frais
#
#      Portion Consumed Weight PurEqualCon  Purchased Format Source
# 0                 NaN   125g           Y        NaN    NaN    NaN
# 1                 NaN   125g           Y        NaN    NaN    NaN
# 2                 NaN   125g           Y        NaN    NaN    NaN
# 3                 NaN   190g           Y        NaN    NaN    NaN
# 4                 NaN   190g           Y        NaN    NaN    NaN
# ...               ...    ...         ...        ...    ...    ...
# 2666             pots  100g            Y        NaN    NaN    NaN
# 2667             pots  100g            Y        NaN    NaN    NaN
# 2668              NaN   150g           Y        NaN    NaN    NaN
# 2675      Baby Danone    60g           Y        NaN    NaN    NaN
# 2676              Jar   163g           Y        NaN    NaN    NaN
#
# [757 rows x 9 columns]

# %%
# Merge columns using .str.cat() and create a new column 'Merged_Column'
CleanRetail['Merged Name'] = CleanRetail['Food Name'].astype(str).str.cat(CleanRetail['Portion Consumed'].astype(str), sep=',')
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11592\3856531053.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CleanRetail['Merged Name'] = CleanRetail['Food Name'].astype(str).str.cat(CleanRetail['Portion Consumed'].astype(str), sep=',')

# %%
CleanRetail['Merged Name'] = CleanRetail['Merged Name'].str.lower()
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_11592\2238590420.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CleanRetail['Merged Name'] = CleanRetail['Merged Name'].str.lower()

# %% [markdown]
# ###                                                        Match Data (Hybrid Algo).
#
# ###### Once matched, Import Weight and Unit Columns into Reduced M&W table

# %% [markdown]
# Seem to work better when run twice. Something isn't working well with the matching process

# %% [markdown]
# ###### Algorithm

# %%
# %%time

def preprocess_text(df, column_name):
    return df[column_name].str.lower()

def fuzzy_matching_score(source, target):
    return fuzz.partial_token_set_ratio(source, target)

def get_most_similar_indices(tfidf_red_food, tfidf_clean_retail):
    similarities = cosine_similarity(tfidf_red_food, tfidf_clean_retail)
    return similarities.argmax(axis=1)

def hybrid_fuzzy_matching(CleanRetail, redFood):
    # Set thresholds for matching
    partial_token_set_ratio_threshold = 98
    cosine_similarity_threshold = 0.70
    min_similarity_threshold = 0.50

    # Preprocess text data in both DataFrames for the "Merged Name" field.
    CleanRetail['Merged Name'] = preprocess_text(CleanRetail, 'Merged Name')
    redFood['Food Name'] = preprocess_text(redFood, 'Food Name')

    # Step 1: Partial Token Set Ratio (Fuzzy Matching)
    CleanRetail['Partial Token Set Ratio'] = CleanRetail['Merged Name'].apply(lambda x: fuzzy_matching_score(x, redFood['Food Name']))
    potential_matches = CleanRetail[CleanRetail['Partial Token Set Ratio'] >= partial_token_set_ratio_threshold]

    # Step 2: TF-IDF and Cosine Similarity (Text Matching) - Use combined matches as input
    vectorizer = TfidfVectorizer()
    vectorizer.fit(potential_matches['Merged Name'])
    tfidf_clean_retail = vectorizer.transform(potential_matches['Merged Name'])
    tfidf_red_food = vectorizer.transform(redFood['Food Name'])

    # Find the most similar match for each redFood product
    max_sim_indices = get_most_similar_indices(tfidf_red_food, tfidf_clean_retail)
    max_sim_scores = cosine_similarity(tfidf_red_food, tfidf_clean_retail).max(axis=1)

    # Update redFood DataFrame with matched information and sources
    redFood['Similarity Score'] = max_sim_scores
    redFood['Weight'] = potential_matches['Weight'].values[max_sim_indices]
    redFood['PurEqualCon'] = potential_matches['PurEqualCon'].values[max_sim_indices]
    redFood['Portion Consumed'] = potential_matches['Portion Consumed'].values[max_sim_indices]

    # Create a mapping dictionary for matched indices to their sources
    match_indices_to_sources = dict(zip(potential_matches.index, potential_matches['Source']))

    # Map the sources and format to the redFood DataFrame based on matched indices
    redFood['Source'] = redFood.index.map(lambda i: match_indices_to_sources.get(max_sim_indices[i], ''))

    # Set to NaN for rows where similarity score is below the minimum threshold
    redFood.loc[redFood['Similarity Score'] < min_similarity_threshold, ['Weight', 'PurEqualCon', 'Portion Consumed', 'Source']] = ''

    return redFood

# Call the hybrid_fuzzy_matching function and get the matched DataFrame
redFood_matched = hybrid_fuzzy_matching(CleanRetail.copy(), redFood.copy())
# Out:
# CPU times: total: 328 ms
# Wall time: 345 ms

# %%
#pd.set_option('display.max_rows', None)
#redFood_matched.head()

# %% [markdown]
# Identifying Matched Items with weights

# %%
pd.set_option('display.max_rows', None)
d = redFood_matched.loc[redFood_matched['Weight'] != '']
d#['Food Name'].value_counts().sum()
# Out:
#     Food Code                                          Food Name Group  \
# 0      17-208                beer, bitter, best, premium, 1 pint    QA
# 1         NaN                beer, bitter, best, premium, bottle    QA
# 2         NaN             beer, bitter, best, premium, small can    QA
# 3         NaN             beer, bitter, best, premium, large can    QA
# 6      17-236                                     sherry, medium    QF
# 7      17-247                                spirits, 40% volume    QK
# 9      17-752                            wine, red, small bottle    QE
# 10     17-756                        wine, white, average bottle    QE
# 12     17-632                          coffee, cappuccino, latte     P
# 14     17-744                                    cranberry juice    PE
# 15     17-498                        drinking chocolate, instant   PAA
# 16     17-672                           energy drink, carbonated   PCA
# 17        NaN                        carbonated drink, large can   PCA
# 18        NaN                carbonated drink, bottled, standard   PCA
# 19        NaN                   carbonated drink, bottled, large   PCA
# 21     17-731                                  horlicks, instant   PAA
# 25     17-751                             lager, premium, 1 pint    QA
# 26        NaN                           lager, premium, 1/2 pint    QA
# 27        NaN                          lager, premium, small can    QA
# 28        NaN                          lager, premium, large can    QA
# 36    11-1144                          breadrolls, brown, crusty    AF
# 39     11-969                                    bread, ciabatta    AF
# 40     11-937                              garlic bread and herb    AF
# 41     11-910    bread, naan, peshwari naan, takeaway and retail    AF
# 42     11-973                                  naan bread, plain    AF
# 43     11-974                                bread, pitta, white    AF
# 44     11-947                                       seeded bread    AF
# 47     11-978                                 french breadsticks    AF
# 48     11-980                                white bread, sliced    AF
# 50     11-983                           bread rolls, brown, soft    AG
# 51     11-984                          bread rolls, malted wheat    AG
# 52     11-985                         bread rolls, white, crusty    AG
# 53     11-986                             bread rolls, wholemeal    AG
# 62     11-821                                biscuits, flavoured    AM
# 63     11-815                        biscuits, cookies, standard    AM
# 64     11-799                         biscuits, digestive, plain    AM
# 82        NaN                     macaroni cheese, canned, large    AD
# 83        NaN                     macaroni cheese, canned, small    AD
# 84        NaN                            macaroni cheese, frozen    AD
# 86        NaN                                        pot-noodles    AD
# 87     11-719                                   noodles, instant    AD
# 90        NaN                                      pizza, frozen     A
# 93     11-718                                   pasta, spaghetti    AD
# 94     11-735          pasta, spaghetti, canned, in tomato sauce    AD
# 97     11-844  pastries, chocolate eclairs, cream filled, retail    AP
# 101       NaN                            milk puddings, ambrosia    AS
# 102   11-1021                            pudding, sponge, canned    AS
# 114    11-919              strudel, fruit filled, retail, frozen    AS
# 116    12-937                          eggs, chicken, whole, raw    CA
# 119    17-031                                        coconut oil    OC
# 120    17-039                                           palm oil    OC
# 121    17-044                                           soya oil    OC
# 122    17-045                                      sunflower oil    OC
# 125       NaN                          anchovies, canned in oil,    JC
# 126    16-385                         bass, sea, flesh only, raw    JA
# 129    16-005                                        bombay duck    JA
# 132    16-372                               cod, flesh only, raw    JA
# 136    16-383                             coley, flesh only, raw    JA
# 137       NaN                              crab, canned in brine    JK
# 144    16-375                           haddock, flesh only, raw    JA
# 145    16-070                              hake, flesh only, raw    JA
# 152    16-260                                            oysters    JM
# 153    16-378                  pollock, alaskan, flesh only, raw    JA
# 154    16-387                                  prawns, king, raw    JK
# 155    14-319                              apple, with core, raw     F
# 157       NaN                                   apricots, canned    FA
# 158    14-040                               avocado pear, fuerte    FA
# 159    14-387                                 avocado pear, hass    FA
# 163    14-388                                  blackberries, raw    FA
# 167    14-326                                       citrus fruit    FA
# 175    14-384                  grapefruit, with skin, raw, small    FA
# 176       NaN                 grapefruit, with skin, raw, medium    FA
# 177       NaN                  grapefruit, with skin, raw, large    FA
# 181    14-373                                         kiwi fruit    FA
# 193    14-168                            mulberries, whole fruit    FA
# 198    14-369                     orange juice, freshly squeezed    FC
# 199    14-361                                      pears, canned     F
# 201    14-376                         pineapple, flesh only, raw    FA
# 207    14-285                                passion fruit juice    FC
# 208    14-179                                      passion fruit    FA
# 209    14-341                            pomegranate juice drink    FC
# 211    14-289                                        prune juice    FC
# 219    14-059                                         star fruit    FA
# 238    13-876                                       curry powder     H
# 241    13-830                                      garlic powder     H
# 247    13-884                                        mixed herbs     H
# 258    18-006                    beef, braising steak, raw, lean   MAC
# 260    18-016                      beef, fillet steak, raw, lean   MAC
# 265    18-064                     beef, sirloin steak, raw, lean   MAC
# 269    18-293           chicken, leg quarter, raw, meat and skin   MCA
# 271    18-297                 chicken, whole, raw, meat and skin   MCA
# 272    18-295          chicken, wing quarter, raw, meat and skin   MCA
# 273    18-503               chicken/turkey pieces, coated, baked   MCA
# 274    19-538                                     chicken slices    MI
# 276    19-128                                corned beef, canned    MI
# 278       NaN                                 casserole, sausage    MR
# 279       NaN                         chow mein, chicken, retail    MR
# 281       NaN                                 coronation chicken    MR
# 282    18-489                               duck, meat only, raw   MCC
# 286    19-496                                                ham   MAA
# 288       NaN          hot pot, lamb/beef with potatoes, retail,    MR
# 291    18-111                            lamb, breast, raw, lean   MAE
# 297       NaN                                    meatballs, beef    MR
# 298       NaN                        meatballs, in tomatoe sauce    MR
# 301    18-387                             rabbit, raw, meat only   MEC
# 302    18-390                            venison, meat only, raw   MEE
# 304    12-333                             cream, fresh, whipping   BJC
# 316    12-398                         desserts, dairy, chocolate    BR
# 317       NaN                                          ice cream    BP
# 318    12-509          ice cream, non dairy, vanilla, soft scoop    BP
# 322    12-389                     lollies, with real fruit juice    BP
# 324    12-322               milk, channel islands, whole, summer   BAB
# 325    12-307                milk, skimmed, pasteurised, average   BAE
# 326    12-313           milk, semi-skimmed, pasteurised, average   BAH
# 327    12-596                  milk, whole, pasteurised, average   BAK
# 328    12-520                  milk, condensed, whole, sweetened   BAR
# 329    12-522                            milk, evaporated, whole   BAR
# 330    12-524  milk, soya, non-dairy alternative to milk, uns...    BC
# 331    12-401                         mousse, chocolate, low fat    BR
# 334    12-375                       yoghurts, pasteurised, fruit    BN
# 341    14-889                                       coconut milk    GA
# 345    14-880                                        nuts, mixed    GA
# 346    14-892                              peanut butter, smooth    GA
# 347    14-882                         peanuts and raisins, mixed    GA
# 353    17-705                                     barbecue sauce    WC
# 354    17-678                    brown sauce, reduced salt/sugar   WCN
# 361    17-701                                   dressing, french   WCG
# 365    17-724                             gravy instant granules    WY
# 366       NaN                                  hollandaise sauce    WC
# 367       NaN                           hollandaise sauce, vegan    WC
# 369    17-364                                            mustard    WY
# 371    17-718                                      pickle, sweet   WCG
# 374    17-711                           soup, minestrone, canned    WA
# 377    17-698                               soup, lentil, canned   WAC
# 378    17-700                               soup, oxtail, canned   WAC
# 379    17-712                            soup, vegetable, canned   WAC
# 380    17-653                 soup, instant, dried, as purchased   WAE
# 381    17-628               sauce, chinese cook in, sweet & sour    WC
# 383    17-703                                        salad cream   WCG
# 391       NaN                                        white sauce   WCD
# 392       NaN                                 white sauce, vegan   WCD
# 393    17-723                               worcestershire sauce   WCN
# 394    17-377                            water, distilled, small    WY
# 396       NaN                                       water, large    WY
# 398    17-659                                   chocolate spread    SC
# 400    17-763                                          creme egg   SEA
# 405    17-689  ice cream sauce, topping, strawberry and choco...    SC
# 406    17-075          jam, reduced sugar, marmalade, lemon curd    SC
# 407    17-777                                 liquorice allsorts   SEC
# 413       NaN                                             nougat   SEC
# 416    17-132                                   pork scratchings    SN
# 417    17-693                             potato crisps, low fat    SN
# 418    17-060                                       sugar, brown    SC
# 420    17-063                                       sugar, white    SC
# 421    17-065                                      syrup, golden    SC
# 433    13-532                baked beans, canned in tomato sauce    DB
# 441       NaN                                 chick peas, canned    DB
# 442    13-080                                      cluster beans    DB
# 443       NaN                              edamame beans, frozen    DB
# 444       NaN                              edamame beans, canned    DB
# 445    13-514                                        green beans    DB
# 446    13-086                                     haricot beans     DB
# 447       NaN                              haricot beans, canned    DB
# 448    13-098                                  mung, dahl, beans    DB
# 450    13-106                                       pinto beans     DB
# 451       NaN                              pinto beans, canned,     DB
# 454    13-112                                       runner beans    DB
# 455    13-115                                         soya beans    DB
# 456    13-117                                        sword beans    DB
# 466    13-067                                        broad beans    DB
# 467       NaN                                broad beans, canned    DB
# 468    13-064                    broad beans, whole, without pod    DB
# 469       NaN                           cannellini beans, canned    DB
# 483       NaN                               vegetable casserole     DR
# 484    15-637                         cauliflower cheese, retail    DR
# 486       NaN                                              curry    DR
# 487    13-244                                             garlic    DG
# 490    13-258                                        horseradish    DG
# 493    13-089                           lentils, green and brown    DB
# 498    15-651                                            lasagne    DR
# 500    13-298                                     mustard leaves    DG
# 504       NaN                                           potatoes    DA
# 507       NaN                              peas, canned in water    DF
# 509       NaN                                      pak choi, raw    DG
# 522       NaN                                  sweetcorn, canned    DG
# 526    15-883                                     shepherd's pie    DR
#
#                                Super Group  \
# 0                      Alcoholic beverages
# 1                      Alcoholic beverages
# 2                      Alcoholic beverages
# 3                      Alcoholic beverages
# 6                      Alcoholic beverages
# 7                      Alcoholic beverages
# 9                      Alcoholic beverages
# 10                     Alcoholic beverages
# 12                               Beverages
# 14                               Beverages
# 15                               Beverages
# 16                               Beverages
# 17                               Beverages
# 18                               Beverages
# 19                               Beverages
# 21                               Beverages
# 25                               Beverages
# 26                               Beverages
# 27                               Beverages
# 28                               Beverages
# 36             Cereals and cereal products
# 39             Cereals and cereal products
# 40             Cereals and cereal products
# 41             Cereals and cereal products
# 42             Cereals and cereal products
# 43             Cereals and cereal products
# 44             Cereals and cereal products
# 47             Cereals and cereal products
# 48             Cereals and cereal products
# 50             Cereals and cereal products
# 51             Cereals and cereal products
# 52             Cereals and cereal products
# 53             Cereals and cereal products
# 62             Cereals and cereal products
# 63             Cereals and cereal products
# 64             Cereals and cereal products
# 82             Cereals and cereal products
# 83             Cereals and cereal products
# 84             Cereals and cereal products
# 86             Cereals and cereal products
# 87             Cereals and cereal products
# 90             Cereals and cereal products
# 93             Cereals and cereal products
# 94             Cereals and cereal products
# 97             Cereals and cereal products
# 101            Cereals and cereal products
# 102            Cereals and cereal products
# 114            Cereals and cereal products
# 116                                   Eggs
# 119                          Fats and oils
# 120                          Fats and oils
# 121                          Fats and oils
# 122                          Fats and oils
# 125                 Fish and fish products
# 126                 Fish and fish products
# 129                 Fish and fish products
# 132                 Fish and fish products
# 136                 Fish and fish products
# 137                 Fish and fish products
# 144                 Fish and fish products
# 145                 Fish and fish products
# 152                 Fish and fish products
# 153                 Fish and fish products
# 154                 Fish and fish products
# 155                                  Fruit
# 157                                  Fruit
# 158                                  Fruit
# 159                                  Fruit
# 163                                  Fruit
# 167                                  Fruit
# 175                                  Fruit
# 176                                  Fruit
# 177                                  Fruit
# 181                                  Fruit
# 193                                  Fruit
# 198                                  Fruit
# 199                                  Fruit
# 201                                  Fruit
# 207                                  Fruit
# 208                                  Fruit
# 209                                  Fruit
# 211                                  Fruit
# 219                                  Fruit
# 238                       Herbs and spices
# 241                       Herbs and spices
# 247                       Herbs and spices
# 258                 Meat and meat products
# 260                 Meat and meat products
# 265                 Meat and meat products
# 269                 Meat and meat products
# 271                 Meat and meat products
# 272                 Meat and meat products
# 273                 Meat and meat products
# 274                 Meat and meat products
# 276                 Meat and meat products
# 278                 Meat and meat products
# 279                 Meat and meat products
# 281                 Meat and meat products
# 282                 Meat and meat products
# 286                 Meat and meat products
# 288                 Meat and meat products
# 291                 Meat and meat products
# 297                 Meat and meat products
# 298                 Meat and meat products
# 301                 Meat and meat products
# 302                 Meat and meat products
# 304                 Milk and milk products
# 316                 Milk and milk products
# 317                 Milk and milk products
# 318                 Milk and milk products
# 322                 Milk and milk products
# 324                 Milk and milk products
# 325                 Milk and milk products
# 326                 Milk and milk products
# 327                 Milk and milk products
# 328                 Milk and milk products
# 329                 Milk and milk products
# 330                 Milk and milk products
# 331                 Milk and milk products
# 334                 Milk and milk products
# 341                         Nuts and seeds
# 345                         Nuts and seeds
# 346                         Nuts and seeds
# 347                         Nuts and seeds
# 353  Soups, sauces and miscellaneous foods
# 354  Soups, sauces and miscellaneous foods
# 361  Soups, sauces and miscellaneous foods
# 365  Soups, sauces and miscellaneous foods
# 366  Soups, sauces and miscellaneous foods
# 367  Soups, sauces and miscellaneous foods
# 369  Soups, sauces and miscellaneous foods
# 371  Soups, sauces and miscellaneous foods
# 374  Soups, sauces and miscellaneous foods
# 377  Soups, sauces and miscellaneous foods
# 378  Soups, sauces and miscellaneous foods
# 379  Soups, sauces and miscellaneous foods
# 380  Soups, sauces and miscellaneous foods
# 381  Soups, sauces and miscellaneous foods
# 383  Soups, sauces and miscellaneous foods
# 391  Soups, sauces and miscellaneous foods
# 392  Soups, sauces and miscellaneous foods
# 393  Soups, sauces and miscellaneous foods
# 394  Soups, sauces and miscellaneous foods
# 396  Soups, sauces and miscellaneous foods
# 398           Sugars, preserves and snacks
# 400           Sugars, preserves and snacks
# 405           Sugars, preserves and snacks
# 406           Sugars, preserves and snacks
# 407           Sugars, preserves and snacks
# 413           Sugars, preserves and snacks
# 416           Sugars, preserves and snacks
# 417           Sugars, preserves and snacks
# 418           Sugars, preserves and snacks
# 420           Sugars, preserves and snacks
# 421           Sugars, preserves and snacks
# 433                             Vegetables
# 441                             Vegetables
# 442                             Vegetables
# 443                             Vegetables
# 444                             Vegetables
# 445                             Vegetables
# 446                             Vegetables
# 447                             Vegetables
# 448                             Vegetables
# 450                             Vegetables
# 451                             Vegetables
# 454                             Vegetables
# 455                             Vegetables
# 456                             Vegetables
# 466                             Vegetables
# 467                             Vegetables
# 468                             Vegetables
# 469                             Vegetables
# 483                             Vegetables
# 484                             Vegetables
# 486                             Vegetables
# 487                             Vegetables
# 490                             Vegetables
# 493                             Vegetables
# 498                             Vegetables
# 500                             Vegetables
# 504                             Vegetables
# 507                             Vegetables
# 509                             Vegetables
# 522                             Vegetables
# 526                             Vegetables
#
#                                         Sale format(s)         Source  \
# 0                                                 pint            NaN
# 1                                          beer bottle
# 2                                            small can
# 3                                            large can            NaN
# 6                                               bottle
# 7                                    bottle, miniature
# 9                                         small bottle            NaN
# 10                                      average bottle
# 12                                                 NaN
# 14                            carton, tetrapak, bottle
# 15                                                 NaN
# 16                                            slim can
# 17                                           large can
# 18                                      average bottle            NaN
# 19                                       large bottle
# 21                                              sachet            NaN
# 25                                                Pint            NaN
# 26                                            1/2 Pint            NaN
# 27                                           small can
# 28                                           large can            NaN
# 36                    loose, individual\nmultiple pack
# 39                    loose, individual\nmultiple pack            NaN
# 40                    loose, individual\nmultiple pack            NaN
# 41                    loose, individual\nmultiple pack
# 42                    loose, individual\nmultiple pack
# 43                    loose, individual\nmultiple pack            NaN
# 44                                                loaf            NaN
# 47                                            baguette
# 48                                                loaf            NaN
# 50                    loose, individual\nmultiple pack
# 51                    loose, individual\nmultiple pack            NaN
# 52                    loose, individual\nmultiple pack            NaN
# 53                    loose, individual\nmultiple pack            NaN
# 62                                      wrapper or box
# 63                                      wrapper or box
# 64                                      wrapper or box
# 82                                              retail
# 83                                              retail
# 84                                              retail
# 86                                                 pot
# 87                                    retail, I packet
# 90                                               large
# 93                                                 raw
# 94                                                 tin
# 97                                              retail            NaN
# 101                                    retail, per pot
# 102                                             canned
# 114                                             frozen
# 116                             egg box, 6, 10, 12, 30
# 119                                                jar
# 120                                             bottle
# 121                                             bottle
# 122                                             bottle
# 125                                                tin
# 126                                             fillet
# 129                                        bombay duck
# 132                                             fillet
# 136                                             fillet
# 137                                                tin
# 144                                                raw
# 145                                                raw
# 152                                                raw
# 153                                                raw
# 154                                                raw            NaN
# 155                                     flesh and skin  Tesco Website
# 157                                             punnet
# 158                                  loose, individual
# 159                                  loose, individual
# 163                                             punnet
# 167                                                net
# 175                                  loose, individual
# 176                                  loose, individual
# 177                                  loose, individual
# 181                                  weighed with skin
# 193                                             punnet
# 198                           carton, tetrapak, bottle
# 199                             loose, individual, bag
# 201                                  loose, individual
# 207                           carton, tetrapak, bottle
# 208                                  weighed with skin
# 209                           carton, tetrapak, bottle
# 211                           carton, tetrapak, bottle
# 219                                  loose, individual
# 238                                          spice jar
# 241                                          spice jar            NaN
# 247                                          spice jar
# 258                                               lean
# 260                                               lean
# 265                                               lean
# 269                                      meat and skin
# 271                                      meat and skin
# 272                                      meat and skin
# 273                                              baked
# 274                                     chicken slices
# 276                                                tin
# 278                                     sausage,retail
# 279                                             retail
# 281                                             retail
# 282                                                raw
# 286                                                NaN
# 288                                            retail,
# 291                                               lean
# 297                                             retail
# 298                                             retail
# 301                                          meat only
# 302                                                raw
# 304                                                tub
# 316                                          chocolate
# 317                                         soft scoop
# 318                                         soft scoop
# 322                              with real fruit juice
# 324  bottle 1 pint, 2 pint, 4 pint, 6 pint, carton ...
# 325  bottle 1 pint, 2 pint, 4 pint, 6 pint, carton ...
# 326  bottle 1 pint, 2 pint, 4 pint, 6 pint, carton ...
# 327  bottle 1 pint, 2 pint, 4 pint, 6 pint, carton ...
# 328                                                tin
# 329                                                tin
# 330                                         carton, 1L
# 331                                            low fat            NaN
# 334                                              fruit
# 341                                    carton/tetrapak
# 345                                             packet
# 346                                                jar
# 347                                             packet
# 353                                     barbecue sauce
# 354                                 reduced salt/sugar
# 361                                             french
# 365                                   instant granules
# 366                                                jar
# 367                                                jar
# 369                                                jar
# 371                                                jar
# 374                                                can
# 377                                                can
# 378                                                can
# 379                                                can
# 380                                                can
# 381                                       sweet & sour
# 383                                        salad cream
# 391                                                jar
# 392                                                jar
# 393                               worcestershire sauce
# 394                                       small bottle
# 396                                       large bottle
# 398                                                jar            NaN
# 400                                         individual
# 405                  strawberry and chocolate flavours            NaN
# 406                                                jar
# 407                                                bag
# 413                                                NaN
# 416                                                bag
# 417                                                bag            NaN
# 418                                                bag
# 420                                                bag
# 421                                                tin            NaN
# 433                                                tin
# 441                                                tin
# 442                                             packet
# 443                                             packet
# 444                                                tin
# 445                                             packet
# 446                                                jar
# 447                                                tin
# 448                                             packet
# 450                                             packet
# 451                                                tin
# 454                                             packet
# 455                                             packet
# 456                                             packet
# 466                                  loose, individual
# 467                                                tin
# 468                                             packet            NaN
# 469                                                can
# 483                                             packet
# 484                                             packet
# 486                                                tin
# 487                                   individual, pack            NaN
# 490                                                raw
# 493                                             packet
# 498                                             packet
# 500                                                raw
# 504                                          potatoes,
# 507                                                tin
# 509                                                raw
# 522                                                tin
# 526                                          vegetable
#
#      Similarity Score     Weight PurEqualCon               Portion Consumed
# 0            0.828152       574g           Y                         1 pint
# 1            0.792934   250/300g           Y                        bottle
# 2            0.782098       333g           Y                      small can
# 3            0.785473       444g           Y                      large can
# 6            0.530675        53g           Y                   1 medium jar
# 7            0.707107        29g           Y                    1 miniature
# 9            1.000000       200g           Y                 I small bottle
# 10           1.000000      750ml           Y               1 average bottle
# 12           0.515378       170g           Y  1 average vending machine cup
# 14           0.511539       110g           Y                     pub bottle
# 15           0.667855        11g           Y              1 sachet, average
# 16           0.678605      330ml           Y                   standard can
# 17           0.730155      500ml           Y               sports/large can
# 18           0.816672      250ml           Y       plastic bottle, standard
# 19           0.781204      500ml           Y          plastic bottle, large
# 21           0.640842        32g           Y                       1 sachet
# 25           0.828152       574g           Y                         1 pint
# 26           0.828152       574g           Y                         1 pint
# 27           0.782098       333g           Y                      small can
# 28           0.785473       444g           Y                      large can
# 36           0.614698        20g           Y                 1 portion pack
# 39           0.548917        20g           Y                        1 slice
# 40           0.661677        20g           Y                        1 slice
# 41           0.561572       260g        Y, P                    2 in a pack
# 42           0.858399       260g        Y, P                    2 in a pack
# 43           0.548917        20g           Y                        1 slice
# 44           0.548917        20g           Y                        1 slice
# 47           0.572960       165g           Y                          large
# 48           0.548917        20g           Y                        1 slice
# 50           0.470702        20g           Y                 1 portion pack
# 51           0.548917        20g           Y                        1 slice
# 52           0.548917        20g           Y                        1 slice
# 53           0.548917        20g           Y                        1 slice
# 62           0.496111       544g           Y               bottle (500 mIs)
# 63           0.608141      330ml           Y               standard, bottle
# 64           0.515999        50g           Y                          small
# 82           0.944269       430g           Y                      large can
# 83           0.943541       210g           Y                      small can
# 84           0.682013       210g           Y                      small can
# 86           0.495482       280g           Y              1 packet, made up
# 87           0.659649       280g           Y              1 packet, made up
# 90           0.608044   350-500g           Y                          large
# 93           0.543350       215g           Y                      small can
# 94           0.516593       215g           Y                      small can
# 97           0.591324        50g           Y                            bar
# 101          0.868712       213g           Y                          small
# 102          0.531543       210g           Y                      small can
# 114          0.488024       600g           Y                     6 servings
# 116          0.541196       480g           Y                          large
# 119          0.599360       200g           Y                    1 small can
# 120          0.599360       200g           Y                    1 small can
# 121          0.599360       200g           Y                    1 small can
# 122          0.599360       200g           Y                    1 small can
# 125          0.648347       200g           Y                    1 small can
# 126          0.702184       250g           Y                    1 raw small
# 129          0.541354       100g           Y                        per bag
# 132          0.493377       170g           Y    in sauce, purchased, frozen
# 136          0.702184       250g           Y                    1 raw small
# 137          0.621057        85g           Y                    1 small can
# 144          0.702184       250g           Y                    1 raw small
# 145          0.702184       250g           Y                    1 raw small
# 152          0.876971       105g           Y           1 can smoked oysters
# 153          0.702184       250g           Y                    1 raw small
# 154          0.745248       100g           Y             1 small jar prawns
# 155          0.762815        75g           Y  1 raw small eating (6 to lb)
# 157          0.488128       210g           Y                          1 can
# 158          0.924432        75g           Y               average 1/2 pear
# 159          0.924432        75g           Y               average 1/2 pear
# 163          0.702184       250g           Y                    1 raw small
# 167          0.540797       110g           Y                     pub bottle
# 175          0.949128       250g           Y                    1 raw small
# 176          0.953106       340g           Y                   1 raw medium
# 177          0.949306       425g           Y                    1 raw large
# 181          0.540797       110g           Y                     pub bottle
# 193          0.540797       110g           Y                     pub bottle
# 198          0.511539       110g           Y                     pub bottle
# 199          0.488128       210g           Y                          1 can
# 201          0.702184       250g           Y                    1 raw small
# 207          0.744402       110g           Y                     pub bottle
# 208          0.540797       110g           Y                     pub bottle
# 209          0.516904       150g           Y                   Stage 1 jars
# 211          0.511539       110g           Y                     pub bottle
# 219          0.540797       110g           Y                     pub bottle
# 238          0.479771       125g           Y                         1 can
# 241          0.574400        20g           Y                        1 slice
# 247          0.502211       210g           Y                      small can
# 258          0.613475       213g           Y                          small
# 260          0.613475       213g           Y                          small
# 265          0.613475       213g           Y                          small
# 269          0.483738       250g           Y                    1 raw small
# 271          0.483738       250g           Y                    1 raw small
# 272          0.483738       250g           Y                    1 raw small
# 273          0.555108       480g           Y                          large
# 274          0.699137       480g           Y                          large
# 276          0.833893       198g           Y                    1 small can
# 278          0.791137        55g           Y                      small can
# 279          0.689754       190g           Y                            NaN
# 281          0.699137       480g           Y                          large
# 282          0.475477       250g           Y                    1 raw small
# 286          0.536964       180g           Y                            NaN
# 288          0.489557        75g           Y                          small
# 291          0.702184       250g           Y                    1 raw small
# 297          0.582226       198g           Y                    1 small can
# 298          0.657832       170g           Y              frozen, purchased
# 301          0.475477       250g           Y                    1 raw small
# 302          0.475477       250g           Y                    1 raw small
# 304          0.616008        12g           Y                       1 sachet
# 316          0.727264       128g           Y                            Can
# 317          0.616008        12g           Y                       1 sachet
# 318          0.616008        12g           Y                       1 sachet
# 322          0.666403       110g           Y                     pub bottle
# 324          0.664302       585g           Y                         1 pint
# 325          0.554430       585g           Y                         1 pint
# 326          0.554430       585g           Y                         1 pint
# 327          0.554430       585g           Y                         1 pint
# 328          0.664302       585g           Y                         1 pint
# 329          0.900485       170g           Y                    1 small can
# 330          0.519932       585g           Y                         1 pint
# 331          0.600031        32g           Y                       1 sachet
# 334          0.540797       110g           Y                     pub bottle
# 341          0.664302       585g           Y                         1 pint
# 345          0.517577        40g           Y                        per bag
# 346          0.792553        25g           Y                 1 portion pack
# 347          0.521683        40g           Y                        per bag
# 353          0.510302        12g           Y                       1 sachet
# 354          0.594896        20g           Y                 1 portion pack
# 361          0.572960       165g           Y                          large
# 365          0.505809        11g           Y              1 sachet, average
# 366          0.510302        12g           Y                       1 sachet
# 367          0.510302        12g           Y                       1 sachet
# 369          0.479771       125g           Y                         1 can
# 371          0.624544        20g           Y                 1 portion pack
# 374          0.717750       300g           Y                      small can
# 377          0.717750       300g           Y                      small can
# 378          0.717750       300g           Y                      small can
# 379          0.582488  210g/440g           Y                            can
# 380          0.547949       300g           Y                      small can
# 381          0.486843       170g           Y              frozen, purchased
# 383          0.841229        12g           Y                       1 sachet
# 391          0.510302        12g           Y                       1 sachet
# 392          0.510302        12g           Y                       1 sachet
# 393          0.510302        12g           Y                       1 sachet
# 394          0.745010       250g           Y                          small
# 396          0.749310       500g           Y                          large
# 398          0.472801        50g           Y                            bar
# 400          0.485265       145g           Y                            NaN
# 405          0.507402        50g           Y                            bar
# 406          0.731960        20g           Y            1 individual carton
# 407          0.725422        56g           Y                      small bag
# 413          0.745238        70g           Y                      small bar
# 416          0.528495       450g           Y               large/family pie
# 417          0.489796        32g           Y                       1 sachet
# 418          0.661237         6g           Y               1 'packet' sugar
# 420          0.935130         6g           Y               1 'packet' sugar
# 421          0.606094        60g           Y                          large
# 433          0.554373        55g           Y              1 canned pilchard
# 441          0.488128       210g           Y                          1 can
# 442          0.694957       170g           Y                      small can
# 443          0.504830       170g           Y                      small can
# 444          0.537384       170g           Y                      small can
# 445          0.694957       170g           Y                      small can
# 446          0.694957       170g           Y                      small can
# 447          0.537384       170g           Y                      small can
# 448          0.694957       170g           Y                      small can
# 450          0.694957       170g           Y                      small can
# 451          0.537384       170g           Y                      small can
# 454          0.694957       170g           Y                      small can
# 455          0.694957       170g           Y                      small can
# 456          0.694957       170g           Y                      small can
# 466          0.694957       170g           Y                      small can
# 467          0.537384       170g           Y                      small can
# 468          0.503528        20g        Y, P                          1 pod
# 469          0.537384       170g           Y                      small can
# 483          0.660492  210g/440g           Y                            can
# 484          0.611509       185g           Y                            NaN
# 486          0.479771       125g           Y                         1 can
# 487          0.574400        20g           Y                        1 slice
# 490          0.692231        12g           Y                       1 sachet
# 493          0.478119        20g           Y                 1 portion pack
# 498          0.500372       290g           Y             ready meal for one
# 500          0.479771       125g           Y                         1 can
# 504          0.895363        75g           Y                          small
# 507          0.620468       250g           Y                  canned, small
# 509          0.702184       250g           Y                    1 raw small
# 522          0.488128       210g           Y                          1 can
# 526          0.621351       480g           Y                          large

# %% [markdown]
# #### Export Matched DataSet

# %%
#redFood_matched.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\ReducedwithWeights\dataproduct.csv')

# %% [markdown]
# ### 320 / 535 items Matched Using Algo 4 which is a combination of Algo 2 & It uses the fuzz.partial_token_set_ratio & Term Frequency-Inverse Document Frequency

# %%
f'Fourth Algorithm Matched {round((320/535) * 100, 2)}% of products between McCane and Widdowson df and Food Portion Sizes df at a threshold of 90 and a Cosine threshold of 70. Contains some errors'
# Out:
# 'Fourth Algorithm Matched 59.81% of products between McCane and Widdowson df and Food Portion Sizes df at a threshold of 90 and a Cosine threshold of 70. Contains some errors'

# %% [markdown]
# ## Plotting Matching Efficiency of Algo 4

# %% [markdown]
# Find total counts of food by Super Group

# %%
d = redFood_matched[redFood_matched['Weight'] != '']
ax4_s = d.groupby('Super Group')['Food Name'].count().rename('Matched Prod Count', inplace=True).copy().sort_values(ascending=True)
ax4 = pd.DataFrame(ax4_s).reset_index()
ax4
# Out:
#                               Super Group  Matched Prod Count
# 0                                    Eggs                   1
# 1                        Herbs and spices                   3
# 2                           Fats and oils                   4
# 3                          Nuts and seeds                   4
# 4                     Alcoholic beverages                   8
# 5                  Fish and fish products                  11
# 6            Sugars, preserves and snacks                  11
# 7                               Beverages                  12
# 8                  Milk and milk products                  14
# 9                                   Fruit                  19
# 10                 Meat and meat products                  20
# 11  Soups, sauces and miscellaneous foods                  20
# 12            Cereals and cereal products                  28
# 13                             Vegetables                  31

# %%
ax4_count = redFood_matched.groupby('Super Group')['Food Name'].count().rename('Total Prod Count', inplace=True).copy().sort_values(ascending=True)
ax4_nt = pd.DataFrame(ax4_count).reset_index()
ax4_nt
# Out:
#                               Super Group  Total Prod Count
# 0                                    Eggs                 2
# 1                           Fats and oils                 6
# 2                     Alcoholic beverages                11
# 3                          Nuts and seeds                17
# 4                               Beverages                21
# 5            Sugars, preserves and snacks                25
# 6                  Fish and fish products                31
# 7                  Milk and milk products                32
# 8                        Herbs and spices                35
# 9                  Meat and meat products                46
# 10  Soups, sauces and miscellaneous foods                46
# 11                                  Fruit                67
# 12            Cereals and cereal products                84
# 13                             Vegetables               110

# %%
# Evaluating Percentaged Mapped
ax4_counts = ax4_nt.merge(ax4, on='Super Group', how='left')
ax4_counts['%Matched'] = ax4_counts['Matched Prod Count'] / ax4_counts['Total Prod Count'] * 100

# %%
import matplotlib.font_manager as fm

# Find the minimum count in the ax4_counts DataFrame.
min_count4 = ax4_counts['%Matched'].min()

# Create a custom color palette.
bar_colors4 = ['lightpink' if count != min_count4 else '#f95d6a' for count in ax4_counts['%Matched']]

# Set the font family and size for the title.
title_font = fm.FontProperties(family='Times New Roman', size=24)

# Set the font family and size for the axes labels.
axis_font = fm.FontProperties(family='Times New Roman', size=18)

# Create the figure and axes objects.
fig, ax = plt.subplots(figsize=(10, 8))

# Plot the horizontal bar chart.
bars = ax.barh(ax4_counts['Super Group'], ax4_counts['%Matched'], color=bar_colors4)

# Add gridlines to the plot.
ax.grid(axis='x', linestyle='--', alpha=0.2)

# Customize the title, x-axis, and y-axis labels.
ax.set_title('Evaluation of Hybrid Matching (Algorithm 4)', fontproperties=title_font)
ax.set_xlabel('Percentage Matched', fontproperties=axis_font)
ax.set_ylabel('Super Group', fontproperties=axis_font)

# Set the maximum value of the x-axis to 100.
ax.set_xlim(0, 100)

# Adjust the spacing around the plot.
plt.tight_layout(pad=1.0)

# Remove the top and right spines from the plot.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Increase the tick label font size.
ax.tick_params(axis='both', which='major', labelsize=13)

# Invert the y-axis to display the highest match on top.
ax.invert_yaxis()

    # Show the plot.
plt.show()

# %% [markdown]
#                                                   NEXT NOTEBOOK
