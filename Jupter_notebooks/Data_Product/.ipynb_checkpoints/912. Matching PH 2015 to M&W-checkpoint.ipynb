# %% [markdown]
# # Matching Public Health data (2015) to M&W

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re #regular expressions 
from fuzzywuzzy import process, fuzz
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os 
import glob

# %%
# %watermark --iversion
# Out:
# matplotlib: 3.7.1
# re        : 2.2.1
# numpy     : 1.23.5
# pandas    : 1.5.3
# seaborn   : 0.12.2
# fuzzywuzzy: 0.18.0

# %% [markdown]
# ###### Read in Data

# %% [markdown]
#                                                       M&W Data

# %% [markdown]
#                                                  Fruit and Vegetables

# %%
pd.set_option('display.max_rows', None)
fv = pd.read_csv(r"C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\ReducedwithWeights\FV_MatchedFPSnDoh11.csv", index_col=0)
#redFood.rename(columns={'Similarity Score':'Similarity Score_FPS','Weight':'Weight_FPS','Portion Consumed':'Portion Consumed_FPS'}, inplace=True)
#redFood.drop(['Source','PurEqualCon'], axis=1, inplace=True)
fv['Food Name'] = fv['Food Name'].str.lower()
fv.fillna('').head(2)
# Out:
#   Food Code Food Name Food sub-group codes  Food Group Sales Format  \
# 0    13-145     ackee                   DG  Vegetables          Can
# 1    13-146      agar                   DG  Vegetables          Bag
#
#    Similarity Score_FPS Weight_FPS Portion Consumed_FPS  Similarity Score DoH  \
# 0              0.000000                                                   0.0
# 1              0.276369                                                   0.0
#
#   Pack Size11 Packaging DoH11 Purchase Date DoH11
# 0
# 1

# %% [markdown]
#                                                 Department of Health Data

# %% [markdown]
# Text tables

# %%
# %%time
filtered_products = pd.read_csv(r"C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\FV_WeightData\text\PHealth_text_FV2015.csv", index_col=0)
filtered_products['Sub-sample Number'] = filtered_products['Sub-sample Number'].astype(str)#.head()
# Out:
# CPU times: total: 0 ns
# Wall time: 13 ms

# %%
filtered_products.head(2)
# Out:
#    Composite Sample Number          Composite Sample Name Sub-sample Number  \
# 1                      1.0  Kiwi fruit, raw, flesh only                 1.2
# 3                      1.0  Kiwi fruit, raw, flesh only                 1.3
#
#                                      Sub-sample Name  \
# 1                                       Tesco kiwi
# 3  Asda Grower’s Selection ripen at home kiwi fru...
#
#                        Brand         Pack size Purchase Date  \
# 1                    Tesco    Purchase Date:      19.10.15
# 3  Asda Grower’s Selection          6 fruits      28.09.15
#
#                         Place of Purchase   Display Until Date  \
# 1  Tesco Extra, Blue Boar Road, Norwich         Use by Date:
# 3          Asda, Boundary Road, Norwich    Best before Date:
#
#    Best Before Date                        Batch Number  Packaging  \
# 1               NaN                        Packaging:      Loose
# 3               NaN  Site: 903126 776590 NM 113 07:14    Plastic
#
#   Sample Condition As Purchased               Post Purchase Storage
# 1                     Ambient    21°C controlled temperature room
# 3                     Ambient    21°C controlled temperature room

# %% [markdown]
# Concatinating All excel files into one file

# %%
# %%time
# Set the directory path where CSV files are located
directory_path = r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\FV_WeightData\tables\2015'

# Use glob to get a list of all CSV files in the directory
csv_files = glob.glob(os.path.join(directory_path, '*.csv'))

# Initialize an empty list to store DataFrames
dataframes = []

# Loop through each CSV file, read it using pandas, and append to the list
for csv_file in csv_files:
    # Read CSV file into a DataFrame
    dataframe = pd.read_csv(csv_file)
    
    # Append DataFrame to the list
    dataframes.append(dataframe)

# Concatenate all DataFrames into a single DataFrame
dataframefull = pd.concat(dataframes, ignore_index=True)
# Out:
# CPU times: total: 46.9 ms
# Wall time: 313 ms

# %% [markdown]
# Minor Cleaning

# %%
dataframefull.drop(['Unnamed: 0','Brand','Display Until Date',
       'Best Before Date', 'Batch Number', 'Sample Condition As Purchased', 'Post Purchase Storage', 'Pack size',
       'Sub-sample\rnumber', 'Average\rweight of\rstone (g)',
       'Edible\rportion'], axis=1, inplace=True)

# %%
dataframefull['Composite Sample Name'] = dataframefull['Composite Sample Name'].str.lower()

# %%
dataframefull.rename(columns={'Sub-sample Number':'Sub_sampleNumber'}, inplace = True)
dataframefull['Sub_sampleNumber'] = dataframefull['Sub_sampleNumber'].astype(str)

# %%
dataframefull.tail(3)
# Out:
#      Composite Sample Number Composite Sample Name Sub_sampleNumber  \
# 434                     41.0  yam, fresh, boiled               41.6
# 435                     41.0  yam, fresh, boiled               41.7
# 436                     41.0  yam, fresh, boiled               41.8
#
#              Sub-sample Name Sample Weight Purchase Date  \
# 434  Aziz Cash & Carry yam          1679.0    30.10.15
# 435       Asian Bazaar yam          1938.3    26.01.16
# 436         Spice Land yam          2284.0    26.01.16
#
#                                   Place of Purchase Packaging
# 434  Aziz Cash &  Carry, Electric Avenue, Brixton     Loose
# 435        Asian Bazaar, Magdalen Street, Norwich     Loose
# 436             Spice Land, Dereham Road, Norwich     Loose

# %% [markdown]
# Matched DoH data doesn't have good weight data. I am going to go back and look at the PdF to try find better information.
#
#
# Tables at the end of pdf have weight info for all samples used. Get this into text table and try matching again

# %% [markdown]
#                                Add Package Size to DoH text table with Sample weights tables

# %%
# %%time
# Define your regular expression matching function
def regex_matching(source, target):
    pattern = re.compile(f'.*{source}.*', re.IGNORECASE)
    return target if re.match(pattern, target) else ''

# Create a function to update 'Pack Size' and 'Match' column based on the regex match
def pack_size(row):
    sub_sample_number = row['Sub_sampleNumber']  # Correct column name
    
    # Find the best match in 'filtered_products' using regular expression
    best_match = filtered_products[filtered_products['Sub-sample Number'].apply(lambda x: regex_matching(sub_sample_number, x)) != '']
    
    if not best_match.empty:
        # Get the first match and retrieve 'Pack Size'
        matched_weight = best_match.iloc[0]['Pack size']  # Correct column name
        return matched_weight
    
    return row['Pack size']  # Return original 'Pack Size' if no match

# Load or define your 'filtered_products' DataFrame
# filtered_products = ...

# Apply the pack_size function to update 'Pack Size' column in 'dataframefull'
dataframefull['Pack size'] = dataframefull.apply(pack_size, axis=1)
# Out:
# CPU times: total: 484 ms
# Wall time: 491 ms

# %%
dataframefull['Composite Sample Name'] = dataframefull['Composite Sample Name'].astype(str)

# %%
dataframefull
# Out:
#      Composite Sample Number  \
# 0                       47.0
# 1                       47.0
# 2                       47.0
# 3                       47.0
# 4                       47.0
# 5                       47.0
# 6                       47.0
# 7                       47.0
# 8                       47.0
# 9                       47.0
# 10                      23.0
# 11                      23.0
# 12                      23.0
# 13                      23.0
# 14                      23.0
# 15                      23.0
# 16                      23.0
# 17                      23.0
# 18                      23.0
# 19                      23.0
# 20                      36.0
# 21                      36.0
# 22                      36.0
# 23                      36.0
# 24                      36.0
# 25                      36.0
# 26                      36.0
# 27                      36.0
# 28                      36.0
# 29                      36.0
# 30                      36.0
# 31                      30.0
# 32                      30.0
# 33                      30.0
# 34                      30.0
# 35                      30.0
# 36                      30.0
# 37                      30.0
# 38                      30.0
# 39                      18.0
# 40                      18.0
# 41                      18.0
# 42                      18.0
# 43                      42.0
# 44                      42.0
# 45                      42.0
# 46                      42.0
# 47                      42.0
# 48                      42.0
# 49                      42.0
# 50                      42.0
# 51                      42.0
# 52                      42.0
# 53                      42.0
# 54                      33.0
# 55                      33.0
# 56                      33.0
# 57                      33.0
# 58                      33.0
# 59                      33.0
# 60                      33.0
# 61                      33.0
# 62                      33.0
# 63                      33.0
# 64                      33.0
# 65                      15.0
# 66                      15.0
# 67                      15.0
# 68                      15.0
# 69                      15.0
# 70                      15.0
# 71                      15.0
# 72                      15.0
# 73                      15.0
# 74                       NaN
# 75                      15.0
# 76                      28.0
# 77                      28.0
# 78                      28.0
# 79                      28.0
# 80                      28.0
# 81                      28.0
# 82                      28.0
# 83                      28.0
# 84                      28.0
# 85                      28.0
# 86                      28.0
# 87                      60.0
# 88                      60.0
# 89                      60.0
# 90                      60.0
# 91                      60.0
# 92                      60.0
# 93                      60.0
# 94                      60.0
# 95                      60.0
# 96                      60.0
# 97                      21.0
# 98                      21.0
# 99                      21.0
# 100                     21.0
# 101                     21.0
# 102                     21.0
# 103                     21.0
# 104                     21.0
# 105                     21.0
# 106                     21.0
# 107                     21.0
# 108                      7.0
# 109                      7.0
# 110                      7.0
# 111                      7.0
# 112                      7.0
# 113                      7.0
# 114                      7.0
# 115                      7.0
# 116                      7.0
# 117                      7.0
# 118                      7.0
# 119                     55.0
# 120                     55.0
# 121                     55.0
# 122                     55.0
# 123                     55.0
# 124                     55.0
# 125                     55.0
# 126                     55.0
# 127                     55.0
# 128                     55.0
# 129                     12.0
# 130                     12.0
# 131                     12.0
# 132                     12.0
# 133                     12.0
# 134                     12.0
# 135                     12.0
# 136                     12.0
# 137                     12.0
# 138                     12.0
# 139                     12.0
# 140                     34.0
# 141                     61.0
# 142                     61.0
# 143                     61.0
# 144                     61.0
# 145                     61.0
# 146                     61.0
# 147                     61.0
# 148                     62.0
# 149                     62.0
# 150                     62.0
# 151                     62.0
# 152                     62.0
# 153                     62.0
# 154                     62.0
# 155                     62.0
# 156                     62.0
# 157                     62.0
# 158                      8.0
# 159                      8.0
# 160                      8.0
# 161                      8.0
# 162                      8.0
# 163                      8.0
# 164                      8.0
# 165                      8.0
# 166                      8.0
# 167                      8.0
# 168                      8.0
# 169                     59.0
# 170                     59.0
# 171                     59.0
# 172                     59.0
# 173                      NaN
# 174                     59.0
# 175                      1.0
# 176                      1.0
# 177                      1.0
# 178                      1.0
# 179                      1.0
# 180                      1.0
# 181                      1.0
# 182                      1.0
# 183                      1.0
# 184                      1.0
# 185                      9.0
# 186                      9.0
# 187                      NaN
# 188                      9.0
# 189                      9.0
# 190                      9.0
# 191                      9.0
# 192                      9.0
# 193                      9.0
# 194                      9.0
# 195                      9.0
# 196                     49.0
# 197                     49.0
# 198                     49.0
# 199                     49.0
# 200                     49.0
# 201                     49.0
# 202                     49.0
# 203                     49.0
# 204                     49.0
# 205                     49.0
# 206                      NaN
# 207                     50.0
# 208                     50.0
# 209                     50.0
# 210                     50.0
# 211                     50.0
# 212                     50.0
# 213                     50.0
# 214                     50.0
# 215                     26.0
# 216                     26.0
# 217                     26.0
# 218                     26.0
# 219                     26.0
# 220                     26.0
# 221                     26.0
# 222                     26.0
# 223                     26.0
# 224                     26.0
# 225                     26.0
# 226                      5.0
# 227                      5.0
# 228                      5.0
# 229                      5.0
# 230                      5.0
# 231                      5.0
# 232                      5.0
# 233                      5.0
# 234                      5.0
# 235                      5.0
# 236                      6.0
# 237                      6.0
# 238                      6.0
# 239                      6.0
# 240                      6.0
# 241                      6.0
# 242                      6.0
# 243                      6.0
# 244                      6.0
# 245                      6.0
# 246                      6.0
# 247                     38.0
# 248                     38.0
# 249                     38.0
# 250                     38.0
# 251                     38.0
# 252                     38.0
# 253                     38.0
# 254                     38.0
# 255                     38.0
# 256                     38.0
# 257                     38.0
# 258                     44.0
# 259                     44.0
# 260                     44.0
# 261                     44.0
# 262                     44.0
# 263                     44.0
# 264                     44.0
# 265                     44.0
# 266                     44.0
# 267                     44.0
# 268                     44.0
# 269                     16.0
# 270                     16.0
# 271                     16.0
# 272                     16.0
# 273                     16.0
# 274                     16.0
# 275                     16.0
# 276                     16.0
# 277                     16.0
# 278                     16.0
# 279                     16.0
# 280                      4.0
# 281                      4.0
# 282                      4.0
# 283                      4.0
# 284                      4.0
# 285                      4.0
# 286                      4.0
# 287                      4.0
# 288                      4.0
# 289                      4.0
# 290                      4.0
# 291                      NaN
# 292                      NaN
# 293                      NaN
# 294                      NaN
# 295                      NaN
# 296                      NaN
# 297                      NaN
# 298                      NaN
# 299                      NaN
# 300                      NaN
# 301                      NaN
# 302                     46.0
# 303                     46.0
# 304                     46.0
# 305                     46.0
# 306                     46.0
# 307                     46.0
# 308                     46.0
# 309                     46.0
# 310                     46.0
# 311                     46.0
# 312                     45.0
# 313                     45.0
# 314                     45.0
# 315                     45.0
# 316                     45.0
# 317                     45.0
# 318                     45.0
# 319                     45.0
# 320                     45.0
# 321                     45.0
# 322                     48.0
# 323                     48.0
# 324                     48.0
# 325                     48.0
# 326                     48.0
# 327                     48.0
# 328                     48.0
# 329                     48.0
# 330                     48.0
# 331                     48.0
# 332                      3.0
# 333                      3.0
# 334                      3.0
# 335                      3.0
# 336                      3.0
# 337                      3.0
# 338                      3.0
# 339                      3.0
# 340                      3.0
# 341                      3.0
# 342                      3.0
# 343                     51.0
# 344                     51.0
# 345                     51.0
# 346                     51.0
# 347                     51.0
# 348                     51.0
# 349                      NaN
# 350                     51.0
# 351                     51.0
# 352                     51.0
# 353                     52.0
# 354                     52.0
# 355                     52.0
# 356                     52.0
# 357                     52.0
# 358                     52.0
# 359                     52.0
# 360                     52.0
# 361                     52.0
# 362                     52.0
# 363                     43.0
# 364                     43.0
# 365                     43.0
# 366                     43.0
# 367                     43.0
# 368                     43.0
# 369                     43.0
# 370                     43.0
# 371                     43.0
# 372                     43.0
# 373                     43.0
# 374                     40.0
# 375                     40.0
# 376                     40.0
# 377                     40.0
# 378                     40.0
# 379                     40.0
# 380                     40.0
# 381                     40.0
# 382                     40.0
# 383                     40.0
# 384                     40.0
# 385                      NaN
# 386                     35.0
# 387                     35.0
# 388                     35.0
# 389                     35.0
# 390                     35.0
# 391                     35.0
# 392                     35.0
# 393                     35.0
# 394                     35.0
# 395                     35.0
# 396                     19.0
# 397                     19.0
# 398                     19.0
# 399                     19.0
# 400                     19.0
# 401                     19.0
# 402                     19.0
# 403                     19.0
# 404                     19.0
# 405                     19.0
# 406                     19.0
# 407                     31.0
# 408                     31.0
# 409                     31.0
# 410                     31.0
# 411                     31.0
# 412                     31.0
# 413                     31.0
# 414                     31.0
# 415                     31.0
# 416                     31.0
# 417                     31.0
# 418                     39.0
# 419                     39.0
# 420                     39.0
# 421                     39.0
# 422                     39.0
# 423                     39.0
# 424                     39.0
# 425                     39.0
# 426                     39.0
# 427                     39.0
# 428                     39.0
# 429                     41.0
# 430                     41.0
# 431                     41.0
# 432                     41.0
# 433                     41.0
# 434                     41.0
# 435                     41.0
# 436                     41.0
#
#                                 Composite Sample Name Sub_sampleNumber  \
# 0               apricots, ready to eat, semi -dried               47.1
# 1               apricots, ready to eat, semi -dried               47.2
# 2               apricots, ready to eat, semi -dried               47.3
# 3               apricots, ready to eat, semi -dried               47.4
# 4               apricots, ready to eat, semi -dried               47.5
# 5               apricots, ready to eat, semi -dried               47.6
# 6               apricots, ready to eat, semi -dried               47.7
# 7               apricots, ready to eat, semi -dried               47.8
# 8               apricots, ready to eat, semi -dried               47.9
# 9               apricots, ready to eat, semi -dried               47.1
# 10                        asparagus, fresh, steamed               23.1
# 11                        asparagus, fresh, steamed               23.2
# 12                        asparagus, fresh, steamed               23.3
# 13                        asparagus, fresh, steamed               23.4
# 14                        asparagus, fresh, steamed               23.5
# 15                        asparagus, fresh, steamed               23.7
# 16                        asparagus, fresh, steamed               23.8
# 17                        asparagus, fresh, steamed               23.9
# 18                        asparagus, fresh, steamed               23.1
# 19                        asparagus, fresh, steamed              23.11
# 20               aubergine, boiled, flesh an d skin               36.1
# 21                aubergine, boiled, flesh and skin               36.2
# 22                aubergine, boiled, flesh and skin               36.3
# 23                aubergine, boiled, flesh and skin               36.4
# 24                aubergine, boiled, flesh and skin               36.5
# 25                 aubergine, boiled, flesh and skin              36.6
# 26                aubergine, boiled, flesh and skin               36.7
# 27                aubergine, boiled, flesh and skin               36.8
# 28                aubergine, boiled, flesh and skin               36.9
# 29                aubergine, flesh and skin, boiled               36.1
# 30                aubergine, boiled, flesh and skin              36.11
# 31                    avocado pear, raw, flesh only               30.2
# 32                    avocado pear, raw, flesh only               30.3
# 33                    avocado pear, raw, flesh only               30.4
# 34                    avocado pear, raw, flesh only               30.5
# 35                    avocado pear, raw, flesh only               30.6
# 36                    avocado pear, raw, flesh only               30.7
# 37                    avocado pear, raw, flesh only               30.8
# 38                    avocado pear, raw, flesh only               30.9
# 39                                 beetroot, cooked               18.1
# 40                                 beetroot, cooked               18.2
# 41                                 beetroot, cooked               18.3
# 42                                 beetroot, cooked               18.4
# 43                                blackberries, raw               42.1
# 44                                blackberries, raw               42.2
# 45                                blackberries, raw               42.3
# 46                                blackberries, raw               42.4
# 47                                blackberries, raw               42.5
# 48                                blackberries, raw               42.6
# 49                                blackberries, raw               42.7
# 50                                blackberries, raw               42.8
# 51                                blackberries, raw               42.9
# 52                                blackberries, raw               42.1
# 53                                blackberries, raw              42.11
# 54                       broad beans, fresh, boiled               33.1
# 55                       broad beans, fresh, boiled               33.2
# 56                       broad beans, fresh, boiled               33.3
# 57                       broad beans, fresh, boiled               33.4
# 58                       broad beans, fresh, boiled               33.5
# 59                       broad beans, fresh, boiled               33.6
# 60                       broad beans, fresh, boiled               33.7
# 61                       broad beans, fresh, boiled               33.8
# 62                       broad beans, fresh, boiled               33.9
# 63                       broad beans, fresh, boiled               33.1
# 64                       broad beans, fresh, boiled              33.11
# 65                         brussels sprouts, boiled               15.1
# 66                         brussels sprouts, boiled               15.2
# 67                         brussels sprouts, boiled               15.3
# 68                         brussels sprouts, boiled               15.4
# 69                         brussels sprouts, boiled               15.5
# 70                         brussels sprouts, boiled               15.6
# 71                         brussels sprouts, boiled               15.7
# 72                         brussels sprouts, boiled               15.8
# 73                         brussels sprouts, boiled               15.9
# 74                         brussels sprouts, boiled               15.1
# 75                         brussels sprouts, boiled              15.11
# 76              butternut squash, boiled flesh only               28.1
# 77              butternut squash, boiled flesh only               28.2
# 78              butternut squash, boiled flesh only               28.3
# 79              butternut squash, boiled flesh only               28.4
# 80              butternut squash, boiled flesh only               28.5
# 81              butternut squash, boiled flesh only               28.6
# 82              butternut squash, boiled flesh only               28.7
# 83              butternut squash, boiled flesh only               28.8
# 84              butternut squash, boiled flesh only               28.9
# 85              butternut squash, boiled flesh only               28.1
# 86              butternut squash, boiled flesh only              28.11
# 87               cannellini beans, canned, reheated               60.1
# 88               cannellini beans, canned, reheated               60.2
# 89               cannellini beans, canned, reheated               60.3
# 90               cannellini beans, canned, reheated               60.4
# 91               cannellini beans, canned, reheated               60.5
# 92               cannellini beans, canned, reheated               60.6
# 93               cannellini beans, canned, reheated               60.7
# 94               cannellini beans, canned, reheated               60.8
# 95               cannellini beans, canned, reheated               60.9
# 96               cannellini beans, canned, reheated               60.1
# 97                                      celery, raw               21.1
# 98                                      celery, raw               21.2
# 99                                      celery, raw               21.3
# 100                                     celery, raw               21.4
# 101                                     celery, raw               21.5
# 102                                     celery, raw               21.6
# 103                                     celery, raw               21.7
# 104                                     celery, raw               21.8
# 105                                     celery, raw               21.9
# 106                                     celery, raw               21.1
# 107                                     celery, raw              21.11
# 108                                   cherries, raw                7.1
# 109                                   cherries, raw                7.2
# 110                                   cherries, raw                7.3
# 111                                   cherries, raw                7.4
# 112                                   cherries, raw                7.5
# 113                                   cherries, raw                7.6
# 114                                   cherries, raw                7.7
# 115                                   cherries, raw                7.8
# 116                                   cherries, raw                7.9
# 117                                    cherries, raw               7.1
# 118                                   cherries, raw               7.11
# 119                     chickpeas, canned, reheated               55.1
# 120                     chickpeas, canned, reheated               55.2
# 121                     chickpeas, canned, reheated               55.3
# 122                     chickpeas, canned, reheated               55.4
# 123                     chickpeas, canned, reheated               55.5
# 124                     chickpeas, canned, reheated               55.6
# 125                     chickpeas, canned, reheated               55.7
# 126                     chickpeas, canned, reheated               55.8
# 127                     chickpeas, canned, reheated               55.9
# 128                     chickpeas, canned, reheated               55.1
# 129                          courgettes, fresh, raw               12.1
# 130                          courgettes, fresh, raw               12.2
# 131                          courgettes, fresh, raw               12.3
# 132                          courgettes, fresh, raw               12.4
# 133                          courgettes, fresh, raw               12.5
# 134                          courgettes, fresh, raw               12.6
# 135                          courgettes, fresh, raw               12.7
# 136                          courgettes, fresh, raw                nan
# 137                          courgettes, fresh, raw               12.9
# 138                          courgettes, fresh, raw               12.1
# 139                          courgettes, fresh, raw              12.11
# 140                       curly kale, fresh, boiled               34.1
# 141                         edamame, frozen, boiled               61.1
# 142                         edamame, frozen, boiled               61.2
# 143                         edamame, frozen, boiled               61.3
# 144                         edamame, frozen, boiled               61.4
# 145                         edamame, frozen, boiled               61.5
# 146                         edamame, frozen, boiled               61.6
# 147                         edamame, frozen, boiled               61.7
# 148                 figs, ready to eat, semi -dried               62.1
# 149                 figs, ready to eat, semi -dried               62.2
# 150                 figs, ready to eat, semi -dried               62.3
# 151                 figs, ready to eat, semi -dried               62.4
# 152                 figs, ready to eat, semi -dried               62.5
# 153                 figs, ready to eat, semi -dried               62.6
# 154                 figs, ready to eat, semi -dried               62.7
# 155                 figs, ready to eat, semi -dried               62.8
# 156                 figs, ready to eat, semi -dried               62.9
# 157                 figs, ready to eat, semi -dried               62.1
# 158                     grapefruit, raw, flesh only                8.1
# 159                     grapefruit, raw, flesh only                8.2
# 160                     grapefruit, raw, flesh only                8.3
# 161                     grapefruit, raw, flesh only                8.4
# 162                     grapefruit, raw, flesh only                8.5
# 163                      grapefruit, raw, flesh only               8.6
# 164                     grapefruit, raw, flesh only                8.7
# 165                     grapefruit, raw, flesh only                8.8
# 166                     grapefruit, raw, flesh only                8.9
# 167                     grapefruit, raw, flesh only                8.1
# 168                     grapefruit, raw, flesh only               8.11
# 169                 haricot beans, canned, reheated               59.1
# 170                 haricot beans, canned, reheated               59.2
# 171                 haricot beans, canned, reheated               59.3
# 172                 haricot beans, canned, reheated               59.4
# 173                 haricot beans, canned, reheated               59.5
# 174                 haricot beans, canned, reheated               59.6
# 175                     kiwi fruit, raw, flesh only                1.2
# 176                     kiwi fruit, raw, flesh only                1.3
# 177                     kiwi fruit, raw, flesh only                1.4
# 178                     kiwi fruit, raw, flesh only                1.5
# 179                     kiwi fruit, raw, flesh only                1.6
# 180                     kiwi fruit, raw, flesh only                1.7
# 181                     kiwi fruit, raw, flesh only                1.8
# 182                     kiwi fruit, raw, flesh only                1.9
# 183                     kiwi fruit, raw, flesh only                1.1
# 184                     kiwi fruit, raw, flesh only               1.11
# 185                               leeks, fresh, raw                9.1
# 186                               leeks, fresh, raw                9.2
# 187                               leeks, fresh, raw                9.3
# 188                               leeks, fresh, raw                9.4
# 189                               leeks, fresh, raw                9.5
# 190                               leeks, fresh, raw                9.6
# 191                               leeks, fresh, raw                9.7
# 192                               leeks, fresh, raw                9.8
# 193                               leeks, fresh, raw                9.9
# 194                               leeks, fresh, raw                9.1
# 195                               leeks, fresh, raw               9.11
# 196                      lentils, split, dried, raw               49.1
# 197                      lentils, split, dried, raw               49.2
# 198                      lentils, split, dried, raw               49.3
# 199                       lentils, split, dried, raw              49.4
# 200                      lentils, split, dried, raw               49.5
# 201                      lentils, split, dried, raw               49.6
# 202                      lentils, split, dried, raw               49.7
# 203                      lentils, split, dried, raw               49.8
# 204                       lentils, split, dried, raw              49.9
# 205                      lentils, split, dried, raw               49.1
# 206                   lentils, split, dried, boiled               50.1
# 207                   lentils, split, dried, boiled               50.2
# 208                   lentils, split, dried, boiled               50.3
# 209                   lentils, split, dried, boiled               50.4
# 210                   lentils, split, dried, boiled               50.5
# 211                   lentils, split, dried, boiled               50.6
# 212                   lentils, split, dried, boiled               50.7
# 213                   lentils, split, dried, boiled               50.8
# 214                   lentils, split, dried, boiled               50.9
# 215                       mange tout, fresh, boiled               26.1
# 216                       mange tout, fresh, boiled               26.2
# 217                       mange tout, fresh, boiled               26.3
# 218                       mange tout, fresh, boiled               26.4
# 219                       mange tout, fresh, boiled               26.5
# 220                       mange tout, fresh, boiled               26.6
# 221                       mange tout, fresh, boiled               26.7
# 222                       mange tout, fresh, boiled               26.8
# 223                       mange tout, fresh, boiled               26.9
# 224                       mange tout, fresh, boiled               26.1
# 225                       mange tout, fresh, boiled              26.11
# 226                 mangoes , ripe, raw, flesh only                5.1
# 227                  mangoes, ripe, raw, flesh only                5.2
# 228                  mangoes, ripe, raw, flesh only                5.3
# 229                  mangoes, ripe, raw, flesh only                5.4
# 230                  mangoes, ripe, raw, flesh only                5.5
# 231                  mangoes, ripe, raw, flesh only                5.6
# 232                  mangoes, ripe, raw, flesh only                5.8
# 233                  mangoes, ripe, raw, flesh only                5.9
# 234                  mangoes, ripe, raw, flesh only                5.1
# 235                  mangoes, ripe, raw, flesh only               5.11
# 236   nectarines, yellow flesh, raw, flesh and skin                6.1
# 237   nectarines, yellow flesh, raw, flesh and skin                6.2
# 238   nectarines, yellow flesh, raw, flesh and skin                6.3
# 239  nectarines, yellow flesh,  raw, flesh and skin                6.4
# 240    nectarines, yellow flesh, raw, flesh and skin               6.5
# 241   nectarines, yellow flesh, raw, flesh and skin                6.6
# 242   nectarines, yellow flesh, raw, flesh and skin                6.7
# 243   nectarines, yellow flesh, raw, flesh and  skin               6.8
# 244   nectarines, yellow flesh, raw, flesh and skin                6.9
# 245   nectarines, yellow flesh, raw, flesh and skin                6.1
# 246   nectarines, yellow flesh, raw, flesh and skin               6.11
# 247                                    okra, boiled               38.1
# 248                                    okra, boiled               38.2
# 249                                    okra, boiled               38.3
# 250                                    okra, boiled               38.4
# 251                                    okra, boiled               38.5
# 252                                    okra, boiled               38.6
# 253                                    okra, boiled               38.7
# 254                                    okra, boiled               38.8
# 255                                    okra, boiled               38.9
# 256                                    okra, boiled               38.1
# 257                                    okra, boiled              38.11
# 258                  papaya, ripe, raw , flesh only               44.1
# 259                   papaya, ripe, raw, flesh only               44.2
# 260                   papaya, ripe, raw, flesh only               44.3
# 261                   papaya, ripe, raw, flesh only               44.4
# 262                   papaya, ripe, raw, flesh only               44.5
# 263                   papaya, ripe, raw, flesh only               44.6
# 264                   papaya, ripe, raw, flesh only               44.7
# 265                   papaya, ripe, raw, flesh only               44.8
# 266                   papaya, ripe, raw, flesh only               44.9
# 267                   papaya, ripe, raw, flesh only               44.1
# 268                   papaya, ripe, raw, flesh only              44.11
# 269                                parsnips, boiled               16.1
# 270                                parsnips, boiled               16.2
# 271                                parsnips, boiled               16.3
# 272                                parsnips, boiled               16.4
# 273                                parsnips, boiled               16.5
# 274                                parsnips, boiled               16.6
# 275                                parsnips, boiled               16.7
# 276                                parsnips, boiled               16.8
# 277                                parsnips, boiled               16.9
# 278                                parsnips, boiled               16.1
# 279                                parsnips, boiled              16.11
# 280               pineapple, fresh, raw, flesh only                4.1
# 281               pineapple, fresh, raw, flesh only                4.2
# 282               pineapple, fresh, raw, flesh only                4.3
# 283               pineapple, fresh, raw, flesh only                4.4
# 284               pineapple, fresh, raw, flesh only                4.5
# 285               pineapple, fresh, raw, flesh only                4.6
# 286               pineapple, fresh, raw, flesh only                4.7
# 287               pineapple, fresh, raw, flesh  only               4.8
# 288               pineapple, fresh, raw, flesh only                4.9
# 289               pineapple, fresh, raw, flesh only                4.1
# 290               pineapple, fresh, raw, flesh only               4.11
# 291                                               nan              nan
# 292                                               nan              nan
# 293                                               nan              nan
# 294                                               nan              nan
# 295                                               nan              nan
# 296                                               nan              nan
# 297                                               nan              nan
# 298                                               nan              nan
# 299                                               nan              nan
# 300                                               nan              nan
# 301                                               nan              nan
# 302               prunes, ready to eat, semi -dried               46.1
# 303               prunes, ready to eat, semi -dried               46.2
# 304               prunes, ready to eat, semi -dried               46.3
# 305               prunes, ready to eat, semi -dried               46.4
# 306               prunes, ready to eat, semi -dried               46.5
# 307               prunes, ready to eat, semi -dried               46.6
# 308               prunes, ready to eat, semi -dried               46.7
# 309               prunes, ready to eat, semi -dried               46.8
# 310               prunes, ready to eat, semi -dried               46.9
# 311               prunes, ready to eat, semi -dried               46.1
# 312                                     radish, raw               45.1
# 313                                     radish, raw               45.2
# 314                                     radish, raw               45.3
# 315                                     radish, raw               45.4
# 316                                     radish, raw               45.5
# 317                                     radish, raw               45.6
# 318                                     radish, raw               45.7
# 319                                     radish, raw               45.8
# 320                                     radish, raw               45.9
# 321                                     radish, raw               45.1
# 322                                  raisins, dried               48.1
# 323                                  raisins, dried               48.2
# 324                                  raisins, dried               48.3
# 325                                  raisins, dried               48.4
# 326                                  raisins, dried               48.5
# 327                                  raisins, dried               48.6
# 328                                  raisins, dried               48.7
# 329                                  raisins, dried               48.8
# 330                                  raisins, dried               48.9
# 331                                  raisins, dried               48.1
# 332                                raspberries, raw                3.1
# 333                                raspberries, raw                3.2
# 334                                raspberries, raw                3.3
# 335                                raspberries, raw                3.4
# 336                                raspberries, raw                3.5
# 337                                raspberries, raw                3.6
# 338                                raspberries, raw                3.7
# 339                                raspberries, raw                3.8
# 340                                raspberries, raw                3.9
# 341                                raspberries, raw                nan
# 342                                raspberries, raw               3.11
# 343                 red kidney beans, dried, boiled               51.1
# 344                 red kidney beans, dried, boiled               51.2
# 345                 red kidney beans, dried, boiled               51.3
# 346                 red kidney beans, dried, boiled               51.4
# 347                 red kidney beans, dried, boiled               51.5
# 348                 red kidney beans, dried, boiled               51.6
# 349                 red kidney beans, dried, boiled               51.7
# 350                 red kidney beans, dried, boiled               51.8
# 351                 red kidney beans, dried, boiled               51.9
# 352                 red kidney beans, dried, boiled               51.1
# 353              red kidney beans, canned, reheated               52.1
# 354              red kidney beans, canned, reheated               52.2
# 355              red kidney beans, canned, reheated               52.3
# 356              red kidney beans, canned, reheated               52.4
# 357              red kidney beans, canned, reheated               52.5
# 358              red kidney beans, canned, reheated               52.6
# 359              red kidney beans, canned, reheated               52.7
# 360              red kidney beans, canned, reheated               52.8
# 361              red kidney beans, canned, reheated               52.9
# 362              red kidney beans, canned, reheated               52.1
# 363                   rhubarb, stewed without sugar               43.1
# 364                   rhubarb, stewed without sugar               43.2
# 365                   rhubarb, stewed without sugar               43.3
# 366                   rhubarb, stewed without sugar               43.4
# 367                   rhubarb, stewed without sugar               43.5
# 368                   rhubarb, stewed without sugar               43.6
# 369                   rhubarb, stewed without sugar               43.7
# 370                   rhubarb, stewed without sugar               43.8
# 371                   rhubarb, stewed without sugar               43.9
# 372                   rhubarb, stewed without sugar               43.1
# 373                   rhubarb, stewed without sugar              43.11
# 374                     runner beans, fresh, boiled               40.1
# 375                     runner beans, fresh, boiled               40.2
# 376                     runner beans, fresh, boiled               40.3
# 377                     runner beans, fresh, boiled               40.4
# 378                     runner beans, fresh, boiled               40.5
# 379                     runner beans, fresh, boiled               40.6
# 380                     runner beans, fresh, boiled               40.7
# 381                     runner beans, fresh, boiled               40.8
# 382                     runner beans, fresh, boiled               40.9
# 383                     runner beans, fresh, boiled               40.1
# 384                     runner beans, fresh, boiled              40.11
# 385                            swede, fresh, boiled               35.1
# 386                            swede, fresh, boiled               35.2
# 387                            swede, fresh, boiled               35.3
# 388                            swede, fresh, boiled               35.4
# 389                            swede, fresh, boiled               35.5
# 390                            swede, fresh, boiled               35.6
# 391                            swede, fresh, boiled               35.7
# 392                            swede, fresh, boiled               35.8
# 393                            swede, fresh, boiled               35.9
# 394                            swede, fresh, boiled               35.1
# 395                            swede, fresh, boiled              35.11
# 396                  sweetcorn, baby, fresh, boiled               19.1
# 397                  sweetcorn, baby, fresh, boiled               19.2
# 398                  sweetcorn, baby, fresh, boiled               19.3
# 399                  sweetcorn, baby, fresh, boiled               19.4
# 400                  sweetcorn, baby, fresh, boiled               19.5
# 401                  sweetcorn, baby, fresh, boiled               19.6
# 402                  sweetcorn, baby, fresh, boiled               19.7
# 403                  sweetcorn, baby, fresh, boiled               19.8
# 404                  sweetcorn, baby, fresh, boiled               19.9
# 405                  sweetcorn, baby, fresh, boiled               19.1
# 406                  sweetcorn, baby, fresh, boiled              19.11
# 407                sweet potato, boiled, flesh only               31.1
# 408                sweet potato, boiled, flesh only               31.2
# 409                sweet potato, boiled, flesh only               31.3
# 410                sweet potato, boiled, flesh only               31.4
# 411                sweet potato, boiled, flesh only               31.5
# 412                sweet potato, boiled, flesh only               31.6
# 413                sweet potato, boiled, flesh only               31.7
# 414                sweet potato, boiled, flesh only               31.8
# 415                sweet potato, boiled, flesh only               31.9
# 416                sweet potato, boiled, flesh only               31.1
# 417                sweet potato, boiled, flesh  only             31.11
# 418                                 watercress, raw               39.1
# 419                                 watercress, raw               39.2
# 420                                 watercress, raw               39.3
# 421                                 watercress, raw               39.4
# 422                                 watercress, raw               39.5
# 423                                 watercress, raw               39.6
# 424                                 watercress, raw               39.7
# 425                                 watercress, raw               39.8
# 426                                 watercress, raw               39.9
# 427                                 watercress, raw               39.1
# 428                                 watercress, raw              39.11
# 429                              yam, fresh, boiled               41.1
# 430                              yam, fresh, boiled               41.2
# 431                              yam, fresh, boiled               41.3
# 432                              yam, fresh, boiled               41.4
# 433                              yam, fresh, boiled               41.5
# 434                              yam, fresh, boiled               41.6
# 435                              yam, fresh, boiled               41.7
# 436                              yam, fresh, boiled               41.8
#
#                                        Sub-sample Name      Sample Weight  \
# 0            Tesco Whole Foods ready to eat apricots                  8.9
# 1                        Tesco ready to eat apricots                  6.3
# 2                      Asda Good & Balanced apricots                  4.8
# 3                               Sainsbury’s apricots                  9.1
# 4                 Morrisons Wholefoods soft apricots                  5.4
# 5                      Marks & Spencer soft apricots               425g
# 6       Neal’s Yard Wholefoods ready to eat apricots                  9.0
# 7                           Whitworths soft apricots                  7.5
# 8        Whitworths snack on golden Malatya apricots                  8.8
# 9        Whitworths snack on golden Malatya apricots                  8.9
# 10                            Tesco asparagus bundle                254.0
# 11                              Tesco asparagus tips                  NaN
# 12                 Asda Grower’s Selection asparagus                272.0
# 13                        Sainsbury’s fine asparagus                121.5
# 14                               Morrisons asparagus                283.0
# 15                          M&S extra fine asparagus                107.2
# 16            Aldi Specially Selected asparagus tips                  NaN
# 17                              Tesco asparagus tips                  NaN
# 18                               Farm Shop asparagus                254.0
# ...
# 104                                    350g
# 105                          Purchase Date:
# 106                                    350g
# 107                          Purchase Date:
# 108                          Purchase Date:
# 109                                    250g
# 110                                    425g
# 111                                    250g
# 112                                    225g
# 113                                    180g
# 114                          Purchase Date:
# 115                                    200g
# 116                                    200g
# 117                          Purchase Date:
# 118                                    200g
# 119  Net weight: 400g; drained weight: 240g
# 120  Net weight: 210g; drained weight: 130g
# 121          400g; net drained weight: 240g
# 122              400g; drained weight: 240g
# 123              300g; drained weight: 180g
# 124              400g; drained weight: 240g
# 125          400g; net drained weight: 240g
# 126  Net weight: 800g; drained weight: 480g
# 127  Net weight: 400g; drained weight: 240g
# 128  Net weight: 400g; drained weight: 240g
# 129                          Purchase Date:
# 130                                    500g
# 131                                  3 pack
# 132                          Purchase Date:
# 133                          Purchase Date:
# 134                                    325g
# 135                                    500g
# 136                          Purchase Date:
# 137                                    300g
# 138                          Purchase Date:
# 139                                      1kg
# 140                                    206g
# 141                                    500g
# 142                                    500g
# 143                                    600g
# 144                                    500g
# 145                                    500g
# 146                                    480g
# 147                                    480g
# 148                                    250g
# 149                                    440g
# 150                                    500g
# 151                                    500g
# 152                                    250g
# 153                                    500g
# 154                                    250g
# 155                                    250g
# 156                                    175g
# 157                                    250g
# 158                          Purchase Date:
# 159                          Purchase Date:
# 160                                 3 fruit
# 161                                 4 fruit
# 162                                 Count 4
# 163                          Purchase Date:
# 164                          Purchase Date:
# 165                                 3 fruit
# 166                          Purchase Date:
# 167                          Purchase Date:
# 168                                 4 fruit
# 169  Net weight: 400g; drained weight: 235g
# 170  Net weight: 400g; drained weight: 235g
# 171              300g; drained weight: 195g
# 172              300g; drained weight: 195g
# 173              400g; drained weight: 265g
# 174              300g; drained weight: 195g
# 175                          Purchase Date:
# 176                                6 fruits
# 177                                 6 fruit
# 178                          Purchase Date:
# 179                          Purchase Date:
# 180                          Purchase Date:
# 181                                6 fruits
# 182                                 6 fruit
# 183                          Purchase Date:
# 184                                       x6
# 185                          Purchase Date:
# 186                                    500g
# 187                                    500g
# 188                                    500g
# 189                                    500g
# 190                          Purchase Date:
# 191                                    600g
# 192                                    750g
# 193                          Purchase Date:
# 194                          Purchase Date:
# 195                                      5kg
# 196                                    500g
# 197                                      2kg
# 198                                    500g
# 199                                    500g
# 200                                    500g
# 201                                    500g
# 202                                      1kg
# 203                                      2kg
# 204                                    500g
# 205                                    500g
# 206                                    500g
# 207                                      2kg
# 208                                    500g
# 209                                    500g
# 210                                    500g
# 211                                    500g
# 212                                      1kg
# 213                                      2kg
# 214                                    500g
# 215                                    215g
# 216                                    200g
# 217                                    155g
# 218                                    200g
# 219                                    155g
# 220                                    200g
# 221                                    150g
# 222                                    155g
# 223                                    120g
# 224                                    215g
# 225                                    300g
# 226                                3 fruits
# 227                                    275g
# 228                          Purchase Date:
# 229                                 2 fruit
# 230                          Purchase Date:
# 231                          Purchase Date:
# 232                                 4 fruit
# 233                                    250g
# 234                                3 fruits
# 235                                 2 fruit
# 236                          Purchase Date:
# 237                                5 fruit s
# 238                                      1kg
# 239                                 4 fruit
# 240                             Min 4 fruit
# 241                          Purchase Date:
# 242                                 4 fruit
# 243                                4 fruit s
# 244                          Purchase Date:
# 245                          Purchase Date:
# 246                                5 fruits
# 247                                    175g
# 248                                    175g
# 249                          Purchase Date:
# 250                         Purchase  Date:
# 251                                    200g
# 252                                    175g
# 253                                    175g
# 254                                    175g
# 255                                    175g
# 256                                    175g
# 257                                 1-1.8kg
# 258                          Purchase Date:
# 259                          Purchase Date:
# 260                                2 fruits
# 261                          Purchase Date:
# 262                          Purchase Date:
# 263                          Purchase Date:
# 264                          Purchase Date:
# 265                          Purchase Date:
# 266                          Purchase Date:
# 267                          Purchase Date:
# 268                          Purchase Date:
# 269                          Purchase Date:
# 270                                    500g
# 271                                    500g
# 272                          Purchase Date:
# 273                                    500g
# 274                          Purchase Date:
# 275                                    500g
# 276                                    750g
# 277                          Purchase Date:
# 278                          Purchase Date:
# 279                                   1.5kg
# 280                                    400g
# 281                          Purchase Date:
# 282                                    400g
# 283                                    350g
# 284                                    180g
# 285                          Purchase Date:
# 286                          Purchase Date:
# 287                          Purchase Date:
# 288                          Purchase Date:
# 289                                    400g
# 290                          Purchase Date:
# 291                          Purchase Date:
# 292                          Purchase Date:
# 293                          Purchase Date:
# 294                          Purchase Date:
# 295                          Purchase Date:
# 296                          Purchase Date:
# 297                          Purchase Date:
# 298                          Purchase Date:
# 299                          Purchase Date:
# 300                          Purchase Date:
# 301                          Purchase Date:
# 302                                    500g
# 303                                    250g
# 304                                    250g
# 305                                    500g
# 306                                    500g
# 307                                    250g
# 308                                    250g
# 309                                    200g
# 310                                    200g
# 311                                    500g
# 312                                    240g
# 313                                    240g
# 314                                    200g
# 315                                    200g
# 316                                    200g
# 317                                    200g
# 318                                    250g
# 319                                    200g
# 320                                    200g
# 321                                    240g
# 322                                    500g
# 323                                    150g
# 324                           168g (12x14g)
# 325                                    250g
# 326                                    500g
# 327                                    500g
# 328                                    250g
# 329                                      2kg
# 330                            112g (8x14g)
# 331                                    500g
# 332                                    150g
# 333                                    150g
# 334                                    150g
# 335                                    150g
# 336                                    150g
# 337                                    160g
# 338                                    150g
# 339                                    150g
# 340                                    150g
# 341                          Purchase Date:
# 342                                    125g
# 343                                    500g
# 344                                    500g
# 345                                    500g
# 346                                    500g
# 347                                    500g
# 348                                    500g
# 349                                    500g
# 350                                      2kg
# 351                                    500g
# 352                                    500g
# 353  Net weight: 400g; drained weight: 240g
# 354  Net weight: 400g; drained weight: 240g
# 355              400g; drained weight: 240g
# 356              400g; drained weight: 240g
# 357              400g; drained weight: 240g
# 358  Net weight: 420g; drained weight: 240g
# 359          400g; net drained weight: 240g
# 360  Net weight: 800g; drained weight: 480g
# 361  Net weight: 400g; drained weight: 240g
# 362  Net weight: 400g; drained weight: 240g
# 363                                    400g
# 364                                    400g
# 365                                    400g
# 366                                    400g
# 367                                    400g
# 368                                    450g
# 369                                    400g
# 370                                      1kg
# 371                                    400g
# 372                                    400g
# 373                                    400g
# 374                                    255g
# 375                                    255g
# 376                                    190g
# 377                                    225g
# 378                                    180g
# 379                                    300g
# 380                                    250g
# 381                                    190g
# 382                                    180g
# 383                                    255g
# 384                                    180g
# 385                               Min. 400g
# 386                               Min. 700g
# 387                                    500g
# 388                               Min. 525g
# 389                               Min. 500g
# 390                                    500g
# 391                          Purchase Date:
# 392                                    500g
# 393                                    500g
# 394                               Min. 400g
# 395                          Purchase Date:
# 396                                    190g
# 397                                    190g
# 398                                    130g
# 399                                    175g
# 400                                    125g
# 401                                    175g
# 402                                    135g
# 403                                    130g
# 404                                    125g
# 405                                    190g
# 406                                      80g
# 407                                      1kg
# 408                                      1kg
# 409                                      1kg
# 410                                  1.25kg
# 411                          Purchase Date:
# 412                                      1kg
# 413                          Purchase Date:
# 414                                  Min. 5
# 415                          Purchase Date:
# 416                                      1kg
# 417                                 6kg net
# 418                                      85g
# 419                                      85g
# 420                                      85g
# 421                                      80g
# 422                                      85g
# 423                                    100g
# 424                                      85g
# 425                                      85g
# 426                                      85g
# 427                                      85g
# 428                                    100g
# 429                          Purchase Date:
# 430                          Purchase Date:
# 431                          Purchase Date:
# 432                          Purchase Date:
# 433                          Purchase Date:
# 434                          Purchase Date:
# 435                          Purchase Date:
# 436                          Purchase Date:

# %%
dataframefull.to_csv(r'C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\Sample Reports\PH2015.csv')

# %% [markdown]
#                                 Removing samples that didn't have the right weights attached

# %%
# %%time
def clean_composite_name(name):
    replacements = [
        (',', ''),
        (r'\bready to eat\b', ''),
        (r'\bsemi -dried\b', ''),
        (r'\bfresh steamed\b', ''),
        (r'\bboiled flesh and skin\b', ''),
        (r'\bboiled flesh an d skin\b', ''),
        (r'\b flesh and skin boiled\b', ''),
        (r'\braw flesh only\b', ''),
        (r'\bcooked\b', ''),
        (r'\braw\b', ''),
        (r'\bfresh boiled\b', ''),
        (r'\bboiled\b', ''),
        (r'\bflesh only\b', ''),
        (r'\breheated\b', ''),
        (r'\bfresh\b', ''),
        (r'\bstewed without sugar\b', ''),
        (r'\bdried\b', ''),
        (r'\bflesh flesh and skin\b', ''),
    ]
    
    for pattern, replacement in replacements:
        name = re.sub(pattern, replacement, name, flags=re.IGNORECASE)
    
    return name.strip()

# Assuming 'dataframefull' is your DataFrame
dataframefull['Composite Sample Name'] = dataframefull['Composite Sample Name'].apply(clean_composite_name)
# Out:
# CPU times: total: 15.6 ms
# Wall time: 7 ms

# %%
# Remove commas from 'Food Name' column
dataframefull['Composite Sample Name'] = dataframefull['Composite Sample Name'].str.replace(',', '').str.strip()

# %%
dataframefull.head(2)
# Out:
#    Composite Sample Number Composite Sample Name Sub_sampleNumber  \
# 0                     47.0              apricots             47.1
# 1                     47.0              apricots             47.2
#
#                              Sub-sample Name Sample Weight Purchase Date  \
# 0  Tesco Whole Foods ready to eat apricots             8.9    28.01.16
# 1              Tesco ready to eat apricots             6.3    30.11.15
#
#                    Place of Purchase  Packaging Pack size
# 0  Tesco, Harford Bridges, Norwich    Plastic      500g
# 1  Tesco, Harford Bridges, Norwich    Plastic      500g

# %%
dataframefull.drop_duplicates(subset='Composite Sample Name', keep='first').dropna().head()
# Out:
#     Composite Sample Number Composite Sample Name Sub_sampleNumber  \
# 0                      47.0              apricots             47.1
# 10                     23.0             asparagus             23.1
# 20                     36.0             aubergine             36.1
# 31                     30.0          avocado pear             30.2
# 39                     18.0              beetroot             18.1
#
#                               Sub-sample Name Sample Weight Purchase Date  \
# 0   Tesco Whole Foods ready to eat apricots             8.9    28.01.16
# 10                   Tesco asparagus bundle           254.0    26.08.15
# 20                          Tesco aubergine           265.0    28.09.15
# 31                      Tesco large avocado           209.0    07.12.15
# 39            Tesco cooked British beetroot           181.8    28.09.15
#
#                     Place of Purchase                         Packaging  \
# 0   Tesco, Harford Bridges, Norwich                           Plastic
# 10  Tesco, Harford Bridges, Norwich                           Plastic
# 20  Tesco, Harford Bridges, Norwich                             Loose
# 31  Tesco, Harford Bridges, Norwich    Sample Condition As Purchased:
# 39  Tesco, Harford Bridges, Norwich                           Plastic
#
#            Pack size
# 0             500g
# 10            250g
# 20  Purchase Date:
# 31  Purchase Date:
# 39            300g

# %% [markdown]
#                                                     Matching M&W and DoH

# %%
# %%time

def fuzzy_matching_score(source, target):
    return fuzz.partial_token_set_ratio(source, target)

def get_most_similar_indices(tfidf_red_food, tfidf_clean_retail):
    similarities = cosine_similarity(tfidf_red_food, tfidf_clean_retail)
    return similarities.argmax(axis=1)

def hybrid_fuzzy_matching(dataframefull, fv, iterations=2):
    # Set initial and subsequent thresholds for matching
    initial_fuzzy_threshold = 85  # Lower the threshold for initial fuzzy matching
    subsequent_fuzzy_threshold = 99
    cosine_similarity_threshold = 0.90
    min_similarity_threshold = 0.62

    for iteration in range(iterations):
        print(f"Iteration {iteration + 1}/{iterations}")
    
          # Step 1: Fuzzy Matching (Initial: permissive, Subsequent: stricter)
        if iteration == 0:
            partial_token_set_ratio_threshold = initial_fuzzy_threshold
        else:
            partial_token_set_ratio_threshold = subsequent_fuzzy_threshold
            
        dataframefull['Partial Token Set Ratio'] = dataframefull['Composite Sample Name'].apply(lambda x: fuzzy_matching_score(x, fv['Food Name']))
        potential_matches = dataframefull[dataframefull['Partial Token Set Ratio'] >= partial_token_set_ratio_threshold]

        print('Completed 1')

        # Step 2: TF-IDF and Cosine Similarity (Text Matching) - Use combined matches as input
        vectorizer = TfidfVectorizer()
        vectorizer.fit(potential_matches['Composite Sample Name'])
        tfidf_clean_doh = vectorizer.transform(potential_matches['Composite Sample Name'])
        tfidf_red_food = vectorizer.transform(fv['Food Name'])

        # Find the most similar match for each redFood product
        max_sim_indices = get_most_similar_indices(tfidf_red_food, tfidf_clean_doh)
        max_sim_scores = cosine_similarity(tfidf_red_food, tfidf_clean_doh).max(axis=1)

        print('Completed 2')

        # Update redFood DataFrame with matched information and sources
        fv['Similarity Score PH15'] = max_sim_scores
        #fv['Weight DoH'] = potential_matches['Sample Weight'].values[max_sim_indices]
        fv['Sample Weight PH15'] = potential_matches['Sample Weight'].values[max_sim_indices]
        fv['Packaging PH15'] = potential_matches['Packaging'].values[max_sim_indices]
        fv['Purchase Date PH15'] = potential_matches['Purchase Date'].values[max_sim_indices]
        fv['Pack Size PH15'] = potential_matches['Pack size'].values[max_sim_indices]

        print('Completed 3')

        # Set to NaN for rows where similarity score is below the minimum threshold
        fv.loc[fv['Similarity Score PH15'] < min_similarity_threshold, [ 'Packaging PH15', 'Sample Weight PH15', 'Purchase Date PH15', 'Pack Size PH15']] = ''
        
        # Update CleanRetail with new matches from redFood
        dataframefull = dataframefull.append(fv[fv['Similarity Score PH15'] >= min_similarity_threshold])


    return fv

# Call the hybrid_fuzzy_matching function and get the matched DataFrame
fv_matched = hybrid_fuzzy_matching(dataframefull.copy(),fv.copy())
# Out:
# Iteration 1/2
# Completed 1
# Completed 2
# Completed 3
# Iteration 2/2
# <timed exec>:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# Completed 1
# Completed 2
# Completed 3
# CPU times: total: 1.28 s
# Wall time: 1.46 s
# <timed exec>:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
fv_matched.fillna('').head(2)
# Out:
#   Food Code Food Name Food sub-group codes  Food Group Sales Format  \
# 0    13-145     ackee                   DG  Vegetables          Can
# 1    13-146      agar                   DG  Vegetables          Bag
#
#    Similarity Score_FPS Weight_FPS Portion Consumed_FPS  Similarity Score DoH  \
# 0              0.000000                                                   0.0
# 1              0.276369                                                   0.0
#
#   Pack Size11 Packaging DoH11 Purchase Date DoH11  Similarity Score PH15  \
# 0                                                                    0.0
# 1                                                                    0.0
#
#   Sample Weight PH15 Packaging PH15 Purchase Date PH15 Pack Size PH15
# 0
# 1

# %% [markdown]
#                                                         Export Data

# %%
fv_matched.to_csv(r"C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\ReducedwithWeights\FV_MatchedFPSnDoh15.csv")

# %% [markdown]
# ## Plotting Matching Efficiency Using Public Health Data 2015

# %% [markdown]
# Find total counts of food by Super Group

# %%
d = fv_matched[fv_matched['Sample Weight PH15'] != '']
ax4_s = d.groupby('Food Group')['Food Name'].count().rename('Matched Prod Count', inplace=True).copy().sort_values(ascending=True)
ax4 = pd.DataFrame(ax4_s).reset_index()
ax4

# %%
ax4_count = fv_matched.groupby('Food Group')['Food Name'].count().rename('Total Prod Count', inplace=True).copy().sort_values(ascending=True)
ax4_nt = pd.DataFrame(ax4_count).reset_index()
ax4_nt

# %%
# Evaluating Percentaged Mapped
ax4_counts = ax4_nt.merge(ax4, on='Food Group', how='left')
ax4_counts['%Matched'] = ax4_counts['Matched Prod Count'] / ax4_counts['Total Prod Count'] * 100

# %%
import matplotlib.font_manager as fm

# Find the minimum count in the ax4_counts DataFrame.
min_count4 = ax4_counts['%Matched'].min()

# Create a custom color palette.
bar_colors4 = ['lightpink' if count != min_count4 else '#f95d6a' for count in ax4_counts['%Matched']]

# Set the font family and size for the title.
title_font = fm.FontProperties(family='Arial', size=23)
subtitle_font = fm.FontProperties(family='Arial', size=12)

# Set the font family and size for the axes labels.
axis_font = fm.FontProperties(family='Arial', size=18)

# Create the figure and axes objects.
fig, ax = plt.subplots(figsize=(10, 7))

# Plot the horizontal bar chart.
bars = ax.barh(ax4_counts['Food Group'], ax4_counts['%Matched'], color=bar_colors4)

# Add gridlines to the plot.
ax.grid(axis='x', linestyle='--', alpha=0.45)

# Customize the title, x-axis, and y-axis labels.
plt.suptitle('Matching Rate of Hybrid Matching Process, FPS',ha='center', fontproperties=title_font, y=1)  # Add y parameter
ax.set_title('The matching process was used to match weights from the Food Portion Sizes data to our reduced food product dataset', ha='center', fontproperties=subtitle_font, y=1.04, x=0.45)  # Add y parameter for subtitle
ax.set_xlabel('Percentage Matched', fontproperties=axis_font)
ax.set_ylabel('Food Group', fontproperties=axis_font)

# Set the maximum value of the x-axis to 100.
ax.set_xlim(0, 100)

# Adjust the spacing around the plot.
plt.tight_layout(pad=1.07)

# Remove the top and right spines from the plot.
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Increase the tick label font size.
ax.tick_params(axis='x', which='major', labelsize=13)

# Adjust y-axis tick label alignment and font size.
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, ha="right", fontsize=12)

# Invert the y-axis to display the lowest match on top.
ax.invert_yaxis()

    # Show the plot.
plt.show()

# %% [markdown]
#                                                        Next Notebook
