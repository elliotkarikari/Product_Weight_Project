# %% [markdown]
# # Fruit and Vegetables Data Product

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re #regular expressions 
from fuzzywuzzy import fuzz
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# Read In Matched Data

# %%
pd.set_option('display.max_rows', None)
Matched = pd.read_csv(r"C:\Users\medekar\Desktop\Product_Weight_Project\Data\Processed\ReducedwithWeights\dataproduct.csv", index_col=0)
Matched.head()
# Out:
#   Food Code                    Food Name Group          Super Group  \
# 0    17-208  beer, bitter, best, premium    QA  Alcoholic beverages
# 1    17-224                 cider, sweet    QC  Alcoholic beverages
# 2    17-234                         port    QF  Alcoholic beverages
# 3    17-236               sherry, medium    QF  Alcoholic beverages
# 4    17-247          spirits, 40% volume    QK  Alcoholic beverages
#
#                                  Sale format(s)  Similarity Score Weight  \
# 0  can, can multipack, bottle, bottle multipack          0.707107   574g
# 1  can, can multipack, bottle, bottle multipack          0.609864    25g
# 2                                        bottle          0.000000    NaN
# 3                                        bottle          0.000000    NaN
# 4                             bottle, miniature          1.000000    29g
#
#   PurEqualCon Portion Consumed Source
# 0           Y           1 pint    NaN
# 1           Y              NaN    NaN
# ...

# %% [markdown]
#                                                     Fruit & Veg

# %% [markdown]
# Cleaning

# %%
FV = Matched.loc[Matched['Super Group'].str.contains('Fruit|Vegetables') ]
a = FV[FV['PurEqualCon']== 'Y']
b = a[~a['Food Code'].isna()]
b['Source'] = 'FPS'
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4260\2627339129.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b['Source'] = 'FPS'

# %%
FV.update(b)
# Out:
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4260\1503287715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FV.update(b)
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4260\1503287715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FV.update(b)
# C:\Users\medekar\AppData\Local\Temp\ipykernel_4260\1503287715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
FV
# Out:
#     Food Code                                          Food Name Group  \
# 153    14-363  apples, cooking, raw, flesh only, weighed with...     F
# 154    14-319                apples, eating, raw, flesh and skin     F
# 155    14-001                                               amla    FA
# 156    14-025                      apricots, raw, flesh and skin    FA
# 157    14-392                 apricots, ready-to-eat, semi-dried    FA
# 158    14-040  avocado, fuerte, flesh only, weighed with skin...    FA
# 159    14-387  avocado, hass, flesh only, weighed with skin a...    FA
# 160    14-331            apple juice, clear, ambient and chilled    FC
# 161    14-043                                 babaco, flesh only    FA
# 162    14-318                            bananas, flesh and skin    FA
# 163    14-388                                  blackberries, raw    FA
# 164    14-053                                 blackcurrants, raw    FA
# ...
